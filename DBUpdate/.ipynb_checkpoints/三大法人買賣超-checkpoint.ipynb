# %% [markdown]
# # Import Modules

# %%
import requests
from datetime import datetime
from pandas import date_range
from time import sleep
# import os

# %%
def ParseData(x):
    try:
        x = x.strip().replace(',', '')
        if x.isnumeric():
            return int(x)
        elif "-" in x:
            return int(x)
        return x
    except:
        return x
col_map = {
        "證券代號":"Ticker",
        "證券名稱":"Name",
        "買進股數":"Buy",
        "賣出股數":"Sell",
        "買賣超股數":"OverBS",
    }
col_otc = ['Ticker', "Name", "Buy", "Sell", "OverBS","Date"]

# %% [markdown]
# # 投信買賣超彙總

# %% [markdown]
# ## 上市

# %%
def GetData_SITC(dt=datetime(2004,12,17)):
    """
    Security Investment Trust Companies - SITC (投信)
    Start With 2004-12-17
    """
    dtStr = dt.strftime("%Y%m%d")
    url = f"https://www.twse.com.tw/fund/TWT44U?response=json&date={dtStr}&_=1645862099918"
    res = requests.get(url)
    js = res.json()

    cols = js['fields'][1:]
    raw_datas = js['data']
    final_datas = []
    for data in raw_datas:
        final_datas.append(dict((col_map[k], ParseData(v)) for k, v in zip(cols, data[1:])))

    return final_datas

# %%
SITC_Data = GetData_SITC()

# %% [markdown]
# ## 上櫃

# %%
def GetData_SITC_OTC(dt=datetime(2007,4,23)):
    """
    OTC
    Security Investment Trust Companies - SITC (投信)
    Start With 2007-04-23
    """
    dtStr = dt.strftime("%Y-%m-%d")
    dateStr = f"{str(dt.year - 1911)}{dt.strftime('/%m/%d')}"
    sellUrl = f"https://www.tpex.org.tw/web/stock/3insti/sitc_trading/sitctr_result.php?l=zh-tw&t=D&type=sell&d={dateStr}&_=1645871498835"
    buyUrl = f"https://www.tpex.org.tw/web/stock/3insti/sitc_trading/sitctr_result.php?l=zh-tw&t=D&type=buy&d={dateStr}&_=1645871498835"
    js_sell = requests.get(sellUrl).json()
    js_buy = requests.get(buyUrl).json()
    final_datas = []
    raw_datas = js_sell['aaData'] + js_buy['aaData']
    for data in raw_datas:
        rows = data[1:] + [dtStr]
        final_datas.append(dict((k, ParseData(v)) for k, v in zip(col_otc, rows)))
    return final_datas

# %%
final_datas = GetData_SITC_OTC()

# %% [markdown]
# # 自營商

# %% [markdown]
# ## 上市

# %%
def GetData_Dealer(dt=datetime(2004,12,17)):
    """
    Dealer (自營商)
    Start With 2004-12-17
    """
    dtStr = dt.strftime("%Y%m%d")
    url = f"https://www.twse.com.tw/fund/TWT43U?response=json&date={dtStr}&_=1645862095882"
    res = requests.get(url)
    js = res.json()

    cols = js['fields'][:2] + js['fields'][-3:]
    raw_datas = js['data']
    final_datas = []
    for data in raw_datas:
        try:
            final_datas.append(dict((col_map[k], ParseData(v)) for k, v in zip(cols, data[:2]+data[-3:])))
        except:
            print(data[:2]+data[-3:])
            break
    return final_datas

# %%
dealer_data = GetData_Dealer()

# %% [markdown]
# ## 上櫃

# %%
def GetData_Dealer_OTC(dt=datetime(2007,4,23)):
    """
    OTC
    Dealer (自營商)
    Start With 2007-04-23
    """
    dtStr = dt.strftime("%Y-%m-%d")
    dateStr = f"{str(dt.year - 1911)}{dt.strftime('/%m/%d')}"
    final_datas = []
    if dt >= datetime(2014,12,1):
        sellUrl = f"https://www.tpex.org.tw/web/stock/3insti/dealer_trading/dealtr_hedge_result.php?l=zh-tw&t=D&type=sell&d={dateStr}&_=1645869758482"
        buyUrl = f"https://www.tpex.org.tw/web/stock/3insti/dealer_trading/dealtr_hedge_result.php?l=zh-tw&t=D&type=buy&d={dateStr}&_=1645869758482"
    else:
        sellUrl = f"https://www.tpex.org.tw/web/stock/3insti/dealer_trading/dealtr_result.php?l=zh-tw&t=D&type=sell&d={dateStr}&_=1645870460266"
        buyUrl = f"https://www.tpex.org.tw/web/stock/3insti/dealer_trading/dealtr_result.php?l=zh-tw&t=D&type=buy&d={dateStr}&_=1645870460266"
    js_sell = requests.get(sellUrl).json()
    js_buy = requests.get(buyUrl).json()
    raw_datas = js_sell['aaData'] + js_buy['aaData']
    for data in raw_datas:
        if dt >= datetime(2014,12,1):
            rows = [data[1],data[2],ParseData(data[3])+ParseData(data[6]),ParseData(data[4])+ParseData(data[7]),ParseData(data[-1]),dtStr]
        else:
            rows = data[1:] + [dtStr]
        final_datas.append(dict((k, ParseData(v)) for k, v in zip(col_otc, rows)))
    return final_datas

# %%
dealer_otc = GetData_Dealer_OTC()

# %%
dealer_otc
# Out:
# [{'Ticker': 70364,
#   'Name': '元富Q9',
#   'Buy': 395,
#   'Sell': 2204,
#   'OverBS': '-1809',
#   'Date': '2007-04-23'},
#  {'Ticker': 5387,
#   'Name': '茂德',
#   'Buy': 20,
#   'Sell': 1353,
#   'OverBS': '-1333',
#   'Date': '2007-04-23'},
#  {'Ticker': 70315,
#   'Name': '群益R9',
#   'Buy': 216,
#   'Sell': 1340,
#   'OverBS': '-1124',
#   'Date': '2007-04-23'},
#  {'Ticker': 70371,
#   'Name': '大華S4',
#   'Buy': 405,
#   'Sell': 1158,
#   'OverBS': '-753',
#   'Date': '2007-04-23'},
#  {'Ticker': 8110,
#   'Name': '華東',
#   'Buy': 0,
#   'Sell': 708,
#   'OverBS': '-708',
#   'Date': '2007-04-23'},
#  {'Ticker': 5326,
#   'Name': '漢磊',
#   'Buy': 95,
#   'Sell': 748,
#   'OverBS': '-653',
#   'Date': '2007-04-23'},
#  {'Ticker': 70246,
#   'Name': '工銀R9',
#   'Buy': 105,
#   'Sell': 730,
#   'OverBS': '-625',
#   'Date': '2007-04-23'},
#  {'Ticker': 3095,
#   'Name': '及成',
#   'Buy': 168,
#   'Sell': 634,
#   'OverBS': '-466',
#   'Date': '2007-04-23'},
#  {'Ticker': 70353,
#   'Name': '寶來Q3',
#   'Buy': 310,
#   'Sell': 772,
#   'OverBS': '-462',
#   'Date': '2007-04-23'},
#  {'Ticker': 70317,
#   'Name': '群益S2',
#   'Buy': 0,
#   'Sell': 393,
#   'OverBS': '-393',
#   'Date': '2007-04-23'},
#  {'Ticker': 70361,
#   'Name': '元富Q8',
#   'Buy': 587,
#   'Sell': 971,
#   'OverBS': '-384',
#   'Date': '2007-04-23'},
#  {'Ticker': 70336,
#   'Name': '寶來P5',
#   'Buy': 95,
#   'Sell': 478,
#   'OverBS': '-383',
#   'Date': '2007-04-23'},
#  {'Ticker': '70348P',
#   'Name': '中信U7',
#   'Buy': 1522,
#   'Sell': 1894,
#   'OverBS': '-372',
#   'Date': '2007-04-23'},
#  {'Ticker': 70363,
#   'Name': '群益S4',
#   'Buy': 0,
#   'Sell': 366,
#   'OverBS': '-366',
#   'Date': '2007-04-23'},
#  {'Ticker': 70303,
#   'Name': '大華R8',
#   'Buy': 0,
#   'Sell': 330,
#   'OverBS': '-330',
#   'Date': '2007-04-23'},
#  {'Ticker': 70385,
#   'Name': '大華S5',
#   'Buy': 7607,
#   'Sell': 582,
#   'OverBS': 7025,
#   'Date': '2007-04-23'},
#  {'Ticker': 70386,
#   'Name': '大華S6',
#   'Buy': 6480,
#   'Sell': 466,
#   'OverBS': 6014,
#   'Date': '2007-04-23'},
#  {'Ticker': 6138,
#   'Name': '茂達',
#   'Buy': 745,
#   'Sell': 33,
#   'OverBS': 712,
#   'Date': '2007-04-23'},
#  {'Ticker': 70356,
#   'Name': '中信U9',
#   'Buy': 3151,
#   'Sell': 2511,
#   'OverBS': 640,
#   'Date': '2007-04-23'},
#  {'Ticker': 70196,
#   'Name': '大華Q7',
#   'Buy': 761,
#   'Sell': 157,
#   'OverBS': 604,
#   'Date': '2007-04-23'},
#  {'Ticker': 8107,
#   'Name': '大億科',
#   'Buy': 640,
#   'Sell': 80,
#   'OverBS': 560,
#   'Date': '2007-04-23'},
#  {'Ticker': 8261,
#   'Name': '富鼎',
#   'Buy': 575,
#   'Sell': 100,
#   'OverBS': 475,
#   'Date': '2007-04-23'},
#  {'Ticker': 6230,
#   'Name': '超眾',
#   'Buy': 506,
#   'Sell': 52,
#   'OverBS': 454,
#   'Date': '2007-04-23'},
#  {'Ticker': 70277,
#   'Name': '中信T4',
#   'Buy': 3093,
#   'Sell': 2639,
#   'OverBS': 454,
#   'Date': '2007-04-23'},
#  {'Ticker': 8054,
#   'Name': '安國',
#   'Buy': 418,
#   'Sell': 44,
#   'OverBS': 374,
#   'Date': '2007-04-23'},
#  {'Ticker': 5521,
#   'Name': '工信',
#   'Buy': 450,
#   'Sell': 110,
#   'OverBS': 340,
#   'Date': '2007-04-23'},
#  {'Ticker': 5483,
#   'Name': '中美晶',
#   'Buy': 318,
#   'Sell': 30,
#   'OverBS': 288,
#   'Date': '2007-04-23'},
#  {'Ticker': 70191,
#   'Name': '元富P6',
#   'Buy': 295,
#   'Sell': 19,
#   'OverBS': 276,
#   'Date': '2007-04-23'},
#  {'Ticker': 70128,
#   'Name': '富邦P6',
#   'Buy': 266,
#   'Sell': 0,
#   'OverBS': 266,
#   'Date': '2007-04-23'},
#  {'Ticker': 70342,
#   'Name': '元富Q5',
#   'Buy': 1121,
#   'Sell': 865,
#   'OverBS': 256,
#   'Date': '2007-04-23'}]

# %%
final_datas
# Out:
# [{'Ticker': '725893',
#   'Name': '金麗科元大15購02',
#   'Buy': 39,
#   'Sell': 3255,
#   'OverBS': '-3216',
#   'Date': '2022-02-25'},
#  {'Ticker': '00888',
#   'Name': '永豐台灣ESG',
#   'Buy': 1163,
#   'Sell': 3014,
#   'OverBS': '-1851',
#   'Date': '2022-02-25'},
#  {'Ticker': '00725B',
#   'Name': '國泰投資級公司債',
#   'Buy': 148,
#   'Sell': 1670,
#   'OverBS': '-1522',
#   'Date': '2022-02-25'},
#  {'Ticker': '00761B',
#   'Name': '國泰A級公司債',
#   'Buy': 106,
#   'Sell': 1602,
#   'OverBS': '-1496',
#   'Date': '2022-02-25'},
#  {'Ticker': '70432P',
#   'Name': '元太元大17售10',
#   'Buy': 551,
#   'Sell': 1931,
#   'OverBS': '-1380',
#   'Date': '2022-02-25'},
#  {'Ticker': '729524',
#   'Name': '萬潤元大18購03',
#   'Buy': 178,
#   'Sell': 1488,
#   'OverBS': '-1310',
#   'Date': '2022-02-25'},
#  {'Ticker': '00722B',
#   'Name': '群益15年IG電信債',
#   'Buy': 112,
#   'Sell': 1277,
#   'OverBS': '-1165',
#   'Date': '2022-02-25'},
#  {'Ticker': '724390',
#   'Name': '大宇資凱基16購01',
#   'Buy': 84,
#   'Sell': 1222,
#   'OverBS': '-1138',
#   'Date': '2022-02-25'},
#  {'Ticker': '00720B',
#   'Name': '元大投資級公司債',
#   'Buy': 154,
#   'Sell': 1284,
#   'OverBS': '-1130',
#   'Date': '2022-02-25'},
#  {'Ticker': '726091',
#   'Name': '金麗科凱基15購02',
#   'Buy': 60,
#   'Sell': 1100,
#   'OverBS': '-1040',
#   'Date': '2022-02-25'},
#  {'Ticker': '726492',
#   'Name': '頎邦國泰17購01',
#   'Buy': 26,
#   'Sell': 944,
#   'OverBS': '-918',
#   'Date': '2022-02-25'},
#  {'Ticker': '70357P',
#   'Name': '力旺中信18售02',
#   'Buy': 60,
#   'Sell': 945,
#   'OverBS': '-885',
#   'Date': '2022-02-25'},
#  {'Ticker': '729245',
#   'Name': '萬潤元大18購02',
#   'Buy': 112,
#   'Sell': 979,
#   'OverBS': '-867',
#   'Date': '2022-02-25'},
#  {'Ticker': '724034',
#   'Name': '大樹元大15購01',
#   'Buy': 446,
#   'Sell': 1302,
#   'OverBS': '-856',
#   'Date': '2022-02-25'},
#  {'Ticker': '729195',
#   'Name': '長聖凱基17購01',
#   'Buy': 5,
#   'Sell': 853,
#   'OverBS': '-848',
#   'Date': '2022-02-25'},
#  {'Ticker': '729433',
#   'Name': '頎邦元大18購02',
#   'Buy': 44,
#   'Sell': 884,
#   'OverBS': '-840',
#   'Date': '2022-02-25'},
#  {'Ticker': '728224',
#   'Name': '頎邦凱基18購01',
#   'Buy': 34,
#   'Sell': 865,
#   'OverBS': '-831',
#   'Date': '2022-02-25'},
#  {'Ticker': '729303',
#   'Name': '萬潤康和18購01',
#   'Buy': 283,
#   'Sell': 1085,
#   'OverBS': '-802',
#   'Date': '2022-02-25'},
#  {'Ticker': '729556',
#   'Name': '群翊凱基18購01',
#   'Buy': 228,
#   'Sell': 1020,
#   'OverBS': '-792',
#   'Date': '2022-02-25'},
#  {'Ticker': '727210',
#   'Name': '創惟凱基17購02',
#   'Buy': 369,
#   'Sell': 1160,
#   'OverBS': '-791',
#   'Date': '2022-02-25'},
#  {'Ticker': '729380',
#   'Name': '翔名凱基17購02',
#   'Buy': 10,
#   'Sell': 798,
#   'OverBS': '-788',
#   'Date': '2022-02-25'},
#  {'Ticker': '730062',
#   'Name': '長聖中信18購02',
#   'Buy': 6,
#   'Sell': 773,
#   'OverBS': '-767',
#   'Date': '2022-02-25'},
#  {'Ticker': '729833',
#   'Name': '大田群益18購01',
#   'Buy': 0,
#   'Sell': 765,
#   'OverBS': '-765',
#   'Date': '2022-02-25'},
#  {'Ticker': '70445P',
#   'Name': '雙鴻元大18售03',
#   'Buy': 160,
#   'Sell': 908,
#   'OverBS': '-748',
#   'Date': '2022-02-25'},
#  {'Ticker': '728800',
#   'Name': '博智元大19購01',
#   'Buy': 117,
#   'Sell': 864,
#   'OverBS': '-747',
#   'Date': '2022-02-25'},
#  {'Ticker': '728587',
#   'Name': '高端永豐17購01',
#   'Buy': 0,
#   'Sell': 732,
#   'OverBS': '-732',
#   'Date': '2022-02-25'},
#  {'Ticker': '728522',
#   'Name': '翔名凱基17購01',
#   'Buy': 0,
#   'Sell': 711,
#   'OverBS': '-711',
#   'Date': '2022-02-25'},
#  {'Ticker': '728760',
#   'Name': '創惟統一18購04',
#   'Buy': 163,
#   'Sell': 869,
#   'OverBS': '-706',
#   'Date': '2022-02-25'},
#  {'Ticker': '727193',
#   'Name': '91APP*元大16購02',
#   'Buy': 0,
#   'Sell': 699,
#   'OverBS': '-699',
#   'Date': '2022-02-25'},
#  {'Ticker': '726147',
#   'Name': '博智群益16購02',
#   'Buy': 134,
#   'Sell': 825,
#   'OverBS': '-691',
#   'Date': '2022-02-25'},
#  {'Ticker': '00724B',
#   'Name': '群益10年IG金融債',
#   'Buy': 112,
#   'Sell': 802,
#   'OverBS': '-690',
#   'Date': '2022-02-25'},
#  {'Ticker': '727945',
#   'Name': '創惟國泰18購03',
#   'Buy': 30,
#   'Sell': 718,
#   'OverBS': '-688',
#   'Date': '2022-02-25'},
#  {'Ticker': '729398',
#   'Name': '金居元大17購06',
#   'Buy': 253,
#   'Sell': 921,
#   'OverBS': '-668',
#   'Date': '2022-02-25'},
#  {'Ticker': '726900',
#   'Name': '萬潤群益15購01',
#   'Buy': 26,
#   'Sell': 669,
#   'OverBS': '-643',
#   'Date': '2022-02-25'},
#  {'Ticker': '728687',
#   'Name': '譜瑞永豐17購02',
#   'Buy': 245,
#   'Sell': 885,
#   'OverBS': '-640',
#   'Date': '2022-02-25'},
#  {'Ticker': '725551',
#   'Name': '頎邦凱基14購03',
#   'Buy': 9,
#   'Sell': 633,
#   'OverBS': '-624',
#   'Date': '2022-02-25'},
#  {'Ticker': '727525',
#   'Name': '信驊元大16購03',
#   'Buy': 145,
#   'Sell': 767,
#   'OverBS': '-622',
#   'Date': '2022-02-25'},
#  {'Ticker': '729209',
#   'Name': '力致永豐17購01',
#   'Buy': 0,
#   'Sell': 611,
#   'OverBS': '-611',
#   'Date': '2022-02-25'},
#  {'Ticker': '727415',
#   'Name': '元太國泰18購01',
#   'Buy': 494,
#   'Sell': 1101,
#   'OverBS': '-607',
#   'Date': '2022-02-25'},
#  {'Ticker': '8390',
#   'Name': '金益鼎',
#   'Buy': 17,
#   'Sell': 622,
#   'OverBS': '-605',
#   'Date': '2022-02-25'},
#  {'Ticker': '728144',
#   'Name': '博智統一19購01',
#   'Buy': 98,
#   'Sell': 693,
#   'OverBS': '-595',
#   'Date': '2022-02-25'},
#  {'Ticker': '728205',
#   'Name': '頎邦永豐16購01',
#   'Buy': 0,
#   'Sell': 589,
#   'OverBS': '-589',
#   'Date': '2022-02-25'},
#  {'Ticker': '725939',
#   'Name': '金麗科永豐15購01',
#   'Buy': 0,
#   'Sell': 582,
#   'OverBS': '-582',
#   'Date': '2022-02-25'},
#  {'Ticker': '729586',
#   'Name': '朋程統一1A購01',
#   'Buy': 18,
#   'Sell': 597,
#   'OverBS': '-579',
#   'Date': '2022-02-25'},
#  {'Ticker': '728056',
#   'Name': '群聯凱基17購05',
#   'Buy': 0,
#   'Sell': 570,
#   'OverBS': '-570',
#   'Date': '2022-02-25'},
#  {'Ticker': '725022',
#   'Name': 'M31永豐14購01',
#   'Buy': 0,
#   'Sell': 550,
#   'OverBS': '-550',
#   'Date': '2022-02-25'},
#  {'Ticker': '729281',
#   'Name': '翔名凱基19購01',
#   'Buy': 0,
#   'Sell': 529,
#   'OverBS': '-529',
#   'Date': '2022-02-25'},
#  {'Ticker': '70080P',
#   'Name': '力旺元大13售02',
#   'Buy': 4230,
#   'Sell': 4742,
#   'OverBS': '-512',
#   'Date': '2022-02-25'},
#  {'Ticker': '729053',
#   'Name': '翔名凱基18購01',
#   'Buy': 0,
#   'Sell': 509,
#   'OverBS': '-509',
#   'Date': '2022-02-25'},
#  {'Ticker': '00746B',
#   'Name': '富邦A級公司債',
#   'Buy': 100,
#   'Sell': 601,
#   'OverBS': '-501',
#   'Date': '2022-02-25'},
#  {'Ticker': '00759B',
#   'Name': 'FH製藥債',
#   'Buy': 100,
#   'Sell': 600,
#   'OverBS': '-500',
#   'Date': '2022-02-25'},
#  {'Ticker': '730002',
#   'Name': '撼訊永豐18購03',
#   'Buy': 0,
#   'Sell': 495,
#   'OverBS': '-495',
#   'Date': '2022-02-25'},
#  {'Ticker': '729386',
#   'Name': '元太群益18購02',
#   'Buy': 31,
#   'Sell': 525,
#   'OverBS': '-494',
#   'Date': '2022-02-25'},
#  {'Ticker': '729844',
#   'Name': '智擎永豐18購01',
#   'Buy': 584,
#   'Sell': 1075,
#   'OverBS': '-491',
#   'Date': '2022-02-25'},
#  {'Ticker': '728592',
#   'Name': '群翊永豐17購01',
#   'Buy': 0,
#   'Sell': 482,
#   'OverBS': '-482',
#   'Date': '2022-02-25'},
#  {'Ticker': '729101',
#   'Name': '金居元大17購05',
#   'Buy': 145,
#   'Sell': 625,
#   'OverBS': '-480',
#   'Date': '2022-02-25'},
#  {'Ticker': '727875',
#   'Name': '創惟群益16購02',
#   'Buy': 551,
#   'Sell': 1030,
#   'OverBS': '-479',
#   'Date': '2022-02-25'},
#  {'Ticker': '725150',
#   'Name': '漢磊國泰16購01',
#   'Buy': 3,
#   'Sell': 480,
#   'OverBS': '-477',
#   'Date': '2022-02-25'},
#  {'Ticker': '729376',
#   'Name': '大田凱基17購01',
#   'Buy': 168,
#   'Sell': 638,
#   'OverBS': '-470',
#   'Date': '2022-02-25'},
#  {'Ticker': '726125',
#   'Name': '大田元大16購01',
#   'Buy': 40,
#   'Sell': 499,
#   'OverBS': '-459',
#   'Date': '2022-02-25'},
#  {'Ticker': '728480',
#   'Name': '信紘科國票18購01',
#   'Buy': 0,
#   'Sell': 450,
#   'OverBS': '-450',
#   'Date': '2022-02-25'},
#  {'Ticker': '724130',
#   'Name': '中美晶元大17購01',
#   'Buy': 25,
#   'Sell': 471,
#   'OverBS': '-446',
#   'Date': '2022-02-25'},
#  {'Ticker': '727053',
#   'Name': '頎邦凱基16購01',
#   'Buy': 20,
#   'Sell': 458,
#   'OverBS': '-438',
#   'Date': '2022-02-25'},
#  {'Ticker': '728002',
#   'Name': '長聖凱基16購02',
#   'Buy': 5,
#   'Sell': 440,
#   'OverBS': '-435',
#   'Date': '2022-02-25'},
#  {'Ticker': '729374',
#   'Name': '撼訊統一19購02',
#   'Buy': 0,
#   'Sell': 430,
#   'OverBS': '-430',
#   'Date': '2022-02-25'},
#  {'Ticker': '728959',
#   'Name': '博智統一19購02',
#   'Buy': 377,
#   'Sell': 805,
#   'OverBS': '-428',
#   'Date': '2022-02-25'},
#  {'Ticker': '729540',
#   'Name': '宜鼎永豐18購01',
#   'Buy': 104,
#   'Sell': 530,
#   'OverBS': '-426',
#   'Date': '2022-02-25'},
#  {'Ticker': '729917',
#   'Name': '雙鴻統一18購01',
#   'Buy': 183,
#   'Sell': 604,
#   'OverBS': '-421',
#   'Date': '2022-02-25'},
#  {'Ticker': '728387',
#   'Name': '智擎永豐17購01',
#   'Buy': 256,
#   'Sell': 674,
#   'OverBS': '-418',
#   'Date': '2022-02-25'},
#  {'Ticker': '3260',
#   'Name': '威剛',
#   'Buy': 141,
#   'Sell': 558,
#   'OverBS': '-417',
#   'Date': '2022-02-25'},
#  {'Ticker': '727501',
#   'Name': '精測兆豐16購01',
#   'Buy': 1,
#   'Sell': 410,
#   'OverBS': '-409',
#   'Date': '2022-02-25'},
#  {'Ticker': '3324',
#   'Name': '雙鴻',
#   'Buy': 339,
#   'Sell': 745,
#   'OverBS': '-406',
#   'Date': '2022-02-25'},
#  {'Ticker': '725896',
#   'Name': '金麗科元大19購01',
#   'Buy': 47,
#   'Sell': 451,
#   'OverBS': '-404',
#   'Date': '2022-02-25'},
#  {'Ticker': '726792',
#   'Name': '元太凱基17購02',
#   'Buy': 1,
#   'Sell': 405,
#   'OverBS': '-404',
#   'Date': '2022-02-25'},
#  {'Ticker': '725025',
#   'Name': '宇峻永豐14購01',
#   'Buy': 0,
#   'Sell': 402,
#   'OverBS': '-402',
#   'Date': '2022-02-25'},
#  {'Ticker': '729954',
#   'Name': '信紘科元大1C購01',
#   'Buy': 9,
#   'Sell': 411,
#   'OverBS': '-402',
#   'Date': '2022-02-25'},
#  {'Ticker': '730055',
#   'Name': '華景電凱基18購01',
#   'Buy': 0,
#   'Sell': 400,
#   'OverBS': '-400',
#   'Date': '2022-02-25'},
#  {'Ticker': '729088',
#   'Name': '榮剛永豐17購01',
#   'Buy': 83,
#   'Sell': 478,
#   'OverBS': '-395',
#   'Date': '2022-02-25'},
#  {'Ticker': '70393P',
#   'Name': '群聯元大17售04',
#   'Buy': 78,
#   'Sell': 472,
#   'OverBS': '-394',
#   'Date': '2022-02-25'},
#  {'Ticker': '729693',
#   'Name': '德微國泰1A購01',
#   'Buy': 0,
#   'Sell': 387,
#   'OverBS': '-387',
#   'Date': '2022-02-25'},
#  {'Ticker': '729686',
#   'Name': '德微凱基18購01',
#   'Buy': 13,
#   'Sell': 399,
#   'OverBS': '-386',
#   'Date': '2022-02-25'},
#  {'Ticker': '728053',
#   'Name': '金居凱基16購03',
#   'Buy': 182,
#   'Sell': 565,
#   'OverBS': '-383',
#   'Date': '2022-02-25'},
#  {'Ticker': '725244',
#   'Name': '湧德元大16購01',
#   'Buy': 7,
#   'Sell': 385,
#   'OverBS': '-378',
#   'Date': '2022-02-25'},
#  {'Ticker': '727155',
#   'Name': '金居元大16購03',
#   'Buy': 92,
#   'Sell': 465,
#   'OverBS': '-373',
#   'Date': '2022-02-25'},
#  {'Ticker': '70335P',
#   'Name': '群聯元大16售07',
#   'Buy': 0,
#   'Sell': 360,
#   'OverBS': '-360',
#   'Date': '2022-02-25'},
#  {'Ticker': '725895',
#   'Name': '金麗科元大17購01',
#   'Buy': 0,
#   'Sell': 355,
#   'OverBS': '-355',
#   'Date': '2022-02-25'},
#  {'Ticker': '725465',
#   'Name': '凡甲永豐14購01',
#   'Buy': 11,
#   'Sell': 363,
#   'OverBS': '-352',
#   'Date': '2022-02-25'},
#  {'Ticker': '724994',
#   'Name': '博智凱基16購01',
#   'Buy': 79,
#   'Sell': 430,
#   'OverBS': '-351',
#   'Date': '2022-02-25'},
#  {'Ticker': '729551',
#   'Name': '金居群益18購01',
#   'Buy': 214,
#   'Sell': 563,
#   'OverBS': '-349',
#   'Date': '2022-02-25'},
#  {'Ticker': '729489',
#   'Name': '朋程永豐18購01',
#   'Buy': 17,
#   'Sell': 363,
#   'OverBS': '-346',
#   'Date': '2022-02-25'},
#  {'Ticker': '729563',
#   'Name': '群翊中信19購01',
#   'Buy': 0,
#   'Sell': 345,
#   'OverBS': '-345',
#   'Date': '2022-02-25'},
#  {'Ticker': '725061',
#   'Name': '太景*群益16購01',
#   'Buy': 54,
#   'Sell': 395,
#   'OverBS': '-341',
#   'Date': '2022-02-25'},
#  {'Ticker': '727117',
#   'Name': '創惟永豐15購04',
#   'Buy': 416,
#   'Sell': 754,
#   'OverBS': '-338',
#   'Date': '2022-02-25'},
#  {'Ticker': '727784',
#   'Name': '創惟群益16購01',
#   'Buy': 11,
#   'Sell': 349,
#   'OverBS': '-338',
#   'Date': '2022-02-25'},
#  {'Ticker': '729355',
#   'Name': '大田元大17購02',
#   'Buy': 12,
#   'Sell': 349,
#   'OverBS': '-337',
#   'Date': '2022-02-25'},
#  {'Ticker': '726435',
#   'Name': '榮剛永豐15購01',
#   'Buy': 16,
#   'Sell': 351,
#   'OverBS': '-335',
#   'Date': '2022-02-25'},
#  {'Ticker': '728299',
#   'Name': '力旺康和17購01',
#   'Buy': 292,
#   'Sell': 624,
#   'OverBS': '-332',
#   'Date': '2022-02-25'},
#  {'Ticker': '725799',
#   'Name': '昇達科凱基15購02',
#   'Buy': 0,
#   'Sell': 325,
#   'OverBS': '-325',
#   'Date': '2022-02-25'},
#  {'Ticker': '729735',
#   'Name': '德微元富19購01',
#   'Buy': 0,
#   'Sell': 323,
#   'OverBS': '-323',
#   'Date': '2022-02-25'},
#  {'Ticker': '727986',
#   'Name': '宇峻國泰18購01',
#   'Buy': 40,
#   'Sell': 358,
#   'OverBS': '-318',
#   'Date': '2022-02-25'},
#  {'Ticker': '729544',
#   'Name': '群翊永豐18購01',
#   'Buy': 0,
#   'Sell': 313,
#   'OverBS': '-313',
#   'Date': '2022-02-25'},
#  {'Ticker': '729366',
#   'Name': '宇峻永豐17購03',
#   'Buy': 0,
#   'Sell': 311,
#   'OverBS': '-311',
#   'Date': '2022-02-25'},
#  {'Ticker': '729076',
#   'Name': '翔名群益17購01',
#   'Buy': 0,
#   'Sell': 309,
#   'OverBS': '-309',
#   'Date': '2022-02-25'},
#  {'Ticker': '70400P',
#   'Name': '創惟國票18售01',
#   'Buy': 42,
#   'Sell': 350,
#   'OverBS': '-308',
#   'Date': '2022-02-25'},
#  {'Ticker': '729256',
#   'Name': '博智凱基19購01',
#   'Buy': 48,
#   'Sell': 351,
#   'OverBS': '-303',
#   'Date': '2022-02-25'},
#  {'Ticker': '722514',
#   'Name': '茂達元大13購02',
#   'Buy': 0,
#   'Sell': 300,
#   'OverBS': '-300',
#   'Date': '2022-02-25'},
#  {'Ticker': '726871',
#   'Name': '威剛統一17購01',
#   'Buy': 0,
#   'Sell': 300,
#   'OverBS': '-300',
#   'Date': '2022-02-25'},
#  {'Ticker': '728633',
#   'Name': '統振凱基19購01',
#   'Buy': 200,
#   'Sell': 499,
#   'OverBS': '-299',
#   'Date': '2022-02-25'},
#  {'Ticker': '725158',
#   'Name': '漢磊群益17購01',
#   'Buy': 25,
#   'Sell': 322,
#   'OverBS': '-297',
#   'Date': '2022-02-25'},
#  {'Ticker': '70108P',
#   'Name': '力旺群益15售02',
#   'Buy': 25,
#   'Sell': 318,
#   'OverBS': '-293',
#   'Date': '2022-02-25'},
#  {'Ticker': '70333P',
#   'Name': '創惟元富19售01',
#   'Buy': 115,
#   'Sell': 408,
#   'OverBS': '-293',
#   'Date': '2022-02-25'},
#  {'Ticker': '726672',
#   'Name': '凡甲統一16購02',
#   'Buy': 8,
#   'Sell': 299,
#   'OverBS': '-291',
#   'Date': '2022-02-25'},
#  {'Ticker': '722643',
#   'Name': '力旺元富17購01',
#   'Buy': 208,
#   'Sell': 496,
#   'OverBS': '-288',
#   'Date': '2022-02-25'},
#  {'Ticker': '723342',
#   'Name': '鈺創元大16購01',
#   'Buy': 100,
#   'Sell': 388,
#   'OverBS': '-288',
#   'Date': '2022-02-25'},
#  {'Ticker': '729559',
#   'Name': '撼訊康和18購02',
#   'Buy': 15,
#   'Sell': 303,
#   'OverBS': '-288',
#   'Date': '2022-02-25'},
#  {'Ticker': '729351',
#   'Name': '博智康和18購01',
#   'Buy': 0,
#   'Sell': 286,
#   'OverBS': '-286',
#   'Date': '2022-02-25'},
#  {'Ticker': '725630',
#   'Name': '榮剛永豐14購01',
#   'Buy': 16,
#   'Sell': 300,
#   'OverBS': '-284',
#   'Date': '2022-02-25'},
#  {'Ticker': '724323',
#   'Name': '雙鴻國票14購01',
#   'Buy': 524,
#   'Sell': 806,
#   'OverBS': '-282',
#   'Date': '2022-02-25'},
#  {'Ticker': '729025',
#   'Name': '信紘科凱基18購01',
#   'Buy': 0,
#   'Sell': 280,
#   'OverBS': '-280',
#   'Date': '2022-02-25'},
#  {'Ticker': '729702',
#   'Name': '德微永豐18購01',
#   'Buy': 0,
#   'Sell': 280,
#   'OverBS': '-280',
#   'Date': '2022-02-25'},
#  {'Ticker': '728663',
#   'Name': '由田群益18購01',
#   'Buy': 0,
#   'Sell': 275,
#   'OverBS': '-275',
#   'Date': '2022-02-25'},
#  {'Ticker': '726434',
#   'Name': '萬潤永豐15購01',
#   'Buy': 85,
#   'Sell': 359,
#   'OverBS': '-274',
#   'Date': '2022-02-25'},
#  {'Ticker': '726035',
#   'Name': '凡甲統一16購01',
#   'Buy': 29,
#   'Sell': 302,
#   'OverBS': '-273',
#   'Date': '2022-02-25'},
#  {'Ticker': '727274',
#   'Name': '凡甲永豐16購01',
#   'Buy': 87,
#   'Sell': 360,
#   'OverBS': '-273',
#   'Date': '2022-02-25'},
#  {'Ticker': '729928',
#   'Name': '鈺太富邦1C購01',
#   'Buy': 100,
#   'Sell': 373,
#   'OverBS': '-273',
#   'Date': '2022-02-25'},
#  {'Ticker': '729571',
#   'Name': '晶焱永豐18購01',
#   'Buy': 223,
#   'Sell': 491,
#   'OverBS': '-268',
#   'Date': '2022-02-25'},
#  {'Ticker': '726109',
#   'Name': '精測元大15購07',
#   'Buy': 0,
#   'Sell': 265,
#   'OverBS': '-265',
#   'Date': '2022-02-25'},
#  {'Ticker': '729480',
#   'Name': '璟德凱基1A購01',
#   'Buy': 0,
#   'Sell': 265,
#   'OverBS': '-265',
#   'Date': '2022-02-25'},
#  {'Ticker': '70209P',
#   'Name': '力旺國票14售03',
#   'Buy': 0,
#   'Sell': 260,
#   'OverBS': '-260',
#   'Date': '2022-02-25'},
#  {'Ticker': '70342P',
#   'Name': '元太統一16售04',
#   'Buy': 0,
#   'Sell': 260,
#   'OverBS': '-260',
#   'Date': '2022-02-25'},
#  {'Ticker': '727454',
#   'Name': '太景*群益17購01',
#   'Buy': 0,
#   'Sell': 259,
#   'OverBS': '-259',
#   'Date': '2022-02-25'},
#  {'Ticker': '729577',
#   'Name': '欣銓元大18購01',
#   'Buy': 0,
#   'Sell': 258,
#   'OverBS': '-258',
#   'Date': '2022-02-25'},
#  {'Ticker': '724817',
#   'Name': '力旺元富16購03',
#   'Buy': 255,
#   'Sell': 511,
#   'OverBS': '-256',
#   'Date': '2022-02-25'},
#  {'Ticker': '729473',
#   'Name': '網家統一1A購02',
#   'Buy': 10,
#   'Sell': 264,
#   'OverBS': '-254',
#   'Date': '2022-02-25'},
#  {'Ticker': '725192',
#   'Name': '鈦昇中信16購01',
#   'Buy': 0,
#   'Sell': 253,
#   'OverBS': '-253',
#   'Date': '2022-02-25'},
#  {'Ticker': '730136',
#   'Name': '朋程永豐18購04',
#   'Buy': 4,
#   'Sell': 257,
#   'OverBS': '-253',
#   'Date': '2022-02-25'},
#  {'Ticker': '727584',
#   'Name': '中美晶元大16購06',
#   'Buy': 0,
#   'Sell': 249,
#   'OverBS': '-249',
#   'Date': '2022-02-25'},
#  {'Ticker': '728021',
#   'Name': '朋程永豐16購02',
#   'Buy': 0,
#   'Sell': 249,
#   'OverBS': '-249',
#   'Date': '2022-02-25'},
#  {'Ticker': '728632',
#   'Name': '統振凱基17購02',
#   'Buy': 450,
#   'Sell': 699,
#   'OverBS': '-249',
#   'Date': '2022-02-25'},
#  {'Ticker': '725631',
#   'Name': '亞信元富17購02',
#   'Buy': 73,
#   'Sell': 320,
#   'OverBS': '-247',
#   'Date': '2022-02-25'},
#  {'Ticker': '727828',
#   'Name': '中美晶元大19購03',
#   'Buy': 0,
#   'Sell': 246,
#   'OverBS': '-246',
#   'Date': '2022-02-25'},
#  {'Ticker': '70345P',
#   'Name': '光頡元富16售03',
#   'Buy': 115,
#   'Sell': 360,
#   'OverBS': '-245',
#   'Date': '2022-02-25'},
#  {'Ticker': '729490',
#   'Name': '精測永豐18購01',
#   'Buy': 0,
#   'Sell': 244,
#   'OverBS': '-244',
#   'Date': '2022-02-25'},
#  {'Ticker': '70410P',
#   'Name': '亞信元大18售03',
#   'Buy': 60,
#   'Sell': 303,
#   'OverBS': '-243',
#   'Date': '2022-02-25'},
#  {'Ticker': '728747',
#   'Name': '博智統一17購02',
#   'Buy': 140,
#   'Sell': 381,
#   'OverBS': '-241',
#   'Date': '2022-02-25'},
#  {'Ticker': '724294',
#   'Name': '群聯元大17購01',
#   'Buy': 368,
#   'Sell': 608,
#   'OverBS': '-240',
#   'Date': '2022-02-25'},
#  {'Ticker': '725441',
#   'Name': '金居國票15購01',
#   'Buy': 100,
#   'Sell': 340,
#   'OverBS': '-240',
#   'Date': '2022-02-25'},
#  {'Ticker': '729016',
#   'Name': '宏捷科元富1A購01',
#   'Buy': 13,
#   'Sell': 253,
#   'OverBS': '-240',
#   'Date': '2022-02-25'},
#  {'Ticker': '730121',
#   'Name': '萬潤國票19購01',
#   'Buy': 0,
#   'Sell': 240,
#   'OverBS': '-240',
#   'Date': '2022-02-25'},
#  {'Ticker': '729533',
#   'Name': '雙鴻中信18購01',
#   'Buy': 173,
#   'Sell': 412,
#   'OverBS': '-239',
#   'Date': '2022-02-25'},
#  {'Ticker': '729246',
#   'Name': '頎邦元大19購01',
#   'Buy': 0,
#   'Sell': 236,
#   'OverBS': '-236',
#   'Date': '2022-02-25'},
#  {'Ticker': '729703',
#   'Name': '德微永豐18購02',
#   'Buy': 0,
#   'Sell': 236,
#   'OverBS': '-236',
#   'Date': '2022-02-25'},
#  {'Ticker': '70351P',
#   'Name': '創惟元富19售02',
#   'Buy': 620,
#   'Sell': 853,
#   'OverBS': '-233',
#   'Date': '2022-02-25'},
#  {'Ticker': '726452',
#   'Name': '金麗科元大15購04',
#   'Buy': 0,
#   'Sell': 230,
#   'OverBS': '-230',
#   'Date': '2022-02-25'},
#  {'Ticker': '726465',
#   'Name': '金麗科統一17購01',
#   'Buy': 0,
#   'Sell': 230,
#   'OverBS': '-230',
#   'Date': '2022-02-25'},
#  {'Ticker': '727633',
#   'Name': '中美晶統一17購01',
#   'Buy': 0,
#   'Sell': 230,
#   'OverBS': '-230',
#   'Date': '2022-02-25'},
#  {'Ticker': '728560',
#   'Name': '高端元富17購02',
#   'Buy': 182,
#   'Sell': 410,
#   'OverBS': '-228',
#   'Date': '2022-02-25'},
#  {'Ticker': '729410',
#   'Name': '凡甲兆豐19購01',
#   'Buy': 10,
#   'Sell': 236,
#   'OverBS': '-226',
#   'Date': '2022-02-25'},
#  {'Ticker': '726878',
#   'Name': '萬潤統一16購01',
#   'Buy': 184,
#   'Sell': 409,
#   'OverBS': '-225',
#   'Date': '2022-02-25'},
#  {'Ticker': '728544',
#   'Name': '信紘科元大17購01',
#   'Buy': 5,
#   'Sell': 230,
#   'OverBS': '-225',
#   'Date': '2022-02-25'},
#  {'Ticker': '729408',
#   'Name': '撼訊永豐17購01',
#   'Buy': 355,
#   'Sell': 580,
#   'OverBS': '-225',
#   'Date': '2022-02-25'},
#  {'Ticker': '728955',
#   'Name': '博智兆豐18購01',
#   'Buy': 0,
#   'Sell': 223,
#   'OverBS': '-223',
#   'Date': '2022-02-25'},
#  {'Ticker': '725892',
#   'Name': '金麗科元大15購01',
#   'Buy': 5,
#   'Sell': 227,
#   'OverBS': '-222',
#   'Date': '2022-02-25'},
#  {'Ticker': '726083',
#   'Name': '永昕永豐15購01',
#   'Buy': 240,
#   'Sell': 461,
#   'OverBS': '-221',
#   'Date': '2022-02-25'},
#  {'Ticker': '725615',
#   'Name': '頎邦元大14購06',
#   'Buy': 239,
#   'Sell': 459,
#   'OverBS': '-220',
#   'Date': '2022-02-25'},
#  {'Ticker': '728473',
#   'Name': '森鉅永豐17購01',
#   'Buy': 55,
#   'Sell': 275,
#   'OverBS': '-220',
#   'Date': '2022-02-25'},
#  {'Ticker': '728330',
#   'Name': '瑞基永豐17購01',
#   'Buy': 0,
#   'Sell': 219,
#   'OverBS': '-219',
#   'Date': '2022-02-25'},
#  {'Ticker': '725447',
#   'Name': '中探針國泰16購02',
#   'Buy': 20,
#   'Sell': 238,
#   'OverBS': '-218',
#   'Date': '2022-02-25'},
#  {'Ticker': '725937',
#   'Name': '昇達科永豐15購02',
#   'Buy': 147,
#   'Sell': 365,
#   'OverBS': '-218',
#   'Date': '2022-02-25'},
#  {'Ticker': '727097',
#   'Name': '茂迪元大18購01',
#   'Buy': 2,
#   'Sell': 220,
#   'OverBS': '-218',
#   'Date': '2022-02-25'},
#  {'Ticker': '00679B',
#   'Name': '元大美債20年',
#   'Buy': 24,
#   'Sell': 240,
#   'OverBS': '-216',
#   'Date': '2022-02-25'},
#  {'Ticker': '723954',
#   'Name': '中美晶元大16購01',
#   'Buy': 18,
#   'Sell': 234,
#   'OverBS': '-216',
#   'Date': '2022-02-25'},
#  {'Ticker': '728257',
#   'Name': '威剛富邦19購01',
#   'Buy': 172,
#   'Sell': 387,
#   'OverBS': '-215',
#   'Date': '2022-02-25'},
#  {'Ticker': '729011',
#   'Name': '博智永豐18購01',
#   'Buy': 0,
#   'Sell': 214,
#   'OverBS': '-214',
#   'Date': '2022-02-25'},
#  {'Ticker': '728412',
#   'Name': '91APP*凱基18購01',
#   'Buy': 0,
#   'Sell': 211,
#   'OverBS': '-211',
#   'Date': '2022-02-25'},
#  {'Ticker': '70414P',
#   'Name': '晶宏元大17售01',
#   'Buy': 10,
#   'Sell': 220,
#   'OverBS': '-210',
#   'Date': '2022-02-25'},
#  {'Ticker': '727894',
#   'Name': '大宇資統一19購01',
#   'Buy': 181,
#   'Sell': 389,
#   'OverBS': '-208',
#   'Date': '2022-02-25'},
#  {'Ticker': '70202P',
#   'Name': '力旺中信17售01',
#   'Buy': 52,
#   'Sell': 259,
#   'OverBS': '-207',
#   'Date': '2022-02-25'},
#  {'Ticker': '726693',
#   'Name': '萬潤兆豐16購01',
#   'Buy': 200,
#   'Sell': 404,
#   'OverBS': '-204',
#   'Date': '2022-02-25'},
#  {'Ticker': '729824',
#   'Name': '德微統一1A購01',
#   'Buy': 8,
#   'Sell': 212,
#   'OverBS': '-204',
#   'Date': '2022-02-25'},
#  {'Ticker': '724474',
#   'Name': '力旺元大17購01',
#   'Buy': 119,
#   'Sell': 322,
#   'OverBS': '-203',
#   'Date': '2022-02-25'},
#  {'Ticker': '728545',
#   'Name': '信紘科元大18購01',
#   'Buy': 0,
#   'Sell': 203,
#   'OverBS': '-203',
#   'Date': '2022-02-25'},
#  {'Ticker': '728767',
#   'Name': '長聖群益17購02',
#   'Buy': 0,
#   'Sell': 202,
#   'OverBS': '-202',
#   'Date': '2022-02-25'},
#  {'Ticker': '70317P',
#   'Name': '創惟元大15售07',
#   'Buy': 0,
#   'Sell': 201,
#   'OverBS': '-201',
#   'Date': '2022-02-25'},
#  {'Ticker': '726882',
#   'Name': '精星統一18購01',
#   'Buy': 0,
#   'Sell': 201,
#   'OverBS': '-201',
#   'Date': '2022-02-25'},
#  {'Ticker': '729655',
#   'Name': '創惟永豐19購01',
#   'Buy': 103,
#   'Sell': 304,
#   'OverBS': '-201',
#   'Date': '2022-02-25'},
#  {'Ticker': '70044P',
#   'Name': '環球晶國票13售02',
#   'Buy': 0,
#   'Sell': 200,
#   'OverBS': '-200',
#   'Date': '2022-02-25'},
#  {'Ticker': '70051P',
#   'Name': '環球晶元大13售06',
#   'Buy': 0,
#   'Sell': 200,
#   'OverBS': '-200',
#   'Date': '2022-02-25'},
#  {'Ticker': '70200P',
#   'Name': '漢磊群益14售03',
#   'Buy': 0,
#   'Sell': 200,
#   'OverBS': '-200',
#   'Date': '2022-02-25'},
#  {'Ticker': '724530',
#   'Name': '世界元大17購02',
#   'Buy': 0,
#   'Sell': 200,
#   'OverBS': '-200',
#   'Date': '2022-02-25'},
#  {'Ticker': '728523',
#   'Name': '華景電凱基17購01',
#   'Buy': 0,
#   'Sell': 200,
#   'OverBS': '-200',
#   'Date': '2022-02-25'},
#  {'Ticker': '728791',
#   'Name': '合晶元大1A購03',
#   'Buy': 0,
#   'Sell': 200,
#   'OverBS': '-200',
#   'Date': '2022-02-25'},
#  {'Ticker': '728992',
#   'Name': '大江統一19購01',
#   'Buy': 0,
#   'Sell': 200,
#   'OverBS': '-200',
#   'Date': '2022-02-25'},
#  {'Ticker': '730047',
#   'Name': '華景電元大1A購01',
#   'Buy': 0,
#   'Sell': 200,
#   'OverBS': '-200',
#   'Date': '2022-02-25'},
#  {'Ticker': '730156',
#   'Name': '華景電統一1B購01',
#   'Buy': 0,
#   'Sell': 200,
#   'OverBS': '-200',
#   'Date': '2022-02-25'},
#  {'Ticker': '729641',
#   'Name': '長聖群益1A購01',
#   'Buy': 0,
#   'Sell': 199,
#   'OverBS': '-199',
#   'Date': '2022-02-25'},
#  {'Ticker': '729653',
#   'Name': '創惟永豐18購03',
#   'Buy': 0,
#   'Sell': 199,
#   'OverBS': '-199',
#   'Date': '2022-02-25'},
#  {'Ticker': '725207',
#   'Name': '漢磊凱基17購01',
#   'Buy': 0,
#   'Sell': 198,
#   'OverBS': '-198',
#   'Date': '2022-02-25'},
#  {'Ticker': '727614',
#   'Name': '萬潤永豐16購01',
#   'Buy': 25,
#   'Sell': 223,
#   'OverBS': '-198',
#   'Date': '2022-02-25'},
#  {'Ticker': '725922',
#   'Name': '金麗科元富15購01',
#   'Buy': 0,
#   'Sell': 197,
#   'OverBS': '-197',
#   'Date': '2022-02-25'},
#  {'Ticker': '00727B',
#   'Name': '國泰1-5Y高收債',
#   'Buy': 101,
#   'Sell': 297,
#   'OverBS': '-196',
#   'Date': '2022-02-25'},
#  {'Ticker': '728844',
#   'Name': '威剛群益18購02',
#   'Buy': 59,
#   'Sell': 255,
#   'OverBS': '-196',
#   'Date': '2022-02-25'},
#  {'Ticker': '70279P',
#   'Name': '信驊元大15售02',
#   'Buy': 0,
#   'Sell': 195,
#   'OverBS': '-195',
#   'Date': '2022-02-25'},
#  {'Ticker': '724579',
#   'Name': '朋程元大13購07',
#   'Buy': 6,
#   'Sell': 200,
#   'OverBS': '-194',
#   'Date': '2022-02-25'},
#  {'Ticker': '724041',
#   'Name': '朋程元大16購01',
#   'Buy': 5,
#   'Sell': 198,
#   'OverBS': '-193',
#   'Date': '2022-02-25'},
#  {'Ticker': '728204',
#   'Name': '博智永豐16購02',
#   'Buy': 2,
#   'Sell': 195,
#   'OverBS': '-193',
#   'Date': '2022-02-25'},
#  {'Ticker': '729467',
#   'Name': '泰博統一18購01',
#   'Buy': 20,
#   'Sell': 211,
#   'OverBS': '-191',
#   'Date': '2022-02-25'},
#  {'Ticker': '725455',
#   'Name': '撼訊凱基15購02',
#   'Buy': 56,
#   'Sell': 246,
#   'OverBS': '-190',
#   'Date': '2022-02-25'},
#  {'Ticker': '726790',
#   'Name': '聚和元大19購01',
#   'Buy': 12,
#   'Sell': 200,
#   'OverBS': '-188',
#   'Date': '2022-02-25'},
#  {'Ticker': '729075',
#   'Name': '信紘科群益17購01',
#   'Buy': 43,
#   'Sell': 230,
#   'OverBS': '-187',
#   'Date': '2022-02-25'},
#  {'Ticker': '724332',
#   'Name': '群聯統一15購02',
#   'Buy': 0,
#   'Sell': 186,
#   'OverBS': '-186',
#   'Date': '2022-02-25'},
#  {'Ticker': '729749',
#   'Name': '鈺太凱基18購01',
#   'Buy': 38,
#   'Sell': 224,
#   'OverBS': '-186',
#   'Date': '2022-02-25'},
#  {'Ticker': '722721',
#   'Name': '朋程元大14購01',
#   'Buy': 0,
#   'Sell': 185,
#   'OverBS': '-185',
#   'Date': '2022-02-25'},
#  {'Ticker': '729185',
#   'Name': '博智元大19購02',
#   'Buy': 15,
#   'Sell': 200,
#   'OverBS': '-185',
#   'Date': '2022-02-25'},
#  {'Ticker': '725766',
#   'Name': '亞信富邦16購01',
#   'Buy': 30,
#   'Sell': 213,
#   'OverBS': '-183',
#   'Date': '2022-02-25'},
#  {'Ticker': '727895',
#   'Name': '元太統一18購05',
#   'Buy': 0,
#   'Sell': 182,
#   'OverBS': '-182',
#   'Date': '2022-02-25'},
#  {'Ticker': '728423',
#   'Name': '榮剛凱基17購01',
#   'Buy': 42,
#   'Sell': 223,
#   'OverBS': '-181',
#   'Date': '2022-02-25'},
#  {'Ticker': '725092',
#   'Name': '同致凱基15購01',
#   'Buy': 0,
#   'Sell': 180,
#   'OverBS': '-180',
#   'Date': '2022-02-25'},
#  {'Ticker': '723589',
#   'Name': '群聯富邦14購01',
#   'Buy': 2,
#   'Sell': 180,
#   'OverBS': '-178',
#   'Date': '2022-02-25'},
#  {'Ticker': '725813',
#   'Name': '昇達科統一16購01',
#   'Buy': 11,
#   'Sell': 189,
#   'OverBS': '-178',
#   'Date': '2022-02-25'},
#  {'Ticker': '728261',
#   'Name': '博智中信16購01',
#   'Buy': 10,
#   'Sell': 186,
#   'OverBS': '-176',
#   'Date': '2022-02-25'},
#  {'Ticker': '724476',
#   'Name': '大宇資元大19購01',
#   'Buy': 114,
#   'Sell': 289,
#   'OverBS': '-175',
#   'Date': '2022-02-25'},
#  {'Ticker': '728565',
#   'Name': '群翊元富1A購01',
#   'Buy': 0,
#   'Sell': 175,
#   'OverBS': '-175',
#   'Date': '2022-02-25'},
#  {'Ticker': '70404P',
#   'Name': '創惟元大17售05',
#   'Buy': 180,
#   'Sell': 354,
#   'OverBS': '-174',
#   'Date': '2022-02-25'},
#  {'Ticker': '730138',
#   'Name': '榮剛永豐18購01',
#   'Buy': 21,
#   'Sell': 194,
#   'OverBS': '-173',
#   'Date': '2022-02-25'},
#  {'Ticker': '727808',
#   'Name': '博智富邦1A購01',
#   'Buy': 5,
#   'Sell': 177,
#   'OverBS': '-172',
#   'Date': '2022-02-25'},
#  {'Ticker': '729378',
#   'Name': '合晶凱基19購03',
#   'Buy': 0,
#   'Sell': 171,
#   'OverBS': '-171',
#   'Date': '2022-02-25'},
#  {'Ticker': '3548',
#   'Name': '兆利',
#   'Buy': 39,
#   'Sell': 209,
#   'OverBS': '-170',
#   'Date': '2022-02-25'},
#  {'Ticker': '725500',
#   'Name': '中探針國票15購02',
#   'Buy': 231,
#   'Sell': 401,
#   'OverBS': '-170',
#   'Date': '2022-02-25'},
#  {'Ticker': '729870',
#   'Name': '網家兆豐18購01',
#   'Buy': 97,
#   'Sell': 267,
#   'OverBS': '-170',
#   'Date': '2022-02-25'},
#  {'Ticker': '00773B',
#   'Name': '中信優先金融債',
#   'Buy': 228,
#   'Sell': 398,
#   'OverBS': '-170',
#   'Date': '2022-02-25'},
#  {'Ticker': '70358P',
#   'Name': '雙鴻國票17售01',
#   'Buy': 37,
#   'Sell': 206,
#   'OverBS': '-169',
#   'Date': '2022-02-25'},
#  {'Ticker': '727657',
#   'Name': '群聯永豐16購02',
#   'Buy': 0,
#   'Sell': 169,
#   'OverBS': '-169',
#   'Date': '2022-02-25'},
#  {'Ticker': '729369',
#   'Name': '統振國票18購01',
#   'Buy': 15,
#   'Sell': 184,
#   'OverBS': '-169',
#   'Date': '2022-02-25'},
#  {'Ticker': '729663',
#   'Name': '金居國票19購01',
#   'Buy': 56,
#   'Sell': 225,
#   'OverBS': '-169',
#   'Date': '2022-02-25'},
#  {'Ticker': '726401',
#   'Name': '金麗科元大15購03',
#   'Buy': 10,
#   'Sell': 178,
#   'OverBS': '-168',
#   'Date': '2022-02-25'},
#  {'Ticker': '728743',
#   'Name': '安格統一1A購01',
#   'Buy': 0,
#   'Sell': 166,
#   'OverBS': '-166',
#   'Date': '2022-02-25'},
#  {'Ticker': '729131',
#   'Name': '金居凱基17購01',
#   'Buy': 162,
#   'Sell': 327,
#   'OverBS': '-165',
#   'Date': '2022-02-25'},
#  {'Ticker': '728447',
#   'Name': '萬潤元大19購01',
#   'Buy': 0,
#   'Sell': 164,
#   'OverBS': '-164',
#   'Date': '2022-02-25'},
#  {'Ticker': '729217',
#   'Name': '晶焱永豐17購03',
#   'Buy': 75,
#   'Sell': 239,
#   'OverBS': '-164',
#   'Date': '2022-02-25'},
#  {'Ticker': '725286',
#   'Name': '網家國泰16購02',
#   'Buy': 235,
#   'Sell': 398,
#   'OverBS': '-163',
#   'Date': '2022-02-25'},
#  {'Ticker': '726603',
#   'Name': '群聯群益15購03',
#   'Buy': 62,
#   'Sell': 224,
#   'OverBS': '-162',
#   'Date': '2022-02-25'},
#  {'Ticker': '727496',
#   'Name': '榮剛元富19購01',
#   'Buy': 26,
#   'Sell': 188,
#   'OverBS': '-162',
#   'Date': '2022-02-25'},
#  {'Ticker': '728634',
#   'Name': '湧德凱基17購01',
#   'Buy': 1,
#   'Sell': 162,
#   'OverBS': '-161',
#   'Date': '2022-02-25'},
#  {'Ticker': '729825',
#   'Name': '德微統一22購01',
#   'Buy': 39,
#   'Sell': 200,
#   'OverBS': '-161',
#   'Date': '2022-02-25'},
#  {'Ticker': '70203P',
#   'Name': '力旺國泰16售01',
#   'Buy': 33,
#   'Sell': 192,
#   'OverBS': '-159',
#   'Date': '2022-02-25'},
#  {'Ticker': '724293',
#   'Name': '群聯元大15購01',
#   'Buy': 27,
#   'Sell': 186,
#   'OverBS': '-159',
#   'Date': '2022-02-25'},
#  {'Ticker': '725995',
#   'Name': '昇達科永豐15購03',
#   'Buy': 27,
#   'Sell': 186,
#   'OverBS': '-159',
#   'Date': '2022-02-25'},
#  {'Ticker': '727767',
#   'Name': '群聯統一16購03',
#   'Buy': 213,
#   'Sell': 372,
#   'OverBS': '-159',
#   'Date': '2022-02-25'},
#  {'Ticker': '727812',
#   'Name': '力旺國票17購01',
#   'Buy': 12,
#   'Sell': 166,
#   'OverBS': '-154',
#   'Date': '2022-02-25'},
#  {'Ticker': '729793',
#   'Name': '德微中信18購01',
#   'Buy': 0,
#   'Sell': 154,
#   'OverBS': '-154',
#   'Date': '2022-02-25'},
#  {'Ticker': '727038',
#   'Name': '撼訊永豐15購01',
#   'Buy': 40,
#   'Sell': 193,
#   'OverBS': '-153',
#   'Date': '2022-02-25'},
#  {'Ticker': '727647',
#   'Name': '群聯元大16購14',
#   'Buy': 166,
#   'Sell': 319,
#   'OverBS': '-153',
#   'Date': '2022-02-25'},
#  {'Ticker': '728436',
#   'Name': '群聯統一18購05',
#   'Buy': 156,
#   'Sell': 308,
#   'OverBS': '-152',
#   'Date': '2022-02-25'},
#  {'Ticker': '729865',
#   'Name': '德微統一19購01',
#   'Buy': 42,
#   'Sell': 194,
#   'OverBS': '-152',
#   'Date': '2022-02-25'},
#  {'Ticker': '70425P',
#   'Name': '光頡中信17售02',
#   'Buy': 50,
#   'Sell': 201,
#   'OverBS': '-151',
#   'Date': '2022-02-25'},
#  {'Ticker': '723428',
#   'Name': '力旺統一14購02',
#   'Buy': 10,
#   'Sell': 161,
#   'OverBS': '-151',
#   'Date': '2022-02-25'},
#  {'Ticker': '728595',
#   'Name': '高端國泰19購01',
#   'Buy': 401,
#   'Sell': 551,
#   'OverBS': '-150',
#   'Date': '2022-02-25'},
#  {'Ticker': '728898',
#   'Name': '鈺太元大17購02',
#   'Buy': 4,
#   'Sell': 154,
#   'OverBS': '-150',
#   'Date': '2022-02-25'},
#  {'Ticker': '727452',
#   'Name': '茂迪國泰18購01',
#   'Buy': 24,
#   'Sell': 173,
#   'OverBS': '-149',
#   'Date': '2022-02-25'},
#  {'Ticker': '725560',
#   'Name': '朋程元大14購06',
#   'Buy': 0,
#   'Sell': 148,
#   'OverBS': '-148',
#   'Date': '2022-02-25'},
#  {'Ticker': '727796',
#   'Name': '博智元大18購01',
#   'Buy': 45,
#   'Sell': 193,
#   'OverBS': '-148',
#   'Date': '2022-02-25'},
#  {'Ticker': '730065',
#   'Name': '六角永豐18購01',
#   'Buy': 161,
#   'Sell': 308,
#   'OverBS': '-147',
#   'Date': '2022-02-25'},
#  {'Ticker': '725863',
#   'Name': '昇達科永豐15購01',
#   'Buy': 131,
#   'Sell': 277,
#   'OverBS': '-146',
#   'Date': '2022-02-25'},
#  {'Ticker': '725975',
#   'Name': '昇達科國泰17購01',
#   'Buy': 277,
#   'Sell': 423,
#   'OverBS': '-146',
#   'Date': '2022-02-25'},
#  {'Ticker': '726201',
#   'Name': '鈊象凱基16購01',
#   'Buy': 4,
#   'Sell': 150,
#   'OverBS': '-146',
#   'Date': '2022-02-25'},
#  {'Ticker': '727390',
#   'Name': '威剛凱基17購01',
#   'Buy': 54,
#   'Sell': 200,
#   'OverBS': '-146',
#   'Date': '2022-02-25'},
#  {'Ticker': '729124',
#   'Name': '群聯元大19購04',
#   'Buy': 2,
#   'Sell': 148,
#   'OverBS': '-146',
#   'Date': '2022-02-25'},
#  {'Ticker': '727081',
#   'Name': '益安永豐15購01',
#   'Buy': 30,
#   'Sell': 175,
#   'OverBS': '-145',
#   'Date': '2022-02-25'},
#  {'Ticker': '728678',
#   'Name': '九齊永豐17購01',
#   'Buy': 50,
#   'Sell': 195,
#   'OverBS': '-145',
#   'Date': '2022-02-25'},
#  {'Ticker': '725470',
#   'Name': '家登永豐14購01',
#   'Buy': 0,
#   'Sell': 144,
#   'OverBS': '-144',
#   'Date': '2022-02-25'},
#  {'Ticker': '8069',
#   'Name': '元太',
#   'Buy': 820,
#   'Sell': 964,
#   'OverBS': '-144',
#   'Date': '2022-02-25'},
#  {'Ticker': '725844',
#   'Name': '昇達科統一17購01',
#   'Buy': 0,
#   'Sell': 143,
#   'OverBS': '-143',
#   'Date': '2022-02-25'},
#  {'Ticker': '728113',
#   'Name': '凡甲國泰18購01',
#   'Buy': 0,
#   'Sell': 143,
#   'OverBS': '-143',
#   'Date': '2022-02-25'},
#  {'Ticker': '728951',
#   'Name': '晶宏元富17購01',
#   'Buy': 503,
#   'Sell': 646,
#   'OverBS': '-143',
#   'Date': '2022-02-25'},
#  {'Ticker': '724421',
#   'Name': '晶焱兆豐15購01',
#   'Buy': 186,
#   'Sell': 328,
#   'OverBS': '-142',
#   'Date': '2022-02-25'},
#  {'Ticker': '725992',
#   'Name': '中光電永豐15購01',
#   'Buy': 5,
#   'Sell': 147,
#   'OverBS': '-142',
#   'Date': '2022-02-25'},
#  {'Ticker': '726259',
#   'Name': '撼訊國泰17購01',
#   'Buy': 20,
#   'Sell': 161,
#   'OverBS': '-141',
#   'Date': '2022-02-25'},
#  {'Ticker': '726861',
#   'Name': '萬潤國票16購01',
#   'Buy': 0,
#   'Sell': 141,
#   'OverBS': '-141',
#   'Date': '2022-02-25'},
#  {'Ticker': '730155',
#   'Name': '智擎統一19購02',
#   'Buy': 0,
#   'Sell': 141,
#   'OverBS': '-141',
#   'Date': '2022-02-25'},
#  {'Ticker': '724481',
#   'Name': '榮剛元大13購07',
#   'Buy': 160,
#   'Sell': 299,
#   'OverBS': '-139',
#   'Date': '2022-02-25'},
#  {'Ticker': '727670',
#   'Name': '茂迪國泰18購02',
#   'Buy': 0,
#   'Sell': 139,
#   'OverBS': '-139',
#   'Date': '2022-02-25'},
#  {'Ticker': '725851',
#   'Name': '博智凱基15購02',
#   'Buy': 106,
#   'Sell': 244,
#   'OverBS': '-138',
#   'Date': '2022-02-25'},
#  {'Ticker': '727631',
#   'Name': '榮剛國票17購01',
#   'Buy': 4,
#   'Sell': 142,
#   'OverBS': '-138',
#   'Date': '2022-02-25'},
#  {'Ticker': '728215',
#   'Name': '群聯統一18購04',
#   'Buy': 53,
#   'Sell': 191,
#   'OverBS': '-138',
#   'Date': '2022-02-25'},
#  {'Ticker': '725724',
#   'Name': '凡甲永豐14購02',
#   'Buy': 6,
#   'Sell': 143,
#   'OverBS': '-137',
#   'Date': '2022-02-25'},
#  {'Ticker': '728079',
#   'Name': '六角永豐16購01',
#   'Buy': 128,
#   'Sell': 265,
#   'OverBS': '-137',
#   'Date': '2022-02-25'},
#  {'Ticker': '727029',
#   'Name': '群聯元大15購08',
#   'Buy': 33,
#   'Sell': 169,
#   'OverBS': '-136',
#   'Date': '2022-02-25'},
#  {'Ticker': '728152',
#   'Name': '漢磊康和18購01',
#   'Buy': 0,
#   'Sell': 136,
#   'OverBS': '-136',
#   'Date': '2022-02-25'},
#  {'Ticker': '729352',
#   'Name': '頎邦康和18購02',
#   'Buy': 0,
#   'Sell': 136,
#   'OverBS': '-136',
#   'Date': '2022-02-25'},
#  {'Ticker': '726450',
#   'Name': '合晶元大17購04',
#   'Buy': 8,
#   'Sell': 143,
#   'OverBS': '-135',
#   'Date': '2022-02-25'},
#  {'Ticker': '729801',
#   'Name': '朋程永豐18購03',
#   'Buy': 0,
#   'Sell': 135,
#   'OverBS': '-135',
#   'Date': '2022-02-25'},
#  {'Ticker': '726977',
#   'Name': '中美晶凱基1B購01',
#   'Buy': 20,
#   'Sell': 154,
#   'OverBS': '-134',
#   'Date': '2022-02-25'},
#  {'Ticker': '727522',
#   'Name': '元太元大1A購01',
#   'Buy': 8,
#   'Sell': 142,
#   'OverBS': '-134',
#   'Date': '2022-02-25'},
#  {'Ticker': '729322',
#   'Name': '茂迪富邦17購01',
#   'Buy': 0,
#   'Sell': 134,
#   'OverBS': '-134',
#   'Date': '2022-02-25'},
#  {'Ticker': '724873',
#   'Name': '博智永豐13購03',
#   'Buy': 7,
#   'Sell': 140,
#   'OverBS': '-133',
#   'Date': '2022-02-25'},
#  {'Ticker': '70443P',
#   'Name': '雙鴻群益1A售01',
#   'Buy': 7,
#   'Sell': 139,
#   'OverBS': '-132',
#   'Date': '2022-02-25'},
#  {'Ticker': '729135',
#   'Name': '博智統一19購03',
#   'Buy': 0,
#   'Sell': 132,
#   'OverBS': '-132',
#   'Date': '2022-02-25'},
#  {'Ticker': '6683',
#   'Name': '雍智科技',
#   'Buy': 22,
#   'Sell': 154,
#   'OverBS': '-132',
#   'Date': '2022-02-25'},
#  {'Ticker': '70081P',
#   'Name': '力旺國票14售01',
#   'Buy': 0,
#   'Sell': 130,
#   'OverBS': '-130',
#   'Date': '2022-02-25'},
#  {'Ticker': '70207P',
#   'Name': '力旺群益14售04',
#   'Buy': 0,
#   'Sell': 130,
#   'OverBS': '-130',
#   'Date': '2022-02-25'},
#  {'Ticker': '724230',
#   'Name': '環球晶元大19購01',
#   'Buy': 1184,
#   'Sell': 1314,
#   'OverBS': '-130',
#   'Date': '2022-02-25'},
#  {'Ticker': '724839',
#   'Name': '力旺統一14購03',
#   'Buy': 0,
#   'Sell': 130,
#   'OverBS': '-130',
#   'Date': '2022-02-25'},
#  {'Ticker': '727805',
#   'Name': '中美晶永豐16購02',
#   'Buy': 178,
#   'Sell': 308,
#   'OverBS': '-130',
#   'Date': '2022-02-25'},
#  {'Ticker': '729539',
#   'Name': '宏觀永豐18購01',
#   'Buy': 20,
#   'Sell': 150,
#   'OverBS': '-130',
#   'Date': '2022-02-25'},
#  {'Ticker': '725856',
#   'Name': '湧德群益16購01',
#   'Buy': 9,
#   'Sell': 138,
#   'OverBS': '-129',
#   'Date': '2022-02-25'},
#  {'Ticker': '728025',
#   'Name': '精測永豐16購01',
#   'Buy': 0,
#   'Sell': 129,
#   'OverBS': '-129',
#   'Date': '2022-02-25'},
#  {'Ticker': '724142',
#   'Name': '環球晶元大15購02',
#   'Buy': 147,
#   'Sell': 275,
#   'OverBS': '-128',
#   'Date': '2022-02-25'},
#  {'Ticker': '725792',
#   'Name': '雍智群益15購01',
#   'Buy': 0,
#   'Sell': 128,
#   'OverBS': '-128',
#   'Date': '2022-02-25'},
#  {'Ticker': '730067',
#   'Name': '亞信永豐18購01',
#   'Buy': 0,
#   'Sell': 128,
#   'OverBS': '-128',
#   'Date': '2022-02-25'},
#  {'Ticker': '727000',
#   'Name': '雙鴻群益17購01',
#   'Buy': 32,
#   'Sell': 159,
#   'OverBS': '-127',
#   'Date': '2022-02-25'},
#  {'Ticker': '728799',
#   'Name': '創惟元大1A購01',
#   'Buy': 245,
#   'Sell': 372,
#   'OverBS': '-127',
#   'Date': '2022-02-25'},
#  {'Ticker': '729846',
#   'Name': '元太凱基19購04',
#   'Buy': 27,
#   'Sell': 154,
#   'OverBS': '-127',
#   'Date': '2022-02-25'},
#  {'Ticker': '724692',
#   'Name': '陸海群益14購01',
#   'Buy': 0,
#   'Sell': 126,
#   'OverBS': '-126',
#   'Date': '2022-02-25'},
#  {'Ticker': '728794',
#   'Name': '朋程元大17購05',
#   'Buy': 5,
#   'Sell': 131,
#   'OverBS': '-126',
#   'Date': '2022-02-25'},
#  {'Ticker': '729624',
#   'Name': '欣銓元大18購02',
#   'Buy': 0,
#   'Sell': 126,
#   'OverBS': '-126',
#   'Date': '2022-02-25'},
#  {'Ticker': '729902',
#   'Name': '網家凱基18購02',
#   'Buy': 23,
#   'Sell': 149,
#   'OverBS': '-126',
#   'Date': '2022-02-25'},
#  {'Ticker': '729594',
#   'Name': '朋程兆豐19購01',
#   'Buy': 108,
#   'Sell': 233,
#   'OverBS': '-125',
#   'Date': '2022-02-25'},
#  {'Ticker': '724961',
#   'Name': '朋程元大14購02',
#   'Buy': 0,
#   'Sell': 123,
#   'OverBS': '-123',
#   'Date': '2022-02-25'},
#  {'Ticker': '726160',
#   'Name': '頎邦康和15購01',
#   'Buy': 0,
#   'Sell': 122,
#   'OverBS': '-122',
#   'Date': '2022-02-25'},
#  {'Ticker': '728279',
#   'Name': '撼訊統一18購02',
#   'Buy': 0,
#   'Sell': 122,
#   'OverBS': '-122',
#   'Date': '2022-02-25'},
#  {'Ticker': '728873',
#   'Name': '博智富邦1C購01',
#   'Buy': 34,
#   'Sell': 156,
#   'OverBS': '-122',
#   'Date': '2022-02-25'},
#  {'Ticker': '728914',
#   'Name': '欣銓永豐17購01',
#   'Buy': 34,
#   'Sell': 156,
#   'OverBS': '-122',
#   'Date': '2022-02-25'},
#  {'Ticker': '729370',
#   'Name': '晶焱國票18購02',
#   'Buy': 14,
#   'Sell': 136,
#   'OverBS': '-122',
#   'Date': '2022-02-25'},
#  {'Ticker': '724879',
#   'Name': '博智元富16購03',
#   'Buy': 112,
#   'Sell': 233,
#   'OverBS': '-121',
#   'Date': '2022-02-25'},
#  {'Ticker': '725618',
#   'Name': '朋程凱基15購02',
#   'Buy': 0,
#   'Sell': 121,
#   'OverBS': '-121',
#   'Date': '2022-02-25'},
#  {'Ticker': '727306',
#   'Name': '力旺凱基17購01',
#   'Buy': 64,
#   'Sell': 185,
#   'OverBS': '-121',
#   'Date': '2022-02-25'},
#  {'Ticker': '728708',
#   'Name': '信紘科凱基17購02',
#   'Buy': 0,
#   'Sell': 121,
#   'OverBS': '-121',
#   'Date': '2022-02-25'},
#  {'Ticker': '728810',
#   'Name': '凡甲統一19購01',
#   'Buy': 11,
#   'Sell': 132,
#   'OverBS': '-121',
#   'Date': '2022-02-25'},
#  {'Ticker': '729347',
#   'Name': '晶焱元富17購01',
#   'Buy': 26,
#   'Sell': 147,
#   'OverBS': '-121',
#   'Date': '2022-02-25'},
#  {'Ticker': '70412P',
#   'Name': '茂達群益17售01',
#   'Buy': 10,
#   'Sell': 130,
#   'OverBS': '-120',
#   'Date': '2022-02-25'},
#  {'Ticker': '725211',
#   'Name': '頎邦富邦16購01',
#   'Buy': 0,
#   'Sell': 120,
#   'OverBS': '-120',
#   'Date': '2022-02-25'},
#  {'Ticker': '725423',
#   'Name': '大江國票15購01',
#   'Buy': 0,
#   'Sell': 120,
#   'OverBS': '-120',
#   'Date': '2022-02-25'},
#  {'Ticker': '726557',
#   'Name': '鈺太元大15購01',
#   'Buy': 46,
#   'Sell': 166,
#   'OverBS': '-120',
#   'Date': '2022-02-25'},
#  {'Ticker': '728686',
#   'Name': '譜瑞永豐17購01',
#   'Buy': 137,
#   'Sell': 257,
#   'OverBS': '-120',
#   'Date': '2022-02-25'},
#  {'Ticker': '727127',
#   'Name': '萬潤富邦18購01',
#   'Buy': 11,
#   'Sell': 130,
#   'OverBS': '-119',
#   'Date': '2022-02-25'},
#  {'Ticker': '730037',
#   'Name': '網家國票18購03',
#   'Buy': 20,
#   'Sell': 139,
#   'OverBS': '-119',
#   'Date': '2022-02-25'},
#  {'Ticker': '6217',
#   'Name': '中探針',
#   'Buy': 41,
#   'Sell': 159,
#   'OverBS': '-118',
#   'Date': '2022-02-25'},
#  {'Ticker': '729242',
#   'Name': '翔名元大18購01',
#   'Buy': 0,
#   'Sell': 118,
#   'OverBS': '-118',
#   'Date': '2022-02-25'},
#  {'Ticker': '729349',
#   'Name': '朋程兆豐18購01',
#   'Buy': 62,
#   'Sell': 180,
#   'OverBS': '-118',
#   'Date': '2022-02-25'},
#  {'Ticker': '725265',
#   'Name': '漢磊凱基15購02',
#   'Buy': 0,
#   'Sell': 117,
#   'OverBS': '-117',
#   'Date': '2022-02-25'},
#  {'Ticker': '725583',
#   'Name': '亞信永豐14購03',
#   'Buy': 22,
#   'Sell': 139,
#   'OverBS': '-117',
#   'Date': '2022-02-25'},
#  {'Ticker': '727658',
#   'Name': '榮剛永豐16購01',
#   'Buy': 17,
#   'Sell': 134,
#   'OverBS': '-117',
#   'Date': '2022-02-25'},
#  {'Ticker': '726694',
#   'Name': '頎邦兆豐17購01',
#   'Buy': 56,
#   'Sell': 172,
#   'OverBS': '-116',
#   'Date': '2022-02-25'},
#  {'Ticker': '2641',
#   'Name': '正德',
#   'Buy': 2,
#   'Sell': 117,
#   'OverBS': '-115',
#   'Date': '2022-02-25'},
#  {'Ticker': '70319P',
#   'Name': '原相凱基15售01',
#   'Buy': 10,
#   'Sell': 125,
#   'OverBS': '-115',
#   'Date': '2022-02-25'},
#  {'Ticker': '728798',
#   'Name': '創惟元大19購02',
#   'Buy': 99,
#   'Sell': 213,
#   'OverBS': '-114',
#   'Date': '2022-02-25'},
#  {'Ticker': '728063',
#   'Name': '朋程群益17購01',
#   'Buy': 12,
#   'Sell': 125,
#   'OverBS': '-113',
#   'Date': '2022-02-25'},
#  {'Ticker': '728965',
#   'Name': '晶宏統一21購01',
#   'Buy': 0,
#   'Sell': 112,
#   'OverBS': '-112',
#   'Date': '2022-02-25'},
#  {'Ticker': '727665',
#   'Name': '優群凱基19購01',
#   'Buy': 50,
#   'Sell': 161,
#   'OverBS': '-111',
#   'Date': '2022-02-25'},
#  {'Ticker': '729434',
#   'Name': '頎邦元大1A購01',
#   'Buy': 7,
#   'Sell': 118,
#   'OverBS': '-111',
#   'Date': '2022-02-25'},
#  {'Ticker': '00756B',
#   'Name': '群益15年EM主權債',
#   'Buy': 104,
#   'Sell': 214,
#   'OverBS': '-110',
#   'Date': '2022-02-25'},
#  {'Ticker': '724146',
#   'Name': '茂迪元富14購01',
#   'Buy': 0,
#   'Sell': 110,
#   'OverBS': '-110',
#   'Date': '2022-02-25'},
#  {'Ticker': '724954',
#   'Name': '金居凱基18購01',
#   'Buy': 26,
#   'Sell': 136,
#   'OverBS': '-110',
#   'Date': '2022-02-25'},
#  {'Ticker': '725870',
#   'Name': '鈺太永豐15購01',
#   'Buy': 138,
#   'Sell': 248,
#   'OverBS': '-110',
#   'Date': '2022-02-25'},
#  {'Ticker': '727188',
#   'Name': '合晶統一1B購02',
#   'Buy': 0,
#   'Sell': 110,
#   'OverBS': '-110',
#   'Date': '2022-02-25'},
#  {'Ticker': '728149',
#   'Name': '博智元富19購01',
#   'Buy': 2,
#   'Sell': 112,
#   'OverBS': '-110',
#   'Date': '2022-02-25'},
#  {'Ticker': '728559',
#   'Name': '高端元富17購01',
#   'Buy': 0,
#   'Sell': 110,
#   'OverBS': '-110',
#   'Date': '2022-02-25'},
#  {'Ticker': '726194',
#   'Name': '中美晶凱基17購01',
#   'Buy': 0,
#   'Sell': 109,
#   'OverBS': '-109',
#   'Date': '2022-02-25'},
#  {'Ticker': '726446',
#   'Name': '榮剛凱基16購01',
#   'Buy': 1,
#   'Sell': 110,
#   'OverBS': '-109',
#   'Date': '2022-02-25'},
#  {'Ticker': '727031',
#   'Name': '穩懋元大16購01',
#   'Buy': 4,
#   'Sell': 113,
#   'OverBS': '-109',
#   'Date': '2022-02-25'},
#  {'Ticker': '729727',
#   'Name': '德微元大18購01',
#   'Buy': 38,
#   'Sell': 147,
#   'OverBS': '-109',
#   'Date': '2022-02-25'},
#  {'Ticker': '725156',
#   'Name': '漢磊群益15購02',
#   'Buy': 10,
#   'Sell': 118,
#   'OverBS': '-108',
#   'Date': '2022-02-25'},
#  {'Ticker': '725300',
#   'Name': '亞信永豐14購02',
#   'Buy': 0,
#   'Sell': 108,
#   'OverBS': '-108',
#   'Date': '2022-02-25'},
#  {'Ticker': '727051',
#   'Name': '萬潤凱基16購01',
#   'Buy': 21,
#   'Sell': 129,
#   'OverBS': '-108',
#   'Date': '2022-02-25'},
#  {'Ticker': '729845',
#   'Name': '中美晶凱基19購04',
#   'Buy': 5,
#   'Sell': 113,
#   'OverBS': '-108',
#   'Date': '2022-02-25'},
#  {'Ticker': '729567',
#   'Name': '朋程永豐18購02',
#   'Buy': 0,
#   'Sell': 107,
#   'OverBS': '-107',
#   'Date': '2022-02-25'},
#  {'Ticker': '725582',
#   'Name': '中光電永豐14購01',
#   'Buy': 6,
#   'Sell': 111,
#   'OverBS': '-105',
#   'Date': '2022-02-25'},
#  {'Ticker': '729788',
#   'Name': '瑞基元大1A購01',
#   'Buy': 0,
#   'Sell': 104,
#   'OverBS': '-104',
#   'Date': '2022-02-25'},
#  {'Ticker': '730135',
#   'Name': '亞信永豐1A購01',
#   'Buy': 0,
#   'Sell': 104,
#   'OverBS': '-104',
#   'Date': '2022-02-25'},
#  {'Ticker': '00772B',
#   'Name': '中信高評級公司債',
#   'Buy': 623,
#   'Sell': 727,
#   'OverBS': '-104',
#   'Date': '2022-02-25'},
#  {'Ticker': '6208',
#   'Name': '日揚',
#   'Buy': 0,
#   'Sell': 103,
#   'OverBS': '-103',
#   'Date': '2022-02-25'},
#  {'Ticker': '726647',
#   'Name': '威剛群益15購04',
#   'Buy': 29,
#   'Sell': 132,
#   'OverBS': '-103',
#   'Date': '2022-02-25'},
#  {'Ticker': '726743',
#   'Name': '群聯元大19購01',
#   'Buy': 30,
#   'Sell': 133,
#   'OverBS': '-103',
#   'Date': '2022-02-25'},
#  {'Ticker': '727177',
#   'Name': '正德國票17購01',
#   'Buy': 118,
#   'Sell': 221,
#   'OverBS': '-103',
#   'Date': '2022-02-25'},
#  {'Ticker': '728345',
#   'Name': '宣德統一1B購01',
#   'Buy': 20,
#   'Sell': 123,
#   'OverBS': '-103',
#   'Date': '2022-02-25'},
#  {'Ticker': '70216P',
#   'Name': '璟德國票15售02',
#   'Buy': 0,
#   'Sell': 102,
#   'OverBS': '-102',
#   'Date': '2022-02-25'},
#  {'Ticker': '70285P',
#   'Name': '力旺元富15售04',
#   'Buy': 0,
#   'Sell': 102,
#   'OverBS': '-102',
#   'Date': '2022-02-25'},
#  {'Ticker': '727325',
#   'Name': '群聯元大16購06',
#   'Buy': 35,
#   'Sell': 137,
#   'OverBS': '-102',
#   'Date': '2022-02-25'},
#  {'Ticker': '727909',
#   'Name': '瑞基元大16購02',
#   'Buy': 4,
#   'Sell': 106,
#   'OverBS': '-102',
#   'Date': '2022-02-25'},
#  {'Ticker': '730069',
#   'Name': '家登永豐19購01',
#   'Buy': 26,
#   'Sell': 128,
#   'OverBS': '-102',
#   'Date': '2022-02-25'},
#  {'Ticker': '726144',
#   'Name': '亞信群益15購01',
#   'Buy': 57,
#   'Sell': 158,
#   'OverBS': '-101',
#   'Date': '2022-02-25'},
#  {'Ticker': '726485',
#   'Name': '長聖永豐15購01',
#   'Buy': 10,
#   'Sell': 111,
#   'OverBS': '-101',
#   'Date': '2022-02-25'},
#  {'Ticker': '728011',
#   'Name': '伍豐元富16購01',
#   'Buy': 499,
#   'Sell': 600,
#   'OverBS': '-101',
#   'Date': '2022-02-25'},
#  {'Ticker': '70274P',
#   'Name': '中光電中信15售03',
#   'Buy': 0,
#   'Sell': 100,
#   'OverBS': '-100',
#   'Date': '2022-02-25'},
#  {'Ticker': '70366P',
#   'Name': '群聯康和16售03',
#   'Buy': 0,
#   'Sell': 100,
#   'OverBS': '-100',
#   'Date': '2022-02-25'},
#  {'Ticker': '722012',
#   'Name': '大中凱基13購01',
#   'Buy': 100,
#   'Sell': 200,
#   'OverBS': '-100',
#   'Date': '2022-02-25'},
#  {'Ticker': '723343',
#   'Name': '頎邦元大16購01',
#   'Buy': 0,
#   'Sell': 100,
#   'OverBS': '-100',
#   'Date': '2022-02-25'},
#  {'Ticker': '723497',
#   'Name': '鈺太凱基14購01',
#   'Buy': 0,
#   'Sell': 100,
#   'OverBS': '-100',
#   'Date': '2022-02-25'},
#  {'Ticker': '724884',
#   'Name': '信音國票14購01',
#   'Buy': 0,
#   'Sell': 100,
#   'OverBS': '-100',
#   'Date': '2022-02-25'},
#  {'Ticker': '725486',
#   'Name': '昇佳電群益14購04',
#   'Buy': 0,
#   'Sell': 100,
#   'OverBS': '-100',
#   'Date': '2022-02-25'},
#  {'Ticker': '725907',
#   'Name': '穩懋凱基15購02',
#   'Buy': 0,
#   'Sell': 100,
#   'OverBS': '-100',
#   'Date': '2022-02-25'},
#  {'Ticker': '725961',
#   'Name': '群聯統一15購03',
#   'Buy': 30,
#   'Sell': 130,
#   'OverBS': '-100',
#   'Date': '2022-02-25'},
#  {'Ticker': '726864',
#   'Name': '點序國票16購01',
#   'Buy': 0,
#   'Sell': 100,
#   'OverBS': '-100',
#   'Date': '2022-02-25'},
#  {'Ticker': '726966',
#   'Name': '金居國票16購01',
#   'Buy': 0,
#   'Sell': 100,
#   'OverBS': '-100',
#   'Date': '2022-02-25'},
#  {'Ticker': '727006',
#   'Name': '元太元富16購02',
#   'Buy': 0,
#   'Sell': 100,
#   'OverBS': '-100',
#   'Date': '2022-02-25'},
#  {'Ticker': '727333',
#   'Name': '家登凱基19購01',
#   'Buy': 0,
#   'Sell': 100,
#   'OverBS': '-100',
#   'Date': '2022-02-25'},
#  {'Ticker': '728288',
#   'Name': '茂達凱基19購01',
#   'Buy': 0,
#   'Sell': 100,
#   'OverBS': '-100',
#   'Date': '2022-02-25'},
#  {'Ticker': '728482',
#   'Name': '高端國票18購01',
#   'Buy': 0,
#   'Sell': 100,
#   'OverBS': '-100',
#   'Date': '2022-02-25'},
#  {'Ticker': '728562',
#   'Name': '華景電元富1A購02',
#   'Buy': 100,
#   'Sell': 200,
#   'OverBS': '-100',
#   'Date': '2022-02-25'},
#  {'Ticker': '728579',
#   'Name': '由田永豐17購02',
#   'Buy': 0,
#   'Sell': 100,
#   'OverBS': '-100',
#   'Date': '2022-02-25'},
#  {'Ticker': '728691',
#   'Name': '中美晶元大1A購01',
#   'Buy': 0,
#   'Sell': 100,
#   'OverBS': '-100',
#   'Date': '2022-02-25'},
#  {'Ticker': '729838',
#   'Name': '禾瑞亞中信1A購01',
#   'Buy': 0,
#   'Sell': 100,
#   'OverBS': '-100',
#   'Date': '2022-02-25'},
#  {'Ticker': '730133',
#   'Name': '宏觀永豐19購01',
#   'Buy': 0,
#   'Sell': 100,
#   'OverBS': '-100',
#   'Date': '2022-02-25'},
#  {'Ticker': '730144',
#   'Name': '翔名元大1A購01',
#   'Buy': 0,
#   'Sell': 100,
#   'OverBS': '-100',
#   'Date': '2022-02-25'},
#  {'Ticker': '725228',
#   'Name': '中美晶元富14購03',
#   'Buy': 2,
#   'Sell': 101,
#   'OverBS': '-99',
#   'Date': '2022-02-25'},
#  {'Ticker': '725719',
#   'Name': '智崴凱基14購01',
#   'Buy': 0,
#   'Sell': 99,
#   'OverBS': '-99',
#   'Date': '2022-02-25'},
#  {'Ticker': '727699',
#   'Name': '大田凱基16購01',
# ...
#   'Name': '海韻電元富19購01',
#   'Buy': 0,
#   'Sell': 30,
#   'OverBS': '-30',
#   'Date': '2022-02-25'},
#  {'Ticker': '728368',
#   'Name': '穩懋富邦19購01',
#   'Buy': 0,
#   'Sell': 30,
#   'OverBS': '-30',
#   'Date': '2022-02-25'},
#  {'Ticker': '728540',
#   'Name': '立碁元大19購01',
#   'Buy': 0,
#   'Sell': 30,
#   'OverBS': '-30',
#   'Date': '2022-02-25'},
#  {'Ticker': '728641',
#   'Name': '大國鋼元大17購02',
#   'Buy': 0,
#   'Sell': 30,
#   'OverBS': '-30',
#   'Date': '2022-02-25'},
#  {'Ticker': '728896',
#   'Name': '群聯元大19購03',
#   'Buy': 7,
#   'Sell': 37,
#   'OverBS': '-30',
#   'Date': '2022-02-25'},
#  {'Ticker': '729326',
#   'Name': '台燿統一19購01',
#   'Buy': 0,
#   'Sell': 30,
#   'OverBS': '-30',
#   'Date': '2022-02-25'},
#  {'Ticker': '729340',
#   'Name': '湧德群益19購01',
#   'Buy': 4,
#   'Sell': 34,
#   'OverBS': '-30',
#   'Date': '2022-02-25'},
#  {'Ticker': '729765',
#   'Name': '大國鋼群益18購01',
#   'Buy': 0,
#   'Sell': 30,
#   'OverBS': '-30',
#   'Date': '2022-02-25'},
#  {'Ticker': '729856',
#   'Name': '漢科凱基18購01',
#   'Buy': 0,
#   'Sell': 30,
#   'OverBS': '-30',
#   'Date': '2022-02-25'},
#  {'Ticker': '729908',
#   'Name': '同致統一1A購02',
#   'Buy': 0,
#   'Sell': 30,
#   'OverBS': '-30',
#   'Date': '2022-02-25'},
#  {'Ticker': '729957',
#   'Name': '鈦昇元大1B購01',
#   'Buy': 0,
#   'Sell': 30,
#   'OverBS': '-30',
#   'Date': '2022-02-25'},
#  {'Ticker': '3624',
#   'Name': '光頡',
#   'Buy': 1,
#   'Sell': 31,
#   'OverBS': '-30',
#   'Date': '2022-02-25'},
#  {'Ticker': '4123',
#   'Name': '晟德',
#   'Buy': 10,
#   'Sell': 40,
#   'OverBS': '-30',
#   'Date': '2022-02-25'},
#  {'Ticker': '3527',
#   'Name': '聚積',
#   'Buy': 1,
#   'Sell': 30,
#   'OverBS': '-29',
#   'Date': '2022-02-25'},
#  {'Ticker': '725320',
#   'Name': '朋程兆豐15購01',
#   'Buy': 269,
#   'Sell': 298,
#   'OverBS': '-29',
#   'Date': '2022-02-25'},
#  {'Ticker': '725959',
#   'Name': '茂達統一17購01',
#   'Buy': 98,
#   'Sell': 127,
#   'OverBS': '-29',
#   'Date': '2022-02-25'},
#  {'Ticker': '728229',
#   'Name': '凡甲群益16購03',
#   'Buy': 5,
#   'Sell': 34,
#   'OverBS': '-29',
#   'Date': '2022-02-25'},
#  {'Ticker': '729168',
#   'Name': '金居元富17購01',
#   'Buy': 25,
#   'Sell': 54,
#   'OverBS': '-29',
#   'Date': '2022-02-25'},
#  {'Ticker': '729604',
#   'Name': '晶焱元富19購01',
#   'Buy': 73,
#   'Sell': 102,
#   'OverBS': '-29',
#   'Date': '2022-02-25'},
#  {'Ticker': '729823',
#   'Name': '頎邦統一18購01',
#   'Buy': 0,
#   'Sell': 29,
#   'OverBS': '-29',
#   'Date': '2022-02-25'},
#  {'Ticker': '729942',
#   'Name': '穩懋永豐18購01',
#   'Buy': 0,
#   'Sell': 29,
#   'OverBS': '-29',
#   'Date': '2022-02-25'},
#  {'Ticker': '729997',
#   'Name': '中光電永豐18購01',
#   'Buy': 5,
#   'Sell': 34,
#   'OverBS': '-29',
#   'Date': '2022-02-25'},
#  {'Ticker': '730105',
#   'Name': '欣銓凱基18購02',
#   'Buy': 5,
#   'Sell': 34,
#   'OverBS': '-29',
#   'Date': '2022-02-25'},
#  {'Ticker': '730112',
#   'Name': '朋程兆豐19購02',
#   'Buy': 5,
#   'Sell': 34,
#   'OverBS': '-29',
#   'Date': '2022-02-25'},
#  {'Ticker': '725432',
#   'Name': '台半元富14購01',
#   'Buy': 0,
#   'Sell': 28,
#   'OverBS': '-28',
#   'Date': '2022-02-25'},
#  {'Ticker': '725435',
#   'Name': '博智元富17購01',
#   'Buy': 0,
#   'Sell': 28,
#   'OverBS': '-28',
#   'Date': '2022-02-25'},
#  {'Ticker': '726405',
#   'Name': '中光電群益16購02',
#   'Buy': 10,
#   'Sell': 38,
#   'OverBS': '-28',
#   'Date': '2022-02-25'},
#  {'Ticker': '727857',
#   'Name': '元太中信16購02',
#   'Buy': 30,
#   'Sell': 58,
#   'OverBS': '-28',
#   'Date': '2022-02-25'},
#  {'Ticker': '728340',
#   'Name': '漢磊國票17購01',
#   'Buy': 0,
#   'Sell': 28,
#   'OverBS': '-28',
#   'Date': '2022-02-25'},
#  {'Ticker': '729520',
#   'Name': '家登統一1A購02',
#   'Buy': 3,
#   'Sell': 31,
#   'OverBS': '-28',
#   'Date': '2022-02-25'},
#  {'Ticker': '724949',
#   'Name': '宜鼎國票15購01',
#   'Buy': 0,
#   'Sell': 27,
#   'OverBS': '-27',
#   'Date': '2022-02-25'},
#  {'Ticker': '725164',
#   'Name': '中探針元大14購02',
#   'Buy': 24,
#   'Sell': 51,
#   'OverBS': '-27',
#   'Date': '2022-02-25'},
#  {'Ticker': '725845',
#   'Name': '昇達科統一17購02',
#   'Buy': 0,
#   'Sell': 27,
#   'OverBS': '-27',
#   'Date': '2022-02-25'},
#  {'Ticker': '726408',
#   'Name': '創惟群益18購01',
#   'Buy': 39,
#   'Sell': 66,
#   'OverBS': '-27',
#   'Date': '2022-02-25'},
#  {'Ticker': '727542',
#   'Name': '泰博凱基16購01',
#   'Buy': 0,
#   'Sell': 27,
#   'OverBS': '-27',
#   'Date': '2022-02-25'},
#  {'Ticker': '728038',
#   'Name': '元太元大16購14',
#   'Buy': 53,
#   'Sell': 80,
#   'OverBS': '-27',
#   'Date': '2022-02-25'},
#  {'Ticker': '728457',
#   'Name': '晶焱群益19購01',
#   'Buy': 73,
#   'Sell': 100,
#   'OverBS': '-27',
#   'Date': '2022-02-25'},
#  {'Ticker': '728866',
#   'Name': '瑞基凱基17購01',
#   'Buy': 5,
#   'Sell': 32,
#   'OverBS': '-27',
#   'Date': '2022-02-25'},
#  {'Ticker': '728948',
#   'Name': '晶宏永豐17購03',
#   'Buy': 43,
#   'Sell': 70,
#   'OverBS': '-27',
#   'Date': '2022-02-25'},
#  {'Ticker': '729956',
#   'Name': '崧騰元大19購01',
#   'Buy': 8,
#   'Sell': 35,
#   'OverBS': '-27',
#   'Date': '2022-02-25'},
#  {'Ticker': '00849B',
#   'Name': '中信EM主權債0-5',
#   'Buy': 86,
#   'Sell': 112,
#   'OverBS': '-26',
#   'Date': '2022-02-25'},
#  {'Ticker': '727656',
#   'Name': '閎康永豐16購01',
#   'Buy': 21,
#   'Sell': 47,
#   'OverBS': '-26',
#   'Date': '2022-02-25'},
#  {'Ticker': '728655',
#   'Name': '榮剛元大17購01',
#   'Buy': 11,
#   'Sell': 37,
#   'OverBS': '-26',
#   'Date': '2022-02-25'},
#  {'Ticker': '729291',
#   'Name': '穩懋元大19購01',
#   'Buy': 10,
#   'Sell': 36,
#   'OverBS': '-26',
#   'Date': '2022-02-25'},
#  {'Ticker': '730097',
#   'Name': '群聯元大18購03',
#   'Buy': 8,
#   'Sell': 34,
#   'OverBS': '-26',
#   'Date': '2022-02-25'},
#  {'Ticker': '8076',
#   'Name': '伍豐',
#   'Buy': 0,
#   'Sell': 25,
#   'OverBS': '-25',
#   'Date': '2022-02-25'},
#  {'Ticker': '70463P',
#   'Name': '博智中信18售01',
#   'Buy': 0,
#   'Sell': 25,
#   'OverBS': '-25',
#   'Date': '2022-02-25'},
#  {'Ticker': '723658',
#   'Name': '聚積元大14購01',
#   'Buy': 201,
#   'Sell': 226,
#   'OverBS': '-25',
#   'Date': '2022-02-25'},
#  {'Ticker': '724454',
#   'Name': '安國群益16購01',
#   'Buy': 0,
#   'Sell': 25,
#   'OverBS': '-25',
#   'Date': '2022-02-25'},
#  {'Ticker': '725836',
#   'Name': '精星永豐15購01',
#   'Buy': 0,
#   'Sell': 25,
#   'OverBS': '-25',
#   'Date': '2022-02-25'},
#  {'Ticker': '725840',
#   'Name': 'M31統一17購01',
#   'Buy': 5,
#   'Sell': 30,
#   'OverBS': '-25',
#   'Date': '2022-02-25'},
#  {'Ticker': '726192',
#   'Name': '家登永豐15購01',
#   'Buy': 0,
#   'Sell': 25,
#   'OverBS': '-25',
#   'Date': '2022-02-25'},
#  {'Ticker': '726244',
#   'Name': '穩懋第一1B購01',
#   'Buy': 0,
#   'Sell': 25,
#   'OverBS': '-25',
#   'Date': '2022-02-25'},
#  {'Ticker': '726316',
#   'Name': '亞信元富18購01',
#   'Buy': 23,
#   'Sell': 48,
#   'OverBS': '-25',
#   'Date': '2022-02-25'},
#  {'Ticker': '727782',
#   'Name': '金居群益16購03',
#   'Buy': 5,
#   'Sell': 30,
#   'OverBS': '-25',
#   'Date': '2022-02-25'},
#  {'Ticker': '728403',
#   'Name': '威剛元大17購04',
#   'Buy': 1,
#   'Sell': 26,
#   'OverBS': '-25',
#   'Date': '2022-02-25'},
#  {'Ticker': '728485',
#   'Name': '由田統一19購01',
#   'Buy': 0,
#   'Sell': 25,
#   'OverBS': '-25',
#   'Date': '2022-02-25'},
#  {'Ticker': '728566',
#   'Name': '鈺太元富17購02',
#   'Buy': 7,
#   'Sell': 32,
#   'OverBS': '-25',
#   'Date': '2022-02-25'},
#  {'Ticker': '729007',
#   'Name': '大學光永豐17購01',
#   'Buy': 10,
#   'Sell': 35,
#   'OverBS': '-25',
#   'Date': '2022-02-25'},
#  {'Ticker': '729177',
#   'Name': '統振群益17購02',
#   'Buy': 100,
#   'Sell': 125,
#   'OverBS': '-25',
#   'Date': '2022-02-25'},
#  {'Ticker': '729385',
#   'Name': '中美晶群益17購06',
#   'Buy': 0,
#   'Sell': 25,
#   'OverBS': '-25',
#   'Date': '2022-02-25'},
#  {'Ticker': '729558',
#   'Name': '凡甲康和18購01',
#   'Buy': 0,
#   'Sell': 25,
#   'OverBS': '-25',
#   'Date': '2022-02-25'},
#  {'Ticker': '730028',
#   'Name': '美琪瑪統一1A購02',
#   'Buy': 0,
#   'Sell': 25,
#   'OverBS': '-25',
#   'Date': '2022-02-25'},
#  {'Ticker': '730146',
#   'Name': '鈺太元大18購04',
#   'Buy': 25,
#   'Sell': 50,
#   'OverBS': '-25',
#   'Date': '2022-02-25'},
#  {'Ticker': '5347',
#   'Name': '世界',
#   'Buy': 17,
#   'Sell': 41,
#   'OverBS': '-24',
#   'Date': '2022-02-25'},
#  {'Ticker': '722462',
#   'Name': '聚積元富14購01',
#   'Buy': 0,
#   'Sell': 24,
#   'OverBS': '-24',
#   'Date': '2022-02-25'},
#  {'Ticker': '725598',
#   'Name': '閎康國票15購01',
#   'Buy': 0,
#   'Sell': 24,
#   'OverBS': '-24',
#   'Date': '2022-02-25'},
#  {'Ticker': '727130',
#   'Name': '正德凱基16購02',
#   'Buy': 197,
#   'Sell': 221,
#   'OverBS': '-24',
#   'Date': '2022-02-25'},
#  {'Ticker': '727196',
#   'Name': '佳邦元大16購01',
#   'Buy': 0,
#   'Sell': 24,
#   'OverBS': '-24',
#   'Date': '2022-02-25'},
#  {'Ticker': '727515',
#   'Name': '光頡永豐16購03',
#   'Buy': 8,
#   'Sell': 32,
#   'OverBS': '-24',
#   'Date': '2022-02-25'},
#  {'Ticker': '728234',
#   'Name': '晶焱群益1C購01',
#   'Buy': 35,
#   'Sell': 59,
#   'OverBS': '-24',
#   'Date': '2022-02-25'},
#  {'Ticker': '728605',
#   'Name': '信紘科群益18購01',
#   'Buy': 6,
#   'Sell': 30,
#   'OverBS': '-24',
#   'Date': '2022-02-25'},
#  {'Ticker': '728912',
#   'Name': '佳邦永豐17購01',
#   'Buy': 0,
#   'Sell': 24,
#   'OverBS': '-24',
#   'Date': '2022-02-25'},
#  {'Ticker': '729134',
#   'Name': '由田統一17購01',
#   'Buy': 46,
#   'Sell': 70,
#   'OverBS': '-24',
#   'Date': '2022-02-25'},
#  {'Ticker': '729142',
#   'Name': '宏佳騰康和18購01',
#   'Buy': 0,
#   'Sell': 24,
#   'OverBS': '-24',
#   'Date': '2022-02-25'},
#  {'Ticker': '729276',
#   'Name': '凡甲凱基17購02',
#   'Buy': 30,
#   'Sell': 54,
#   'OverBS': '-24',
#   'Date': '2022-02-25'},
#  {'Ticker': '729534',
#   'Name': '中美晶國泰1A購01',
#   'Buy': 131,
#   'Sell': 155,
#   'OverBS': '-24',
#   'Date': '2022-02-25'},
#  {'Ticker': '00782B',
#   'Name': '國泰A級公用債',
#   'Buy': 100,
#   'Sell': 123,
#   'OverBS': '-23',
#   'Date': '2022-02-25'},
#  {'Ticker': '70314P',
#   'Name': '佳邦國票16售02',
#   'Buy': 25,
#   'Sell': 48,
#   'OverBS': '-23',
#   'Date': '2022-02-25'},
#  {'Ticker': '70449P',
#   'Name': '元太康和18售02',
#   'Buy': 0,
#   'Sell': 23,
#   'OverBS': '-23',
#   'Date': '2022-02-25'},
#  {'Ticker': '727409',
#   'Name': '正德永豐16購02',
#   'Buy': 7,
#   'Sell': 30,
#   'OverBS': '-23',
#   'Date': '2022-02-25'},
#  {'Ticker': '727485',
#   'Name': '中探針群益17購01',
#   'Buy': 20,
#   'Sell': 43,
#   'OverBS': '-23',
#   'Date': '2022-02-25'},
#  {'Ticker': '728418',
#   'Name': '長科*凱基19購01',
#   'Buy': 0,
#   'Sell': 23,
#   'OverBS': '-23',
#   'Date': '2022-02-25'},
#  {'Ticker': '729203',
#   'Name': '頎邦凱基1B購01',
#   'Buy': 0,
#   'Sell': 23,
#   'OverBS': '-23',
#   'Date': '2022-02-25'},
#  {'Ticker': '729205',
#   'Name': '原相富邦1A購01',
#   'Buy': 10,
#   'Sell': 33,
#   'OverBS': '-23',
#   'Date': '2022-02-25'},
#  {'Ticker': '3227',
#   'Name': '原相',
#   'Buy': 10,
#   'Sell': 33,
#   'OverBS': '-23',
#   'Date': '2022-02-25'},
#  {'Ticker': '6237',
#   'Name': '驊訊',
#   'Buy': 0,
#   'Sell': 23,
#   'OverBS': '-23',
#   'Date': '2022-02-25'},
#  {'Ticker': '70189P',
#   'Name': '力旺元大14售04',
#   'Buy': 0,
#   'Sell': 22,
#   'OverBS': '-22',
#   'Date': '2022-02-25'},
#  {'Ticker': '70356P',
#   'Name': '合晶元大16售07',
#   'Buy': 38,
#   'Sell': 60,
#   'OverBS': '-22',
#   'Date': '2022-02-25'},
#  {'Ticker': '726857',
#   'Name': '元太康和18購01',
#   'Buy': 0,
#   'Sell': 22,
#   'OverBS': '-22',
#   'Date': '2022-02-25'},
#  {'Ticker': '727058',
#   'Name': '安國元大17購01',
#   'Buy': 1,
#   'Sell': 23,
#   'OverBS': '-22',
#   'Date': '2022-02-25'},
#  {'Ticker': '728472',
#   'Name': '長科*永豐17購01',
#   'Buy': 3,
#   'Sell': 25,
#   'OverBS': '-22',
#   'Date': '2022-02-25'},
#  {'Ticker': '729254',
#   'Name': '亨泰光凱基17購01',
#   'Buy': 10,
#   'Sell': 32,
#   'OverBS': '-22',
#   'Date': '2022-02-25'},
#  {'Ticker': '729268',
#   'Name': '頎邦群益17購01',
#   'Buy': 10,
#   'Sell': 32,
#   'OverBS': '-22',
#   'Date': '2022-02-25'},
#  {'Ticker': '729776',
#   'Name': '順藥群益19購01',
#   'Buy': 106,
#   'Sell': 128,
#   'OverBS': '-22',
#   'Date': '2022-02-25'},
#  {'Ticker': '00740B',
#   'Name': '富邦全球投等債',
#   'Buy': 102,
#   'Sell': 123,
#   'OverBS': '-21',
#   'Date': '2022-02-25'},
#  {'Ticker': '00755B',
#   'Name': '群益15年IG公用債',
#   'Buy': 100,
#   'Sell': 121,
#   'OverBS': '-21',
#   'Date': '2022-02-25'},
#  {'Ticker': '725285',
#   'Name': '頎邦康和14購01',
#   'Buy': 0,
#   'Sell': 21,
#   'OverBS': '-21',
#   'Date': '2022-02-25'},
#  {'Ticker': '726037',
#   'Name': '中光電統一16購03',
#   'Buy': 96,
#   'Sell': 117,
#   'OverBS': '-21',
#   'Date': '2022-02-25'},
#  {'Ticker': '728225',
#   'Name': '精測凱基17購01',
#   'Buy': 30,
#   'Sell': 51,
#   'OverBS': '-21',
#   'Date': '2022-02-25'},
#  {'Ticker': '729361',
#   'Name': '長科*元大19購01',
#   'Buy': 0,
#   'Sell': 21,
#   'OverBS': '-21',
#   'Date': '2022-02-25'},
#  {'Ticker': '3484',
#   'Name': '崧騰',
#   'Buy': 11,
#   'Sell': 32,
#   'OverBS': '-21',
#   'Date': '2022-02-25'},
#  {'Ticker': '6568',
#   'Name': '宏觀',
#   'Buy': 1,
#   'Sell': 21,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '70144P',
#   'Name': '精測群益13售03',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '70177P',
#   'Name': '漢磊群益14售02',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '70263P',
#   'Name': '力旺元大15售03',
#   'Buy': 10,
#   'Sell': 30,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '70429P',
#   'Name': '合晶凱基17售08',
#   'Buy': 10,
#   'Sell': 30,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '722900',
#   'Name': '大宇資國泰13購01',
#   'Buy': 55,
#   'Sell': 75,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '724731',
#   'Name': '廣運元富16購01',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '724951',
#   'Name': '點序統一17購01',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '725120',
#   'Name': '宏捷科元大16購02',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '725283',
#   'Name': '榮剛元富17購01',
#   'Buy': 16,
#   'Sell': 36,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '725412',
#   'Name': '群聯元大15購02',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '725456',
#   'Name': '台燿富邦15購01',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '725545',
#   'Name': '聚和統一14購01',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '725693',
#   'Name': '聚和統一17購01',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '725969',
#   'Name': '精華凱基15購01',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '726002',
#   'Name': '元太元大17購02',
#   'Buy': 3,
#   'Sell': 23,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '726156',
#   'Name': '亞信兆豐17購01',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '726348',
#   'Name': '中光電統一17購02',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '726502',
#   'Name': '長科*凱基15購03',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '726599',
#   'Name': '安國群益16購02',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '726985',
#   'Name': '中光電富邦19購01',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '727074',
#   'Name': '撼訊群益15購01',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '727260',
#   'Name': '穩懋凱基18購02',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '727646',
#   'Name': '群聯元大16購13',
#   'Buy': 40,
#   'Sell': 60,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '727652',
#   'Name': '聖暉中信16購01',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '727686',
#   'Name': '點序群益16購01',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '727753',
#   'Name': '九暘永豐16購01',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '727858',
#   'Name': '光頡中信18購01',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '728043',
#   'Name': '茂迪元大16購04',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '728126',
#   'Name': '禾瑞亞中信16購01',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '728497',
#   'Name': '華景電統一18購01',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '728529',
#   'Name': '曜越凱基17購01',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '728532',
#   'Name': '宇峻麥證17購01',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '728568',
#   'Name': '大中中信17購01',
#   'Buy': 38,
#   'Sell': 58,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '728991',
#   'Name': '網家國票18購02',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '728994',
#   'Name': '茂達統一19購01',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  {'Ticker': '729006',
#   'Name': '晶焱麥證18購01',
#   'Buy': 0,
#   'Sell': 20,
#   'OverBS': '-20',
#   'Date': '2022-02-25'},
#  ...]

# %% [markdown]
# # 外資

# %% [markdown]
# ## 上市

# %%
def GetData_Foreign(dt=datetime(2004,12,17)):
    """
    Foreign Investors include Mainland Area Investors (外資含陸資)
    Start With 2004-12-17
    """
    dtStr = dt.strftime("%Y%m%d")
    url = f"https://www.twse.com.tw/fund/TWT38U?response=json&date={dtStr}&_=1645862108043"
    res = requests.get(url)
    js = res.json()

    cols = js['fields'][1:3] + js['fields'][-3:]
    raw_datas = js['data']
    final_datas = []
    for data in raw_datas:
        try:
            final_datas.append(dict((col_map[k], ParseData(v)) for k, v in zip(cols, data[1:3]+data[-3:])))
        except:
            print(data[:2]+data[-3:])
            break
    return final_datas

# %%
Foreign_datas = GetData_Foreign()

# %% [markdown]
# ## 上櫃

# %%
def GetData_Foreign_OTC(dt=datetime(2007,4,23)):
    """
    OTC
    Foreign Investors include Mainland Area Investors (外資含陸資)
    Start With 2007-04-23
    """
    dtStr = dt.strftime("%Y-%m-%d")
    dateStr = f"{str(dt.year - 1911)}{dt.strftime('/%m/%d')}"
    
    sellUrl = f"https://www.tpex.org.tw/web/stock/3insti/qfii_trading/forgtr_result.php?l=zh-tw&t=D&type=sell&d={dateStr}&_=1645871930051"
    buyUrl = f"https://www.tpex.org.tw/web/stock/3insti/qfii_trading/forgtr_result.php?l=zh-tw&t=D&type=buy&d={dateStr}&_=1645871930051"
    js_sell = requests.get(sellUrl).json()
    js_buy = requests.get(buyUrl).json()
    final_datas = []
    raw_datas = ''
    raw_datas = js_sell['aaData'] + js_buy['aaData']
    for data in raw_datas:
        print(data)
        rows = data[1:3] + data[-3:] + [dtStr]
        print(rows)
        print(rows[-4], rows[-3])
        print(ParseData(rows[-4]), ParseData(rows[-3]))
        rows[-2] = ParseData(rows[-4]) - ParseData(rows[-3])
        final_datas.append(dict((k, ParseData(v)) for k, v in zip(col_otc, rows)))
    return final_datas

# %%
final_datas = GetData_Foreign_OTC()
# Out:
# ['\n1', '5347', '世界', '-1245', '524653', '31.94']
# ['5347', '世界', '-1245', '524653', '31.94', '2007-04-23']
# -1245 524653
# -1245 524653
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-8475ba625d04> in <module>
# ----> 1 final_datas = GetData_Foreign_OTC()
#
# <ipython-input-110-fa14368486ee> in GetData_Foreign_OTC(dt)
#      21         print(rows[-4], rows[-3])
#      22         print(ParseData(rows[-4]), ParseData(rows[-3]))
# ---> 23         rows[-2] = ParseData(rows[-4]) - ParseData(rows[-3])
#      24         final_datas.append(dict((k, ParseData(v)) for k, v in zip(col_otc, rows)))
#      25     return final_datas
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
final_datas
# Out:
# [{'Ticker': 5347,
#   'Name': '世界',
#   'Buy': '-1245',
#   'Sell': 524653,
#   'OverBS': '31.94',
#   'Date': '2007-04-23'},
#  {'Ticker': 6244,
#   'Name': '茂迪',
#   'Buy': '-885',
#   'Sell': 27621,
#   'OverBS': '19.17',
#   'Date': '2007-04-23'},
#  {'Ticker': 3095,
#   'Name': '及成',
#   'Buy': '-593',
#   'Sell': 29438,
#   'OverBS': '23.2',
#   'Date': '2007-04-23'},
#  {'Ticker': 5466,
#   'Name': '泰林',
#   'Buy': '-500',
#   'Sell': 18769,
#   'OverBS': '6.16',
#   'Date': '2007-04-23'},
#  {'Ticker': 4533,
#   'Name': '協易機',
#   'Buy': '-500',
#   'Sell': 9375,
#   'OverBS': '10.34',
#   'Date': '2007-04-23'},
#  {'Ticker': 8937,
#   'Name': '合騏',
#   'Buy': '-350',
#   'Sell': 6061,
#   'OverBS': '7.57',
#   'Date': '2007-04-23'},
#  {'Ticker': 3372,
#   'Name': '典範',
#   'Buy': '-150',
#   'Sell': 58296,
#   'OverBS': '30.99',
#   'Date': '2007-04-23'},
#  {'Ticker': 8021,
#   'Name': '尖點',
#   'Buy': '-122',
#   'Sell': 16331,
#   'OverBS': '21.45',
#   'Date': '2007-04-23'},
#  {'Ticker': 6232,
#   'Name': '仕欽',
#   'Buy': '-100',
#   'Sell': 7925,
#   'OverBS': '2.68',
#   'Date': '2007-04-23'},
#  {'Ticker': 1565,
#   'Name': '精華',
#   'Buy': '-97',
#   'Sell': 12489,
#   'OverBS': '26.21',
#   'Date': '2007-04-23'},
#  {'Ticker': 3452,
#   'Name': '益通',
#   'Buy': '-73',
#   'Sell': 2623,
#   'OverBS': '6.51',
#   'Date': '2007-04-23'},
#  {'Ticker': 2059,
#   'Name': '川湖',
#   'Buy': '-73',
#   'Sell': 4764,
#   'OverBS': '7.09',
#   'Date': '2007-04-23'},
#  {'Ticker': 4126,
#   'Name': '太醫',
#   'Buy': '-62',
#   'Sell': 2255,
#   'OverBS': '5.99',
#   'Date': '2007-04-23'},
#  {'Ticker': 6153,
#   'Name': '嘉聯益',
#   'Buy': '-50',
#   'Sell': 14971,
#   'OverBS': '5.08',
#   'Date': '2007-04-23'},
#  {'Ticker': 5009,
#   'Name': '榮剛',
#   'Buy': '-49',
#   'Sell': 63566,
#   'OverBS': '22.68',
#   'Date': '2007-04-23'},
#  {'Ticker': 5346,
#   'Name': '力晶',
#   'Buy': 10709,
#   'Sell': 1345637,
#   'OverBS': '19.53',
#   'Date': '2007-04-23'},
#  {'Ticker': 5387,
#   'Name': '茂德',
#   'Buy': 2802,
#   'Sell': 576708,
#   'OverBS': '9.51',
#   'Date': '2007-04-23'},
#  {'Ticker': 6180,
#   'Name': '橘子',
#   'Buy': 1204,
#   'Sell': 45656,
#   'OverBS': '31.08',
#   'Date': '2007-04-23'},
#  {'Ticker': 5371,
#   'Name': '中光電',
#   'Buy': 908,
#   'Sell': 106734,
#   'OverBS': '15.99',
#   'Date': '2007-04-23'},
#  {'Ticker': 6008,
#   'Name': '中信證',
#   'Buy': 750,
#   'Sell': 427538,
#   'OverBS': '16.76',
#   'Date': '2007-04-23'},
#  {'Ticker': 6213,
#   'Name': '聯茂',
#   'Buy': 452,
#   'Sell': 5295,
#   'OverBS': '2.26',
#   'Date': '2007-04-23'},
#  {'Ticker': 5529,
#   'Name': '志嘉',
#   'Buy': 431,
#   'Sell': 2210,
#   'OverBS': '5.5',
#   'Date': '2007-04-23'},
#  {'Ticker': 4417,
#   'Name': '金洲',
#   'Buy': 350,
#   'Sell': 705,
#   'OverBS': '1.32',
#   'Date': '2007-04-23'},
#  {'Ticker': 6194,
#   'Name': '育富',
#   'Buy': 300,
#   'Sell': 4327,
#   'OverBS': '3.89',
#   'Date': '2007-04-23'},
#  {'Ticker': 8076,
#   'Name': '伍豐',
#   'Buy': 229,
#   'Sell': 4612,
#   'OverBS': '8.53',
#   'Date': '2007-04-23'},
#  {'Ticker': 3211,
#   'Name': '順達',
#   'Buy': 214,
#   'Sell': 11882,
#   'OverBS': '13.74',
#   'Date': '2007-04-23'},
#  {'Ticker': 6121,
#   'Name': '新普',
#   'Buy': 207,
#   'Sell': 41125,
#   'OverBS': '27.4',
#   'Date': '2007-04-23'},
#  {'Ticker': 5522,
#   'Name': '遠雄',
#   'Buy': 203,
#   'Sell': 72667,
#   'OverBS': '11.14',
#   'Date': '2007-04-23'},
#  {'Ticker': 5438,
#   'Name': '東友',
#   'Buy': 200,
#   'Sell': 16052,
#   'OverBS': '15.18',
#   'Date': '2007-04-23'},
#  {'Ticker': 8255,
#   'Name': '朋程',
#   'Buy': 200,
#   'Sell': 1881,
#   'OverBS': '4.09',
#   'Date': '2007-04-23'}]

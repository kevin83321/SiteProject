# %%
from Utils import Connect2Mongo
import pandas as pd
import QuantLib as ql
from datetime import datetime, timedelta
from math import ceil
import os
option_data_path = "I:\\GitGroups\\HomeLab\\data-collection\\TXO"

# %%
def GetExpireDate(symbol:str, ttm:str) -> ql.Date:
    nthWeekMapping = {
        "O":3,
        "F":3,
        "A":3
    }
    nWeek = nthWeekMapping.get(symbol[2], symbol[2])
    yStr, mStr = ttm.split('/')
    return ql.Date.nthWeekday(int(nWeek), ql.Wednesday, int(mStr), int(yStr)).to_date().strftime("%Y-%m-%d")

def week_of_month(dt):
    """ Returns the week of the month for the specified date.
    """

    first_day = dt.replace(day=1)

    dom = dt.day
    adjusted_dom = dom + first_day.weekday()

    return int(ceil(adjusted_dom/7.0))

def get_expire_date(dtStr:str) -> ql.Date:
    dt = datetime.strptime(dtStr, "%Y-%m-%d")
    yStr, mStr, dStr = dtStr.split('-')
    for week in range(1, 6):
        try:
            # expire at nth wednesday
            expire_date = ql.Date.nthWeekday(week, ql.Wednesday, int(mStr), int(yStr)).to_date()
            if expire_date > dt.date():
                break
        except:
            # expire at next month first wednesday
            expire_date += timedelta(days=7)
    if dt.date() > expire_date:
        expire_date += timedelta(days=7)
    return expire_date.strftime("%Y-%m-%d")

def get_maturity(dtStr):
    y, m, d = dtStr.split('-')
    dt = datetime.strptime(dtStr, "%Y-%m-%d")
    w_of_month = week_of_month(dt)
    ttm = y + m
    if w_of_month != 3:
        ttm += "W" + str(w_of_month)
    return ttm

# %%
table = Connect2Mongo("TWSE.HistoricalPrice.Index.Intraday")

# %%
full_df = list(table.find({"Date":{"$lte":"2024-01-31", "$gte":"2023-01-01"}, "IndexName":"發行量加權股價指數"}))

full_df = pd.DataFrame(full_df)
full_df['DateTime'] = full_df['Date'] + " " + full_df['Time']
del full_df['_id']

# %%
grouped = full_df.groupby("Date")
dfs = {}
for group in grouped.groups:
    dfs[group] = grouped.get_group(group)

# %%
middles = {}
for k, v in dfs.items():
    tmp_middle = v[v.Time.isin(["09:00:00", "09:10:00", "09:20:00", "09:30:00"])].Close.mean()
    selected_middle = int(round(tmp_middle / 100) * 100)
    middles[k] = {"middle":selected_middle}

# %%
for k, v in middles.items():
    try:
        v['expire_date'] = get_expire_date(k)
        if v['expire_date'] not in full_df.Date.unique():
            for i in range(1, 20):
                tmp_dtStr = (datetime.strptime(v['expire_date'], "%Y-%m-%d") + timedelta(days=i)).strftime("%Y-%m-%d")
                if tmp_dtStr in full_df.Date.to_list():
                    v['expire_date'] = tmp_dtStr
        v['expire_price'] = full_df[full_df.Date==v['expire_date']].sort_values("Time").Close.iloc[-1]
        v['expire_diff'] = round(abs(v['expire_price'] - v['middle']), 2)
        period_price = full_df[(full_df.DateTime.between(k + " 09:30:00", v['expire_date'] + " 13:31:00"))].Close
        v['max_price_before_expire'] = period_price.max()
        v['min_price_before_expire'] = period_price.min()
        v['expire_diff_max'] = round(abs(v['max_price_before_expire'] - v['middle']), 2)
        v['expire_diff_min'] = round(abs(v['min_price_before_expire'] - v['middle']), 2)
        v['used_strike'] = {
            'buy_call': v['middle'] + 100,
            'buy_put': v['middle'] - 100,
            'sell_call': v['middle'] + 300,
            'sell_put': v['middle'] - 300,
        }
        v['Maturity'] = get_maturity(v['expire_date'])
        v['days_to_expire'] = (datetime.strptime(v['expire_date'], "%Y-%m-%d") - datetime.strptime(k, "%Y-%m-%d")).days
    except:
        print(v['expire_date'])

# %%
wins = []
losses = []
for k, v in middles.items():
    if v['expire_diff_max'] >= 207:
        wins.append(k)
    else:
        losses.append(k)

# %%
num_win = len(wins)
num_loss = len(losses)
win_rate = round(num_win / (num_win + num_loss) * 100, 2)

num_win, num_loss, win_rate
# Out:
# (92, 168, 35.38)

# %%
def read_intraday_data(date, strikes, maturity):
    intraday_data = pd.read_csv(os.path.join(option_data_path, f"TXO_{date.replace('-', '_')}.csv"), encoding='utf-8', index_col=0)
    intraday_data = intraday_data[(intraday_data.tradingtime.between(84500, 134500))]
    return intraday_data[(intraday_data.maturity==maturity) & (intraday_data.exprice.isin(strikes))]

# %%
def daytrade_pnl(entry_date, v):
    
    strikes = list(v['used_strike'].values())
    maturity = v['Maturity']

    used_data = read_intraday_data(entry_date, strikes, maturity)

    buy_call_data = used_data[(used_data['C/P'] == "C") & (used_data.exprice==v['used_strike']['buy_call']) & (used_data.tradingtime <= 93000)]
    sell_call_data = used_data[(used_data['C/P'] == "C") & (used_data.exprice==v['used_strike']['sell_call']) & (used_data.tradingtime <= 93000)]
    buy_put_data = used_data[(used_data['C/P'] == "P") & (used_data.exprice==v['used_strike']['buy_put']) & (used_data.tradingtime <= 93000)]
    sell_put_data = used_data[(used_data['C/P'] == "P") & (used_data.exprice==v['used_strike']['sell_put']) & (used_data.tradingtime <= 93000)]
    
    buy_call_exit_data = used_data[(used_data['C/P'] == "C") & (used_data.exprice==v['used_strike']['buy_call']) & (used_data.tradingtime > 93000)]
    sell_call_exit_data = used_data[(used_data['C/P'] == "C") & (used_data.exprice==v['used_strike']['sell_call']) & (used_data.tradingtime > 93000)]
    buy_put_exit_data = used_data[(used_data['C/P'] == "P") & (used_data.exprice==v['used_strike']['buy_put']) & (used_data.tradingtime > 93000)]
    sell_put_exit_data = used_data[(used_data['C/P'] == "P") & (used_data.exprice==v['used_strike']['sell_put']) & (used_data.tradingtime > 93000)]

    buy_call_entry = buy_call_data.iloc[-1].price
    sell_call_entry = sell_call_data.iloc[-1].price
    buy_put_entry = buy_put_data.iloc[-1].price
    sell_put_entry = sell_put_data.iloc[-1].price

    buy_call_exit = buy_call_exit_data.iloc[-1].price
    sell_call_exit = sell_call_exit_data.iloc[-1].price
    buy_put_exit= buy_put_exit_data.iloc[-1].price
    sell_put_exit = sell_put_exit_data.iloc[-1].price

    buy_call_pnl = buy_call_exit - buy_call_entry
    sell_call_pnl = sell_call_entry - sell_call_exit
    buy_put_pnl = buy_put_exit - buy_put_entry
    sell_put_pnl = sell_put_entry - sell_put_exit

    pnl = round(buy_call_pnl + sell_call_pnl + buy_put_pnl + sell_put_pnl, 2)
    entry_cost = round(-buy_call_entry + sell_call_entry - buy_put_entry + sell_put_entry, 2)
    minimum_diff_index = int(abs(entry_cost)) + 101
    
    v['daytrade_pnl'] = pnl
    v['entry_cost'] = entry_cost
    
    print(f"==================== daytrade report of {entry_date}====================")
    print(f"middle line : {v['middle']}")
    print(f"used strike : {v['used_strike']}")
    print(f"entry of each contract : buy_call[{buy_call_entry}], sell_call[{sell_call_entry}], buy_put[{buy_put_entry}], sell_put[{sell_put_entry}]")
    print(f"entry cost : {entry_cost}")
    print(f"minimum diff by entry : {minimum_diff_index}")
    print(f"max_diff_between_entry_and_expire : {v['expire_diff_max']}")
    print(f"exit of each contract : buy_call[{buy_call_exit}], sell_call[{sell_call_exit}], buy_put[{buy_put_exit}], sell_put[{sell_put_exit}]")
    print(f"pnl : {pnl}")
    return pnl

# %%
def expire_pnl(entry_date, v):
    
    strikes = list(v['used_strike'].values())
    maturity = v['Maturity']
    
    entry_date_data = read_intraday_data(entry_date, strikes, maturity)
    exit_date_data = read_intraday_data(v['expire_date'], strikes, maturity)

    buy_call_data = entry_date_data[(entry_date_data['C/P'] == "C") & (entry_date_data.exprice==v['used_strike']['buy_call']) & (entry_date_data.tradingtime <= 93000)]
    sell_call_data = entry_date_data[(entry_date_data['C/P'] == "C") & (entry_date_data.exprice==v['used_strike']['sell_call']) & (entry_date_data.tradingtime <= 93000)]
    buy_put_data = entry_date_data[(entry_date_data['C/P'] == "P") & (entry_date_data.exprice==v['used_strike']['buy_put']) & (entry_date_data.tradingtime <= 93000)]
    sell_put_data = entry_date_data[(entry_date_data['C/P'] == "P") & (entry_date_data.exprice==v['used_strike']['sell_put']) & (entry_date_data.tradingtime <= 93000)]
    
    buy_call_exit_data = exit_date_data[(exit_date_data['C/P'] == "C") & (exit_date_data.exprice==v['used_strike']['buy_call'])]
    sell_call_exit_data = exit_date_data[(exit_date_data['C/P'] == "C") & (exit_date_data.exprice==v['used_strike']['sell_call'])]
    buy_put_exit_data = exit_date_data[(exit_date_data['C/P'] == "P") & (exit_date_data.exprice==v['used_strike']['buy_put'])]
    sell_put_exit_data = exit_date_data[(exit_date_data['C/P'] == "P") & (exit_date_data.exprice==v['used_strike']['sell_put'])]

    buy_call_entry = buy_call_data.iloc[-1].price
    sell_call_entry = sell_call_data.iloc[-1].price
    buy_put_entry = buy_put_data.iloc[-1].price
    sell_put_entry = sell_put_data.iloc[-1].price

    buy_call_exit = buy_call_exit_data.iloc[-1].price
    sell_call_exit = sell_call_exit_data.iloc[-1].price
    buy_put_exit = buy_put_exit_data.iloc[-1].price
    sell_put_exit = sell_put_exit_data.iloc[-1].price

    buy_call_pnl = buy_call_exit - buy_call_entry
    sell_call_pnl = sell_call_entry - sell_call_exit
    buy_put_pnl = buy_put_exit - buy_put_entry
    sell_put_pnl = sell_put_entry - sell_put_exit

    pnl = round(buy_call_pnl + sell_call_pnl + buy_put_pnl + sell_put_pnl, 2)
    entry_cost = round(-buy_call_entry + sell_call_entry - buy_put_entry + sell_put_entry, 2)
    minimum_diff_index = int(abs(entry_cost)) + 101
    
    v['expire_pnl'] = pnl
    v['entry_cost_to_expire'] = entry_cost
    
    print(f"==================== expire report of {entry_date}====================")
    print(f"middle line : {v['middle']}")
    print(f"used strike : {v['used_strike']}")
    print(f"days to expire : {v['days_to_expire']}")
    print(f"entry of each contract : buy_call[{buy_call_entry}], sell_call[{sell_call_entry}], buy_put[{buy_put_entry}], sell_put[{sell_put_entry}]")
    print(f"entry cost : {entry_cost}")
    print(f"minimum diff by entry : {minimum_diff_index}")
    print(f"max_diff_between_entry_and_expire : {v['expire_diff_max']}")
    print(f"exit of each contract : buy_call[{buy_call_exit}], sell_call[{sell_call_exit}], buy_put[{buy_put_exit}], sell_put[{sell_put_exit}]")
    print(f"pnl : {pnl}")
    return pnl

# %%
for k, v in middles.items():
    try:
        daytrade_pnl(k, v)
    except:
        pass
# Out:
# ==================== daytrade report of 2023-10-05====================
# middle line : 16400
# used strike : {'buy_call': 16500, 'buy_put': 16300, 'sell_call': 16700, 'sell_put': 16100}
# entry of each contract : buy_call[102.0], sell_call[45.0], buy_put[149.0], sell_put[79.0]
# entry cost : -127.0
# minimum diff by entry : 228
# max_diff_between_entry_and_expire : 329.5
# exit of each contract : buy_call[140.0], sell_call[63.0], buy_put[100.0], sell_put[52.0]
# pnl : -2.0
# ==================== daytrade report of 2023-10-06====================
# middle line : 16500
# used strike : {'buy_call': 16600, 'buy_put': 16400, 'sell_call': 16800, 'sell_put': 16200}
# entry of each contract : buy_call[106.0], sell_call[44.5], buy_put[116.0], sell_put[59.0]
# entry cost : -118.5
# minimum diff by entry : 219
# max_diff_between_entry_and_expire : 229.5
# exit of each contract : buy_call[112.0], sell_call[45.0], buy_put[100.0], sell_put[50.0]
# pnl : -1.5
# ==================== daytrade report of 2023-10-11====================
# middle line : 16700
# used strike : {'buy_call': 16800, 'buy_put': 16600, 'sell_call': 17000, 'sell_put': 16400}
# entry of each contract : buy_call[150.0], sell_call[66.0], buy_put[119.0], sell_put[65.0]
# entry cost : -138.0
# minimum diff by entry : 239
# max_diff_between_entry_and_expire : 125.91
# exit of each contract : buy_call[129.0], sell_call[57.0], buy_put[120.0], sell_put[64.0]
# pnl : -10.0
# ==================== daytrade report of 2023-10-12====================
# middle line : 16700
# used strike : {'buy_call': 16800, 'buy_put': 16600, 'sell_call': 17000, 'sell_put': 16400}
# entry of each contract : buy_call[148.0], sell_call[69.0], buy_put[95.0], sell_put[48.0]
# entry cost : -126.0
# minimum diff by entry : 227
# max_diff_between_entry_and_expire : 125.91
# exit of each contract : buy_call[184.0], sell_call[89.0], buy_put[68.0], sell_put[33.5]
# pnl : 3.5
# ==================== daytrade report of 2023-10-13====================
# middle line : 16800
# used strike : {'buy_call': 16900, 'buy_put': 16700, 'sell_call': 17100, 'sell_put': 16500}
# entry of each contract : buy_call[104.0], sell_call[43.5], buy_put[117.0], sell_put[61.0]
# entry cost : -116.5
# minimum diff by entry : 217
# max_diff_between_entry_and_expire : 6.71
# exit of each contract : buy_call[99.0], sell_call[41.0], buy_put[119.0], sell_put[62.0]
# pnl : -1.5
# ==================== daytrade report of 2023-10-16====================
# middle line : 16700
# used strike : {'buy_call': 16800, 'buy_put': 16600, 'sell_call': 17000, 'sell_put': 16400}
# entry of each contract : buy_call[99.0], sell_call[39.0], buy_put[122.0], sell_put[62.0]
# entry cost : -120.0
# minimum diff by entry : 221
# max_diff_between_entry_and_expire : 70.64
# exit of each contract : buy_call[82.0], sell_call[29.0], buy_put[127.0], sell_put[63.0]
# pnl : -3.0
# ==================== daytrade report of 2023-10-17====================
# middle line : 16700
# used strike : {'buy_call': 16800, 'buy_put': 16600, 'sell_call': 17000, 'sell_put': 16400}
# entry of each contract : buy_call[98.0], sell_call[33.5], buy_put[89.0], sell_put[40.0]
# entry cost : -113.5
# minimum diff by entry : 214
# max_diff_between_entry_and_expire : 42.91
# exit of each contract : buy_call[75.0], sell_call[23.0], buy_put[111.0], sell_put[53.0]
# pnl : -3.5
# c:\users\kevin\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3343: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ==================== daytrade report of 2023-10-25====================
# middle line : 16400
# used strike : {'buy_call': 16500, 'buy_put': 16300, 'sell_call': 16700, 'sell_put': 16100}
# entry of each contract : buy_call[82.0], sell_call[25.0], buy_put[94.0], sell_put[42.0]
# entry cost : -109.0
# minimum diff by entry : 210
# max_diff_between_entry_and_expire : 59.34
# exit of each contract : buy_call[61.0], sell_call[14.5], buy_put[106.0], sell_put[46.5]
# pnl : -3.0
# ==================== daytrade report of 2023-10-26====================
# middle line : 16200
# used strike : {'buy_call': 16300, 'buy_put': 16100, 'sell_call': 16500, 'sell_put': 15900}
# entry of each contract : buy_call[53.0], sell_call[13.5], buy_put[140.0], sell_put[69.0]
# entry cost : -110.5
# minimum diff by entry : 211
# max_diff_between_entry_and_expire : 15.35
# exit of each contract : buy_call[40.0], sell_call[8.9], buy_put[153.0], sell_put[74.0]
# pnl : -0.4
# ==================== daytrade report of 2023-10-27====================
# middle line : 16100
# used strike : {'buy_call': 16200, 'buy_put': 16000, 'sell_call': 16400, 'sell_put': 15800}
# entry of each contract : buy_call[98.0], sell_call[27.0], buy_put[58.0], sell_put[21.5]
# entry cost : -107.5
# minimum diff by entry : 208
# max_diff_between_entry_and_expire : 115.35
# exit of each contract : buy_call[80.0], sell_call[17.5], buy_put[58.0], sell_put[21.0]
# pnl : -8.0
# ==================== daytrade report of 2023-10-30====================
# middle line : 16200
# used strike : {'buy_call': 16300, 'buy_put': 16100, 'sell_call': 16500, 'sell_put': 15900}
# entry of each contract : buy_call[22.5], sell_call[2.0], buy_put[60.0], sell_put[14.5]
# entry cost : -66.0
# minimum diff by entry : 167
# max_diff_between_entry_and_expire : 15.35
# exit of each contract : buy_call[18.5], sell_call[1.9], buy_put[53.0], sell_put[11.5]
# pnl : -7.9
# ==================== daytrade report of 2023-10-31====================
# middle line : 16200
# used strike : {'buy_call': 16300, 'buy_put': 16100, 'sell_call': 16500, 'sell_put': 15900}
# entry of each contract : buy_call[15.0], sell_call[1.1], buy_put[41.0], sell_put[6.1]
# entry cost : -48.8
# minimum diff by entry : 149
# max_diff_between_entry_and_expire : 8.11
# exit of each contract : buy_call[1.6], sell_call[0.7], buy_put[126.0], sell_put[22.5]
# pnl : 55.6
# ==================== daytrade report of 2023-11-01====================
# middle line : 16100
# used strike : {'buy_call': 16200, 'buy_put': 16000, 'sell_call': 16400, 'sell_put': 15800}
# entry of each contract : buy_call[78.0], sell_call[24.5], buy_put[103.0], sell_put[46.0]
# entry cost : -110.5
# minimum diff by entry : 211
# max_diff_between_entry_and_expire : 675.23
# exit of each contract : buy_call[63.0], sell_call[17.5], buy_put[111.0], sell_put[47.0]
# pnl : -1.0
# ==================== daytrade report of 2023-11-02====================
# middle line : 16200
# used strike : {'buy_call': 16300, 'buy_put': 16100, 'sell_call': 16500, 'sell_put': 15900}
# entry of each contract : buy_call[122.0], sell_call[41.0], buy_put[39.0], sell_put[12.5]
# entry cost : -107.5
# minimum diff by entry : 208
# max_diff_between_entry_and_expire : 575.23
# exit of each contract : buy_call[146.0], sell_call[49.5], buy_put[22.5], sell_put[7.0]
# pnl : 4.5
# ==================== daytrade report of 2023-11-03====================
# middle line : 16400
# used strike : {'buy_call': 16500, 'buy_put': 16300, 'sell_call': 16700, 'sell_put': 16100}
# entry of each contract : buy_call[65.0], sell_call[12.5], buy_put[38.5], sell_put[9.8]
# entry cost : -81.2
# minimum diff by entry : 182
# max_diff_between_entry_and_expire : 375.23
# exit of each contract : buy_call[75.0], sell_call[13.5], buy_put[24.0], sell_put[6.5]
# pnl : -2.2
# ==================== daytrade report of 2023-11-06====================
# middle line : 16600
# used strike : {'buy_call': 16700, 'buy_put': 16500, 'sell_call': 16900, 'sell_put': 16300}
# entry of each contract : buy_call[37.0], sell_call[4.1], buy_put[25.0], sell_put[5.9]
# entry cost : -52.0
# minimum diff by entry : 153
# max_diff_between_entry_and_expire : 175.23
# exit of each contract : buy_call[38.5], sell_call[4.0], buy_put[19.5], sell_put[6.0]
# pnl : -4.0
# ==================== daytrade report of 2023-11-07====================
# middle line : 16600
# used strike : {'buy_call': 16700, 'buy_put': 16500, 'sell_call': 16900, 'sell_put': 16300}
# entry of each contract : buy_call[26.0], sell_call[2.0], buy_put[11.0], sell_put[2.3]
# entry cost : -32.7
# minimum diff by entry : 133
# max_diff_between_entry_and_expire : 175.23
# exit of each contract : buy_call[36.5], sell_call[1.0], buy_put[3.9], sell_put[1.0]
# pnl : 5.7
# ==================== daytrade report of 2023-11-08====================
# middle line : 16700
# used strike : {'buy_call': 16800, 'buy_put': 16600, 'sell_call': 17000, 'sell_put': 16400}
# entry of each contract : buy_call[79.0], sell_call[23.0], buy_put[75.0], sell_put[30.5]
# entry cost : -100.5
# minimum diff by entry : 201
# max_diff_between_entry_and_expire : 443.88
# exit of each contract : buy_call[89.0], sell_call[24.0], buy_put[62.0], sell_put[25.5]
# pnl : 1.0
# ==================== daytrade report of 2023-11-09====================
# middle line : 16700
# used strike : {'buy_call': 16800, 'buy_put': 16600, 'sell_call': 17000, 'sell_put': 16400}
# entry of each contract : buy_call[66.0], sell_call[12.5], buy_put[58.0], sell_put[22.0]
# entry cost : -89.5
# minimum diff by entry : 190
# max_diff_between_entry_and_expire : 443.88
# exit of each contract : buy_call[81.0], sell_call[17.5], buy_put[44.5], sell_put[15.0]
# pnl : 3.5
# ==================== daytrade report of 2023-11-10====================
# middle line : 16700
# used strike : {'buy_call': 16800, 'buy_put': 16600, 'sell_call': 17000, 'sell_put': 16400}
# entry of each contract : buy_call[45.0], sell_call[7.3], buy_put[59.0], sell_put[18.5]
# entry cost : -78.2
# minimum diff by entry : 179
# max_diff_between_entry_and_expire : 443.88
# exit of each contract : buy_call[54.0], sell_call[9.5], buy_put[38.5], sell_put[10.5]
# pnl : -5.7
# ==================== daytrade report of 2023-11-13====================
# middle line : 16800
# used strike : {'buy_call': 16900, 'buy_put': 16700, 'sell_call': 17100, 'sell_put': 16500}
# entry of each contract : buy_call[75.0], sell_call[15.0], buy_put[14.0], sell_put[2.6]
# entry cost : -71.4
# minimum diff by entry : 172
# max_diff_between_entry_and_expire : 343.88
# exit of each contract : buy_call[52.0], sell_call[7.0], buy_put[15.0], sell_put[3.5]
# pnl : -14.9
# ==================== daytrade report of 2023-11-14====================
# middle line : 16900
# used strike : {'buy_call': 17000, 'buy_put': 16800, 'sell_call': 17200, 'sell_put': 16600}
# entry of each contract : buy_call[24.0], sell_call[1.5], buy_put[14.5], sell_put[2.0]
# entry cost : -35.0
# minimum diff by entry : 136
# max_diff_between_entry_and_expire : 243.88
# exit of each contract : buy_call[29.5], sell_call[1.9], buy_put[9.6], sell_put[2.0]
# pnl : 0.2
# ==================== daytrade report of 2023-11-15====================
# middle line : 17100
# used strike : {'buy_call': 17200, 'buy_put': 17000, 'sell_call': 17400, 'sell_put': 16800}
# entry of each contract : buy_call[111.0], sell_call[39.5], buy_put[57.0], sell_put[22.5]
# entry cost : -106.0
# minimum diff by entry : 207
# max_diff_between_entry_and_expire : 321.17
# exit of each contract : buy_call[100.0], sell_call[34.0], buy_put[54.0], sell_put[17.5]
# pnl : -3.5
# ==================== daytrade report of 2023-11-16====================
# middle line : 17200
# used strike : {'buy_call': 17300, 'buy_put': 17100, 'sell_call': 17500, 'sell_put': 16900}
# entry of each contract : buy_call[61.0], sell_call[16.0], buy_put[71.0], sell_put[23.0]
# entry cost : -93.0
# minimum diff by entry : 194
# max_diff_between_entry_and_expire : 221.17
# exit of each contract : buy_call[57.0], sell_call[14.0], buy_put[70.0], sell_put[22.0]
# pnl : -2.0
# ==================== daytrade report of 2023-11-17====================
# middle line : 17200
# used strike : {'buy_call': 17300, 'buy_put': 17100, 'sell_call': 17500, 'sell_put': 16900}
# entry of each contract : buy_call[52.0], sell_call[11.0], buy_put[64.0], sell_put[19.0]
# entry cost : -86.0
# minimum diff by entry : 187
# max_diff_between_entry_and_expire : 221.17
# exit of each contract : buy_call[57.0], sell_call[12.5], buy_put[52.0], sell_put[14.5]
# pnl : -4.0
# ==================== daytrade report of 2023-11-20====================
# middle line : 17200
# used strike : {'buy_call': 17300, 'buy_put': 17100, 'sell_call': 17500, 'sell_put': 16900}
# entry of each contract : buy_call[47.0], sell_call[6.8], buy_put[33.5], sell_put[5.9]
# entry cost : -67.8
# minimum diff by entry : 168
# max_diff_between_entry_and_expire : 221.17
# exit of each contract : buy_call[35.0], sell_call[4.7], buy_put[37.5], sell_put[5.9]
# pnl : -5.9
# ==================== daytrade report of 2023-11-21====================
# middle line : 17300
# used strike : {'buy_call': 17400, 'buy_put': 17200, 'sell_call': 17600, 'sell_put': 17000}
# entry of each contract : buy_call[49.5], sell_call[4.6], buy_put[13.0], sell_put[2.4]
# entry cost : -55.5
# minimum diff by entry : 156
# max_diff_between_entry_and_expire : 121.17
# exit of each contract : buy_call[58.0], sell_call[4.4], buy_put[4.0], sell_put[0.8]
# pnl : 1.3
# ==================== daytrade report of 2023-11-22====================
# middle line : 17300
# used strike : {'buy_call': 17400, 'buy_put': 17200, 'sell_call': 17600, 'sell_put': 17000}
# entry of each contract : buy_call[85.0], sell_call[27.0], buy_put[57.0], sell_put[18.0]
# entry cost : -97.0
# minimum diff by entry : 198
# max_diff_between_entry_and_expire : 141.79
# exit of each contract : buy_call[63.0], sell_call[16.5], buy_put[59.0], sell_put[15.0]
# pnl : -6.5
# ==================== daytrade report of 2023-11-23====================
# middle line : 17300
# used strike : {'buy_call': 17400, 'buy_put': 17200, 'sell_call': 17600, 'sell_put': 17000}
# entry of each contract : buy_call[55.0], sell_call[11.5], buy_put[46.0], sell_put[10.5]
# entry cost : -79.0
# minimum diff by entry : 180
# max_diff_between_entry_and_expire : 141.79
# exit of each contract : buy_call[52.0], sell_call[9.8], buy_put[41.0], sell_put[9.1]
# pnl : -4.9
# ==================== daytrade report of 2023-11-24====================
# middle line : 17300
# used strike : {'buy_call': 17400, 'buy_put': 17200, 'sell_call': 17600, 'sell_put': 17000}
# entry of each contract : buy_call[37.5], sell_call[5.8], buy_put[42.5], sell_put[8.0]
# entry cost : -66.2
# minimum diff by entry : 167
# max_diff_between_entry_and_expire : 141.79
# exit of each contract : buy_call[39.5], sell_call[6.5], buy_put[35.0], sell_put[6.2]
# pnl : -4.4
# ==================== daytrade report of 2023-11-27====================
# middle line : 17300
# used strike : {'buy_call': 17400, 'buy_put': 17200, 'sell_call': 17600, 'sell_put': 17000}
# entry of each contract : buy_call[43.0], sell_call[4.9], buy_put[19.5], sell_put[2.8]
# entry cost : -54.8
# minimum diff by entry : 155
# max_diff_between_entry_and_expire : 141.79
# exit of each contract : buy_call[5.4], sell_call[1.0], buy_put[80.0], sell_put[12.5]
# pnl : 17.1
# ==================== daytrade report of 2023-11-28====================
# middle line : 17200
# used strike : {'buy_call': 17300, 'buy_put': 17100, 'sell_call': 17500, 'sell_put': 16900}
# entry of each contract : buy_call[24.0], sell_call[1.2], buy_put[10.5], sell_put[1.2]
# entry cost : -32.1
# minimum diff by entry : 133
# max_diff_between_entry_and_expire : 241.79
# exit of each contract : buy_call[76.0], sell_call[3.9], buy_put[1.6], sell_put[0.3]
# pnl : 41.3
# ==================== daytrade report of 2023-11-29====================
# middle line : 17400
# used strike : {'buy_call': 17500, 'buy_put': 17300, 'sell_call': 17700, 'sell_put': 17100}
# entry of each contract : buy_call[4.8], sell_call[0.1], buy_put[1.8], sell_put[0.4]
# entry cost : -6.1
# minimum diff by entry : 107
# max_diff_between_entry_and_expire : 38.06
# exit of each contract : buy_call[0.1], sell_call[0.1], buy_put[0.1], sell_put[0.1]
# pnl : -6.1
# ==================== daytrade report of 2023-11-30====================
# middle line : 17400
# used strike : {'buy_call': 17500, 'buy_put': 17300, 'sell_call': 17700, 'sell_put': 17100}
# entry of each contract : buy_call[99.0], sell_call[40.5], buy_put[118.0], sell_put[54.0]
# entry cost : -122.5
# minimum diff by entry : 223
# max_diff_between_entry_and_expire : 116.61
# exit of each contract : buy_call[108.0], sell_call[46.0], buy_put[107.0], sell_put[47.5]
# pnl : -1.0
# ==================== daytrade report of 2023-12-01====================
# middle line : 17400
# used strike : {'buy_call': 17500, 'buy_put': 17300, 'sell_call': 17700, 'sell_put': 17100}
# entry of each contract : buy_call[77.0], sell_call[32.0], buy_put[125.0], sell_put[66.0]
# entry cost : -104.0
# minimum diff by entry : 205
# max_diff_between_entry_and_expire : 116.61
# exit of each contract : buy_call[113.0], sell_call[45.0], buy_put[91.0], sell_put[39.5]
# pnl : 15.5
# ==================== daytrade report of 2023-12-04====================
# middle line : 17500
# used strike : {'buy_call': 17600, 'buy_put': 17400, 'sell_call': 17800, 'sell_put': 17200}
# entry of each contract : buy_call[67.0], sell_call[22.5], buy_put[111.0], sell_put[48.0]
# entry cost : -107.5
# minimum diff by entry : 208
# max_diff_between_entry_and_expire : 46.62
# exit of each contract : buy_call[57.0], sell_call[17.5], buy_put[114.0], sell_put[47.5]
# pnl : -1.5
# ==================== daytrade report of 2023-12-05====================
# middle line : 17300
# used strike : {'buy_call': 17400, 'buy_put': 17200, 'sell_call': 17600, 'sell_put': 17000}
# entry of each contract : buy_call[74.0], sell_call[24.0], buy_put[93.0], sell_put[38.0]
# entry cost : -105.0
# minimum diff by entry : 206
# max_diff_between_entry_and_expire : 139.85
# exit of each contract : buy_call[82.0], sell_call[26.0], buy_put[69.0], sell_put[25.0]
# pnl : -5.0
# ==================== daytrade report of 2023-12-06====================
# middle line : 17400
# used strike : {'buy_call': 17500, 'buy_put': 17300, 'sell_call': 17700, 'sell_put': 17100}
# entry of each contract : buy_call[98.0], sell_call[41.0], buy_put[121.0], sell_put[61.0]
# entry cost : -117.0
# minimum diff by entry : 218
# max_diff_between_entry_and_expire : 128.72
# exit of each contract : buy_call[100.0], sell_call[44.0], buy_put[119.0], sell_put[55.0]
# pnl : 3.0
# ==================== daytrade report of 2023-12-07====================
# middle line : 17400
# used strike : {'buy_call': 17500, 'buy_put': 17300, 'sell_call': 17700, 'sell_put': 17100}
# entry of each contract : buy_call[74.0], sell_call[29.5], buy_put[140.0], sell_put[66.0]
# entry cost : -118.5
# minimum diff by entry : 219
# max_diff_between_entry_and_expire : 128.72
# exit of each contract : buy_call[63.0], sell_call[25.0], buy_put[162.0], sell_put[81.0]
# pnl : 0.5
# ==================== daytrade report of 2023-12-08====================
# middle line : 17400
# used strike : {'buy_call': 17500, 'buy_put': 17300, 'sell_call': 17700, 'sell_put': 17100}
# entry of each contract : buy_call[112.0], sell_call[47.0], buy_put[89.0], sell_put[39.5]
# entry cost : -114.5
# minimum diff by entry : 215
# max_diff_between_entry_and_expire : 128.72
# exit of each contract : buy_call[87.0], sell_call[32.0], buy_put[108.0], sell_put[48.0]
# pnl : 0.5
# ==================== daytrade report of 2023-12-11====================
# middle line : 17400
# used strike : {'buy_call': 17500, 'buy_put': 17300, 'sell_call': 17700, 'sell_put': 17100}
# entry of each contract : buy_call[77.0], sell_call[27.5], buy_put[100.0], sell_put[43.0]
# entry cost : -106.5
# minimum diff by entry : 207
# max_diff_between_entry_and_expire : 128.72
# exit of each contract : buy_call[90.0], sell_call[31.5], buy_put[79.0], sell_put[31.0]
# pnl : 0.0
# ==================== daytrade report of 2023-12-12====================
# middle line : 17500
# used strike : {'buy_call': 17600, 'buy_put': 17400, 'sell_call': 17800, 'sell_put': 17200}
# entry of each contract : buy_call[78.0], sell_call[25.5], buy_put[74.0], sell_put[26.5]
# entry cost : -100.0
# minimum diff by entry : 201
# max_diff_between_entry_and_expire : 7.92
# exit of each contract : buy_call[63.0], sell_call[20.0], buy_put[88.0], sell_put[34.0]
# pnl : -3.0
# ==================== daytrade report of 2023-12-13====================
# middle line : 17500
# used strike : {'buy_call': 17600, 'buy_put': 17400, 'sell_call': 17800, 'sell_put': 17200}
# entry of each contract : buy_call[103.0], sell_call[42.0], buy_put[102.0], sell_put[43.0]
# entry cost : -120.0
# minimum diff by entry : 221
# max_diff_between_entry_and_expire : 243.54
# exit of each contract : buy_call[80.0], sell_call[29.0], buy_put[115.0], sell_put[52.0]
# pnl : -6.0
# ==================== daytrade report of 2023-12-14====================
# middle line : 17600
# used strike : {'buy_call': 17700, 'buy_put': 17500, 'sell_call': 17900, 'sell_put': 17300}
# entry of each contract : buy_call[108.0], sell_call[42.0], buy_put[75.0], sell_put[29.0]
# entry cost : -112.0
# minimum diff by entry : 213
# max_diff_between_entry_and_expire : 143.54
# exit of each contract : buy_call[107.0], sell_call[38.0], buy_put[70.0], sell_put[27.0]
# pnl : 0.0
# ==================== daytrade report of 2023-12-15====================
# middle line : 17700
# used strike : {'buy_call': 17800, 'buy_put': 17600, 'sell_call': 18000, 'sell_put': 17400}
# entry of each contract : buy_call[85.0], sell_call[28.0], buy_put[76.0], sell_put[31.5]
# entry cost : -101.5
# minimum diff by entry : 202
# max_diff_between_entry_and_expire : 38.82
# exit of each contract : buy_call[66.0], sell_call[20.5], buy_put[91.0], sell_put[34.5]
# pnl : 0.5
# ==================== daytrade report of 2023-12-18====================
# middle line : 17600
# used strike : {'buy_call': 17700, 'buy_put': 17500, 'sell_call': 17900, 'sell_put': 17300}
# entry of each contract : buy_call[86.0], sell_call[27.0], buy_put[62.0], sell_put[21.0]
# entry cost : -100.0
# minimum diff by entry : 201
# max_diff_between_entry_and_expire : 69.84
# exit of each contract : buy_call[91.0], sell_call[27.0], buy_put[53.0], sell_put[18.0]
# pnl : -1.0
# ==================== daytrade report of 2023-12-19====================
# middle line : 17600
# used strike : {'buy_call': 17700, 'buy_put': 17500, 'sell_call': 17900, 'sell_put': 17300}
# entry of each contract : buy_call[52.0], sell_call[12.0], buy_put[67.0], sell_put[21.5]
# entry cost : -85.5
# minimum diff by entry : 186
# max_diff_between_entry_and_expire : 57.65
# exit of each contract : buy_call[48.5], sell_call[10.5], buy_put[70.0], sell_put[21.0]
# pnl : 1.5
# ==================== daytrade report of 2023-12-27====================
# middle line : 17800
# used strike : {'buy_call': 17900, 'buy_put': 17700, 'sell_call': 18100, 'sell_put': 17500}
# entry of each contract : buy_call[55.0], sell_call[10.5], buy_put[47.5], sell_put[13.5]
# entry cost : -78.5
# minimum diff by entry : 179
# max_diff_between_entry_and_expire : 156.74
# exit of each contract : buy_call[80.0], sell_call[18.0], buy_put[33.5], sell_put[8.1]
# pnl : 8.9
# ==================== daytrade report of 2023-12-28====================
# middle line : 17900
# used strike : {'buy_call': 18000, 'buy_put': 17800, 'sell_call': 18200, 'sell_put': 17600}
# entry of each contract : buy_call[36.0], sell_call[5.8], buy_put[55.0], sell_put[13.5]
# entry cost : -71.7
# minimum diff by entry : 172
# max_diff_between_entry_and_expire : 56.74
# exit of each contract : buy_call[36.0], sell_call[5.7], buy_put[48.0], sell_put[10.5]
# pnl : -3.9
# ==================== daytrade report of 2023-12-29====================
# middle line : 17900
# used strike : {'buy_call': 18000, 'buy_put': 17800, 'sell_call': 18200, 'sell_put': 17600}
# entry of each contract : buy_call[29.5], sell_call[4.3], buy_put[51.0], sell_put[10.0]
# entry cost : -66.2
# minimum diff by entry : 167
# max_diff_between_entry_and_expire : 56.74
# exit of each contract : buy_call[30.5], sell_call[3.9], buy_put[36.0], sell_put[5.7]
# pnl : -9.3
# ==================== daytrade report of 2024-01-02====================
# middle line : 17900
# used strike : {'buy_call': 18000, 'buy_put': 17800, 'sell_call': 18200, 'sell_put': 17600}
# entry of each contract : buy_call[11.0], sell_call[0.8], buy_put[28.0], sell_put[2.3]
# entry cost : -35.9
# minimum diff by entry : 136
# max_diff_between_entry_and_expire : 6.82
# exit of each contract : buy_call[2.6], sell_call[0.5], buy_put[26.5], sell_put[1.1]
# pnl : -8.4
# ==================== daytrade report of 2024-01-03====================
# middle line : 17700
# used strike : {'buy_call': 17800, 'buy_put': 17600, 'sell_call': 18000, 'sell_put': 17400}
# entry of each contract : buy_call[40.5], sell_call[9.8], buy_put[112.0], sell_put[43.0]
# entry cost : -99.7
# minimum diff by entry : 200
# max_diff_between_entry_and_expire : 5.74
# exit of each contract : buy_call[30.0], sell_call[7.0], buy_put[129.0], sell_put[52.0]
# pnl : 0.3
# ==================== daytrade report of 2024-01-04====================
# middle line : 17600
# used strike : {'buy_call': 17700, 'buy_put': 17500, 'sell_call': 17900, 'sell_put': 17300}
# entry of each contract : buy_call[44.5], sell_call[9.0], buy_put[86.0], sell_put[31.0]
# entry cost : -90.5
# minimum diff by entry : 191
# max_diff_between_entry_and_expire : 94.26
# exit of each contract : buy_call[48.0], sell_call[10.5], buy_put[79.0], sell_put[27.5]
# pnl : -1.5
# ==================== daytrade report of 2024-01-05====================
# middle line : 17600
# used strike : {'buy_call': 17700, 'buy_put': 17500, 'sell_call': 17900, 'sell_put': 17300}
# entry of each contract : buy_call[47.0], sell_call[8.2], buy_put[60.0], sell_put[17.0]
# entry cost : -81.8
# minimum diff by entry : 182
# max_diff_between_entry_and_expire : 94.26
# exit of each contract : buy_call[30.0], sell_call[4.6], buy_put[81.0], sell_put[24.5]
# pnl : 0.1
# ==================== daytrade report of 2024-01-08====================
# middle line : 17600
# used strike : {'buy_call': 17700, 'buy_put': 17500, 'sell_call': 17900, 'sell_put': 17300}
# entry of each contract : buy_call[69.0], sell_call[8.1], buy_put[18.0], sell_put[4.3]
# entry cost : -74.6
# minimum diff by entry : 175
# max_diff_between_entry_and_expire : 94.26
# exit of each contract : buy_call[28.0], sell_call[2.4], buy_put[29.0], sell_put[5.0]
# pnl : -25.0
# ==================== daytrade report of 2024-01-09====================
# middle line : 17600
# used strike : {'buy_call': 17700, 'buy_put': 17500, 'sell_call': 17900, 'sell_put': 17300}
# entry of each contract : buy_call[45.5], sell_call[2.5], buy_put[8.5], sell_put[1.7]
# entry cost : -49.8
# minimum diff by entry : 150
# max_diff_between_entry_and_expire : 42.06
# exit of each contract : buy_call[3.6], sell_call[0.8], buy_put[26.5], sell_put[2.5]
# pnl : -23.0
# ==================== daytrade report of 2024-01-10====================
# middle line : 17500
# used strike : {'buy_call': 17600, 'buy_put': 17400, 'sell_call': 17800, 'sell_put': 17200}
# entry of each contract : buy_call[106.0], sell_call[46.0], buy_put[117.0], sell_put[60.0]
# entry cost : -117.0
# minimum diff by entry : 218
# max_diff_between_entry_and_expire : 132.77
# exit of each contract : buy_call[94.0], sell_call[39.5], buy_put[133.0], sell_put[69.0]
# pnl : 1.5
# ==================== daytrade report of 2024-01-11====================
# middle line : 17500
# used strike : {'buy_call': 17600, 'buy_put': 17400, 'sell_call': 17800, 'sell_put': 17200}
# entry of each contract : buy_call[113.0], sell_call[49.0], buy_put[115.0], sell_put[59.0]
# entry cost : -120.0
# minimum diff by entry : 221
# max_diff_between_entry_and_expire : 132.77
# exit of each contract : buy_call[153.0], sell_call[74.0], buy_put[100.0], sell_put[53.0]
# pnl : 6.0
# ==================== daytrade report of 2024-01-12====================
# middle line : 17500
# used strike : {'buy_call': 17600, 'buy_put': 17400, 'sell_call': 17800, 'sell_put': 17200}
# entry of each contract : buy_call[111.0], sell_call[57.0], buy_put[144.0], sell_put[74.0]
# entry cost : -124.0
# minimum diff by entry : 225
# max_diff_between_entry_and_expire : 132.77
# exit of each contract : buy_call[112.0], sell_call[49.0], buy_put[130.0], sell_put[72.0]
# pnl : -3.0
# ==================== daytrade report of 2024-01-15====================
# middle line : 17600
# used strike : {'buy_call': 17700, 'buy_put': 17500, 'sell_call': 17900, 'sell_put': 17300}
# entry of each contract : buy_call[25.5], sell_call[3.2], buy_put[54.0], sell_put[13.0]
# entry cost : -63.3
# minimum diff by entry : 164
# max_diff_between_entry_and_expire : 20.3
# exit of each contract : buy_call[15.0], sell_call[2.6], buy_put[41.0], sell_put[9.0]
# pnl : -18.9
# ==================== daytrade report of 2024-01-16====================
# middle line : 17400
# used strike : {'buy_call': 17500, 'buy_put': 17300, 'sell_call': 17700, 'sell_put': 17100}
# entry of each contract : buy_call[15.5], sell_call[1.8], buy_put[32.0], sell_put[5.2]
# entry cost : -40.5
# minimum diff by entry : 141
# max_diff_between_entry_and_expire : 56.52
# exit of each contract : buy_call[5.1], sell_call[1.0], buy_put[37.0], sell_put[5.0]
# pnl : -4.4
# ==================== daytrade report of 2024-01-17====================
# middle line : 17300
# used strike : {'buy_call': 17400, 'buy_put': 17200, 'sell_call': 17600, 'sell_put': 17000}
# entry of each contract : buy_call[100.0], sell_call[33.5], buy_put[82.0], sell_put[35.0]
# entry cost : -113.5
# minimum diff by entry : 214
# max_diff_between_entry_and_expire : 644.98
# exit of each contract : buy_call[61.0], sell_call[18.0], buy_put[123.0], sell_put[60.0]
# pnl : -7.5
# ==================== daytrade report of 2024-01-18====================
# middle line : 17200
# used strike : {'buy_call': 17300, 'buy_put': 17100, 'sell_call': 17500, 'sell_put': 16900}
# entry of each contract : buy_call[99.0], sell_call[31.5], buy_put[62.0], sell_put[23.0]
# entry cost : -106.5
# minimum diff by entry : 207
# max_diff_between_entry_and_expire : 744.98
# exit of each contract : buy_call[97.0], sell_call[31.0], buy_put[58.0], sell_put[20.0]
# pnl : -2.5
# ==================== daytrade report of 2024-01-19====================
# middle line : 17500
# used strike : {'buy_call': 17600, 'buy_put': 17400, 'sell_call': 17800, 'sell_put': 17200}
# entry of each contract : buy_call[47.0], sell_call[8.3], buy_put[56.0], sell_put[16.5]
# entry cost : -78.2
# minimum diff by entry : 179
# max_diff_between_entry_and_expire : 444.98
# exit of each contract : buy_call[137.0], sell_call[45.0], buy_put[20.0], sell_put[6.2]
# pnl : 27.6
# ==================== daytrade report of 2024-01-22====================
# middle line : 17800
# used strike : {'buy_call': 17900, 'buy_put': 17700, 'sell_call': 18100, 'sell_put': 17500}
# entry of each contract : buy_call[56.0], sell_call[11.5], buy_put[31.5], sell_put[7.2]
# entry cost : -68.8
# minimum diff by entry : 169
# max_diff_between_entry_and_expire : 144.98
# exit of each contract : buy_call[38.5], sell_call[5.6], buy_put[26.0], sell_put[5.2]
# pnl : -15.1
# ==================== daytrade report of 2024-01-23====================
# middle line : 17900
# used strike : {'buy_call': 18000, 'buy_put': 17800, 'sell_call': 18200, 'sell_put': 17600}
# entry of each contract : buy_call[8.0], sell_call[0.7], buy_put[30.5], sell_put[3.5]
# entry cost : -34.3
# minimum diff by entry : 135
# max_diff_between_entry_and_expire : 44.98
# exit of each contract : buy_call[7.0], sell_call[0.7], buy_put[23.5], sell_put[1.9]
# pnl : -6.4
# ==================== daytrade report of 2024-01-24====================
# middle line : 17900
# used strike : {'buy_call': 18000, 'buy_put': 17800, 'sell_call': 18200, 'sell_put': 17600}
# entry of each contract : buy_call[86.0], sell_call[28.0], buy_put[79.0], sell_put[33.0]
# entry cost : -104.0
# minimum diff by entry : 205
# max_diff_between_entry_and_expire : 238.74
# exit of each contract : buy_call[66.0], sell_call[16.5], buy_put[86.0], sell_put[36.5]
# pnl : -5.0
# ==================== daytrade report of 2024-01-25====================
# middle line : 17900
# used strike : {'buy_call': 18000, 'buy_put': 17800, 'sell_call': 18200, 'sell_put': 17600}
# entry of each contract : buy_call[88.0], sell_call[23.5], buy_put[61.0], sell_put[23.5]
# entry cost : -102.0
# minimum diff by entry : 203
# max_diff_between_entry_and_expire : 238.74
# exit of each contract : buy_call[102.0], sell_call[28.5], buy_put[45.0], sell_put[15.5]
# pnl : 1.0
# ==================== daytrade report of 2024-01-26====================
# middle line : 18000
# used strike : {'buy_call': 18100, 'buy_put': 17900, 'sell_call': 18300, 'sell_put': 17700}
# entry of each contract : buy_call[52.0], sell_call[9.6], buy_put[65.0], sell_put[24.0]
# entry cost : -83.4
# minimum diff by entry : 184
# max_diff_between_entry_and_expire : 138.74
# exit of each contract : buy_call[45.5], sell_call[7.8], buy_put[62.0], sell_put[22.0]
# pnl : -5.7
# ==================== daytrade report of 2024-01-29====================
# middle line : 18000
# used strike : {'buy_call': 18100, 'buy_put': 17900, 'sell_call': 18300, 'sell_put': 17700}
# entry of each contract : buy_call[47.0], sell_call[5.4], buy_put[34.0], sell_put[9.4]
# entry cost : -66.2
# minimum diff by entry : 167
# max_diff_between_entry_and_expire : 138.74
# exit of each contract : buy_call[68.0], sell_call[7.4], buy_put[6.6], sell_put[1.4]
# pnl : -0.4
# ==================== daytrade report of 2024-01-30====================
# middle line : 18100
# used strike : {'buy_call': 18200, 'buy_put': 18000, 'sell_call': 18400, 'sell_put': 17800}
# entry of each contract : buy_call[16.5], sell_call[1.0], buy_put[10.0], sell_put[1.2]
# entry cost : -24.3
# minimum diff by entry : 125
# max_diff_between_entry_and_expire : 38.74
# exit of each contract : buy_call[5.9], sell_call[0.5], buy_put[17.0], sell_put[1.5]
# pnl : -3.4
# ==================== daytrade report of 2024-01-31====================
# middle line : 18000
# used strike : {'buy_call': 18100, 'buy_put': 17900, 'sell_call': 18300, 'sell_put': 17700}
# entry of each contract : buy_call[0.4], sell_call[0.1], buy_put[12.0], sell_put[0.4]
# entry cost : -11.9
# minimum diff by entry : 112
# max_diff_between_entry_and_expire : 40.42
# exit of each contract : buy_call[0.1], sell_call[0.1], buy_put[4.1], sell_put[0.3]
# pnl : -8.1

# %%
for k, v in middles.items():
    try:
        expire_pnl(k, v)
    except:
        pass
# Out:
# ==================== expire report of 2023-10-05====================
# middle line : 16400
# used strike : {'buy_call': 16500, 'buy_put': 16300, 'sell_call': 16700, 'sell_put': 16100}
# days to expire : 6
# entry of each contract : buy_call[102.0], sell_call[45.0], buy_put[149.0], sell_put[79.0]
# entry cost : -127.0
# minimum diff by entry : 228
# max_diff_between_entry_and_expire : 329.5
# exit of each contract : buy_call[260.0], sell_call[125.0], buy_put[17.5], sell_put[7.2]
# pnl : 18.3
# ==================== expire report of 2023-10-06====================
# middle line : 16500
# used strike : {'buy_call': 16600, 'buy_put': 16400, 'sell_call': 16800, 'sell_put': 16200}
# days to expire : 5
# entry of each contract : buy_call[106.0], sell_call[44.5], buy_put[116.0], sell_put[59.0]
# entry cost : -118.5
# minimum diff by entry : 219
# max_diff_between_entry_and_expire : 229.5
# exit of each contract : buy_call[186.0], sell_call[76.0], buy_put[28.0], sell_put[10.5]
# pnl : 9.0
# c:\users\kevin\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3343: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ==================== expire report of 2023-10-11====================
# middle line : 16700
# used strike : {'buy_call': 16800, 'buy_put': 16600, 'sell_call': 17000, 'sell_put': 16400}
# days to expire : 7
# entry of each contract : buy_call[150.0], sell_call[66.0], buy_put[119.0], sell_put[65.0]
# entry cost : -138.0
# minimum diff by entry : 239
# max_diff_between_entry_and_expire : 125.91
# exit of each contract : buy_call[22.5], sell_call[5.1], buy_put[212.0], sell_put[108.0]
# pnl : -16.6
# ==================== expire report of 2023-10-12====================
# middle line : 16700
# used strike : {'buy_call': 16800, 'buy_put': 16600, 'sell_call': 17000, 'sell_put': 16400}
# days to expire : 6
# entry of each contract : buy_call[148.0], sell_call[69.0], buy_put[95.0], sell_put[48.0]
# entry cost : -126.0
# minimum diff by entry : 227
# max_diff_between_entry_and_expire : 125.91
# exit of each contract : buy_call[22.5], sell_call[5.1], buy_put[212.0], sell_put[108.0]
# pnl : -4.6
# ==================== expire report of 2023-10-13====================
# middle line : 16800
# used strike : {'buy_call': 16900, 'buy_put': 16700, 'sell_call': 17100, 'sell_put': 16500}
# days to expire : 5
# entry of each contract : buy_call[104.0], sell_call[43.5], buy_put[117.0], sell_put[61.0]
# entry cost : -116.5
# minimum diff by entry : 217
# max_diff_between_entry_and_expire : 6.71
# exit of each contract : buy_call[11.0], sell_call[2.9], buy_put[283.0], sell_put[155.0]
# pnl : 19.6
# ==================== expire report of 2023-10-16====================
# middle line : 16700
# used strike : {'buy_call': 16800, 'buy_put': 16600, 'sell_call': 17000, 'sell_put': 16400}
# days to expire : 2
# entry of each contract : buy_call[99.0], sell_call[39.0], buy_put[122.0], sell_put[62.0]
# entry cost : -120.0
# minimum diff by entry : 221
# max_diff_between_entry_and_expire : 70.64
# exit of each contract : buy_call[22.5], sell_call[5.1], buy_put[212.0], sell_put[108.0]
# pnl : 1.4
# ==================== expire report of 2023-10-17====================
# middle line : 16700
# used strike : {'buy_call': 16800, 'buy_put': 16600, 'sell_call': 17000, 'sell_put': 16400}
# days to expire : 1
# entry of each contract : buy_call[98.0], sell_call[33.5], buy_put[89.0], sell_put[40.0]
# entry cost : -113.5
# minimum diff by entry : 214
# max_diff_between_entry_and_expire : 42.91
# exit of each contract : buy_call[22.5], sell_call[5.1], buy_put[212.0], sell_put[108.0]
# pnl : 7.9
# ==================== expire report of 2023-10-25====================
# middle line : 16400
# used strike : {'buy_call': 16500, 'buy_put': 16300, 'sell_call': 16700, 'sell_put': 16100}
# days to expire : 7
# entry of each contract : buy_call[82.0], sell_call[25.0], buy_put[94.0], sell_put[42.0]
# entry cost : -109.0
# minimum diff by entry : 210
# max_diff_between_entry_and_expire : 59.34
# exit of each contract : buy_call[0.1], sell_call[0.1], buy_put[241.0], sell_put[40.0]
# pnl : 92.0
# ==================== expire report of 2023-10-26====================
# middle line : 16200
# used strike : {'buy_call': 16300, 'buy_put': 16100, 'sell_call': 16500, 'sell_put': 15900}
# days to expire : 6
# entry of each contract : buy_call[53.0], sell_call[13.5], buy_put[140.0], sell_put[69.0]
# entry cost : -110.5
# minimum diff by entry : 211
# max_diff_between_entry_and_expire : 15.35
# exit of each contract : buy_call[0.1], sell_call[0.1], buy_put[40.0], sell_put[0.1]
# pnl : -70.6
# ==================== expire report of 2023-10-27====================
# middle line : 16100
# used strike : {'buy_call': 16200, 'buy_put': 16000, 'sell_call': 16400, 'sell_put': 15800}
# days to expire : 5
# entry of each contract : buy_call[98.0], sell_call[27.0], buy_put[58.0], sell_put[21.5]
# entry cost : -107.5
# minimum diff by entry : 208
# max_diff_between_entry_and_expire : 115.35
# exit of each contract : buy_call[0.1], sell_call[0.1], buy_put[0.1], sell_put[0.1]
# pnl : -107.5
# ==================== expire report of 2023-10-30====================
# middle line : 16200
# used strike : {'buy_call': 16300, 'buy_put': 16100, 'sell_call': 16500, 'sell_put': 15900}
# days to expire : 2
# entry of each contract : buy_call[22.5], sell_call[2.0], buy_put[60.0], sell_put[14.5]
# entry cost : -66.0
# minimum diff by entry : 167
# max_diff_between_entry_and_expire : 15.35
# exit of each contract : buy_call[0.1], sell_call[0.1], buy_put[40.0], sell_put[0.1]
# pnl : -26.1
# ==================== expire report of 2023-10-31====================
# middle line : 16200
# used strike : {'buy_call': 16300, 'buy_put': 16100, 'sell_call': 16500, 'sell_put': 15900}
# days to expire : 1
# entry of each contract : buy_call[15.0], sell_call[1.1], buy_put[41.0], sell_put[6.1]
# entry cost : -48.8
# minimum diff by entry : 149
# max_diff_between_entry_and_expire : 8.11
# exit of each contract : buy_call[0.1], sell_call[0.1], buy_put[40.0], sell_put[0.1]
# pnl : -8.9
# ==================== expire report of 2023-11-01====================
# middle line : 16100
# used strike : {'buy_call': 16200, 'buy_put': 16000, 'sell_call': 16400, 'sell_put': 15800}
# days to expire : 7
# entry of each contract : buy_call[78.0], sell_call[24.5], buy_put[103.0], sell_put[46.0]
# entry cost : -110.5
# minimum diff by entry : 211
# max_diff_between_entry_and_expire : 675.23
# exit of each contract : buy_call[535.0], sell_call[335.0], buy_put[0.2], sell_put[0.4]
# pnl : 89.3
# ==================== expire report of 2023-11-02====================
# middle line : 16200
# used strike : {'buy_call': 16300, 'buy_put': 16100, 'sell_call': 16500, 'sell_put': 15900}
# days to expire : 6
# entry of each contract : buy_call[122.0], sell_call[41.0], buy_put[39.0], sell_put[12.5]
# entry cost : -107.5
# minimum diff by entry : 208
# max_diff_between_entry_and_expire : 575.23
# exit of each contract : buy_call[433.0], sell_call[235.0], buy_put[0.1], sell_put[0.1]
# pnl : 90.5
# ==================== expire report of 2023-11-03====================
# middle line : 16400
# used strike : {'buy_call': 16500, 'buy_put': 16300, 'sell_call': 16700, 'sell_put': 16100}
# days to expire : 5
# entry of each contract : buy_call[65.0], sell_call[12.5], buy_put[38.5], sell_put[9.8]
# entry cost : -81.2
# minimum diff by entry : 182
# max_diff_between_entry_and_expire : 375.23
# exit of each contract : buy_call[235.0], sell_call[34.0], buy_put[0.1], sell_put[0.1]
# pnl : 119.8
# ==================== expire report of 2023-11-06====================
# middle line : 16600
# used strike : {'buy_call': 16700, 'buy_put': 16500, 'sell_call': 16900, 'sell_put': 16300}
# days to expire : 2
# entry of each contract : buy_call[37.0], sell_call[4.1], buy_put[25.0], sell_put[5.9]
# entry cost : -52.0
# minimum diff by entry : 153
# max_diff_between_entry_and_expire : 175.23
# exit of each contract : buy_call[34.0], sell_call[0.1], buy_put[0.1], sell_put[0.1]
# pnl : -18.1
# ==================== expire report of 2023-11-07====================
# middle line : 16600
# used strike : {'buy_call': 16700, 'buy_put': 16500, 'sell_call': 16900, 'sell_put': 16300}
# days to expire : 1
# entry of each contract : buy_call[26.0], sell_call[2.0], buy_put[11.0], sell_put[2.3]
# entry cost : -32.7
# minimum diff by entry : 133
# max_diff_between_entry_and_expire : 175.23
# exit of each contract : buy_call[34.0], sell_call[0.1], buy_put[0.1], sell_put[0.1]
# pnl : 1.2
# ==================== expire report of 2023-11-08====================
# middle line : 16700
# used strike : {'buy_call': 16800, 'buy_put': 16600, 'sell_call': 17000, 'sell_put': 16400}
# days to expire : 7
# entry of each contract : buy_call[79.0], sell_call[23.0], buy_put[75.0], sell_put[30.5]
# entry cost : -100.5
# minimum diff by entry : 201
# max_diff_between_entry_and_expire : 443.88
# exit of each contract : buy_call[323.0], sell_call[123.0], buy_put[0.1], sell_put[0.1]
# pnl : 99.5
# ==================== expire report of 2023-11-09====================
# middle line : 16700
# used strike : {'buy_call': 16800, 'buy_put': 16600, 'sell_call': 17000, 'sell_put': 16400}
# days to expire : 6
# entry of each contract : buy_call[66.0], sell_call[12.5], buy_put[58.0], sell_put[22.0]
# entry cost : -89.5
# minimum diff by entry : 190
# max_diff_between_entry_and_expire : 443.88
# exit of each contract : buy_call[323.0], sell_call[123.0], buy_put[0.1], sell_put[0.1]
# pnl : 110.5
# ==================== expire report of 2023-11-10====================
# middle line : 16700
# used strike : {'buy_call': 16800, 'buy_put': 16600, 'sell_call': 17000, 'sell_put': 16400}
# days to expire : 5
# entry of each contract : buy_call[45.0], sell_call[7.3], buy_put[59.0], sell_put[18.5]
# entry cost : -78.2
# minimum diff by entry : 179
# max_diff_between_entry_and_expire : 443.88
# exit of each contract : buy_call[323.0], sell_call[123.0], buy_put[0.1], sell_put[0.1]
# pnl : 121.8
# ==================== expire report of 2023-11-13====================
# middle line : 16800
# used strike : {'buy_call': 16900, 'buy_put': 16700, 'sell_call': 17100, 'sell_put': 16500}
# days to expire : 2
# entry of each contract : buy_call[75.0], sell_call[15.0], buy_put[14.0], sell_put[2.6]
# entry cost : -71.4
# minimum diff by entry : 172
# max_diff_between_entry_and_expire : 343.88
# exit of each contract : buy_call[223.0], sell_call[23.0], buy_put[0.3], sell_put[0.3]
# pnl : 128.6
# ==================== expire report of 2023-11-14====================
# middle line : 16900
# used strike : {'buy_call': 17000, 'buy_put': 16800, 'sell_call': 17200, 'sell_put': 16600}
# days to expire : 1
# entry of each contract : buy_call[24.0], sell_call[1.5], buy_put[14.5], sell_put[2.0]
# entry cost : -35.0
# minimum diff by entry : 136
# max_diff_between_entry_and_expire : 243.88
# exit of each contract : buy_call[123.0], sell_call[0.1], buy_put[0.1], sell_put[0.1]
# pnl : 87.9
# ==================== expire report of 2023-11-15====================
# middle line : 17100
# used strike : {'buy_call': 17200, 'buy_put': 17000, 'sell_call': 17400, 'sell_put': 16800}
# days to expire : 7
# entry of each contract : buy_call[111.0], sell_call[39.5], buy_put[57.0], sell_put[22.5]
# entry cost : -106.0
# minimum diff by entry : 207
# max_diff_between_entry_and_expire : 321.17
# exit of each contract : buy_call[88.0], sell_call[0.2], buy_put[0.1], sell_put[0.1]
# pnl : -18.2
# ==================== expire report of 2023-11-16====================
# middle line : 17200
# used strike : {'buy_call': 17300, 'buy_put': 17100, 'sell_call': 17500, 'sell_put': 16900}
# days to expire : 6
# entry of each contract : buy_call[61.0], sell_call[16.0], buy_put[71.0], sell_put[23.0]
# entry cost : -93.0
# minimum diff by entry : 194
# max_diff_between_entry_and_expire : 221.17
# exit of each contract : buy_call[0.2], sell_call[0.2], buy_put[0.1], sell_put[0.1]
# pnl : -93.0
# ==================== expire report of 2023-11-17====================
# middle line : 17200
# used strike : {'buy_call': 17300, 'buy_put': 17100, 'sell_call': 17500, 'sell_put': 16900}
# days to expire : 5
# entry of each contract : buy_call[52.0], sell_call[11.0], buy_put[64.0], sell_put[19.0]
# entry cost : -86.0
# minimum diff by entry : 187
# max_diff_between_entry_and_expire : 221.17
# exit of each contract : buy_call[0.2], sell_call[0.2], buy_put[0.1], sell_put[0.1]
# pnl : -86.0
# ==================== expire report of 2023-11-20====================
# middle line : 17200
# used strike : {'buy_call': 17300, 'buy_put': 17100, 'sell_call': 17500, 'sell_put': 16900}
# days to expire : 2
# entry of each contract : buy_call[47.0], sell_call[6.8], buy_put[33.5], sell_put[5.9]
# entry cost : -67.8
# minimum diff by entry : 168
# max_diff_between_entry_and_expire : 221.17
# exit of each contract : buy_call[0.2], sell_call[0.2], buy_put[0.1], sell_put[0.1]
# pnl : -67.8
# ==================== expire report of 2023-11-21====================
# middle line : 17300
# used strike : {'buy_call': 17400, 'buy_put': 17200, 'sell_call': 17600, 'sell_put': 17000}
# days to expire : 1
# entry of each contract : buy_call[49.5], sell_call[4.6], buy_put[13.0], sell_put[2.4]
# entry cost : -55.5
# minimum diff by entry : 156
# max_diff_between_entry_and_expire : 121.17
# exit of each contract : buy_call[0.2], sell_call[0.1], buy_put[0.2], sell_put[0.1]
# pnl : -55.3
# ==================== expire report of 2023-11-22====================
# middle line : 17300
# used strike : {'buy_call': 17400, 'buy_put': 17200, 'sell_call': 17600, 'sell_put': 17000}
# days to expire : 7
# entry of each contract : buy_call[85.0], sell_call[27.0], buy_put[57.0], sell_put[18.0]
# entry cost : -97.0
# minimum diff by entry : 198
# max_diff_between_entry_and_expire : 141.79
# exit of each contract : buy_call[0.1], sell_call[0.1], buy_put[0.1], sell_put[0.1]
# pnl : -97.0
# ==================== expire report of 2023-11-23====================
# middle line : 17300
# used strike : {'buy_call': 17400, 'buy_put': 17200, 'sell_call': 17600, 'sell_put': 17000}
# days to expire : 6
# entry of each contract : buy_call[55.0], sell_call[11.5], buy_put[46.0], sell_put[10.5]
# entry cost : -79.0
# minimum diff by entry : 180
# max_diff_between_entry_and_expire : 141.79
# exit of each contract : buy_call[0.1], sell_call[0.1], buy_put[0.1], sell_put[0.1]
# pnl : -79.0
# ==================== expire report of 2023-11-24====================
# middle line : 17300
# used strike : {'buy_call': 17400, 'buy_put': 17200, 'sell_call': 17600, 'sell_put': 17000}
# days to expire : 5
# entry of each contract : buy_call[37.5], sell_call[5.8], buy_put[42.5], sell_put[8.0]
# entry cost : -66.2
# minimum diff by entry : 167
# max_diff_between_entry_and_expire : 141.79
# exit of each contract : buy_call[0.1], sell_call[0.1], buy_put[0.1], sell_put[0.1]
# pnl : -66.2
# ==================== expire report of 2023-11-27====================
# middle line : 17300
# used strike : {'buy_call': 17400, 'buy_put': 17200, 'sell_call': 17600, 'sell_put': 17000}
# days to expire : 2
# entry of each contract : buy_call[43.0], sell_call[4.9], buy_put[19.5], sell_put[2.8]
# entry cost : -54.8
# minimum diff by entry : 155
# max_diff_between_entry_and_expire : 141.79
# exit of each contract : buy_call[0.1], sell_call[0.1], buy_put[0.1], sell_put[0.1]
# pnl : -54.8
# ==================== expire report of 2023-11-28====================
# middle line : 17200
# used strike : {'buy_call': 17300, 'buy_put': 17100, 'sell_call': 17500, 'sell_put': 16900}
# days to expire : 1
# entry of each contract : buy_call[24.0], sell_call[1.2], buy_put[10.5], sell_put[1.2]
# entry cost : -32.1
# minimum diff by entry : 133
# max_diff_between_entry_and_expire : 241.79
# exit of each contract : buy_call[68.0], sell_call[0.1], buy_put[0.1], sell_put[0.1]
# pnl : 35.8
# ==================== expire report of 2023-11-29====================
# middle line : 17400
# used strike : {'buy_call': 17500, 'buy_put': 17300, 'sell_call': 17700, 'sell_put': 17100}
# days to expire : 0
# entry of each contract : buy_call[4.8], sell_call[0.1], buy_put[1.8], sell_put[0.4]
# entry cost : -6.1
# minimum diff by entry : 107
# max_diff_between_entry_and_expire : 38.06
# exit of each contract : buy_call[0.1], sell_call[0.1], buy_put[0.1], sell_put[0.1]
# pnl : -6.1
# ==================== expire report of 2023-11-30====================
# middle line : 17400
# used strike : {'buy_call': 17500, 'buy_put': 17300, 'sell_call': 17700, 'sell_put': 17100}
# days to expire : 6
# entry of each contract : buy_call[99.0], sell_call[40.5], buy_put[118.0], sell_put[54.0]
# entry cost : -122.5
# minimum diff by entry : 223
# max_diff_between_entry_and_expire : 116.61
# exit of each contract : buy_call[60.0], sell_call[14.5], buy_put[70.0], sell_put[22.0]
# pnl : -29.0
# ==================== expire report of 2023-12-01====================
# middle line : 17400
# used strike : {'buy_call': 17500, 'buy_put': 17300, 'sell_call': 17700, 'sell_put': 17100}
# days to expire : 5
# entry of each contract : buy_call[77.0], sell_call[32.0], buy_put[125.0], sell_put[66.0]
# entry cost : -104.0
# minimum diff by entry : 205
# max_diff_between_entry_and_expire : 116.61
# exit of each contract : buy_call[60.0], sell_call[14.5], buy_put[70.0], sell_put[22.0]
# pnl : -10.5
# ==================== expire report of 2023-12-04====================
# middle line : 17500
# used strike : {'buy_call': 17600, 'buy_put': 17400, 'sell_call': 17800, 'sell_put': 17200}
# days to expire : 2
# entry of each contract : buy_call[67.0], sell_call[22.5], buy_put[111.0], sell_put[48.0]
# entry cost : -107.5
# minimum diff by entry : 208
# max_diff_between_entry_and_expire : 46.62
# exit of each contract : buy_call[31.5], sell_call[6.5], buy_put[113.0], sell_put[40.5]
# pnl : -10.0
# ==================== expire report of 2023-12-05====================
# middle line : 17300
# used strike : {'buy_call': 17400, 'buy_put': 17200, 'sell_call': 17600, 'sell_put': 17000}
# days to expire : 1
# entry of each contract : buy_call[74.0], sell_call[24.0], buy_put[93.0], sell_put[38.0]
# entry cost : -105.0
# minimum diff by entry : 206
# max_diff_between_entry_and_expire : 139.85
# exit of each contract : buy_call[101.0], sell_call[31.5], buy_put[40.5], sell_put[10.5]
# pnl : -5.5
# ==================== expire report of 2023-12-06====================
# middle line : 17400
# used strike : {'buy_call': 17500, 'buy_put': 17300, 'sell_call': 17700, 'sell_put': 17100}
# days to expire : 7
# entry of each contract : buy_call[98.0], sell_call[41.0], buy_put[121.0], sell_put[61.0]
# entry cost : -117.0
# minimum diff by entry : 218
# max_diff_between_entry_and_expire : 128.72
# exit of each contract : buy_call[81.0], sell_call[22.5], buy_put[44.0], sell_put[12.0]
# pnl : -26.5
# ==================== expire report of 2023-12-07====================
# middle line : 17400
# used strike : {'buy_call': 17500, 'buy_put': 17300, 'sell_call': 17700, 'sell_put': 17100}
# days to expire : 6
# entry of each contract : buy_call[74.0], sell_call[29.5], buy_put[140.0], sell_put[66.0]
# entry cost : -118.5
# minimum diff by entry : 219
# max_diff_between_entry_and_expire : 128.72
# exit of each contract : buy_call[81.0], sell_call[22.5], buy_put[44.0], sell_put[12.0]
# pnl : -28.0
# ==================== expire report of 2023-12-08====================
# middle line : 17400
# used strike : {'buy_call': 17500, 'buy_put': 17300, 'sell_call': 17700, 'sell_put': 17100}
# days to expire : 5
# entry of each contract : buy_call[112.0], sell_call[47.0], buy_put[89.0], sell_put[39.5]
# entry cost : -114.5
# minimum diff by entry : 215
# max_diff_between_entry_and_expire : 128.72
# exit of each contract : buy_call[81.0], sell_call[22.5], buy_put[44.0], sell_put[12.0]
# pnl : -24.0
# ==================== expire report of 2023-12-11====================
# middle line : 17400
# used strike : {'buy_call': 17500, 'buy_put': 17300, 'sell_call': 17700, 'sell_put': 17100}
# days to expire : 2
# entry of each contract : buy_call[77.0], sell_call[27.5], buy_put[100.0], sell_put[43.0]
# entry cost : -106.5
# minimum diff by entry : 207
# max_diff_between_entry_and_expire : 128.72
# exit of each contract : buy_call[81.0], sell_call[22.5], buy_put[44.0], sell_put[12.0]
# pnl : -16.0
# ==================== expire report of 2023-12-12====================
# middle line : 17500
# used strike : {'buy_call': 17600, 'buy_put': 17400, 'sell_call': 17800, 'sell_put': 17200}
# days to expire : 1
# entry of each contract : buy_call[78.0], sell_call[25.5], buy_put[74.0], sell_put[26.5]
# entry cost : -100.0
# minimum diff by entry : 201
# max_diff_between_entry_and_expire : 7.92
# exit of each contract : buy_call[45.0], sell_call[9.6], buy_put[75.0], sell_put[23.0]
# pnl : -12.6
# ==================== expire report of 2023-12-13====================
# middle line : 17500
# used strike : {'buy_call': 17600, 'buy_put': 17400, 'sell_call': 17800, 'sell_put': 17200}
# days to expire : 7
# entry of each contract : buy_call[103.0], sell_call[42.0], buy_put[102.0], sell_put[43.0]
# entry cost : -120.0
# minimum diff by entry : 221
# max_diff_between_entry_and_expire : 243.54
# exit of each contract : buy_call[130.0], sell_call[38.0], buy_put[14.0], sell_put[3.7]
# pnl : -17.7
# ==================== expire report of 2023-12-14====================
# middle line : 17600
# used strike : {'buy_call': 17700, 'buy_put': 17500, 'sell_call': 17900, 'sell_put': 17300}
# days to expire : 6
# entry of each contract : buy_call[108.0], sell_call[42.0], buy_put[75.0], sell_put[29.0]
# entry cost : -112.0
# minimum diff by entry : 213
# max_diff_between_entry_and_expire : 143.54
# exit of each contract : buy_call[76.0], sell_call[16.5], buy_put[30.0], sell_put[6.6]
# pnl : -29.1
# ==================== expire report of 2023-12-15====================
# middle line : 17700
# used strike : {'buy_call': 17800, 'buy_put': 17600, 'sell_call': 18000, 'sell_put': 17400}
# days to expire : 5
# entry of each contract : buy_call[85.0], sell_call[28.0], buy_put[76.0], sell_put[31.5]
# entry cost : -101.5
# minimum diff by entry : 202
# max_diff_between_entry_and_expire : 38.82
# exit of each contract : buy_call[38.0], sell_call[6.5], buy_put[59.0], sell_put[14.0]
# pnl : -25.0
# ==================== expire report of 2023-12-18====================
# middle line : 17600
# used strike : {'buy_call': 17700, 'buy_put': 17500, 'sell_call': 17900, 'sell_put': 17300}
# days to expire : 2
# entry of each contract : buy_call[86.0], sell_call[27.0], buy_put[62.0], sell_put[21.0]
# entry cost : -100.0
# minimum diff by entry : 201
# max_diff_between_entry_and_expire : 69.84
# exit of each contract : buy_call[76.0], sell_call[16.5], buy_put[30.0], sell_put[6.6]
# pnl : -17.1
# ==================== expire report of 2023-12-19====================
# middle line : 17600
# used strike : {'buy_call': 17700, 'buy_put': 17500, 'sell_call': 17900, 'sell_put': 17300}
# days to expire : 1
# entry of each contract : buy_call[52.0], sell_call[12.0], buy_put[67.0], sell_put[21.5]
# entry cost : -85.5
# minimum diff by entry : 186
# max_diff_between_entry_and_expire : 57.65
# exit of each contract : buy_call[76.0], sell_call[16.5], buy_put[30.0], sell_put[6.6]
# pnl : -2.6
# ==================== expire report of 2023-12-27====================
# middle line : 17800
# used strike : {'buy_call': 17900, 'buy_put': 17700, 'sell_call': 18100, 'sell_put': 17500}
# days to expire : 7
# entry of each contract : buy_call[55.0], sell_call[10.5], buy_put[47.5], sell_put[13.5]
# entry cost : -78.5
# minimum diff by entry : 179
# max_diff_between_entry_and_expire : 156.74
# exit of each contract : buy_call[0.2], sell_call[0.3], buy_put[143.0], sell_put[0.1]
# pnl : 64.3
# ==================== expire report of 2023-12-28====================
# middle line : 17900
# used strike : {'buy_call': 18000, 'buy_put': 17800, 'sell_call': 18200, 'sell_put': 17600}
# days to expire : 6
# entry of each contract : buy_call[36.0], sell_call[5.8], buy_put[55.0], sell_put[13.5]
# entry cost : -71.7
# minimum diff by entry : 172
# max_diff_between_entry_and_expire : 56.74
# exit of each contract : buy_call[0.2], sell_call[0.1], buy_put[244.0], sell_put[44.0]
# pnl : 128.4
# ==================== expire report of 2023-12-29====================
# middle line : 17900
# used strike : {'buy_call': 18000, 'buy_put': 17800, 'sell_call': 18200, 'sell_put': 17600}
# days to expire : 5
# entry of each contract : buy_call[29.5], sell_call[4.3], buy_put[51.0], sell_put[10.0]
# entry cost : -66.2
# minimum diff by entry : 167
# max_diff_between_entry_and_expire : 56.74
# exit of each contract : buy_call[0.2], sell_call[0.1], buy_put[244.0], sell_put[44.0]
# pnl : 133.9
# ==================== expire report of 2024-01-02====================
# middle line : 17900
# used strike : {'buy_call': 18000, 'buy_put': 17800, 'sell_call': 18200, 'sell_put': 17600}
# days to expire : 1
# entry of each contract : buy_call[11.0], sell_call[0.8], buy_put[28.0], sell_put[2.3]
# entry cost : -35.9
# minimum diff by entry : 136
# max_diff_between_entry_and_expire : 6.82
# exit of each contract : buy_call[0.2], sell_call[0.1], buy_put[244.0], sell_put[44.0]
# pnl : 164.2
# ==================== expire report of 2024-01-03====================
# middle line : 17700
# used strike : {'buy_call': 17800, 'buy_put': 17600, 'sell_call': 18000, 'sell_put': 17400}
# days to expire : 7
# entry of each contract : buy_call[40.5], sell_call[9.8], buy_put[112.0], sell_put[43.0]
# entry cost : -99.7
# minimum diff by entry : 200
# max_diff_between_entry_and_expire : 5.74
# exit of each contract : buy_call[0.3], sell_call[0.2], buy_put[118.0], sell_put[0.1]
# pnl : 18.3
# ==================== expire report of 2024-01-04====================
# middle line : 17600
# used strike : {'buy_call': 17700, 'buy_put': 17500, 'sell_call': 17900, 'sell_put': 17300}
# days to expire : 6
# entry of each contract : buy_call[44.5], sell_call[9.0], buy_put[86.0], sell_put[31.0]
# entry cost : -90.5
# minimum diff by entry : 191
# max_diff_between_entry_and_expire : 94.26
# exit of each contract : buy_call[0.2], sell_call[0.1], buy_put[19.0], sell_put[0.2]
# pnl : -71.6
# ==================== expire report of 2024-01-05====================
# middle line : 17600
# used strike : {'buy_call': 17700, 'buy_put': 17500, 'sell_call': 17900, 'sell_put': 17300}
# days to expire : 5
# entry of each contract : buy_call[47.0], sell_call[8.2], buy_put[60.0], sell_put[17.0]
# entry cost : -81.8
# minimum diff by entry : 182
# max_diff_between_entry_and_expire : 94.26
# exit of each contract : buy_call[0.2], sell_call[0.1], buy_put[19.0], sell_put[0.2]
# pnl : -62.9
# ==================== expire report of 2024-01-08====================
# middle line : 17600
# used strike : {'buy_call': 17700, 'buy_put': 17500, 'sell_call': 17900, 'sell_put': 17300}
# days to expire : 2
# entry of each contract : buy_call[69.0], sell_call[8.1], buy_put[18.0], sell_put[4.3]
# entry cost : -74.6
# minimum diff by entry : 175
# max_diff_between_entry_and_expire : 94.26
# exit of each contract : buy_call[0.2], sell_call[0.1], buy_put[19.0], sell_put[0.2]
# pnl : -55.7
# ==================== expire report of 2024-01-09====================
# middle line : 17600
# used strike : {'buy_call': 17700, 'buy_put': 17500, 'sell_call': 17900, 'sell_put': 17300}
# days to expire : 1
# entry of each contract : buy_call[45.5], sell_call[2.5], buy_put[8.5], sell_put[1.7]
# entry cost : -49.8
# minimum diff by entry : 150
# max_diff_between_entry_and_expire : 42.06
# exit of each contract : buy_call[0.2], sell_call[0.1], buy_put[19.0], sell_put[0.2]
# pnl : -30.9
# ==================== expire report of 2024-01-10====================
# middle line : 17500
# used strike : {'buy_call': 17600, 'buy_put': 17400, 'sell_call': 17800, 'sell_put': 17200}
# days to expire : 7
# entry of each contract : buy_call[106.0], sell_call[46.0], buy_put[117.0], sell_put[60.0]
# entry cost : -117.0
# minimum diff by entry : 218
# max_diff_between_entry_and_expire : 132.77
# exit of each contract : buy_call[0.1], sell_call[0.1], buy_put[232.0], sell_put[32.5]
# pnl : 82.5
# ==================== expire report of 2024-01-11====================
# middle line : 17500
# used strike : {'buy_call': 17600, 'buy_put': 17400, 'sell_call': 17800, 'sell_put': 17200}
# days to expire : 6
# entry of each contract : buy_call[113.0], sell_call[49.0], buy_put[115.0], sell_put[59.0]
# entry cost : -120.0
# minimum diff by entry : 221
# max_diff_between_entry_and_expire : 132.77
# exit of each contract : buy_call[0.1], sell_call[0.1], buy_put[232.0], sell_put[32.5]
# pnl : 79.5
# ==================== expire report of 2024-01-12====================
# middle line : 17500
# used strike : {'buy_call': 17600, 'buy_put': 17400, 'sell_call': 17800, 'sell_put': 17200}
# days to expire : 5
# entry of each contract : buy_call[111.0], sell_call[57.0], buy_put[144.0], sell_put[74.0]
# entry cost : -124.0
# minimum diff by entry : 225
# max_diff_between_entry_and_expire : 132.77
# exit of each contract : buy_call[0.1], sell_call[0.1], buy_put[232.0], sell_put[32.5]
# pnl : 75.5
# ==================== expire report of 2024-01-15====================
# middle line : 17600
# used strike : {'buy_call': 17700, 'buy_put': 17500, 'sell_call': 17900, 'sell_put': 17300}
# days to expire : 2
# entry of each contract : buy_call[25.5], sell_call[3.2], buy_put[54.0], sell_put[13.0]
# entry cost : -63.3
# minimum diff by entry : 164
# max_diff_between_entry_and_expire : 20.3
# exit of each contract : buy_call[0.1], sell_call[0.3], buy_put[332.0], sell_put[132.0]
# pnl : 136.5
# ==================== expire report of 2024-01-16====================
# middle line : 17400
# used strike : {'buy_call': 17500, 'buy_put': 17300, 'sell_call': 17700, 'sell_put': 17100}
# days to expire : 1
# entry of each contract : buy_call[15.5], sell_call[1.8], buy_put[32.0], sell_put[5.2]
# entry cost : -40.5
# minimum diff by entry : 141
# max_diff_between_entry_and_expire : 56.52
# exit of each contract : buy_call[0.2], sell_call[0.1], buy_put[132.0], sell_put[0.2]
# pnl : 91.4
# ==================== expire report of 2024-01-17====================
# middle line : 17300
# used strike : {'buy_call': 17400, 'buy_put': 17200, 'sell_call': 17600, 'sell_put': 17000}
# days to expire : 7
# entry of each contract : buy_call[100.0], sell_call[33.5], buy_put[82.0], sell_put[35.0]
# entry cost : -113.5
# minimum diff by entry : 214
# max_diff_between_entry_and_expire : 644.98
# exit of each contract : buy_call[474.0], sell_call[273.0], buy_put[0.2], sell_put[0.5]
# pnl : 87.2
# ==================== expire report of 2024-01-18====================
# middle line : 17200
# used strike : {'buy_call': 17300, 'buy_put': 17100, 'sell_call': 17500, 'sell_put': 16900}
# days to expire : 6
# entry of each contract : buy_call[99.0], sell_call[31.5], buy_put[62.0], sell_put[23.0]
# entry cost : -106.5
# minimum diff by entry : 207
# max_diff_between_entry_and_expire : 744.98
# exit of each contract : buy_call[570.0], sell_call[374.0], buy_put[0.2], sell_put[0.3]
# pnl : 89.4
# ==================== expire report of 2024-01-19====================
# middle line : 17500
# used strike : {'buy_call': 17600, 'buy_put': 17400, 'sell_call': 17800, 'sell_put': 17200}
# days to expire : 5
# entry of each contract : buy_call[47.0], sell_call[8.3], buy_put[56.0], sell_put[16.5]
# entry cost : -78.2
# minimum diff by entry : 179
# max_diff_between_entry_and_expire : 444.98
# exit of each contract : buy_call[273.0], sell_call[73.0], buy_put[0.3], sell_put[0.2]
# pnl : 121.9
# ==================== expire report of 2024-01-22====================
# middle line : 17800
# used strike : {'buy_call': 17900, 'buy_put': 17700, 'sell_call': 18100, 'sell_put': 17500}
# days to expire : 2
# entry of each contract : buy_call[56.0], sell_call[11.5], buy_put[31.5], sell_put[7.2]
# entry cost : -68.8
# minimum diff by entry : 169
# max_diff_between_entry_and_expire : 144.98
# exit of each contract : buy_call[0.1], sell_call[0.2], buy_put[0.1], sell_put[0.3]
# pnl : -69.1
# ==================== expire report of 2024-01-23====================
# middle line : 17900
# used strike : {'buy_call': 18000, 'buy_put': 17800, 'sell_call': 18200, 'sell_put': 17600}
# days to expire : 1
# entry of each contract : buy_call[8.0], sell_call[0.7], buy_put[30.5], sell_put[3.5]
# entry cost : -34.3
# minimum diff by entry : 135
# max_diff_between_entry_and_expire : 44.98
# exit of each contract : buy_call[0.1], sell_call[0.1], buy_put[0.1], sell_put[0.1]
# pnl : -34.3
# ==================== expire report of 2024-01-24====================
# middle line : 17900
# used strike : {'buy_call': 18000, 'buy_put': 17800, 'sell_call': 18200, 'sell_put': 17600}
# days to expire : 7
# entry of each contract : buy_call[86.0], sell_call[28.0], buy_put[79.0], sell_put[33.0]
# entry cost : -104.0
# minimum diff by entry : 205
# max_diff_between_entry_and_expire : 238.74
# exit of each contract : buy_call[0.2], sell_call[0.1], buy_put[0.1], sell_put[0.1]
# pnl : -103.9
# ==================== expire report of 2024-01-25====================
# middle line : 17900
# used strike : {'buy_call': 18000, 'buy_put': 17800, 'sell_call': 18200, 'sell_put': 17600}
# days to expire : 6
# entry of each contract : buy_call[88.0], sell_call[23.5], buy_put[61.0], sell_put[23.5]
# entry cost : -102.0
# minimum diff by entry : 203
# max_diff_between_entry_and_expire : 238.74
# exit of each contract : buy_call[0.2], sell_call[0.1], buy_put[0.1], sell_put[0.1]
# pnl : -101.9
# ==================== expire report of 2024-01-26====================
# middle line : 18000
# used strike : {'buy_call': 18100, 'buy_put': 17900, 'sell_call': 18300, 'sell_put': 17700}
# days to expire : 5
# entry of each contract : buy_call[52.0], sell_call[9.6], buy_put[65.0], sell_put[24.0]
# entry cost : -83.4
# minimum diff by entry : 184
# max_diff_between_entry_and_expire : 138.74
# exit of each contract : buy_call[0.1], sell_call[0.1], buy_put[4.1], sell_put[0.3]
# pnl : -79.6
# ==================== expire report of 2024-01-29====================
# middle line : 18000
# used strike : {'buy_call': 18100, 'buy_put': 17900, 'sell_call': 18300, 'sell_put': 17700}
# days to expire : 2
# entry of each contract : buy_call[47.0], sell_call[5.4], buy_put[34.0], sell_put[9.4]
# entry cost : -66.2
# minimum diff by entry : 167
# max_diff_between_entry_and_expire : 138.74
# exit of each contract : buy_call[0.1], sell_call[0.1], buy_put[4.1], sell_put[0.3]
# pnl : -62.4
# ==================== expire report of 2024-01-30====================
# middle line : 18100
# used strike : {'buy_call': 18200, 'buy_put': 18000, 'sell_call': 18400, 'sell_put': 17800}
# days to expire : 1
# entry of each contract : buy_call[16.5], sell_call[1.0], buy_put[10.0], sell_put[1.2]
# entry cost : -24.3
# minimum diff by entry : 125
# max_diff_between_entry_and_expire : 38.74
# exit of each contract : buy_call[0.1], sell_call[0.1], buy_put[103.0], sell_put[0.1]
# pnl : 78.6
# ==================== expire report of 2024-01-31====================
# middle line : 18000
# used strike : {'buy_call': 18100, 'buy_put': 17900, 'sell_call': 18300, 'sell_put': 17700}
# days to expire : 0
# entry of each contract : buy_call[0.4], sell_call[0.1], buy_put[12.0], sell_put[0.4]
# entry cost : -11.9
# minimum diff by entry : 112
# max_diff_between_entry_and_expire : 40.42
# exit of each contract : buy_call[0.1], sell_call[0.1], buy_put[4.1], sell_put[0.3]
# pnl : -8.1

# %%
daytrade_cnt = 0
expire_trade_cnt = 0
daytrade_pnl = 0 
expirce_pnl = 0 
for k, v in middles.items():
    if 'daytrade_pnl' in v:
        if v['daytrade_pnl'] is not None:
            daytrade_pnl += v['daytrade_pnl']
            daytrade_cnt += 1
    if 'expire_pnl' in v:
        if v['expire_pnl'] is not None:
            expirce_pnl += v['expire_pnl']
            expire_trade_cnt += 1

# %%
daytrade_cnt, expire_trade_cnt, daytrade_pnl, expirce_pnl, round(daytrade_pnl / daytrade_cnt, 2), round(expirce_pnl / expire_trade_cnt , 2)
# Out:
# (72, 72, -74.29999999999998, 574.9, -1.03, 7.98)

# %%
import warnings
warnings.filterwarnings("ignore")

from datetime import datetime, timedelta
from pandas import DataFrame, concat, date_range, ExcelWriter, to_datetime
import os
from numpy import isnan, inf, mean
import time
import json
from Calculator import Calculator as Calc

from utils import getSchema, changedType

parent = os.path.dirname(os.path.abspath("__file__"))
output_path = os.path.join(parent, "Output", "GoldCross")
if not os.path.isdir(output_path):
    os.makedirs(output_path)
# Out:
# c:\users\kevin\appdata\local\programs\python\python37\lib\site-packages\mpl_finance.py:22: DeprecationWarning:
#
#   =================================================================
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
#   =================================================================
#
#   category=DeprecationWarning)

# %%
def StockInterDay(start_date:[str,datetime]=datetime(2021,4,14), 
                  end_date:[str,datetime]=datetime(2021,4,14),
                  tickers:[str,list]=''):
    if isinstance(start_date, datetime):
        start_date = start_date.strftime("%Y-%m-%d")
    if isinstance(end_date, datetime):
        end_date = end_date.strftime("%Y-%m-%d")
    if isinstance(tickers, str):
        tickers = tickers.split(',')
    schema = getSchema('TWSE')
    table = schema['historicalPrice']
    data = list(table.find({'Date':{'$gte':start_date, '$lte':end_date}, "Ticker" :{"$in":tickers}}))
    return data

def StockList():
    schema = getSchema('TWSE')
    table = schema['StockList']
    last_date = sorted(table.distinct("UpdateDate"))[-1]
    data = list(table.find({"UpdateDate":{"$eq":last_date}, "Industry" :{"$ne":""}}))
    return data

# %%
def get_commission(price:float, multiplier:int=1000, qty=1, long:bool=1, dayTrade:bool=False):
    """
    計算個別部位的單邊交易成本

    Params:
        symbol : 商品代碼
        exchange : 交易所
        cost : 交易價格
        multiplier : 價格還原現金之乘數
            例如:
                股票 : 1張 = 1,000股，10元的股票還原現金價值，即為10 *1,000 = 10,000元
                期貨 : 台指期1點200元，假設現在10,000點，則一口台股的價值為 200 * 10,000 = 2,000,000
        qty : 買賣口數或張數
        Real : 是否為實單, default = False
        direction : 交易方向 進場(買賣)或出場
            P.S. 股票交易的交易稅是出場才計算
    """
    commission = price * (0.1425 / 100) * multiplier * qty
    commission = 20 if commission < 20 else commission
    tax = price * (0.3 / 100) * multiplier * qty
    if dayTrade:
        fee /= 2
#     tradeCost = commission# * 0.6
    if not long:
        return commission, tax
    return commission, 0

# %%
def CreateTradeLog(entry_date, exit_date, entry_price, exit_price, max_price, min_price, pos:int = 1, qty:int = 1, multiplier:int=1000):
    pnl = (exit_price - entry_price) * pos * qty * multiplier
    entry_com, entry_tax = get_commission(entry_price, multiplier, qty, long = pos > 0)
    exit_com, exit_tax = get_commission(exit_price, multiplier, qty, long = not (pos > 0))
#     print(entry_date, exit_date, entry_price, exit_price,entry_com,entry_tax,exit_com,exit_tax)
    return {
        'EntryDate':entry_date,
        'ExitDate':exit_date,
        'EntryPrice':entry_price,
        'ExitPrice':exit_price,
        'EntryCommission':round(entry_com),
        'ExitCommission':round(exit_com),
        'EntryTax':round(entry_tax),
        'ExitTax':round(exit_tax),
        'TotalCost':round(entry_com)+round(exit_com)+round(entry_tax)+round(exit_tax),
        'HoldingPeriod':(exit_date-entry_date).days,
        'Net':round(pnl - (round(entry_com)+round(exit_com)+round(entry_tax)+round(exit_tax))),
        'Ret':round((pnl - (round(entry_com)+round(exit_com)+round(entry_tax)+round(exit_tax))) / (entry_price * 1000),4),
        'MaxPriceBetweeenHolding':max_price,
        'MaxRetBetweeenHolding':round(max_price/entry_price-1,4),
        'MinPriceBetweeenHolding':min_price,
        'MinRetBetweeenHolding':round(min_price/entry_price-1,4)
    }

# %%
def GoldCross(df:DataFrame, **kwargs):
    entry_date = None
    exit_date = None
    entry_price = 0
    exit_price = 0
    max_price = 0
    min_price = inf
    sig = pos = 0
#     num_breakout_day = int(kwargs.get('num_breakout_day', 100))
    take_profit = float(kwargs.get('take_profit', .1))
    stop_loss = float(kwargs.get('stop_loss', .1))
    
    
    df['MA20'] = Calc.MA(df.fillna(method='ffill'), [20]).MA20
    df['EMA12'] = Calc.EMA(df.fillna(method='ffill'), [12]).EMA12
    result = []
    for i, row in enumerate(df.itertuples()):
        if not i: continue
        # Check Signal without pos
        if not sig and not pos:
            if row.EMA12 > row.MA20 and df.EMA12.iloc[i-1] <= df.MA20.iloc[i-1]:
                sig = 1
        # Entry Market
        elif sig and not pos:
#             if row.Ticker == '1538':print(row)
            if not row.Volume or isnan(row.Open): continue
#             print(row)
            pos, sig = sig, 0
            max_price = min_price = entry_price = row.Open
            entry_date = row.Date
            max_price = max(row.High, max_price)
            min_price = min(row.Low, min_price)
        # Check Signal with pos
        elif not sig and pos:
            max_price = max(row.High, entry_price)
            min_price = min(row.Low, entry_price)
            if (row.High / entry_price - 1 >= take_profit):
                sig = -1
#                 exit_price = row.High
            if (row.Low / entry_price - 1 <= -stop_loss):
                sig = -1
#                 exit_price = row.Low
        # Exit Market
        elif sig and pos:
            
            if not row.Volume or isnan(row.Open): continue
#             if row.Ticker == '1538':print(row)
            exit_price = row.Open
            exit_date = row.Date
            res = CreateTradeLog(entry_date, exit_date, entry_price, exit_price, max_price, min_price, pos)
            result.append(res)
            entry_date = None
            exit_date = None
            entry_price = 0
            exit_price = 0
            max_price = 0
            min_price = inf
            sig = pos = 0
        if i == df.shape[0]-1 and pos:
            exit_price = row.Close
            if not row.Volume or isnan(row.Open):
                exit_price = df.fillna(method='ffill').Close.iloc[-1]
            
            exit_date = row.Date
            res = CreateTradeLog(entry_date, exit_date, entry_price, exit_price, max_price, min_price, pos)
            result.append(res)
            entry_date = None
            exit_date = None
            entry_price = 0
            exit_price = 0
            max_price = 0
            min_price = inf
            sig = pos = 0
#     print()
            
    return result

# %%
def Backtest(strategy:callable, ticker:str, dt:datetime=datetime.today(), bt_period = 5, params:dict={}):
    data = StockInterDay(dt+timedelta(-365*bt_period), dt, ticker)
    if not data:return []
    df = DataFrame(data)
    print(f"From {df.Date.iloc[0]} to {df.Date.iloc[-1]}")
#     print(df.iloc[0])
    df.Date = to_datetime(df.Date)
    for col in 'Open,High,Low,Close,Volume'.split(','):
        df[col] = df[col].apply(changedType)
    return strategy(df, **params)

# %%
bt_list = StockList()

# %%
results = {}
for ticker_info in bt_list:
    print(f"============= Backtest {ticker_info['Ticker']}=============")
    results[ticker_info['Ticker']] = Backtest(GoldCross, ticker_info['Ticker'], bt_period = 10)
#     break
# Out:
# ============= Backtest 1101=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1102=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1103=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1104=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1108=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1109=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1110=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1201=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1203=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1210=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1213=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1215=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1216=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1217=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1218=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1219=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1220=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1225=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1227=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1229=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1231=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1232=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1233=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1234=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1235=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1236=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1256=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1301=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1303=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1304=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1305=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1307=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1308=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1309=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1310=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1312=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1313=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1314=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1315=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1316=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1319=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1321=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1323=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1324=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1325=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1326=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1337=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1338=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1339=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1340=============
# From 2014-01-14 to 2023-08-02
# ============= Backtest 1341=============
# From 2018-12-24 to 2023-08-02
# ============= Backtest 1342=============
# From 2020-11-24 to 2023-08-02
# ============= Backtest 1402=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1409=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1410=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1413=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1414=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1416=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1417=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1418=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1419=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1423=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1432=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1434=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1435=============
# From 2013-08-05 to 2023-04-07
# ============= Backtest 1436=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1437=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1438=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1439=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1440=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1441=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1442=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1443=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1444=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1445=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1446=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1447=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1449=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1451=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1452=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1453=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1454=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1455=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1456=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1457=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1459=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1460=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1463=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1464=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1465=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1466=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1467=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1468=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1470=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1471=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1472=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1473=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1474=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1475=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1476=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1477=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1503=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1504=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1506=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1512=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1513=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1514=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1515=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1516=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1517=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1519=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1521=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1522=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1524=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1525=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1526=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1527=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1528=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1529=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1530=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1531=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1532=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1533=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1535=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1536=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1537=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1538=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1539=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1540=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1541=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1558=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1560=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1568=============
# From 2014-05-14 to 2023-08-02
# ============= Backtest 1582=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1583=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1587=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1589=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1590=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1597=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1598=============
# From 2016-09-20 to 2023-08-02
# ============= Backtest 1603=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1604=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1605=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1608=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1609=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1611=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1612=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1614=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1615=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1616=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1617=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1618=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1626=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1701=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1702=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1707=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1708=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1709=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1710=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1711=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1712=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1713=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1714=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1717=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1718=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1720=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1721=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1722=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1723=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1725=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1726=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1727=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1730=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1731=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1732=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1733=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1734=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1735=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1736=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1737=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1760=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1762=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1773=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1776=============
# From 2016-05-09 to 2023-08-02
# ============= Backtest 1783=============
# From 2013-12-20 to 2023-08-02
# ============= Backtest 1786=============
# From 2013-11-12 to 2023-08-02
# ============= Backtest 1789=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1795=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1802=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1805=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1806=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1808=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1809=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1810=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1817=============
# From 2013-10-24 to 2023-08-02
# ============= Backtest 1903=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1904=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1905=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1906=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1907=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 1909=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2002=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2006=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2007=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2008=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2009=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2010=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2012=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2013=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2014=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2015=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2017=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2020=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2022=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2023=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2024=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2025=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2027=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2028=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2029=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2030=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2031=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2032=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2033=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2034=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2038=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2049=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2059=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2062=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2069=============
# From 2016-03-22 to 2023-08-02
# ============= Backtest 2101=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2102=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2103=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2104=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2105=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2106=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2107=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2108=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2109=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2114=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2115=============
# From 2013-12-25 to 2023-08-02
# ============= Backtest 2201=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2204=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2206=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2207=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2208=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2227=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2228=============
# From 2013-11-25 to 2023-08-02
# ============= Backtest 2231=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2233=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2236=============
# From 2015-06-03 to 2023-08-02
# ============= Backtest 2239=============
# From 2016-01-27 to 2023-08-02
# ============= Backtest 2241=============
# From 2016-03-10 to 2023-08-02
# ============= Backtest 2243=============
# From 2017-09-27 to 2023-08-02
# ============= Backtest 2247=============
# From 2020-10-12 to 2023-08-02
# ============= Backtest 2301=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2302=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2303=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2305=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2308=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2312=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2313=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2314=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2316=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2317=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2321=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2323=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2324=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2327=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2328=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2329=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2330=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2331=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2332=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2337=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2338=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2340=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2342=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2344=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2345=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2347=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2348=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2349=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2351=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2352=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2353=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2354=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2355=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2356=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2357=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2358=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2359=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2360=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2362=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2363=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2364=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2365=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2367=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2368=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2369=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2371=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2373=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2374=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2375=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2376=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2377=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2379=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2380=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2382=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2383=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2385=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2387=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2388=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2390=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2392=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2393=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2395=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2397=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2399=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2401=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2402=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2404=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2405=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2406=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2408=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2409=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2412=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2413=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2414=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2415=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2417=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2419=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2420=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2421=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2423=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2424=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2425=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2426=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2427=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2428=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2429=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2430=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2431=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2433=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2434=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2436=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2438=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2439=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2440=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2441=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2442=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2443=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2444=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2449=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2450=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2451=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2453=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2454=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2455=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2457=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2458=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2459=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2460=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2461=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2462=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2464=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2465=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2466=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2467=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2468=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2471=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2472=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2474=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2476=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2477=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2478=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2480=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2481=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2482=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2483=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2484=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2485=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2486=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2488=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2489=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2491=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2492=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2493=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2495=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2496=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2497=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2498=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2501=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2504=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2505=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2506=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2509=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2511=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2514=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2515=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2516=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2520=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2524=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2527=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2528=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2530=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2534=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2535=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2536=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2537=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2538=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2539=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2540=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2542=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2543=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2545=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2546=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2547=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2548=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2597=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2601=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2603=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2605=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2606=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2607=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2608=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2609=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2610=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2611=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2612=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2613=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2614=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2615=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2616=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2617=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2618=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2630=============
# From 2017-02-24 to 2023-08-02
# ============= Backtest 2633=============
# From 2016-10-27 to 2023-08-02
# ============= Backtest 2634=============
# From 2014-08-25 to 2023-08-02
# ============= Backtest 2636=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2637=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2642=============
# From 2013-12-12 to 2023-08-02
# ============= Backtest 2701=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2702=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2704=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2705=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2706=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2707=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2712=============
# From 2013-12-03 to 2023-08-02
# ============= Backtest 2722=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2723=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2727=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2731=============
# From 2013-09-24 to 2023-08-02
# ============= Backtest 2739=============
# From 2016-05-19 to 2023-08-02
# ============= Backtest 2748=============
# From 2016-11-23 to 2023-08-02
# ============= Backtest 2801=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2809=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2812=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2816=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2820=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2832=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2834=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2836=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2838=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2845=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2849=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2850=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2851=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2852=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2855=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2867=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2880=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2881=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2882=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2883=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2884=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2885=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2886=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2887=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2888=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2889=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2890=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2891=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2892=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2897=============
# From 2017-05-05 to 2023-08-02
# ============= Backtest 2901=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2903=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2904=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2905=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2906=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2908=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2910=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2911=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2912=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2913=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2915=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2923=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2929=============
# From 2013-12-30 to 2023-08-02
# ============= Backtest 2939=============
# From 2018-01-11 to 2023-08-02
# ============= Backtest 3002=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3003=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3004=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3005=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3006=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3008=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3010=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3011=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3013=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3014=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3015=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3016=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3017=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3018=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3019=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3021=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3022=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3023=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3024=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3025=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3026=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3027=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3028=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3029=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3030=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3031=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3032=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3033=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3034=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3035=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3036=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3037=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3038=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3040=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3041=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3042=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3043=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3044=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3045=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3046=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3047=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3048=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3049=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3050=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3051=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3052=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3054=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3055=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3056=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3057=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3058=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3059=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3060=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3062=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3090=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3094=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3130=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3138=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3149=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3164=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3167=============
# From 2013-10-21 to 2023-08-02
# ============= Backtest 3189=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3209=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3229=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3231=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3257=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3266=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3296=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3305=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3308=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3311=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3312=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3321=============
# From 2015-12-15 to 2023-08-02
# ============= Backtest 3338=============
# From 2013-12-13 to 2023-08-02
# ============= Backtest 3346=============
# From 2016-12-19 to 2023-08-02
# ============= Backtest 3356=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3376=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3380=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3406=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3413=============
# From 2015-07-28 to 2023-08-02
# ============= Backtest 3416=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3419=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3432=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3437=============
# From 2014-07-09 to 2023-08-02
# ============= Backtest 3443=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3450=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3454=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3481=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3494=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3501=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3504=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3515=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3518=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3528=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3530=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3532=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3533=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3535=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3543=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3545=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3550=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3557=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3563=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3576=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3583=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3588=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3591=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3593=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3596=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3605=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3607=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3617=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3622=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3645=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3653=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3661=============
# From 2014-10-28 to 2023-08-02
# ============= Backtest 3665=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3669=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3673=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3679=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3682=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3686=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3694=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3701=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3702=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3703=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3704=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3705=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 3706=============
# From 2013-09-12 to 2023-08-02
# ============= Backtest 3708=============
# From 2016-08-31 to 2023-08-02
# ============= Backtest 3711=============
# From 2018-04-30 to 2023-08-02
# ============= Backtest 3712=============
# From 2018-10-01 to 2023-08-02
# ============= Backtest 3714=============
# From 2021-01-06 to 2023-08-02
# ============= Backtest 4104=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 4106=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 4108=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 4119=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 4133=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 4137=============
# From 2013-11-27 to 2023-08-02
# ============= Backtest 4142=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 4155=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 4164=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 4190=============
# From 2015-10-21 to 2023-08-02
# ============= Backtest 4306=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 4414=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 4426=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 4438=============
# From 2016-10-18 to 2023-08-02
# ============= Backtest 4439=============
# From 2019-12-05 to 2023-08-02
# ============= Backtest 4526=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 4532=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 4536=============
# From 2013-10-09 to 2023-08-02
# ============= Backtest 4540=============
# From 2014-11-19 to 2023-08-02
# ============= Backtest 4545=============
# From 2016-01-06 to 2023-08-02
# ============= Backtest 4551=============
# From 2015-08-10 to 2023-08-02
# ============= Backtest 4552=============
# From 2016-07-20 to 2023-08-02
# ============= Backtest 4555=============
# From 2015-10-27 to 2023-08-02
# ============= Backtest 4557=============
# From 2015-10-12 to 2023-08-02
# ============= Backtest 4560=============
# From 2016-12-09 to 2023-08-02
# ============= Backtest 4562=============
# From 2015-11-20 to 2023-08-02
# ============= Backtest 4564=============
# From 2017-01-20 to 2023-08-02
# ============= Backtest 4566=============
# From 2017-02-24 to 2023-08-02
# ============= Backtest 4571=============
# From 2019-09-17 to 2023-08-02
# ============= Backtest 4572=============
# From 2019-09-10 to 2023-08-02
# ============= Backtest 4576=============
# From 2019-09-04 to 2023-08-02
# ============= Backtest 4581=============
# From 2020-03-09 to 2023-08-02
# ============= Backtest 4720=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 4722=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 4737=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 4739=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 4746=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 4755=============
# From 2013-11-27 to 2023-08-02
# ============= Backtest 4763=============
# From 2015-11-09 to 2023-08-02
# ============= Backtest 4764=============
# From 2016-10-14 to 2023-08-02
# ============= Backtest 4766=============
# From 2018-11-28 to 2023-08-02
# ============= Backtest 4807=============
# From 2016-11-28 to 2023-08-02
# ============= Backtest 4904=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 4906=============
# From 2013-08-05 to 2023-08-02
# ...
# ============= Backtest 6716=============
# From 2020-03-27 to 2023-08-01
# ============= Backtest 6727=============
# From 2020-12-01 to 2023-08-01
# ============= Backtest 6728=============
# From 2020-12-25 to 2023-08-01
# ============= Backtest 6732=============
# From 2020-06-08 to 2023-08-01
# ============= Backtest 6733=============
# From 2021-01-28 to 2023-08-01
# ============= Backtest 6747=============
# From 2021-01-19 to 2023-08-01
# ============= Backtest 6751=============
# From 2020-12-25 to 2023-08-01
# ============= Backtest 6752=============
# From 2020-12-10 to 2023-08-01
# ============= Backtest 6762=============
# From 2020-12-18 to 2023-08-01
# ============= Backtest 6767=============
# From 2021-01-25 to 2023-08-01
# ============= Backtest 6803=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 7402=============
# From 2014-12-26 to 2023-08-01
# ============= Backtest 7556=============
# From 2020-10-30 to 2023-08-01
# ============= Backtest 8024=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8027=============
# From 2015-06-09 to 2023-08-01
# ============= Backtest 8032=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8034=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8038=============
# From 2013-11-21 to 2023-08-01
# ============= Backtest 8040=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8042=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8043=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8044=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8047=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8048=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8049=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8050=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8054=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8059=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8064=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8066=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8067=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8068=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8069=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8071=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8074=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8076=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8077=============
# From 2013-11-22 to 2023-08-01
# ============= Backtest 8080=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8083=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8084=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8085=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8086=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8087=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8088=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8089=============
# From 2020-09-23 to 2023-08-01
# ============= Backtest 8091=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8092=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8093=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8096=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8097=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8099=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8107=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8109=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8111=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8121=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8147=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8155=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8171=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8176=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8182=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8183=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8234=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8240=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8255=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8277=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8279=============
# From 2016-09-26 to 2023-08-01
# ============= Backtest 8284=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8289=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8291=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8299=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8342=============
# From 2016-06-03 to 2023-08-01
# ============= Backtest 8349=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8354=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8358=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8383=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8390=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8401=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8403=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8409=============
# From 2013-11-25 to 2023-08-01
# ============= Backtest 8410=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8415=============
# From 2016-09-07 to 2023-08-01
# ============= Backtest 8416=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8418=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8420=============
# From 2014-11-10 to 2023-08-01
# ============= Backtest 8421=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8423=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8424=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8426=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8431=============
# From 2015-03-30 to 2023-08-01
# ============= Backtest 8432=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8433=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8435=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8436=============
# From 2013-09-12 to 2023-08-01
# ============= Backtest 8437=============
# From 2015-05-06 to 2023-08-01
# ============= Backtest 8440=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8444=============
# From 2015-10-27 to 2023-08-01
# ============= Backtest 8446=============
# From 2013-12-19 to 2023-08-01
# ============= Backtest 8450=============
# From 2014-10-07 to 2023-08-01
# ============= Backtest 8455=============
# From 2016-01-08 to 2023-08-01
# ============= Backtest 8472=============
# From 2016-01-11 to 2023-08-01
# ============= Backtest 8476=============
# From 2017-03-28 to 2023-08-01
# ============= Backtest 8477=============
# From 2016-10-31 to 2023-08-01
# ============= Backtest 8489=============
# From 2016-01-12 to 2023-08-01
# ============= Backtest 8905=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8906=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8908=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8916=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8917=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8921=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8923=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8924=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8927=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8928=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8929=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8930=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8931=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8932=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8933=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8935=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8936=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8937=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8938=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8941=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 8942=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 9949=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 9950=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 9951=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 9960=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 9962=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 4148=============
# From 2017-06-08 to 2023-08-02
# ============= Backtest 6781=============
# From 2021-03-22 to 2023-08-02
# ============= Backtest 6776=============
# From 2021-03-31 to 2023-08-02
# ============= Backtest 2211=============
# From 2021-04-12 to 2023-08-02
# ============= Backtest 6768=============
# From 2021-04-22 to 2023-08-02
# ============= Backtest 3357=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 6741=============
# From 2021-05-25 to 2023-08-01
# ============= Backtest 2250=============
# From 2021-05-31 to 2023-08-02
# ============= Backtest 5236=============
# From 2021-07-29 to 2023-08-01
# ============= Backtest 1522A=============
# From 2021-08-10 to 2023-08-02
# ============= Backtest 6684=============
# From 2021-08-11 to 2023-08-01
# ============= Backtest 2753=============
# From 2021-09-09 to 2023-08-02
# ============= Backtest 2348A=============
# From 2021-09-27 to 2023-08-02
# ============= Backtest 6790=============
# From 2021-09-29 to 2023-08-02
# ============= Backtest 6788=============
# From 2021-09-29 to 2023-08-01
# ============= Backtest 2947=============
# From 2021-10-06 to 2023-08-01
# ============= Backtest 4440=============
# From 2021-10-25 to 2023-08-02
# ============= Backtest 5222=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 2881C=============
# From 2021-10-29 to 2023-08-02
# ============= Backtest 6761=============
# From 2021-11-08 to 2023-08-01
# ============= Backtest 6806=============
# From 2021-11-15 to 2023-08-02
# ============= Backtest 2945=============
# From 2021-11-30 to 2023-08-02
# ============= Backtest 6770=============
# From 2021-12-06 to 2023-08-02
# ============= Backtest 6792=============
# From 2021-12-08 to 2023-08-02
# ============= Backtest 4770=============
# From 2021-12-22 to 2023-08-02
# ============= Backtest 2883B=============
# From 2021-12-30 to 2023-08-02
# ============= Backtest 6691=============
# From 2022-01-03 to 2023-08-02
# ============= Backtest 3592=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 6719=============
# From 2022-01-13 to 2023-08-02
# ============= Backtest 2756=============
# From 2022-01-14 to 2023-08-01
# ============= Backtest 5244=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 6693=============
# From 2022-03-01 to 2023-08-01
# ============= Backtest 8112A=============
# From 2022-03-07 to 2023-08-02
# ============= Backtest 8438=============
# From 2013-08-05 to 2023-08-02
# ============= Backtest 6829=============
# From 2022-03-11 to 2023-08-01
# ============= Backtest 4923=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 6763=============
# From 2022-03-15 to 2023-08-01
# ============= Backtest 4558=============
# From 2014-11-14 to 2023-08-01
# ============= Backtest 3349=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 6804=============
# From 2022-03-31 to 2023-08-01
# ============= Backtest 4768=============
# From 2022-04-13 to 2023-08-01
# ============= Backtest 6807=============
# From 2022-04-25 to 2023-08-02
# ============= Backtest 6721=============
# From 2022-04-29 to 2023-08-01
# ============= Backtest 6735=============
# From 2022-04-29 to 2023-08-01
# ============= Backtest 4583=============
# From 2022-05-09 to 2023-08-02
# ============= Backtest 6799=============
# From 2022-05-12 to 2023-08-02
# ============= Backtest 6585=============
# From 2016-09-08 to 2023-08-02
# ============= Backtest 5228=============
# From 2015-03-26 to 2023-08-01
# ============= Backtest 6546=============
# From 2015-07-28 to 2023-08-01
# ============= Backtest 6796=============
# From 2022-06-01 to 2023-08-02
# ============= Backtest 6550=============
# From 2016-02-15 to 2023-08-02
# ============= Backtest 4577=============
# From 2022-06-14 to 2023-08-01
# ============= Backtest 6789=============
# From 2022-06-30 to 2023-08-02
# ============= Backtest 6823=============
# From 2022-06-30 to 2023-08-01
# ============= Backtest 2887Z1=============
# From 2022-07-26 to 2023-08-02
# ============= Backtest 6811=============
# From 2022-08-09 to 2023-08-01
# ============= Backtest 6854=============
# From 2022-08-18 to 2023-08-02
# ============= Backtest 3715=============
# From 2022-08-25 to 2023-08-02
# ============= Backtest 6830=============
# From 2022-08-31 to 2023-08-02
# ============= Backtest 6834=============
# From 2022-09-01 to 2023-08-02
# ============= Backtest 3430=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 6689=============
# From 2022-09-13 to 2023-08-02
# ============= Backtest 6592A=============
# From 2022-09-26 to 2023-08-02
# ============= Backtest 4584=============
# From 2022-10-05 to 2023-08-01
# ============= Backtest 6855=============
# From 2022-10-07 to 2023-08-01
# ============= Backtest 4951=============
# From 2013-08-05 to 2023-08-01
# ============= Backtest 6695=============
# From 2022-11-04 to 2023-08-02
# ============= Backtest 6835=============
# From 2022-11-10 to 2023-08-02
# ============= Backtest 6791=============
# From 2022-11-14 to 2023-08-01
# ============= Backtest 6843=============
# From 2022-11-21 to 2023-08-01
# ============= Backtest 6782=============
# From 2022-11-28 to 2023-08-02
# ============= Backtest 6859=============
# From 2022-11-28 to 2023-08-01
# ============= Backtest 6874=============
# From 2022-12-14 to 2023-08-01
# ============= Backtest 3447=============
# From 2022-12-15 to 2023-08-02
# ============= Backtest 6517=============
# From 2015-02-11 to 2023-08-01
# ============= Backtest 8227=============
# From 2022-12-20 to 2023-08-01
# ============= Backtest 6708=============
# From 2022-12-29 to 2023-08-01
# ============= Backtest 6865=============
# From 2023-01-11 to 2023-08-01
# ============= Backtest 6841=============
# From 2023-03-01 to 2023-08-01
# ============= Backtest 6873=============
# From 2023-03-06 to 2023-08-02
# ============= Backtest 6753=============
# From 2023-03-10 to 2023-08-02
# ============= Backtest 2645=============
# From 2023-03-14 to 2023-08-02
# ============= Backtest 6869=============
# From 2023-03-14 to 2023-08-02
# ============= Backtest 6863=============
# From 2023-03-21 to 2023-08-02
# ============= Backtest 6606=============
# From 2023-03-24 to 2023-08-02
# ============= Backtest 6840=============
# From 2023-03-24 to 2023-08-01
# ============= Backtest 6861=============
# From 2023-03-27 to 2023-08-02
# ============= Backtest 2432=============
# From 2023-05-31 to 2023-08-02
# ============= Backtest 6584=============
# From 2016-08-01 to 2023-08-01
# ============= Backtest 6821=============
# From 2023-05-22 to 2023-08-01
# ============= Backtest 6846=============
# From 2023-05-15 to 2023-08-01
# ============= Backtest 6657=============
# From 2023-06-12 to 2023-08-02
# ============= Backtest 6877=============
# From 2023-06-16 to 2023-08-01
# ============= Backtest 2073=============
# From 2023-06-21 to 2023-08-01
# ============= Backtest 6902=============
# From 2023-07-13 to 2023-08-02
# ============= Backtest 4569=============
# From 2023-07-31 to 2023-08-02

# %% [markdown]
# # Summary

# %%
results['1101']
# Out:
# [{'EntryDate': Timestamp('2013-11-20 00:00:00'),
#   'ExitDate': Timestamp('2014-02-26 00:00:00'),
#   'EntryPrice': 43.2,
#   'ExitPrice': 47.15,
#   'EntryCommission': 62,
#   'ExitCommission': 67,
#   'EntryTax': 0,
#   'ExitTax': 141,
#   'TotalCost': 270,
#   'HoldingPeriod': 98,
#   'Net': 3680,
#   'Ret': 0.0852,
#   'MaxPriceBetweeenHolding': 48.45,
#   'MaxRetBetweeenHolding': 0.1215,
#   'MinPriceBetweeenHolding': 43.2,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2014-04-02 00:00:00'),
#   'ExitDate': Timestamp('2014-12-18 00:00:00'),
#   'EntryPrice': 47.75,
#   'ExitPrice': 41.85,
#   'EntryCommission': 68,
#   'ExitCommission': 60,
#   'EntryTax': 0,
#   'ExitTax': 126,
#   'TotalCost': 254,
#   'HoldingPeriod': 260,
#   'Net': -6154,
#   'Ret': -0.1289,
#   'MaxPriceBetweeenHolding': 47.75,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 41.55,
#   'MinRetBetweeenHolding': -0.1298},
#  {'EntryDate': Timestamp('2015-01-29 00:00:00'),
#   'ExitDate': Timestamp('2015-06-05 00:00:00'),
#   'EntryPrice': 42.7,
#   'ExitPrice': 38.75,
#   'EntryCommission': 61,
#   'ExitCommission': 55,
#   'EntryTax': 0,
#   'ExitTax': 116,
#   'TotalCost': 232,
#   'HoldingPeriod': 127,
#   'Net': -4182,
#   'Ret': -0.0979,
#   'MaxPriceBetweeenHolding': 42.7,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 37.65,
#   'MinRetBetweeenHolding': -0.1183},
#  {'EntryDate': Timestamp('2015-07-01 00:00:00'),
#   'ExitDate': Timestamp('2015-07-29 00:00:00'),
#   'EntryPrice': 38.8,
#   'ExitPrice': 35.1,
#   'EntryCommission': 55,
#   'ExitCommission': 50,
#   'EntryTax': 0,
#   'ExitTax': 105,
#   'TotalCost': 210,
#   'HoldingPeriod': 28,
#   'Net': -3910,
#   'Ret': -0.1008,
#   'MaxPriceBetweeenHolding': 38.8,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 34.8,
#   'MinRetBetweeenHolding': -0.1031},
#  {'EntryDate': Timestamp('2015-09-02 00:00:00'),
#   'ExitDate': Timestamp('2015-10-13 00:00:00'),
#   'EntryPrice': 34.0,
#   'ExitPrice': 37.35,
#   'EntryCommission': 48,
#   'ExitCommission': 53,
#   'EntryTax': 0,
#   'ExitTax': 112,
#   'TotalCost': 213,
#   'HoldingPeriod': 41,
#   'Net': 3137,
#   'Ret': 0.0923,
#   'MaxPriceBetweeenHolding': 37.5,
#   'MaxRetBetweeenHolding': 0.1029,
#   'MinPriceBetweeenHolding': 34.0,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2016-02-02 00:00:00'),
#   'ExitDate': Timestamp('2016-03-01 00:00:00'),
#   'EntryPrice': 27.1,
#   'ExitPrice': 29.9,
#   'EntryCommission': 39,
#   'ExitCommission': 43,
#   'EntryTax': 0,
#   'ExitTax': 90,
#   'TotalCost': 172,
#   'HoldingPeriod': 28,
#   'Net': 2628,
#   'Ret': 0.097,
#   'MaxPriceBetweeenHolding': 30.3,
#   'MaxRetBetweeenHolding': 0.1181,
#   'MinPriceBetweeenHolding': 27.1,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2016-04-15 00:00:00'),
#   'ExitDate': Timestamp('2016-05-11 00:00:00'),
#   'EntryPrice': 33.1,
#   'ExitPrice': 30.4,
#   'EntryCommission': 47,
#   'ExitCommission': 43,
#   'EntryTax': 0,
#   'ExitTax': 91,
#   'TotalCost': 181,
#   'HoldingPeriod': 26,
#   'Net': -2881,
#   'Ret': -0.087,
#   'MaxPriceBetweeenHolding': 33.1,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 29.7,
#   'MinRetBetweeenHolding': -0.1027},
#  {'EntryDate': Timestamp('2016-06-01 00:00:00'),
#   'ExitDate': Timestamp('2016-07-05 00:00:00'),
#   'EntryPrice': 30.0,
#   'ExitPrice': 33.7,
#   'EntryCommission': 43,
#   'ExitCommission': 48,
#   'EntryTax': 0,
#   'ExitTax': 101,
#   'TotalCost': 192,
#   'HoldingPeriod': 34,
#   'Net': 3508,
#   'Ret': 0.1169,
#   'MaxPriceBetweeenHolding': 33.65,
#   'MaxRetBetweeenHolding': 0.1217,
#   'MinPriceBetweeenHolding': 30.0,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2016-08-12 00:00:00'),
#   'ExitDate': Timestamp('2017-02-13 00:00:00'),
#   'EntryPrice': 35.0,
#   'ExitPrice': 38.2,
#   'EntryCommission': 50,
#   'ExitCommission': 54,
#   'EntryTax': 0,
#   'ExitTax': 115,
#   'TotalCost': 219,
#   'HoldingPeriod': 185,
#   'Net': 2981,
#   'Ret': 0.0852,
#   'MaxPriceBetweeenHolding': 38.8,
#   'MaxRetBetweeenHolding': 0.1086,
#   'MinPriceBetweeenHolding': 35.0,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2017-03-16 00:00:00'),
#   'ExitDate': Timestamp('2017-05-12 00:00:00'),
#   'EntryPrice': 38.2,
#   'ExitPrice': 34.6,
#   'EntryCommission': 54,
#   'ExitCommission': 49,
#   'EntryTax': 0,
#   'ExitTax': 104,
#   'TotalCost': 207,
#   'HoldingPeriod': 57,
#   'Net': -3807,
#   'Ret': -0.0997,
#   'MaxPriceBetweeenHolding': 38.2,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 34.15,
#   'MinRetBetweeenHolding': -0.106},
#  {'EntryDate': Timestamp('2017-06-05 00:00:00'),
#   'ExitDate': Timestamp('2018-01-09 00:00:00'),
#   'EntryPrice': 34.8,
#   'ExitPrice': 38.1,
#   'EntryCommission': 50,
#   'ExitCommission': 54,
#   'EntryTax': 0,
#   'ExitTax': 114,
#   'TotalCost': 218,
#   'HoldingPeriod': 218,
#   'Net': 3082,
#   'Ret': 0.0886,
#   'MaxPriceBetweeenHolding': 38.3,
#   'MaxRetBetweeenHolding': 0.1006,
#   'MinPriceBetweeenHolding': 34.8,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2018-03-13 00:00:00'),
#   'ExitDate': Timestamp('2018-04-25 00:00:00'),
#   'EntryPrice': 37.0,
#   'ExitPrice': 40.65,
#   'EntryCommission': 53,
#   'ExitCommission': 58,
#   'EntryTax': 0,
#   'ExitTax': 122,
#   'TotalCost': 233,
#   'HoldingPeriod': 43,
#   'Net': 3417,
#   'Ret': 0.0924,
#   'MaxPriceBetweeenHolding': 41.0,
#   'MaxRetBetweeenHolding': 0.1081,
#   'MinPriceBetweeenHolding': 37.0,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2018-06-15 00:00:00'),
#   'ExitDate': Timestamp('2018-07-27 00:00:00'),
#   'EntryPrice': 45.1,
#   'ExitPrice': 40.8,
#   'EntryCommission': 64,
#   'ExitCommission': 58,
#   'EntryTax': 0,
#   'ExitTax': 122,
#   'TotalCost': 244,
#   'HoldingPeriod': 42,
#   'Net': -4544,
#   'Ret': -0.1008,
#   'MaxPriceBetweeenHolding': 45.1,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 40.1,
#   'MinRetBetweeenHolding': -0.1109},
#  {'EntryDate': Timestamp('2018-08-16 00:00:00'),
#   'ExitDate': Timestamp('2018-09-11 00:00:00'),
#   'EntryPrice': 41.85,
#   'ExitPrice': 38.3,
#   'EntryCommission': 60,
#   'ExitCommission': 55,
#   'EntryTax': 0,
#   'ExitTax': 115,
#   'TotalCost': 230,
#   'HoldingPeriod': 26,
#   'Net': -3780,
#   'Ret': -0.0903,
#   'MaxPriceBetweeenHolding': 41.85,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 37.4,
#   'MinRetBetweeenHolding': -0.1063},
#  {'EntryDate': Timestamp('2018-10-01 00:00:00'),
#   'ExitDate': Timestamp('2018-10-12 00:00:00'),
#   'EntryPrice': 41.5,
#   'ExitPrice': 37.25,
#   'EntryCommission': 59,
#   'ExitCommission': 53,
#   'EntryTax': 0,
#   'ExitTax': 112,
#   'TotalCost': 224,
#   'HoldingPeriod': 11,
#   'Net': -4474,
#   'Ret': -0.1078,
#   'MaxPriceBetweeenHolding': 41.5,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 37.0,
#   'MinRetBetweeenHolding': -0.1084},
#  {'EntryDate': Timestamp('2018-11-14 00:00:00'),
#   'ExitDate': Timestamp('2018-11-28 00:00:00'),
#   'EntryPrice': 37.05,
#   'ExitPrice': 33.65,
#   'EntryCommission': 53,
#   'ExitCommission': 48,
#   'EntryTax': 0,
#   'ExitTax': 101,
#   'TotalCost': 202,
#   'HoldingPeriod': 14,
#   'Net': -3602,
#   'Ret': -0.0972,
#   'MaxPriceBetweeenHolding': 37.05,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 32.7,
#   'MinRetBetweeenHolding': -0.1174},
#  {'EntryDate': Timestamp('2018-12-17 00:00:00'),
#   'ExitDate': Timestamp('2019-02-22 00:00:00'),
#   'EntryPrice': 35.6,
#   'ExitPrice': 39.15,
#   'EntryCommission': 51,
#   'ExitCommission': 56,
#   'EntryTax': 0,
#   'ExitTax': 117,
#   'TotalCost': 224,
#   'HoldingPeriod': 67,
#   'Net': 3326,
#   'Ret': 0.0934,
#   'MaxPriceBetweeenHolding': 39.45,
#   'MaxRetBetweeenHolding': 0.1081,
#   'MinPriceBetweeenHolding': 35.6,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2019-03-26 00:00:00'),
#   'ExitDate': Timestamp('2019-06-18 00:00:00'),
#   'EntryPrice': 40.55,
#   'ExitPrice': 45.0,
#   'EntryCommission': 58,
#   'ExitCommission': 64,
#   'EntryTax': 0,
#   'ExitTax': 135,
#   'TotalCost': 257,
#   'HoldingPeriod': 84,
#   'Net': 4193,
#   'Ret': 0.1034,
#   'MaxPriceBetweeenHolding': 44.95,
#   'MaxRetBetweeenHolding': 0.1085,
#   'MinPriceBetweeenHolding': 40.55,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2019-09-09 00:00:00'),
#   'ExitDate': Timestamp('2020-01-03 00:00:00'),
#   'EntryPrice': 40.0,
#   'ExitPrice': 44.15,
#   'EntryCommission': 57,
#   'ExitCommission': 63,
#   'EntryTax': 0,
#   'ExitTax': 132,
#   'TotalCost': 252,
#   'HoldingPeriod': 116,
#   'Net': 3898,
#   'Ret': 0.0974,
#   'MaxPriceBetweeenHolding': 44.15,
#   'MaxRetBetweeenHolding': 0.1038,
#   'MinPriceBetweeenHolding': 40.0,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2020-02-24 00:00:00'),
#   'ExitDate': Timestamp('2020-03-16 00:00:00'),
#   'EntryPrice': 43.0,
#   'ExitPrice': 40.25,
#   'EntryCommission': 61,
#   'ExitCommission': 57,
#   'EntryTax': 0,
#   'ExitTax': 121,
#   'TotalCost': 239,
#   'HoldingPeriod': 21,
#   'Net': -2989,
#   'Ret': -0.0695,
#   'MaxPriceBetweeenHolding': 43.0,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 38.3,
#   'MinRetBetweeenHolding': -0.1093},
#  {'EntryDate': Timestamp('2020-04-08 00:00:00'),
#   'ExitDate': Timestamp('2020-06-05 00:00:00'),
#   'EntryPrice': 40.0,
#   'ExitPrice': 43.5,
#   'EntryCommission': 57,
#   'ExitCommission': 62,
#   'EntryTax': 0,
#   'ExitTax': 130,
#   'TotalCost': 249,
#   'HoldingPeriod': 58,
#   'Net': 3251,
#   'Ret': 0.0813,
#   'MaxPriceBetweeenHolding': 44.0,
#   'MaxRetBetweeenHolding': 0.1,
#   'MinPriceBetweeenHolding': 40.0,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2020-07-07 00:00:00'),
#   'ExitDate': Timestamp('2021-04-19 00:00:00'),
#   'EntryPrice': 44.4,
#   'ExitPrice': 49.9,
#   'EntryCommission': 63,
#   'ExitCommission': 71,
#   'EntryTax': 0,
#   'ExitTax': 150,
#   'TotalCost': 284,
#   'HoldingPeriod': 286,
#   'Net': 5216,
#   'Ret': 0.1175,
#   'MaxPriceBetweeenHolding': 49.0,
#   'MaxRetBetweeenHolding': 0.1036,
#   'MinPriceBetweeenHolding': 44.4,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2021-06-01 00:00:00'),
#   'ExitDate': Timestamp('2021-08-13 00:00:00'),
#   'EntryPrice': 51.6,
#   'ExitPrice': 48.05,
#   'EntryCommission': 74,
#   'ExitCommission': 68,
#   'EntryTax': 0,
#   'ExitTax': 144,
#   'TotalCost': 286,
#   'HoldingPeriod': 73,
#   'Net': -3836,
#   'Ret': -0.0743,
#   'MaxPriceBetweeenHolding': 51.6,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 45.65,
#   'MinRetBetweeenHolding': -0.1153},
#  {'EntryDate': Timestamp('2021-09-07 00:00:00'),
#   'ExitDate': Timestamp('2022-05-11 00:00:00'),
#   'EntryPrice': 48.8,
#   'ExitPrice': 42.5,
#   'EntryCommission': 70,
#   'ExitCommission': 61,
#   'EntryTax': 0,
#   'ExitTax': 128,
#   'TotalCost': 259,
#   'HoldingPeriod': 246,
#   'Net': -6559,
#   'Ret': -0.1344,
#   'MaxPriceBetweeenHolding': 48.8,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 43.65,
#   'MinRetBetweeenHolding': -0.1055},
#  {'EntryDate': Timestamp('2022-06-06 00:00:00'),
#   'ExitDate': Timestamp('2022-07-26 00:00:00'),
#   'EntryPrice': 41.75,
#   'ExitPrice': 37.85,
#   'EntryCommission': 59,
#   'ExitCommission': 54,
#   'EntryTax': 0,
#   'ExitTax': 114,
#   'TotalCost': 227,
#   'HoldingPeriod': 50,
#   'Net': -4127,
#   'Ret': -0.0989,
#   'MaxPriceBetweeenHolding': 41.75,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 37.5,
#   'MinRetBetweeenHolding': -0.1018},
#  {'EntryDate': Timestamp('2022-08-15 00:00:00'),
#   'ExitDate': Timestamp('2022-09-29 00:00:00'),
#   'EntryPrice': 39.3,
#   'ExitPrice': 34.5,
#   'EntryCommission': 56,
#   'ExitCommission': 49,
#   'EntryTax': 0,
#   'ExitTax': 104,
#   'TotalCost': 209,
#   'HoldingPeriod': 45,
#   'Net': -5009,
#   'Ret': -0.1275,
#   'MaxPriceBetweeenHolding': 39.3,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 34.9,
#   'MinRetBetweeenHolding': -0.112},
#  {'EntryDate': Timestamp('2022-11-10 00:00:00'),
#   'ExitDate': Timestamp('2023-01-13 00:00:00'),
#   'EntryPrice': 31.7,
#   'ExitPrice': 35.55,
#   'EntryCommission': 45,
#   'ExitCommission': 51,
#   'EntryTax': 0,
#   'ExitTax': 107,
#   'TotalCost': 203,
#   'HoldingPeriod': 64,
#   'Net': 3647,
#   'Ret': 0.115,
#   'MaxPriceBetweeenHolding': 35.5,
#   'MaxRetBetweeenHolding': 0.1199,
#   'MinPriceBetweeenHolding': 31.7,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2023-04-12 00:00:00'),
#   'ExitDate': Timestamp('2023-08-02 00:00:00'),
#   'EntryPrice': 37.6,
#   'ExitPrice': 37.2,
#   'EntryCommission': 54,
#   'ExitCommission': 53,
#   'EntryTax': 0,
#   'ExitTax': 112,
#   'TotalCost': 219,
#   'HoldingPeriod': 112,
#   'Net': -619,
#   'Ret': -0.0165,
#   'MaxPriceBetweeenHolding': 37.8,
#   'MaxRetBetweeenHolding': 0.0053,
#   'MinPriceBetweeenHolding': 37.15,
#   'MinRetBetweeenHolding': -0.012}]

# %%
summary_ = []
bt_day = datetime.today()
bt_day_str = bt_day.strftime("%Y%m%d")
for ticker, result in results.items():
    total_cost = 0
#     total_pnl = 0
    total_net = 0
    trade_num = len(result)
    win_num = 0
    loss_num = 0
    hold_period = []
    rets = []
    for res in result:
        total_net += res['Net']
        total_cost += res['TotalCost']
        win_num += int(res['Net'] > 0)
        loss_num += int(res['Net'] < 0)
        hold_period.append(res['HoldingPeriod'])
        rets.append(res['Ret'])
    summary_.append({
        '代號':ticker,
        '總成本':total_cost,
        '總損益(淨)':total_net,
        '獲利次數':win_num,
        '損失次數':loss_num,
        '總交易次數':trade_num,
        '勝率%':round(win_num / trade_num*100,2) if trade_num else 0,
        '平均報酬':mean(rets),
        '平均持倉時間(日)':mean(hold_period)
    })
    if result:
        DataFrame(result).to_csv(os.path.join(output_path, f'{ticker}_{bt_day_str}.csv'), index=False)

# %%
sum_df = DataFrame(summary_)#.sort_values(['勝率%','總交易次數'], ascending=False)

# %%
sum_df['總損益(淨)'].sum()
# Out:
# 4338267

# %%
sum_df
# Out:
#         代號   總成本  總損益(淨)  獲利次數  損失次數  總交易次數    勝率%      平均報酬   平均持倉時間(日)
# 0     1101  6409  -14509    13    15     28  46.43 -0.005925   87.857143
# 1     1102  5005     295    13    10     23  56.52  0.007665  107.000000
# 2     1103  2866    9214    19    11     30  63.33  0.024170   71.833333
# 3     1104  2760    3290    11     9     20  55.00  0.014050  130.650000
# 4     1108  1599    4751    14     8     22  63.64  0.022645  116.727273
# ...    ...   ...     ...   ...   ...    ...    ...       ...         ...
# 1813  6657     0       0     0     0      0   0.00       NaN         NaN
# 1814  6877   265   -6415     0     1      1   0.00 -0.128300    4.000000
# 1815  2073     0       0     0     0      0   0.00       NaN         NaN
# 1816  6902     0       0     0     0      0   0.00       NaN         NaN
# 1817  4569     0       0     0     0      0   0.00       NaN         NaN
#
# [1818 rows x 9 columns]

# %%
sum_df.to_csv(os.path.join(output_path, 'Summary.csv'),index=False, encoding='utf-8-sig')

# %%
sum_df_prob_sorted = sum_df[sum_df['勝率%'] > 65]
sum_df_trade_num_sorted = sum_df[sum_df.總交易次數 >= 20]
sum_df_holding_period_sorted = sum_df[sum_df['平均持倉時間(日)'] <= 40]

# %%
# top_num = 100
prob_Ticker = sum_df_prob_sorted.代號 # .iloc[:top_num]
trade_num_Ticker = sum_df_trade_num_sorted.代號 # .iloc[:top_num]
holding_period_Ticker = sum_df_holding_period_sorted.代號
suitable_Ticker = list(set(prob_Ticker).intersection(trade_num_Ticker).intersection(holding_period_Ticker))

# %%
print(sum_df[sum_df.代號.isin(suitable_Ticker)].shape)
sum_df[sum_df.代號.isin(suitable_Ticker)].sort_values("勝率%", ascending=False).head(50)
# Out:
# (53, 9)
#         代號     總成本   總損益(淨)  獲利次數  損失次數  總交易次數    勝率%      平均報酬  平均持倉時間(日)
# 306   2379   55510   418190    32     9     41  78.05  0.054239  36.048780
# 814   6558    5400    26990    19     7     26  73.08  0.043773  23.884615
# 1552  6548   26078   216972    21     8     29  72.41  0.044497  35.793103
# 1140  3581    4271    22629    26    10     36  72.22  0.037753  32.750000
# 1532  6488  102323   485977    30    12     42  71.43  0.041269  23.452381
# 581   3432    4311    22479    33    14     47  70.21  0.039643  29.425532
# 869   8374    5479    35741    28    12     40  70.00  0.037707  38.900000
# 1518  6432    6594    42156    25    11     36  69.44  0.043081  34.388889
# 779   6243    5925    68005    34    15     49  69.39  0.074214  21.489796
# 762   6196   17970    86230    31    14     45  68.89  0.039427  33.466667
# 127   1539    5886    38414    28    13     41  68.29  0.041690  32.658537
# 1438  6148    3194    20116    28    13     41  68.29  0.037990  31.829268
# 333   2421    9583    58417    28    13     41  68.29  0.039100  35.682927
# 1588  6683   36350   148150    17     8     25  68.00  0.033180  12.840000
# 1418  6111   25294   168746    34    16     50  68.00  0.042688  24.520000
# 706   5269  199963  1452037    36    17     53  67.92  0.033155  14.735849
# 1092  3379    3596    16764    27    13     40  67.50  0.039012  36.725000
# 918   9938   19687    91613    31    15     46  67.39  0.030657  32.695652
# 283   2351   23739    94961    35    17     52  67.31  0.027758  25.423077
# 1432  6138   23751    19449    35    17     52  67.31  0.037179  24.692308
# 1447  6167    2759     8471    30    15     45  66.67  0.024540  28.555556
# 1475  6220    8251    35449    32    16     48  66.67  0.026204  29.229167
# 1658  8279   23037   106663    20    10     30  66.67  0.031443  32.766667
# 1306  5202    4712    16978    30    15     45  66.67  0.030098  26.333333
# 1278  4908    7360    10840    30    15     45  66.67  0.016533  26.266667
# 1257  4714    3445    14735    28    14     42  66.67  0.031388  38.809524
# 1128  3546   18498    52902    30    15     45  66.67  0.030024  30.022222
# 291   2359    5505    22345    30    15     45  66.67  0.027407  34.266667
# 1075  3306    6518    47232    28    14     42  66.67  0.041752  32.761905
# 1046  3218   31359   104541    26    13     39  66.67  0.029692  39.000000
# 677   4915   13585    65065    30    15     45  66.67  0.030536  33.555556
# 1472  6217   11728    32772    33    17     50  66.00  0.017424  29.420000
# 279   2345   44542   214058    33    17     50  66.00  0.027262  29.780000
# 298   2368   10159    27781    33    17     50  66.00  0.020396  28.580000
# 1156  3652    5796    37404    29    15     44  65.91  0.042611  33.477273
# 292   2360   33730   102870    29    15     44  65.91  0.026098  38.136364
# 1479  6227    6461    15389    29    15     44  65.91  0.019089  33.363636
# 603   3583   16293    77007    27    14     41  65.85  0.033927  37.951220
# 569   3311    6001    31699    27    14     41  65.85  0.044590  39.902439
# 1672  8410    7986    12514    27    14     41  65.85  0.021205  34.634146
# 1375  5478   19834    68666    27    14     41  65.85  0.025761  34.195122
# 1528  6472   49660   171190    25    13     38  65.79  0.030608  18.026316
# 250   2236    7006    39044    23    12     35  65.71  0.039454  37.400000
# 1482  6231   18521    57579    34    18     52  65.38  0.029321  22.846154
# 1131  3552   49688    38112    34    18     52  65.38  0.027640  18.538462
# 1058  3259    7598    24402    30    16     46  65.22  0.026680  21.239130
# 1573  6616    2952    20508    15     8     23  65.22  0.027087  35.521739
# 1578  6643   48590   242910    15     8     23  65.22  0.035196  18.173913
# 138   1597   17363    48787    28    15     43  65.12  0.026872  29.883721
# 1377  5483   22097   115303    28    15     43  65.12  0.028177  29.976744

# %%
sum_df[sum_df.代號.isin(suitable_Ticker)].sort_values("勝率%", ascending=False).to_csv(os.path.join(output_path, 'Summary_prob_holding_tradenum.csv'), index=False)

# %%
sum_df[sum_df.代號.isin(suitable_Ticker)].sort_values("勝率%", ascending=False).sum()#describe()
# Out:
# 代號           6.558655e+155
# 總成本           6.819490e+05
# 總損益(淨)        3.469261e+06
# 獲利次數          1.089000e+03
# 損失次數          5.170000e+02
# 總交易次數         1.606000e+03
# 勝率%           2.657180e+03
# 平均報酬          1.329695e+00
# 平均持倉時間(日)     1.179085e+03
# dtype: float64

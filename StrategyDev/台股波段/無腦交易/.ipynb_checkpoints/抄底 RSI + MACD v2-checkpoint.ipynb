# %%
import warnings
warnings.filterwarnings("ignore")

from datetime import datetime, timedelta
from pandas import DataFrame, concat, date_range, ExcelWriter, to_datetime
import os
from numpy import isnan, inf, mean
import time
import json
from Calculator import Calculator as Calc

from utils import getSchema, changedType
from BacktestBaseFunc import *

parent = os.path.dirname(os.path.abspath("__file__"))
output_path = os.path.join(parent, "Output", "VTurn_RSI_MACD")
if not os.path.isdir(output_path):
    os.makedirs(output_path)

# %%
def RSI_MACD_VTurn(df:DataFrame, **kwargs):
    entry_date = None
    exit_date = None
    entry_price = 0
    exit_price = 0
    max_price = 0
    min_price = inf
    sig = pos = 0
#     num_breakout_day = int(kwargs.get('num_breakout_day', 100))
    window = int(kwargs.get('window', 14))
    take_profit = float(kwargs.get('take_profit', .1))
    stop_loss = float(kwargs.get('stop_loss', .1))
    
    
    df = Calc.MACD(df.fillna(method='ffill'))
    df = Calc.RSI(df.fillna(method='ffill'), [window])
    result = []
    for i, row in enumerate(df.itertuples()):
        if not i: continue
        if isnan(row.OSC) or isnan(getattr(row,f"RSI{window}")): continue
        # Check Signal without pos
        if not sig and not pos:
            condi_osc = row.OSC < 0 and min(row.OSC, df.loc[row.Index-2, 'OSC']) > df.loc[row.Index-1, 'OSC']
            condi_rsi = getattr(row,f"RSI{window}") >= 30 and df.loc[row.Index-2, 'RSI14'] < 30 and df.loc[row.Index-1, 'RSI14'] < 30
            condi_bar = row.Close > row.Open
            if condi_osc and condi_rsi and condi_bar:
                sig = 1
        # Entry Market
        elif sig and not pos:
#             if row.Ticker == '1538':print(row)
            if not row.Volume or isnan(row.Open): continue
#             print(row)
            pos, sig = sig, 0
            max_price = min_price = entry_price = row.Open
            entry_date = row.Date
            max_price = max(row.High, max_price)
            min_price = min(row.Low, min_price)
        # Check Signal with pos
        elif not sig and pos:
            max_price = max(row.High, entry_price)
            min_price = min(row.Low, entry_price)
            if (row.High / entry_price - 1 >= take_profit):
                sig = -1
#                 exit_price = row.High
            if (row.Low / entry_price - 1 <= -stop_loss):
                sig = -1
#                 exit_price = row.Low
        # Exit Market
        elif sig and pos:
            
            if not row.Volume or isnan(row.Open): continue
#             if row.Ticker == '1538':print(row)
            exit_price = row.Open
            exit_date = row.Date
            res = CreateTradeLog(entry_date, exit_date, entry_price, exit_price, max_price, min_price, pos)
            result.append(res)
            entry_date = None
            exit_date = None
            entry_price = 0
            exit_price = 0
            max_price = 0
            min_price = inf
            sig = pos = 0
        if i == df.shape[0]-1 and pos:
            exit_price = row.Close
            if not row.Volume or isnan(row.Open):
                exit_price = df.fillna(method='ffill').Close.iloc[-1]
            
            exit_date = row.Date
            res = CreateTradeLog(entry_date, exit_date, entry_price, exit_price, max_price, min_price, pos)
            result.append(res)
            entry_date = None
            exit_date = None
            entry_price = 0
            exit_price = 0
            max_price = 0
            min_price = inf
            sig = pos = 0
#     print()
            
    return result

# %%
bt_list = StockList()

# %%
results = {}
for ticker_info in bt_list:
    print(f"============= Backtest {ticker_info['Ticker']}=============")
    results[ticker_info['Ticker']] = Backtest(RSI_MACD_VTurn, ticker_info['Ticker'], bt_period = 10)
#     break
# Out:
# ============= Backtest 1101=============
# ============= Backtest 1102=============
# ============= Backtest 1103=============
# ============= Backtest 1104=============
# ============= Backtest 1108=============
# ============= Backtest 1109=============
# ============= Backtest 1110=============
# ============= Backtest 1201=============
# ============= Backtest 1203=============
# ============= Backtest 1210=============
# ============= Backtest 1213=============
# ============= Backtest 1215=============
# ============= Backtest 1216=============
# ============= Backtest 1217=============
# ============= Backtest 1218=============
# ============= Backtest 1219=============
# ============= Backtest 1220=============
# ============= Backtest 1225=============
# ============= Backtest 1227=============
# ============= Backtest 1229=============
# ============= Backtest 1231=============
# ============= Backtest 1232=============
# ============= Backtest 1233=============
# ============= Backtest 1234=============
# ============= Backtest 1235=============
# ============= Backtest 1236=============
# ============= Backtest 1256=============
# ============= Backtest 1301=============
# ============= Backtest 1303=============
# ============= Backtest 1304=============
# ============= Backtest 1305=============
# ============= Backtest 1307=============
# ============= Backtest 1308=============
# ============= Backtest 1309=============
# ============= Backtest 1310=============
# ============= Backtest 1312=============
# ============= Backtest 1313=============
# ============= Backtest 1314=============
# ============= Backtest 1315=============
# ============= Backtest 1316=============
# ============= Backtest 1319=============
# ============= Backtest 1321=============
# ============= Backtest 1323=============
# ============= Backtest 1324=============
# ============= Backtest 1325=============
# ============= Backtest 1326=============
# ============= Backtest 1337=============
# ============= Backtest 1338=============
# ============= Backtest 1339=============
# ============= Backtest 1340=============
# ============= Backtest 1341=============
# ============= Backtest 1342=============
# ============= Backtest 1402=============
# ============= Backtest 1409=============
# ============= Backtest 1410=============
# ============= Backtest 1413=============
# ============= Backtest 1414=============
# ============= Backtest 1416=============
# ============= Backtest 1417=============
# ============= Backtest 1418=============
# ============= Backtest 1419=============
# ============= Backtest 1423=============
# ============= Backtest 1432=============
# ============= Backtest 1434=============
# ============= Backtest 1435=============
# ============= Backtest 1436=============
# ============= Backtest 1437=============
# ============= Backtest 1438=============
# ============= Backtest 1439=============
# ============= Backtest 1440=============
# ============= Backtest 1441=============
# ============= Backtest 1442=============
# ============= Backtest 1443=============
# ============= Backtest 1444=============
# ============= Backtest 1445=============
# ============= Backtest 1446=============
# ============= Backtest 1447=============
# ============= Backtest 1449=============
# ============= Backtest 1451=============
# ============= Backtest 1452=============
# ============= Backtest 1453=============
# ============= Backtest 1454=============
# ============= Backtest 1455=============
# ============= Backtest 1456=============
# ============= Backtest 1457=============
# ============= Backtest 1459=============
# ============= Backtest 1460=============
# ============= Backtest 1463=============
# ============= Backtest 1464=============
# ============= Backtest 1465=============
# ============= Backtest 1466=============
# ============= Backtest 1467=============
# ============= Backtest 1468=============
# ============= Backtest 1470=============
# ============= Backtest 1471=============
# ============= Backtest 1472=============
# ============= Backtest 1473=============
# ============= Backtest 1474=============
# ============= Backtest 1475=============
# ============= Backtest 1476=============
# ============= Backtest 1477=============
# ============= Backtest 1503=============
# ============= Backtest 1504=============
# ============= Backtest 1506=============
# ============= Backtest 1512=============
# ============= Backtest 1513=============
# ============= Backtest 1514=============
# ============= Backtest 1515=============
# ============= Backtest 1516=============
# ============= Backtest 1517=============
# ============= Backtest 1519=============
# ============= Backtest 1521=============
# ============= Backtest 1522=============
# ============= Backtest 1524=============
# ============= Backtest 1525=============
# ============= Backtest 1526=============
# ============= Backtest 1527=============
# ============= Backtest 1528=============
# ============= Backtest 1529=============
# ============= Backtest 1530=============
# ============= Backtest 1531=============
# ============= Backtest 1532=============
# ============= Backtest 1533=============
# ============= Backtest 1535=============
# ============= Backtest 1536=============
# ============= Backtest 1537=============
# ============= Backtest 1538=============
# ============= Backtest 1539=============
# ============= Backtest 1540=============
# ============= Backtest 1541=============
# ============= Backtest 1558=============
# ============= Backtest 1560=============
# ============= Backtest 1568=============
# ============= Backtest 1582=============
# ============= Backtest 1583=============
# ============= Backtest 1587=============
# ============= Backtest 1589=============
# ============= Backtest 1590=============
# ============= Backtest 1597=============
# ============= Backtest 1598=============
# ============= Backtest 1603=============
# ============= Backtest 1604=============
# ============= Backtest 1605=============
# ============= Backtest 1608=============
# ============= Backtest 1609=============
# ============= Backtest 1611=============
# ============= Backtest 1612=============
# ============= Backtest 1614=============
# ============= Backtest 1615=============
# ============= Backtest 1616=============
# ============= Backtest 1617=============
# ============= Backtest 1618=============
# ============= Backtest 1626=============
# ============= Backtest 1701=============
# ============= Backtest 1702=============
# ============= Backtest 1707=============
# ============= Backtest 1708=============
# ============= Backtest 1709=============
# ============= Backtest 1710=============
# ============= Backtest 1711=============
# ============= Backtest 1712=============
# ============= Backtest 1713=============
# ============= Backtest 1714=============
# ============= Backtest 1717=============
# ============= Backtest 1718=============
# ============= Backtest 1720=============
# ============= Backtest 1721=============
# ============= Backtest 1722=============
# ============= Backtest 1723=============
# ============= Backtest 1725=============
# ============= Backtest 1726=============
# ============= Backtest 1727=============
# ============= Backtest 1730=============
# ============= Backtest 1731=============
# ============= Backtest 1732=============
# ============= Backtest 1733=============
# ============= Backtest 1734=============
# ============= Backtest 1735=============
# ============= Backtest 1736=============
# ============= Backtest 1737=============
# ============= Backtest 1760=============
# ============= Backtest 1762=============
# ============= Backtest 1773=============
# ============= Backtest 1776=============
# ============= Backtest 1783=============
# ============= Backtest 1786=============
# ============= Backtest 1789=============
# ============= Backtest 1795=============
# ============= Backtest 1802=============
# ============= Backtest 1805=============
# ============= Backtest 1806=============
# ============= Backtest 1808=============
# ============= Backtest 1809=============
# ============= Backtest 1810=============
# ============= Backtest 1817=============
# ============= Backtest 1903=============
# ============= Backtest 1904=============
# ============= Backtest 1905=============
# ============= Backtest 1906=============
# ============= Backtest 1907=============
# ============= Backtest 1909=============
# ============= Backtest 2002=============
# ============= Backtest 2006=============
# ============= Backtest 2007=============
# ============= Backtest 2008=============
# ============= Backtest 2009=============
# ============= Backtest 2010=============
# ============= Backtest 2012=============
# ============= Backtest 2013=============
# ============= Backtest 2014=============
# ============= Backtest 2015=============
# ============= Backtest 2017=============
# ============= Backtest 2020=============
# ============= Backtest 2022=============
# ============= Backtest 2023=============
# ============= Backtest 2024=============
# ============= Backtest 2025=============
# ============= Backtest 2027=============
# ============= Backtest 2028=============
# ============= Backtest 2029=============
# ============= Backtest 2030=============
# ============= Backtest 2031=============
# ============= Backtest 2032=============
# ============= Backtest 2033=============
# ============= Backtest 2034=============
# ============= Backtest 2038=============
# ============= Backtest 2049=============
# ============= Backtest 2059=============
# ============= Backtest 2062=============
# ============= Backtest 2069=============
# ============= Backtest 2101=============
# ============= Backtest 2102=============
# ============= Backtest 2103=============
# ============= Backtest 2104=============
# ============= Backtest 2105=============
# ============= Backtest 2106=============
# ============= Backtest 2107=============
# ============= Backtest 2108=============
# ============= Backtest 2109=============
# ============= Backtest 2114=============
# ============= Backtest 2115=============
# ============= Backtest 2201=============
# ============= Backtest 2204=============
# ============= Backtest 2206=============
# ============= Backtest 2207=============
# ============= Backtest 2208=============
# ============= Backtest 2227=============
# ============= Backtest 2228=============
# ============= Backtest 2231=============
# ============= Backtest 2233=============
# ============= Backtest 2236=============
# ============= Backtest 2239=============
# ============= Backtest 2241=============
# ============= Backtest 2243=============
# ============= Backtest 2247=============
# ============= Backtest 2301=============
# ============= Backtest 2302=============
# ============= Backtest 2303=============
# ============= Backtest 2305=============
# ============= Backtest 2308=============
# ============= Backtest 2312=============
# ============= Backtest 2313=============
# ============= Backtest 2314=============
# ============= Backtest 2316=============
# ============= Backtest 2317=============
# ============= Backtest 2321=============
# ============= Backtest 2323=============
# ============= Backtest 2324=============
# ============= Backtest 2327=============
# ============= Backtest 2328=============
# ============= Backtest 2329=============
# ============= Backtest 2330=============
# ============= Backtest 2331=============
# ============= Backtest 2332=============
# ============= Backtest 2337=============
# ============= Backtest 2338=============
# ============= Backtest 2340=============
# ============= Backtest 2342=============
# ============= Backtest 2344=============
# ============= Backtest 2345=============
# ============= Backtest 2347=============
# ============= Backtest 2348=============
# ============= Backtest 2349=============
# ============= Backtest 2351=============
# ============= Backtest 2352=============
# ============= Backtest 2353=============
# ============= Backtest 2354=============
# ============= Backtest 2355=============
# ============= Backtest 2356=============
# ============= Backtest 2357=============
# ============= Backtest 2358=============
# ============= Backtest 2359=============
# ============= Backtest 2360=============
# ============= Backtest 2362=============
# ============= Backtest 2363=============
# ============= Backtest 2364=============
# ============= Backtest 2365=============
# ============= Backtest 2367=============
# ============= Backtest 2368=============
# ============= Backtest 2369=============
# ============= Backtest 2371=============
# ============= Backtest 2373=============
# ============= Backtest 2374=============
# ============= Backtest 2375=============
# ============= Backtest 2376=============
# ============= Backtest 2377=============
# ============= Backtest 2379=============
# ============= Backtest 2380=============
# ============= Backtest 2382=============
# ============= Backtest 2383=============
# ============= Backtest 2385=============
# ============= Backtest 2387=============
# ============= Backtest 2388=============
# ============= Backtest 2390=============
# ============= Backtest 2392=============
# ============= Backtest 2393=============
# ============= Backtest 2395=============
# ============= Backtest 2397=============
# ============= Backtest 2399=============
# ============= Backtest 2401=============
# ============= Backtest 2402=============
# ============= Backtest 2404=============
# ============= Backtest 2405=============
# ============= Backtest 2406=============
# ============= Backtest 2408=============
# ============= Backtest 2409=============
# ============= Backtest 2412=============
# ============= Backtest 2413=============
# ============= Backtest 2414=============
# ============= Backtest 2415=============
# ============= Backtest 2417=============
# ============= Backtest 2419=============
# ============= Backtest 2420=============
# ============= Backtest 2421=============
# ============= Backtest 2423=============
# ============= Backtest 2424=============
# ============= Backtest 2425=============
# ============= Backtest 2426=============
# ============= Backtest 2427=============
# ============= Backtest 2428=============
# ============= Backtest 2429=============
# ============= Backtest 2430=============
# ============= Backtest 2431=============
# ============= Backtest 2433=============
# ============= Backtest 2434=============
# ============= Backtest 2436=============
# ============= Backtest 2438=============
# ============= Backtest 2439=============
# ============= Backtest 2440=============
# ============= Backtest 2441=============
# ============= Backtest 2442=============
# ============= Backtest 2443=============
# ============= Backtest 2444=============
# ============= Backtest 2449=============
# ============= Backtest 2450=============
# ============= Backtest 2451=============
# ============= Backtest 2453=============
# ============= Backtest 2454=============
# ============= Backtest 2455=============
# ============= Backtest 2457=============
# ============= Backtest 2458=============
# ============= Backtest 2459=============
# ============= Backtest 2460=============
# ============= Backtest 2461=============
# ============= Backtest 2462=============
# ============= Backtest 2464=============
# ============= Backtest 2465=============
# ============= Backtest 2466=============
# ============= Backtest 2467=============
# ============= Backtest 2468=============
# ============= Backtest 2471=============
# ============= Backtest 2472=============
# ============= Backtest 2474=============
# ============= Backtest 2476=============
# ============= Backtest 2477=============
# ============= Backtest 2478=============
# ============= Backtest 2480=============
# ============= Backtest 2481=============
# ============= Backtest 2482=============
# ============= Backtest 2483=============
# ============= Backtest 2484=============
# ============= Backtest 2485=============
# ============= Backtest 2486=============
# ============= Backtest 2488=============
# ============= Backtest 2489=============
# ============= Backtest 2491=============
# ============= Backtest 2492=============
# ============= Backtest 2493=============
# ============= Backtest 2495=============
# ============= Backtest 2496=============
# ============= Backtest 2497=============
# ============= Backtest 2498=============
# ============= Backtest 2501=============
# ============= Backtest 2504=============
# ============= Backtest 2505=============
# ============= Backtest 2506=============
# ============= Backtest 2509=============
# ============= Backtest 2511=============
# ============= Backtest 2514=============
# ============= Backtest 2515=============
# ============= Backtest 2516=============
# ============= Backtest 2520=============
# ============= Backtest 2524=============
# ============= Backtest 2527=============
# ============= Backtest 2528=============
# ============= Backtest 2530=============
# ============= Backtest 2534=============
# ============= Backtest 2535=============
# ============= Backtest 2536=============
# ============= Backtest 2537=============
# ============= Backtest 2538=============
# ============= Backtest 2539=============
# ============= Backtest 2540=============
# ============= Backtest 2542=============
# ============= Backtest 2543=============
# ============= Backtest 2545=============
# ============= Backtest 2546=============
# ============= Backtest 2547=============
# ============= Backtest 2548=============
# ============= Backtest 2597=============
# ============= Backtest 2601=============
# ============= Backtest 2603=============
# ============= Backtest 2605=============
# ============= Backtest 2606=============
# ============= Backtest 2607=============
# ============= Backtest 2608=============
# ============= Backtest 2609=============
# ============= Backtest 2610=============
# ============= Backtest 2611=============
# ============= Backtest 2612=============
# ============= Backtest 2613=============
# ============= Backtest 2614=============
# ============= Backtest 2615=============
# ============= Backtest 2616=============
# ============= Backtest 2617=============
# ============= Backtest 2618=============
# ============= Backtest 2630=============
# ============= Backtest 2633=============
# ============= Backtest 2634=============
# ============= Backtest 2636=============
# ============= Backtest 2637=============
# ============= Backtest 2642=============
# ============= Backtest 2701=============
# ============= Backtest 2702=============
# ============= Backtest 2704=============
# ============= Backtest 2705=============
# ============= Backtest 2706=============
# ============= Backtest 2707=============
# ============= Backtest 2712=============
# ============= Backtest 2722=============
# ============= Backtest 2723=============
# ============= Backtest 2727=============
# ============= Backtest 2731=============
# ============= Backtest 2739=============
# ============= Backtest 2748=============
# ============= Backtest 2801=============
# ============= Backtest 2809=============
# ============= Backtest 2812=============
# ============= Backtest 2816=============
# ============= Backtest 2820=============
# ============= Backtest 2832=============
# ============= Backtest 2834=============
# ============= Backtest 2836=============
# ============= Backtest 2838=============
# ============= Backtest 2841=============
# ============= Backtest 2845=============
# ============= Backtest 2849=============
# ============= Backtest 2850=============
# ============= Backtest 2851=============
# ============= Backtest 2852=============
# ============= Backtest 2855=============
# ============= Backtest 2867=============
# ============= Backtest 2880=============
# ============= Backtest 2881=============
# ============= Backtest 2882=============
# ============= Backtest 2883=============
# ============= Backtest 2884=============
# ============= Backtest 2885=============
# ============= Backtest 2886=============
# ============= Backtest 2887=============
# ============= Backtest 2888=============
# ============= Backtest 2889=============
# ============= Backtest 2890=============
# ============= Backtest 2891=============
# ============= Backtest 2892=============
# ============= Backtest 2897=============
# ============= Backtest 2901=============
# ============= Backtest 2903=============
# ============= Backtest 2904=============
# ============= Backtest 2905=============
# ============= Backtest 2906=============
# ============= Backtest 2908=============
# ============= Backtest 2910=============
# ============= Backtest 2911=============
# ============= Backtest 2912=============
# ============= Backtest 2913=============
# ============= Backtest 2915=============
# ============= Backtest 2923=============
# ============= Backtest 2929=============
# ============= Backtest 2936=============
# ============= Backtest 2939=============
# ============= Backtest 3002=============
# ============= Backtest 3003=============
# ============= Backtest 3004=============
# ============= Backtest 3005=============
# ============= Backtest 3006=============
# ============= Backtest 3008=============
# ============= Backtest 3010=============
# ============= Backtest 3011=============
# ============= Backtest 3013=============
# ============= Backtest 3014=============
# ============= Backtest 3015=============
# ============= Backtest 3016=============
# ============= Backtest 3017=============
# ============= Backtest 3018=============
# ============= Backtest 3019=============
# ============= Backtest 3021=============
# ============= Backtest 3022=============
# ============= Backtest 3023=============
# ============= Backtest 3024=============
# ============= Backtest 3025=============
# ============= Backtest 3026=============
# ============= Backtest 3027=============
# ============= Backtest 3028=============
# ============= Backtest 3029=============
# ============= Backtest 3030=============
# ============= Backtest 3031=============
# ============= Backtest 3032=============
# ============= Backtest 3033=============
# ============= Backtest 3034=============
# ============= Backtest 3035=============
# ============= Backtest 3036=============
# ============= Backtest 3037=============
# ============= Backtest 3038=============
# ============= Backtest 3040=============
# ============= Backtest 3041=============
# ============= Backtest 3042=============
# ============= Backtest 3043=============
# ============= Backtest 3044=============
# ============= Backtest 3045=============
# ============= Backtest 3046=============
# ============= Backtest 3047=============
# ============= Backtest 3048=============
# ============= Backtest 3049=============
# ============= Backtest 3050=============
# ============= Backtest 3051=============
# ============= Backtest 3052=============
# ============= Backtest 3054=============
# ============= Backtest 3055=============
# ============= Backtest 3056=============
# ============= Backtest 3057=============
# ============= Backtest 3058=============
# ============= Backtest 3059=============
# ============= Backtest 3060=============
# ============= Backtest 3062=============
# ============= Backtest 3090=============
# ============= Backtest 3094=============
# ============= Backtest 3130=============
# ============= Backtest 3138=============
# ============= Backtest 3149=============
# ============= Backtest 3164=============
# ============= Backtest 3167=============
# ============= Backtest 3189=============
# ============= Backtest 3209=============
# ============= Backtest 3229=============
# ============= Backtest 3231=============
# ============= Backtest 3257=============
# ============= Backtest 3266=============
# ============= Backtest 3296=============
# ============= Backtest 3305=============
# ============= Backtest 3308=============
# ============= Backtest 3311=============
# ============= Backtest 3312=============
# ============= Backtest 3321=============
# ============= Backtest 3338=============
# ============= Backtest 3346=============
# ============= Backtest 3356=============
# ============= Backtest 3376=============
# ============= Backtest 3380=============
# ============= Backtest 3383=============
# ============= Backtest 3406=============
# ============= Backtest 3413=============
# ============= Backtest 3416=============
# ============= Backtest 3419=============
# ============= Backtest 3432=============
# ============= Backtest 3437=============
# ============= Backtest 3443=============
# ============= Backtest 3450=============
# ============= Backtest 3454=============
# ============= Backtest 3481=============
# ============= Backtest 3494=============
# ============= Backtest 3501=============
# ============= Backtest 3504=============
# ============= Backtest 3515=============
# ============= Backtest 3518=============
# ============= Backtest 3528=============
# ============= Backtest 3530=============
# ============= Backtest 3532=============
# ============= Backtest 3533=============
# ============= Backtest 3535=============
# ============= Backtest 3536=============
# ============= Backtest 3543=============
# ============= Backtest 3545=============
# ============= Backtest 3550=============
# ============= Backtest 3557=============
# ============= Backtest 3563=============
# ============= Backtest 3576=============
# ============= Backtest 3583=============
# ============= Backtest 3588=============
# ============= Backtest 3591=============
# ============= Backtest 3593=============
# ============= Backtest 3596=============
# ============= Backtest 3605=============
# ============= Backtest 3607=============
# ============= Backtest 3617=============
# ============= Backtest 3622=============
# ============= Backtest 3645=============
# ============= Backtest 3653=============
# ============= Backtest 3661=============
# ============= Backtest 3665=============
# ============= Backtest 3669=============
# ============= Backtest 3673=============
# ============= Backtest 3679=============
# ============= Backtest 3682=============
# ============= Backtest 3686=============
# ============= Backtest 3694=============
# ============= Backtest 3701=============
# ============= Backtest 3702=============
# ============= Backtest 3703=============
# ============= Backtest 3704=============
# ============= Backtest 3705=============
# ============= Backtest 3706=============
# ============= Backtest 3708=============
# ============= Backtest 3711=============
# ============= Backtest 3712=============
# ============= Backtest 3714=============
# ============= Backtest 4104=============
# ============= Backtest 4106=============
# ============= Backtest 4108=============
# ============= Backtest 4119=============
# ============= Backtest 4133=============
# ============= Backtest 4137=============
# ============= Backtest 4142=============
# ============= Backtest 4155=============
# ============= Backtest 4164=============
# ============= Backtest 4190=============
# ============= Backtest 4306=============
# ============= Backtest 4414=============
# ============= Backtest 4426=============
# ============= Backtest 4438=============
# ============= Backtest 4439=============
# ============= Backtest 4526=============
# ============= Backtest 4532=============
# ============= Backtest 4536=============
# ============= Backtest 4540=============
# ============= Backtest 4545=============
# ============= Backtest 4551=============
# ============= Backtest 4552=============
# ============= Backtest 4555=============
# ============= Backtest 4557=============
# ============= Backtest 4560=============
# ============= Backtest 4562=============
# ============= Backtest 4564=============
# ============= Backtest 4566=============
# ============= Backtest 4571=============
# ============= Backtest 4572=============
# ============= Backtest 4576=============
# ============= Backtest 4581=============
# ============= Backtest 4720=============
# ============= Backtest 4722=============
# ============= Backtest 4737=============
# ============= Backtest 4739=============
# ============= Backtest 4746=============
# ============= Backtest 4755=============
# ============= Backtest 4763=============
# ============= Backtest 4764=============
# ============= Backtest 4766=============
# ============= Backtest 4807=============
# ============= Backtest 4904=============
# ============= Backtest 4906=============
# ============= Backtest 4912=============
# ============= Backtest 4915=============
# ============= Backtest 4916=============
# ============= Backtest 4919=============
# ============= Backtest 4927=============
# ============= Backtest 4930=============
# ============= Backtest 4934=============
# ============= Backtest 4935=============
# ============= Backtest 4938=============
# ============= Backtest 4942=============
# ============= Backtest 4943=============
# ============= Backtest 4952=============
# ============= Backtest 4956=============
# ============= Backtest 4958=============
# ============= Backtest 4960=============
# ============= Backtest 4961=============
# ============= Backtest 4967=============
# ============= Backtest 4968=============
# ============= Backtest 4976=============
# ============= Backtest 4977=============
# ============= Backtest 4989=============
# ============= Backtest 4994=============
# ============= Backtest 4999=============
# ============= Backtest 5007=============
# ============= Backtest 5203=============
# ============= Backtest 5215=============
# ============= Backtest 5225=============
# ============= Backtest 5234=============
# ============= Backtest 5243=============
# ============= Backtest 5258=============
# ============= Backtest 5269=============
# ============= Backtest 5283=============
# ============= Backtest 5284=============
# ============= Backtest 5285=============
# ============= Backtest 5288=============
# ============= Backtest 5388=============
# ============= Backtest 5434=============
# ============= Backtest 5469=============
# ============= Backtest 5471=============
# ============= Backtest 5484=============
# ============= Backtest 5515=============
# ============= Backtest 5519=============
# ============= Backtest 5521=============
# ============= Backtest 5522=============
# ============= Backtest 5525=============
# ============= Backtest 5531=============
# ============= Backtest 5533=============
# ============= Backtest 5534=============
# ============= Backtest 5538=============
# ============= Backtest 5546=============
# ============= Backtest 5607=============
# ============= Backtest 5608=============
# ============= Backtest 5706=============
# ============= Backtest 5871=============
# ============= Backtest 5876=============
# ============= Backtest 5880=============
# ============= Backtest 5906=============
# ============= Backtest 5907=============
# ============= Backtest 6005=============
# ============= Backtest 6024=============
# ============= Backtest 6108=============
# ============= Backtest 6112=============
# ============= Backtest 6115=============
# ============= Backtest 6116=============
# ============= Backtest 6117=============
# ============= Backtest 6120=============
# ============= Backtest 6128=============
# ============= Backtest 6133=============
# ============= Backtest 6136=============
# ============= Backtest 6139=============
# ============= Backtest 6141=============
# ============= Backtest 6142=============
# ============= Backtest 6152=============
# ============= Backtest 6153=============
# ============= Backtest 6155=============
# ============= Backtest 6164=============
# ============= Backtest 6165=============
# ============= Backtest 6166=============
# ============= Backtest 6168=============
# ============= Backtest 6172=============
# ============= Backtest 6176=============
# ============= Backtest 6177=============
# ============= Backtest 6183=============
# ============= Backtest 6184=============
# ============= Backtest 6189=============
# ============= Backtest 6191=============
# ============= Backtest 6192=============
# ============= Backtest 6196=============
# ============= Backtest 6197=============
# ============= Backtest 6201=============
# ============= Backtest 6202=============
# ============= Backtest 6205=============
# ============= Backtest 6206=============
# ============= Backtest 6209=============
# ============= Backtest 6213=============
# ============= Backtest 6214=============
# ============= Backtest 6215=============
# ============= Backtest 6216=============
# ============= Backtest 6224=============
# ============= Backtest 6225=============
# ============= Backtest 6226=============
# ============= Backtest 6230=============
# ============= Backtest 6235=============
# ============= Backtest 6239=============
# ============= Backtest 6243=============
# ============= Backtest 6251=============
# ============= Backtest 6257=============
# ============= Backtest 6269=============
# ============= Backtest 6271=============
# ============= Backtest 6277=============
# ============= Backtest 6278=============
# ============= Backtest 6281=============
# ============= Backtest 6282=============
# ============= Backtest 6283=============
# ============= Backtest 6285=============
# ============= Backtest 6288=============
# ============= Backtest 6289=============
# ============= Backtest 6405=============
# ============= Backtest 6409=============
# ============= Backtest 6412=============
# ============= Backtest 6414=============
# ============= Backtest 6415=============
# ============= Backtest 6416=============
# ============= Backtest 6431=============
# ============= Backtest 6438=============
# ============= Backtest 6442=============
# ============= Backtest 6443=============
# ============= Backtest 6449=============
# ============= Backtest 6451=============
# ============= Backtest 6456=============
# ============= Backtest 6464=============
# ============= Backtest 6477=============
# ============= Backtest 6491=============
# ============= Backtest 6504=============
# ============= Backtest 6505=============
# ============= Backtest 6515=============
# ============= Backtest 6525=============
# ============= Backtest 6531=============
# ============= Backtest 6533=============
# ============= Backtest 6541=============
# ============= Backtest 6552=============
# ============= Backtest 6558=============
# ============= Backtest 6573=============
# ============= Backtest 6579=============
# ============= Backtest 6581=============
# ============= Backtest 6582=============
# ============= Backtest 6591=============
# ============= Backtest 6592=============
# ============= Backtest 6598=============
# ============= Backtest 6605=============
# ============= Backtest 6625=============
# ============= Backtest 6641=============
# ============= Backtest 6655=============
# ============= Backtest 6666=============
# ============= Backtest 6668=============
# ============= Backtest 6669=============
# ============= Backtest 6670=============
# ============= Backtest 6671=============
# ============= Backtest 6672=============
# ============= Backtest 6674=============
# ============= Backtest 6698=============
# ============= Backtest 6706=============
# ============= Backtest 6715=============
# ============= Backtest 6743=============
# ============= Backtest 6754=============
# ============= Backtest 6756=============
# ============= Backtest 8011=============
# ============= Backtest 8016=============
# ============= Backtest 8021=============
# ============= Backtest 8028=============
# ============= Backtest 8033=============
# ============= Backtest 8039=============
# ============= Backtest 8046=============
# ============= Backtest 8070=============
# ============= Backtest 8072=============
# ============= Backtest 8081=============
# ============= Backtest 8101=============
# ============= Backtest 8103=============
# ============= Backtest 8104=============
# ============= Backtest 8105=============
# ============= Backtest 8110=============
# ============= Backtest 8112=============
# ============= Backtest 8114=============
# ============= Backtest 8131=============
# ============= Backtest 8150=============
# ============= Backtest 8163=============
# ============= Backtest 8201=============
# ============= Backtest 8210=============
# ============= Backtest 8213=============
# ============= Backtest 8215=============
# ============= Backtest 8222=============
# ============= Backtest 8249=============
# ============= Backtest 8261=============
# ============= Backtest 8271=============
# ============= Backtest 8341=============
# ============= Backtest 8367=============
# ============= Backtest 8374=============
# ============= Backtest 8404=============
# ============= Backtest 8411=============
# ============= Backtest 8422=============
# ============= Backtest 8429=============
# ============= Backtest 8442=============
# ============= Backtest 8443=============
# ============= Backtest 8454=============
# ============= Backtest 8462=============
# ============= Backtest 8463=============
# ============= Backtest 8464=============
# ============= Backtest 8466=============
# ============= Backtest 8467=============
# ============= Backtest 8473=============
# ============= Backtest 8478=============
# ============= Backtest 8480=============
# ============= Backtest 8481=============
# ============= Backtest 8482=============
# ============= Backtest 8488=============
# ============= Backtest 8499=============
# ============= Backtest 8926=============
# ============= Backtest 8940=============
# ============= Backtest 8996=============
# ============= Backtest 9802=============
# ============= Backtest 9902=============
# ============= Backtest 9904=============
# ============= Backtest 9905=============
# ============= Backtest 9906=============
# ============= Backtest 9907=============
# ============= Backtest 9908=============
# ============= Backtest 9910=============
# ============= Backtest 9911=============
# ============= Backtest 9912=============
# ============= Backtest 9914=============
# ============= Backtest 9917=============
# ============= Backtest 9918=============
# ============= Backtest 9919=============
# ============= Backtest 9921=============
# ============= Backtest 9924=============
# ============= Backtest 9925=============
# ============= Backtest 9926=============
# ============= Backtest 9927=============
# ============= Backtest 9928=============
# ============= Backtest 9929=============
# ============= Backtest 9930=============
# ============= Backtest 9931=============
# ============= Backtest 9933=============
# ============= Backtest 9934=============
# ============= Backtest 9935=============
# ============= Backtest 9937=============
# ============= Backtest 9938=============
# ============= Backtest 9939=============
# ============= Backtest 9940=============
# ============= Backtest 9941=============
# ============= Backtest 9942=============
# ============= Backtest 9943=============
# ============= Backtest 9944=============
# ============= Backtest 9945=============
# ============= Backtest 9946=============
# ============= Backtest 9955=============
# ============= Backtest 9958=============
# ============= Backtest 1312A=============
# ============= Backtest 2002A=============
# ============= Backtest 2836A=============
# ============= Backtest 2838A=============
# ============= Backtest 2881A=============
# ============= Backtest 2881B=============
# ============= Backtest 2882A=============
# ============= Backtest 2882B=============
# ============= Backtest 2887E=============
# ============= Backtest 2887F=============
# ============= Backtest 2888A=============
# ============= Backtest 2888B=============
# ============= Backtest 2891B=============
# ============= Backtest 2891C=============
# ============= Backtest 2897A=============
# ============= Backtest 3702A=============
# ============= Backtest 5871A=============
# ============= Backtest 9941A=============
# ============= Backtest 1240=============
# ============= Backtest 1258=============
# ============= Backtest 1259=============
# ============= Backtest 1264=============
# ============= Backtest 1268=============
# ============= Backtest 1336=============
# ============= Backtest 1565=============
# ============= Backtest 1569=============
# ============= Backtest 1570=============
# ============= Backtest 1580=============
# ============= Backtest 1584=============
# ============= Backtest 1586=============
# ============= Backtest 1591=============
# ============= Backtest 1593=============
# ============= Backtest 1595=============
# ============= Backtest 1599=============
# ============= Backtest 1742=============
# ============= Backtest 1752=============
# ============= Backtest 1777=============
# ============= Backtest 1781=============
# ============= Backtest 1784=============
# ============= Backtest 1785=============
# ============= Backtest 1788=============
# ============= Backtest 1796=============
# ============= Backtest 1799=============
# ============= Backtest 1813=============
# ============= Backtest 1815=============
# ============= Backtest 2035=============
# ============= Backtest 2061=============
# ============= Backtest 2063=============
# ============= Backtest 2064=============
# ============= Backtest 2065=============
# ============= Backtest 2066=============
# ============= Backtest 2067=============
# ============= Backtest 2070=============
# ============= Backtest 2221=============
# ============= Backtest 2230=============
# ============= Backtest 2235=============
# ============= Backtest 2596=============
# ============= Backtest 2640=============
# ============= Backtest 2641=============
# ============= Backtest 2643=============
# ============= Backtest 2718=============
# ============= Backtest 2719=============
# ============= Backtest 2724=============
# ============= Backtest 2726=============
# ============= Backtest 2729=============
# ============= Backtest 2732=============
# ============= Backtest 2734=============
# ============= Backtest 2736=============
# ============= Backtest 2740=============
# ============= Backtest 2743=============
# ============= Backtest 2745=============
# ============= Backtest 2752=============
# ============= Backtest 2754=============
# ============= Backtest 2755=============
# ============= Backtest 2916=============
# ============= Backtest 2924=============
# ============= Backtest 2926=============
# ============= Backtest 2937=============
# ============= Backtest 3064=============
# ============= Backtest 3066=============
# ============= Backtest 3067=============
# ============= Backtest 3071=============
# ============= Backtest 3073=============
# ============= Backtest 3078=============
# ============= Backtest 3081=============
# ============= Backtest 3083=============
# ============= Backtest 3085=============
# ============= Backtest 3086=============
# ============= Backtest 3088=============
# ============= Backtest 3089=============
# ============= Backtest 3092=============
# ============= Backtest 3093=============
# ============= Backtest 3095=============
# ============= Backtest 3105=============
# ============= Backtest 3114=============
# ============= Backtest 3115=============
# ============= Backtest 3118=============
# ============= Backtest 3122=============
# ============= Backtest 3128=============
# ============= Backtest 3131=============
# ============= Backtest 3141=============
# ============= Backtest 3147=============
# ============= Backtest 3152=============
# ============= Backtest 3162=============
# ============= Backtest 3163=============
# ============= Backtest 3169=============
# ============= Backtest 3171=============
# ============= Backtest 3176=============
# ============= Backtest 3178=============
# ============= Backtest 3188=============
# ============= Backtest 3191=============
# ============= Backtest 3202=============
# ============= Backtest 3205=============
# ============= Backtest 3206=============
# ============= Backtest 3207=============
# ============= Backtest 3211=============
# ============= Backtest 3213=============
# ============= Backtest 3217=============
# ============= Backtest 3218=============
# ============= Backtest 3219=============
# ============= Backtest 3221=============
# ============= Backtest 3224=============
# ============= Backtest 3226=============
# ============= Backtest 3227=============
# ============= Backtest 3228=============
# ============= Backtest 3230=============
# ============= Backtest 3232=============
# ============= Backtest 3234=============
# ============= Backtest 3236=============
# ============= Backtest 3252=============
# ============= Backtest 3259=============
# ============= Backtest 3260=============
# ============= Backtest 3264=============
# ============= Backtest 3265=============
# ============= Backtest 3268=============
# ============= Backtest 3272=============
# ============= Backtest 3276=============
# ============= Backtest 3284=============
# ============= Backtest 3285=============
# ============= Backtest 3287=============
# ============= Backtest 3288=============
# ============= Backtest 3289=============
# ============= Backtest 3290=============
# ============= Backtest 3293=============
# ============= Backtest 3294=============
# ============= Backtest 3297=============
# ============= Backtest 3303=============
# ============= Backtest 3306=============
# ============= Backtest 3310=============
# ============= Backtest 3313=============
# ============= Backtest 3317=============
# ============= Backtest 3322=============
# ============= Backtest 3323=============
# ============= Backtest 3324=============
# ============= Backtest 3325=============
# ============= Backtest 3332=============
# ============= Backtest 3339=============
# ============= Backtest 3354=============
# ============= Backtest 3360=============
# ============= Backtest 3362=============
# ============= Backtest 3363=============
# ============= Backtest 3372=============
# ============= Backtest 3373=============
# ============= Backtest 3374=============
# ============= Backtest 3379=============
# ============= Backtest 3388=============
# ============= Backtest 3390=============
# ============= Backtest 3402=============
# ============= Backtest 3426=============
# ============= Backtest 3434=============
# ============= Backtest 3438=============
# ============= Backtest 3441=============
# ============= Backtest 3444=============
# ============= Backtest 3455=============
# ============= Backtest 3465=============
# ============= Backtest 3466=============
# ============= Backtest 3479=============
# ============= Backtest 3483=============
# ============= Backtest 3484=============
# ============= Backtest 3489=============
# ============= Backtest 3490=============
# ============= Backtest 3491=============
# ============= Backtest 3492=============
# ============= Backtest 3498=============
# ============= Backtest 3499=============
# ============= Backtest 3508=============
# ============= Backtest 3511=============
# ============= Backtest 3512=============
# ============= Backtest 3516=============
# ============= Backtest 3520=============
# ============= Backtest 3521=============
# ============= Backtest 3522=============
# ============= Backtest 3523=============
# ============= Backtest 3526=============
# ============= Backtest 3527=============
# ============= Backtest 3529=============
# ============= Backtest 3531=============
# ============= Backtest 3537=============
# ============= Backtest 3540=============
# ============= Backtest 3541=============
# ============= Backtest 3546=============
# ============= Backtest 3548=============
# ============= Backtest 3551=============
# ============= Backtest 3552=============
# ============= Backtest 3555=============
# ============= Backtest 3556=============
# ============= Backtest 3558=============
# ============= Backtest 3564=============
# ============= Backtest 3567=============
# ============= Backtest 3570=============
# ============= Backtest 3577=============
# ============= Backtest 3580=============
# ============= Backtest 3581=============
# ============= Backtest 3587=============
# ============= Backtest 3594=============
# ============= Backtest 3597=============
# ============= Backtest 3609=============
# ============= Backtest 3611=============
# ============= Backtest 3615=============
# ============= Backtest 3623=============
# ============= Backtest 3624=============
# ============= Backtest 3625=============
# ============= Backtest 3628=============
# ============= Backtest 3629=============
# ============= Backtest 3630=============
# ============= Backtest 3631=============
# ============= Backtest 3632=============
# ============= Backtest 3642=============
# ============= Backtest 3646=============
# ============= Backtest 3652=============
# ============= Backtest 3663=============
# ============= Backtest 3664=============
# ============= Backtest 3666=============
# ...
# ============= Backtest 6130=============
# ============= Backtest 6134=============
# ============= Backtest 6138=============
# ============= Backtest 6140=============
# ============= Backtest 6143=============
# ============= Backtest 6144=============
# ============= Backtest 6146=============
# ============= Backtest 6147=============
# ============= Backtest 6148=============
# ============= Backtest 6150=============
# ============= Backtest 6151=============
# ============= Backtest 6154=============
# ============= Backtest 6156=============
# ============= Backtest 6158=============
# ============= Backtest 6160=============
# ============= Backtest 6161=============
# ============= Backtest 6163=============
# ============= Backtest 6167=============
# ============= Backtest 6169=============
# ============= Backtest 6170=============
# ============= Backtest 6171=============
# ============= Backtest 6173=============
# ============= Backtest 6174=============
# ============= Backtest 6175=============
# ============= Backtest 6179=============
# ============= Backtest 6180=============
# ============= Backtest 6182=============
# ============= Backtest 6185=============
# ============= Backtest 6186=============
# ============= Backtest 6187=============
# ============= Backtest 6188=============
# ============= Backtest 6190=============
# ============= Backtest 6194=============
# ============= Backtest 6195=============
# ============= Backtest 6198=============
# ============= Backtest 6199=============
# ============= Backtest 6203=============
# ============= Backtest 6204=============
# ============= Backtest 6207=============
# ============= Backtest 6208=============
# ============= Backtest 6210=============
# ============= Backtest 6212=============
# ============= Backtest 6217=============
# ============= Backtest 6218=============
# ============= Backtest 6219=============
# ============= Backtest 6220=============
# ============= Backtest 6221=============
# ============= Backtest 6222=============
# ============= Backtest 6223=============
# ============= Backtest 6227=============
# ============= Backtest 6228=============
# ============= Backtest 6229=============
# ============= Backtest 6231=============
# ============= Backtest 6233=============
# ============= Backtest 6234=============
# ============= Backtest 6236=============
# ============= Backtest 6237=============
# ============= Backtest 6240=============
# ============= Backtest 6241=============
# ============= Backtest 6242=============
# ============= Backtest 6244=============
# ============= Backtest 6245=============
# ============= Backtest 6246=============
# ============= Backtest 6247=============
# ============= Backtest 6248=============
# ============= Backtest 6259=============
# ============= Backtest 6261=============
# ============= Backtest 6263=============
# ============= Backtest 6264=============
# ============= Backtest 6265=============
# ============= Backtest 6266=============
# ============= Backtest 6270=============
# ============= Backtest 6274=============
# ============= Backtest 6275=============
# ============= Backtest 6276=============
# ============= Backtest 6279=============
# ============= Backtest 6284=============
# ============= Backtest 6287=============
# ============= Backtest 6290=============
# ============= Backtest 6291=============
# ============= Backtest 6292=============
# ============= Backtest 6294=============
# ============= Backtest 6404=============
# ============= Backtest 6411=============
# ============= Backtest 6417=============
# ============= Backtest 6418=============
# ============= Backtest 6419=============
# ============= Backtest 6425=============
# ============= Backtest 6426=============
# ============= Backtest 6432=============
# ============= Backtest 6435=============
# ============= Backtest 6441=============
# ============= Backtest 6446=============
# ============= Backtest 6457=============
# ============= Backtest 6461=============
# ============= Backtest 6462=============
# ============= Backtest 6465=============
# ============= Backtest 6469=============
# ============= Backtest 6470=============
# ============= Backtest 6472=============
# ============= Backtest 6482=============
# ============= Backtest 6485=============
# ============= Backtest 6486=============
# ============= Backtest 6488=============
# ============= Backtest 6492=============
# ============= Backtest 6494=============
# ============= Backtest 6496=============
# ============= Backtest 6499=============
# ============= Backtest 6506=============
# ============= Backtest 6508=============
# ============= Backtest 6509=============
# ============= Backtest 6510=============
# ============= Backtest 6512=============
# ============= Backtest 6514=============
# ============= Backtest 6516=============
# ============= Backtest 6523=============
# ============= Backtest 6527=============
# ============= Backtest 6530=============
# ============= Backtest 6532=============
# ============= Backtest 6535=============
# ============= Backtest 6538=============
# ============= Backtest 6542=============
# ============= Backtest 6547=============
# ============= Backtest 6548=============
# ============= Backtest 6556=============
# ============= Backtest 6560=============
# ============= Backtest 6561=============
# ============= Backtest 6568=============
# ============= Backtest 6569=============
# ============= Backtest 6570=============
# ============= Backtest 6574=============
# ============= Backtest 6576=============
# ============= Backtest 6577=============
# ============= Backtest 6578=============
# ============= Backtest 6588=============
# ============= Backtest 6589=============
# ============= Backtest 6590=============
# ============= Backtest 6593=============
# ============= Backtest 6594=============
# ============= Backtest 6596=============
# ============= Backtest 6603=============
# ============= Backtest 6609=============
# ============= Backtest 6612=============
# ============= Backtest 6613=============
# ============= Backtest 6615=============
# ============= Backtest 6616=============
# ============= Backtest 6624=============
# ============= Backtest 6629=============
# ============= Backtest 6640=============
# ============= Backtest 6642=============
# ============= Backtest 6643=============
# ============= Backtest 6649=============
# ============= Backtest 6651=============
# ============= Backtest 6654=============
# ============= Backtest 6661=============
# ============= Backtest 6662=============
# ============= Backtest 6664=============
# ============= Backtest 6667=============
# ============= Backtest 6679=============
# ============= Backtest 6680=============
# ============= Backtest 6683=============
# ============= Backtest 6690=============
# ============= Backtest 6697=============
# ============= Backtest 6703=============
# ============= Backtest 6712=============
# ============= Backtest 6716=============
# ============= Backtest 6727=============
# ============= Backtest 6728=============
# ============= Backtest 6732=============
# ============= Backtest 6733=============
# ============= Backtest 6747=============
# ============= Backtest 6751=============
# ============= Backtest 6752=============
# ============= Backtest 6762=============
# ============= Backtest 6767=============
# ============= Backtest 6803=============
# ============= Backtest 7402=============
# ============= Backtest 7556=============
# ============= Backtest 8024=============
# ============= Backtest 8027=============
# ============= Backtest 8032=============
# ============= Backtest 8034=============
# ============= Backtest 8038=============
# ============= Backtest 8040=============
# ============= Backtest 8042=============
# ============= Backtest 8043=============
# ============= Backtest 8044=============
# ============= Backtest 8047=============
# ============= Backtest 8048=============
# ============= Backtest 8049=============
# ============= Backtest 8050=============
# ============= Backtest 8054=============
# ============= Backtest 8059=============
# ============= Backtest 8064=============
# ============= Backtest 8066=============
# ============= Backtest 8067=============
# ============= Backtest 8068=============
# ============= Backtest 8069=============
# ============= Backtest 8071=============
# ============= Backtest 8074=============
# ============= Backtest 8076=============
# ============= Backtest 8077=============
# ============= Backtest 8080=============
# ============= Backtest 8083=============
# ============= Backtest 8084=============
# ============= Backtest 8085=============
# ============= Backtest 8086=============
# ============= Backtest 8087=============
# ============= Backtest 8088=============
# ============= Backtest 8089=============
# ============= Backtest 8091=============
# ============= Backtest 8092=============
# ============= Backtest 8093=============
# ============= Backtest 8096=============
# ============= Backtest 8097=============
# ============= Backtest 8099=============
# ============= Backtest 8107=============
# ============= Backtest 8109=============
# ============= Backtest 8111=============
# ============= Backtest 8121=============
# ============= Backtest 8147=============
# ============= Backtest 8155=============
# ============= Backtest 8171=============
# ============= Backtest 8176=============
# ============= Backtest 8182=============
# ============= Backtest 8183=============
# ============= Backtest 8234=============
# ============= Backtest 8240=============
# ============= Backtest 8255=============
# ============= Backtest 8277=============
# ============= Backtest 8279=============
# ============= Backtest 8284=============
# ============= Backtest 8289=============
# ============= Backtest 8291=============
# ============= Backtest 8299=============
# ============= Backtest 8342=============
# ============= Backtest 8349=============
# ============= Backtest 8354=============
# ============= Backtest 8358=============
# ============= Backtest 8383=============
# ============= Backtest 8390=============
# ============= Backtest 8401=============
# ============= Backtest 8403=============
# ============= Backtest 8409=============
# ============= Backtest 8410=============
# ============= Backtest 8415=============
# ============= Backtest 8416=============
# ============= Backtest 8418=============
# ============= Backtest 8420=============
# ============= Backtest 8421=============
# ============= Backtest 8423=============
# ============= Backtest 8424=============
# ============= Backtest 8426=============
# ============= Backtest 8431=============
# ============= Backtest 8432=============
# ============= Backtest 8433=============
# ============= Backtest 8435=============
# ============= Backtest 8436=============
# ============= Backtest 8437=============
# ============= Backtest 8440=============
# ============= Backtest 8444=============
# ============= Backtest 8446=============
# ============= Backtest 8450=============
# ============= Backtest 8455=============
# ============= Backtest 8472=============
# ============= Backtest 8476=============
# ============= Backtest 8477=============
# ============= Backtest 8489=============
# ============= Backtest 8905=============
# ============= Backtest 8906=============
# ============= Backtest 8908=============
# ============= Backtest 8916=============
# ============= Backtest 8917=============
# ============= Backtest 8921=============
# ============= Backtest 8923=============
# ============= Backtest 8924=============
# ============= Backtest 8927=============
# ============= Backtest 8928=============
# ============= Backtest 8929=============
# ============= Backtest 8930=============
# ============= Backtest 8931=============
# ============= Backtest 8932=============
# ============= Backtest 8933=============
# ============= Backtest 8935=============
# ============= Backtest 8936=============
# ============= Backtest 8937=============
# ============= Backtest 8938=============
# ============= Backtest 8941=============
# ============= Backtest 8942=============
# ============= Backtest 9949=============
# ============= Backtest 9950=============
# ============= Backtest 9951=============
# ============= Backtest 9960=============
# ============= Backtest 9962=============
# ============= Backtest 8916A=============
# ============= Backtest 4148=============
# ============= Backtest 6781=============
# ============= Backtest 6776=============
# ============= Backtest 2211=============
# ============= Backtest 6768=============
# ============= Backtest 3357=============
# ============= Backtest 6741=============
# ============= Backtest 2250=============
# ============= Backtest 5236=============
# ============= Backtest 1522A=============
# ============= Backtest 6684=============
# ============= Backtest 2753=============
# ============= Backtest 2348A=============
# ============= Backtest 6790=============
# ============= Backtest 6788=============
# ============= Backtest 2947=============
# ============= Backtest 4440=============
# ============= Backtest 5222=============
# ============= Backtest 2881C=============
# ============= Backtest 6761=============
# ============= Backtest 6806=============
# ============= Backtest 2945=============
# ============= Backtest 6770=============
# ============= Backtest 6792=============
# ============= Backtest 4770=============
# ============= Backtest 2883B=============
# ============= Backtest 6691=============
# ============= Backtest 3592=============
# ============= Backtest 6719=============
# ============= Backtest 2756=============
# ============= Backtest 5244=============
# ============= Backtest 6693=============
# ============= Backtest 8112A=============
# ============= Backtest 8438=============
# ============= Backtest 6829=============
# ============= Backtest 4923=============
# ============= Backtest 6763=============
# ============= Backtest 4558=============
# ============= Backtest 3349=============
# ============= Backtest 6804=============
# ============= Backtest 4768=============
# ============= Backtest 6807=============
# ============= Backtest 6721=============
# ============= Backtest 6735=============
# ============= Backtest 4583=============
# ============= Backtest 6799=============
# ============= Backtest 6585=============
# ============= Backtest 5228=============
# ============= Backtest 6546=============
# ============= Backtest 6796=============
# ============= Backtest 6550=============
# ============= Backtest 4577=============
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-3c40191e9467> in <module>
#       2 for ticker_info in bt_list:
#       3     print(f"============= Backtest {ticker_info['Ticker']}=============")
# ----> 4     results[ticker_info['Ticker']] = Backtest(RSI_MACD_VTurn, ticker_info['Ticker'], bt_period = 10)
#       5 #     break
#
# F:\SiteProject\StrategyDev\台股波段\無腦交易\BacktestBaseFunc.py in Backtest(strategy, ticker, dt, bt_period, params)
#      86         if not df: return []
#      87     if df.empty: return []
# ---> 88     return strategy(df, **params)
#      89
#
# <ipython-input-10-6ee380e78ae7> in RSI_MACD_VTurn(df, **kwargs)
#      14
#      15     df = Calc.MACD(df.fillna(method='ffill'))
# ---> 16     df = Calc.RSI(df.fillna(method='ffill'), [window])
#      17     result = []
#      18     for i, row in enumerate(df.itertuples()):
#
# F:\SiteProject\StrategyDev\台股波段\無腦交易\Calculator.py in RSI(df, windows)
#     191
#     192                 tmp_df.loc[row.Index,'RSI'] = tmp_df.loc[row.Index,'UpDiffMean'] / (tmp_df.loc[row.Index,'UpDiffMean'] + abs(tmp_df.loc[row.Index,'DnDiffMean'])) * 100
# --> 193             df[f'RSI{window}'] = round(tmp_df.RSI, 2)
#     194         return df
#     195
#
# c:\users\kevin\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'RSI'

# %% [markdown]
# # Summary

# %%
results['1101']
# Out:
# [{'EntryDate': Timestamp('2013-06-27 00:00:00'),
#   'ExitDate': Timestamp('2013-07-22 00:00:00'),
#   'EntryPrice': 35.2,
#   'ExitPrice': 38.75,
#   'EntryCommission': 50,
#   'ExitCommission': 55,
#   'EntryTax': 0,
#   'ExitTax': 116,
#   'TotalCost': 221,
#   'HoldingPeriod': 25,
#   'Net': 3329,
#   'Ret': 0.0946,
#   'MaxPriceBetweeenHolding': 38.75,
#   'MaxRetBetweeenHolding': 0.1009,
#   'MinPriceBetweeenHolding': 35.2,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2014-05-15 00:00:00'),
#   'ExitDate': Timestamp('2014-08-25 00:00:00'),
#   'EntryPrice': 44.3,
#   'ExitPrice': 49.55,
#   'EntryCommission': 63,
#   'ExitCommission': 71,
#   'EntryTax': 0,
#   'ExitTax': 149,
#   'TotalCost': 283,
#   'HoldingPeriod': 102,
#   'Net': 4967,
#   'Ret': 0.1121,
#   'MaxPriceBetweeenHolding': 49.55,
#   'MaxRetBetweeenHolding': 0.1185,
#   'MinPriceBetweeenHolding': 44.3,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2014-12-22 00:00:00'),
#   'ExitDate': Timestamp('2015-06-05 00:00:00'),
#   'EntryPrice': 42.1,
#   'ExitPrice': 38.75,
#   'EntryCommission': 60,
#   'ExitCommission': 55,
#   'EntryTax': 0,
#   'ExitTax': 116,
#   'TotalCost': 231,
#   'HoldingPeriod': 165,
#   'Net': -3581,
#   'Ret': -0.0851,
#   'MaxPriceBetweeenHolding': 42.1,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 37.65,
#   'MinRetBetweeenHolding': -0.1057},
#  {'EntryDate': Timestamp('2015-06-09 00:00:00'),
#   'ExitDate': Timestamp('2015-07-29 00:00:00'),
#   'EntryPrice': 39.65,
#   'ExitPrice': 35.1,
#   'EntryCommission': 57,
#   'ExitCommission': 50,
#   'EntryTax': 0,
#   'ExitTax': 105,
#   'TotalCost': 212,
#   'HoldingPeriod': 50,
#   'Net': -4762,
#   'Ret': -0.1201,
#   'MaxPriceBetweeenHolding': 39.65,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 34.8,
#   'MinRetBetweeenHolding': -0.1223},
#  {'EntryDate': Timestamp('2015-12-02 00:00:00'),
#   'ExitDate': Timestamp('2015-12-15 00:00:00'),
#   'EntryPrice': 30.5,
#   'ExitPrice': 27.45,
#   'EntryCommission': 43,
#   'ExitCommission': 39,
#   'EntryTax': 0,
#   'ExitTax': 82,
#   'TotalCost': 164,
#   'HoldingPeriod': 13,
#   'Net': -3214,
#   'Ret': -0.1054,
#   'MaxPriceBetweeenHolding': 30.5,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 26.9,
#   'MinRetBetweeenHolding': -0.118},
#  {'EntryDate': Timestamp('2016-12-29 00:00:00'),
#   'ExitDate': Timestamp('2017-02-13 00:00:00'),
#   'EntryPrice': 34.5,
#   'ExitPrice': 38.2,
#   'EntryCommission': 49,
#   'ExitCommission': 54,
#   'EntryTax': 0,
#   'ExitTax': 115,
#   'TotalCost': 218,
#   'HoldingPeriod': 46,
#   'Net': 3482,
#   'Ret': 0.1009,
#   'MaxPriceBetweeenHolding': 38.8,
#   'MaxRetBetweeenHolding': 0.1246,
#   'MinPriceBetweeenHolding': 34.5,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2020-03-23 00:00:00'),
#   'ExitDate': Timestamp('2020-03-26 00:00:00'),
#   'EntryPrice': 35.8,
#   'ExitPrice': 39.5,
#   'EntryCommission': 51,
#   'ExitCommission': 56,
#   'EntryTax': 0,
#   'ExitTax': 119,
#   'TotalCost': 226,
#   'HoldingPeriod': 3,
#   'Net': 3474,
#   'Ret': 0.097,
#   'MaxPriceBetweeenHolding': 39.5,
#   'MaxRetBetweeenHolding': 0.1034,
#   'MinPriceBetweeenHolding': 35.8,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2021-12-02 00:00:00'),
#   'ExitDate': Timestamp('2022-05-13 00:00:00'),
#   'EntryPrice': 46.6,
#   'ExitPrice': 40.9,
#   'EntryCommission': 66,
#   'ExitCommission': 58,
#   'EntryTax': 0,
#   'ExitTax': 123,
#   'TotalCost': 247,
#   'HoldingPeriod': 162,
#   'Net': -5947,
#   'Ret': -0.1276,
#   'MaxPriceBetweeenHolding': 46.6,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 40.8,
#   'MinRetBetweeenHolding': -0.1245}]

# %%
summary_ = []
bt_day = datetime.today()
bt_day_str = bt_day.strftime("%Y%m%d")
for ticker, result in results.items():
    total_cost = 0
#     total_pnl = 0
    total_net = 0
    trade_num = len(result)
    win_num = 0
    loss_num = 0
    hold_period = []
    rets = []
    for res in result:
        total_net += res['Net']
        total_cost += res['TotalCost']
        win_num += int(res['Net'] > 0)
        loss_num += int(res['Net'] < 0)
        hold_period.append(res['HoldingPeriod'])
        rets.append(res['Ret'])
    summary_.append({
        '代號':ticker,
        '總成本':total_cost,
        '總損益(淨)':total_net,
        '獲利次數':win_num,
        '損失次數':loss_num,
        '總交易次數':trade_num,
        '勝率%':round(win_num / trade_num*100,2) if trade_num else 0,
        '平均報酬':mean(rets),
        '平均持倉時間(日)':mean(hold_period)
    })
    if result:
        DataFrame(result).to_csv(os.path.join(output_path, f'{ticker}_{bt_day_str}.csv'), index=False)

# %%
sum_df = DataFrame(summary_)#.sort_values(['勝率%','總交易次數'], ascending=False)

# %%
sum_df['總損益(淨)'].sum()
# Out:
# -1013580

# %%
sum_df.describe()
# Out:
#                 總成本        總損益(淨)         獲利次數         損失次數        總交易次數  \
# count   1788.000000  1.788000e+03  1788.000000  1788.000000  1788.000000
# mean    1438.506711 -5.668792e+02     2.715884     2.340604     5.056488
# std     2904.856142  4.016442e+04     1.824976     1.771119     2.834484
# min        0.000000 -1.854950e+05     0.000000     0.000000     0.000000
# 25%      385.000000 -4.881000e+03     1.000000     1.000000     3.000000
# 50%      747.500000  0.000000e+00     3.000000     2.000000     5.000000
# 75%     1479.500000  3.883500e+03     4.000000     3.000000     7.000000
# max    83487.000000  1.491513e+06     9.000000    10.000000    16.000000
#
#                勝率%         平均報酬    平均持倉時間(日)
# count  1788.000000  1701.000000  1701.000000
# mean     51.249469     0.005008    69.808060
# std      27.855417     0.058970    85.709436
# min       0.000000    -0.240400     1.000000
# 25%      33.330000    -0.030400    28.000000
# 50%      50.000000     0.003525    46.142857
# 75%      66.670000     0.041833    80.000000
# max     100.000000     0.438275  1114.000000

# %%
sum_df.to_csv(os.path.join(output_path, 'Summary.csv'),index=False, encoding='utf-8-sig')

# %%
sum_df_prob_sorted = sum_df[sum_df['勝率%'] > 60]
sum_df_trade_num_sorted = sum_df[sum_df.總交易次數 >= 10]
sum_df_holding_period_sorted = sum_df[sum_df['平均持倉時間(日)'] <= sum_df['平均持倉時間(日)'].describe()['mean']]

# %%
# top_num = 100
prob_Ticker = sum_df_prob_sorted.代號 # .iloc[:top_num]
trade_num_Ticker = sum_df_trade_num_sorted.代號 # .iloc[:top_num]
holding_period_Ticker = sum_df_holding_period_sorted.代號
suitable_Ticker = list(set(prob_Ticker).intersection(trade_num_Ticker).intersection(holding_period_Ticker))

# %%
print(sum_df[sum_df.代號.isin(suitable_Ticker)].shape)
sum_df[sum_df.代號.isin(suitable_Ticker)].sort_values("勝率%", ascending=False).head(50)
# Out:
# (24, 9)
#         代號   總成本  總損益(淨)  獲利次數  損失次數  總交易次數    勝率%      平均報酬  平均持倉時間(日)
# 266   2323   583    3077     8     2     10  80.00  0.054750  52.700000
# 298   2368  1004    8546     8     2     10  80.00  0.046280  11.900000
# 323   2406  1105    6645     8     2     10  80.00  0.047940  17.500000
# 263   2316  1292   15758     8     2     10  80.00  0.068160  58.300000
# 394   2505  1140    3260     9     3     12  75.00  0.044075  37.250000
# 544   3050   822    2328     9     3     12  75.00  0.025900  30.750000
# 971   1742  1291   13159     8     3     11  72.73  0.103709  21.272727
# 605   3563  8778   68872     8     3     11  72.73  0.044464  28.727273
# 1095  3360  1075    6675     8     3     11  72.73  0.045536  15.727273
# 121   1532  1852    7848     7     3     10  70.00  0.032660  62.500000
# 1421  6016   637    2653     7     3     10  70.00  0.031340  55.700000
# 1271  4728  3129   26621     7     3     10  70.00  0.050000  38.500000
# 1090  3324  4599   68151     7     3     10  70.00  0.038660  23.300000
# 909   9914  9145   24355     7     3     10  70.00  0.022910  39.100000
# 717   5469  1450   10890     7     3     10  70.00  0.046380  55.700000
# 642   4142  1736    6964     7     3     10  70.00  0.021330  33.300000
# 1305  4979  2297    4703     8     4     12  66.67  0.006508  16.416667
# 638   4108  2133    5217     9     5     14  64.29  0.002121  42.357143
# 452   2731  7599   29301     9     5     14  64.29  0.022250  50.428571
# 1044  3176  4149   18401     7     4     11  63.64  0.041191  24.636364
# 1244  4529  1430    5870     7     4     11  63.64  0.015591  35.818182
# 1297  4946  2997    1053     7     4     11  63.64  0.035036  39.181818
# 1504  6246   973    9667     7     4     11  63.64  0.053409  23.545455
# 1727  8937   928    2822     7     4     11  63.64  0.023464  67.454545

# %%
sum_df[sum_df.代號.isin(suitable_Ticker)].sort_values("勝率%", ascending=False).to_csv(os.path.join(output_path, 'Summary_prob_holding_tradenum.csv'), index=False)

# %%
sum_df[sum_df.代號.isin(suitable_Ticker)].sort_values("勝率%", ascending=False).sum()#describe()
# Out:
# 代號           2.323237e+95
# 總成本          6.214400e+04
# 總損益(淨)       3.528360e+05
# 獲利次數         1.840000e+02
# 損失次數         7.800000e+01
# 總交易次數        2.620000e+02
# 勝率%          1.691640e+03
# 平均報酬         9.236648e-01
# 平均持倉時間(日)    8.820660e+02
# dtype: float64

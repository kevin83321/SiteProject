# %%
import warnings
warnings.filterwarnings("ignore")

from datetime import datetime, timedelta
from pandas import DataFrame, concat, date_range, ExcelWriter, to_datetime, read_csv
import os
from numpy import isnan, inf, mean
import time
import json
from Calculator import Calculator

from utils import getSchema, changedType
from BacktestBaseFunc import *


parent = os.path.dirname(os.path.abspath("__file__"))
output_path = os.path.join(parent, "Output", "HundredBreakOutL")
if not os.path.isdir(output_path):
    os.makedirs(output_path)

# %%
bt_list = StockList()

# %%
results = {}
files = [x for x in os.listdir(os.path.join(output_path)) if 'Summary' not in x and '20220615' in x]
for f_name in files:
    results[f_name.split("_")[0]] = read_csv(os.path.join(output_path, f_name))
# for ticker_info in bt_list:
#     print(f"============= Backtest {ticker_info['Ticker']}=============")
#     results[ticker_info["Ticker"]] = read_csv(os.path.join(output_path, f'{ticker_info["Ticker"]}_{bt_day_str}.csv'))

# %%
results['2330']
# Out:
#      EntryDate    ExitDate  EntryPrice  ExitPrice  EntryCommission  \
# 0   2002-11-12  2002-11-26       45.50      51.50               65
# 1   2002-11-28  2002-12-20       51.50      45.90               73
# 2   2002-12-24  2003-01-14       44.30      51.00               63
# 3   2003-01-16  2003-02-07       50.50      41.30               72
# 4   2003-02-11  2003-02-24       41.30      45.20               59
# 5   2003-02-26  2003-03-20       43.20      49.00               62
# 6   2003-03-24  2003-03-28       48.90      44.70               70
# 7   2003-04-01  2003-04-08       41.50      46.00               59
# 8   2003-04-10  2003-05-14       44.70      49.00               64
# 9   2003-05-16  2003-06-02       49.80      55.00               71
# 10  2003-06-05  2003-07-04       56.50      61.50               81
# 11  2003-07-08  2003-09-08       62.00      68.50               88
# 12  2003-09-10  2003-12-02       70.00      65.00              100
# 13  2003-12-04  2003-12-18       66.00      59.00               94
# 14  2003-12-22  2004-01-12       60.50      67.50               86
# 15  2004-01-14  2004-03-17       67.00      61.00               95
# 16  2004-03-19  2004-03-24       62.00      58.50               88
# 17  2004-03-26  2004-05-18       59.00      52.00               84
# 18  2004-05-20  2004-06-15       54.00      43.30               77
# 19  2004-06-17  2004-07-01       43.30      48.50               62
# 20  2004-07-05  2004-11-18       45.00      50.00               64
# 21  2004-11-22  2005-02-03       49.00      53.50               70
# 22  2005-02-15  2005-10-21       54.50      48.70               78
# 23  2005-10-25  2005-11-14       51.50      56.60               73
# 24  2005-11-16  2005-12-07       57.00      62.50               81
# 25  2005-12-09  2006-01-10       61.10      68.00               87
# 26  2006-01-12  2006-03-09       66.50      59.00               95
# 27  2006-03-13  2006-04-10       61.40      66.80               87
# 28  2006-04-12  2006-06-09       65.10      58.00               93
# 29  2006-06-13  2006-10-14       57.00      63.50               81
# 30  2006-10-17  2007-01-17       64.00      69.90               91
# 31  2007-01-19  2007-08-02       69.50      62.00               99
# 32  2007-08-06  2008-01-08       62.50      55.80               89
# 33  2008-01-10  2008-01-23       57.00      51.00               81
# 34  2008-01-25  2008-02-12       55.00      59.70               78
# 35  2008-02-14  2008-03-25       60.20      67.40               86
# 36  2008-03-27  2008-07-04       65.00      59.30               93
# 50              79         0      166        319             20   3581
# 51              86         0      181        345             48   5055
# 52              95         0      200        381            455   6219
# 53             108         0      226        432             42   6568
# 54             100         0      210        420             54  -7420
# 55             105         0      221        421             43   6479
# 56              94         0      198        398             96  -8798
# 57             102         0      214        409             40   5891
# 58             111         0      234        446            132   6654
#
#        Ret  MaxPriceBetweeenHolding  MaxRetBetweeenHolding  \
# 0   0.1255                    52.00                 0.1429
# 1  -0.1141                    51.50                 0.0000
# 2   0.1447                    50.50                 0.1400
# 3  -0.1872                    50.50                 0.0000
# 4   0.0882                    45.90                 0.1114
# 5   0.1278                    48.20                 0.1157
# 6  -0.0914                    48.90                 0.0000
# 7   0.1021                    46.50                 0.1205
# 8   0.0899                    49.80                 0.1141
# 9   0.0981                    55.00                 0.1044
# 10  0.0822                    63.00                 0.1150
# 11  0.0985                    69.00                 0.1129
# 12 -0.0770                    70.00                 0.0000
# 13 -0.1114                    66.00                 0.0000
# 14  0.1094                    67.50                 0.1157
# 15 -0.0950                    67.00                 0.0000
# 16 -0.0620                    62.00                 0.0000
# 17 -0.1240                    59.00                 0.0000
# 18 -0.2031                    54.00                 0.0000
# 19  0.1137                    48.40                 0.1178
# 20  0.1048                    49.70                 0.1044
# 21  0.0856                    54.00                 0.1020
# 22 -0.1118                    54.50                 0.0000
# 23  0.0927                    57.00                 0.1068
# 24  0.0902                    62.70                 0.1000
# 25  0.1066                    68.40                 0.1195
# 26 -0.1181                    66.50                 0.0000
# 27  0.0817                    67.80                 0.1042
# 28 -0.1144                    65.10                 0.0000
# 29  0.1077                    63.40                 0.1123
# 30  0.0859                    70.50                 0.1016
# 31 -0.1133                    69.50                 0.0000
# 32 -0.1126                    62.50                 0.0000
# 33 -0.1106                    57.00                 0.0000
# 34  0.0792                    62.20                 0.1309
# 35  0.1132                    69.30                 0.1512
# 36 -0.0932                    65.00                 0.0000
# 37 -0.0723                    59.90                 0.0000
# 38 -0.1265                    59.40                 0.0000
# 39 -0.1325                    55.00                 0.0000
# 40 -0.1458                    46.25                 0.0000
# 41  0.1576                    42.45                 0.1427
# 42 -0.1306                    49.50                 0.0000
# 43 -0.1213                    43.10                 0.0000
# 44  0.1172                    40.30                 0.1071
# 45  0.0704                    44.90                 0.1281
# 46  0.0868                    47.40                 0.1023
# 47  0.1119                    52.40                 0.1269
# 48  0.1437                    59.00                 0.1217
# 49 -0.1184                    57.50                 0.0000
# 50  0.0694                    57.30                 0.1105
# 51  0.0919                    61.00                 0.1091
# 52  0.1033                    66.40                 0.1030
# 53  0.0959                    75.90                 0.1080
# 54 -0.0964                    77.00                 0.0000
# 55  0.0970                    73.70                 0.1033
# 56 -0.1183                    74.40                 0.0000
# 57  0.0905                    72.00                 0.1060
# 58  0.0937                    79.50                 0.1197
#
#     MinPriceBetweeenHolding  MinRetBetweeenHolding
# 0                     45.50                 0.0000
# 1                     45.00                -0.1262
# 2                     44.30                 0.0000
# 3                     44.40                -0.1208
# 4                     41.30                 0.0000
# 5                     43.20                 0.0000
# 6                     44.00                -0.1002
# 7                     41.50                 0.0000
# 8                     44.70                 0.0000
# 9                     49.80                 0.0000
# 10                    56.50                 0.0000
# 11                    62.00                 0.0000
# 12                    62.50                -0.1071
# 13                    59.00                -0.1061
# 14                    60.50                 0.0000
# 15                    60.00                -0.1045
# 16                    55.00                -0.1129
# 17                    51.50                -0.1271
# 18                    43.20                -0.2000
# 19                    43.30                 0.0000
# 20                    45.00                 0.0000
# 21                    49.00                 0.0000
# 22                    49.00                -0.1009
# 23                    51.50                 0.0000
# 24                    57.00                 0.0000
# 25                    61.10                 0.0000
# 26                    58.90                -0.1143
# 27                    61.40                 0.0000
# 28                    55.90                -0.1413
# 29                    57.00                 0.0000
# 30                    64.00                 0.0000
# 31                    61.30                -0.1180
# 32                    55.80                -0.1072
# 33                    49.60                -0.1298
# 34                    55.00                 0.0000
# 35                    60.20                 0.0000
# 36                    57.50                -0.1154
# 37                    53.20                -0.1119
# 38                    53.00                -0.1077
# 39                    49.00                -0.1091
# 40                    41.15                -0.1103
# 41                    37.15                 0.0000
# 42                    41.55                -0.1606
# 43                    38.30                -0.1114
# 44                    36.40                 0.0000
# 45                    39.80                 0.0000
# 46                    43.00                 0.0000
# 47                    46.50                 0.0000
# 48                    52.60                 0.0000
# 49                    51.70                -0.1009
# 50                    51.60                 0.0000
# 51                    55.00                 0.0000
# 52                    60.20                 0.0000
# 53                    68.50                 0.0000
# 54                    69.10                -0.1026
# 55                    66.80                 0.0000
# 56                    66.00                -0.1129
# 57                    65.10                 0.0000
# 58                    71.00                 0.0000

# %% [markdown]
# # Plot KBar

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
def PlotKBar(ticker, df, bt_result, trade_num=0, ma_len=5, ma_len2=10, ma_len3 = 20, predict_start:datetime=None):
#     df = ReadDailyDataLonger(ticker, date)
    show_trade = bt_result.iloc[trade_num]
    trade_end = to_datetime(show_trade.ExitDate)
    trade_start = to_datetime(show_trade.EntryDate)
    end_date = trade_end
    start_date = end_date+timedelta(-250)
    df.Date = to_datetime(df.Date)
    df = df[(df.Date<=end_date) & (df.Date>=start_date)]
    df['MA'] = df.Close.rolling(ma_len).mean()
    df['MA2'] = df.Close.rolling(ma_len2).mean()
    df['MA3'] = df.Close.rolling(ma_len3).mean()
    df['Adj V'] = df.Volume.apply(lambda x: int(float(x)/1000))
    
    fig = make_subplots(rows=2, cols=1, shared_xaxes=True, 
                        vertical_spacing=0.3, 
                        subplot_titles=(f'OHLC and MA of {ticker} From {start_date} to {end_date}', 'Volume'), 
                        row_width=[0.2, 0.7])
    
    fig.add_trace(go.Candlestick(x=df.Date,
                    open=df.Open,
                    high=df.High,
                    low=df.Low,
                    close=df.Close,
                    name="CandleStick"), row=1,col=1)
    fig.add_trace(
        go.Scatter(
            x=df.Date,
            y=df.MA,
            name=f"MA{ma_len}"
        ), row=1,col=1)
    fig.add_trace(
        go.Scatter(
            x=df.Date,
            y=df.MA2,
            name=f"MA{ma_len2}"
        ), row=1,col=1)
    fig.add_trace(
        go.Scatter(
            x=df.Date,
            y=df.MA3,
            name=f"MA{ma_len3}"
        ), row=1,col=1)
#     if predict_start:
    fig.add_trace(
    go.Scatter(
        x=[trade_start]*100,
        y=list(np.linspace(df.Low.min(),df.High.max(), 100)),#[],
        name=f"Trade Entry Date {predict_start.strftime('%Y-%m-%d')}",
        opacity=.9,
        line = dict(color='royalred', width=1, dash='dash')
#             color
    ), row=1,col=1)

    fig.add_trace(
    go.Scatter(
        x=[trade_end]*100,
        y=list(np.linspace(df.Low.min(),df.High.max(), 100)),#[],
        name=f"Trade Exit Date {predict_start.strftime('%Y-%m-%d')}",
        opacity=.9,
        line = dict(color='royalblue', width=1, dash='dash')
#             color
    ), row=1,col=1)
    
    fig.add_trace(go.Bar(x=df.Date, y=df['Adj V'], showlegend=False, name = "Volume"), row=2, col=1)
    fig.add_trace(go.Scatter(x=df.Date, y=df['Adj V'].rolling(5).mean(), showlegend=False, name="VMA5"), row=2, col=1)
    fig.add_trace(go.Scatter(x=df.Date, y=df['Adj V'].rolling(20).mean(), showlegend=False, name="VMA20"), row=2, col=1)
    test_df = df.copy(deep=True)
#     test_df.Date = pd.to_datetime(test_df.Date)
    begin_date, end_date = [start_date, end_date]
    test_df = test_df.set_index("Date").reindex(date_range(begin_date, end_date, freq='D'))
    datebreaks = test_df['Close'][test_df['Close'].isnull()].index
#     fig.update_layout(shapes=[
#         dict(
#             type= 'line',
#             yref= 'paper', y0= [df.Low.min()], y1= [df.High.max()],
#             xref= 'x', x0= [predict_start], x1= [predict_start]
#     )])
    fig.update_xaxes(rangebreaks=[dict(values=datebreaks)])
    fig.show()

# %%
ticker = '2330'
dt = datetime(2022,6,15)
bt_period = 20
df = StockInterDay(dt+timedelta(-365*bt_period), dt, ticker)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-6eb3d8bf2007> in <module>
#       4 df = StockInterDay(dt+timedelta(-365*bt_period), dt, ticker)
#       5
# ----> 6 PlotKBar(ticker, df, results[ticker], ma_len=5, ma_len2=10, ma_len3 = 20)
#
# <ipython-input-11-d7b677e43c5b> in PlotKBar(ticker, df, bt_result, ma_len, ma_len2, ma_len3, predict_start)
#       5     df['MA3'] = df.Close.rolling(ma_len3).mean()
#       6     df['Adj V'] = df.Volume.apply(lambda x: int(float(x)/1000))
# ----> 7     df.Date = pd.to_datetime(df.Date)
#       8     start_date = df.Date.iloc[0]
#       9     end_date = df.Date.iloc[-1]
#
# NameError: name 'pd' is not defined

# %%
results[ticker].iloc[0].ExitDate
# Out:
# '2002-11-26'

# %%
PlotKBar(ticker, df, results[ticker], trade_num=0, ma_len=5, ma_len2=10, ma_len3 = 20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-dad09026b589> in <module>
# ----> 1 PlotKBar(ticker, df, results[ticker], trade_num=0, ma_len=5, ma_len2=10, ma_len3 = 20)
#
# <ipython-input-25-2ea1ae34b142> in PlotKBar(ticker, df, bt_result, trade_num, ma_len, ma_len2, ma_len3, predict_start)
#       3     show_trade = bt_result.iloc[trade_num]
#       4     trade_end = to_datetime(show_trade.ExitDate)
# ----> 5     trade_start = to_datetime(show_trade.StartDate)
#       6     end_date = to_datetime(show_trade.ExitDate)
#       7     start_date = end_date+timedelta(-250)
#
# c:\users\kevin\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'StartDate'

# %%
import warnings
warnings.filterwarnings("ignore")

from datetime import datetime, timedelta
from pandas import DataFrame, concat, date_range, ExcelWriter, to_datetime
import os
from numpy import isnan, inf, mean
import time
import json
from Calculator import Calculator as Calc

from utils import getSchema, changedType
from BacktestBaseFunc import *

parent = os.path.dirname(os.path.abspath("__file__"))
output_path = os.path.join(parent, "Output", "Mom_MA_EMA_RSI")
if not os.path.isdir(output_path):
    os.makedirs(output_path)
# Out:
# c:\users\kevin\appdata\local\programs\python\python37\lib\site-packages\mpl_finance.py:22: DeprecationWarning:
#
#   =================================================================
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
#   =================================================================
#
#   category=DeprecationWarning)

# %%
def Mom_MA_EMA_RSI(df:DataFrame, **kwargs):
    entry_date = None
    exit_date = None
    entry_price = 0
    exit_price = 0
    max_price = 0
    min_price = inf
    sig = pos = 0
    window = int(kwargs.get('window', 14))
#     take_profit = float(kwargs.get('take_profit', .1))
#     stop_loss = float(kwargs.get('stop_loss', .1))
    
#     df = Calc.MACD(df.fillna(method='ffill'))
    df = Calc.MA(df.fillna(method='ffill'),[10])
    df = Calc.EMA(df.fillna(method='ffill'),[10])
    df = Calc.RSI(df.fillna(method='ffill'), [window])
    result = []
    for i, row in enumerate(df.itertuples()):
        if not i: continue
        if isnan(getattr(row,f"MA{10}")) or isnan(getattr(row,f"RSI{window}")): continue
        # Check Signal without pos
        if not sig and not pos:
            rsi = getattr(row,f"RSI{window}")
            # 多單條件
            g_condi = row.MA10 > row.EMA10
            long_rsi = rsi > 50 and rsi < 70
            red_bar = row.Close > row.Open and row.Low > max(row.MA10, row.EMA10)
            # 空單條件
            d_condi = row.MA10 < row.EMA10
            short_rsi = rsi < 50 and rsi > 30
            green_bar = row.Close < row.Open and row.High < min(row.MA10, row.EMA10)
            if g_condi and long_rsi and red_bar:
                sig = 1
            elif d_condi and short_rsi and green_bar:
                sig = -1
            if sig:
                sl = row.MA10
                tp = round(abs(row.Close - row.MA10) * 1.5, 2) * sig + row.Close
            pos, sig = sig, 0
            max_price = min_price = entry_price = row.Close
            entry_date = row.Date
        # Check Signal with pos
        elif not sig and pos:
            max_price = max(row.High, entry_price)
            min_price = min(row.Low, entry_price)
#             print(f"stoploss : {round(sl, 2)}, takeprofit : {round(tp, 2)}")
#             print(row.Open, row.High, row.Low, row.Close, pos)
            if pos > 0:
                if row.High >= tp:
                    exit_price = tp
                elif row.Low <= sl:
                    exit_price = sl
            else:
                if row.Low <= tp:
                    exit_price = tp
                elif row.High >= sl:
                    exit_price = sl
            if exit_price:
                exit_price = round(exit_price, 2)
                sig = -pos
        # Exit Market
#         elif sig and pos:
            if sig:
                if not row.Volume or isnan(row.Close): continue
    #             if row.Ticker == '1538':print(row)
    #             exit_price = row.Open
                exit_date = row.Date
#                 print(entry_date, exit_date, entry_price, exit_price, max_price, min_price, pos)
                res = CreateTradeLog(entry_date, exit_date, entry_price, exit_price, max_price, min_price, pos)
#                 print(res)
                result.append(res)
                entry_date = None
                exit_date = None
                entry_price = 0
                exit_price = 0
                max_price = 0
                min_price = inf
                sig = pos = 0
                tp = sl = 0
        if i == df.shape[0]-1 and pos:
            exit_price = row.Close
            if not row.Volume or isnan(row.Open):
                exit_price = df.fillna(method='ffill').Close.iloc[-1]
            
            exit_date = row.Date
            res = CreateTradeLog(entry_date, exit_date, entry_price, exit_price, max_price, min_price, pos)
            result.append(res)
            entry_date = None
            exit_date = None
            entry_price = 0
            exit_price = 0
            max_price = 0
            min_price = inf
            sig = pos = 0
            tp = sl = 0
#     print()
            
    return result

# %%
bt_list = StockList()

# %%
results = {}
for ticker_info in bt_list:
    print(f"============= Backtest {ticker_info['Ticker']}=============")
    results[ticker_info['Ticker']] = Backtest(Mom_MA_EMA_RSI, ticker_info['Ticker'], bt_period = 20)
#     break
# Out:
# ============= Backtest 1101=============
# ============= Backtest 1102=============
# ============= Backtest 1103=============
# ============= Backtest 1104=============
# ============= Backtest 1108=============
# ============= Backtest 1109=============
# ============= Backtest 1110=============
# ============= Backtest 1201=============
# ============= Backtest 1203=============
# ============= Backtest 1210=============
# ============= Backtest 1213=============
# ============= Backtest 1215=============
# ============= Backtest 1216=============
# ============= Backtest 1217=============
# ============= Backtest 1218=============
# ============= Backtest 1219=============
# ============= Backtest 1220=============
# ============= Backtest 1225=============
# ============= Backtest 1227=============
# ============= Backtest 1229=============
# ============= Backtest 1231=============
# ============= Backtest 1232=============
# ============= Backtest 1233=============
# ============= Backtest 1234=============
# ============= Backtest 1235=============
# ============= Backtest 1236=============
# ============= Backtest 1256=============
# ============= Backtest 1301=============
# ============= Backtest 1303=============
# ============= Backtest 1304=============
# ============= Backtest 1305=============
# ============= Backtest 1307=============
# ============= Backtest 1308=============
# ============= Backtest 1309=============
# ============= Backtest 1310=============
# ============= Backtest 1312=============
# ============= Backtest 1313=============
# ============= Backtest 1314=============
# ============= Backtest 1315=============
# ============= Backtest 1316=============
# ============= Backtest 1319=============
# ============= Backtest 1321=============
# ============= Backtest 1323=============
# ============= Backtest 1324=============
# ============= Backtest 1325=============
# ============= Backtest 1326=============
# ============= Backtest 1337=============
# ============= Backtest 1338=============
# ============= Backtest 1339=============
# ============= Backtest 1340=============
# ============= Backtest 1341=============
# ============= Backtest 1342=============
# ============= Backtest 1402=============
# ============= Backtest 1409=============
# ============= Backtest 1410=============
# ============= Backtest 1413=============
# ============= Backtest 1414=============
# ============= Backtest 1416=============
# ============= Backtest 1417=============
# ============= Backtest 1418=============
# ============= Backtest 1419=============
# ============= Backtest 1423=============
# ============= Backtest 1432=============
# ============= Backtest 1434=============
# ============= Backtest 1435=============
# ============= Backtest 1436=============
# ============= Backtest 1437=============
# ============= Backtest 1438=============
# ============= Backtest 1439=============
# ============= Backtest 1440=============
# ============= Backtest 1441=============
# ============= Backtest 1442=============
# ============= Backtest 1443=============
# ============= Backtest 1444=============
# ============= Backtest 1445=============
# ============= Backtest 1446=============
# ============= Backtest 1447=============
# ============= Backtest 1449=============
# ============= Backtest 1451=============
# ============= Backtest 1452=============
# ============= Backtest 1453=============
# ============= Backtest 1454=============
# ============= Backtest 1455=============
# ============= Backtest 1456=============
# ============= Backtest 1457=============
# ============= Backtest 1459=============
# ============= Backtest 1460=============
# ============= Backtest 1463=============
# ============= Backtest 1464=============
# ============= Backtest 1465=============
# ============= Backtest 1466=============
# ============= Backtest 1467=============
# ============= Backtest 1468=============
# ============= Backtest 1470=============
# ============= Backtest 1471=============
# ============= Backtest 1472=============
# ============= Backtest 1473=============
# ============= Backtest 1474=============
# ============= Backtest 1475=============
# ============= Backtest 1476=============
# ============= Backtest 1477=============
# ============= Backtest 1503=============
# ============= Backtest 1504=============
# ============= Backtest 1506=============
# ============= Backtest 1512=============
# ============= Backtest 1513=============
# ============= Backtest 1514=============
# ============= Backtest 1515=============
# ============= Backtest 1516=============
# ============= Backtest 1517=============
# ============= Backtest 1519=============
# ============= Backtest 1521=============
# ============= Backtest 1522=============
# ============= Backtest 1524=============
# ============= Backtest 1525=============
# ============= Backtest 1526=============
# ============= Backtest 1527=============
# ============= Backtest 1528=============
# ============= Backtest 1529=============
# ============= Backtest 1530=============
# ============= Backtest 1531=============
# ============= Backtest 1532=============
# ============= Backtest 1533=============
# ============= Backtest 1535=============
# ============= Backtest 1536=============
# ============= Backtest 1537=============
# ============= Backtest 1538=============
# ============= Backtest 1539=============
# ============= Backtest 1540=============
# ============= Backtest 1541=============
# ============= Backtest 1558=============
# ============= Backtest 1560=============
# ============= Backtest 1568=============
# ============= Backtest 1582=============
# ============= Backtest 1583=============
# ============= Backtest 1587=============
# ============= Backtest 1589=============
# ============= Backtest 1590=============
# ============= Backtest 1597=============
# ============= Backtest 1598=============
# ============= Backtest 1603=============
# ============= Backtest 1604=============
# ============= Backtest 1605=============
# ============= Backtest 1608=============
# ============= Backtest 1609=============
# ============= Backtest 1611=============
# ============= Backtest 1612=============
# ============= Backtest 1614=============
# ============= Backtest 1615=============
# ============= Backtest 1616=============
# ============= Backtest 1617=============
# ============= Backtest 1618=============
# ============= Backtest 1626=============
# ============= Backtest 1701=============
# ============= Backtest 1702=============
# ============= Backtest 1707=============
# ============= Backtest 1708=============
# ============= Backtest 1709=============
# ============= Backtest 1710=============
# ============= Backtest 1711=============
# ============= Backtest 1712=============
# ============= Backtest 1713=============
# ============= Backtest 1714=============
# ============= Backtest 1717=============
# ============= Backtest 1718=============
# ============= Backtest 1720=============
# ============= Backtest 1721=============
# ============= Backtest 1722=============
# ============= Backtest 1723=============
# ============= Backtest 1725=============
# ============= Backtest 1726=============
# ============= Backtest 1727=============
# ============= Backtest 1730=============
# ============= Backtest 1731=============
# ============= Backtest 1732=============
# ============= Backtest 1733=============
# ============= Backtest 1734=============
# ============= Backtest 1735=============
# ============= Backtest 1736=============
# ============= Backtest 1737=============
# ============= Backtest 1760=============
# ============= Backtest 1762=============
# ============= Backtest 1773=============
# ============= Backtest 1776=============
# ============= Backtest 1783=============
# ============= Backtest 1786=============
# ============= Backtest 1789=============
# ============= Backtest 1795=============
# ============= Backtest 1802=============
# ============= Backtest 1805=============
# ============= Backtest 1806=============
# ============= Backtest 1808=============
# ============= Backtest 1809=============
# ============= Backtest 1810=============
# ============= Backtest 1817=============
# ============= Backtest 1903=============
# ============= Backtest 1904=============
# ============= Backtest 1905=============
# ============= Backtest 1906=============
# ============= Backtest 1907=============
# ============= Backtest 1909=============
# ============= Backtest 2002=============
# ============= Backtest 2006=============
# ============= Backtest 2007=============
# ============= Backtest 2008=============
# ============= Backtest 2009=============
# ============= Backtest 2010=============
# ============= Backtest 2012=============
# ============= Backtest 2013=============
# ============= Backtest 2014=============
# ============= Backtest 2015=============
# ============= Backtest 2017=============
# ============= Backtest 2020=============
# ============= Backtest 2022=============
# ============= Backtest 2023=============
# ============= Backtest 2024=============
# ============= Backtest 2025=============
# ============= Backtest 2027=============
# ============= Backtest 2028=============
# ============= Backtest 2029=============
# ============= Backtest 2030=============
# ============= Backtest 2031=============
# ============= Backtest 2032=============
# ============= Backtest 2033=============
# ============= Backtest 2034=============
# ============= Backtest 2038=============
# ============= Backtest 2049=============
# ============= Backtest 2059=============
# ============= Backtest 2062=============
# ============= Backtest 2069=============
# ============= Backtest 2101=============
# ============= Backtest 2102=============
# ============= Backtest 2103=============
# ============= Backtest 2104=============
# ============= Backtest 2105=============
# ============= Backtest 2106=============
# ============= Backtest 2107=============
# ============= Backtest 2108=============
# ============= Backtest 2109=============
# ============= Backtest 2114=============
# ============= Backtest 2115=============
# ============= Backtest 2201=============
# ============= Backtest 2204=============
# ============= Backtest 2206=============
# ============= Backtest 2207=============
# ============= Backtest 2208=============
# ============= Backtest 2227=============
# ============= Backtest 2228=============
# ============= Backtest 2231=============
# ============= Backtest 2233=============
# ============= Backtest 2236=============
# ============= Backtest 2239=============
# ============= Backtest 2241=============
# ============= Backtest 2243=============
# ============= Backtest 2247=============
# ============= Backtest 2301=============
# ============= Backtest 2302=============
# ============= Backtest 2303=============
# ============= Backtest 2305=============
# ============= Backtest 2308=============
# ============= Backtest 2312=============
# ============= Backtest 2313=============
# ============= Backtest 2314=============
# ============= Backtest 2316=============
# ============= Backtest 2317=============
# ============= Backtest 2321=============
# ============= Backtest 2323=============
# ============= Backtest 2324=============
# ============= Backtest 2327=============
# ============= Backtest 2328=============
# ============= Backtest 2329=============
# ============= Backtest 2330=============
# ============= Backtest 2331=============
# ============= Backtest 2332=============
# ============= Backtest 2337=============
# ============= Backtest 2338=============
# ============= Backtest 2340=============
# ============= Backtest 2342=============
# ============= Backtest 2344=============
# ============= Backtest 2345=============
# ============= Backtest 2347=============
# ============= Backtest 2348=============
# ============= Backtest 2349=============
# ============= Backtest 2351=============
# ============= Backtest 2352=============
# ============= Backtest 2353=============
# ============= Backtest 2354=============
# ============= Backtest 2355=============
# ============= Backtest 2356=============
# ============= Backtest 2357=============
# ============= Backtest 2358=============
# ============= Backtest 2359=============
# ============= Backtest 2360=============
# ============= Backtest 2362=============
# ============= Backtest 2363=============
# ============= Backtest 2364=============
# ============= Backtest 2365=============
# ============= Backtest 2367=============
# ============= Backtest 2368=============
# ============= Backtest 2369=============
# ============= Backtest 2371=============
# ============= Backtest 2373=============
# ============= Backtest 2374=============
# ============= Backtest 2375=============
# ============= Backtest 2376=============
# ============= Backtest 2377=============
# ============= Backtest 2379=============
# ============= Backtest 2380=============
# ============= Backtest 2382=============
# ============= Backtest 2383=============
# ============= Backtest 2385=============
# ============= Backtest 2387=============
# ============= Backtest 2388=============
# ============= Backtest 2390=============
# ============= Backtest 2392=============
# ============= Backtest 2393=============
# ============= Backtest 2395=============
# ============= Backtest 2397=============
# ============= Backtest 2399=============
# ============= Backtest 2401=============
# ============= Backtest 2402=============
# ============= Backtest 2404=============
# ============= Backtest 2405=============
# ============= Backtest 2406=============
# ============= Backtest 2408=============
# ============= Backtest 2409=============
# ============= Backtest 2412=============
# ============= Backtest 2413=============
# ============= Backtest 2414=============
# ============= Backtest 2415=============
# ============= Backtest 2417=============
# ============= Backtest 2419=============
# ============= Backtest 2420=============
# ============= Backtest 2421=============
# ============= Backtest 2423=============
# ============= Backtest 2424=============
# ============= Backtest 2425=============
# ============= Backtest 2426=============
# ============= Backtest 2427=============
# ============= Backtest 2428=============
# ============= Backtest 2429=============
# ============= Backtest 2430=============
# ============= Backtest 2431=============
# ============= Backtest 2433=============
# ============= Backtest 2434=============
# ============= Backtest 2436=============
# ============= Backtest 2438=============
# ============= Backtest 2439=============
# ============= Backtest 2440=============
# ============= Backtest 2441=============
# ============= Backtest 2442=============
# ============= Backtest 2443=============
# ============= Backtest 2444=============
# ============= Backtest 2449=============
# ============= Backtest 2450=============
# ============= Backtest 2451=============
# ============= Backtest 2453=============
# ============= Backtest 2454=============
# ============= Backtest 2455=============
# ============= Backtest 2457=============
# ============= Backtest 2458=============
# ============= Backtest 2459=============
# ============= Backtest 2460=============
# ============= Backtest 2461=============
# ============= Backtest 2462=============
# ============= Backtest 2464=============
# ============= Backtest 2465=============
# ============= Backtest 2466=============
# ============= Backtest 2467=============
# ============= Backtest 2468=============
# ============= Backtest 2471=============
# ============= Backtest 2472=============
# ============= Backtest 2474=============
# ============= Backtest 2476=============
# ============= Backtest 2477=============
# ============= Backtest 2478=============
# ============= Backtest 2480=============
# ============= Backtest 2481=============
# ============= Backtest 2482=============
# ============= Backtest 2483=============
# ============= Backtest 2484=============
# ============= Backtest 2485=============
# ============= Backtest 2486=============
# ============= Backtest 2488=============
# ============= Backtest 2489=============
# ============= Backtest 2491=============
# ============= Backtest 2492=============
# ============= Backtest 2493=============
# ============= Backtest 2495=============
# ============= Backtest 2496=============
# ============= Backtest 2497=============
# ============= Backtest 2498=============
# ============= Backtest 2501=============
# ============= Backtest 2504=============
# ============= Backtest 2505=============
# ============= Backtest 2506=============
# ============= Backtest 2509=============
# ============= Backtest 2511=============
# ============= Backtest 2514=============
# ============= Backtest 2515=============
# ============= Backtest 2516=============
# ============= Backtest 2520=============
# ============= Backtest 2524=============
# ============= Backtest 2527=============
# ============= Backtest 2528=============
# ============= Backtest 2530=============
# ============= Backtest 2534=============
# ============= Backtest 2535=============
# ============= Backtest 2536=============
# ============= Backtest 2537=============
# ============= Backtest 2538=============
# ============= Backtest 2539=============
# ============= Backtest 2540=============
# ============= Backtest 2542=============
# ============= Backtest 2543=============
# ============= Backtest 2545=============
# ============= Backtest 2546=============
# ============= Backtest 2547=============
# ============= Backtest 2548=============
# ============= Backtest 2597=============
# ============= Backtest 2601=============
# ============= Backtest 2603=============
# ============= Backtest 2605=============
# ============= Backtest 2606=============
# ============= Backtest 2607=============
# ============= Backtest 2608=============
# ============= Backtest 2609=============
# ============= Backtest 2610=============
# ============= Backtest 2611=============
# ============= Backtest 2612=============
# ============= Backtest 2613=============
# ============= Backtest 2614=============
# ============= Backtest 2615=============
# ============= Backtest 2616=============
# ============= Backtest 2617=============
# ============= Backtest 2618=============
# ============= Backtest 2630=============
# ============= Backtest 2633=============
# ============= Backtest 2634=============
# ============= Backtest 2636=============
# ============= Backtest 2637=============
# ============= Backtest 2642=============
# ============= Backtest 2701=============
# ============= Backtest 2702=============
# ============= Backtest 2704=============
# ============= Backtest 2705=============
# ============= Backtest 2706=============
# ============= Backtest 2707=============
# ============= Backtest 2712=============
# ============= Backtest 2722=============
# ============= Backtest 2723=============
# ============= Backtest 2727=============
# ============= Backtest 2731=============
# ============= Backtest 2739=============
# ============= Backtest 2748=============
# ============= Backtest 2801=============
# ============= Backtest 2809=============
# ============= Backtest 2812=============
# ============= Backtest 2816=============
# ============= Backtest 2820=============
# ============= Backtest 2832=============
# ============= Backtest 2834=============
# ============= Backtest 2836=============
# ============= Backtest 2838=============
# ============= Backtest 2845=============
# ============= Backtest 2849=============
# ============= Backtest 2850=============
# ============= Backtest 2851=============
# ============= Backtest 2852=============
# ============= Backtest 2855=============
# ============= Backtest 2867=============
# ============= Backtest 2880=============
# ============= Backtest 2881=============
# ============= Backtest 2882=============
# ============= Backtest 2883=============
# ============= Backtest 2884=============
# ============= Backtest 2885=============
# ============= Backtest 2886=============
# ============= Backtest 2887=============
# ============= Backtest 2888=============
# ============= Backtest 2889=============
# ============= Backtest 2890=============
# ============= Backtest 2891=============
# ============= Backtest 2892=============
# ============= Backtest 2897=============
# ============= Backtest 2901=============
# ============= Backtest 2903=============
# ============= Backtest 2904=============
# ============= Backtest 2905=============
# ============= Backtest 2906=============
# ============= Backtest 2908=============
# ============= Backtest 2910=============
# ============= Backtest 2911=============
# ============= Backtest 2912=============
# ============= Backtest 2913=============
# ============= Backtest 2915=============
# ============= Backtest 2923=============
# ============= Backtest 2929=============
# ============= Backtest 2939=============
# ============= Backtest 3002=============
# ============= Backtest 3003=============
# ============= Backtest 3004=============
# ============= Backtest 3005=============
# ============= Backtest 3006=============
# ============= Backtest 3008=============
# ============= Backtest 3010=============
# ============= Backtest 3011=============
# ============= Backtest 3013=============
# ============= Backtest 3014=============
# ============= Backtest 3015=============
# ============= Backtest 3016=============
# ============= Backtest 3017=============
# ============= Backtest 3018=============
# ============= Backtest 3019=============
# ============= Backtest 3021=============
# ============= Backtest 3022=============
# ============= Backtest 3023=============
# ============= Backtest 3024=============
# ============= Backtest 3025=============
# ============= Backtest 3026=============
# ============= Backtest 3027=============
# ============= Backtest 3028=============
# ============= Backtest 3029=============
# ============= Backtest 3030=============
# ============= Backtest 3031=============
# ============= Backtest 3032=============
# ============= Backtest 3033=============
# ============= Backtest 3034=============
# ============= Backtest 3035=============
# ============= Backtest 3036=============
# ============= Backtest 3037=============
# ============= Backtest 3038=============
# ============= Backtest 3040=============
# ============= Backtest 3041=============
# ============= Backtest 3042=============
# ============= Backtest 3043=============
# ============= Backtest 3044=============
# ============= Backtest 3045=============
# ============= Backtest 3046=============
# ============= Backtest 3047=============
# ============= Backtest 3048=============
# ============= Backtest 3049=============
# ============= Backtest 3050=============
# ============= Backtest 3051=============
# ============= Backtest 3052=============
# ============= Backtest 3054=============
# ============= Backtest 3055=============
# ============= Backtest 3056=============
# ============= Backtest 3057=============
# ============= Backtest 3058=============
# ============= Backtest 3059=============
# ============= Backtest 3060=============
# ============= Backtest 3062=============
# ============= Backtest 3090=============
# ============= Backtest 3094=============
# ============= Backtest 3130=============
# ============= Backtest 3138=============
# ============= Backtest 3149=============
# ============= Backtest 3164=============
# ============= Backtest 3167=============
# ============= Backtest 3189=============
# ============= Backtest 3209=============
# ============= Backtest 3229=============
# ============= Backtest 3231=============
# ============= Backtest 3257=============
# ============= Backtest 3266=============
# ============= Backtest 3296=============
# ============= Backtest 3305=============
# ============= Backtest 3308=============
# ============= Backtest 3311=============
# ============= Backtest 3312=============
# ============= Backtest 3321=============
# ============= Backtest 3338=============
# ============= Backtest 3346=============
# ============= Backtest 3356=============
# ============= Backtest 3376=============
# ============= Backtest 3380=============
# ============= Backtest 3406=============
# ============= Backtest 3413=============
# ============= Backtest 3416=============
# ============= Backtest 3419=============
# ============= Backtest 3432=============
# ============= Backtest 3437=============
# ============= Backtest 3443=============
# ============= Backtest 3450=============
# ============= Backtest 3454=============
# ============= Backtest 3481=============
# ============= Backtest 3494=============
# ============= Backtest 3501=============
# ============= Backtest 3504=============
# ============= Backtest 3515=============
# ============= Backtest 3518=============
# ============= Backtest 3528=============
# ============= Backtest 3530=============
# ============= Backtest 3532=============
# ============= Backtest 3533=============
# ============= Backtest 3535=============
# ============= Backtest 3536=============
# ============= Backtest 3543=============
# ============= Backtest 3545=============
# ============= Backtest 3550=============
# ============= Backtest 3557=============
# ============= Backtest 3563=============
# ============= Backtest 3576=============
# ============= Backtest 3583=============
# ============= Backtest 3588=============
# ============= Backtest 3591=============
# ============= Backtest 3593=============
# ============= Backtest 3596=============
# ============= Backtest 3605=============
# ============= Backtest 3607=============
# ============= Backtest 3617=============
# ============= Backtest 3622=============
# ============= Backtest 3645=============
# ============= Backtest 3653=============
# ============= Backtest 3661=============
# ============= Backtest 3665=============
# ============= Backtest 3669=============
# ============= Backtest 3673=============
# ============= Backtest 3679=============
# ============= Backtest 3682=============
# ============= Backtest 3686=============
# ============= Backtest 3694=============
# ============= Backtest 3701=============
# ============= Backtest 3702=============
# ============= Backtest 3703=============
# ============= Backtest 3704=============
# ============= Backtest 3705=============
# ============= Backtest 3706=============
# ============= Backtest 3708=============
# ============= Backtest 3711=============
# ============= Backtest 3712=============
# ============= Backtest 3714=============
# ============= Backtest 4104=============
# ============= Backtest 4106=============
# ============= Backtest 4108=============
# ============= Backtest 4119=============
# ============= Backtest 4133=============
# ============= Backtest 4137=============
# ============= Backtest 4142=============
# ============= Backtest 4155=============
# ============= Backtest 4164=============
# ============= Backtest 4190=============
# ============= Backtest 4306=============
# ============= Backtest 4414=============
# ============= Backtest 4426=============
# ============= Backtest 4438=============
# ============= Backtest 4439=============
# ============= Backtest 4526=============
# ============= Backtest 4532=============
# ============= Backtest 4536=============
# ============= Backtest 4540=============
# ============= Backtest 4545=============
# ============= Backtest 4551=============
# ============= Backtest 4552=============
# ============= Backtest 4555=============
# ============= Backtest 4557=============
# ============= Backtest 4560=============
# ============= Backtest 4562=============
# ============= Backtest 4564=============
# ============= Backtest 4566=============
# ============= Backtest 4571=============
# ============= Backtest 4572=============
# ============= Backtest 4576=============
# ============= Backtest 4581=============
# ============= Backtest 4720=============
# ============= Backtest 4722=============
# ============= Backtest 4737=============
# ============= Backtest 4739=============
# ============= Backtest 4746=============
# ============= Backtest 4755=============
# ============= Backtest 4763=============
# ============= Backtest 4764=============
# ============= Backtest 4766=============
# ============= Backtest 4807=============
# ============= Backtest 4904=============
# ============= Backtest 4906=============
# ============= Backtest 4912=============
# ============= Backtest 4915=============
# ============= Backtest 4916=============
# ============= Backtest 4919=============
# ============= Backtest 4927=============
# ============= Backtest 4930=============
# ============= Backtest 4934=============
# ============= Backtest 4935=============
# ============= Backtest 4938=============
# ============= Backtest 4942=============
# ============= Backtest 4943=============
# ============= Backtest 4952=============
# ============= Backtest 4956=============
# ============= Backtest 4958=============
# ============= Backtest 4960=============
# ============= Backtest 4961=============
# ============= Backtest 4967=============
# ============= Backtest 4968=============
# ============= Backtest 4976=============
# ============= Backtest 4977=============
# ============= Backtest 4989=============
# ============= Backtest 4994=============
# ============= Backtest 4999=============
# ============= Backtest 5007=============
# ============= Backtest 5203=============
# ============= Backtest 5215=============
# ============= Backtest 5225=============
# ============= Backtest 5234=============
# ============= Backtest 5243=============
# ============= Backtest 5258=============
# ============= Backtest 5269=============
# ============= Backtest 5283=============
# ============= Backtest 5284=============
# ============= Backtest 5285=============
# ============= Backtest 5288=============
# ============= Backtest 5388=============
# ============= Backtest 5434=============
# ============= Backtest 5469=============
# ============= Backtest 5471=============
# ============= Backtest 5484=============
# ============= Backtest 5515=============
# ============= Backtest 5519=============
# ============= Backtest 5521=============
# ============= Backtest 5522=============
# ============= Backtest 5525=============
# ============= Backtest 5531=============
# ============= Backtest 5533=============
# ============= Backtest 5534=============
# ============= Backtest 5538=============
# ============= Backtest 5546=============
# ============= Backtest 5607=============
# ============= Backtest 5608=============
# ============= Backtest 5706=============
# ============= Backtest 5871=============
# ============= Backtest 5876=============
# ============= Backtest 5880=============
# ============= Backtest 5906=============
# ============= Backtest 5907=============
# ============= Backtest 6005=============
# ============= Backtest 6024=============
# ============= Backtest 6108=============
# ============= Backtest 6112=============
# ============= Backtest 6115=============
# ============= Backtest 6116=============
# ============= Backtest 6117=============
# ============= Backtest 6120=============
# ============= Backtest 6128=============
# ============= Backtest 6133=============
# ============= Backtest 6136=============
# ============= Backtest 6139=============
# ============= Backtest 6141=============
# ============= Backtest 6142=============
# ============= Backtest 6152=============
# ============= Backtest 6153=============
# ============= Backtest 6155=============
# ============= Backtest 6164=============
# ============= Backtest 6165=============
# ============= Backtest 6166=============
# ============= Backtest 6168=============
# ============= Backtest 6176=============
# ============= Backtest 6177=============
# ============= Backtest 6183=============
# ============= Backtest 6184=============
# ============= Backtest 6189=============
# ============= Backtest 6191=============
# ============= Backtest 6192=============
# ============= Backtest 6196=============
# ============= Backtest 6197=============
# ============= Backtest 6201=============
# ============= Backtest 6202=============
# ============= Backtest 6205=============
# ============= Backtest 6206=============
# ============= Backtest 6209=============
# ============= Backtest 6213=============
# ============= Backtest 6214=============
# ============= Backtest 6215=============
# ============= Backtest 6216=============
# ============= Backtest 6224=============
# ============= Backtest 6225=============
# ============= Backtest 6226=============
# ============= Backtest 6230=============
# ============= Backtest 6235=============
# ============= Backtest 6239=============
# ============= Backtest 6243=============
# ============= Backtest 6257=============
# ============= Backtest 6269=============
# ============= Backtest 6271=============
# ============= Backtest 6277=============
# ============= Backtest 6278=============
# ============= Backtest 6281=============
# ============= Backtest 6282=============
# ============= Backtest 6283=============
# ============= Backtest 6285=============
# ============= Backtest 6288=============
# ============= Backtest 6405=============
# ============= Backtest 6409=============
# ============= Backtest 6412=============
# ============= Backtest 6414=============
# ============= Backtest 6415=============
# ============= Backtest 6416=============
# ============= Backtest 6431=============
# ============= Backtest 6438=============
# ============= Backtest 6442=============
# ============= Backtest 6443=============
# ============= Backtest 6449=============
# ============= Backtest 6451=============
# ============= Backtest 6456=============
# ============= Backtest 6464=============
# ============= Backtest 6477=============
# ============= Backtest 6491=============
# ============= Backtest 6504=============
# ============= Backtest 6505=============
# ============= Backtest 6515=============
# ============= Backtest 6525=============
# ============= Backtest 6531=============
# ============= Backtest 6533=============
# ============= Backtest 6541=============
# ============= Backtest 6552=============
# ============= Backtest 6558=============
# ============= Backtest 6573=============
# ============= Backtest 6579=============
# ============= Backtest 6581=============
# ============= Backtest 6582=============
# ============= Backtest 6591=============
# ============= Backtest 6592=============
# ============= Backtest 6598=============
# ============= Backtest 6605=============
# ============= Backtest 6625=============
# ============= Backtest 6641=============
# ============= Backtest 6655=============
# ============= Backtest 6666=============
# ============= Backtest 6668=============
# ============= Backtest 6669=============
# ============= Backtest 6670=============
# ============= Backtest 6671=============
# ============= Backtest 6672=============
# ============= Backtest 6674=============
# ============= Backtest 6698=============
# ============= Backtest 6706=============
# ============= Backtest 6715=============
# ============= Backtest 6743=============
# ============= Backtest 6754=============
# ============= Backtest 6756=============
# ============= Backtest 8011=============
# ============= Backtest 8016=============
# ============= Backtest 8021=============
# ============= Backtest 8028=============
# ============= Backtest 8033=============
# ============= Backtest 8039=============
# ============= Backtest 8046=============
# ============= Backtest 8070=============
# ============= Backtest 8072=============
# ============= Backtest 8081=============
# ============= Backtest 8101=============
# ============= Backtest 8103=============
# ============= Backtest 8104=============
# ============= Backtest 8105=============
# ============= Backtest 8110=============
# ============= Backtest 8112=============
# ============= Backtest 8114=============
# ============= Backtest 8131=============
# ============= Backtest 8150=============
# ============= Backtest 8163=============
# ============= Backtest 8201=============
# ============= Backtest 8210=============
# ============= Backtest 8213=============
# ============= Backtest 8215=============
# ============= Backtest 8222=============
# ============= Backtest 8249=============
# ============= Backtest 8261=============
# ============= Backtest 8271=============
# ============= Backtest 8341=============
# ============= Backtest 8367=============
# ============= Backtest 8374=============
# ============= Backtest 8404=============
# ============= Backtest 8411=============
# ============= Backtest 8422=============
# ============= Backtest 8429=============
# ============= Backtest 8442=============
# ============= Backtest 8443=============
# ============= Backtest 8454=============
# ============= Backtest 8462=============
# ============= Backtest 8463=============
# ============= Backtest 8464=============
# ============= Backtest 8466=============
# ============= Backtest 8467=============
# ============= Backtest 8473=============
# ============= Backtest 8478=============
# ============= Backtest 8480=============
# ============= Backtest 8481=============
# ============= Backtest 8482=============
# ============= Backtest 8488=============
# ============= Backtest 8499=============
# ============= Backtest 8926=============
# ============= Backtest 8940=============
# ============= Backtest 8996=============
# ============= Backtest 9802=============
# ============= Backtest 9902=============
# ============= Backtest 9904=============
# ============= Backtest 9905=============
# ============= Backtest 9906=============
# ============= Backtest 9907=============
# ============= Backtest 9908=============
# ============= Backtest 9910=============
# ============= Backtest 9911=============
# ============= Backtest 9912=============
# ============= Backtest 9914=============
# ============= Backtest 9917=============
# ============= Backtest 9918=============
# ============= Backtest 9919=============
# ============= Backtest 9921=============
# ============= Backtest 9924=============
# ============= Backtest 9925=============
# ============= Backtest 9926=============
# ============= Backtest 9927=============
# ============= Backtest 9928=============
# ============= Backtest 9929=============
# ============= Backtest 9930=============
# ============= Backtest 9931=============
# ============= Backtest 9933=============
# ============= Backtest 9934=============
# ============= Backtest 9935=============
# ============= Backtest 9937=============
# ============= Backtest 9938=============
# ============= Backtest 9939=============
# ============= Backtest 9940=============
# ============= Backtest 9941=============
# ============= Backtest 9942=============
# ============= Backtest 9943=============
# ============= Backtest 9944=============
# ============= Backtest 9945=============
# ============= Backtest 9946=============
# ============= Backtest 9955=============
# ============= Backtest 9958=============
# ============= Backtest 1312A=============
# ============= Backtest 2002A=============
# ============= Backtest 2836A=============
# ============= Backtest 2838A=============
# ============= Backtest 2881A=============
# ============= Backtest 2881B=============
# ============= Backtest 2882A=============
# ============= Backtest 2882B=============
# ============= Backtest 2887E=============
# ============= Backtest 2887F=============
# ============= Backtest 2888A=============
# ============= Backtest 2888B=============
# ============= Backtest 2891B=============
# ============= Backtest 2891C=============
# ============= Backtest 2897A=============
# ============= Backtest 3702A=============
# ============= Backtest 5871A=============
# ============= Backtest 9941A=============
# ============= Backtest 1240=============
# ============= Backtest 1258=============
# ============= Backtest 1259=============
# ============= Backtest 1264=============
# ============= Backtest 1268=============
# ============= Backtest 1336=============
# ============= Backtest 1565=============
# ============= Backtest 1569=============
# ============= Backtest 1570=============
# ============= Backtest 1580=============
# ============= Backtest 1584=============
# ============= Backtest 1586=============
# ============= Backtest 1591=============
# ============= Backtest 1593=============
# ============= Backtest 1595=============
# ============= Backtest 1599=============
# ============= Backtest 1742=============
# ============= Backtest 1752=============
# ============= Backtest 1777=============
# ============= Backtest 1781=============
# ============= Backtest 1784=============
# ============= Backtest 1785=============
# ============= Backtest 1788=============
# ============= Backtest 1796=============
# ============= Backtest 1799=============
# ============= Backtest 1813=============
# ============= Backtest 1815=============
# ============= Backtest 2035=============
# ============= Backtest 2061=============
# ============= Backtest 2063=============
# ============= Backtest 2064=============
# ============= Backtest 2065=============
# ============= Backtest 2066=============
# ============= Backtest 2067=============
# ============= Backtest 2070=============
# ============= Backtest 2221=============
# ============= Backtest 2230=============
# ============= Backtest 2235=============
# ============= Backtest 2596=============
# ============= Backtest 2640=============
# ============= Backtest 2641=============
# ============= Backtest 2643=============
# ============= Backtest 2718=============
# ============= Backtest 2719=============
# ============= Backtest 2724=============
# ============= Backtest 2726=============
# ============= Backtest 2729=============
# ============= Backtest 2732=============
# ============= Backtest 2734=============
# ============= Backtest 2736=============
# ============= Backtest 2740=============
# ============= Backtest 2743=============
# ============= Backtest 2745=============
# ============= Backtest 2752=============
# ============= Backtest 2754=============
# ============= Backtest 2755=============
# ============= Backtest 2916=============
# ============= Backtest 2924=============
# ============= Backtest 2926=============
# ============= Backtest 2937=============
# ============= Backtest 3064=============
# ============= Backtest 3066=============
# ============= Backtest 3067=============
# ============= Backtest 3071=============
# ============= Backtest 3073=============
# ============= Backtest 3078=============
# ============= Backtest 3081=============
# ============= Backtest 3083=============
# ============= Backtest 3085=============
# ============= Backtest 3086=============
# ============= Backtest 3088=============
# ============= Backtest 3089=============
# ============= Backtest 3092=============
# ============= Backtest 3093=============
# ============= Backtest 3095=============
# ============= Backtest 3105=============
# ============= Backtest 3114=============
# ============= Backtest 3115=============
# ============= Backtest 3118=============
# ============= Backtest 3122=============
# ============= Backtest 3128=============
# ============= Backtest 3131=============
# ============= Backtest 3141=============
# ============= Backtest 3147=============
# ============= Backtest 3152=============
# ============= Backtest 3162=============
# ============= Backtest 3163=============
# ============= Backtest 3169=============
# ============= Backtest 3171=============
# ============= Backtest 3176=============
# ============= Backtest 3178=============
# ============= Backtest 3188=============
# ============= Backtest 3191=============
# ============= Backtest 3202=============
# ============= Backtest 3205=============
# ============= Backtest 3206=============
# ============= Backtest 3207=============
# ============= Backtest 3211=============
# ============= Backtest 3213=============
# ============= Backtest 3217=============
# ============= Backtest 3218=============
# ============= Backtest 3219=============
# ============= Backtest 3221=============
# ============= Backtest 3224=============
# ============= Backtest 3226=============
# ============= Backtest 3227=============
# ============= Backtest 3228=============
# ============= Backtest 3230=============
# ============= Backtest 3232=============
# ============= Backtest 3234=============
# ============= Backtest 3236=============
# ============= Backtest 3252=============
# ============= Backtest 3259=============
# ============= Backtest 3260=============
# ============= Backtest 3264=============
# ============= Backtest 3265=============
# ============= Backtest 3268=============
# ============= Backtest 3272=============
# ============= Backtest 3276=============
# ============= Backtest 3284=============
# ============= Backtest 3285=============
# ============= Backtest 3287=============
# ============= Backtest 3288=============
# ============= Backtest 3289=============
# ============= Backtest 3290=============
# ============= Backtest 3293=============
# ============= Backtest 3294=============
# ============= Backtest 3297=============
# ============= Backtest 3303=============
# ============= Backtest 3306=============
# ============= Backtest 3310=============
# ============= Backtest 3313=============
# ============= Backtest 3317=============
# ============= Backtest 3322=============
# ============= Backtest 3323=============
# ============= Backtest 3324=============
# ============= Backtest 3325=============
# ============= Backtest 3332=============
# ============= Backtest 3339=============
# ============= Backtest 3354=============
# ============= Backtest 3360=============
# ============= Backtest 3362=============
# ============= Backtest 3363=============
# ============= Backtest 3372=============
# ============= Backtest 3373=============
# ============= Backtest 3374=============
# ============= Backtest 3379=============
# ============= Backtest 3388=============
# ============= Backtest 3390=============
# ============= Backtest 3402=============
# ============= Backtest 3426=============
# ============= Backtest 3434=============
# ============= Backtest 3438=============
# ============= Backtest 3441=============
# ============= Backtest 3444=============
# ============= Backtest 3455=============
# ============= Backtest 3465=============
# ============= Backtest 3466=============
# ============= Backtest 3479=============
# ============= Backtest 3483=============
# ============= Backtest 3484=============
# ============= Backtest 3489=============
# ============= Backtest 3490=============
# ============= Backtest 3491=============
# ============= Backtest 3492=============
# ============= Backtest 3498=============
# ============= Backtest 3499=============
# ============= Backtest 3508=============
# ============= Backtest 3511=============
# ============= Backtest 3512=============
# ============= Backtest 3516=============
# ============= Backtest 3520=============
# ============= Backtest 3521=============
# ============= Backtest 3522=============
# ============= Backtest 3523=============
# ============= Backtest 3526=============
# ============= Backtest 3527=============
# ============= Backtest 3529=============
# ============= Backtest 3531=============
# ============= Backtest 3537=============
# ============= Backtest 3540=============
# ============= Backtest 3541=============
# ============= Backtest 3546=============
# ============= Backtest 3548=============
# ============= Backtest 3551=============
# ============= Backtest 3552=============
# ============= Backtest 3555=============
# ============= Backtest 3556=============
# ============= Backtest 3558=============
# ============= Backtest 3564=============
# ============= Backtest 3567=============
# ============= Backtest 3570=============
# ============= Backtest 3577=============
# ============= Backtest 3580=============
# ============= Backtest 3581=============
# ============= Backtest 3587=============
# ============= Backtest 3594=============
# ============= Backtest 3597=============
# ============= Backtest 3609=============
# ============= Backtest 3611=============
# ============= Backtest 3615=============
# ============= Backtest 3623=============
# ============= Backtest 3624=============
# ============= Backtest 3625=============
# ============= Backtest 3628=============
# ============= Backtest 3629=============
# ============= Backtest 3630=============
# ============= Backtest 3631=============
# ============= Backtest 3632=============
# ============= Backtest 3642=============
# ============= Backtest 3646=============
# ============= Backtest 3652=============
# ============= Backtest 3663=============
# ============= Backtest 3664=============
# ============= Backtest 3666=============
# ============= Backtest 3672=============
# ============= Backtest 3675=============
# ============= Backtest 3680=============
# ============= Backtest 3684=============
# ============= Backtest 3685=============
# ============= Backtest 3687=============
# ...
# ============= Backtest 6147=============
# ============= Backtest 6148=============
# ============= Backtest 6150=============
# ============= Backtest 6151=============
# ============= Backtest 6154=============
# ============= Backtest 6156=============
# ============= Backtest 6158=============
# ============= Backtest 6160=============
# ============= Backtest 6161=============
# ============= Backtest 6163=============
# ============= Backtest 6167=============
# ============= Backtest 6169=============
# ============= Backtest 6170=============
# ============= Backtest 6171=============
# ============= Backtest 6173=============
# ============= Backtest 6174=============
# ============= Backtest 6175=============
# ============= Backtest 6179=============
# ============= Backtest 6180=============
# ============= Backtest 6182=============
# ============= Backtest 6185=============
# ============= Backtest 6186=============
# ============= Backtest 6187=============
# ============= Backtest 6188=============
# ============= Backtest 6190=============
# ============= Backtest 6194=============
# ============= Backtest 6195=============
# ============= Backtest 6198=============
# ============= Backtest 6199=============
# ============= Backtest 6203=============
# ============= Backtest 6204=============
# ============= Backtest 6207=============
# ============= Backtest 6208=============
# ============= Backtest 6210=============
# ============= Backtest 6212=============
# ============= Backtest 6217=============
# ============= Backtest 6218=============
# ============= Backtest 6219=============
# ============= Backtest 6220=============
# ============= Backtest 6221=============
# ============= Backtest 6222=============
# ============= Backtest 6223=============
# ============= Backtest 6227=============
# ============= Backtest 6228=============
# ============= Backtest 6229=============
# ============= Backtest 6231=============
# ============= Backtest 6233=============
# ============= Backtest 6234=============
# ============= Backtest 6236=============
# ============= Backtest 6237=============
# ============= Backtest 6240=============
# ============= Backtest 6241=============
# ============= Backtest 6242=============
# ============= Backtest 6244=============
# ============= Backtest 6245=============
# ============= Backtest 6246=============
# ============= Backtest 6247=============
# ============= Backtest 6248=============
# ============= Backtest 6259=============
# ============= Backtest 6261=============
# ============= Backtest 6263=============
# ============= Backtest 6264=============
# ============= Backtest 6265=============
# ============= Backtest 6266=============
# ============= Backtest 6270=============
# ============= Backtest 6274=============
# ============= Backtest 6275=============
# ============= Backtest 6276=============
# ============= Backtest 6279=============
# ============= Backtest 6284=============
# ============= Backtest 6287=============
# ============= Backtest 6290=============
# ============= Backtest 6291=============
# ============= Backtest 6292=============
# ============= Backtest 6294=============
# ============= Backtest 6404=============
# ============= Backtest 6411=============
# ============= Backtest 6417=============
# ============= Backtest 6418=============
# ============= Backtest 6419=============
# ============= Backtest 6425=============
# ============= Backtest 6426=============
# ============= Backtest 6432=============
# ============= Backtest 6435=============
# ============= Backtest 6441=============
# ============= Backtest 6446=============
# ============= Backtest 6457=============
# ============= Backtest 6461=============
# ============= Backtest 6462=============
# ============= Backtest 6465=============
# ============= Backtest 6469=============
# ============= Backtest 6470=============
# ============= Backtest 6472=============
# ============= Backtest 6482=============
# ============= Backtest 6485=============
# ============= Backtest 6486=============
# ============= Backtest 6488=============
# ============= Backtest 6492=============
# ============= Backtest 6494=============
# ============= Backtest 6496=============
# ============= Backtest 6499=============
# ============= Backtest 6506=============
# ============= Backtest 6508=============
# ============= Backtest 6509=============
# ============= Backtest 6510=============
# ============= Backtest 6512=============
# ============= Backtest 6514=============
# ============= Backtest 6516=============
# ============= Backtest 6523=============
# ============= Backtest 6527=============
# ============= Backtest 6530=============
# ============= Backtest 6532=============
# ============= Backtest 6535=============
# ============= Backtest 6538=============
# ============= Backtest 6542=============
# ============= Backtest 6547=============
# ============= Backtest 6548=============
# ============= Backtest 6556=============
# ============= Backtest 6560=============
# ============= Backtest 6561=============
# ============= Backtest 6568=============
# ============= Backtest 6569=============
# ============= Backtest 6570=============
# ============= Backtest 6574=============
# ============= Backtest 6576=============
# ============= Backtest 6577=============
# ============= Backtest 6578=============
# ============= Backtest 6588=============
# ============= Backtest 6589=============
# ============= Backtest 6590=============
# ============= Backtest 6593=============
# ============= Backtest 6594=============
# ============= Backtest 6596=============
# ============= Backtest 6603=============
# ============= Backtest 6609=============
# ============= Backtest 6612=============
# ============= Backtest 6613=============
# ============= Backtest 6615=============
# ============= Backtest 6616=============
# ============= Backtest 6624=============
# ============= Backtest 6629=============
# ============= Backtest 6640=============
# ============= Backtest 6642=============
# ============= Backtest 6643=============
# ============= Backtest 6649=============
# ============= Backtest 6651=============
# ============= Backtest 6654=============
# ============= Backtest 6661=============
# ============= Backtest 6662=============
# ============= Backtest 6664=============
# ============= Backtest 6667=============
# ============= Backtest 6679=============
# ============= Backtest 6680=============
# ============= Backtest 6683=============
# ============= Backtest 6690=============
# ============= Backtest 6697=============
# ============= Backtest 6703=============
# ============= Backtest 6712=============
# ============= Backtest 6716=============
# ============= Backtest 6727=============
# ============= Backtest 6728=============
# ============= Backtest 6732=============
# ============= Backtest 6733=============
# ============= Backtest 6747=============
# ============= Backtest 6751=============
# ============= Backtest 6752=============
# ============= Backtest 6762=============
# ============= Backtest 6767=============
# ============= Backtest 6803=============
# ============= Backtest 7402=============
# ============= Backtest 7556=============
# ============= Backtest 8024=============
# ============= Backtest 8027=============
# ============= Backtest 8032=============
# ============= Backtest 8034=============
# ============= Backtest 8038=============
# ============= Backtest 8040=============
# ============= Backtest 8042=============
# ============= Backtest 8043=============
# ============= Backtest 8044=============
# ============= Backtest 8047=============
# ============= Backtest 8048=============
# ============= Backtest 8049=============
# ============= Backtest 8050=============
# ============= Backtest 8054=============
# ============= Backtest 8059=============
# ============= Backtest 8064=============
# ============= Backtest 8066=============
# ============= Backtest 8067=============
# ============= Backtest 8068=============
# ============= Backtest 8069=============
# ============= Backtest 8071=============
# ============= Backtest 8074=============
# ============= Backtest 8076=============
# ============= Backtest 8077=============
# ============= Backtest 8080=============
# ============= Backtest 8083=============
# ============= Backtest 8084=============
# ============= Backtest 8085=============
# ============= Backtest 8086=============
# ============= Backtest 8087=============
# ============= Backtest 8088=============
# ============= Backtest 8089=============
# ============= Backtest 8091=============
# ============= Backtest 8092=============
# ============= Backtest 8093=============
# ============= Backtest 8096=============
# ============= Backtest 8097=============
# ============= Backtest 8099=============
# ============= Backtest 8107=============
# ============= Backtest 8109=============
# ============= Backtest 8111=============
# ============= Backtest 8121=============
# ============= Backtest 8147=============
# ============= Backtest 8155=============
# ============= Backtest 8171=============
# ============= Backtest 8176=============
# ============= Backtest 8182=============
# ============= Backtest 8183=============
# ============= Backtest 8234=============
# ============= Backtest 8240=============
# ============= Backtest 8255=============
# ============= Backtest 8277=============
# ============= Backtest 8279=============
# ============= Backtest 8284=============
# ============= Backtest 8289=============
# ============= Backtest 8291=============
# ============= Backtest 8299=============
# ============= Backtest 8342=============
# ============= Backtest 8349=============
# ============= Backtest 8354=============
# ============= Backtest 8358=============
# ============= Backtest 8383=============
# ============= Backtest 8390=============
# ============= Backtest 8401=============
# ============= Backtest 8403=============
# ============= Backtest 8409=============
# ============= Backtest 8410=============
# ============= Backtest 8415=============
# ============= Backtest 8416=============
# ============= Backtest 8418=============
# ============= Backtest 8420=============
# ============= Backtest 8421=============
# ============= Backtest 8423=============
# ============= Backtest 8424=============
# ============= Backtest 8426=============
# ============= Backtest 8431=============
# ============= Backtest 8432=============
# ============= Backtest 8433=============
# ============= Backtest 8435=============
# ============= Backtest 8436=============
# ============= Backtest 8437=============
# ============= Backtest 8440=============
# ============= Backtest 8444=============
# ============= Backtest 8446=============
# ============= Backtest 8450=============
# ============= Backtest 8455=============
# ============= Backtest 8472=============
# ============= Backtest 8476=============
# ============= Backtest 8477=============
# ============= Backtest 8489=============
# ============= Backtest 8905=============
# ============= Backtest 8906=============
# ============= Backtest 8908=============
# ============= Backtest 8916=============
# ============= Backtest 8917=============
# ============= Backtest 8921=============
# ============= Backtest 8923=============
# ============= Backtest 8924=============
# ============= Backtest 8927=============
# ============= Backtest 8928=============
# ============= Backtest 8929=============
# ============= Backtest 8930=============
# ============= Backtest 8931=============
# ============= Backtest 8932=============
# ============= Backtest 8933=============
# ============= Backtest 8935=============
# ============= Backtest 8936=============
# ============= Backtest 8937=============
# ============= Backtest 8938=============
# ============= Backtest 8941=============
# ============= Backtest 8942=============
# ============= Backtest 9949=============
# ============= Backtest 9950=============
# ============= Backtest 9951=============
# ============= Backtest 9960=============
# ============= Backtest 9962=============
# ============= Backtest 8916A=============
# ============= Backtest 4148=============
# ============= Backtest 6781=============
# ============= Backtest 6776=============
# ============= Backtest 2211=============
# ============= Backtest 6768=============
# ============= Backtest 3357=============
# ============= Backtest 6741=============
# ============= Backtest 2250=============
# ============= Backtest 5236=============
# ============= Backtest 1522A=============
# ============= Backtest 6684=============
# ============= Backtest 2753=============
# ============= Backtest 2348A=============
# ============= Backtest 6790=============
# ============= Backtest 6788=============
# ============= Backtest 2947=============
# ============= Backtest 4440=============
# ============= Backtest 5222=============
# ============= Backtest 2881C=============
# ============= Backtest 6761=============
# ============= Backtest 6806=============
# ============= Backtest 2945=============
# ============= Backtest 6770=============
# ============= Backtest 6792=============
# ============= Backtest 4770=============
# ============= Backtest 2883B=============
# ============= Backtest 6691=============
# ============= Backtest 3592=============
# ============= Backtest 6719=============
# ============= Backtest 2756=============
# ============= Backtest 5244=============
# ============= Backtest 6693=============
# ============= Backtest 8112A=============
# ============= Backtest 8438=============
# ============= Backtest 6829=============
# ============= Backtest 4923=============
# ============= Backtest 6763=============
# ============= Backtest 4558=============
# ============= Backtest 3349=============
# ============= Backtest 6804=============
# ============= Backtest 4768=============
# ============= Backtest 6807=============
# ============= Backtest 6721=============
# ============= Backtest 6735=============
# ============= Backtest 4583=============
# ============= Backtest 6799=============
# ============= Backtest 6585=============
# ============= Backtest 5228=============
# ============= Backtest 6546=============
# ============= Backtest 6796=============
# ============= Backtest 6550=============
# ============= Backtest 4577=============
# ============= Backtest 6789=============
# ============= Backtest 6823=============
# ============= Backtest 2887Z1=============
# ============= Backtest 6811=============
# ============= Backtest 6854=============
# ============= Backtest 3715=============
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-4c379956499b> in <module>
#       2 for ticker_info in bt_list:
#       3     print(f"============= Backtest {ticker_info['Ticker']}=============")
# ----> 4     results[ticker_info['Ticker']] = Backtest(Mom_MA_EMA_RSI, ticker_info['Ticker'], bt_period = 20)
#       5 #     break
#
# F:\SiteProject\StrategyDev\台股波段\無腦交易\BacktestBaseFunc.py in Backtest(strategy, ticker, dt, bt_period, params)
#      86         if not df: return []
#      87     if df.empty: return []
# ---> 88     return strategy(df, **params)
#      89
#
# <ipython-input-60-29af0080da8a> in Mom_MA_EMA_RSI(df, **kwargs)
#      14     df = Calc.MA(df.fillna(method='ffill'),[10])
#      15     df = Calc.EMA(df.fillna(method='ffill'),[10])
# ---> 16     df = Calc.RSI(df.fillna(method='ffill'), [window])
#      17     result = []
#      18     for i, row in enumerate(df.itertuples()):
#
# F:\SiteProject\StrategyDev\台股波段\無腦交易\Calculator.py in RSI(df, windows)
#     211
#     212                 tmp_df.loc[row.Index,'RSI'] = tmp_df.loc[row.Index,'UpDiffMean'] / (tmp_df.loc[row.Index,'UpDiffMean'] + abs(tmp_df.loc[row.Index,'DnDiffMean'])) * 100
# --> 213             df[f'RSI{window}'] = round(tmp_df.RSI, 2)
#     214         return df
#     215
#
# c:\users\kevin\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'RSI'

# %% [markdown]
# # Summary

# %%
results['1101']
# Out:
# [{'EntryDate': Timestamp('2003-02-25 00:00:00'),
#   'ExitDate': Timestamp('2003-03-05 00:00:00'),
#   'EntryPrice': 12.05,
#   'ExitPrice': 13.099999999999998,
#   'EntryCommission': 20,
#   'ExitCommission': 20,
#   'EntryTax': 36,
#   'ExitTax': 0,
#   'TotalCost': 76,
#   'HoldingPeriod': 8,
#   'Net': -1126,
#   'Ret': -0.0934,
#   'MaxPriceBetweeenHolding': 13.15,
#   'MaxRetBetweeenHolding': 0.0913,
#   'MinPriceBetweeenHolding': 12.05,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2003-03-07 00:00:00'),
#   'ExitDate': Timestamp('2003-03-13 00:00:00'),
#   'EntryPrice': 11.8,
#   'ExitPrice': 12.465,
#   'EntryCommission': 20,
#   'ExitCommission': 20,
#   'EntryTax': 35,
#   'ExitTax': 0,
#   'TotalCost': 75,
#   'HoldingPeriod': 6,
#   'Net': -740,
#   'Ret': -0.0627,
#   'MaxPriceBetweeenHolding': 12.5,
#   'MaxRetBetweeenHolding': 0.0593,
#   'MinPriceBetweeenHolding': 11.8,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2003-04-07 00:00:00'),
#   'ExitDate': Timestamp('2003-04-21 00:00:00'),
#   'EntryPrice': 13.75,
#   'ExitPrice': 13.115000000000006,
#   'EntryCommission': 20,
#   'ExitCommission': 20,
#   'EntryTax': 0,
#   'ExitTax': 39,
#   'TotalCost': 79,
#   'HoldingPeriod': 14,
#   'Net': -714,
#   'Ret': -0.0519,
#   'MaxPriceBetweeenHolding': 13.75,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 12.8,
#   'MinRetBetweeenHolding': -0.0691},
#  {'EntryDate': Timestamp('2003-05-21 00:00:00'),
#   'ExitDate': Timestamp('2003-05-23 00:00:00'),
#   'EntryPrice': 10.05,
#   'ExitPrice': 10.405000000000005,
#   'EntryCommission': 20,
#   'ExitCommission': 20,
#   'EntryTax': 30,
#   'ExitTax': 0,
#   'TotalCost': 70,
#   'HoldingPeriod': 2,
#   'Net': -425,
#   'Ret': -0.0423,
#   'MaxPriceBetweeenHolding': 10.7,
#   'MaxRetBetweeenHolding': 0.0647,
#   'MinPriceBetweeenHolding': 10.05,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2003-06-06 00:00:00'),
#   'ExitDate': Timestamp('2003-06-09 00:00:00'),
#   'EntryPrice': 12.05,
#   'ExitPrice': 11.740000000000002,
#   'EntryCommission': 20,
#   'ExitCommission': 20,
#   'EntryTax': 0,
#   'ExitTax': 35,
#   'TotalCost': 75,
#   'HoldingPeriod': 3,
#   'Net': -385,
#   'Ret': -0.032,
#   'MaxPriceBetweeenHolding': 12.1,
#   'MaxRetBetweeenHolding': 0.0041,
#   'MinPriceBetweeenHolding': 11.65,
#   'MinRetBetweeenHolding': -0.0332},
#  {'EntryDate': Timestamp('2003-06-16 00:00:00'),
#   'ExitDate': Timestamp('2003-06-20 00:00:00'),
#   'EntryPrice': 12.4,
#   'ExitPrice': 12.100000000000005,
#   'EntryCommission': 20,
#   'ExitCommission': 20,
#   'EntryTax': 0,
#   'ExitTax': 36,
#   'TotalCost': 76,
#   'HoldingPeriod': 4,
#   'Net': -376,
#   'Ret': -0.0303,
#   'MaxPriceBetweeenHolding': 12.6,
#   'MaxRetBetweeenHolding': 0.0161,
#   'MinPriceBetweeenHolding': 12.1,
#   'MinRetBetweeenHolding': -0.0242},
#  {'EntryDate': Timestamp('2003-11-28 00:00:00'),
#   'ExitDate': Timestamp('2003-12-01 00:00:00'),
#   'EntryPrice': 15.1,
#   'ExitPrice': 15.43000000000001,
#   'EntryCommission': 22,
#   'ExitCommission': 22,
#   'EntryTax': 45,
#   'ExitTax': 0,
#   'TotalCost': 89,
#   'HoldingPeriod': 3,
#   'Net': -419,
#   'Ret': -0.0277,
#   'MaxPriceBetweeenHolding': 15.5,
#   'MaxRetBetweeenHolding': 0.0265,
#   'MinPriceBetweeenHolding': 15.0,
#   'MinRetBetweeenHolding': -0.0066},
#  {'EntryDate': Timestamp('2003-12-26 00:00:00'),
#   'ExitDate': Timestamp('2003-12-29 00:00:00'),
#   'EntryPrice': 16.8,
#   'ExitPrice': 17.1,
#   'EntryCommission': 24,
#   'ExitCommission': 24,
#   'EntryTax': 0,
#   'ExitTax': 51,
#   'TotalCost': 99,
#   'HoldingPeriod': 3,
#   'Net': 201,
#   'Ret': 0.012,
#   'MaxPriceBetweeenHolding': 17.1,
#   'MaxRetBetweeenHolding': 0.0179,
#   'MinPriceBetweeenHolding': 16.6,
#   'MinRetBetweeenHolding': -0.0119},
#  {'EntryDate': Timestamp('2004-01-14 00:00:00'),
#   'ExitDate': Timestamp('2004-01-29 00:00:00'),
#   'EntryPrice': 18.6,
#   'ExitPrice': 17.890000000000008,
#   'EntryCommission': 27,
#   'ExitCommission': 25,
#   'EntryTax': 0,
#   'ExitTax': 54,
#   'TotalCost': 106,
#   'HoldingPeriod': 15,
#   'Net': -816,
#   'Ret': -0.0439,
#   'MaxPriceBetweeenHolding': 18.6,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 17.8,
#   'MinRetBetweeenHolding': -0.043},
#  {'EntryDate': Timestamp('2004-02-23 00:00:00'),
#   'ExitDate': Timestamp('2004-02-24 00:00:00'),
#   'EntryPrice': 20.7,
#   'ExitPrice': 20.170000000000012,
#   'EntryCommission': 29,
#   'ExitCommission': 29,
#   'EntryTax': 0,
#   'ExitTax': 61,
#   'TotalCost': 119,
#   'HoldingPeriod': 1,
#   'Net': -649,
#   'Ret': -0.0314,
#   'MaxPriceBetweeenHolding': 20.9,
#   'MaxRetBetweeenHolding': 0.0097,
#   'MinPriceBetweeenHolding': 20.0,
#   'MinRetBetweeenHolding': -0.0338},
#  {'EntryDate': Timestamp('2004-03-02 00:00:00'),
#   'ExitDate': Timestamp('2004-03-05 00:00:00'),
#   'EntryPrice': 21.4,
#   'ExitPrice': 20.350000000000016,
#   'EntryCommission': 30,
#   'ExitCommission': 29,
#   'EntryTax': 0,
#   'ExitTax': 61,
#   'TotalCost': 120,
#   'HoldingPeriod': 3,
#   'Net': -1170,
#   'Ret': -0.0547,
#   'MaxPriceBetweeenHolding': 21.4,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 20.2,
#   'MinRetBetweeenHolding': -0.0561},
#  {'EntryDate': Timestamp('2004-05-10 00:00:00'),
#   'ExitDate': Timestamp('2004-05-12 00:00:00'),
#   'EntryPrice': 14.4,
#   'ExitPrice': 14.970000000000013,
#   'EntryCommission': 21,
#   'ExitCommission': 21,
#   'EntryTax': 43,
#   'ExitTax': 0,
#   'TotalCost': 85,
#   'HoldingPeriod': 2,
#   'Net': -655,
#   'Ret': -0.0455,
#   'MaxPriceBetweeenHolding': 15.1,
#   'MaxRetBetweeenHolding': 0.0486,
#   'MinPriceBetweeenHolding': 14.4,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2004-07-08 00:00:00'),
#   'ExitDate': Timestamp('2004-07-15 00:00:00'),
#   'EntryPrice': 15.7,
#   'ExitPrice': 15.235000000000014,
#   'EntryCommission': 22,
#   'ExitCommission': 22,
#   'EntryTax': 0,
#   'ExitTax': 46,
#   'TotalCost': 90,
#   'HoldingPeriod': 7,
#   'Net': -555,
#   'Ret': -0.0354,
#   'MaxPriceBetweeenHolding': 15.7,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 15.0,
#   'MinRetBetweeenHolding': -0.0446},
#  {'EntryDate': Timestamp('2004-10-01 00:00:00'),
#   'ExitDate': Timestamp('2004-10-13 00:00:00'),
#   'EntryPrice': 19.3,
#   'ExitPrice': 18.690000000000015,
#   'EntryCommission': 28,
#   'ExitCommission': 27,
#   'EntryTax': 0,
#   'ExitTax': 56,
#   'TotalCost': 111,
#   'HoldingPeriod': 12,
#   'Net': -721,
#   'Ret': -0.0374,
#   'MaxPriceBetweeenHolding': 19.3,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 18.5,
#   'MinRetBetweeenHolding': -0.0415},
#  {'EntryDate': Timestamp('2005-03-29 00:00:00'),
#   'ExitDate': Timestamp('2005-03-30 00:00:00'),
#   'EntryPrice': 19.3,
#   'ExitPrice': 19.01,
#   'EntryCommission': 28,
#   'ExitCommission': 27,
#   'EntryTax': 58,
#   'ExitTax': 0,
#   'TotalCost': 113,
#   'HoldingPeriod': 1,
#   'Net': 177,
#   'Ret': 0.0092,
#   'MaxPriceBetweeenHolding': 19.3,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 18.55,
#   'MinRetBetweeenHolding': -0.0389},
#  {'EntryDate': Timestamp('2005-04-15 00:00:00'),
#   'ExitDate': Timestamp('2005-04-20 00:00:00'),
#   'EntryPrice': 17.95,
#   'ExitPrice': 18.305000000000014,
#   'EntryCommission': 26,
#   'ExitCommission': 26,
#   'EntryTax': 54,
#   'ExitTax': 0,
#   'TotalCost': 106,
#   'HoldingPeriod': 5,
#   'Net': -461,
#   'Ret': -0.0257,
#   'MaxPriceBetweeenHolding': 18.4,
#   'MaxRetBetweeenHolding': 0.0251,
#   'MinPriceBetweeenHolding': 17.95,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2005-10-07 00:00:00'),
#   'ExitDate': Timestamp('2005-10-18 00:00:00'),
#   'EntryPrice': 21.0,
#   'ExitPrice': 20.770000000000017,
#   'EntryCommission': 30,
#   'ExitCommission': 30,
#   'EntryTax': 0,
#   'ExitTax': 62,
#   'TotalCost': 122,
#   'HoldingPeriod': 11,
#   'Net': -352,
#   'Ret': -0.0168,
#   'MaxPriceBetweeenHolding': 21.0,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 20.65,
#   'MinRetBetweeenHolding': -0.0167},
#  {'EntryDate': Timestamp('2005-12-16 00:00:00'),
#   'ExitDate': Timestamp('2005-12-19 00:00:00'),
#   'EntryPrice': 21.55,
#   'ExitPrice': 21.650000000000002,
#   'EntryCommission': 31,
#   'ExitCommission': 31,
#   'EntryTax': 0,
#   'ExitTax': 65,
#   'TotalCost': 127,
#   'HoldingPeriod': 3,
#   'Net': -27,
#   'Ret': -0.0013,
#   'MaxPriceBetweeenHolding': 22.6,
#   'MaxRetBetweeenHolding': 0.0487,
#   'MinPriceBetweeenHolding': 21.55,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2006-01-05 00:00:00'),
#   'ExitDate': Timestamp('2006-01-09 00:00:00'),
#   'EntryPrice': 23.65,
#   'ExitPrice': 23.385000000000012,
#   'EntryCommission': 34,
#   'ExitCommission': 33,
#   'EntryTax': 0,
#   'ExitTax': 70,
#   'TotalCost': 137,
#   'HoldingPeriod': 4,
#   'Net': -402,
#   'Ret': -0.017,
#   'MaxPriceBetweeenHolding': 23.7,
#   'MaxRetBetweeenHolding': 0.0021,
#   'MinPriceBetweeenHolding': 23.1,
#   'MinRetBetweeenHolding': -0.0233},
#  {'EntryDate': Timestamp('2006-01-16 00:00:00'),
#   'ExitDate': Timestamp('2006-01-18 00:00:00'),
#   'EntryPrice': 24.15,
#   'ExitPrice': 23.515000000000015,
#   'EntryCommission': 34,
#   'ExitCommission': 34,
#   'EntryTax': 0,
#   'ExitTax': 71,
#   'TotalCost': 139,
#   'HoldingPeriod': 2,
#   'Net': -774,
#   'Ret': -0.032,
#   'MaxPriceBetweeenHolding': 24.15,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 23.45,
#   'MinRetBetweeenHolding': -0.029},
#  {'EntryDate': Timestamp('2006-02-03 00:00:00'),
#   'ExitDate': Timestamp('2006-02-09 00:00:00'),
#   'EntryPrice': 24.85,
#   'ExitPrice': 23.950000000000017,
#   'EntryCommission': 35,
#   'ExitCommission': 34,
#   'EntryTax': 0,
#   'ExitTax': 72,
#   'TotalCost': 141,
#   'HoldingPeriod': 6,
#   'Net': -1041,
#   'Ret': -0.0419,
#   'MaxPriceBetweeenHolding': 24.85,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 23.95,
#   'MinRetBetweeenHolding': -0.0362},
#  {'EntryDate': Timestamp('2006-03-29 00:00:00'),
#   'ExitDate': Timestamp('2006-03-30 00:00:00'),
#   'EntryPrice': 24.2,
#   'ExitPrice': 24.760000000000012,
#   'EntryCommission': 34,
#   'ExitCommission': 35,
#   'EntryTax': 73,
#   'ExitTax': 0,
#   'TotalCost': 142,
#   'HoldingPeriod': 1,
#   'Net': -702,
#   'Ret': -0.029,
#   'MaxPriceBetweeenHolding': 24.9,
#   'MaxRetBetweeenHolding': 0.0289,
#   'MinPriceBetweeenHolding': 23.9,
#   'MinRetBetweeenHolding': -0.0124},
#  {'EntryDate': Timestamp('2006-04-11 00:00:00'),
#   'ExitDate': Timestamp('2006-04-12 00:00:00'),
#   'EntryPrice': 24.5,
#   'ExitPrice': 24.76000000000002,
#   'EntryCommission': 35,
#   'ExitCommission': 35,
#   'EntryTax': 74,
#   'ExitTax': 0,
#   'TotalCost': 144,
#   'HoldingPeriod': 1,
#   'Net': -404,
#   'Ret': -0.0165,
#   'MaxPriceBetweeenHolding': 24.85,
#   'MaxRetBetweeenHolding': 0.0143,
#   'MinPriceBetweeenHolding': 24.5,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2006-04-27 00:00:00'),
#   'ExitDate': Timestamp('2006-04-28 00:00:00'),
#   'EntryPrice': 25.45,
#   'ExitPrice': 25.14500000000002,
#   'EntryCommission': 36,
#   'ExitCommission': 36,
#   'EntryTax': 0,
#   'ExitTax': 75,
#   'TotalCost': 147,
#   'HoldingPeriod': 1,
#   'Net': -452,
#   'Ret': -0.0178,
#   'MaxPriceBetweeenHolding': 25.45,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 24.4,
#   'MinRetBetweeenHolding': -0.0413},
#  {'EntryDate': Timestamp('2006-06-06 00:00:00'),
#   'ExitDate': Timestamp('2006-06-08 00:00:00'),
#   'EntryPrice': 24.25,
#   'ExitPrice': 23.09,
#   'EntryCommission': 35,
#   'ExitCommission': 33,
#   'EntryTax': 73,
#   'ExitTax': 0,
#   'TotalCost': 141,
#   'HoldingPeriod': 2,
#   'Net': 1019,
#   'Ret': 0.042,
#   'MaxPriceBetweeenHolding': 24.25,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 22.05,
#   'MinRetBetweeenHolding': -0.0907},
#  {'EntryDate': Timestamp('2006-07-12 00:00:00'),
#   'ExitDate': Timestamp('2006-07-14 00:00:00'),
#   'EntryPrice': 24.65,
#   'ExitPrice': 24.035000000000043,
#   'EntryCommission': 35,
#   'ExitCommission': 34,
#   'EntryTax': 0,
#   'ExitTax': 72,
#   'TotalCost': 141,
#   'HoldingPeriod': 2,
#   'Net': -756,
#   'Ret': -0.0307,
#   'MaxPriceBetweeenHolding': 24.65,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 23.55,
#   'MinRetBetweeenHolding': -0.0446},
#  {'EntryDate': Timestamp('2006-08-14 00:00:00'),
#   'ExitDate': Timestamp('2006-08-21 00:00:00'),
#   'EntryPrice': 24.45,
#   'ExitPrice': 24.080000000000037,
#   'EntryCommission': 35,
#   'ExitCommission': 34,
#   'EntryTax': 0,
#   'ExitTax': 72,
#   'TotalCost': 141,
#   'HoldingPeriod': 7,
#   'Net': -511,
#   'Ret': -0.0209,
#   'MaxPriceBetweeenHolding': 24.7,
#   'MaxRetBetweeenHolding': 0.0102,
#   'MinPriceBetweeenHolding': 23.65,
#   'MinRetBetweeenHolding': -0.0327},
#  {'EntryDate': Timestamp('2006-10-19 00:00:00'),
#   'ExitDate': Timestamp('2006-10-20 00:00:00'),
#   'EntryPrice': 26.25,
#   'ExitPrice': 26.82,
#   'EntryCommission': 37,
#   'ExitCommission': 38,
#   'EntryTax': 0,
#   'ExitTax': 80,
#   'TotalCost': 155,
#   'HoldingPeriod': 1,
#   'Net': 415,
#   'Ret': 0.0158,
#   'MaxPriceBetweeenHolding': 27.3,
#   'MaxRetBetweeenHolding': 0.04,
#   'MinPriceBetweeenHolding': 26.25,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2006-11-07 00:00:00'),
#   'ExitDate': Timestamp('2006-11-08 00:00:00'),
#   'EntryPrice': 27.0,
#   'ExitPrice': 26.700000000000045,
#   'EntryCommission': 38,
#   'ExitCommission': 38,
#   'EntryTax': 0,
#   'ExitTax': 80,
#   'TotalCost': 156,
#   'HoldingPeriod': 1,
#   'Net': -456,
#   'Ret': -0.0169,
#   'MaxPriceBetweeenHolding': 27.0,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 26.6,
#   'MinRetBetweeenHolding': -0.0148},
#  {'EntryDate': Timestamp('2007-02-13 00:00:00'),
#   'ExitDate': Timestamp('2007-02-26 00:00:00'),
#   'EntryPrice': 27.9,
#   'ExitPrice': 27.47,
#   'EntryCommission': 40,
#   'ExitCommission': 39,
#   'EntryTax': 84,
#   'ExitTax': 0,
#   'TotalCost': 163,
#   'HoldingPeriod': 13,
#   'Net': 267,
#   'Ret': 0.0096,
#   'MaxPriceBetweeenHolding': 27.95,
#   'MaxRetBetweeenHolding': 0.0018,
#   'MinPriceBetweeenHolding': 27.1,
#   'MinRetBetweeenHolding': -0.0287},
#  {'EntryDate': Timestamp('2007-03-30 00:00:00'),
#   'ExitDate': Timestamp('2007-04-09 00:00:00'),
#   'EntryPrice': 27.9,
#   'ExitPrice': 28.75,
#   'EntryCommission': 40,
#   'ExitCommission': 41,
#   'EntryTax': 0,
#   'ExitTax': 86,
#   'TotalCost': 167,
#   'HoldingPeriod': 10,
#   'Net': 683,
#   'Ret': 0.0245,
#   'MaxPriceBetweeenHolding': 29.8,
#   'MaxRetBetweeenHolding': 0.0681,
#   'MinPriceBetweeenHolding': 27.9,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2007-07-13 00:00:00'),
#   'ExitDate': Timestamp('2007-07-16 00:00:00'),
#   'EntryPrice': 38.3,
#   'ExitPrice': 38.949999999999996,
#   'EntryCommission': 55,
#   'ExitCommission': 56,
#   'EntryTax': 0,
#   'ExitTax': 117,
#   'TotalCost': 228,
#   'HoldingPeriod': 3,
#   'Net': 422,
#   'Ret': 0.011,
#   'MaxPriceBetweeenHolding': 40.5,
#   'MaxRetBetweeenHolding': 0.0574,
#   'MinPriceBetweeenHolding': 38.3,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2007-08-07 00:00:00'),
#   'ExitDate': Timestamp('2007-08-10 00:00:00'),
#   'EntryPrice': 41.25,
#   'ExitPrice': 39.56000000000006,
#   'EntryCommission': 59,
#   'ExitCommission': 56,
#   'EntryTax': 0,
#   'ExitTax': 119,
#   'TotalCost': 234,
#   'HoldingPeriod': 3,
#   'Net': -1924,
#   'Ret': -0.0466,
#   'MaxPriceBetweeenHolding': 41.25,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 38.8,
#   'MinRetBetweeenHolding': -0.0594},
#  {'EntryDate': Timestamp('2007-08-23 00:00:00'),
#   'ExitDate': Timestamp('2007-08-29 00:00:00'),
#   'EntryPrice': 40.0,
#   'ExitPrice': 39.050000000000054,
#   'EntryCommission': 57,
#   'ExitCommission': 56,
#   'EntryTax': 0,
#   'ExitTax': 117,
#   'TotalCost': 230,
#   'HoldingPeriod': 6,
#   'Net': -1180,
#   'Ret': -0.0295,
#   'MaxPriceBetweeenHolding': 40.0,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 38.3,
#   'MinRetBetweeenHolding': -0.0425},
#  {'EntryDate': Timestamp('2007-09-14 00:00:00'),
#   'ExitDate': Timestamp('2007-09-17 00:00:00'),
#   'EntryPrice': 42.3,
#   'ExitPrice': 43.589999999999996,
#   'EntryCommission': 60,
#   'ExitCommission': 62,
#   'EntryTax': 0,
#   'ExitTax': 131,
#   'TotalCost': 253,
#   'HoldingPeriod': 3,
#   'Net': 1037,
#   'Ret': 0.0245,
#   'MaxPriceBetweeenHolding': 43.6,
#   'MaxRetBetweeenHolding': 0.0307,
#   'MinPriceBetweeenHolding': 41.5,
#   'MinRetBetweeenHolding': -0.0189},
#  {'EntryDate': Timestamp('2007-10-26 00:00:00'),
#   'ExitDate': Timestamp('2007-10-31 00:00:00'),
#   'EntryPrice': 56.8,
#   'ExitPrice': 54.13000000000005,
#   'EntryCommission': 81,
#   'ExitCommission': 77,
#   'EntryTax': 0,
#   'ExitTax': 162,
#   'TotalCost': 320,
#   'HoldingPeriod': 5,
#   'Net': -2990,
#   'Ret': -0.0526,
#   'MaxPriceBetweeenHolding': 56.8,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 54.1,
#   'MinRetBetweeenHolding': -0.0475},
#  {'EntryDate': Timestamp('2007-11-15 00:00:00'),
#   'ExitDate': Timestamp('2007-11-16 00:00:00'),
#   'EntryPrice': 49.1,
#   'ExitPrice': 47.34,
#   'EntryCommission': 70,
#   'ExitCommission': 67,
#   'EntryTax': 147,
#   'ExitTax': 0,
#   'TotalCost': 284,
#   'HoldingPeriod': 1,
#   'Net': 1476,
#   'Ret': 0.0301,
#   'MaxPriceBetweeenHolding': 49.1,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 46.0,
#   'MinRetBetweeenHolding': -0.0631},
#  {'EntryDate': Timestamp('2007-11-28 00:00:00'),
#   'ExitDate': Timestamp('2007-11-29 00:00:00'),
#   'EntryPrice': 44.85,
#   'ExitPrice': 45.20500000000006,
#   'EntryCommission': 64,
#   'ExitCommission': 64,
#   'EntryTax': 135,
#   'ExitTax': 0,
#   'TotalCost': 263,
#   'HoldingPeriod': 1,
#   'Net': -618,
#   'Ret': -0.0138,
#   'MaxPriceBetweeenHolding': 46.8,
#   'MaxRetBetweeenHolding': 0.0435,
#   'MinPriceBetweeenHolding': 44.85,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2008-05-12 00:00:00'),
#   'ExitDate': Timestamp('2008-05-13 00:00:00'),
#   'EntryPrice': 48.9,
#   'ExitPrice': 50.22000000000007,
#   'EntryCommission': 70,
#   'ExitCommission': 72,
#   'EntryTax': 147,
#   'ExitTax': 0,
#   'TotalCost': 289,
#   'HoldingPeriod': 1,
#   'Net': -1609,
#   'Ret': -0.0329,
#   'MaxPriceBetweeenHolding': 51.9,
#   'MaxRetBetweeenHolding': 0.0613,
#   'MinPriceBetweeenHolding': 48.9,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2008-06-19 00:00:00'),
#   'ExitDate': Timestamp('2008-06-20 00:00:00'),
#   'EntryPrice': 46.0,
#   'ExitPrice': 44.48,
#   'EntryCommission': 66,
#   'ExitCommission': 63,
#   'EntryTax': 138,
#   'ExitTax': 0,
#   'TotalCost': 267,
#   'HoldingPeriod': 1,
#   'Net': 1253,
#   'Ret': 0.0272,
#   'MaxPriceBetweeenHolding': 46.8,
#   'MaxRetBetweeenHolding': 0.0174,
#   'MinPriceBetweeenHolding': 44.0,
#   'MinRetBetweeenHolding': -0.0435},
#  {'EntryDate': Timestamp('2008-06-24 00:00:00'),
#   'ExitDate': Timestamp('2008-06-27 00:00:00'),
#   'EntryPrice': 43.5,
#   'ExitPrice': 40.58,
#   'EntryCommission': 62,
#   'ExitCommission': 58,
#   'EntryTax': 130,
#   'ExitTax': 0,
#   'TotalCost': 250,
#   'HoldingPeriod': 3,
#   'Net': 2670,
#   'Ret': 0.0614,
#   'MaxPriceBetweeenHolding': 43.5,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 39.2,
#   'MinRetBetweeenHolding': -0.0989},
#  {'EntryDate': Timestamp('2008-08-15 00:00:00'),
#   'ExitDate': Timestamp('2008-08-18 00:00:00'),
#   'EntryPrice': 33.5,
#   'ExitPrice': 31.64,
#   'EntryCommission': 48,
#   'ExitCommission': 45,
#   'EntryTax': 100,
#   'ExitTax': 0,
#   'TotalCost': 193,
#   'HoldingPeriod': 3,
#   'Net': 1667,
#   'Ret': 0.0498,
#   'MaxPriceBetweeenHolding': 33.8,
#   'MaxRetBetweeenHolding': 0.009,
#   'MinPriceBetweeenHolding': 31.2,
#   'MinRetBetweeenHolding': -0.0687},
#  {'EntryDate': Timestamp('2008-08-21 00:00:00'),
#   'ExitDate': Timestamp('2008-08-27 00:00:00'),
#   'EntryPrice': 31.0,
#   'ExitPrice': 32.630000000000045,
#   'EntryCommission': 44,
#   'ExitCommission': 46,
#   'EntryTax': 93,
#   'ExitTax': 0,
#   'TotalCost': 183,
#   'HoldingPeriod': 6,
#   'Net': -1813,
#   'Ret': -0.0585,
#   'MaxPriceBetweeenHolding': 32.95,
#   'MaxRetBetweeenHolding': 0.0629,
#   'MinPriceBetweeenHolding': 31.0,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2008-10-08 00:00:00'),
#   'ExitDate': Timestamp('2008-10-23 00:00:00'),
#   'EntryPrice': 18.2,
#   'ExitPrice': 15.76,
#   'EntryCommission': 26,
#   'ExitCommission': 22,
#   'EntryTax': 55,
#   'ExitTax': 0,
#   'TotalCost': 103,
#   'HoldingPeriod': 15,
#   'Net': 2337,
#   'Ret': 0.1284,
#   'MaxPriceBetweeenHolding': 18.2,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 15.75,
#   'MinRetBetweeenHolding': -0.1346},
#  {'EntryDate': Timestamp('2008-11-24 00:00:00'),
#   'ExitDate': Timestamp('2008-12-18 00:00:00'),
#   'EntryPrice': 24.1,
#   'ExitPrice': 27.94,
#   'EntryCommission': 34,
#   'ExitCommission': 40,
#   'EntryTax': 0,
#   'ExitTax': 84,
#   'TotalCost': 158,
#   'HoldingPeriod': 24,
#   'Net': 3682,
#   'Ret': 0.1528,
#   'MaxPriceBetweeenHolding': 28.15,
#   'MaxRetBetweeenHolding': 0.168,
#   'MinPriceBetweeenHolding': 24.1,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2009-02-16 00:00:00'),
#   'ExitDate': Timestamp('2009-02-17 00:00:00'),
#   'EntryPrice': 27.35,
#   'ExitPrice': 26.51000000000003,
#   'EntryCommission': 39,
#   'ExitCommission': 38,
#   'EntryTax': 0,
#   'ExitTax': 80,
#   'TotalCost': 157,
#   'HoldingPeriod': 1,
#   'Net': -997,
#   'Ret': -0.0365,
#   'MaxPriceBetweeenHolding': 27.75,
#   'MaxRetBetweeenHolding': 0.0146,
#   'MinPriceBetweeenHolding': 26.45,
#   'MinRetBetweeenHolding': -0.0329},
#  {'EntryDate': Timestamp('2009-04-02 00:00:00'),
#   'ExitDate': Timestamp('2009-04-10 00:00:00'),
#   'EntryPrice': 30.25,
#   'ExitPrice': 32.33,
#   'EntryCommission': 43,
#   'ExitCommission': 46,
#   'EntryTax': 0,
#   'ExitTax': 97,
#   'TotalCost': 186,
#   'HoldingPeriod': 8,
#   'Net': 1894,
#   'Ret': 0.0626,
#   'MaxPriceBetweeenHolding': 34.0,
#   'MaxRetBetweeenHolding': 0.124,
#   'MinPriceBetweeenHolding': 30.25,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2009-06-18 00:00:00'),
#   'ExitDate': Timestamp('2009-06-24 00:00:00'),
#   'EntryPrice': 29.6,
#   'ExitPrice': 30.80000000000003,
#   'EntryCommission': 42,
#   'ExitCommission': 44,
#   'EntryTax': 89,
#   'ExitTax': 0,
#   'TotalCost': 175,
#   'HoldingPeriod': 6,
#   'Net': -1375,
#   'Ret': -0.0465,
#   'MaxPriceBetweeenHolding': 31.2,
#   'MaxRetBetweeenHolding': 0.0541,
#   'MinPriceBetweeenHolding': 29.1,
#   'MinRetBetweeenHolding': -0.0169},
#  {'EntryDate': Timestamp('2009-07-07 00:00:00'),
#   'ExitDate': Timestamp('2009-07-08 00:00:00'),
#   'EntryPrice': 32.65,
#   'ExitPrice': 31.910000000000018,
#   'EntryCommission': 47,
#   'ExitCommission': 45,
#   'EntryTax': 0,
#   'ExitTax': 96,
#   'TotalCost': 188,
#   'HoldingPeriod': 1,
#   'Net': -928,
#   'Ret': -0.0284,
#   'MaxPriceBetweeenHolding': 32.65,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 31.5,
#   'MinRetBetweeenHolding': -0.0352},
#  {'EntryDate': Timestamp('2009-08-04 00:00:00'),
#   'ExitDate': Timestamp('2009-08-10 00:00:00'),
#   'EntryPrice': 35.8,
#   'ExitPrice': 37.559999999999995,
#   'EntryCommission': 51,
#   'ExitCommission': 54,
#   'EntryTax': 0,
#   'ExitTax': 113,
#   'TotalCost': 218,
#   'HoldingPeriod': 6,
#   'Net': 1542,
#   'Ret': 0.0431,
#   'MaxPriceBetweeenHolding': 39.8,
#   'MaxRetBetweeenHolding': 0.1117,
#   'MinPriceBetweeenHolding': 35.8,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2010-04-15 00:00:00'),
#   'ExitDate': Timestamp('2010-04-19 00:00:00'),
#   'EntryPrice': 30.4,
#   'ExitPrice': 29.92500000000003,
#   'EntryCommission': 43,
#   'ExitCommission': 43,
#   'EntryTax': 0,
#   'ExitTax': 90,
#   'TotalCost': 176,
#   'HoldingPeriod': 4,
#   'Net': -651,
#   'Ret': -0.0214,
#   'MaxPriceBetweeenHolding': 30.4,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 28.7,
#   'MinRetBetweeenHolding': -0.0559},
#  {'EntryDate': Timestamp('2010-04-29 00:00:00'),
#   'ExitDate': Timestamp('2010-04-30 00:00:00'),
#   'EntryPrice': 28.3,
#   'ExitPrice': 28.560000000000038,
#   'EntryCommission': 40,
#   'ExitCommission': 41,
#   'EntryTax': 85,
#   'ExitTax': 0,
#   'TotalCost': 166,
#   'HoldingPeriod': 1,
#   'Net': -426,
#   'Ret': -0.0151,
#   'MaxPriceBetweeenHolding': 28.65,
#   'MaxRetBetweeenHolding': 0.0124,
#   'MinPriceBetweeenHolding': 28.2,
#   'MinRetBetweeenHolding': -0.0035},
#  {'EntryDate': Timestamp('2010-05-21 00:00:00'),
#   'ExitDate': Timestamp('2010-05-24 00:00:00'),
#   'EntryPrice': 25.95,
#   'ExitPrice': 26.535000000000025,
#   'EntryCommission': 37,
#   'ExitCommission': 38,
#   'EntryTax': 78,
#   'ExitTax': 0,
#   'TotalCost': 153,
#   'HoldingPeriod': 3,
#   'Net': -738,
#   'Ret': -0.0284,
#   'MaxPriceBetweeenHolding': 26.8,
#   'MaxRetBetweeenHolding': 0.0328,
#   'MinPriceBetweeenHolding': 25.95,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2010-06-11 00:00:00'),
#   'ExitDate': Timestamp('2010-06-17 00:00:00'),
#   'EntryPrice': 27.3,
#   'ExitPrice': 27.66,
#   'EntryCommission': 39,
#   'ExitCommission': 39,
#   'EntryTax': 0,
#   'ExitTax': 83,
#   'TotalCost': 161,
#   'HoldingPeriod': 6,
#   'Net': 199,
#   'Ret': 0.0073,
#   'MaxPriceBetweeenHolding': 27.8,
#   'MaxRetBetweeenHolding': 0.0183,
#   'MinPriceBetweeenHolding': 27.3,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2010-10-14 00:00:00'),
#   'ExitDate': Timestamp('2010-10-15 00:00:00'),
#   'EntryPrice': 34.2,
#   'ExitPrice': 33.82500000000003,
#   'EntryCommission': 49,
#   'ExitCommission': 48,
#   'EntryTax': 0,
#   'ExitTax': 101,
#   'TotalCost': 198,
#   'HoldingPeriod': 1,
#   'Net': -573,
#   'Ret': -0.0168,
#   'MaxPriceBetweeenHolding': 34.5,
#   'MaxRetBetweeenHolding': 0.0088,
#   'MinPriceBetweeenHolding': 33.65,
#   'MinRetBetweeenHolding': -0.0161},
#  {'EntryDate': Timestamp('2010-10-29 00:00:00'),
#   'ExitDate': Timestamp('2010-11-01 00:00:00'),
#   'EntryPrice': 32.6,
#   'ExitPrice': 32.985000000000035,
#   'EntryCommission': 46,
#   'ExitCommission': 47,
#   'EntryTax': 98,
#   'ExitTax': 0,
#   'TotalCost': 191,
#   'HoldingPeriod': 3,
#   'Net': -576,
#   'Ret': -0.0177,
#   'MaxPriceBetweeenHolding': 33.15,
#   'MaxRetBetweeenHolding': 0.0169,
#   'MinPriceBetweeenHolding': 32.6,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2010-11-26 00:00:00'),
#   'ExitDate': Timestamp('2010-12-01 00:00:00'),
#   'EntryPrice': 30.9,
#   'ExitPrice': 31.80000000000001,
#   'EntryCommission': 44,
#   'ExitCommission': 45,
#   'EntryTax': 93,
#   'ExitTax': 0,
#   'TotalCost': 182,
#   'HoldingPeriod': 5,
#   'Net': -1082,
#   'Ret': -0.035,
#   'MaxPriceBetweeenHolding': 32.2,
#   'MaxRetBetweeenHolding': 0.0421,
#   'MinPriceBetweeenHolding': 30.9,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2011-01-06 00:00:00'),
#   'ExitDate': Timestamp('2011-01-07 00:00:00'),
#   'EntryPrice': 32.4,
#   'ExitPrice': 32.03,
#   'EntryCommission': 46,
#   'ExitCommission': 46,
#   'EntryTax': 97,
#   'ExitTax': 0,
#   'TotalCost': 189,
#   'HoldingPeriod': 1,
#   'Net': 181,
#   'Ret': 0.0056,
#   'MaxPriceBetweeenHolding': 32.5,
#   'MaxRetBetweeenHolding': 0.0031,
#   'MinPriceBetweeenHolding': 32.0,
#   'MinRetBetweeenHolding': -0.0123},
#  {'EntryDate': Timestamp('2011-02-17 00:00:00'),
#   'ExitDate': Timestamp('2011-02-18 00:00:00'),
#   'EntryPrice': 30.05,
#   'ExitPrice': 30.285000000000032,
#   'EntryCommission': 43,
#   'ExitCommission': 43,
#   'EntryTax': 90,
#   'ExitTax': 0,
#   'TotalCost': 176,
#   'HoldingPeriod': 1,
#   'Net': -411,
#   'Ret': -0.0137,
#   'MaxPriceBetweeenHolding': 30.45,
#   'MaxRetBetweeenHolding': 0.0133,
#   'MinPriceBetweeenHolding': 30.05,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2011-02-24 00:00:00'),
#   'ExitDate': Timestamp('2011-03-02 00:00:00'),
#   'EntryPrice': 29.35,
#   'ExitPrice': 29.970000000000034,
#   'EntryCommission': 42,
#   'ExitCommission': 43,
#   'EntryTax': 88,
#   'ExitTax': 0,
#   'TotalCost': 173,
#   'HoldingPeriod': 6,
#   'Net': -793,
#   'Ret': -0.027,
#   'MaxPriceBetweeenHolding': 30.3,
#   'MaxRetBetweeenHolding': 0.0324,
#   'MinPriceBetweeenHolding': 29.35,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2011-05-19 00:00:00'),
#   'ExitDate': Timestamp('2011-05-26 00:00:00'),
#   'EntryPrice': 38.6,
#   'ExitPrice': 39.36500000000003,
#   'EntryCommission': 55,
#   'ExitCommission': 56,
#   'EntryTax': 116,
#   'ExitTax': 0,
#   'TotalCost': 227,
#   'HoldingPeriod': 7,
#   'Net': -992,
#   'Ret': -0.0257,
#   'MaxPriceBetweeenHolding': 39.85,
#   'MaxRetBetweeenHolding': 0.0324,
#   'MinPriceBetweeenHolding': 38.6,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2011-06-28 00:00:00'),
#   'ExitDate': Timestamp('2011-06-29 00:00:00'),
#   'EntryPrice': 40.8,
#   'ExitPrice': 41.489999999999995,
#   'EntryCommission': 58,
#   'ExitCommission': 59,
#   'EntryTax': 0,
#   'ExitTax': 124,
#   'TotalCost': 241,
#   'HoldingPeriod': 1,
#   'Net': 449,
#   'Ret': 0.011,
#   'MaxPriceBetweeenHolding': 42.2,
#   'MaxRetBetweeenHolding': 0.0343,
#   'MinPriceBetweeenHolding': 40.8,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2011-07-21 00:00:00'),
#   'ExitDate': Timestamp('2011-07-22 00:00:00'),
#   'EntryPrice': 46.3,
#   'ExitPrice': 48.059999999999995,
#   'EntryCommission': 66,
#   'ExitCommission': 68,
#   'EntryTax': 0,
#   'ExitTax': 144,
#   'TotalCost': 278,
#   'HoldingPeriod': 1,
#   'Net': 1482,
#   'Ret': 0.032,
#   'MaxPriceBetweeenHolding': 49.45,
#   'MaxRetBetweeenHolding': 0.068,
#   'MinPriceBetweeenHolding': 46.3,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2011-09-07 00:00:00'),
#   'ExitDate': Timestamp('2011-09-09 00:00:00'),
#   'EntryPrice': 35.25,
#   'ExitPrice': 37.535000000000025,
#   'EntryCommission': 50,
#   'ExitCommission': 53,
#   'EntryTax': 106,
#   'ExitTax': 0,
#   'TotalCost': 209,
#   'HoldingPeriod': 2,
#   'Net': -2494,
#   'Ret': -0.0708,
#   'MaxPriceBetweeenHolding': 37.6,
#   'MaxRetBetweeenHolding': 0.0667,
#   'MinPriceBetweeenHolding': 35.25,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2011-09-19 00:00:00'),
#   'ExitDate': Timestamp('2011-09-20 00:00:00'),
#   'EntryPrice': 34.95,
#   'ExitPrice': 33.870000000000005,
#   'EntryCommission': 50,
#   'ExitCommission': 48,
#   'EntryTax': 105,
#   'ExitTax': 0,
#   'TotalCost': 203,
#   'HoldingPeriod': 1,
#   'Net': 877,
#   'Ret': 0.0251,
#   'MaxPriceBetweeenHolding': 35.3,
#   'MaxRetBetweeenHolding': 0.01,
#   'MinPriceBetweeenHolding': 33.5,
#   'MinRetBetweeenHolding': -0.0415},
#  {'EntryDate': Timestamp('2011-11-07 00:00:00'),
#   'ExitDate': Timestamp('2011-11-08 00:00:00'),
#   'EntryPrice': 37.75,
#   'ExitPrice': 37.05000000000003,
#   'EntryCommission': 54,
#   'ExitCommission': 53,
#   'EntryTax': 0,
#   'ExitTax': 111,
#   'TotalCost': 218,
#   'HoldingPeriod': 1,
#   'Net': -918,
#   'Ret': -0.0243,
#   'MaxPriceBetweeenHolding': 38.05,
#   'MaxRetBetweeenHolding': 0.0079,
#   'MinPriceBetweeenHolding': 36.7,
#   'MinRetBetweeenHolding': -0.0278},
#  {'EntryDate': Timestamp('2011-12-09 00:00:00'),
#   'ExitDate': Timestamp('2011-12-21 00:00:00'),
#   'EntryPrice': 33.0,
#   'ExitPrice': 34.08500000000003,
#   'EntryCommission': 47,
#   'ExitCommission': 49,
#   'EntryTax': 99,
#   'ExitTax': 0,
#   'TotalCost': 195,
#   'HoldingPeriod': 12,
#   'Net': -1280,
#   'Ret': -0.0388,
#   'MaxPriceBetweeenHolding': 35.1,
#   'MaxRetBetweeenHolding': 0.0636,
#   'MinPriceBetweeenHolding': 33.0,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2012-01-11 00:00:00'),
#   'ExitDate': Timestamp('2012-01-16 00:00:00'),
#   'EntryPrice': 36.0,
#   'ExitPrice': 35.22000000000003,
#   'EntryCommission': 51,
#   'ExitCommission': 50,
#   'EntryTax': 0,
#   'ExitTax': 106,
#   'TotalCost': 207,
#   'HoldingPeriod': 5,
#   'Net': -987,
#   'Ret': -0.0274,
#   'MaxPriceBetweeenHolding': 36.4,
#   'MaxRetBetweeenHolding': 0.0111,
#   'MinPriceBetweeenHolding': 35.05,
#   'MinRetBetweeenHolding': -0.0264},
#  {'EntryDate': Timestamp('2012-02-04 00:00:00'),
#   'ExitDate': Timestamp('2012-02-06 00:00:00'),
#   'EntryPrice': 36.95,
#   'ExitPrice': 36.48000000000003,
#   'EntryCommission': 53,
#   'ExitCommission': 52,
#   'EntryTax': 0,
#   'ExitTax': 109,
#   'TotalCost': 214,
#   'HoldingPeriod': 2,
#   'Net': -684,
#   'Ret': -0.0185,
#   'MaxPriceBetweeenHolding': 36.95,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 36.2,
#   'MinRetBetweeenHolding': -0.0203},
#  {'EntryDate': Timestamp('2012-07-13 00:00:00'),
#   'ExitDate': Timestamp('2012-07-16 00:00:00'),
#   'EntryPrice': 36.25,
#   'ExitPrice': 36.130000000000024,
#   'EntryCommission': 52,
#   'ExitCommission': 51,
#   'EntryTax': 0,
#   'ExitTax': 108,
#   'TotalCost': 211,
#   'HoldingPeriod': 3,
#   'Net': -331,
#   'Ret': -0.0091,
#   'MaxPriceBetweeenHolding': 36.4,
#   'MaxRetBetweeenHolding': 0.0041,
#   'MinPriceBetweeenHolding': 36.0,
#   'MinRetBetweeenHolding': -0.0069},
#  {'EntryDate': Timestamp('2012-07-20 00:00:00'),
#   'ExitDate': Timestamp('2012-07-23 00:00:00'),
#   'EntryPrice': 37.0,
#   'ExitPrice': 36.40500000000003,
#   'EntryCommission': 53,
#   'ExitCommission': 52,
#   'EntryTax': 0,
#   'ExitTax': 109,
#   'TotalCost': 214,
#   'HoldingPeriod': 3,
#   'Net': -809,
#   'Ret': -0.0219,
#   'MaxPriceBetweeenHolding': 37.0,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 36.2,
#   'MinRetBetweeenHolding': -0.0216},
#  {'EntryDate': Timestamp('2012-09-05 00:00:00'),
#   'ExitDate': Timestamp('2012-09-07 00:00:00'),
#   'EntryPrice': 32.55,
#   'ExitPrice': 33.15500000000004,
#   'EntryCommission': 46,
#   'ExitCommission': 47,
#   'EntryTax': 98,
#   'ExitTax': 0,
#   'TotalCost': 191,
#   'HoldingPeriod': 2,
#   'Net': -796,
#   'Ret': -0.0245,
#   'MaxPriceBetweeenHolding': 34.15,
#   'MaxRetBetweeenHolding': 0.0492,
#   'MinPriceBetweeenHolding': 32.45,
#   'MinRetBetweeenHolding': -0.0031},
#  {'EntryDate': Timestamp('2012-11-28 00:00:00'),
#   'ExitDate': Timestamp('2012-11-29 00:00:00'),
#   'EntryPrice': 36.0,
#   'ExitPrice': 36.51000000000003,
#   'EntryCommission': 51,
#   'ExitCommission': 52,
#   'EntryTax': 108,
#   'ExitTax': 0,
#   'TotalCost': 211,
#   'HoldingPeriod': 1,
#   'Net': -721,
#   'Ret': -0.02,
#   'MaxPriceBetweeenHolding': 37.4,
#   'MaxRetBetweeenHolding': 0.0389,
#   'MinPriceBetweeenHolding': 36.0,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2012-12-13 00:00:00'),
#   'ExitDate': Timestamp('2012-12-18 00:00:00'),
#   'EntryPrice': 39.05,
#   'ExitPrice': 38.520000000000024,
#   'EntryCommission': 56,
#   'ExitCommission': 55,
#   'EntryTax': 0,
#   'ExitTax': 116,
#   'TotalCost': 227,
#   'HoldingPeriod': 5,
#   'Net': -757,
#   'Ret': -0.0194,
#   'MaxPriceBetweeenHolding': 39.05,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 37.8,
#   'MinRetBetweeenHolding': -0.032},
#  {'EntryDate': Timestamp('2013-03-12 00:00:00'),
#   'ExitDate': Timestamp('2013-03-13 00:00:00'),
#   'EntryPrice': 38.15,
#   'ExitPrice': 38.42500000000004,
#   'EntryCommission': 54,
#   'ExitCommission': 55,
#   'EntryTax': 114,
#   'ExitTax': 0,
#   'TotalCost': 223,
#   'HoldingPeriod': 1,
#   'Net': -498,
#   'Ret': -0.0131,
#   'MaxPriceBetweeenHolding': 38.65,
#   'MaxRetBetweeenHolding': 0.0131,
#   'MinPriceBetweeenHolding': 38.15,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2013-04-15 00:00:00'),
#   'ExitDate': Timestamp('2013-04-16 00:00:00'),
#   'EntryPrice': 38.4,
#   'ExitPrice': 37.870000000000026,
#   'EntryCommission': 55,
#   'ExitCommission': 54,
#   'EntryTax': 0,
#   'ExitTax': 114,
#   'TotalCost': 223,
#   'HoldingPeriod': 1,
#   'Net': -753,
#   'Ret': -0.0196,
#   'MaxPriceBetweeenHolding': 38.5,
#   'MaxRetBetweeenHolding': 0.0026,
#   'MinPriceBetweeenHolding': 37.7,
#   'MinRetBetweeenHolding': -0.0182},
#  {'EntryDate': Timestamp('2013-06-20 00:00:00'),
#   'ExitDate': Timestamp('2013-06-21 00:00:00'),
#   'EntryPrice': 37.3,
#   'ExitPrice': 36.72,
#   'EntryCommission': 53,
#   'ExitCommission': 52,
#   'EntryTax': 112,
#   'ExitTax': 0,
#   'TotalCost': 217,
#   'HoldingPeriod': 1,
#   'Net': 363,
#   'Ret': 0.0097,
#   'MaxPriceBetweeenHolding': 37.3,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 35.15,
#   'MinRetBetweeenHolding': -0.0576},
#  {'EntryDate': Timestamp('2013-08-06 00:00:00'),
#   'ExitDate': Timestamp('2013-08-07 00:00:00'),
#   'EntryPrice': 36.4,
#   'ExitPrice': 36.97500000000002,
#   'EntryCommission': 52,
#   'ExitCommission': 53,
#   'EntryTax': 109,
#   'ExitTax': 0,
#   'TotalCost': 214,
#   'HoldingPeriod': 1,
#   'Net': -789,
#   'Ret': -0.0217,
#   'MaxPriceBetweeenHolding': 37.0,
#   'MaxRetBetweeenHolding': 0.0165,
#   'MinPriceBetweeenHolding': 36.1,
#   'MinRetBetweeenHolding': -0.0082},
#  {'EntryDate': Timestamp('2013-09-11 00:00:00'),
#   'ExitDate': Timestamp('2013-09-12 00:00:00'),
#   'EntryPrice': 40.0,
#   'ExitPrice': 40.65,
#   'EntryCommission': 57,
#   'ExitCommission': 58,
#   'EntryTax': 0,
#   'ExitTax': 122,
#   'TotalCost': 237,
#   'HoldingPeriod': 1,
#   'Net': 413,
#   'Ret': 0.0103,
#   'MaxPriceBetweeenHolding': 40.75,
#   'MaxRetBetweeenHolding': 0.0188,
#   'MinPriceBetweeenHolding': 40.0,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2013-10-03 00:00:00'),
#   'ExitDate': Timestamp('2013-10-08 00:00:00'),
#   'EntryPrice': 42.6,
#   'ExitPrice': 43.52,
#   'EntryCommission': 61,
#   'ExitCommission': 62,
#   'EntryTax': 0,
#   'ExitTax': 131,
#   'TotalCost': 254,
#   'HoldingPeriod': 5,
#   'Net': 666,
#   'Ret': 0.0156,
#   'MaxPriceBetweeenHolding': 43.6,
#   'MaxRetBetweeenHolding': 0.0235,
#   'MinPriceBetweeenHolding': 42.6,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2013-10-09 00:00:00'),
#   'ExitDate': Timestamp('2013-10-14 00:00:00'),
#   'EntryPrice': 43.2,
#   'ExitPrice': 44.0,
#   'EntryCommission': 62,
#   'ExitCommission': 63,
#   'EntryTax': 0,
#   'ExitTax': 132,
#   'TotalCost': 257,
#   'HoldingPeriod': 5,
#   'Net': 543,
#   'Ret': 0.0126,
#   'MaxPriceBetweeenHolding': 44.25,
#   'MaxRetBetweeenHolding': 0.0243,
#   'MinPriceBetweeenHolding': 43.0,
#   'MinRetBetweeenHolding': -0.0046},
#  {'EntryDate': Timestamp('2013-12-23 00:00:00'),
#   'ExitDate': Timestamp('2013-12-24 00:00:00'),
#   'EntryPrice': 45.85,
#   'ExitPrice': 45.425000000000026,
#   'EntryCommission': 65,
#   'ExitCommission': 65,
#   'EntryTax': 0,
#   'ExitTax': 136,
#   'TotalCost': 266,
#   'HoldingPeriod': 1,
#   'Net': -691,
#   'Ret': -0.0151,
#   'MaxPriceBetweeenHolding': 45.85,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 45.35,
#   'MinRetBetweeenHolding': -0.0109},
#  {'EntryDate': Timestamp('2014-02-12 00:00:00'),
#   'ExitDate': Timestamp('2014-02-13 00:00:00'),
#   'EntryPrice': 45.3,
#   'ExitPrice': 44.415000000000035,
#   'EntryCommission': 65,
#   'ExitCommission': 63,
#   'EntryTax': 0,
#   'ExitTax': 133,
#   'TotalCost': 261,
#   'HoldingPeriod': 1,
#   'Net': -1146,
#   'Ret': -0.0253,
#   'MaxPriceBetweeenHolding': 45.55,
#   'MaxRetBetweeenHolding': 0.0055,
#   'MinPriceBetweeenHolding': 44.4,
#   'MinRetBetweeenHolding': -0.0199},
#  {'EntryDate': Timestamp('2014-04-21 00:00:00'),
#   'ExitDate': Timestamp('2014-04-23 00:00:00'),
#   'EntryPrice': 49.1,
#   'ExitPrice': 48.550000000000026,
#   'EntryCommission': 70,
#   'ExitCommission': 69,
#   'EntryTax': 0,
#   'ExitTax': 146,
#   'TotalCost': 285,
#   'HoldingPeriod': 2,
#   'Net': -835,
#   'Ret': -0.017,
#   'MaxPriceBetweeenHolding': 49.45,
#   'MaxRetBetweeenHolding': 0.0071,
#   'MinPriceBetweeenHolding': 48.5,
#   'MinRetBetweeenHolding': -0.0122},
#  {'EntryDate': Timestamp('2014-05-21 00:00:00'),
#   'ExitDate': Timestamp('2014-05-27 00:00:00'),
#   'EntryPrice': 44.0,
#   'ExitPrice': 44.76000000000003,
#   'EntryCommission': 63,
#   'ExitCommission': 64,
#   'EntryTax': 132,
#   'ExitTax': 0,
#   'TotalCost': 259,
#   'HoldingPeriod': 6,
#   'Net': -1019,
#   'Ret': -0.0232,
#   'MaxPriceBetweeenHolding': 45.15,
#   'MaxRetBetweeenHolding': 0.0261,
#   'MinPriceBetweeenHolding': 44.0,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2014-10-06 00:00:00'),
#   'ExitDate': Timestamp('2014-10-08 00:00:00'),
#   'EntryPrice': 44.8,
#   'ExitPrice': 45.300000000000026,
#   'EntryCommission': 64,
#   'ExitCommission': 65,
#   'EntryTax': 134,
#   'ExitTax': 0,
#   'TotalCost': 263,
#   'HoldingPeriod': 2,
#   'Net': -763,
#   'Ret': -0.017,
#   'MaxPriceBetweeenHolding': 45.6,
#   'MaxRetBetweeenHolding': 0.0179,
#   'MinPriceBetweeenHolding': 44.5,
#   'MinRetBetweeenHolding': -0.0067},
#  {'EntryDate': Timestamp('2015-05-20 00:00:00'),
#   'ExitDate': Timestamp('2015-05-21 00:00:00'),
#   'EntryPrice': 42.55,
#   'ExitPrice': 42.32,
#   'EntryCommission': 61,
#   'ExitCommission': 60,
#   'EntryTax': 128,
#   'ExitTax': 0,
#   'TotalCost': 249,
#   'HoldingPeriod': 1,
#   'Net': -19,
#   'Ret': -0.0004,
#   'MaxPriceBetweeenHolding': 42.55,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 41.55,
#   'MinRetBetweeenHolding': -0.0235},
#  {'EntryDate': Timestamp('2015-07-15 00:00:00'),
#   'ExitDate': Timestamp('2015-07-21 00:00:00'),
#   'EntryPrice': 40.3,
#   'ExitPrice': 39.38000000000002,
#   'EntryCommission': 57,
#   'ExitCommission': 56,
#   'EntryTax': 0,
#   'ExitTax': 118,
#   'TotalCost': 231,
#   'HoldingPeriod': 6,
#   'Net': -1151,
#   'Ret': -0.0286,
#   'MaxPriceBetweeenHolding': 40.3,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 39.15,
#   'MinRetBetweeenHolding': -0.0285},
#  {'EntryDate': Timestamp('2015-08-14 00:00:00'),
#   'ExitDate': Timestamp('2015-08-18 00:00:00'),
#   'EntryPrice': 33.5,
#   'ExitPrice': 33.96000000000002,
#   'EntryCommission': 48,
#   'ExitCommission': 48,
#   'EntryTax': 100,
#   'ExitTax': 0,
#   'TotalCost': 196,
#   'HoldingPeriod': 4,
#   'Net': -656,
#   'Ret': -0.0196,
#   'MaxPriceBetweeenHolding': 34.0,
#   'MaxRetBetweeenHolding': 0.0149,
#   'MinPriceBetweeenHolding': 33.45,
#   'MinRetBetweeenHolding': -0.0015},
#  {'EntryDate': Timestamp('2015-09-09 00:00:00'),
#   'ExitDate': Timestamp('2015-09-23 00:00:00'),
#   'EntryPrice': 35.45,
#   'ExitPrice': 34.09500000000002,
#   'EntryCommission': 51,
#   'ExitCommission': 49,
#   'EntryTax': 0,
#   'ExitTax': 102,
#   'TotalCost': 202,
#   'HoldingPeriod': 14,
#   'Net': -1557,
#   'Ret': -0.0439,
#   'MaxPriceBetweeenHolding': 35.45,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 33.65,
#   'MinRetBetweeenHolding': -0.0508},
#  {'EntryDate': Timestamp('2016-01-19 00:00:00'),
#   'ExitDate': Timestamp('2016-01-20 00:00:00'),
#   'EntryPrice': 26.5,
#   'ExitPrice': 26.35,
#   'EntryCommission': 38,
#   'ExitCommission': 38,
#   'EntryTax': 80,
#   'ExitTax': 0,
#   'TotalCost': 156,
#   'HoldingPeriod': 1,
#   'Net': -6,
#   'Ret': -0.0002,
#   'MaxPriceBetweeenHolding': 26.5,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 25.85,
#   'MinRetBetweeenHolding': -0.0245},
#  {'EntryDate': Timestamp('2016-03-17 00:00:00'),
#   'ExitDate': Timestamp('2016-03-18 00:00:00'),
#   'EntryPrice': 30.85,
#   'ExitPrice': 31.540000000000003,
#   'EntryCommission': 44,
#   'ExitCommission': 45,
#   'EntryTax': 0,
#   'ExitTax': 95,
#   'TotalCost': 184,
#   'HoldingPeriod': 1,
#   'Net': 506,
#   'Ret': 0.0164,
#   'MaxPriceBetweeenHolding': 31.6,
#   'MaxRetBetweeenHolding': 0.0243,
#   'MinPriceBetweeenHolding': 30.85,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2016-04-25 00:00:00'),
#   'ExitDate': Timestamp('2016-04-26 00:00:00'),
#   'EntryPrice': 33.2,
#   'ExitPrice': 32.87500000000002,
#   'EntryCommission': 47,
#   'ExitCommission': 47,
#   'EntryTax': 0,
#   'ExitTax': 99,
#   'TotalCost': 193,
#   'HoldingPeriod': 1,
#   'Net': -518,
#   'Ret': -0.0156,
#   'MaxPriceBetweeenHolding': 33.5,
#   'MaxRetBetweeenHolding': 0.009,
#   'MinPriceBetweeenHolding': 32.75,
#   'MinRetBetweeenHolding': -0.0136},
#  {'EntryDate': Timestamp('2016-06-22 00:00:00'),
#   'ExitDate': Timestamp('2016-06-24 00:00:00'),
#   'EntryPrice': 32.75,
#   'ExitPrice': 31.790000000000013,
#   'EntryCommission': 47,
#   'ExitCommission': 45,
#   'EntryTax': 0,
#   'ExitTax': 95,
#   'TotalCost': 187,
#   'HoldingPeriod': 2,
#   'Net': -1147,
#   'Ret': -0.035,
#   'MaxPriceBetweeenHolding': 32.75,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 31.2,
#   'MinRetBetweeenHolding': -0.0473},
#  {'EntryDate': Timestamp('2016-07-01 00:00:00'),
#   'ExitDate': Timestamp('2016-07-04 00:00:00'),
#   'EntryPrice': 32.65,
#   'ExitPrice': 33.559999999999995,
#   'EntryCommission': 47,
#   'ExitCommission': 48,
#   'EntryTax': 0,
#   'ExitTax': 101,
#   'TotalCost': 196,
#   'HoldingPeriod': 3,
#   'Net': 714,
#   'Ret': 0.0219,
#   'MaxPriceBetweeenHolding': 33.65,
#   'MaxRetBetweeenHolding': 0.0306,
#   'MinPriceBetweeenHolding': 32.65,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2016-07-18 00:00:00'),
#   'ExitDate': Timestamp('2016-07-25 00:00:00'),
#   'EntryPrice': 35.5,
#   'ExitPrice': 34.550000000000026,
#   'EntryCommission': 51,
#   'ExitCommission': 49,
#   'EntryTax': 0,
#   'ExitTax': 104,
#   'TotalCost': 204,
#   'HoldingPeriod': 7,
#   'Net': -1154,
#   'Ret': -0.0325,
#   'MaxPriceBetweeenHolding': 35.5,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 33.45,
#   'MinRetBetweeenHolding': -0.0577},
#  {'EntryDate': Timestamp('2016-09-09 00:00:00'),
#   'ExitDate': Timestamp('2016-09-12 00:00:00'),
#   'EntryPrice': 35.75,
#   'ExitPrice': 34.78,
#   'EntryCommission': 51,
#   'ExitCommission': 50,
#   'EntryTax': 107,
#   'ExitTax': 0,
#   'TotalCost': 208,
#   'HoldingPeriod': 3,
#   'Net': 762,
#   'Ret': 0.0213,
#   'MaxPriceBetweeenHolding': 35.75,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 34.6,
#   'MinRetBetweeenHolding': -0.0322},
#  {'EntryDate': Timestamp('2017-03-01 00:00:00'),
#   'ExitDate': Timestamp('2017-03-02 00:00:00'),
#   'EntryPrice': 37.7,
#   'ExitPrice': 37.89,
#   'EntryCommission': 54,
#   'ExitCommission': 54,
#   'EntryTax': 0,
#   'ExitTax': 114,
#   'TotalCost': 222,
#   'HoldingPeriod': 1,
#   'Net': -32,
#   'Ret': -0.0008,
#   'MaxPriceBetweeenHolding': 38.9,
#   'MaxRetBetweeenHolding': 0.0318,
#   'MinPriceBetweeenHolding': 37.7,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2017-04-10 00:00:00'),
#   'ExitDate': Timestamp('2017-04-11 00:00:00'),
#   'EntryPrice': 37.0,
#   'ExitPrice': 37.225000000000016,
#   'EntryCommission': 53,
#   'ExitCommission': 53,
#   'EntryTax': 111,
#   'ExitTax': 0,
#   'TotalCost': 217,
#   'HoldingPeriod': 1,
#   'Net': -442,
#   'Ret': -0.0119,
#   'MaxPriceBetweeenHolding': 37.3,
#   'MaxRetBetweeenHolding': 0.0081,
#   'MinPriceBetweeenHolding': 36.9,
#   'MinRetBetweeenHolding': -0.0027},
#  {'EntryDate': Timestamp('2017-04-14 00:00:00'),
#   'ExitDate': Timestamp('2017-04-21 00:00:00'),
#   'EntryPrice': 36.5,
#   'ExitPrice': 35.95,
#   'EntryCommission': 52,
#   'ExitCommission': 51,
#   'EntryTax': 110,
#   'ExitTax': 0,
#   'TotalCost': 213,
#   'HoldingPeriod': 7,
#   'Net': 337,
#   'Ret': 0.0092,
#   'MaxPriceBetweeenHolding': 37.1,
#   'MaxRetBetweeenHolding': 0.0164,
#   'MinPriceBetweeenHolding': 35.35,
#   'MinRetBetweeenHolding': -0.0315},
#  {'EntryDate': Timestamp('2017-05-05 00:00:00'),
#   'ExitDate': Timestamp('2017-06-15 00:00:00'),
#   'EntryPrice': 34.7,
#   'ExitPrice': 33.68,
#   'EntryCommission': 49,
#   'ExitCommission': 48,
#   'EntryTax': 104,
#   'ExitTax': 0,
#   'TotalCost': 201,
#   'HoldingPeriod': 41,
#   'Net': 819,
#   'Ret': 0.0236,
#   'MaxPriceBetweeenHolding': 34.7,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 33.5,
#   'MinRetBetweeenHolding': -0.0346},
#  {'EntryDate': Timestamp('2017-07-04 00:00:00'),
#   'ExitDate': Timestamp('2017-07-07 00:00:00'),
#   'EntryPrice': 35.45,
#   'ExitPrice': 35.06500000000001,
#   'EntryCommission': 51,
#   'ExitCommission': 50,
#   'EntryTax': 0,
#   'ExitTax': 105,
#   'TotalCost': 206,
#   'HoldingPeriod': 3,
#   'Net': -591,
#   'Ret': -0.0167,
#   'MaxPriceBetweeenHolding': 35.45,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 35.05,
#   'MinRetBetweeenHolding': -0.0113},
#  {'EntryDate': Timestamp('2017-07-17 00:00:00'),
#   'ExitDate': Timestamp('2017-07-18 00:00:00'),
#   'EntryPrice': 35.8,
#   'ExitPrice': 35.320000000000014,
#   'EntryCommission': 51,
#   'ExitCommission': 50,
#   'EntryTax': 0,
#   'ExitTax': 106,
#   'TotalCost': 207,
#   'HoldingPeriod': 1,
#   'Net': -687,
#   'Ret': -0.0192,
#   'MaxPriceBetweeenHolding': 36.05,
#   'MaxRetBetweeenHolding': 0.007,
#   'MinPriceBetweeenHolding': 35.25,
#   'MinRetBetweeenHolding': -0.0154},
#  {'EntryDate': Timestamp('2017-08-09 00:00:00'),
#   'ExitDate': Timestamp('2017-08-10 00:00:00'),
#   'EntryPrice': 34.75,
#   'ExitPrice': 34.37,
#   'EntryCommission': 50,
#   'ExitCommission': 49,
#   'EntryTax': 104,
#   'ExitTax': 0,
#   'TotalCost': 203,
#   'HoldingPeriod': 1,
#   'Net': 177,
#   'Ret': 0.0051,
#   'MaxPriceBetweeenHolding': 34.75,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 34.3,
#   'MinRetBetweeenHolding': -0.0129},
#  {'EntryDate': Timestamp('2017-09-21 00:00:00'),
#   'ExitDate': Timestamp('2017-09-22 00:00:00'),
#   'EntryPrice': 33.8,
#   'ExitPrice': 33.905000000000015,
#   'EntryCommission': 48,
#   'ExitCommission': 48,
#   'EntryTax': 101,
#   'ExitTax': 0,
#   'TotalCost': 197,
#   'HoldingPeriod': 1,
#   'Net': -302,
#   'Ret': -0.0089,
#   'MaxPriceBetweeenHolding': 33.95,
#   'MaxRetBetweeenHolding': 0.0044,
#   'MinPriceBetweeenHolding': 33.8,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2017-11-24 00:00:00'),
#   'ExitDate': Timestamp('2017-11-27 00:00:00'),
#   'EntryPrice': 34.55,
#   'ExitPrice': 34.32500000000001,
#   'EntryCommission': 49,
#   'ExitCommission': 49,
#   'EntryTax': 0,
#   'ExitTax': 103,
#   'TotalCost': 201,
#   'HoldingPeriod': 3,
#   'Net': -426,
#   'Ret': -0.0123,
#   'MaxPriceBetweeenHolding': 34.6,
#   'MaxRetBetweeenHolding': 0.0014,
#   'MinPriceBetweeenHolding': 34.25,
#   'MinRetBetweeenHolding': -0.0087},
#  {'EntryDate': Timestamp('2018-04-23 00:00:00'),
#   'ExitDate': Timestamp('2018-04-24 00:00:00'),
#   'EntryPrice': 38.9,
#   'ExitPrice': 39.64,
#   'EntryCommission': 55,
#   'ExitCommission': 56,
#   'EntryTax': 0,
#   'ExitTax': 119,
#   'TotalCost': 230,
#   'HoldingPeriod': 1,
#   'Net': 510,
#   'Ret': 0.0131,
#   'MaxPriceBetweeenHolding': 41.0,
#   'MaxRetBetweeenHolding': 0.054,
#   'MinPriceBetweeenHolding': 38.9,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2018-05-10 00:00:00'),
#   'ExitDate': Timestamp('2018-05-14 00:00:00'),
#   'EntryPrice': 41.1,
#   'ExitPrice': 42.1,
#   'EntryCommission': 59,
#   'ExitCommission': 60,
#   'EntryTax': 0,
#   'ExitTax': 126,
#   'TotalCost': 245,
#   'HoldingPeriod': 4,
#   'Net': 755,
#   'Ret': 0.0184,
#   'MaxPriceBetweeenHolding': 43.25,
#   'MaxRetBetweeenHolding': 0.0523,
#   'MinPriceBetweeenHolding': 41.1,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2018-07-26 00:00:00'),
#   'ExitDate': Timestamp('2018-08-13 00:00:00'),
#   'EntryPrice': 40.5,
#   'ExitPrice': 42.920000000000016,
#   'EntryCommission': 58,
#   'ExitCommission': 61,
#   'EntryTax': 122,
#   'ExitTax': 0,
#   'TotalCost': 241,
#   'HoldingPeriod': 18,
#   'Net': -2661,
#   'Ret': -0.0657,
#   'MaxPriceBetweeenHolding': 43.7,
#   'MaxRetBetweeenHolding': 0.079,
#   'MinPriceBetweeenHolding': 40.5,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2019-01-07 00:00:00'),
#   'ExitDate': Timestamp('2019-01-08 00:00:00'),
#   'EntryPrice': 36.0,
#   'ExitPrice': 35.56000000000002,
#   'EntryCommission': 51,
#   'ExitCommission': 51,
#   'EntryTax': 0,
#   'ExitTax': 107,
#   'TotalCost': 209,
#   'HoldingPeriod': 1,
#   'Net': -649,
#   'Ret': -0.018,
#   'MaxPriceBetweeenHolding': 36.0,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 35.55,
#   'MinRetBetweeenHolding': -0.0125},
#  {'EntryDate': Timestamp('2019-02-20 00:00:00'),
#   'ExitDate': Timestamp('2019-02-21 00:00:00'),
#   'EntryPrice': 37.85,
#   'ExitPrice': 38.42,
#   'EntryCommission': 54,
#   'ExitCommission': 55,
#   'EntryTax': 0,
#   'ExitTax': 115,
#   'TotalCost': 224,
#   'HoldingPeriod': 1,
#   'Net': 346,
#   'Ret': 0.0091,
#   'MaxPriceBetweeenHolding': 39.45,
#   'MaxRetBetweeenHolding': 0.0423,
#   'MinPriceBetweeenHolding': 37.85,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2019-03-13 00:00:00'),
#   'ExitDate': Timestamp('2019-03-18 00:00:00'),
#   'EntryPrice': 38.5,
#   'ExitPrice': 38.180000000000014,
#   'EntryCommission': 55,
#   'ExitCommission': 54,
#   'EntryTax': 0,
#   'ExitTax': 115,
#   'TotalCost': 224,
#   'HoldingPeriod': 5,
#   'Net': -544,
#   'Ret': -0.0141,
#   'MaxPriceBetweeenHolding': 38.85,
#   'MaxRetBetweeenHolding': 0.0091,
#   'MinPriceBetweeenHolding': 37.6,
#   'MinRetBetweeenHolding': -0.0234},
#  {'EntryDate': Timestamp('2020-03-09 00:00:00'),
#   'ExitDate': Timestamp('2020-03-12 00:00:00'),
#   'EntryPrice': 41.85,
#   'ExitPrice': 40.74,
#   'EntryCommission': 60,
#   'ExitCommission': 58,
#   'EntryTax': 126,
#   'ExitTax': 0,
#   'TotalCost': 244,
#   'HoldingPeriod': 3,
#   'Net': 866,
#   'Ret': 0.0207,
#   'MaxPriceBetweeenHolding': 41.85,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 40.4,
#   'MinRetBetweeenHolding': -0.0346},
#  {'EntryDate': Timestamp('2020-04-20 00:00:00'),
#   'ExitDate': Timestamp('2020-04-22 00:00:00'),
#   'EntryPrice': 42.35,
#   'ExitPrice': 41.29500000000002,
#   'EntryCommission': 60,
#   'ExitCommission': 59,
#   'EntryTax': 0,
#   'ExitTax': 124,
#   'TotalCost': 243,
#   'HoldingPeriod': 2,
#   'Net': -1298,
#   'Ret': -0.0306,
#   'MaxPriceBetweeenHolding': 42.35,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 41.25,
#   'MinRetBetweeenHolding': -0.026},
#  {'EntryDate': Timestamp('2020-04-29 00:00:00'),
#   'ExitDate': Timestamp('2020-04-30 00:00:00'),
#   'EntryPrice': 42.55,
#   'ExitPrice': 43.29,
#   'EntryCommission': 61,
#   'ExitCommission': 62,
#   'EntryTax': 0,
#   'ExitTax': 130,
#   'TotalCost': 253,
#   'HoldingPeriod': 1,
#   'Net': 487,
#   'Ret': 0.0114,
#   'MaxPriceBetweeenHolding': 43.35,
#   'MaxRetBetweeenHolding': 0.0188,
#   'MinPriceBetweeenHolding': 42.55,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2020-05-12 00:00:00'),
#   'ExitDate': Timestamp('2020-05-13 00:00:00'),
#   'EntryPrice': 42.95,
#   'ExitPrice': 42.74500000000002,
#   'EntryCommission': 61,
#   'ExitCommission': 61,
#   'EntryTax': 0,
#   'ExitTax': 128,
#   'TotalCost': 250,
#   'HoldingPeriod': 1,
#   'Net': -455,
#   'Ret': -0.0106,
#   'MaxPriceBetweeenHolding': 42.95,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 42.3,
#   'MinRetBetweeenHolding': -0.0151},
#  {'EntryDate': Timestamp('2020-06-01 00:00:00'),
#   'ExitDate': Timestamp('2020-06-10 00:00:00'),
#   'EntryPrice': 43.1,
#   'ExitPrice': 44.07,
#   'EntryCommission': 61,
#   'ExitCommission': 63,
#   'EntryTax': 0,
#   'ExitTax': 132,
#   'TotalCost': 256,
#   'HoldingPeriod': 9,
#   'Net': 714,
#   'Ret': 0.0166,
#   'MaxPriceBetweeenHolding': 44.15,
#   'MaxRetBetweeenHolding': 0.0244,
#   'MinPriceBetweeenHolding': 43.1,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2020-07-15 00:00:00'),
#   'ExitDate': Timestamp('2020-07-16 00:00:00'),
#   'EntryPrice': 45.6,
#   'ExitPrice': 44.795000000000016,
#   'EntryCommission': 65,
#   'ExitCommission': 64,
#   'EntryTax': 0,
#   'ExitTax': 134,
#   'TotalCost': 263,
#   'HoldingPeriod': 1,
#   'Net': -1068,
#   'Ret': -0.0234,
#   'MaxPriceBetweeenHolding': 45.6,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 44.4,
#   'MinRetBetweeenHolding': -0.0263},
#  {'EntryDate': Timestamp('2020-07-21 00:00:00'),
#   'ExitDate': Timestamp('2020-07-24 00:00:00'),
#   'EntryPrice': 45.55,
#   'ExitPrice': 45.145000000000024,
#   'EntryCommission': 65,
#   'ExitCommission': 64,
#   'EntryTax': 0,
#   'ExitTax': 135,
#   'TotalCost': 264,
#   'HoldingPeriod': 3,
#   'Net': -669,
#   'Ret': -0.0147,
#   'MaxPriceBetweeenHolding': 45.55,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 45.0,
#   'MinRetBetweeenHolding': -0.0121},
#  {'EntryDate': Timestamp('2020-09-10 00:00:00'),
#   'ExitDate': Timestamp('2020-09-14 00:00:00'),
#   'EntryPrice': 42.45,
#   'ExitPrice': 42.71000000000001,
#   'EntryCommission': 60,
#   'ExitCommission': 61,
#   'EntryTax': 127,
#   'ExitTax': 0,
#   'TotalCost': 248,
#   'HoldingPeriod': 4,
#   'Net': -508,
#   'Ret': -0.012,
#   'MaxPriceBetweeenHolding': 42.95,
#   'MaxRetBetweeenHolding': 0.0118,
#   'MinPriceBetweeenHolding': 42.3,
#   'MinRetBetweeenHolding': -0.0035},
#  {'EntryDate': Timestamp('2020-09-21 00:00:00'),
#   'ExitDate': Timestamp('2020-09-22 00:00:00'),
#   'EntryPrice': 42.25,
#   'ExitPrice': 41.75,
#   'EntryCommission': 60,
#   'ExitCommission': 59,
#   'EntryTax': 127,
#   'ExitTax': 0,
#   'TotalCost': 246,
#   'HoldingPeriod': 1,
#   'Net': 254,
#   'Ret': 0.006,
#   'MaxPriceBetweeenHolding': 42.25,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 41.6,
#   'MinRetBetweeenHolding': -0.0154},
#  {'EntryDate': Timestamp('2020-10-13 00:00:00'),
#   'ExitDate': Timestamp('2020-10-23 00:00:00'),
#   'EntryPrice': 40.5,
#   'ExitPrice': 41.025000000000006,
#   'EntryCommission': 58,
#   'ExitCommission': 58,
#   'EntryTax': 122,
#   'ExitTax': 0,
#   'TotalCost': 238,
#   'HoldingPeriod': 10,
#   'Net': -763,
#   'Ret': -0.0188,
#   'MaxPriceBetweeenHolding': 41.1,
#   'MaxRetBetweeenHolding': 0.0148,
#   'MinPriceBetweeenHolding': 40.5,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2020-11-23 00:00:00'),
#   'ExitDate': Timestamp('2020-12-03 00:00:00'),
#   'EntryPrice': 43.0,
#   'ExitPrice': 43.71,
#   'EntryCommission': 61,
#   'ExitCommission': 62,
#   'EntryTax': 0,
#   'ExitTax': 131,
#   'TotalCost': 254,
#   'HoldingPeriod': 10,
#   'Net': 456,
#   'Ret': 0.0106,
#   'MaxPriceBetweeenHolding': 44.05,
#   'MaxRetBetweeenHolding': 0.0244,
#   'MinPriceBetweeenHolding': 43.0,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2021-03-03 00:00:00'),
#   'ExitDate': Timestamp('2021-03-09 00:00:00'),
#   'EntryPrice': 42.55,
#   'ExitPrice': 43.29,
#   'EntryCommission': 61,
#   'ExitCommission': 62,
#   'EntryTax': 0,
#   'ExitTax': 130,
#   'TotalCost': 253,
#   'HoldingPeriod': 6,
#   'Net': 487,
#   'Ret': 0.0114,
#   'MaxPriceBetweeenHolding': 43.4,
#   'MaxRetBetweeenHolding': 0.02,
#   'MinPriceBetweeenHolding': 42.55,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2021-03-18 00:00:00'),
#   'ExitDate': Timestamp('2021-03-19 00:00:00'),
#   'EntryPrice': 43.1,
#   'ExitPrice': 42.800000000000026,
#   'EntryCommission': 61,
#   'ExitCommission': 61,
#   'EntryTax': 0,
#   'ExitTax': 128,
#   'TotalCost': 250,
#   'HoldingPeriod': 1,
#   'Net': -550,
#   'Ret': -0.0128,
#   'MaxPriceBetweeenHolding': 43.1,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 42.6,
#   'MinRetBetweeenHolding': -0.0116},
#  {'EntryDate': Timestamp('2021-05-10 00:00:00'),
#   'ExitDate': Timestamp('2021-05-11 00:00:00'),
#   'EntryPrice': 52.9,
#   'ExitPrice': 52.150000000000034,
#   'EntryCommission': 75,
#   'ExitCommission': 74,
#   'EntryTax': 0,
#   'ExitTax': 156,
#   'TotalCost': 305,
#   'HoldingPeriod': 1,
#   'Net': -1055,
#   'Ret': -0.0199,
#   'MaxPriceBetweeenHolding': 53.2,
#   'MaxRetBetweeenHolding': 0.0057,
#   'MinPriceBetweeenHolding': 50.9,
#   'MinRetBetweeenHolding': -0.0378},
#  {'EntryDate': Timestamp('2021-07-02 00:00:00'),
#   'ExitDate': Timestamp('2021-07-05 00:00:00'),
#   'EntryPrice': 50.5,
#   'ExitPrice': 50.91000000000004,
#   'EntryCommission': 72,
#   'ExitCommission': 73,
#   'EntryTax': 152,
#   'ExitTax': 0,
#   'TotalCost': 297,
#   'HoldingPeriod': 3,
#   'Net': -707,
#   'Ret': -0.014,
#   'MaxPriceBetweeenHolding': 51.0,
#   'MaxRetBetweeenHolding': 0.0099,
#   'MinPriceBetweeenHolding': 50.5,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2021-08-24 00:00:00'),
#   'ExitDate': Timestamp('2021-08-30 00:00:00'),
#   'EntryPrice': 46.75,
#   'ExitPrice': 47.550000000000026,
#   'EntryCommission': 67,
#   'ExitCommission': 68,
#   'EntryTax': 140,
#   'ExitTax': 0,
#   'TotalCost': 275,
#   'HoldingPeriod': 6,
#   'Net': -1075,
#   'Ret': -0.023,
#   'MaxPriceBetweeenHolding': 47.6,
#   'MaxRetBetweeenHolding': 0.0182,
#   'MinPriceBetweeenHolding': 46.75,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2021-10-29 00:00:00'),
#   'ExitDate': Timestamp('2021-11-02 00:00:00'),
#   'EntryPrice': 48.25,
#   'ExitPrice': 48.66000000000004,
#   'EntryCommission': 69,
#   'ExitCommission': 69,
#   'EntryTax': 145,
#   'ExitTax': 0,
#   'TotalCost': 283,
#   'HoldingPeriod': 4,
#   'Net': -693,
#   'Ret': -0.0144,
#   'MaxPriceBetweeenHolding': 48.75,
#   'MaxRetBetweeenHolding': 0.0104,
#   'MinPriceBetweeenHolding': 48.1,
#   'MinRetBetweeenHolding': -0.0031},
#  {'EntryDate': Timestamp('2022-02-15 00:00:00'),
#   'ExitDate': Timestamp('2022-02-16 00:00:00'),
#   'EntryPrice': 47.0,
#   'ExitPrice': 47.14000000000001,
#   'EntryCommission': 67,
#   'ExitCommission': 67,
#   'EntryTax': 141,
#   'ExitTax': 0,
#   'TotalCost': 275,
#   'HoldingPeriod': 1,
#   'Net': -415,
#   'Ret': -0.0088,
#   'MaxPriceBetweeenHolding': 47.15,
#   'MaxRetBetweeenHolding': 0.0032,
#   'MinPriceBetweeenHolding': 47.0,
#   'MinRetBetweeenHolding': 0.0},
#  {'EntryDate': Timestamp('2022-04-26 00:00:00'),
#   'ExitDate': Timestamp('2022-05-03 00:00:00'),
#   'EntryPrice': 46.2,
#   'ExitPrice': 45.31,
#   'EntryCommission': 66,
#   'ExitCommission': 65,
#   'EntryTax': 139,
#   'ExitTax': 0,
#   'TotalCost': 270,
#   'HoldingPeriod': 7,
#   'Net': 620,
#   'Ret': 0.0134,
#   'MaxPriceBetweeenHolding': 46.2,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 45.1,
#   'MinRetBetweeenHolding': -0.0238},
#  {'EntryDate': Timestamp('2022-05-05 00:00:00'),
#   'ExitDate': Timestamp('2022-05-09 00:00:00'),
#   'EntryPrice': 45.6,
#   'ExitPrice': 45.01,
#   'EntryCommission': 65,
#   'ExitCommission': 64,
#   'EntryTax': 137,
#   'ExitTax': 0,
#   'TotalCost': 266,
#   'HoldingPeriod': 4,
#   'Net': 324,
#   'Ret': 0.0071,
#   'MaxPriceBetweeenHolding': 45.6,
#   'MaxRetBetweeenHolding': 0.0,
#   'MinPriceBetweeenHolding': 44.15,
#   'MinRetBetweeenHolding': -0.0318}]

# %%
summary_ = []
bt_day = datetime.today()
bt_day_str = bt_day.strftime("%Y%m%d")
for ticker, result in results.items():
    total_cost = 0
#     total_pnl = 0
    total_net = 0
    trade_num = len(result)
    win_num = 0
    loss_num = 0
    hold_period = []
    rets = []
    for res in result:
        total_net += res['Net']
        total_cost += res['TotalCost']
        win_num += int(res['Net'] > 0)
        loss_num += int(res['Net'] < 0)
        hold_period.append(res['HoldingPeriod'])
        rets.append(res['Ret'])
    summary_.append({
        '代號':ticker,
        '總成本':total_cost,
        '總損益(淨)':total_net,
        '獲利次數':win_num,
        '損失次數':loss_num,
        '總交易次數':trade_num,
        '勝率%':round(win_num / trade_num*100,2) if trade_num else 0,
        '平均報酬':mean(rets),
        '平均持倉時間(日)':mean(hold_period)
    })
    if result:
        DataFrame(result).to_csv(os.path.join(output_path, f'{ticker}_{bt_day_str}.csv'), index=False)

# %%
sum_df = DataFrame(summary_)#.sort_values(['勝率%','總交易次數'], ascending=False)

# %%
sum_df['總損益(淨)'].sum()
# Out:
# -23565593

# %%
sum_df.describe()
# Out:
#                 總成本        總損益(淨)         獲利次數         損失次數        總交易次數  \
# count  1.787000e+03  1.787000e+03  1787.000000  1787.000000  1787.000000
# mean   2.348282e+04 -1.318724e+04    39.254057    48.077224    87.379407
# std    4.790209e+04  9.203255e+04    18.426797    20.992471    37.886144
# min    0.000000e+00 -3.546935e+06     0.000000     0.000000     0.000000
# 25%    8.953000e+03 -1.585950e+04    24.000000    33.000000    58.000000
# 50%    1.429300e+04 -6.939000e+03    43.000000    53.000000    99.000000
# 75%    2.508350e+04 -3.615000e+02    54.000000    64.000000   117.000000
# max    1.595045e+06  3.223920e+05    77.000000   109.000000   175.000000
#
#                勝率%         平均報酬    平均持倉時間(日)
# count  1787.000000  1768.000000  1768.000000
# mean     43.696698    -0.003694     7.036598
# std       9.495311     0.019151    35.637143
# min       0.000000    -0.287664     1.000000
# 25%      40.000000    -0.006373     4.207721
# 50%      44.640000    -0.003481     4.666667
# 75%      49.065000    -0.001054     5.204825
# max      83.330000     0.612946  1178.000000

# %%
sum_df.to_csv(os.path.join(output_path, 'Summary.csv'),index=False, encoding='utf-8-sig')

# %%
sum_df_prob_sorted = sum_df[sum_df['勝率%'] > 60]
sum_df_trade_num_sorted = sum_df[sum_df.總交易次數 >= 10]
sum_df_holding_period_sorted = sum_df[sum_df['平均持倉時間(日)'] <= sum_df['平均持倉時間(日)'].describe()['50%']]

# %%
# top_num = 100
prob_Ticker = sum_df_prob_sorted.代號 # .iloc[:top_num]
trade_num_Ticker = sum_df_trade_num_sorted.代號 # .iloc[:top_num]
holding_period_Ticker = sum_df_holding_period_sorted.代號
suitable_Ticker = list(set(prob_Ticker).intersection(trade_num_Ticker).intersection(holding_period_Ticker))

# %%
print(sum_df[sum_df.代號.isin(suitable_Ticker)].shape)
sum_df[sum_df.代號.isin(suitable_Ticker)].sort_values("勝率%", ascending=False).head(50)
# Out:
# (7, 9)
#         代號    總成本  總損益(淨)  獲利次數  損失次數  總交易次數    勝率%      平均報酬  平均持倉時間(日)
# 1778  6546   2351    -801    16     6     22  72.73 -0.000400   3.636364
# 1584  6642   4217   15143    10     4     14  71.43  0.013821   3.571429
# 1587  6651   7009     801     7     4     11  63.64  0.001627   3.727273
# 647   4439  20751   27129    15     9     24  62.50  0.008142   3.791667
# 718   5519  11522   12868    53    32     85  62.35  0.004486   4.470588
# 827   6666  15408   -9238    14     9     23  60.87 -0.002743   4.434783
# 1120  3520  17382   14768    50    33     83  60.24  0.005304   4.397590

# %%
sum_df[sum_df.代號.isin(suitable_Ticker)].sort_values("勝率%", ascending=False).to_csv(os.path.join(output_path, 'Summary_prob_holding_tradenum.csv'), index=False)

# %%
sum_df[sum_df.代號.isin(suitable_Ticker)].sort_values("勝率%", ascending=False).sum()#describe()
# Out:
# 代號           4.960620e+111
# 總成本           1.600200e+05
# 總損益(淨)        1.044990e+06
# 獲利次數          4.100000e+02
# 損失次數          1.460000e+02
# 總交易次數         5.560000e+02
# 勝率%           2.073710e+03
# 平均報酬          1.280408e+00
# 平均持倉時間(日)     7.459708e+02
# dtype: float64

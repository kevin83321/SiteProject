# %%
import shioaji as sj
from datetime import datetime, timedelta
import pandas as pd
import numpy as np
import pytz
from copy import deepcopy

import json
import os 
parent = os.path.dirname(os.path.abspath("__file__"))
StrongPath = os.path.join(parent, 'StrongTickers')
if not os.path.isdir(StrongPath):
    os.makedirs(StrongPath)
# import matplotlib.pyplot as plt
# %matplotlib inline

# %%
api = sj.Shioaji()
api.login('F128497445', '89118217k')
# Out:
# Response Code: 0 | Event Code: 0 | Info: host '203.66.91.161:80', hostname '203.66.91.161:80' IP 203.66.91.161:80 (host 1 of 1) (host connection attempt 1 of 1) (total connection attempt 1 of 1) | Event: Session up
# [FutureAccount(person_id='F128497445', broker_id='F002000', account_id='1473661', signed=True, username='鄭圳宏'),
#  Account(account_type=<AccountType.H: 'H'>, person_id='F128497445', broker_id='9A92', account_id='0011645', username='鄭圳宏'),
#  StockAccount(person_id='F128497445', broker_id='9A92', account_id='0231901', signed=True, username='鄭圳宏\u3000\u3000')]

# %%
def ReadEarnedTicks():
    earned_ticks = {'price':[], 'ticks':[]}
    with open(os.path.join(parent, 'EarnedTicks.txt'), "r") as f:
        lines = f.readlines()
        for line in lines[1:]:
            earned_ticks['price'].append(int(line.split(',')[0]))
            earned_ticks['ticks'].append(int(line.split(',')[1].strip()))
            
        return earned_ticks

# %%
earned_ticks = ReadEarnedTicks()

# %%
def getEarnedTicks(entry_price,upTrend=True):
    tmp_p = deepcopy(earned_ticks['price'])
    tmp_t = deepcopy(earned_ticks['ticks'])
    tmp_p.append(entry_price)
    tmp_p = sorted(tmp_p)
#     if upTrend:
    idx = tmp_p.index(entry_price)
#     else:
#         idx = tmp_p.index(entry_price) - 1
#     try:
    return tmp_t[idx]#*int(round(bool(not upTrend)*1.3))
#     except:
#         return tmp_t[0]#*int(round(bool(not upTrend)*1.2))

# %%
def getTargetPrice(entry_price, upTrend=True, sl=1):
    num_ticks = getEarnedTicks(entry_price,upTrend)
    tmp_up_target = dn_target = up_target = entry_price
    for i in range(num_ticks):
        up_target += get_minimum_tick(up_target)
    up_target = round(up_target, 2)
    for i in range(num_ticks-1):
        tmp_up_target += get_minimum_tick(tmp_up_target)
    tmp_up_target = round(tmp_up_target, 2)
    while 1:
        tick = get_minimum_tick(dn_target)
        small_tick = get_minimum_tick(dn_target-tick)
        dn_target -= min(tick, small_tick)
        if (entry_price - round(dn_target, 2)) > (tmp_up_target - entry_price):
            break
    print(f'entry:{entry_price}, up_target:{up_target}, dn_target:{round(dn_target, 2)}')
    if sl:
        if upTrend:
            for i in range(2):
                tick = get_minimum_tick(dn_target)
                small_tick = get_minimum_tick(dn_target-tick)
                dn_target -= min(tick, small_tick)
        else:
            for i in range(2):
                up_target += get_minimum_tick(up_target)
            
    if upTrend:
        return round(up_target, 2), round(dn_target, 2)        
    else:
        return round(dn_target, 2), round(up_target, 2)

def getLimit(price, pct=0.1, trend="U"):
    tmp_price = price
    if trend == "U":
        while 1:
            tick = get_minimum_tick(tmp_price)
            tmp_price += tick
            if (tmp_price/price) > 1 + pct:
                tmp_price -= tick
                break
    elif trend == "D":
        while 1:
            tick = get_minimum_tick(tmp_price)
            tmp_price -= tick
            if (tmp_price/price) < 1 - pct:
                tmp_price += tick
                break
            
    return round(tmp_price, 2)
#     return round(entry_price, 2)

# %%
getTargetPrice(101.5, 0)
# Out:
# entry:101.5, up_target:103.0, dn_target:100.0
# (100.0, 104.0)

# %%
results = {}

# %%
from typing import Callable, List
from enum import Enum

from datetime import datetime, timedelta

from typing import List
from copy import deepcopy

class AttrDict(dict):
    def __init__(self, *args, **kwargs):
        super(AttrDict, self).__init__(*args, **kwargs)
        self.__dict__ = self
        
class BaseData(AttrDict):
    
    def __init__(self, *args, **kwargs):
        super(BaseData, self).__init__(*args, **kwargs)
        
class TickData(BaseData):
    """
    儲存即時收到的Info報價
    """
    def __init__(self, *args, **kwargs):
        super(TickData, self).__init__(*args, **kwargs)
        
class BarData(BaseData):
    """
    儲存即時收到的Info報價
    """
    def __init__(self, *args, **kwargs):
        super(BarData, self).__init__(*args, **kwargs)

class TradeMode(Enum):
    """
    交易模式
    """
    REALTIME = '實盤交易'
    SIMULATION = '模擬交易'
    BACKTEST = '回測'
    BACKTESTINTRADAY = '日內回測'

# 資料格式 (RealTime)
class Interval(Enum):
    """
    資料頻率
    """
    TICK = '逐筆'
    MINUTE = '分K'
    HOUR = '小時K'
    DAILY = '日K'

class BarGenerator:
    """
    For:
    1. generateing x minute bar/x hour bar data from tick data

    Notice:
    1. x can be any number
    """

    def __init__(self, ticker: str, interval: Interval = Interval.MINUTE, window: int = 5,
                 trademode: TradeMode = TradeMode.REALTIME, 
                 callback: Callable = None, size=15, date=datetime.today()):
        """
        Constructor
        """
        self.ticker = ticker
        self.interval = interval
        self.window = window
        self._trademode = trademode
        self.callback = callback

        self.setupBarCycle(interval, window)
        self.bars: List[BarData] = []
        self.inited = False
        self.barCount = 0
        self.size = size
        self.date = date

    def setupBarCycle(self, interval, window) -> None:
        if self._trademode in [TradeMode.REALTIME, TradeMode.SIMULATION]:
            self.current = date.replace(hour=9,minute=0,second=0,microsecond=0)#datetime.now().replace(second=0)
        elif self._trademode == TradeMode.BACKTESTINTRADAY:
            self.current = 84500
        self._intervalCycle(interval, window)

    def _intervalCycle(self, interval: Interval, window: int):
        if self._trademode in [TradeMode.REALTIME, TradeMode.SIMULATION]:
            if interval == Interval.MINUTE:
                self.cycle = timedelta(seconds=60 * window)
            elif interval == Interval.HOUR:
                self.cycle = timedelta(seconds=60 * 60 * window)
        elif self._trademode == TradeMode.BACKTESTINTRADAY:
            if interval == Interval.MINUTE:
                self.cycle = 100 * window
            elif interval == Interval.HOUR:
                self.cycle = 100 * 100 * window

    def updateBar(self, tick: TickData):
        try:
            if self._trademode == TradeMode.BACKTESTINTRADAY:
                return self._updateBarBacktest(tick)
            return self._updateBar(tick)
        except:
            raise

    def _updateBar(self, tick: TickData):
        try:
            try:
                time, close, volume = tick.time, tick.close, tick.volume
            except:
                # print(tick)
                time, close, volume = tick['time'], tick['close'], tick['volume']
            if not self.bars or time > self.current:
                self.bars.append(self._createNewBar(time, close, volume))
                self._updateCurBarTime()
                if len(self.bars) >= self.size:
                    self.inited = True
                if len(self.bars) > 1:
#                     print(self.bars[-2])
                    return self.bars[-2]
                    if self.callback:
                        self.callback(self.bars[-2])
            else:
                self._updateCurBar(close, volume)
        except:
            raise

    def _updateBarBacktest(self, tick: TickData):
        time, close, volume = tick.time, tick.close, tick.volume
        if not self.bars or time > self.current:
            self.bars.append(self._createNewBar(time, close, volume))
            self._updateCurBarTime()
            if len(self.bars) >= self.size:
                self.inited = True
            if len(self.bars) > 1:
                self.callback(self.bars[-2])
        else:
            self._updateCurBar(close, volume)
            
    def _createNewBar(self, time, close, volume):
        return BarData(
                    symbol=self.ticker,
                    time=time,
                    open=close,
                    high=close,
                    low=close,
                    close=close,
                    volume=volume
                )
    
    def _updateCurBar(self, close, volume):
        curBar = self.bars[-1]
        curBar.high = max(curBar.high, close)
        curBar.low = min(curBar.low, close)
        curBar.close = close
        curBar.volume += volume
        self.bars[-1] = curBar

    def _updateCurBarTime(self):
        self.current += self.cycle
        if self._trademode in [TradeMode.REALTIME, TradeMode.SIMULATION]:
            return
        elif self._trademode == TradeMode.BACKTESTINTRADAY:
            timeList = self._intTolist(self.current)
            if self.interval == Interval.MINUTE:
                if timeList[1] >= 60:
                    timeList[0] += 1
                    timeList[1] -= 60
            if timeList[0] >= 24:
                timeList[0] -= 24
            self.current = int(''.join([str(int(x)) for x in timeList]))

    def _intTolist(self, t):
        ss = t % 100
        t /= 100
        mm = t % 100
        hh = t / 100
        return [int(hh), int(mm), int(ss)]

    @property
    def closes(self):
        return [getattr(bar, 'close') for bar in self.bars][:-1]

    @property
    def opens(self):
        return [getattr(bar, 'open') for bar in self.bars][:-1]

    @property
    def highs(self):
        return [getattr(bar, 'high') for bar in self.bars][:-1]

    @property
    def lows(self):
        return [getattr(bar, 'low') for bar in self.bars][:-1]

    @property
    def volumes(self):
        return [getattr(bar, 'volume') for bar in self.bars][:-1]

# %%
def readStrongTicker(dtStr, atr=""):
    datapath = os.path.join(StrongPath+atr, f'{dtStr}_tradableTicker.json')
    if not os.path.isfile(datapath):
        datapath = os.path.join(StrongPath+atr, f'{dtStr}_strongTicker.json')
#         with open(os.path.join(StrongPath, f'{dtStr}_tradableTicker.json'), 'r') as f:
#             tickers = json.load(f)
#             return tickers
    if os.path.isfile(datapath):
        with open(datapath, 'r') as f:
            tickers = json.load(f)
            return tickers
    else:
        return {}

def get_minimum_tick(cost):
    if cost < 10:
        return 0.01
    elif cost < 50:
        return 0.05
    elif cost < 100:
        return 0.1
    elif cost < 500:
        return 0.5
    elif cost < 1000:
        return 1
    else:
        return 5
    
def get_commission(price:float, multiplier:int=1000, qty=1, Real:bool=True, direction:str='', dayTrade:bool=False):
    """
    計算個別部位的單邊交易成本

    Params:
        symbol : 商品代碼
        exchange : 交易所
        cost : 交易價格
        multiplier : 價格還原現金之乘數
            例如:
                股票 : 1張 = 1,000股，10元的股票還原現金價值，即為10 *1,000 = 10,000元
                期貨 : 台指期1點200元，假設現在10,000點，則一口台股的價值為 200 * 10,000 = 2,000,000
        qty : 買賣口數或張數
        Real : 是否為實單, default = False
        direction : 交易方向 進場(買賣)或出場
            P.S. 股票交易的交易稅是出場才計算
    """
    tick = get_minimum_tick(price)
    commission = price * (0.1425 / 100) * multiplier * qty
    commission = 20 if commission < 20 else commission
    fee = price * (0.3 / 100) * multiplier * qty
    if dayTrade:
        fee /= 2
    slide = tick * multiplier
    tradeCost = commission * 0.6
    if direction == 'EXIT' or direction == 0:
        tradeCost += fee
    if not Real:
        tradeCost += slide * qty
    return tradeCost

# %%
def ReadData(api, ticker, date):
    dateStr = date.strftime("%Y-%m-%d")
    contact = api.Contracts.Stocks[ticker]
    data = api.ticks(contact, dateStr, 
            query_type=sj.constant.TicksQueryType.RangeTime, 
            time_start='09:00:00',#datetime(2021,11,5,8,45,0).time(),
           time_end='13:30:00')#datetime(2021,11,5,13,45,0).time())
    df = pd.DataFrame(data.dict())
    df['datetime'] = df.ts.apply(lambda x: datetime.utcfromtimestamp(int(str(x)[:10])).astimezone(pytz.timezone('Asia/Taipei')))
    df['datetime'] = pd.to_datetime(df['datetime'].apply(lambda x: x.strftime("%Y-%m-%d %H:%M:%S.%f")))
    return df

# %%
def backtest(api:sj.Shioaji, ticker:str, date:datetime, open_threshold:float=0, PreData:dict={},
             v_threshold:float=.01, entry_percent:float=.05, exit_percent:float=.09, 
             takeprofit:float=.6, start_moving_take = .015, sl_ratio:float=.02, max_size:float = 1, 
             exit_time:str='13:00:00.000000'): # 

    # prepare data
    df = ReadData(api, ticker, date)
    
    # setting Parameters
    opening = False
    closing = False
    
    pre_time:str="09:00:00"
    pre_volume:int = 0
    pre_close:int = 0
    total_v:int = 0 
    refPrice:float = PreData.get('PreClose', 0)
    preHigh:float = PreData.get('PreHigh', PreData.get('PreClose', 0))
#     preLow:float = PreData.get('PreLow', 9999)
    entry_threshold:float = 0 if not refPrice else refPrice * (1 + entry_percent)
    exit_threshold:float = 0 if not refPrice else refPrice * (1 + exit_percent)
    max_ret:float = 0
    min_ret:float = 0
    tmp_ret:float = 0
    pos = 0
    sig = 0
    traded = 0
    long_traded = short_traded = 0
    entry = 0
    entry_time = 0

#     preHigh = 0
#     preLow = 9999
    sl_threshold = 0
    short_sl_ratio = .02
    
    pnl:float = 0
    total_volume = 0
#     first_5mink = {'open':None, 'high':0,'low':9999, 'close':0}
        
    entry_time = ''
    exit_pos_time = ''
    tmp_pnl = 0
    barG = BarGenerator(ticker, date=date)
    open_l = open_h = None
    total_pnl = 0
    vols = []
    vma5 = []
    vma10 = []
    inter_h = None
    inter_l = None
    max_v = 0
    
    for row in df.itertuples():
#         print(row)
        price = row.close
        time = row.datetime
        qty = row.volume
        if not qty: continue
        total_volume += qty
        tick = TickData(time=time, close=price,volume=qty)
        update_bar = barG.updateBar(tick)
        if update_bar and not pos:
#             print(update_bar)
            if len(barG.bars) >= 3 and not (open_h and open_l):
                open_h = max(barG.highs[:2])
                open_l = min(barG.lows[:2])
                print(f"open_h : {open_h}, open_l : {open_l}")
#             vols.append(update_bar.volume)
#             if len(vols) >= 5:
#                 vma5.append(np.mean(vols[-5:]))
#             if len(vols) >= 10:
#                 vma10.append(np.mean(vols[-10:]))
        if update_bar:
            if update_bar.volume > max_v:
                max_v = update_bar.volume
                inter_h = update_bar.high
                inter_l = update_bar.low
                continue
        if len(barG.bars) < 2:
            continue
        if time <= time.replace(hour=13,minute=0,second=0, microsecond=0) and not pos:
            if not pos and not sig and not traded: # check signal without position
                if update_bar:
                    if update_bar.close >= inter_h:
                        sig = 1
                        oneTradeOnly=True
                    if update_bar.close <= inter_l:
                        sig = -1
                        oneTradeOnly=True
#                 if update_bar and vma5 and vma10:
#                     if vma5[-2] <= vma10[-1] and vma5[-1] > vma10[-1] and price <= entry_threshold:
#                         sig = 1
#                         oneTradeOnly=True
#                 if not short_traded:
#                 if open_l and price < open_l and row.datetime.strftime('%H:%M:%S.%f') >= "12:00:00.000000" and not short_traded:
#                     print("Entry Short signal with price touch")
#                     sig = -1
#                     oneTradeOnly = True
#                 elif update_bar and open_l and update_bar['close'] < open_l and not short_traded: # update_bar['open']
#                     print(f"5m Bar CLose :{update_bar['close']}, open low : {open_l}")
# #                     print("Entry Short signal with price low open threshold")
# # #                     print(','.join([str(x) for x in [update_bar['close'], open_l]]))
#                     sig = -1
#                     oneTradeOnly = True
#                 elif min(barG.bars[0]['open'], barG.bars[0]['close']) * .995 and price >= refPrice * (1 - entry_percent) and not short_traded:
#                     sig = -1
#                     oneTradeOnly = True
#                 elif update_bar and open_h and update_bar['close'] > open_h and update_bar['close'] <= entry_threshold and not long_traded:
#                 if price > max(barG.bars[0]['open'], barG.bars[0]['close'], preHigh) * 1.005 and price <= entry_threshold and not long_traded: # ,preHigh
#                     sig = 1
#                     oneTradeOnly = True
            elif not pos and sig: # entry market
                print(f"Entry at close = {price}, bid : {row.bid_price}, ask : {row.ask_price}")
                if sig > 0:
                    entry = row.ask_price
                elif sig < 0:
                    entry = row.bid_price
                if abs(entry / price - 1) >= .005:
                    entry = price
                pos, sig = sig, 0
                entry_time = row.datetime
                target, sl_threshold = getTargetPrice(entry, pos > 0)
                sl_threshold = getLimit(entry, sl_ratio, 'D')# * (1 - sl_ratio * pos)
                if pos == -1:
#                     short_sl_ratio = open_h / entry - 1
                    sl_threshold = getLimit(entry, sl_ratio)
#                     sl_threshold = entry * (1 - short_sl_ratio * pos)
#                     sl_threshold = min(sl_threshold, (open_h + open_l) / 2)
                    
                    
        elif pos and not sig: # check signal with position
            tmp_pnl = (price - entry) * 1000 * pos
            tmp_pnl -= int(get_commission(entry if pos > 0 else price)) # 進場成本
            tmp_pnl -= int(get_commission(price if pos > 0 else entry, direction='EXIT', dayTrade=True)) # 出場成本
            if pos > 0:
                tmp_ret = ((price / entry) - 1) * pos
            else:
                tmp_ret = (tmp_pnl / (entry * 1000))# - 1
#             print(f"Tmp PnL : {tmp_pnl}")
            
#             if tmp_ret > max_ret:
# #                 sl_threshold = entry * (1 - sl_ratio * pos)
#                 sl_threshold = price * (1 - sl_ratio * pos)
#                 if pos == -1:
#                     sl_threshold = price * (1 - short_sl_ratio * self.pos)
#                     sl_threshold = min(sl_threshold, (open_h + open_l) / 2)
#                 sl_threshold = min(price * (1 - sl_ratio * pos), (open_h + open_l) / 2)
#                 print(row.datetime, price * (1 + sl_ratio), (open_h + open_l) / 2, sl_threshold)
            max_ret = max(tmp_ret, max_ret)
            min_ret = min(tmp_ret, min_ret)
#             print(f"close : {price}, pos : {pos}, tmp_pnl : {tmp_pnl}, max_ret : {max_ret}")
            
#             do_exit_take = False #tmp_ret >= 0.01 and ((entry_time.strftime('%H:%M:%S.%f') >= "12:00:00.000000") or pos == 1)
            do_exit_take = ((pos > 0) and price >= target) or ((pos < 0) and  price <= target)
                    
#             if max_ret >= start_moving_take:
#                 do_exit_take = (tmp_ret / max_ret) <= (takeprofit) if max_ret else False
#             do_exit_stop = price > sl_threshold if pos == -1 else price < sl_threshold
            do_exit_stop = ((pos > 0) and price <= sl_threshold) or ((pos < 0) and  price >= sl_threshold)
            do_exit = price >= exit_threshold if pos > 0 else price <= (refPrice * (1 - exit_percent))

            exit_end = time.strftime('%H:%M:%S.%f') >= exit_time
            if any([do_exit, do_exit_stop, exit_end, do_exit_take]): # 
                print(do_exit, do_exit_stop, exit_end, do_exit_take)
                try:
                    print(f"sl_threshold {sl_threshold}, half-high-low :{(open_h + open_l) / 2}")
                except:
                    pass
                print(f"Max Ret : {round(max_ret*100,2)}%")
                print(f"Min Ret : {round(min_ret*100,2)}%")
                sig = -pos
                print(f"Signal For Exit : {sig}")
#                     self.closing=True
#                     self.DoTrade('S' if self.pos > 0 else 'B')
#                     self.sendNotifyExit(self.q20_data['datetime'].strftime("%H:%M:%S.%f"), self.symbol, self.name,
#                                      close, self.q20_data['pct_chg'], do_exit_take or do_exit)
        elif pos and sig:
            signal_time = row.datetime
            print(f"Calculate PnL at close = {price}, ask : {row.ask_price} at {row.datetime}")
#             if sig > 0:
#                 exit = row.ask_price
#             elif sig < 0:
#                 exit = row.bid_price
#             if abs(exit / price - 1) >= .005:
            exit = price
            tmp_pnl = (exit - entry) * 1000 * pos
            tmp_pnl -= int(get_commission(entry if pos > 0 else exit)) # 進場成本
            tmp_pnl -= int(get_commission(exit if pos > 0 else entry, direction='EXIT', dayTrade=True)) # 出場成本
            tmp_ret = ((price / entry) - 1) * pos
            total_pnl += tmp_pnl
            
            print('\n---------------PnL Summary--------------')
            print(f'Exit Position of {ticker}')
            print(f'Entry : {entry} at {entry_time}')
            print(f'Exit : {price} at {signal_time}')
            print(f'Trading PnL with Cost : {int(round(tmp_pnl))}')
            print(f'Total PnL with Cost : {int(round(total_pnl))}')
            print(f'Total Ret with Cost : {round(tmp_ret * 100, 2)}%')
            print(f'Total PnL with Cost of max size {max_size}: {max_size * int(round(tmp_pnl))}\n')
            
            if pos > 0:
                long_traded = True
            elif pos < 0:
                short_traded = True
            sig = pos = 0
            traded = 1#(long_traded and short_traded) or (total_pnl > 0)
            exit_pos_time = row.datetime
        else:
            if pos and not sig:
                tmp_pnl = (price - entry) * 1000 * pos
                tmp_pnl -= int(get_commission(entry if pos > 0 else price)) # 進場成本
                tmp_pnl -= int(get_commission(price if pos > 0 else entry, direction='EXIT', dayTrade=True)) # 出場成本
                tmp_ret = ((price / entry) - 1) * pos
#                 tmp_ret = (tmp_pnl / entry * 1000) - 1
                if tmp_ret > max_ret:
                    sl_threshold = price * (1 - sl_ratio)
                max_ret = max(tmp_ret, max_ret)

                do_exit_take = do_exit_take = tmp_ret >= 0.01 # False
#                 if max_ret >= start_moving_take:
#                     do_exit_take = (tmp_ret / max_ret) <= (takeprofit) if max_ret else False
                do_exit_stop = price > sl_threshold if pos == -1 else price < sl_threshold
                do_exit = price >= exit_threshold if pos > 0 else price <= (refPrice * (1 - exit_percent))
                sig = -pos
            elif pos and sig:
                signal_time = row.datetime
                print(price, row.bid_price)
                exit = row.bid_price
                if abs(exit / price - 1) >= .005:
                    exit = price
                tmp_pnl = (exit - entry) * 1000 * pos
                tmp_pnl -= int(get_commission(entry if pos > 0 else exit)) # 進場成本
                tmp_pnl -= int(get_commission(exit if pos > 0 else entry, direction='EXIT', dayTrade=True)) # 出場成本
                tmp_ret = ((price / entry) - 1) * pos
                total_pnl += tmp_pnl
                
            
                print('\n---------------PnL Summary--------------')
                print(f'Exit Position of {ticker}')
                print(f'Entry : {entry} at {entry_time}')
                print(f'Exit : {price} at {signal_time}')
                print(f'Trading PnL with Cost : {int(round(tmp_pnl))}')
                print(f'Total PnL with Cost : {int(round(total_pnl))}')
                print(f'Total Ret with Cost : {round(tmp_ret * 100, 2)}%')
                print(f'Total PnL with Cost of max size {max_size}: {max_size * int(round(tmp_pnl))}\n')
                
                if pos > 0:
                    long_traded = True
                elif pos < 0:
                    short_traded = True
                sig = pos = 0
                traded = (long_traded and short_traded) or (total_pnl > 0)
                exit_pos_time = row.datetime
    return int(round(total_pnl))

# %%
# date = datetime(2022,2,25)
date = datetime(2021,12,17)
open_thresholds = readStrongTicker(date.strftime("%Y-%m-%d"))#, 'ATR')
total_capital = 5e6
seperated_capital = int(total_capital / len(open_thresholds.keys()))
max_size_map = {}
for k, v in open_thresholds.items():
    try:
        max_pos = int(seperated_capital / (v['PreClose'] * 1000))
        print(f'{k} 最大倉位 : {max_pos}, 昨收 : {v}')
        max_size_map[k] = max_pos
    except:
        max_pos = int(seperated_capital / (v * 1000))
        print(f'{k} 最大倉位 : {max_pos}, 昨收 : {v}')
        max_size_map[k] = max_pos
        open_thresholds[k] = {'PreClose':v}
# Out:
# 1529 最大倉位 : 10, 昨收 : {'PreClose': 21.65, 'PreHigh': 21.65, 'PreLow': 20.05}
# 2495 最大倉位 : 10, 昨收 : {'PreClose': 20.8, 'PreHigh': 20.8, 'PreLow': 19.5}
# 3035 最大倉位 : 0, 昨收 : {'PreClose': 217.5, 'PreHigh': 217.5, 'PreLow': 201.5}
# 3041 最大倉位 : 6, 昨收 : {'PreClose': 36.05, 'PreHigh': 36.05, 'PreLow': 33.25}
# 3060 最大倉位 : 7, 昨收 : {'PreClose': 27.7, 'PreHigh': 27.7, 'PreLow': 25.2}
# 3443 最大倉位 : 0, 昨收 : {'PreClose': 661.0, 'PreHigh': 661.0, 'PreLow': 610.0}
# 3607 最大倉位 : 12, 昨收 : {'PreClose': 17.35, 'PreHigh': 17.35, 'PreLow': 15.65}
# 5258 最大倉位 : 5, 昨收 : {'PreClose': 40.7, 'PreHigh': 40.7, 'PreLow': 37.9}
# 6698 最大倉位 : 3, 昨收 : {'PreClose': 56.6, 'PreHigh': 56.6, 'PreLow': 55.0}
# 8478 最大倉位 : 1, 昨收 : {'PreClose': 171.0, 'PreHigh': 171.0, 'PreLow': 163.5}
# 3114 最大倉位 : 6, 昨收 : {'PreClose': 31.55, 'PreHigh': 31.55, 'PreLow': 28.6}
# 3128 最大倉位 : 7, 昨收 : {'PreClose': 28.9, 'PreHigh': 28.9, 'PreLow': 25.0}
# 3141 最大倉位 : 0, 昨收 : {'PreClose': 292.5, 'PreHigh': 292.5, 'PreLow': 268.0}
# 3390 最大倉位 : 8, 昨收 : {'PreClose': 26.0, 'PreHigh': 26.4, 'PreLow': 24.5}
# 3466 最大倉位 : 9, 昨收 : {'PreClose': 21.85, 'PreHigh': 21.85, 'PreLow': 19.6}
# 3491 最大倉位 : 1, 昨收 : {'PreClose': 216.0, 'PreHigh': 216.0, 'PreLow': 199.0}
# 3675 最大倉位 : 0, 昨收 : {'PreClose': 320.0, 'PreHigh': 320.0, 'PreLow': 292.0}
# 5351 最大倉位 : 2, 昨收 : {'PreClose': 99.9, 'PreHigh': 99.9, 'PreLow': 91.7}
# 5371 最大倉位 : 2, 昨收 : {'PreClose': 89.1, 'PreHigh': 89.1, 'PreLow': 82.6}
# 6104 最大倉位 : 1, 昨收 : {'PreClose': 208.0, 'PreHigh': 208.0, 'PreLow': 193.0}
# 6156 最大倉位 : 9, 昨收 : {'PreClose': 21.75, 'PreHigh': 21.85, 'PreLow': 20.05}
# 6185 最大倉位 : 14, 昨收 : {'PreClose': 15.25, 'PreHigh': 15.25, 'PreLow': 14.25}
# 8089 最大倉位 : 6, 昨收 : {'PreClose': 34.25, 'PreHigh': 34.25, 'PreLow': 33.0}

# %%
ticker = '1529'
df = ReadData(api, ticker, date)
df.set_index("datetime").close.plot(figsize=(12,8))
# plt.show()
backtest(api, ticker, date, open_thresholds[ticker]['PreClose'], 
                            PreData=open_thresholds[ticker],max_size=max_size_map[ticker], sl_ratio=0.02)
# Out:
# c:\users\kevin\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_matplotlib\converter.py:256: MatplotlibDeprecationWarning:
# The epoch2num function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   base = dates.epoch2num(dt.asi8 / 1.0e9)
# open_h : 21.75, open_l : 21.05
# Entry at close = 21.55, bid : 21.45, ask : 21.5
# entry:21.5, up_target:21.65, dn_target:21.35
# False False False True
# sl_threshold 21.1, half-high-low :21.4
# Max Ret : 0.7%
# Min Ret : 0.0%
# Signal For Exit : -1
# Calculate PnL at close = 21.65, ask : 21.65 at 2021-12-17 09:10:53
#
# ---------------PnL Summary--------------
# Exit Position of 1529
# Entry : 21.5 at 2021-12-17 09:10:13
# Exit : 21.65 at 2021-12-17 09:10:53
# Trading PnL with Cost : 82
# Total PnL with Cost : 82
# Total Ret with Cost : 0.7%
# Total PnL with Cost of max size 10: 820
# 82

# %%
pnl_ = {}
for ticker in open_thresholds.keys():
    try:
        print(f'backtest : {ticker}')
        condi_1 = (open_thresholds[ticker]['PreClose'] >= 10 and open_thresholds[ticker]['PreClose'] <= 20)
        condi_2 = (open_thresholds[ticker]['PreClose'] >= 100 and open_thresholds[ticker]['PreClose'] <= 200)
#         if not (open_thresholds[ticker]['PreClose'] >= 10 and open_thresholds[ticker]['PreClose'] <= 20):continue
#         if not (open_thresholds[ticker]['PreClose'] >= 100 and open_thresholds[ticker]['PreClose'] <= 200):continue
#         if not any([condi_1, condi_2]):continue
        if open_thresholds[ticker]['PreClose'] > 1000:continue
        pnl_[ticker] = backtest(api, ticker, date, open_thresholds[ticker]['PreClose'], 
                            PreData=open_thresholds[ticker],max_size=max_size_map[ticker], sl_ratio=0.02,
                               entry_percent=.06)
#                                exit_time='10:00:00.000')
    except:
        pass
# Out:
# backtest : 1529
# open_h : 21.75, open_l : 21.05
# Entry at close = 21.55, bid : 21.45, ask : 21.5
# entry:21.5, up_target:21.65, dn_target:21.35
# False False False True
# sl_threshold 21.1, half-high-low :21.4
# Max Ret : 0.7%
# Min Ret : 0.0%
# Signal For Exit : -1
# Calculate PnL at close = 21.65, ask : 21.65 at 2021-12-17 09:10:53
#
# ---------------PnL Summary--------------
# Exit Position of 1529
# Entry : 21.5 at 2021-12-17 09:10:13
# Exit : 21.65 at 2021-12-17 09:10:53
# Trading PnL with Cost : 82
# Total PnL with Cost : 82
# Total Ret with Cost : 0.7%
# Total PnL with Cost of max size 10: 820
#
# backtest : 2495
# open_h : 21.7, open_l : 20.15
# Entry at close = 21.0, bid : 21.0, ask : 21.05
# entry:21.05, up_target:21.2, dn_target:20.95
# False False False True
# sl_threshold 20.65, half-high-low :20.924999999999997
# Max Ret : 0.71%
# Min Ret : -0.24%
# Signal For Exit : -1
# Calculate PnL at close = 21.2, ask : 21.2 at 2021-12-17 09:10:34
#
# ---------------PnL Summary--------------
# Exit Position of 2495
# Entry : 21.05 at 2021-12-17 09:10:01
# Exit : 21.2 at 2021-12-17 09:10:34
# Trading PnL with Cost : 84
# Total PnL with Cost : 84
# Total Ret with Cost : 0.71%
# Total PnL with Cost of max size 10: 840
#
# backtest : 3035
# open_h : 221.5, open_l : 216.0
# Entry at close = 221.0, bid : 220.5, ask : 221.0
# entry:221.0, up_target:222.5, dn_target:219.5
# False False False True
# sl_threshold 217.0, half-high-low :218.75
# Max Ret : 0.68%
# Min Ret : -0.23%
# Signal For Exit : -1
# Calculate PnL at close = 222.5, ask : 222.5 at 2021-12-17 09:10:54
#
# ---------------PnL Summary--------------
# Exit Position of 3035
# Entry : 221.0 at 2021-12-17 09:10:01
# Exit : 222.5 at 2021-12-17 09:10:54
# Trading PnL with Cost : 789
# Total PnL with Cost : 789
# Total Ret with Cost : 0.68%
# Total PnL with Cost of max size 0: 0
#
# backtest : 3041
# open_h : 35.45, open_l : 34.8
# Entry at close = 34.5, bid : 34.45, ask : 34.5
# entry:34.45, up_target:34.65, dn_target:34.3
# False False False True
# sl_threshold 35.1, half-high-low :35.125
# Max Ret : 0.12%
# Min Ret : -1.04%
# Signal For Exit : 1
# Calculate PnL at close = 34.35, ask : 34.4 at 2021-12-17 10:32:55
#
# ---------------PnL Summary--------------
# Exit Position of 3041
# Entry : 34.45 at 2021-12-17 10:15:01
# Exit : 34.35 at 2021-12-17 10:32:55
# Trading PnL with Cost : -10
# Total PnL with Cost : -10
# Total Ret with Cost : 0.29%
# Total PnL with Cost of max size 6: -60
#
# Entry at close = 34.4, bid : 34.35, ask : 34.4
# entry:34.35, up_target:34.55, dn_target:34.15
# False False False True
# sl_threshold 35.0, half-high-low :35.125
# Max Ret : 0.26%
# Min Ret : -1.04%
# Signal For Exit : 1
# Calculate PnL at close = 34.2, ask : 34.2 at 2021-12-17 10:48:01
#
# ---------------PnL Summary--------------
# Exit Position of 3041
# Entry : 34.35 at 2021-12-17 10:35:11
# Exit : 34.2 at 2021-12-17 10:48:01
# Trading PnL with Cost : 41
# Total PnL with Cost : 31
# Total Ret with Cost : 0.44%
# Total PnL with Cost of max size 6: 246
#
# backtest : 3060
# open_h : 28.5, open_l : 27.3
# Entry at close = 28.5, bid : 28.5, ask : 28.55
# entry:28.55, up_target:28.7, dn_target:28.45
# False True False False
# sl_threshold 28.0, half-high-low :27.9
# Max Ret : 0.0%
# Min Ret : -1.93%
# Signal For Exit : -1
# Calculate PnL at close = 28.0, ask : 28.05 at 2021-12-17 10:01:04
#
# ---------------PnL Summary--------------
# Exit Position of 3060
# Entry : 28.55 at 2021-12-17 09:50:05
# Exit : 28.0 at 2021-12-17 10:01:04
# Trading PnL with Cost : -639
# Total PnL with Cost : -639
# Total Ret with Cost : -1.93%
# Total PnL with Cost of max size 7: -4473
#
# Entry at close = 27.3, bid : 27.25, ask : 27.3
# entry:27.25, up_target:27.4, dn_target:27.1
# False False False True
# sl_threshold 27.75, half-high-low :27.9
# Max Ret : 0.23%
# Min Ret : -1.93%
# Signal For Exit : 1
# Calculate PnL at close = 27.1, ask : 27.2 at 2021-12-17 10:36:14
#
# ---------------PnL Summary--------------
# Exit Position of 3060
# Entry : 27.25 at 2021-12-17 10:35:06
# Exit : 27.1 at 2021-12-17 10:36:14
# Trading PnL with Cost : 63
# Total PnL with Cost : -576
# Total Ret with Cost : 0.55%
# Total PnL with Cost of max size 7: 441
#
# backtest : 3443
# open_h : 653.0, open_l : 641.0
# Entry at close = 638.0, bid : 638.0, ask : 639.0
# entry:638.0, up_target:640.0, dn_target:636.0
# False False False True
# sl_threshold 650.0, half-high-low :647.0
# Max Ret : 0%
# Min Ret : -1.26%
# Signal For Exit : 1
# Calculate PnL at close = 635.0, ask : 637.0 at 2021-12-17 09:42:53
#
# ---------------PnL Summary--------------
# Exit Position of 3443
# Entry : 638.0 at 2021-12-17 09:20:06
# Exit : 635.0 at 2021-12-17 09:42:53
# Trading PnL with Cost : 956
# Total PnL with Cost : 956
# Total Ret with Cost : 0.47%
# Total PnL with Cost of max size 0: 0
#
# backtest : 3607
# open_h : 18.7, open_l : 17.4
# Entry at close = 18.4, bid : 18.4, ask : 18.45
# entry:18.45, up_target:18.6, dn_target:18.3
# False True False False
# sl_threshold 18.1, half-high-low :18.049999999999997
# Max Ret : 0.0%
# Min Ret : -1.9%
# Signal For Exit : -1
# Calculate PnL at close = 18.1, ask : 18.15 at 2021-12-17 09:11:57
#
# ---------------PnL Summary--------------
# Exit Position of 3607
# Entry : 18.45 at 2021-12-17 09:10:07
# Exit : 18.1 at 2021-12-17 09:11:57
# Trading PnL with Cost : -407
# Total PnL with Cost : -407
# Total Ret with Cost : -1.9%
# Total PnL with Cost of max size 12: -4884
#
# Entry at close = 17.25, bid : 17.25, ask : 17.3
# entry:17.25, up_target:17.4, dn_target:17.1
# False False False True
# sl_threshold 17.55, half-high-low :18.049999999999997
# Max Ret : 0.56%
# Min Ret : -1.9%
# Signal For Exit : 1
# Calculate PnL at close = 17.2, ask : 17.2 at 2021-12-17 10:56:16
#
# ---------------PnL Summary--------------
# Exit Position of 3607
# Entry : 17.25 at 2021-12-17 10:55:03
# Exit : 17.2 at 2021-12-17 10:56:16
# Trading PnL with Cost : -4
# Total PnL with Cost : -411
# Total Ret with Cost : 0.29%
# Total PnL with Cost of max size 12: -48
#
# backtest : 5258
# open_h : 43.0, open_l : 41.3
# Entry at close = 41.1, bid : 41.05, ask : 41.2
# entry:41.05, up_target:41.25, dn_target:40.85
# False False False True
# sl_threshold 41.85, half-high-low :42.15
# Max Ret : 0.17%
# Min Ret : -0.81%
# Signal For Exit : 1
# Calculate PnL at close = 40.85, ask : 40.9 at 2021-12-17 10:27:21
#
# ---------------PnL Summary--------------
# Exit Position of 5258
# Entry : 41.05 at 2021-12-17 10:25:01
# Exit : 40.85 at 2021-12-17 10:27:21
# Trading PnL with Cost : 70
# Total PnL with Cost : 70
# Total Ret with Cost : 0.49%
# Total PnL with Cost of max size 5: 350
#
# backtest : 6698
# open_h : 55.0, open_l : 53.1
# Entry at close = 55.0, bid : 54.9, ask : 55.0
# entry:55.0, up_target:55.3, dn_target:54.7
# False False False True
# sl_threshold 54.0, half-high-low :54.05
# Max Ret : 0.55%
# Min Ret : -0.55%
# Signal For Exit : -1
# Calculate PnL at close = 55.3, ask : 55.3 at 2021-12-17 09:33:02
#
# ---------------PnL Summary--------------
# Exit Position of 6698
# Entry : 55.0 at 2021-12-17 09:30:04
# Exit : 55.3 at 2021-12-17 09:33:02
# Trading PnL with Cost : 123
# Total PnL with Cost : 123
# Total Ret with Cost : 0.55%
# Total PnL with Cost of max size 3: 369
#
# backtest : 8478
# open_h : 184.5, open_l : 177.0
# Entry at close = 179.0, bid : 178.5, ask : 179.0
# entry:178.5, up_target:180.0, dn_target:177.0
# False False False True
# sl_threshold 182.0, half-high-low :180.75
# Max Ret : 0.52%
# Min Ret : -0.88%
# Signal For Exit : 1
# Calculate PnL at close = 177.5, ask : 177.5 at 2021-12-17 09:28:43
#
# ---------------PnL Summary--------------
# Exit Position of 8478
# Entry : 178.5 at 2021-12-17 09:25:02
# Exit : 177.5 at 2021-12-17 09:28:43
# Trading PnL with Cost : 429
# Total PnL with Cost : 429
# Total Ret with Cost : 0.56%
# Total PnL with Cost of max size 1: 429
#
# backtest : 3114
# open_h : 31.4, open_l : 30.9
# Entry at close = 33.0, bid : 32.85, ask : 33.0
# entry:33.0, up_target:33.2, dn_target:32.8
# False False False True
# sl_threshold 32.35, half-high-low :31.15
# Max Ret : 0.61%
# Min Ret : -0.3%
# Signal For Exit : -1
# Calculate PnL at close = 33.2, ask : 33.2 at 2021-12-17 09:20:10
#
# ---------------PnL Summary--------------
# Exit Position of 3114
# Entry : 33.0 at 2021-12-17 09:20:02
# Exit : 33.2 at 2021-12-17 09:20:10
# Trading PnL with Cost : 94
# Total PnL with Cost : 94
# Total Ret with Cost : 0.61%
# Total PnL with Cost of max size 6: 564
#
# backtest : 3128
# open_h : 28.7, open_l : 27.7
# Entry at close = 27.45, bid : 27.4, ask : 27.45
# entry:27.4, up_target:27.55, dn_target:27.25
# False False False True
# sl_threshold 27.9, half-high-low :28.2
# Max Ret : 0.23%
# Min Ret : -1.23%
# Signal For Exit : 1
# Calculate PnL at close = 27.25, ask : 27.3 at 2021-12-17 09:40:19
#
# ---------------PnL Summary--------------
# Exit Position of 3128
# Entry : 27.4 at 2021-12-17 09:20:04
# Exit : 27.25 at 2021-12-17 09:40:19
# Trading PnL with Cost : 63
# Total PnL with Cost : 63
# Total Ret with Cost : 0.55%
# Total PnL with Cost of max size 7: 441
#
# backtest : 3141
# open_h : 286.5, open_l : 280.0
# Entry at close = 279.0, bid : 278.0, ask : 279.0
# entry:278.0, up_target:279.5, dn_target:276.5
# False False False True
# sl_threshold 283.5, half-high-low :283.25
# Max Ret : 0.22%
# Min Ret : -1.04%
# Signal For Exit : 1
# Calculate PnL at close = 276.5, ask : 277.0 at 2021-12-17 09:52:35
#
# ---------------PnL Summary--------------
# Exit Position of 3141
# Entry : 278.0 at 2021-12-17 09:25:02
# Exit : 276.5 at 2021-12-17 09:52:35
# Trading PnL with Cost : 610
# Total PnL with Cost : 610
# Total Ret with Cost : 0.54%
# Total PnL with Cost of max size 0: 0
#
# backtest : 3390
# open_h : 26.55, open_l : 25.6
# Entry at close = 25.55, bid : 25.5, ask : 25.55
# entry:25.5, up_target:25.65, dn_target:25.35
# False False False True
# sl_threshold 26.0, half-high-low :26.075000000000003
# Max Ret : 0.27%
# Min Ret : -0.91%
# Signal For Exit : 1
# Calculate PnL at close = 25.4, ask : 25.4 at 2021-12-17 11:13:16
#
# ---------------PnL Summary--------------
# Exit Position of 3390
# Entry : 25.5 at 2021-12-17 10:55:13
# Exit : 25.4 at 2021-12-17 11:13:16
# Trading PnL with Cost : 19
# Total PnL with Cost : 19
# Total Ret with Cost : 0.39%
# Total PnL with Cost of max size 8: 152
#
# backtest : 3466
# open_h : 22.8, open_l : 21.6
# Entry at close = 22.75, bid : 22.7, ask : 22.75
# entry:22.75, up_target:22.9, dn_target:22.6
# False False False True
# sl_threshold 22.3, half-high-low :22.200000000000003
# Max Ret : 0.66%
# Min Ret : -1.1%
# Signal For Exit : -1
# Calculate PnL at close = 22.9, ask : 22.9 at 2021-12-17 09:12:54
#
# ---------------PnL Summary--------------
# Exit Position of 3466
# Entry : 22.75 at 2021-12-17 09:10:10
# Exit : 22.9 at 2021-12-17 09:12:54
# Trading PnL with Cost : 78
# Total PnL with Cost : 78
# Total Ret with Cost : 0.66%
# Total PnL with Cost of max size 9: 702
#
# backtest : 3491
# open_h : 212.5, open_l : 208.0
# Entry at close = 209.0, bid : 209.0, ask : 209.5
# entry:209.0, up_target:210.5, dn_target:207.5
# False False False True
# sl_threshold 213.0, half-high-low :210.25
# Max Ret : 0.4%
# Min Ret : -0.56%
# Signal For Exit : 1
# Calculate PnL at close = 207.5, ask : 208.0 at 2021-12-17 09:57:14
#
# ---------------PnL Summary--------------
# Exit Position of 3491
# Entry : 209.0 at 2021-12-17 09:45:06
# Exit : 207.5 at 2021-12-17 09:57:14
# Trading PnL with Cost : 831
# Total PnL with Cost : 831
# Total Ret with Cost : 0.72%
# Total PnL with Cost of max size 1: 831
#
# backtest : 3675
# open_h : 316.0, open_l : 305.0
# Entry at close = 304.0, bid : 303.5, ask : 304.5
# entry:303.5, up_target:305.5, dn_target:301.5
# False False False True
# sl_threshold 309.5, half-high-low :310.5
# Max Ret : 0.34%
# Min Ret : -1.97%
# Signal For Exit : 1
# Calculate PnL at close = 301.0, ask : 302.0 at 2021-12-17 09:37:59
#
# ---------------PnL Summary--------------
# Exit Position of 3675
# Entry : 303.5 at 2021-12-17 09:15:13
# Exit : 301.0 at 2021-12-17 09:37:59
# Trading PnL with Cost : 1529
# Total PnL with Cost : 1529
# Total Ret with Cost : 0.82%
# Total PnL with Cost of max size 0: 0
#
# backtest : 5351
# open_h : 99.7, open_l : 96.3
# Entry at close = 96.8, bid : 96.6, ask : 96.8
# entry:96.6, up_target:96.8, dn_target:96.4
# False False False True
# sl_threshold 98.5, half-high-low :98.0
# Max Ret : 0%
# Min Ret : -1.15%
# Signal For Exit : 1
# Calculate PnL at close = 96.4, ask : 96.4 at 2021-12-17 09:19:45
#
# ---------------PnL Summary--------------
# Exit Position of 5351
# Entry : 96.6 at 2021-12-17 09:15:01
# Exit : 96.4 at 2021-12-17 09:19:45
# Trading PnL with Cost : -109
# Total PnL with Cost : -109
# Total Ret with Cost : 0.21%
# Total PnL with Cost of max size 2: -218
#
# Entry at close = 96.4, bid : 96.4, ask : 96.6
# entry:96.4, up_target:96.6, dn_target:96.3
# False False False True
# sl_threshold 98.3, half-high-low :98.0
# Max Ret : 0%
# Min Ret : -1.15%
# Signal For Exit : 1
# Calculate PnL at close = 96.4, ask : 96.4 at 2021-12-17 09:21:08
#
# ---------------PnL Summary--------------
# Exit Position of 5351
# Entry : 96.4 at 2021-12-17 09:20:01
# Exit : 96.4 at 2021-12-17 09:21:08
# Trading PnL with Cost : -309
# Total PnL with Cost : -418
# Total Ret with Cost : -0.0%
# Total PnL with Cost of max size 2: -618
#
# Entry at close = 97.1, bid : 97.1, ask : 97.2
# entry:97.1, up_target:97.3, dn_target:96.9
# False False False True
# sl_threshold 99.0, half-high-low :98.0
# Max Ret : 0%
# Min Ret : -1.15%
# Signal For Exit : 1
# Calculate PnL at close = 97.0, ask : 97.0 at 2021-12-17 09:26:34
#
# ---------------PnL Summary--------------
# Exit Position of 5351
# Entry : 97.1 at 2021-12-17 09:25:01
# Exit : 97.0 at 2021-12-17 09:26:34
# Trading PnL with Cost : -210
# Total PnL with Cost : -628
# Total Ret with Cost : 0.1%
# Total PnL with Cost of max size 2: -420
#
# Entry at close = 96.5, bid : 96.5, ask : 96.6
# entry:96.5, up_target:96.7, dn_target:96.3
# False False False True
# sl_threshold 98.4, half-high-low :98.0
# Max Ret : 0%
# Min Ret : -1.88%
# Signal For Exit : 1
# Calculate PnL at close = 96.3, ask : 96.4 at 2021-12-17 09:57:35
#
# ---------------PnL Summary--------------
# Exit Position of 5351
# Entry : 96.5 at 2021-12-17 09:30:05
# Exit : 96.3 at 2021-12-17 09:57:35
# Trading PnL with Cost : -109
# Total PnL with Cost : -737
# Total Ret with Cost : 0.21%
# Total PnL with Cost of max size 2: -218
#
# Entry at close = 95.9, bid : 95.8, ask : 95.9
# entry:95.8, up_target:96.0, dn_target:95.6
# False False False True
# sl_threshold 97.7, half-high-low :98.0
# Max Ret : 0%
# Min Ret : -1.88%
# Signal For Exit : 1
# Calculate PnL at close = 95.7, ask : 95.7 at 2021-12-17 10:02:30
#
# ---------------PnL Summary--------------
# Exit Position of 5351
# Entry : 95.8 at 2021-12-17 10:00:02
# Exit : 95.7 at 2021-12-17 10:02:30
# Trading PnL with Cost : -206
# Total PnL with Cost : -943
# Total Ret with Cost : 0.1%
# Total PnL with Cost of max size 2: -412
#
# Entry at close = 95.3, bid : 95.3, ask : 95.4
# entry:95.3, up_target:95.5, dn_target:95.1
# False False False True
# sl_threshold 97.2, half-high-low :98.0
# Max Ret : 0%
# Min Ret : -1.88%
# Signal For Exit : 1
# Calculate PnL at close = 95.2, ask : 95.2 at 2021-12-17 10:08:02
#
# ---------------PnL Summary--------------
# Exit Position of 5351
# Entry : 95.3 at 2021-12-17 10:05:02
# Exit : 95.2 at 2021-12-17 10:08:02
# Trading PnL with Cost : -205
# Total PnL with Cost : -1148
# Total Ret with Cost : 0.1%
# Total PnL with Cost of max size 2: -410
#
# Entry at close = 93.9, bid : 93.9, ask : 94.0
# entry:93.9, up_target:94.1, dn_target:93.8
# False False False True
# sl_threshold 95.7, half-high-low :98.0
# Max Ret : 0%
# Min Ret : -1.88%
# Signal For Exit : 1
# Calculate PnL at close = 93.9, ask : 94.0 at 2021-12-17 10:10:04
#
# ---------------PnL Summary--------------
# Exit Position of 5351
# Entry : 93.9 at 2021-12-17 10:10:01
# Exit : 93.9 at 2021-12-17 10:10:04
# Trading PnL with Cost : -301
# Total PnL with Cost : -1449
# Total Ret with Cost : -0.0%
# Total PnL with Cost of max size 2: -602
#
# Entry at close = 94.8, bid : 94.8, ask : 94.9
# entry:94.8, up_target:95.0, dn_target:94.6
# False False False True
# sl_threshold 96.6, half-high-low :98.0
# Max Ret : 0%
# Min Ret : -1.88%
# Signal For Exit : 1
# Calculate PnL at close = 94.6, ask : 94.5 at 2021-12-17 10:15:50
#
# ---------------PnL Summary--------------
# Exit Position of 5351
# Entry : 94.8 at 2021-12-17 10:15:04
# Exit : 94.6 at 2021-12-17 10:15:50
# Trading PnL with Cost : -103
# Total PnL with Cost : -1552
# Total Ret with Cost : 0.21%
# Total PnL with Cost of max size 2: -206
#
# Entry at close = 95.0, bid : 94.9, ask : 95.0
# entry:94.9, up_target:95.1, dn_target:94.8
# False False False True
# sl_threshold 96.7, half-high-low :98.0
# Max Ret : 0%
# Min Ret : -1.88%
# Signal For Exit : 1
# Calculate PnL at close = 95.0, ask : 95.0 at 2021-12-17 10:21:38
#
# ---------------PnL Summary--------------
# Exit Position of 5351
# Entry : 94.9 at 2021-12-17 10:20:01
# Exit : 95.0 at 2021-12-17 10:21:38
# Trading PnL with Cost : -404
# Total PnL with Cost : -1956
# Total Ret with Cost : -0.11%
# Total PnL with Cost of max size 2: -808
#
# Entry at close = 94.7, bid : 94.7, ask : 94.8
# entry:94.7, up_target:94.9, dn_target:94.6
# False False False True
# sl_threshold 96.5, half-high-low :98.0
# Max Ret : 0%
# Min Ret : -1.88%
# Signal For Exit : 1
# Calculate PnL at close = 94.6, ask : 94.7 at 2021-12-17 10:25:53
#
# ---------------PnL Summary--------------
# Exit Position of 5351
# Entry : 94.7 at 2021-12-17 10:25:07
# Exit : 94.6 at 2021-12-17 10:25:53
# Trading PnL with Cost : -203
# Total PnL with Cost : -2159
# Total Ret with Cost : 0.11%
# Total PnL with Cost of max size 2: -406
#
# Entry at close = 94.7, bid : 94.6, ask : 94.7
# entry:94.6, up_target:94.8, dn_target:94.4
# False False False True
# sl_threshold 96.4, half-high-low :98.0
# Max Ret : 0%
# Min Ret : -1.88%
# Signal For Exit : 1
# Calculate PnL at close = 94.5, ask : 94.5 at 2021-12-17 10:42:01
#
# ---------------PnL Summary--------------
# Exit Position of 5351
# Entry : 94.6 at 2021-12-17 10:30:03
# Exit : 94.5 at 2021-12-17 10:42:01
# Trading PnL with Cost : -202
# Total PnL with Cost : -2361
# Total Ret with Cost : 0.11%
# Total PnL with Cost of max size 2: -404
#
# Entry at close = 94.6, bid : 94.6, ask : 94.7
# entry:94.6, up_target:94.8, dn_target:94.4
# False False False True
# sl_threshold 96.4, half-high-low :98.0
# Max Ret : 0%
# Min Ret : -1.88%
# Signal For Exit : 1
# Calculate PnL at close = 94.6, ask : 94.7 at 2021-12-17 10:50:23
#
# ---------------PnL Summary--------------
# Exit Position of 5351
# Entry : 94.6 at 2021-12-17 10:45:05
# Exit : 94.6 at 2021-12-17 10:50:23
# Trading PnL with Cost : -302
# Total PnL with Cost : -2663
# Total Ret with Cost : -0.0%
# Total PnL with Cost of max size 2: -604
#
# Entry at close = 94.0, bid : 94.0, ask : 94.1
# entry:94.0, up_target:94.2, dn_target:93.8
# False False False True
# sl_threshold 95.8, half-high-low :98.0
# Max Ret : 0%
# Min Ret : -1.88%
# Signal For Exit : 1
# Calculate PnL at close = 93.9, ask : 94.0 at 2021-12-17 11:01:54
#
# ---------------PnL Summary--------------
# Exit Position of 5351
# Entry : 94.0 at 2021-12-17 10:55:02
# Exit : 93.9 at 2021-12-17 11:01:54
# Trading PnL with Cost : -201
# Total PnL with Cost : -2864
# Total Ret with Cost : 0.11%
# Total PnL with Cost of max size 2: -402
#
# Entry at close = 93.4, bid : 93.3, ask : 93.4
# entry:93.3, up_target:93.5, dn_target:93.1
# False False False True
# sl_threshold 95.1, half-high-low :98.0
# Max Ret : 0%
# Min Ret : -1.88%
# Signal For Exit : 1
# Calculate PnL at close = 93.0, ask : 93.3 at 2021-12-17 11:07:02
#
# ---------------PnL Summary--------------
# Exit Position of 5351
# Entry : 93.3 at 2021-12-17 11:05:05
# Exit : 93.0 at 2021-12-17 11:07:02
# Trading PnL with Cost : 2
# Total PnL with Cost : -2862
# Total Ret with Cost : 0.32%
# Total PnL with Cost of max size 2: 4
#
# Entry at close = 92.0, bid : 92.0, ask : 92.1
# entry:92.0, up_target:92.2, dn_target:91.8
# False False False True
# sl_threshold 93.8, half-high-low :98.0
# Max Ret : 0%
# Min Ret : -1.88%
# Signal For Exit : 1
# Calculate PnL at close = 92.0, ask : 92.0 at 2021-12-17 11:41:04
#
# ---------------PnL Summary--------------
# Exit Position of 5351
# Entry : 92.0 at 2021-12-17 11:10:01
# Exit : 92.0 at 2021-12-17 11:41:04
# Trading PnL with Cost : -294
# Total PnL with Cost : -3156
# Total Ret with Cost : -0.0%
# Total PnL with Cost of max size 2: -588
#
# Entry at close = 92.1, bid : 92.1, ask : 92.2
# entry:92.1, up_target:92.3, dn_target:91.9
# False False False True
# sl_threshold 93.9, half-high-low :98.0
# Max Ret : 0%
# Min Ret : -1.88%
# Signal For Exit : 1
# Calculate PnL at close = 91.9, ask : 92.0 at 2021-12-17 12:06:10
#
# ---------------PnL Summary--------------
# Exit Position of 5351
# Entry : 92.1 at 2021-12-17 11:45:10
# Exit : 91.9 at 2021-12-17 12:06:10
# Trading PnL with Cost : -94
# Total PnL with Cost : -3250
# Total Ret with Cost : 0.22%
# Total PnL with Cost of max size 2: -188
#
# Entry at close = 91.5, bid : 91.4, ask : 91.5
# entry:91.4, up_target:91.6, dn_target:91.3
# False False False True
# sl_threshold 93.2, half-high-low :98.0
# Max Ret : 0%
# Min Ret : -1.88%
# Signal For Exit : 1
# Calculate PnL at close = 91.3, ask : 91.4 at 2021-12-17 12:10:23
#
# ---------------PnL Summary--------------
# Exit Position of 5351
# Entry : 91.4 at 2021-12-17 12:10:03
# Exit : 91.3 at 2021-12-17 12:10:23
# Trading PnL with Cost : -193
# Total PnL with Cost : -3443
# Total Ret with Cost : 0.11%
# Total PnL with Cost of max size 2: -386
#
# Entry at close = 90.3, bid : 90.3, ask : 90.4
# entry:90.3, up_target:90.5, dn_target:90.1
# True False False False
# sl_threshold 92.1, half-high-low :98.0
# Max Ret : 0%
# Min Ret : -1.88%
# Signal For Exit : 1
# Calculate PnL at close = 90.3, ask : 90.4 at 2021-12-17 12:15:01
#
# ---------------PnL Summary--------------
# Exit Position of 5351
# Entry : 90.3 at 2021-12-17 12:15:01
# Exit : 90.3 at 2021-12-17 12:15:01
# Trading PnL with Cost : -289
# Total PnL with Cost : -3732
# Total Ret with Cost : -0.0%
# Total PnL with Cost of max size 2: -578
#
# Entry at close = 91.6, bid : 91.5, ask : 91.6
# entry:91.5, up_target:91.7, dn_target:91.3
# False False False True
# sl_threshold 93.3, half-high-low :98.0
# Max Ret : 0%
# Min Ret : -1.88%
# Signal For Exit : 1
# Calculate PnL at close = 91.4, ask : 91.5 at 2021-12-17 12:21:21
#
# ---------------PnL Summary--------------
# Exit Position of 5351
# Entry : 91.5 at 2021-12-17 12:20:01
# Exit : 91.4 at 2021-12-17 12:21:21
# Trading PnL with Cost : -193
# Total PnL with Cost : -3925
# Total Ret with Cost : 0.11%
# Total PnL with Cost of max size 2: -386
#
# Entry at close = 91.5, bid : 91.4, ask : 91.5
# entry:91.4, up_target:91.6, dn_target:91.3
# False True False False
# sl_threshold 93.2, half-high-low :98.0
# Max Ret : 0%
# Min Ret : -2.29%
# Signal For Exit : 1
# Calculate PnL at close = 93.2, ask : 93.2 at 2021-12-17 12:55:33
#
# ---------------PnL Summary--------------
# Exit Position of 5351
# Entry : 91.4 at 2021-12-17 12:25:10
# Exit : 93.2 at 2021-12-17 12:55:33
# Trading PnL with Cost : -2094
# Total PnL with Cost : -6019
# Total Ret with Cost : -1.97%
# Total PnL with Cost of max size 2: -4188
#
# backtest : 5371
# open_h : 87.8, open_l : 85.8
# Entry at close = 86.0, bid : 85.9, ask : 86.2
# entry:85.9, up_target:86.3, dn_target:85.6
# False False False True
# sl_threshold 87.6, half-high-low :86.8
# Max Ret : 0.03%
# Min Ret : -0.67%
# Signal For Exit : 1
# Calculate PnL at close = 85.6, ask : 85.9 at 2021-12-17 09:10:09
#
# ---------------PnL Summary--------------
# Exit Position of 5371
# Entry : 85.9 at 2021-12-17 09:10:02
# Exit : 85.6 at 2021-12-17 09:10:09
# Trading PnL with Cost : 25
# Total PnL with Cost : 25
# Total Ret with Cost : 0.35%
# Total PnL with Cost of max size 2: 50
#
# backtest : 6104
# open_h : 209.5, open_l : 202.0
# Entry at close = 209.0, bid : 209.0, ask : 209.5
# entry:209.5, up_target:211.0, dn_target:208.0
# False False False True
# sl_threshold 205.5, half-high-low :205.75
# Max Ret : 0.72%
# Min Ret : -0.48%
# Signal For Exit : -1
# Calculate PnL at close = 211.0, ask : 211.0 at 2021-12-17 09:16:48
#
# ---------------PnL Summary--------------
# Exit Position of 6104
# Entry : 209.5 at 2021-12-17 09:15:01
# Exit : 211.0 at 2021-12-17 09:16:48
# Trading PnL with Cost : 825
# Total PnL with Cost : 825
# Total Ret with Cost : 0.72%
# Total PnL with Cost of max size 1: 825
#
# backtest : 6156
# open_h : 22.0, open_l : 21.1
# Entry at close = 22.0, bid : 21.95, ask : 22.0
# entry:22.0, up_target:22.15, dn_target:21.85
# False True False False
# sl_threshold 21.6, half-high-low :21.55
# Max Ret : 0.23%
# Min Ret : -1.82%
# Signal For Exit : -1
# Calculate PnL at close = 21.6, ask : 21.7 at 2021-12-17 09:23:14
#
# ---------------PnL Summary--------------
# Exit Position of 6156
# Entry : 22.0 at 2021-12-17 09:10:05
# Exit : 21.6 at 2021-12-17 09:23:14
# Trading PnL with Cost : -468
# Total PnL with Cost : -468
# Total Ret with Cost : -1.82%
# Total PnL with Cost of max size 9: -4212
#
# Entry at close = 21.15, bid : 21.1, ask : 21.15
# entry:21.1, up_target:21.25, dn_target:21.0
# False False False True
# sl_threshold 21.5, half-high-low :21.55
# Max Ret : 0.23%
# Min Ret : -1.82%
# Signal For Exit : 1
# Calculate PnL at close = 21.0, ask : 21.1 at 2021-12-17 09:53:12
#
# ---------------PnL Summary--------------
# Exit Position of 6156
# Entry : 21.1 at 2021-12-17 09:51:04
# Exit : 21.0 at 2021-12-17 09:53:12
# Trading PnL with Cost : 34
# Total PnL with Cost : -434
# Total Ret with Cost : 0.47%
# Total PnL with Cost of max size 9: 306
#
# backtest : 6185
# open_h : 15.75, open_l : 14.85
# Entry at close = 14.9, bid : 14.9, ask : 14.95
# entry:14.9, up_target:15.0, dn_target:14.85
# False False False True
# sl_threshold 15.15, half-high-low :15.3
# Max Ret : 0.02%
# Min Ret : -0.32%
# Signal For Exit : 1
# Calculate PnL at close = 14.9, ask : 14.9 at 2021-12-17 12:01:00
#
# ---------------PnL Summary--------------
# Exit Position of 6185
# Entry : 14.9 at 2021-12-17 12:00:07
# Exit : 14.9 at 2021-12-17 12:01:00
# Trading PnL with Cost : -47
# Total PnL with Cost : -47
# Total Ret with Cost : -0.0%
# Total PnL with Cost of max size 14: -658
#
# Entry at close = 14.85, bid : 14.8, ask : 14.85
# entry:14.8, up_target:14.9, dn_target:14.75
# False False True False
# sl_threshold 15.05, half-high-low :15.3
# Max Ret : 0.02%
# Min Ret : -1.32%
# Signal For Exit : 1
# Calculate PnL at close = 14.9, ask : 14.9 at 2021-12-17 13:02:11
#
# ---------------PnL Summary--------------
# Exit Position of 6185
# Entry : 14.8 at 2021-12-17 12:05:34
# Exit : 14.9 at 2021-12-17 13:02:11
# Trading PnL with Cost : -146
# Total PnL with Cost : -193
# Total Ret with Cost : -0.68%
# Total PnL with Cost of max size 14: -2044
#
# backtest : 8089
# open_h : 33.7, open_l : 32.5
# Entry at close = 33.6, bid : 33.6, ask : 33.7
# entry:33.7, up_target:33.9, dn_target:33.55
# False True False False
# sl_threshold 33.05, half-high-low :33.1
# Max Ret : 0%
# Min Ret : -1.93%
# Signal For Exit : -1
# Calculate PnL at close = 33.0, ask : 33.2 at 2021-12-17 09:15:18
#
# ---------------PnL Summary--------------
# Exit Position of 8089
# Entry : 33.7 at 2021-12-17 09:10:07
# Exit : 33.0 at 2021-12-17 09:15:18
# Trading PnL with Cost : -805
# Total PnL with Cost : -805
# Total Ret with Cost : -2.08%
# Total PnL with Cost of max size 6: -4830
#
# Entry at close = 33.3, bid : 33.3, ask : 33.4
# entry:33.4, up_target:33.6, dn_target:33.2
# False True False False
# sl_threshold 32.75, half-high-low :33.1
# Max Ret : 0%
# Min Ret : -1.95%
# Signal For Exit : -1
# Calculate PnL at close = 32.75, ask : 33.1 at 2021-12-17 10:42:21
#
# ---------------PnL Summary--------------
# Exit Position of 8089
# Entry : 33.4 at 2021-12-17 10:27:10
# Exit : 32.75 at 2021-12-17 10:42:21
# Trading PnL with Cost : -755
# Total PnL with Cost : -1560
# Total Ret with Cost : -1.95%
# Total PnL with Cost of max size 6: -4530
#
# Entry at close = 32.25, bid : 32.2, ask : 32.7
# entry:32.2, up_target:32.4, dn_target:32.05
# False False False True
# sl_threshold 32.8, half-high-low :33.1
# Max Ret : 0.15%
# Min Ret : -1.95%
# Signal For Exit : 1
# Calculate PnL at close = 32.05, ask : 32.05 at 2021-12-17 10:55:05
#
# ---------------PnL Summary--------------
# Exit Position of 8089
# Entry : 32.2 at 2021-12-17 10:45:02
# Exit : 32.05 at 2021-12-17 10:55:05
# Trading PnL with Cost : 48
# Total PnL with Cost : -1512
# Total Ret with Cost : 0.47%
# Total PnL with Cost of max size 6: 288

# %%
single_pnl = 0
max_pnl = 0
trade_value = 0
for ticker in pnl_.keys():
    print(ticker, pnl_[ticker])
    trade_value += open_thresholds[ticker]['PreClose'] * 1000
    single_pnl += pnl_[ticker]
    max_pnl += pnl_[ticker] * max_size_map[ticker]
    
print(f'交易量 : {trade_value}')
print(f'single pnl sum : {single_pnl}')
print(f'max pnl sum : {max_pnl}')
results[date] = single_pnl
# Out:
# 1529 82
# 2495 84
# 3035 789
# 3041 31
# 3060 -576
# 3443 956
# 3607 -411
# 5258 70
# 6698 123
# 8478 429
# 3114 94
# 3128 63
# 3141 610
# 3390 19
# 3466 78
# 3491 831
# 3675 1529
# 5351 -6019
# 5371 25
# 6104 825
# 6156 -434
# 6185 -193
# 8089 -1512
# 交易量 : 2675400.0
# single pnl sum : -2507
# max pnl sum : -30123

# %%
df = pd.DataFrame([{'datetime':k, 'pnl':v}for k, v in results.items()]).sort_values("datetime")

# %%
df
# Out:
#     datetime   pnl
# 0 2021-12-17  -276
# 1 2021-12-20   270
# 2 2021-12-21   633
# 3 2021-12-22  -180
# 4 2021-12-23  1039

# %%
df.set_index('datetime').cumsum().plot()#[datetime(2022,1,1):].cumsum()#.plot()# [datetime(2022,1,1):]
# Out:
# <AxesSubplot:xlabel='datetime'>

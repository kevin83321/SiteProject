# %%
import shioaji as sj
from datetime import datetime, timedelta
import pandas as pd
import numpy as np
import pytz
from copy import deepcopy

import json
import os 
parent = os.path.dirname(os.path.abspath("__file__"))
StrongPath = os.path.join(parent, 'StrongTickers')
if not os.path.isdir(StrongPath):
    os.makedirs(StrongPath)
# import matplotlib.pyplot as plt
# %matplotlib inline

# %%
api = sj.Shioaji()
api.login('F128497445', '89118217k')
# Out:
# Response Code: 0 | Event Code: 0 | Info: host '203.66.91.161:80', hostname '203.66.91.161:80' IP 203.66.91.161:80 (host 1 of 1) (host connection attempt 1 of 1) (total connection attempt 1 of 1) | Event: Session up
# [FutureAccount(person_id='F128497445', broker_id='F002000', account_id='1473661', signed=True, username='鄭圳宏'),
#  Account(account_type=<AccountType.H: 'H'>, person_id='F128497445', broker_id='9A92', account_id='0011645', username='鄭圳宏'),
#  StockAccount(person_id='F128497445', broker_id='9A92', account_id='0231901', signed=True, username='鄭圳宏\u3000\u3000')]

# %%
def ReadEarnedTicks():
    earned_ticks = {'price':[], 'ticks':[]}
    with open(os.path.join(parent, 'EarnedTicks.txt'), "r") as f:
        lines = f.readlines()
        for line in lines[1:]:
            earned_ticks['price'].append(int(line.split(',')[0]))
            earned_ticks['ticks'].append(int(line.split(',')[1].strip()))
            
        return earned_ticks

# %%
earned_ticks = ReadEarnedTicks()

# %%
def getEarnedTicks(entry_price,upTrend=True):
    tmp_p = deepcopy(earned_ticks['price'])
    tmp_t = deepcopy(earned_ticks['ticks'])
    tmp_p.append(entry_price)
    tmp_p = sorted(tmp_p)
    if upTrend:
        idx = tmp_p.index(entry_price)
    else:
        idx = tmp_p.index(entry_price) - 1
    try:
        return tmp_t[idx]#*int(round(bool(not upTrend)*1.3))
    except:
        return tmp_t[0]#*int(round(bool(not upTrend)*1.2))

# %%
def getTargetPrice(entry_price, upTrend=True, sl=1):
    num_ticks = getEarnedTicks(entry_price,upTrend)
    print(num_ticks)
    tmp_up_target = dn_target = up_target = entry_price
    for i in range(num_ticks):
        up_target += get_minimum_tick(up_target)
    up_target = round(up_target, 2)
    for i in range(num_ticks-1):
        tmp_up_target += get_minimum_tick(tmp_up_target)
    tmp_up_target = round(tmp_up_target, 2)
    while 1:
        tick = get_minimum_tick(dn_target)
        small_tick = get_minimum_tick(dn_target-tick)
        dn_target -= min(tick, small_tick)
        if (entry_price - round(dn_target, 2)) > (tmp_up_target - entry_price):
            break
    print(f'entry:{entry_price}, up_target:{up_target}, dn_target:{round(dn_target, 2)}')
    if sl:
        if upTrend:
            for i in range(2):
                tick = get_minimum_tick(dn_target)
                small_tick = get_minimum_tick(dn_target-tick)
                dn_target -= min(tick, small_tick)
        else:
            for i in range(2):
                up_target += get_minimum_tick(up_target)
            
    if upTrend:
        return round(up_target, 2), round(dn_target, 2)        
    else:
        return round(dn_target, 2), round(up_target, 2)

def getLimit(price, pct=0.1, trend="U"):
    tmp_price = price
    if trend == "U":
        while 1:
            tick = get_minimum_tick(tmp_price)
            tmp_price += tick
            if (tmp_price/price) > 1 + pct:
                tmp_price -= tick
                break
    elif trend == "D":
        while 1:
            tick = get_minimum_tick(tmp_price)
            tmp_price -= tick
            if (tmp_price/price) < 1 - pct:
                tmp_price += tick
                break
            
    return round(tmp_price, 2)
#     return round(entry_price, 2)

# %%
getTargetPrice(96.6, 0)
# Out:
# 4
# entry:96.6, up_target:97.0, dn_target:96.2
# (96.2, 97.2)

# %%
results = {}

# %%
from typing import Callable, List
from enum import Enum

from datetime import datetime, timedelta

from typing import List
from copy import deepcopy

class AttrDict(dict):
    def __init__(self, *args, **kwargs):
        super(AttrDict, self).__init__(*args, **kwargs)
        self.__dict__ = self
        
class BaseData(AttrDict):
    
    def __init__(self, *args, **kwargs):
        super(BaseData, self).__init__(*args, **kwargs)
        
class TickData(BaseData):
    """
    儲存即時收到的Info報價
    """
    def __init__(self, *args, **kwargs):
        super(TickData, self).__init__(*args, **kwargs)
        
class BarData(BaseData):
    """
    儲存即時收到的Info報價
    """
    def __init__(self, *args, **kwargs):
        super(BarData, self).__init__(*args, **kwargs)

class TradeMode(Enum):
    """
    交易模式
    """
    REALTIME = '實盤交易'
    SIMULATION = '模擬交易'
    BACKTEST = '回測'
    BACKTESTINTRADAY = '日內回測'

# 資料格式 (RealTime)
class Interval(Enum):
    """
    資料頻率
    """
    TICK = '逐筆'
    MINUTE = '分K'
    HOUR = '小時K'
    DAILY = '日K'

class BarGenerator:
    """
    For:
    1. generateing x minute bar/x hour bar data from tick data

    Notice:
    1. x can be any number
    """

    def __init__(self, ticker: str, interval: Interval = Interval.MINUTE, window: int = 5,
                 trademode: TradeMode = TradeMode.REALTIME, 
                 callback: Callable = None, size=15, date=datetime.today()):
        """
        Constructor
        """
        self.ticker = ticker
        self.interval = interval
        self.window = window
        self._trademode = trademode
        self.callback = callback

        self.setupBarCycle(interval, window)
        self.bars: List[BarData] = []
        self.inited = False
        self.barCount = 0
        self.size = size
        self.date = date

    def setupBarCycle(self, interval, window) -> None:
        if self._trademode in [TradeMode.REALTIME, TradeMode.SIMULATION]:
            self.current = date.replace(hour=9,minute=0,second=0,microsecond=0)#datetime.now().replace(second=0)
        elif self._trademode == TradeMode.BACKTESTINTRADAY:
            self.current = 84500
        self._intervalCycle(interval, window)

    def _intervalCycle(self, interval: Interval, window: int):
        if self._trademode in [TradeMode.REALTIME, TradeMode.SIMULATION]:
            if interval == Interval.MINUTE:
                self.cycle = timedelta(seconds=60 * window)
            elif interval == Interval.HOUR:
                self.cycle = timedelta(seconds=60 * 60 * window)
        elif self._trademode == TradeMode.BACKTESTINTRADAY:
            if interval == Interval.MINUTE:
                self.cycle = 100 * window
            elif interval == Interval.HOUR:
                self.cycle = 100 * 100 * window

    def updateBar(self, tick: TickData):
        try:
            if self._trademode == TradeMode.BACKTESTINTRADAY:
                return self._updateBarBacktest(tick)
            return self._updateBar(tick)
        except:
            raise

    def _updateBar(self, tick: TickData):
        try:
            try:
                time, close, volume = tick.time, tick.close, tick.volume
            except:
                # print(tick)
                time, close, volume = tick['time'], tick['close'], tick['volume']
            if not self.bars or time > self.current:
                self.bars.append(self._createNewBar(time, close, volume))
                self._updateCurBarTime()
                if len(self.bars) >= self.size:
                    self.inited = True
                if len(self.bars) > 1:
#                     print(self.bars[-2])
                    return self.bars[-2]
                    if self.callback:
                        self.callback(self.bars[-2])
            else:
                self._updateCurBar(close, volume)
        except:
            raise

    def _updateBarBacktest(self, tick: TickData):
        time, close, volume = tick.time, tick.close, tick.volume
        if not self.bars or time > self.current:
            self.bars.append(self._createNewBar(time, close, volume))
            self._updateCurBarTime()
            if len(self.bars) >= self.size:
                self.inited = True
            if len(self.bars) > 1:
                self.callback(self.bars[-2])
        else:
            self._updateCurBar(close, volume)
            
    def _createNewBar(self, time, close, volume):
        return BarData(
                    symbol=self.ticker,
                    time=time,
                    open=close,
                    high=close,
                    low=close,
                    close=close,
                    volume=volume
                )
    
    def _updateCurBar(self, close, volume):
        curBar = self.bars[-1]
        curBar.high = max(curBar.high, close)
        curBar.low = min(curBar.low, close)
        curBar.close = close
        curBar.volume += volume
        self.bars[-1] = curBar

    def _updateCurBarTime(self):
        self.current += self.cycle
        if self._trademode in [TradeMode.REALTIME, TradeMode.SIMULATION]:
            return
        elif self._trademode == TradeMode.BACKTESTINTRADAY:
            timeList = self._intTolist(self.current)
            if self.interval == Interval.MINUTE:
                if timeList[1] >= 60:
                    timeList[0] += 1
                    timeList[1] -= 60
            if timeList[0] >= 24:
                timeList[0] -= 24
            self.current = int(''.join([str(int(x)) for x in timeList]))

    def _intTolist(self, t):
        ss = t % 100
        t /= 100
        mm = t % 100
        hh = t / 100
        return [int(hh), int(mm), int(ss)]

    @property
    def closes(self):
        return [getattr(bar, 'close') for bar in self.bars][:-1]

    @property
    def opens(self):
        return [getattr(bar, 'open') for bar in self.bars][:-1]

    @property
    def highs(self):
        return [getattr(bar, 'high') for bar in self.bars][:-1]

    @property
    def lows(self):
        return [getattr(bar, 'low') for bar in self.bars][:-1]

    @property
    def volumes(self):
        return [getattr(bar, 'volume') for bar in self.bars][:-1]

# %%
def readStrongTicker(dtStr, atr=""):
    datapath = os.path.join(StrongPath+atr, f'{dtStr}_tradableTicker.json')
    if not os.path.isfile(datapath):
        datapath = os.path.join(StrongPath+atr, f'{dtStr}_strongTicker.json')
#         with open(os.path.join(StrongPath, f'{dtStr}_tradableTicker.json'), 'r') as f:
#             tickers = json.load(f)
#             return tickers
    if os.path.isfile(datapath):
        with open(datapath, 'r') as f:
            tickers = json.load(f)
            return tickers
    else:
        return {}

def get_minimum_tick(cost):
    if cost < 10:
        return 0.01
    elif cost < 50:
        return 0.05
    elif cost < 100:
        return 0.1
    elif cost < 500:
        return 0.5
    elif cost < 1000:
        return 1
    else:
        return 5
    
def get_commission(price:float, multiplier:int=1000, qty=1, Real:bool=True, direction:str='', dayTrade:bool=False):
    """
    計算個別部位的單邊交易成本

    Params:
        symbol : 商品代碼
        exchange : 交易所
        cost : 交易價格
        multiplier : 價格還原現金之乘數
            例如:
                股票 : 1張 = 1,000股，10元的股票還原現金價值，即為10 *1,000 = 10,000元
                期貨 : 台指期1點200元，假設現在10,000點，則一口台股的價值為 200 * 10,000 = 2,000,000
        qty : 買賣口數或張數
        Real : 是否為實單, default = False
        direction : 交易方向 進場(買賣)或出場
            P.S. 股票交易的交易稅是出場才計算
    """
    tick = get_minimum_tick(price)
    commission = price * (0.1425 / 100) * multiplier * qty
    commission = 20 if commission < 20 else commission
    fee = price * (0.3 / 100) * multiplier * qty
    if dayTrade:
        fee /= 2
    slide = tick * multiplier
    tradeCost = commission# * 0.6
    if direction == 'EXIT' or direction == 0:
        tradeCost += fee
    if not Real:
        tradeCost += slide * qty
    return tradeCost

# %%
def ReadData(api, ticker, date):
    dateStr = date.strftime("%Y-%m-%d")
    contact = api.Contracts.Stocks[ticker]
    data = api.ticks(contact, dateStr, 
            query_type=sj.constant.TicksQueryType.RangeTime, 
            time_start='09:00:00',#datetime(2021,11,5,8,45,0).time(),
           time_end='13:30:00')#datetime(2021,11,5,13,45,0).time())
    df = pd.DataFrame(data.dict())
    df['datetime'] = df.ts.apply(lambda x: datetime.utcfromtimestamp(int(str(x)[:10])).astimezone(pytz.timezone('Asia/Taipei')))
    df['datetime'] = pd.to_datetime(df['datetime'].apply(lambda x: x.strftime("%Y-%m-%d %H:%M:%S.%f")))
    return df

# %%
def backtest(api:sj.Shioaji, ticker:str, date:datetime, open_threshold:float=0, PreData:dict={},
             v_threshold:float=.01, entry_percent:float=.05, exit_percent:float=.09, 
             takeprofit:float=.6, start_moving_take = .015, sl_ratio:float=.02, max_size:float = 1, 
             exit_time:str='13:00:00.000000', show_debug=False): # 

    # prepare data
    df = ReadData(api, ticker, date)
    
    # setting Parameters
    opening = False
    closing = False
    
    pre_time:str="09:00:00"
    pre_volume:int = 0
    pre_close:int = 0
    total_v:int = 0 
    refPrice:float = PreData.get('PreClose', 0)
    preHigh:float = PreData.get('PreHigh', PreData.get('PreClose', 0))
#     preLow:float = PreData.get('PreLow', 9999)
    entry_threshold:float = 0 if not refPrice else refPrice * (1 + entry_percent)
    exit_threshold:float = 0 if not refPrice else refPrice * (1 + exit_percent)
    max_ret:float = 0
    min_ret:float = 0
    tmp_ret:float = 0
    pos = 0
    sig = 0
    traded = 0
    long_traded = short_traded = 0
    entry = 0
    entry_time = 0

#     preHigh = 0
#     preLow = 9999
    sl_threshold = 0
    short_sl_ratio = .02
    
    pnl:float = 0
    total_volume = 0
#     first_5mink = {'open':None, 'high':0,'low':9999, 'close':0}
        
    entry_time = ''
    exit_pos_time = ''
    tmp_pnl = 0
    barG = BarGenerator(ticker, date=date)
    open_l = open_h = None
    total_pnl = 0
    vols = []
    vma5 = []
    vma10 = []
    inter_h = None
    inter_l = None
    max_v = 0
    cost = 0
    
    for row in df.itertuples():
#         print(row)
        price = row.close
        time = row.datetime
        qty = row.volume
        if not qty: continue
        total_volume += qty
        tick = TickData(time=time, close=price,volume=qty)
        update_bar = barG.updateBar(tick)
        if update_bar and not pos:
#             print(update_bar)
            if len(barG.bars) >= 3 and not (open_h and open_l):
                open_h = max(barG.highs[:2])
                open_l = min(barG.lows[:2])
                print(f"open_h : {open_h}, open_l : {open_l}")
#             vols.append(update_bar.volume)
#             if len(vols) >= 5:
#                 vma5.append(np.mean(vols[-5:]))
#             if len(vols) >= 10:
#                 vma10.append(np.mean(vols[-10:]))
        if update_bar:
            if update_bar.volume > max_v:
                max_v = update_bar.volume
                inter_h = update_bar.high
                inter_l = update_bar.low
                continue
        if len(barG.bars) < 2:
            continue
        if time <= time.replace(hour=13,minute=0,second=0, microsecond=0) and not pos:
            if not pos and not sig and not traded: # check signal without position
                if update_bar:
                    if show_debug:
                        print(f"大量5分K高點 : {inter_h}, 大量5分K低點 : {inter_l}")
                        print(update_bar)
                    if barG.bars[0].open > refPrice:
                        if update_bar.close >= inter_h and price <= refPrice * (1 + entry_percent):
                            sig = 1
                            oneTradeOnly=True
                        elif update_bar.close <= inter_l and price >= refPrice * (1 - entry_percent) and price <= refPrice:
                            sig = -1
                            oneTradeOnly=True
                    elif barG.bars[0].open < refPrice:
                        if update_bar.close >= inter_h and price <= refPrice * (1 + entry_percent) and price >= refPrice:
                            sig = 1
                            oneTradeOnly=True
                        elif update_bar.close <= inter_l and price >= refPrice * (1 - entry_percent):
                            sig = -1
                            oneTradeOnly=True
#                 if update_bar and vma5 and vma10:
#                     if vma5[-2] <= vma10[-1] and vma5[-1] > vma10[-1] and price <= entry_threshold:
#                         sig = 1
#                         oneTradeOnly=True
#                 if not short_traded:
#                 if open_l and price < open_l and row.datetime.strftime('%H:%M:%S.%f') >= "12:00:00.000000" and not short_traded:
#                     print("Entry Short signal with price touch")
#                     sig = -1
#                     oneTradeOnly = True
#                 elif update_bar and open_l and update_bar['close'] < open_l and not short_traded: # update_bar['open']
#                     print(f"5m Bar CLose :{update_bar['close']}, open low : {open_l}")
# #                     print("Entry Short signal with price low open threshold")
# # #                     print(','.join([str(x) for x in [update_bar['close'], open_l]]))
#                     sig = -1
#                     oneTradeOnly = True
#                 elif min(barG.bars[0]['open'], barG.bars[0]['close']) * .995 and price >= refPrice * (1 - entry_percent) and not short_traded:
#                     sig = -1
#                     oneTradeOnly = True
#                 elif update_bar and open_h and update_bar['close'] > open_h and update_bar['close'] <= entry_threshold and not long_traded:
#                 if price > max(barG.bars[0]['open'], barG.bars[0]['close'], preHigh) * 1.005 and price <= entry_threshold and not long_traded: # ,preHigh
#                     sig = 1
#                     oneTradeOnly = True
            elif not pos and sig: # entry market
                print(f"Entry at close = {price}, bid : {row.bid_price}, ask : {row.ask_price}")
                if sig > 0:
                    entry = row.ask_price
                elif sig < 0:
                    entry = row.bid_price
                if abs(entry / price - 1) >= .005:
                    entry = price
                pos, sig = sig, 0
                entry_time = row.datetime
                target, sl_threshold = getTargetPrice(entry, pos > 0)
                sl_threshold = getLimit(entry, sl_ratio, 'D')# * (1 - sl_ratio * pos)
                if pos == -1:
#                     short_sl_ratio = open_h / entry - 1
                    sl_threshold = getLimit(entry, sl_ratio)
#                     sl_threshold = entry * (1 - short_sl_ratio * pos)
#                     sl_threshold = min(sl_threshold, (open_h + open_l) / 2)
                    
                    
        elif pos and not sig: # check signal with position
            tmp_pnl = (price - entry) * 1000 * pos
            cost = int(get_commission(entry if pos > 0 else price)) # 進場成本
            cost += int(get_commission(price if pos > 0 else entry, direction='EXIT', dayTrade=True)) # 出場成本
#             tmp_pnl -= int(get_commission(entry if pos > 0 else price)) # 進場成本
#             tmp_pnl -= int(get_commission(price if pos > 0 else entry, direction='EXIT', dayTrade=True)) # 出場成本
#             if pos > 0:
            tmp_pnl -= cost
            tmp_ret = ((price / entry) - 1) * pos
#             else:
#                 tmp_ret = (tmp_pnl / (entry * 1000))# - 1
#             print(f"Tmp PnL : {tmp_pnl}")
            
#             if tmp_ret > max_ret:
# #                 sl_threshold = entry * (1 - sl_ratio * pos)
#                 sl_threshold = price * (1 - sl_ratio * pos)
#                 if pos == -1:
#                     sl_threshold = price * (1 - short_sl_ratio * self.pos)
#                     sl_threshold = min(sl_threshold, (open_h + open_l) / 2)
#                 sl_threshold = min(price * (1 - sl_ratio * pos), (open_h + open_l) / 2)
#                 print(row.datetime, price * (1 + sl_ratio), (open_h + open_l) / 2, sl_threshold)
            max_ret = max(tmp_ret, max_ret)
            min_ret = min(tmp_ret, min_ret)
#             print(f"close : {price}, pos : {pos}, tmp_pnl : {tmp_pnl}, max_ret : {max_ret}")
            
#             do_exit_take = False #tmp_ret >= 0.01 and ((entry_time.strftime('%H:%M:%S.%f') >= "12:00:00.000000") or pos == 1)
            do_exit_take = ((pos > 0) and price >= target) or ((pos < 0) and  price <= target)
                    
#             if max_ret >= start_moving_take:
#                 do_exit_take = (tmp_ret / max_ret) <= (takeprofit) if max_ret else False
#             do_exit_stop = price > sl_threshold if pos == -1 else price < sl_threshold
            do_exit_stop = tmp_ret <= -sl_ratio#((pos > 0) and price <= sl_threshold) or ((pos < 0) and  price >= sl_threshold)
            do_exit = price >= exit_threshold if pos > 0 else price <= (refPrice * (1 - exit_percent))

            exit_end = time.strftime('%H:%M:%S.%f') >= exit_time
            if any([do_exit, do_exit_stop, exit_end, do_exit_take]): # 
                print(do_exit, do_exit_stop, exit_end, do_exit_take)
                try:
                    print(f"sl_threshold {sl_threshold}, half-high-low :{(open_h + open_l) / 2}")
                except:
                    pass
                print(f"Max Ret : {round(max_ret*100,2)}%")
                print(f"Min Ret : {round(min_ret*100,2)}%")
                sig = -pos
                print(f"Signal For Exit : {sig}")
#                     self.closing=True
#                     self.DoTrade('S' if self.pos > 0 else 'B')
#                     self.sendNotifyExit(self.q20_data['datetime'].strftime("%H:%M:%S.%f"), self.symbol, self.name,
#                                      close, self.q20_data['pct_chg'], do_exit_take or do_exit)
        elif pos and sig:
            signal_time = row.datetime
            print(f"Calculate PnL at close = {price}, ask : {row.ask_price} at {row.datetime}")
#             if sig > 0:
#                 exit = row.ask_price
#             elif sig < 0:
#                 exit = row.bid_price
#             if abs(exit / price - 1) >= .005:
            exit = price
            tmp_pnl = (exit - entry) * 1000 * pos
            cost = int(get_commission(entry if pos > 0 else price)) # 進場成本
            cost += int(get_commission(price if pos > 0 else entry, direction='EXIT', dayTrade=True)) # 出場成本
#             tmp_pnl -= int(get_commission(entry if pos > 0 else price)) # 進場成本
#             tmp_pnl -= int(get_commission(price if pos > 0 else entry, direction='EXIT', dayTrade=True)) # 出場成本
#             if pos > 0:
            tmp_pnl -= cost
            tmp_ret = ((price / entry) - 1) * pos
            total_pnl += tmp_pnl
            
            print('\n---------------PnL Summary--------------')
            print(f'Exit Position of {ticker}')
            print(f'Entry : {entry} at {entry_time}')
            print(f'Exit : {price} at {signal_time}')
            print(f'Trading PnL with Cost : {int(round(tmp_pnl))}')
            print(f'Total PnL with Cost : {int(round(total_pnl))}')
            print(f'Total Ret with Cost : {round(tmp_ret * 100, 2)}%')
            print(f'Total PnL with Cost of max size {max_size}: {max_size * int(round(tmp_pnl))}\n')
            
            if pos > 0:
                long_traded = True
            elif pos < 0:
                short_traded = True
            sig = pos = 0
            traded = 1#(long_traded and short_traded) or (total_pnl > 0)
            exit_pos_time = row.datetime
        else:
            if pos and not sig:
                tmp_pnl = (price - entry) * 1000 * pos
                cost = int(get_commission(entry if pos > 0 else price)) # 進場成本
                cost += int(get_commission(price if pos > 0 else entry, direction='EXIT', dayTrade=True)) # 出場成本
    #             tmp_pnl -= int(get_commission(entry if pos > 0 else price)) # 進場成本
    #             tmp_pnl -= int(get_commission(price if pos > 0 else entry, direction='EXIT', dayTrade=True)) # 出場成本
    #             if pos > 0:
                tmp_pnl -= cost
#                 tmp_pnl -= int(get_commission(entry if pos > 0 else price)) # 進場成本
#                 tmp_pnl -= int(get_commission(price if pos > 0 else entry, direction='EXIT', dayTrade=True)) # 出場成本
                tmp_ret = ((price / entry) - 1) * pos
#                 tmp_ret = (tmp_pnl / entry * 1000) - 1
                if tmp_ret > max_ret:
                    sl_threshold = price * (1 - sl_ratio)
                max_ret = max(tmp_ret, max_ret)

                do_exit_take = do_exit_take = tmp_ret >= 0.01 # False
#                 if max_ret >= start_moving_take:
#                     do_exit_take = (tmp_ret / max_ret) <= (takeprofit) if max_ret else False
                do_exit_stop = price > sl_threshold if pos == -1 else price < sl_threshold
                do_exit = price >= exit_threshold if pos > 0 else price <= (refPrice * (1 - exit_percent))
                sig = -pos
            elif pos and sig:
                signal_time = row.datetime
                print(price, row.bid_price)
                exit = row.bid_price
                if abs(exit / price - 1) >= .005:
                    exit = price
                tmp_pnl = (exit - entry) * 1000 * pos
                cost = int(get_commission(entry if pos > 0 else price)) # 進場成本
                cost += int(get_commission(price if pos > 0 else entry, direction='EXIT', dayTrade=True)) # 出場成本
    #             tmp_pnl -= int(get_commission(entry if pos > 0 else price)) # 進場成本
    #             tmp_pnl -= int(get_commission(price if pos > 0 else entry, direction='EXIT', dayTrade=True)) # 出場成本
    #             if pos > 0:
                tmp_pnl -= cost
#                 tmp_pnl -= int(get_commission(entry if pos > 0 else exit)) # 進場成本
#                 tmp_pnl -= int(get_commission(exit if pos > 0 else entry, direction='EXIT', dayTrade=True)) # 出場成本
                tmp_ret = ((price / entry) - 1) * pos
                total_pnl += tmp_pnl
                
            
                print('\n---------------PnL Summary--------------')
                print(f'Exit Position of {ticker}')
                print(f'Entry : {entry} at {entry_time}')
                print(f'Exit : {price} at {signal_time}')
                print(f'Trading PnL with Cost : {int(round(tmp_pnl))}')
                print(f'Total PnL with Cost : {int(round(total_pnl))}')
                print(f'Total Ret with Cost : {round(tmp_ret * 100, 2)}%')
                print(f'Total PnL with Cost of max size {max_size}: {max_size * int(round(tmp_pnl))}\n')
                
                if pos > 0:
                    long_traded = True
                elif pos < 0:
                    short_traded = True
                sig = pos = 0
                traded = (long_traded and short_traded) or (total_pnl > 0)
                exit_pos_time = row.datetime
    return int(round(total_pnl)), int(round(cost))

# %%
# date = datetime(2022,2,25)
date = datetime(2021,12,24)
open_thresholds = readStrongTicker(date.strftime("%Y-%m-%d"))#, 'ATR')
total_capital = 5e6
seperated_capital = int(total_capital / len(open_thresholds.keys()))
max_size_map = {}
for k, v in open_thresholds.items():
    try:
        max_pos = int(seperated_capital / (v['PreClose'] * 1000))
        print(f'{k} 最大倉位 : {max_pos}, 昨收 : {v}')
        max_size_map[k] = max_pos
    except:
        max_pos = int(seperated_capital / (v * 1000))
        print(f'{k} 最大倉位 : {max_pos}, 昨收 : {v}')
        max_size_map[k] = max_pos
        open_thresholds[k] = {'PreClose':v}
# Out:
# 2312 最大倉位 : 22, 昨收 : {'PreClose': 16.75, 'PreHigh': 16.75, 'PreLow': 15.75}
# 2340 最大倉位 : 5, 昨收 : {'PreClose': 66.6, 'PreHigh': 66.6, 'PreLow': 64.5}
# 2374 最大倉位 : 13, 昨收 : {'PreClose': 27.7, 'PreHigh': 27.7, 'PreLow': 25.65}
# 2417 最大倉位 : 14, 昨收 : {'PreClose': 27.3, 'PreHigh': 27.3, 'PreLow': 25.1}
# 3167 最大倉位 : 3, 昨收 : {'PreClose': 111.5, 'PreHigh': 111.5, 'PreLow': 102.5}
# 3518 最大倉位 : 15, 昨收 : {'PreClose': 25.2, 'PreHigh': 25.2, 'PreLow': 23.05}
# 3669 最大倉位 : 6, 昨收 : {'PreClose': 59.2, 'PreHigh': 59.2, 'PreLow': 54.0}
# 4927 最大倉位 : 2, 昨收 : {'PreClose': 129.0, 'PreHigh': 129.0, 'PreLow': 119.5}
# 3322 最大倉位 : 13, 昨收 : {'PreClose': 28.8, 'PreHigh': 28.8, 'PreLow': 27.6}
# 3689 最大倉位 : 7, 昨收 : {'PreClose': 52.9, 'PreHigh': 52.9, 'PreLow': 51.0}
# 5386 最大倉位 : 6, 昨收 : {'PreClose': 58.4, 'PreHigh': 59.2, 'PreLow': 54.5}
# 6158 最大倉位 : 9, 昨收 : {'PreClose': 42.6, 'PreHigh': 42.6, 'PreLow': 41.15}
# 8255 最大倉位 : 1, 昨收 : {'PreClose': 248.0, 'PreHigh': 250.5, 'PreLow': 230.0}

# %%
ticker = '1732'
df = ReadData(api, ticker, date)
df.set_index("datetime").close.plot(figsize=(12,8))
# plt.show()
backtest(api, ticker, date, open_thresholds[ticker]['PreClose'], 
         PreData=open_thresholds[ticker],max_size=max_size_map[ticker], sl_ratio=0.02,
        show_debug=True)
# Out:
# c:\users\kevin\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_matplotlib\converter.py:256: MatplotlibDeprecationWarning:
# The epoch2num function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   base = dates.epoch2num(dt.asi8 / 1.0e9)
# open_h : 34.0, open_l : 32.05
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 09:05:04'), 'open': 32.85, 'high': 32.95, 'low': 32.05, 'close': 32.15, 'volume': 859}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 09:10:02'), 'open': 32.3, 'high': 32.65, 'low': 32.2, 'close': 32.4, 'volume': 324}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 09:15:08'), 'open': 32.5, 'high': 32.85, 'low': 32.3, 'close': 32.4, 'volume': 315}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 09:20:03'), 'open': 32.4, 'high': 32.5, 'low': 32.2, 'close': 32.45, 'volume': 223}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 09:25:03'), 'open': 32.45, 'high': 32.5, 'low': 32.0, 'close': 32.2, 'volume': 486}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 09:30:10'), 'open': 32.3, 'high': 32.35, 'low': 32.1, 'close': 32.25, 'volume': 54}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 09:35:08'), 'open': 32.2, 'high': 32.35, 'low': 32.15, 'close': 32.35, 'volume': 70}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 09:40:07'), 'open': 32.35, 'high': 32.35, 'low': 32.15, 'close': 32.25, 'volume': 48}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 09:45:10'), 'open': 32.3, 'high': 32.4, 'low': 32.3, 'close': 32.35, 'volume': 39}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 09:50:17'), 'open': 32.35, 'high': 32.4, 'low': 32.3, 'close': 32.4, 'volume': 73}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 09:55:16'), 'open': 32.45, 'high': 32.7, 'low': 32.45, 'close': 32.7, 'volume': 138}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 10:00:10'), 'open': 32.6, 'high': 33.5, 'low': 32.45, 'close': 33.25, 'volume': 499}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 10:05:04'), 'open': 33.4, 'high': 33.8, 'low': 33.05, 'close': 33.7, 'volume': 397}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 10:10:02'), 'open': 33.75, 'high': 33.8, 'low': 33.0, 'close': 33.15, 'volume': 290}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 10:15:09'), 'open': 33.15, 'high': 33.3, 'low': 32.7, 'close': 32.7, 'volume': 166}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 10:20:04'), 'open': 32.7, 'high': 33.4, 'low': 32.65, 'close': 33.15, 'volume': 139}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 10:25:10'), 'open': 33.1, 'high': 33.1, 'low': 32.9, 'close': 33.05, 'volume': 30}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 10:30:11'), 'open': 33.1, 'high': 33.15, 'low': 32.9, 'close': 32.95, 'volume': 28}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 10:35:13'), 'open': 32.95, 'high': 33.35, 'low': 32.95, 'close': 33.25, 'volume': 97}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 10:40:06'), 'open': 33.2, 'high': 33.25, 'low': 32.9, 'close': 32.9, 'volume': 53}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 10:45:27'), 'open': 33.0, 'high': 33.1, 'low': 32.9, 'close': 33.05, 'volume': 34}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 10:50:12'), 'open': 33.1, 'high': 33.15, 'low': 33.1, 'close': 33.1, 'volume': 29}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 10:55:17'), 'open': 33.05, 'high': 33.05, 'low': 32.95, 'close': 32.95, 'volume': 30}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 11:00:11'), 'open': 32.95, 'high': 33.2, 'low': 32.95, 'close': 33.2, 'volume': 68}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 11:05:20'), 'open': 33.2, 'high': 33.2, 'low': 33.1, 'close': 33.1, 'volume': 26}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 11:10:08'), 'open': 33.1, 'high': 33.25, 'low': 33.1, 'close': 33.25, 'volume': 68}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 11:15:14'), 'open': 33.2, 'high': 33.3, 'low': 33.15, 'close': 33.15, 'volume': 39}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 11:20:46'), 'open': 33.2, 'high': 33.2, 'low': 33.1, 'close': 33.1, 'volume': 19}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 11:25:24'), 'open': 33.1, 'high': 33.15, 'low': 33.05, 'close': 33.1, 'volume': 12}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 11:30:10'), 'open': 33.1, 'high': 33.1, 'low': 33.0, 'close': 33.0, 'volume': 45}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 11:35:43'), 'open': 33.0, 'high': 33.0, 'low': 32.9, 'close': 32.9, 'volume': 55}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 11:40:05'), 'open': 32.85, 'high': 32.85, 'low': 32.75, 'close': 32.85, 'volume': 70}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 11:45:20'), 'open': 32.85, 'high': 32.9, 'low': 32.85, 'close': 32.9, 'volume': 15}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 11:51:22'), 'open': 32.9, 'high': 32.9, 'low': 32.9, 'close': 32.9, 'volume': 4}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 11:55:52'), 'open': 32.9, 'high': 33.0, 'low': 32.9, 'close': 32.95, 'volume': 23}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 12:00:13'), 'open': 33.0, 'high': 33.05, 'low': 32.9, 'close': 32.95, 'volume': 31}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 12:06:26'), 'open': 32.95, 'high': 32.95, 'low': 32.9, 'close': 32.95, 'volume': 7}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 12:10:39'), 'open': 33.0, 'high': 33.0, 'low': 32.9, 'close': 32.95, 'volume': 48}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 12:15:24'), 'open': 32.9, 'high': 32.9, 'low': 32.8, 'close': 32.8, 'volume': 64}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 12:20:29'), 'open': 32.8, 'high': 32.8, 'low': 32.65, 'close': 32.65, 'volume': 61}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 12:25:01'), 'open': 32.65, 'high': 32.65, 'low': 32.5, 'close': 32.6, 'volume': 119}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 12:30:02'), 'open': 32.65, 'high': 32.8, 'low': 32.55, 'close': 32.55, 'volume': 22}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 12:35:11'), 'open': 32.6, 'high': 32.65, 'low': 32.55, 'close': 32.6, 'volume': 19}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 12:40:53'), 'open': 32.6, 'high': 32.6, 'low': 32.5, 'close': 32.5, 'volume': 70}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 12:45:01'), 'open': 32.5, 'high': 32.5, 'low': 32.4, 'close': 32.45, 'volume': 74}
# 大量5分K高點 : 34.0, 大量5分K低點 : 32.55
# {'symbol': '1732', 'time': Timestamp('2021-12-20 12:50:02'), 'open': 32.45, 'high': 32.55, 'low': 32.45, 'close': 32.55, 'volume': 19}
# (0, 0)

# %%
pnl_ = {}
cost_ = {}
for ticker in open_thresholds.keys():
    try:
        print(f'backtest : {ticker}')
        condi_1 = (open_thresholds[ticker]['PreClose'] >= 10 and open_thresholds[ticker]['PreClose'] <= 20)
        condi_2 = (open_thresholds[ticker]['PreClose'] >= 100 and open_thresholds[ticker]['PreClose'] <= 200)
#         if not (open_thresholds[ticker]['PreClose'] >= 10 and open_thresholds[ticker]['PreClose'] <= 20):continue
#         if not (open_thresholds[ticker]['PreClose'] >= 100 and open_thresholds[ticker]['PreClose'] <= 200):continue
#         if not any([condi_1, condi_2]):continue
        if open_thresholds[ticker]['PreClose'] > 1000:continue
        pnl_[ticker], cost_[ticker] = backtest(api, ticker, date, open_thresholds[ticker]['PreClose'], 
                            PreData=open_thresholds[ticker],max_size=max_size_map[ticker], sl_ratio=0.02,
                               entry_percent=.06)
#                                exit_time='10:00:00.000')
    except:
        pass
# Out:
# backtest : 2312
# open_h : 17.0, open_l : 16.6
# Entry at close = 16.55, bid : 16.55, ask : 16.6
# 2
# entry:16.55, up_target:16.65, dn_target:16.45
# False False False True
# sl_threshold 16.85, half-high-low :16.8
# Max Ret : 0.6%
# Min Ret : -0.91%
# Signal For Exit : 1
# Calculate PnL at close = 16.5, ask : 16.55 at 2021-12-24 10:09:32
#
# ---------------PnL Summary--------------
# Exit Position of 2312
# Entry : 16.55 at 2021-12-24 09:40:02
# Exit : 16.5 at 2021-12-24 10:09:32
# Trading PnL with Cost : -21
# Total PnL with Cost : -21
# Total Ret with Cost : 0.3%
# Total PnL with Cost of max size 22: -462
#
# backtest : 2340
# open_h : 72.7, open_l : 69.0
# backtest : 2374
# open_h : 28.8, open_l : 28.1
# Entry at close = 28.95, bid : 28.9, ask : 28.95
# 3
# entry:28.95, up_target:29.1, dn_target:28.8
# False False False True
# sl_threshold 28.4, half-high-low :28.450000000000003
# Max Ret : 0.52%
# Min Ret : -0.86%
# Signal For Exit : -1
# Calculate PnL at close = 29.0, ask : 29.1 at 2021-12-24 09:22:09
#
# ---------------PnL Summary--------------
# Exit Position of 2374
# Entry : 28.95 at 2021-12-24 09:20:01
# Exit : 29.0 at 2021-12-24 09:22:09
# Trading PnL with Cost : -75
# Total PnL with Cost : -75
# Total Ret with Cost : 0.17%
# Total PnL with Cost of max size 13: -975
#
# backtest : 2417
# open_h : 30.0, open_l : 28.2
# backtest : 3167
# open_h : 111.0, open_l : 105.5
# Entry at close = 106.0, bid : 105.5, ask : 106.0
# 2
# entry:105.5, up_target:106.5, dn_target:104.5
# False False False True
# sl_threshold 107.5, half-high-low :108.25
# Max Ret : 0.95%
# Min Ret : -0.95%
# Signal For Exit : 1
# Calculate PnL at close = 104.5, ask : 105.0 at 2021-12-24 09:16:19
#
# ---------------PnL Summary--------------
# Exit Position of 3167
# Entry : 105.5 at 2021-12-24 09:10:08
# Exit : 104.5 at 2021-12-24 09:16:19
# Trading PnL with Cost : 544
# Total PnL with Cost : 544
# Total Ret with Cost : 0.95%
# Total PnL with Cost of max size 3: 1632
#
# backtest : 3518
# open_h : 25.2, open_l : 24.65
# Entry at close = 24.7, bid : 24.7, ask : 24.85
# 3
# entry:24.7, up_target:24.85, dn_target:24.55
# False False False True
# sl_threshold 25.15, half-high-low :24.924999999999997
# Max Ret : 0.61%
# Min Ret : -0.0%
# Signal For Exit : 1
# Calculate PnL at close = 24.55, ask : 24.65 at 2021-12-24 09:13:26
#
# ---------------PnL Summary--------------
# Exit Position of 3518
# Entry : 24.7 at 2021-12-24 09:10:41
# Exit : 24.55 at 2021-12-24 09:13:26
# Trading PnL with Cost : 44
# Total PnL with Cost : 44
# Total Ret with Cost : 0.61%
# Total PnL with Cost of max size 15: 660
#
# backtest : 3669
# open_h : 61.8, open_l : 58.5
# backtest : 4927
# open_h : 129.5, open_l : 125.5
# backtest : 3322
# open_h : 29.9, open_l : 28.05
# backtest : 3689
# open_h : 55.8, open_l : 53.1
# Entry at close = 52.9, bid : 52.8, ask : 52.9
# 3
# entry:52.8, up_target:53.1, dn_target:52.5
# False False False True
# sl_threshold 53.8, half-high-low :54.45
# Max Ret : 0.57%
# Min Ret : -0.38%
# Signal For Exit : 1
# Calculate PnL at close = 52.4, ask : 52.5 at 2021-12-24 09:54:51
#
# ---------------PnL Summary--------------
# Exit Position of 3689
# Entry : 52.8 at 2021-12-24 09:50:17
# Exit : 52.4 at 2021-12-24 09:54:51
# Trading PnL with Cost : 172
# Total PnL with Cost : 172
# Total Ret with Cost : 0.76%
# Total PnL with Cost of max size 7: 1204
#
# backtest : 5386
# open_h : 57.8, open_l : 56.2
# Entry at close = 56.2, bid : 56.2, ask : 56.3
# 3
# entry:56.2, up_target:56.5, dn_target:56.0
# False False False True
# sl_threshold 57.3, half-high-low :57.0
# Max Ret : 0.36%
# Min Ret : -0.18%
# Signal For Exit : 1
# Calculate PnL at close = 56.0, ask : 56.1 at 2021-12-24 09:10:35
#
# ---------------PnL Summary--------------
# Exit Position of 5386
# Entry : 56.2 at 2021-12-24 09:10:02
# Exit : 56.0 at 2021-12-24 09:10:35
# Trading PnL with Cost : -43
# Total PnL with Cost : -43
# Total Ret with Cost : 0.36%
# Total PnL with Cost of max size 6: -258
#
# backtest : 6158
# open_h : 46.85, open_l : 45.1
# backtest : 8255
# open_h : 254.0, open_l : 248.5
# Entry at close = 247.5, bid : 247.0, ask : 247.5
# 3
# entry:247.0, up_target:248.5, dn_target:245.5
# False False False True
# sl_threshold 251.5, half-high-low :251.25
# Max Ret : 0.61%
# Min Ret : -0.2%
# Signal For Exit : 1
# Calculate PnL at close = 245.5, ask : 246.5 at 2021-12-24 09:43:15
#
# ---------------PnL Summary--------------
# Exit Position of 8255
# Entry : 247.0 at 2021-12-24 09:40:26
# Exit : 245.5 at 2021-12-24 09:43:15
# Trading PnL with Cost : 429
# Total PnL with Cost : 429
# Total Ret with Cost : 0.61%
# Total PnL with Cost of max size 1: 429

# %%
single_pnl = 0
max_pnl = 0
trade_value = 0
single_cost = 0
for ticker in pnl_.keys():
    print(ticker, pnl_[ticker])
    if pnl_[ticker]:
        trade_value += open_thresholds[ticker]['PreClose'] * 1000
        single_pnl += pnl_[ticker]
        max_pnl += pnl_[ticker] * max_size_map[ticker]
        single_cost += cost_[ticker] 
    
print(f'交易量 : {trade_value}')
print(f'single pnl sum : {single_pnl}')
print(f'single cost sum : {round(single_cost - trade_value * 1.5e-3)}')
print(f'手續費折讓 : {round((single_cost - trade_value * 1.5e-3)*0.55)}')
print(f'max pnl sum : {max_pnl}')

results[date] = single_pnl
# Out:
# 2312 -21
# 2340 0
# 2374 -75
# 2417 0
# 3167 544
# 3518 44
# 3669 0
# 4927 0
# 3322 0
# 3689 172
# 5386 -43
# 6158 0
# 8255 429
# 交易量 : 540450.0
# single pnl sum : 1050
# single cost sum : 1489
# 手續費折讓 : 819
# max pnl sum : 2230

# %%
df = pd.DataFrame([{'datetime':k, 'pnl':v}for k, v in results.items()]).sort_values("datetime")

# %%
df
# Out:
#     datetime   pnl
# 0 2021-12-17  1601
# 1 2021-12-20     0
# 2 2021-12-21 -1980
# 3 2021-12-22 -6051
# 4 2021-12-23 -4138
# 5 2021-12-24  1050
# 6 2021-12-27 -1628
# 7 2021-12-29 -2008
# 8 2021-12-30 -3025

# %%
df.set_index('datetime').cumsum().plot()#[datetime(2022,1,1):].cumsum()#.plot()# [datetime(2022,1,1):]
# Out:
# c:\users\kevin\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_matplotlib\converter.py:256: MatplotlibDeprecationWarning:
# The epoch2num function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   base = dates.epoch2num(dt.asi8 / 1.0e9)
# <AxesSubplot:xlabel='datetime'>

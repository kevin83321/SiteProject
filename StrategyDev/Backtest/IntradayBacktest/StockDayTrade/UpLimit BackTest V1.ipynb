# %%
import shioaji as sj
from datetime import datetime, timedelta
import pandas as pd
import pytz

import json
import os 
parent = os.path.dirname(os.path.abspath("__file__"))
StrongPath = os.path.join(parent, 'StrongTickers')
if not os.path.isdir(StrongPath):
    os.makedirs(StrongPath)
# import matplotlib.pyplot as plt
# %matplotlib inline

# %%
api = sj.Shioaji()
api.login('F128497445', 'j7629864')
# Out:
# Response Code: 0 | Event Code: 0 | Info: host '203.66.91.161:80', hostname '203.66.91.161:80' IP 203.66.91.161:80 (host 1 of 1) (host connection attempt 1 of 1) (total connection attempt 1 of 1) | Event: Session up
# [FutureAccount(person_id='F128497445', broker_id='F002000', account_id='1473661', signed=True, username='鄭圳宏'),
#  Account(account_type=<AccountType.H: 'H'>, person_id='F128497445', broker_id='9A92', account_id='0011645', username='鄭圳宏'),
#  StockAccount(person_id='F128497445', broker_id='9A92', account_id='0231901', signed=True, username='鄭圳宏\u3000\u3000')]

# %%
ticker = '1533'
dateStr = "2022-01-04"
contact = api.Contracts.Stocks[ticker]
data = api.ticks(contact, dateStr, 
        query_type=sj.constant.TicksQueryType.RangeTime, 
        time_start='09:12:00',#datetime(2021,11,5,8,45,0).time(),
       time_end='09:15:00')#datetime(2021,11,5,13,45,0).time())
df = pd.DataFrame(data.dict())
df['datetime'] = df.ts.apply(lambda x: datetime.utcfromtimestamp(int(str(x)[:10])).astimezone(pytz.timezone('Asia/Taipei')).strftime("%Y-%m-%d %H:%M:%S.")+str(x)[10:16])

# %%
df.head(50)
# Out:
#                      ts  close  volume  bid_price  bid_volume  ask_price  \
# 0   1641287520889606000   65.3       1        0.0        2285        0.0
# 1   1641287521192343000   65.3       5        0.0        2280        0.0
# 2   1641287521823710000   65.3       3        0.0        2277        0.0
# 3   1641287521919204000   65.3       1        0.0        2276        0.0
# 4   1641287522058631000   65.3       5        0.0        2271        0.0
# 5   1641287523281537000   65.3       1        0.0        2270        0.0
# 6   1641287524948668000   65.3       4        0.0        2266        0.0
# 7   1641287526047217000   65.3     499        0.0        1768        0.0
# 8   1641287526047479000   65.3     499        0.0        1269        0.0
# 9   1641287526047581000   65.3     499        0.0         770        0.0
# 10  1641287526047756000   65.3     499        0.0         271        0.0
# 11  1641287526047971000   65.3     448       65.1           1       65.3
# 12  1641287526067738000   65.1       1       65.0           3       65.1
# 13  1641287526075849000   65.0       3       64.8           8       65.1
# 14  1641287526075849000   64.8       7       64.8           8       65.1
# 15  1641287526075982000   64.8       5       64.8           3       65.1
# 16  1641287526081459000   64.8       3       64.6           5       65.1
# 17  1641287526081459000   64.7       1       64.6           5       65.1
# 18  1641287526081459000   64.6       1       64.6           5       65.1
# 19  1641287526113640000   64.6       5       64.6           1       64.8
# 20  1641287526171698000   64.5       1       64.5           4       64.8
# 21  1641287526207682000   64.5       4       64.4          10       64.8
# 22  1641287526770356000   64.4       1       64.4           9       64.7
# 23  1641287526801243000   64.4       6       64.4           3       64.7
# 24  1641287527011891000   64.4       3       64.2           2       64.7
# 25  1641287527089412000   64.2       2       64.0           7       64.1
# 26  1641287527089412000   64.1       5       64.0           7       64.1
# 27  1641287528637441000   64.1       1       64.0           7       64.1
# 28  1641287531793578000   64.0       7       63.8           2       64.1
# 29  1641287536928488000   63.8       2       63.6           1       63.7
# 30  1641287536928488000   63.7       1       63.6           1       63.7
# 31  1641287537677634000   63.6       1       63.5           5       63.6
# 32  1641287539029952000   63.5       1       63.5           4       63.6
# 33  1641287539484326000   63.6       1       63.5           4       63.6
# 34  1641287539804686000   63.6       1       63.5           4       63.7
# 35  1641287540210442000   63.5       1       63.5           3       63.7
# 36  1641287541044963000   63.5       1       63.5           2       63.7
# 37  1641287544195941000   63.7       1       63.6           2       63.7
# 38  1641287545646136000   63.7       1       63.6           2       63.7
# 39  1641287545748071000   63.6       1       63.6           1       63.7
# 40  1641287546313442000   63.6       1       63.1           6       63.7
# 41  1641287546313442000   63.5       3       63.1           6       63.7
# 42  1641287546313442000   63.4       4       63.1           6       63.7
# 43  1641287546313442000   63.3       5       63.1           6       63.7
# 44  1641287546313442000   63.2       1       63.1           6       63.7
# 45  1641287546313442000   63.1       1       63.1           6       63.7
# 46  1641287551469917000   63.7       1       63.5           1       63.8
# 47  1641287551530221000   63.8      10       63.5           1       63.8
# 48  1641287551542802000   63.8       5       63.5           1       63.9
# 49  1641287552438995000   63.6       1       63.6           1       63.8
#
#     ask_volume  tick_type                    datetime
# 0            0          1  2022-01-04 09:12:00.889606
# 1            0          1  2022-01-04 09:12:01.192343
# 2            0          1  2022-01-04 09:12:01.823710
# 3            0          1  2022-01-04 09:12:01.919204
# 4            0          1  2022-01-04 09:12:02.058631
# 5            0          1  2022-01-04 09:12:03.281537
# 6            0          1  2022-01-04 09:12:04.948668
# 7            0          1  2022-01-04 09:12:06.047217
# 8            0          1  2022-01-04 09:12:06.047479
# 9            0          1  2022-01-04 09:12:06.047581
# 10           0          1  2022-01-04 09:12:06.047756
# 11          51          1  2022-01-04 09:12:06.047971
# 12         121          2  2022-01-04 09:12:06.067738
# 13         121          2  2022-01-04 09:12:06.075849
# 14         121          2  2022-01-04 09:12:06.075849
# 15         121          2  2022-01-04 09:12:06.075982
# 16         121          2  2022-01-04 09:12:06.081459
# 17         121          2  2022-01-04 09:12:06.081459
# 18         121          2  2022-01-04 09:12:06.081459
# 19          15          2  2022-01-04 09:12:06.113640
# 20          15          2  2022-01-04 09:12:06.171698
# 21          15          2  2022-01-04 09:12:06.207682
# 22           1          2  2022-01-04 09:12:06.770356
# 23           1          2  2022-01-04 09:12:06.801243
# 24           1          2  2022-01-04 09:12:07.011891
# 25           8          2  2022-01-04 09:12:07.089412
# 26           8          2  2022-01-04 09:12:07.089412
# 27           8          1  2022-01-04 09:12:08.637441
# 28          29          2  2022-01-04 09:12:11.793578
# 29           2          2  2022-01-04 09:12:16.928488
# 30           2          2  2022-01-04 09:12:16.928488
# 31           2          2  2022-01-04 09:12:17.677634
# 32           2          2  2022-01-04 09:12:19.029952
# 33           1          1  2022-01-04 09:12:19.484326
# 34          17          1  2022-01-04 09:12:19.804686
# 35          17          2  2022-01-04 09:12:20.210442
# 36          17          2  2022-01-04 09:12:21.044963
# 37          16          1  2022-01-04 09:12:24.195941
# 38          15          1  2022-01-04 09:12:25.646136
# 39          15          2  2022-01-04 09:12:25.748071
# 40          15          2  2022-01-04 09:12:26.313442
# 41          15          2  2022-01-04 09:12:26.313442
# 42          15          2  2022-01-04 09:12:26.313442
# 43          15          2  2022-01-04 09:12:26.313442
# 44          15          2  2022-01-04 09:12:26.313442
# 45          15          2  2022-01-04 09:12:26.313442
# 46          15          2  2022-01-04 09:12:31.469917
# 47           5          1  2022-01-04 09:12:31.530221
# 48           1          1  2022-01-04 09:12:31.542802
# 49           1          2  2022-01-04 09:12:32.438995

# %%
def readStrongTicker(dtStr):
    if os.path.isfile(os.path.join(StrongPath, f'{dtStr}_tradableTicker.json')):
        with open(os.path.join(StrongPath, f'{dtStr}_tradableTicker.json'), 'r') as f:
            tickers = json.load(f)
            return tickers
    elif os.path.isfile(os.path.join(StrongPath, f'{dtStr}_strongTicker.json')):
        with open(os.path.join(StrongPath, f'{dtStr}_strongTicker.json'), 'r') as f:
            tickers = json.load(f)
            return tickers
    else:
        return {}

def get_minimum_tick(cost):
    if cost < 10:
        return 0.01
    elif cost < 50:
        return 0.05
    elif cost < 100:
        return 0.1
    elif cost < 500:
        return 0.5
    elif cost < 1000:
        return 1
    else:
        return 5
    
def get_commission(price:float, multiplier:int=1000, qty=1, Real:bool=True, direction:str='', dayTrade:bool=False):
    """
    計算個別部位的單邊交易成本

    Params:
        symbol : 商品代碼
        exchange : 交易所
        cost : 交易價格
        multiplier : 價格還原現金之乘數
            例如:
                股票 : 1張 = 1,000股，10元的股票還原現金價值，即為10 *1,000 = 10,000元
                期貨 : 台指期1點200元，假設現在10,000點，則一口台股的價值為 200 * 10,000 = 2,000,000
        qty : 買賣口數或張數
        Real : 是否為實單, default = False
        direction : 交易方向 進場(買賣)或出場
            P.S. 股票交易的交易稅是出場才計算
    """
    tick = get_minimum_tick(price)
    commission = price * (0.1425 / 100) * multiplier * qty
    commission = 20 if commission < 20 else commission
    fee = price * (0.3 / 100) * multiplier * qty
    if dayTrade:
        fee /= 2
    slide = tick * multiplier
    tradeCost = commission * 0.6
    if direction == 'EXIT' or direction == 0:
        tradeCost += fee
    if not Real:
        tradeCost += slide * qty
    return tradeCost

# %%
def backtest(api:sj.Shioaji, ticker:str, date:datetime, open_threshold:float=0, PreData:dict={},
             v_threshold:float=.01, entry_percent:float=.06, exit_percent:float=.09, 
             takeprofit:float=.6, start_moving_take = .015, sl_ratio:float=.02, max_size:float = 1, 
             exit_time:str='13:00:00.000000'): # 
#     print(PreData)
    # prepare data
    dateStr = date.strftime("%Y-%m-%d")
    contact = api.Contracts.Stocks[ticker]
    data = api.ticks(contact, dateStr, 
            query_type=sj.constant.TicksQueryType.RangeTime, 
            time_start='09:00:00',#datetime(2021,11,5,8,45,0).time(),
           time_end='13:30:00')#datetime(2021,11,5,13,45,0).time())
    df = pd.DataFrame(data.dict())
    df['datetime'] = df.ts.apply(lambda x: datetime.utcfromtimestamp(int(str(x)[:10])).astimezone(pytz.timezone('Asia/Taipei')))
#     df['time'] = 
    
    # setting Parameters
    opening = False
    closing = False
    
    pre_time:str="09:00:00"
    pre_volume:int = 0
    pre_close:int = 0
    total_v:int = 0 
    refPrice:float = PreData.get('PreClose', 0)
    preHigh:float = PreData.get('PreHigh', PreData.get('PreClose', 0))
#     preLow:float = PreData.get('PreLow', 9999)
    entry_threshold:float = 0 if not refPrice else refPrice * (1 + entry_percent)
    exit_threshold:float = 0 if not refPrice else refPrice * (1 + exit_percent)
    max_ret:float = 0
    tmp_ret:float = 0
    pos = 0
    sig = 0
    traded = 0
    entry = 0
    entry_time = 0

#     preHigh = 0
#     preLow = 9999
    sl_threshold = 0
    
    pnl:float = 0
    total_volume = 0
    first_5mink = {'open':None, 'high':0,'low':9999, 'close':0}
        
    entry_time = ''
    exit_pos_time = ''
    tmp_pnl = 0
    for row in df.itertuples():
#         print(row)
        price = row.close
        time = row.datetime
        qty = row.volume
        total_volume += qty
        
#         if not pre_close :
#             pre_close = price
#         print(time.strftime('%H%M%S'), time.strftime('%H%M%S') <= "090500", time.strftime('%H%M%S') < exit_time)
        if time <= time.replace(hour=9,minute=5,second=0, microsecond=0):#"09:05:00.000000":
            if not first_5mink['open']:
                first_5mink['open'] = price
            first_5mink['high'] = max(first_5mink['high'], price)
            first_5mink['low'] = min(first_5mink['low'], price)
            first_5mink['close'] = price
            continue
        if time < time.replace(hour=13,minute=0,second=0, microsecond=0):# < exit_time:# or time <= "13:00:00.000000":
            if not pos and not sig and not traded: # check signal without position
                if price > max(first_5mink['open'], first_5mink['close'],preHigh) * 1.005 and price <= entry_threshold:
                    print(','.join([str(x) for x in [price, first_5mink['open'], first_5mink['close'], preHigh, max(first_5mink['open'], first_5mink['close'],preHigh) * 1.005]]))
#                     print(price, preHigh, max(max(first_5mink['open'], first_5mink['close'], first_5mink['high']),preHigh) * 1.005)#, price > max(max(first_5mink['open'], first_5mink['close'], first_5mink['high']),preHigh) * 1.005)
                    sig = 1
                    oneTradeOnly = True
            elif not pos and sig: # entry market
#                 print(row)
                print(price, row.ask_price)
                entry = row.ask_price
                if abs(entry / price - 1) >= .005:
                    entry = price
                pos, sig = sig, 0
                entry_time = row.datetime
                sl_threshold = entry * (1 - sl_ratio)
            elif pos and not sig: # check signal with position
                tmp_pnl = (price - entry) * 1000 * pos
                tmp_pnl -= int(get_commission(entry if pos > 0 else price)) # 進場成本
                tmp_pnl -= int(get_commission(price if pos > 0 else entry, direction='EXIT', dayTrade=True)) # 出場成本
                tmp_ret = ((price / entry) - 1) * pos
#                 tmp_ret = (tmp_pnl / entry * 1000) - 1
                if tmp_ret > max_ret:
                    sl_threshold = price * (1 - sl_ratio)
                max_ret = max(tmp_ret, max_ret)
                
                do_exit_take = tmp_ret >= 0.01
#                 if max_ret >= start_moving_take:
                    
#                     do_exit_take = (tmp_ret / max_ret) <= (takeprofit) if max_ret else False
                do_exit_stop = price <= sl_threshold
                do_exit = price >= exit_threshold if pos > 0 else price <= (refPrice * (1 - exit_percent))
                
#                 exit_end = time.strftime('%H:%M:%S.%f') >= exit_time
                if any([do_exit, do_exit_take, do_exit_stop]):
                    sig = -pos
#                     self.closing=True
#                     self.DoTrade('S' if self.pos > 0 else 'B')
#                     self.sendNotifyExit(self.q20_data['datetime'].strftime("%H:%M:%S.%f"), self.symbol, self.name,
#                                      close, self.q20_data['pct_chg'], do_exit_take or do_exit)
            elif pos and sig:
                signal_time = row.datetime
                print(price, row.bid_price)
                exit = row.bid_price
                if abs(exit / price - 1) >= .005:
                    exit = price
                tmp_pnl = (price - entry) * 1000 * pos
                tmp_pnl -= int(get_commission(entry if pos > 0 else price)) # 進場成本
                tmp_pnl -= int(get_commission(price if pos > 0 else entry, direction='EXIT', dayTrade=True)) # 出場成本
                tmp_ret = ((price / entry) - 1) * pos
            
                print('\n---------------PnL Summary--------------')
                print(f'Exit Position of {ticker}')
                print(f'Entry : {entry} at {entry_time}')
                print(f'Exit : {price} at {signal_time}')
                print(f'Total PnL with Cost : {int(round(tmp_pnl))}')
                print(f'Total Ret with Cost : {round(tmp_ret * 100, 2)}%')
                print(f'Total PnL with Cost of max size {max_size}: {max_size * int(round(tmp_pnl))}\n')
                
                sig = pos = 0
                traded = True
                exit_pos_time = row.datetime
        else:
            if pos and not sig:
                tmp_pnl = (price - entry) * 1000 * pos
                tmp_pnl -= int(get_commission(entry if pos > 0 else price)) # 進場成本
                tmp_pnl -= int(get_commission(price if pos > 0 else entry, direction='EXIT', dayTrade=True)) # 出場成本
                tmp_ret = ((price / entry) - 1) * pos
#                 tmp_ret = (tmp_pnl / entry * 1000) - 1
                if tmp_ret > max_ret:
                    sl_threshold = price * (1 - sl_ratio)
                max_ret = max(tmp_ret, max_ret)

                do_exit_take = do_exit_take = tmp_ret >= 0.01 # False
#                 if max_ret >= start_moving_take:
#                     do_exit_take = (tmp_ret / max_ret) <= (takeprofit) if max_ret else False
                do_exit_stop = price <= sl_threshold
                do_exit = price >= exit_threshold if pos > 0 else price <= (refPrice * (1 - exit_percent))
                sig = -pos
            elif pos and sig:
                signal_time = row.datetime
                print(price, row.bid_price)
                exit = row.bid_price
                if abs(exit / price - 1) >= .005:
                    eixt = price
                tmp_pnl = (price - entry) * 1000 * pos
                tmp_pnl -= int(get_commission(entry if pos > 0 else price)) # 進場成本
                tmp_pnl -= int(get_commission(price if pos > 0 else entry, direction='EXIT', dayTrade=True)) # 出場成本
                tmp_ret = ((price / entry) - 1) * pos
            
                print('\n---------------PnL Summary--------------')
                print(f'Exit Position of {ticker}')
                print(f'Entry : {entry} at {entry_time}')
                print(f'Exit : {price} at {signal_time}')
                print(f'Total PnL with Cost : {int(round(tmp_pnl))}')
                print(f'Total Ret with Cost : {round(tmp_ret * 100, 2)}%')
                print(f'Total PnL with Cost of max size {max_size}: {max_size * int(round(tmp_pnl))}\n')
                
                sig = pos = 0
                traded = True
                exit_pos_time = row.datetime
    return int(round(tmp_pnl))

# %%
date = datetime(2021,12,30)
open_thresholds = readStrongTicker(date.strftime("%Y-%m-%d"))
total_capital = 5e6
seperated_capital = int(total_capital / len(open_thresholds.keys()))
max_size_map = {}
for k, v in open_thresholds.items():
    try:
        max_pos = int(seperated_capital / (v['PreClose'] * 1000))
        print(f'{k} 最大倉位 : {max_pos}, 昨收 : {v}')
        max_size_map[k] = max_pos
    except:
        max_pos = int(seperated_capital / (v * 1000))
        print(f'{k} 最大倉位 : {max_pos}, 昨收 : {v}')
        max_size_map[k] = max_pos
        open_thresholds[k] = {'PreClose':v}
# Out:
# 1560 最大倉位 : 1, 昨收 : {'PreClose': 117.5, 'PreHigh': 117.5, 'PreLow': 107.0}
# 1599 最大倉位 : 3, 昨收 : {'PreClose': 50.3, 'PreHigh': 51.7, 'PreLow': 47.55}
# 1717 最大倉位 : 4, 昨收 : {'PreClose': 40.55, 'PreHigh': 41.05, 'PreLow': 37.45}
# 1773 最大倉位 : 1, 昨收 : {'PreClose': 178.5, 'PreHigh': 178.5, 'PreLow': 163.0}
# 2323 最大倉位 : 17, 昨收 : {'PreClose': 10.45, 'PreHigh': 10.45, 'PreLow': 10.45}
# 2359 最大倉位 : 8, 昨收 : {'PreClose': 21.75, 'PreHigh': 21.75, 'PreLow': 21.75}
# 2427 最大倉位 : 13, 昨收 : {'PreClose': 13.3, 'PreHigh': 13.35, 'PreLow': 12.15}
# 3094 最大倉位 : 4, 昨收 : {'PreClose': 46.05, 'PreHigh': 46.05, 'PreLow': 42.5}
# 3306 最大倉位 : 5, 昨收 : {'PreClose': 36.5, 'PreHigh': 36.5, 'PreLow': 34.0}
# 3455 最大倉位 : 2, 昨收 : {'PreClose': 83.6, 'PreHigh': 83.6, 'PreLow': 76.2}
# 3550 最大倉位 : 9, 昨收 : {'PreClose': 20.1, 'PreHigh': 20.5, 'PreLow': 19.4}
# 3583 最大倉位 : 1, 昨收 : {'PreClose': 98.2, 'PreHigh': 98.2, 'PreLow': 89.8}
# 3624 最大倉位 : 2, 昨收 : {'PreClose': 78.1, 'PreHigh': 78.8, 'PreLow': 72.3}
# 3672 最大倉位 : 3, 昨收 : {'PreClose': 49.35, 'PreHigh': 49.35, 'PreLow': 44.7}
# 4162 最大倉位 : 2, 昨收 : {'PreClose': 71.5, 'PreHigh': 71.5, 'PreLow': 68.9}
# 4755 最大倉位 : 1, 昨收 : {'PreClose': 178.0, 'PreHigh': 178.0, 'PreLow': 162.5}
# 5452 最大倉位 : 7, 昨收 : {'PreClose': 23.9, 'PreHigh': 25.3, 'PreLow': 23.3}
# 6133 最大倉位 : 16, 昨收 : {'PreClose': 11.3, 'PreHigh': 11.9, 'PreLow': 11.0}
# 6134 最大倉位 : 5, 昨收 : {'PreClose': 34.3, 'PreHigh': 34.3, 'PreLow': 32.2}
# 6148 最大倉位 : 12, 昨收 : {'PreClose': 15.4, 'PreHigh': 16.65, 'PreLow': 15.15}
# 6196 最大倉位 : 1, 昨收 : {'PreClose': 177.5, 'PreHigh': 177.5, 'PreLow': 162.5}
# 6208 最大倉位 : 2, 昨收 : {'PreClose': 63.4, 'PreHigh': 63.4, 'PreLow': 58.0}
# 6667 最大倉位 : 2, 昨收 : {'PreClose': 87.3, 'PreHigh': 87.3, 'PreLow': 78.9}
# 6698 最大倉位 : 3, 昨收 : {'PreClose': 58.9, 'PreHigh': 58.9, 'PreLow': 55.3}
# 8027 最大倉位 : 2, 昨收 : {'PreClose': 85.2, 'PreHigh': 85.5, 'PreLow': 78.9}
# 8028 最大倉位 : 3, 昨收 : {'PreClose': 57.8, 'PreHigh': 57.8, 'PreLow': 52.1}
# 8071 最大倉位 : 11, 昨收 : {'PreClose': 16.8, 'PreHigh': 16.8, 'PreLow': 15.4}

# %%
pnl_ = {}
for ticker in open_thresholds.keys():
# ticker = '6185'
    try:
        print(f'backtest : {ticker}')
        pnl_[ticker] = backtest(api, ticker, date, open_thresholds[ticker]['PreClose'], 
                            PreData=open_thresholds[ticker],max_size=max_size_map[ticker])
    except:
        pass
#     pnl_[ticker]
#     break
# Out:
# backtest : 1560
# 122.5,119.0,121.5,117.5,122.10749999999999
# 122.5 122.5
# 124.0 123.5
#
# ---------------PnL Summary--------------
# Exit Position of 1560
# Entry : 122.5 at 2021-12-30 09:07:42+08:00
# Exit : 124.0 at 2021-12-30 09:08:56+08:00
# Total PnL with Cost : 1104
# Total Ret with Cost : 1.22%
# Total PnL with Cost of max size 1: 1104
#
# backtest : 1599
# 52.0,49.45,49.85,51.7,51.9585
# 52.0 52.0
# 52.6 52.5
#
# ---------------PnL Summary--------------
# Exit Position of 1599
# Entry : 52.0 at 2021-12-30 09:23:38+08:00
# Exit : 52.6 at 2021-12-30 09:27:39+08:00
# Total PnL with Cost : 433
# Total Ret with Cost : 1.15%
# Total PnL with Cost of max size 3: 1299
#
# backtest : 1717
# backtest : 1773
# 179.5,178.5,175.0,178.5,179.39249999999998
# 179.0 179.5
# 181.0 181.0
#
# ---------------PnL Summary--------------
# Exit Position of 1773
# Entry : 179.5 at 2021-12-30 09:17:14+08:00
# Exit : 181.0 at 2021-12-30 09:17:51+08:00
# Total PnL with Cost : 921
# Total Ret with Cost : 0.84%
# Total PnL with Cost of max size 1: 921
#
# backtest : 2323
# backtest : 2359
# backtest : 2427
# backtest : 3094
# 47.85,47.6,46.95,46.05,47.837999999999994
# 47.65 47.85
# 48.2 48.15
#
# ---------------PnL Summary--------------
# Exit Position of 3094
# Entry : 47.85 at 2021-12-30 09:09:29+08:00
# Exit : 48.2 at 2021-12-30 09:13:13+08:00
# Total PnL with Cost : 197
# Total Ret with Cost : 0.73%
# Total PnL with Cost of max size 4: 788
#
# backtest : 3306
# 37.5,36.5,37.3,36.5,37.48649999999999
# 37.6 37.6
# 37.1 37.05
#
# ---------------PnL Summary--------------
# Exit Position of 3306
# Entry : 37.6 at 2021-12-30 09:26:17+08:00
# Exit : 37.1 at 2021-12-30 09:39:51+08:00
# Total PnL with Cost : -619
# Total Ret with Cost : -1.33%
# Total PnL with Cost of max size 5: -3095
#
# backtest : 3455
# 84.1,81.0,82.1,83.6,84.01799999999999
# 84.1 84.2
# 85.1 85.0
#
# ---------------PnL Summary--------------
# Exit Position of 3455
# Entry : 84.2 at 2021-12-30 09:31:56+08:00
# Exit : 85.1 at 2021-12-30 09:37:25+08:00
# Total PnL with Cost : 629
# Total Ret with Cost : 1.07%
# Total PnL with Cost of max size 2: 1258
#
# backtest : 3550
# backtest : 3583
# backtest : 3624
# 81.3,80.7,80.8,78.8,81.204
# 81.3 81.3
# 82.2 82.0
#
# ---------------PnL Summary--------------
# Exit Position of 3624
# Entry : 81.3 at 2021-12-30 09:41:02+08:00
# Exit : 82.2 at 2021-12-30 09:50:13+08:00
# Total PnL with Cost : 638
# Total Ret with Cost : 1.11%
# Total PnL with Cost of max size 2: 1276
#
# backtest : 3672
# backtest : 4162
# 74.2,73.8,73.2,71.5,74.16899999999998
# 74.1 74.2
# 72.9 73.0
#
# ---------------PnL Summary--------------
# Exit Position of 4162
# Entry : 74.2 at 2021-12-30 09:16:38+08:00
# Exit : 72.9 at 2021-12-30 09:23:10+08:00
# Total PnL with Cost : -1534
# Total Ret with Cost : -1.75%
# Total PnL with Cost of max size 2: -3068
#
# backtest : 4755
# 181.0,180.0,175.0,178.0,180.89999999999998
# 181.0 181.0
# 183.0 182.5
#
# ---------------PnL Summary--------------
# Exit Position of 4755
# Entry : 181.0 at 2021-12-30 09:16:44+08:00
# Exit : 183.0 at 2021-12-30 09:16:56+08:00
# Total PnL with Cost : 1416
# Total Ret with Cost : 1.1%
# Total PnL with Cost of max size 1: 1416
#
# backtest : 5452
# backtest : 6133
# backtest : 6134
# 35.8,35.6,34.4,34.3,35.778
# 35.8 35.8
# 35.05 35.05
#
# ---------------PnL Summary--------------
# Exit Position of 6134
# Entry : 35.8 at 2021-12-30 09:31:49+08:00
# Exit : 35.05 at 2021-12-30 09:37:28+08:00
# Total PnL with Cost : -862
# Total Ret with Cost : -2.09%
# Total PnL with Cost of max size 5: -4310
#
# backtest : 6148
# backtest : 6196
# 184.5,183.5,183.0,177.5,184.4175
# 184.5 184.5
# 186.5 186.0
#
# ---------------PnL Summary--------------
# Exit Position of 6196
# Entry : 184.5 at 2021-12-30 09:05:45+08:00
# Exit : 186.5 at 2021-12-30 09:19:24+08:00
# Total PnL with Cost : 1404
# Total Ret with Cost : 1.08%
# Total PnL with Cost of max size 1: 1404
#
# backtest : 6208
# backtest : 6667
# backtest : 6698
# 59.2,58.6,57.9,58.9,59.19449999999999
# 59.2 59.2
# 59.8 59.5
#
# ---------------PnL Summary--------------
# Exit Position of 6698
# Entry : 59.2 at 2021-12-30 12:05:30+08:00
# Exit : 59.8 at 2021-12-30 12:05:41+08:00
# Total PnL with Cost : 410
# Total Ret with Cost : 1.01%
# Total PnL with Cost of max size 3: 1230
#
# backtest : 8027
# 86.0,85.2,84.4,85.5,85.9275
# 86.0 86.0
# 84.8 84.8
#
# ---------------PnL Summary--------------
# Exit Position of 8027
# Entry : 86.0 at 2021-12-30 09:34:43+08:00
# Exit : 84.8 at 2021-12-30 09:54:57+08:00
# Total PnL with Cost : -1472
# Total Ret with Cost : -1.4%
# Total PnL with Cost of max size 2: -2944
#
# backtest : 8028
# 58.7,57.8,58.4,57.8,58.69199999999999
# 58.7 58.7
# 59.4 59.1
#
# ---------------PnL Summary--------------
# Exit Position of 8028
# Entry : 58.7 at 2021-12-30 09:05:22+08:00
# Exit : 59.4 at 2021-12-30 09:06:15+08:00
# Total PnL with Cost : 511
# Total Ret with Cost : 1.19%
# Total PnL with Cost of max size 3: 1533
#
# backtest : 8071
# 17.5,17.4,17.25,16.8,17.487
# 17.55 17.6
# 17.2 17.15
#
# ---------------PnL Summary--------------
# Exit Position of 8071
# Entry : 17.6 at 2021-12-30 09:07:52+08:00
# Exit : 17.2 at 2021-12-30 09:08:25+08:00
# Total PnL with Cost : -455
# Total Ret with Cost : -2.27%
# Total PnL with Cost of max size 11: -5005

# %%
single_pnl = 0
max_pnl = 0
trade_value = 0
for ticker in pnl_.keys():
    trade_value += open_thresholds[ticker]['PreClose'] * 1000
    single_pnl += pnl_[ticker]
    max_pnl += pnl_[ticker] * max_size_map[ticker]
    
print(f'交易量 : {trade_value}')
print(f'single pnl sum : {single_pnl}')
print(f'max pnl sum : {max_pnl}')
# Out:
# 交易量 : 1725550.0
# single pnl sum : 2721
# max pnl sum : -6193

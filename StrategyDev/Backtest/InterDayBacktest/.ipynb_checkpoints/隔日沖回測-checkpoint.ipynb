# %%
from Calculator import Calculator as Calc
from PlotTools import createPlot
import shioaji as sj
import pytz
import time
from utils import (
    pd, np, getSchema, getDateBeforeTrade, 
    saveRecommand, timedelta, GetException,
    sendResultTable, VolumeFilter, PriceFilter,
    changedType, datetime, timedelta
)
from pprint import pprint

import warnings
warnings.filterwarnings("ignore")
# Out:
# c:\users\kevin\appdata\local\programs\python\python37\lib\site-packages\mpl_finance.py:22: DeprecationWarning:
#
#   =================================================================
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
#   =================================================================
#
#   category=DeprecationWarning)

# %%
api = sj.Shioaji()
api.login('F128497445', '89118217k')
# Out:
# Response Code: 0 | Event Code: 0 | Info: host '203.66.91.161:80', hostname '203.66.91.161:80' IP 203.66.91.161:80 (host 1 of 1) (host connection attempt 1 of 1) (total connection attempt 1 of 1) | Event: Session up
# [FutureAccount(person_id='F128497445', broker_id='F002000', account_id='1473661', signed=True, username='鄭圳宏'),
#  Account(account_type=<AccountType.H: 'H'>, person_id='F128497445', broker_id='9A92', account_id='0011645', username='鄭圳宏'),
#  StockAccount(person_id='F128497445', broker_id='9A92', account_id='0231901', signed=True, username='鄭圳宏\u3000\u3000')]

# %%
def ReadData(api, ticker, date, time_end='13:30:00'):
    dateStr = date.strftime("%Y-%m-%d")
    contact = api.Contracts.Stocks[ticker]
    data = api.ticks(contact, dateStr, 
            query_type=sj.constant.TicksQueryType.RangeTime, 
            time_start='09:00:00',#datetime(2021,11,5,8,45,0).time(),
            time_end=time_end)#datetime(2021,11,5,13,45,0).time())
    df = pd.DataFrame(data.dict())
    df['datetime'] = df.ts.apply(lambda x: datetime.utcfromtimestamp(int(str(x)[:10])).astimezone(pytz.timezone('Asia/Taipei')))
    df['datetime'] = pd.to_datetime(df['datetime'].apply(lambda x: x.strftime("%Y-%m-%d %H:%M:%S.%f")))
    return df

# %%
def get_minimum_tick(cost):
    if cost < 10:
        return 0.01
    elif cost < 50:
        return 0.05
    elif cost < 100:
        return 0.1
    elif cost < 500:
        return 0.5
    elif cost < 1000:
        return 1
    else:
        return 5
    
def getLimit(price, pct=0.1, trend="U"):
    if np.isnan(price): return price
    tmp_price = price
    if trend == "U":
        while 1:
            tick = get_minimum_tick(tmp_price)
            tmp_price += tick
            if (tmp_price/price) > 1 + pct:
                tmp_price -= tick
                break
    elif trend == "D":
        while 1:
            tick = get_minimum_tick(tmp_price)
            tmp_price -= tick
            if (tmp_price/price) < 1 - pct:
                tmp_price += tick
                break
            
    return round(tmp_price, 2)

def get_commission(price:float, multiplier:int=1000, qty=1, Real:bool=True, direction:str='', dayTrade:bool=False):
    """
    計算個別部位的單邊交易成本

    Params:
        symbol : 商品代碼
        exchange : 交易所
        cost : 交易價格
        multiplier : 價格還原現金之乘數
            例如:
                股票 : 1張 = 1,000股，10元的股票還原現金價值，即為10 *1,000 = 10,000元
                期貨 : 台指期1點200元，假設現在10,000點，則一口台股的價值為 200 * 10,000 = 2,000,000
        qty : 買賣口數或張數
        Real : 是否為實單, default = False
        direction : 交易方向 進場(買賣)或出場
            P.S. 股票交易的交易稅是出場才計算
    """
    tick = get_minimum_tick(price)
    commission = price * (0.1425 / 100) * multiplier * qty
    commission = 20 if commission < 20 else commission
    fee = price * (0.3 / 100) * multiplier * qty
    if dayTrade:
        fee /= 2
    slide = tick * multiplier
    tradeCost = commission * 0.6
    if direction == 'EXIT' or direction == 0:
        tradeCost += fee
    if not Real:
        tradeCost += slide * qty
    return tradeCost

# %%
def FindCrossDayTradeTicker(td = datetime.today(), min_price=0, max_price=50, num_shares=10000, shares_ratio=0):
    try:
        td, last = getDateBeforeTrade(td.replace(hour=18))
        # setup data
        schema = getSchema('TWSE')
        table = schema['StockList']
        last_date = sorted(table.distinct("UpdateDate"))[-1]
        info_data = dict((x['Ticker'], x['Industry']+f"({x['Market'][-1]})") for x in table.find({"UpdateDate":{"$eq":last_date}, "Industry" :{"$ne":""}}) if "金融" not in x['Industry'])
        
        schema = getSchema('TWSE')
        table = schema['historicalPrice']
        data = list(table.find({'Date':{'$gte':last.strftime('%Y-%m-%d'), '$lte':td.strftime('%Y-%m-%d')}, "Ticker" :{"$in":list(info_data.keys())}}))
        
        df = pd.DataFrame(data).set_index('Date')
        if len(df.index.unique()) < 2:
            data = list(table.find({'Date':{'$gte':(last+timedelta(-30)).strftime('%Y-%m-%d'), '$lte':td.strftime('%Y-%m-%d')}}))
            df = pd.DataFrame(data).set_index('Date')
            df = df.loc[sorted(df.index.unique())[-2:], :]
        del df['_id']
        for col in 'Open,High,Low,Close,Volume'.split(','):
            df[col] = df[col].apply(changedType)
        df["Adj V"] = df["Volume"].apply(lambda x: int(x/1000))
        
        # print(df.loc[sorted(df.index.unique())[-1],:].Volume >= num_shares)

        
        last_df = df.loc[sorted(df.index.unique())[-1],:].reset_index().set_index("Ticker")
        # 強勢股
        last_df = last_df[last_df.Volume >= 1000]
        last_df['Ret'] = 0
        last_df["HighRet"] = 0
        for ticker in last_df.index.unique():
            last_df.loc[ticker, "Ret"] = df[df.Ticker == ticker].Close.pct_change()[-1]
            try:
                last_df.loc[ticker, "HighRet"] = (df[df.Ticker == ticker].High.iloc[-1] / df[df.Ticker == ticker].Close.iloc[-2]) - 1
            except:
                pass
        last_df = last_df[last_df["Adj V"] >= num_shares]
        ticker_volume_filted = last_df.index
        
        final_select = []
        pre_3y = td + timedelta(-365*3)
        momentums = []
        for ticker in ticker_volume_filted:#df.Ticker.unique():
            try:
                temp_df = pd.DataFrame(list(table.find({'Ticker':{'$eq':ticker},'Date':{'$gte':pre_3y.strftime('%Y-%m-%d'), '$lte':td.strftime('%Y-%m-%d')}}))).set_index('Date')
                
                if temp_df is None:
                    print(ticker, 'is None', temp_df)
                    continue
                if temp_df.empty:
                    print(ticker, 'is empty', temp_df)
                    continue
                for col in 'Open,High,Low,Close,Volume'.split(','):
                    temp_df[col] = temp_df[col].apply(changedType)
                
                # temp_df = Calc.MACD(temp_df)
                # temp_df = Calc.DI(temp_df)
                temp_df = Calc.MA(temp_df, [5, 10, 20, 60, 150], 'Close')
                # temp_df = Calc.EMA(temp_df, [67, 23])
                # temp_df = Calc.calculateTOWER(temp_df)
                # temp_df = Calc.BBAND(temp_df, 20, 2)
                # temp_df['slope'] = temp_df['MA20'].pct_change()
                temp_df['Ret'] = temp_df.Close.pct_change()
                temp_df['slope_5'] = temp_df['MA5'].pct_change()
                temp_df['slope_10'] = temp_df['MA10'].pct_change()
                temp_df['Adj V'] = temp_df.Volume.apply(lambda x: int(x/1000))
                temp_df['VMA5'] = temp_df['Adj V'].rolling(5).mean()
                temp_df['VMA20'] = temp_df['Adj V'].rolling(20).mean()
                temp_df["ATR%"] = (temp_df["High"] / temp_df["Low"] - 1).rolling(5).mean()
                # # temp_df['upslope'] = temp_df['upband'].pct_change()
                # # temp_df['bandwidth'] = temp_df['upband'] / temp_df['dnband'] - 1
                v_ratio = (temp_df['Adj V'].iloc[-1] / temp_df['Adj V'].iloc[-2])
                v_slope = temp_df.VMA20.pct_change().iloc[-1]
                
                condi_1 = min(temp_df.VMA5.iloc[-1], temp_df.VMA20.iloc[-1]) >= 5000
                condi_2 = temp_df.slope_10.iloc[-1] > 0 and temp_df.MA5.iloc[-1] > temp_df.MA10.iloc[-1]
                condi_3 = temp_df.MA10.iloc[-1] > temp_df.MA20.iloc[-1]
                condi_4 = 1.5 <= v_ratio and v_ratio <= 5
                condi_5 = temp_df.slope_5.iloc[-1] > 0
                # condi_5 = temp_df.slope.iloc[-1] > 0
                condi_6 = v_slope > 0
                condi_7 = temp_df.High.iloc[-1] >= temp_df.High.iloc[-5:].max()
                condi_8 = temp_df["ATR%"].iloc[-1] >= 0.03
                if all([condi_1, condi_2, condi_3, condi_4, condi_5, condi_6, condi_7, condi_8]): #, condi_8
                    final_select.append(ticker)
            except:
                pass
        return final_select
    except:
        # print(f'ticker : {ticker}\t Error : ',GetException())
        print(f'Error : ',GetException())
        return []
    
def FindCrossDayTradeTicker2(td = datetime.today(), min_price=0, max_price=50, num_shares=10000, shares_ratio=0):
    try:
        td, last = getDateBeforeTrade(td.replace(hour=18))
        # setup data
        schema = getSchema('TWSE')
        table = schema['StockList']
        last_date = sorted(table.distinct("UpdateDate"))[-1]
        info_data = dict((x['Ticker'], x['Industry']+f"({x['Market'][-1]})") for x in table.find({"UpdateDate":{"$eq":last_date}, "Industry" :{"$ne":""}}) if "金融" not in x['Industry'])
        
        schema = getSchema('TWSE')
        table = schema['historicalPrice']
        data = list(table.find({'Date':{'$gte':(td+timedelta(-30)).strftime('%Y-%m-%d'), '$lte':td.strftime('%Y-%m-%d')}, "Ticker" :{"$in":list(info_data.keys())}}))
        
        df = pd.DataFrame(data).set_index('Date')
        if len(df.index.unique()) < 3:
            data = list(table.find({'Date':{'$gte':(td+timedelta(-60)).strftime('%Y-%m-%d'), '$lte':td.strftime('%Y-%m-%d')}}))
            df = pd.DataFrame(data).set_index('Date')
#         df = df.loc[sorted(df.index.unique())[-3:], :]
        del df['_id']
        for col in 'Open,High,Low,Close,Volume'.split(','):
            df[col] = df[col].apply(changedType)
        df["Adj V"] = df["Volume"].apply(lambda x: int(x/1000))
        df['up_limit'] = df.Close.apply(getLimit)
        final_select = []
        for ticker in list(info_data.keys()):
            try:
                tmp_df = df[df.Ticker == ticker]
                tmp_df = Calc.MA(tmp_df, [5,10,20])
                tmp_df['slope5'] = tmp_df.MA5.pct_change()
                tmp_df['slope10'] = tmp_df.MA10.pct_change()
                tmp_df['slope20'] = tmp_df.MA20.pct_change()
                tmp_df['VMA'] = tmp_df['Adj V'].rolling(5).mean()
                
                v_condi = tmp_df.VMA.iloc[-1] >= 1000 and tmp_df.VMA.pct_change().iloc[-1] > 0
                slope_condi = tmp_df.slope5.iloc[-1] > 0 and tmp_df.slope10.iloc[-1] > 0 and tmp_df.slope20.iloc[-1] > 0
                ma_condi = tmp_df.MA5.iloc[-1] > tmp_df.MA10.iloc[-1] and tmp_df.MA10.iloc[-1] > tmp_df.MA20.iloc[-1]
                real_bar = max(abs(tmp_df[['Open','Close']].max(axis=1).iloc[-1] - tmp_df[['Open','Close']].min(axis=1).iloc[-1]), get_minimum_tick(tmp_df.Close.iloc[-1]))
                up_line = abs(tmp_df.High.iloc[-1] - tmp_df[['Open','Close']].max(axis=1).iloc[-1])
                k_condi1 = up_line / real_bar >= 1 and tmp_df.Open.iloc[-1] >= tmp_df.Close.iloc[-1] if real_bar else False
                k_condi2 = tmp_df.Open.iloc[-1] / tmp_df.Close.iloc[-1] - 1 >= .05
                k_condi = all(not k_condi1, not k_condi2)
                if all([v_condi, k_condi]): # slope_condi, ma_condi, , not k_condi
                    if tmp_df.Close.iloc[-2] >= tmp_df.up_limit.iloc[-3]:
                        if tmp_df['Adj V'].iloc[-1] > tmp_df['Adj V'].iloc[-2]:
                            if tmp_df.Close.iloc[-1] != tmp_df.up_limit.iloc[-2] and (tmp_df.Close.iloc[-1] / tmp_df.Close.iloc[-2] - 1) >= .02: # tmp_df.Close.iloc[-1] != getLimit(tmp_df.Close.iloc[-2],trend="D"):
                                print(ticker, up_line, real_bar, up_line / real_bar)
                                final_select.append((ticker, tmp_df.Close.iloc[-1]))
            except KeyboardInterrupt:
                return []
            except:
                pass
            
        return final_select
    except:
        # print(f'ticker : {ticker}\t Error : ',GetException())
        print(f'Error : ',GetException())
        return []

def Backtest(td = datetime.today(), tickers=[]):
    try:
        output = []
        loss_trade = []
        win_trade = []
        total_pnl = 0
        total_trade_value = 0
        for ticker, refPrice in tickers:
            pnl = 0
            max_ret = 0
            min_ret = 1
            target = getLimit(refPrice, 0.02)
            stop_loss = getLimit(refPrice, 0.03, "D")
            df = ReadData(api, ticker, date)
            
            for row in df.itertuples():
                price = row.close
                qty = row.volume
                time = row.datetime
                tmp_ret = price / refPrice - 1
                max_ret = max(tmp_ret, max_ret)
                min_ret = min(tmp_ret, min_ret)
                if not qty:continue
                if price >= target or price <= stop_loss or time >= time.replace(hour=13,minute=0, second=0):
                    exit = row.bid_price
                    if abs(exit / price - 1) > .005:
                        continue
                    pnl = (exit - refPrice) * 1000
                    pnl -= int(get_commission(refPrice)) # 進場成本
                    pnl -= int(get_commission(exit, direction='EXIT')) # 出場成本
                    
                    output.append({
                        "Ticker":ticker,
                        "Entry":refPrice,
                        "Exit":exit,
                        "exit_time":time,
                        "PnL":pnl,
                        "MaxRet":max_ret,
                        "MinRet":min_ret
                    })
                    break
            total_pnl += pnl
            total_trade_value += refPrice * 1000
            if pnl > 0:
                win_trade.append(ticker)
            else:
                loss_trade.append(ticker)
                
        print("Max Ret >= 2% : ", len(win_trade), win_trade)
#         print(f"profit Probability for all : {round(len(ticker_volume_filted) / len(tickers)*100, 2)} %")
        print(f"profit Probability for trade : {round(len(win_trade) / len(tickers)*100, 2)} %")
        print(f'Total PnL without cost: {total_pnl}')
        print(f'Total Trade Value: {total_trade_value}')
        print(pd.DataFrame(output))
        return output
    except:
        # print(f'ticker : {ticker}\t Error : ',GetException())
        print(f'Error : ',GetException())
        pass

# %%
def MainBacktest(date = datetime(2022,1,14)):
    try:
        print("\n\n=======================回測開始=======================")
        tdStr = date.strftime('%Y-%m-%d')
        if date.isocalendar()[-1] > 5:
            print(f"{tdStr} is Holiday.")
            return
        i = -1
        while i:
            last_date = date + timedelta(i)
            if last_date.isocalendar()[-1] <= 5:
                break
            i -= 1

        print(f"Backtest {tdStr}, ticker prepare from {last_date.strftime('%Y-%m-%d')}.\n")
        tickers = FindCrossDayTradeTicker2(last_date, min_price=0, max_price=9999, num_shares=1000, shares_ratio=1.5)
        if tickers:
            print(tickers, '\n')
            return Backtest(date, tickers)
        else:
            print(f"No Tickers for {tdStr} to Trade.\n")
            return []
    except:
        return []

# %% [markdown]
# date = datetime(2022,3,29)
# tdStr = date.strftime('%Y-%m-%d')
# if date.isocalendar()[-1] > 5:
#     print(f"{tdStr} is Holiday.")
# #     return
# i = -1
# while i:
#     last_date = date + timedelta(i)
#     if last_date.isocalendar()[-1] <= 5:
#         break
#     i -= 1
# tickers = FindCrossDayTradeTicker2(last_date, min_price=0, max_price=9999, num_shares=1000, shares_ratio=1.5)

# %% [markdown]
# tickers

# %%
result = {}

# %%
start_date = datetime(2022,1,1)
end_date = datetime(2022,1,3)
# end_date = datetime(2022,1,3)

for date in pd.date_range(start_date, end_date):
    try:
        result[date.strftime("%Y-%m-%d")] = MainBacktest(date)
    except KeyboardInterrupt:
        break
# Out:
# =======================回測開始=======================
# 2022-01-01 is Holiday.
#
#
# =======================回測開始=======================
# 2022-01-02 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2022-01-03, ticker prepare from 2021-12-31.
#
# 1560 5.5 2.0 2.75
# 2349 0.25 0.75 0.3333333333333333
# 8028 3.700000000000003 0.5 7.400000000000006
# 3455 2.9000000000000057 7.0 0.4142857142857151
# 4162 0.7000000000000028 1.2000000000000028 0.5833333333333344
# 6134 0.8999999999999986 1.8999999999999986 0.4736842105263154
# 8071 0.40000000000000213 1.2999999999999972 0.30769230769231
# [('1560', 121.0), ('2349', 11.75), ('8028', 58.3), ('3455', 88.0), ('4162', 72.6), ('6134', 33.7), ('8071', 16.1)]
#
# Max Ret >= 2% :  3 ['1560', '8028', '3455']
# profit Probability for trade : 42.86 %
# Total PnL without cost: -694.9999999999866
# Total Trade Value: 401450.0
#   Ticker   Entry    Exit           exit_time     PnL    MaxRet    MinRet
# 0   1560  121.00  123.50 2022-01-03 09:00:00  1921.0  0.024793  0.024793
# 1   2349   11.75   11.40 2022-01-03 09:00:46  -408.0  0.000000 -0.029787
# 2   8028   58.30   59.50 2022-01-03 09:00:02   922.0  0.020583  0.020583
# 3   3455   88.00   89.50 2022-01-03 09:00:06  1080.0  0.019318  0.014773
# 4   4162   72.60   70.40 2022-01-03 09:19:53 -2533.0  0.012397 -0.028926
# 5   6134   33.70   32.70 2022-01-03 09:00:18 -1154.0  0.000000 -0.029674
# 6   8071   16.10   15.65 2022-01-03 09:42:37  -523.0  0.003106 -0.027950

# %%
start_date = datetime(2022,1,1)
end_date = datetime(2022,3,29)
# end_date = datetime(2022,1,3)

for date in pd.date_range(start_date, end_date):
    try:
        result[date.strftime("%Y-%m-%d")] = MainBacktest(date)
    except KeyboardInterrupt:
        break
# Out:
# =======================回測開始=======================
# 2022-01-01 is Holiday.
#
#
# =======================回測開始=======================
# 2022-01-02 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2022-01-03, ticker prepare from 2021-12-31.
#
# 1560 5.5 2.0 2.75
# 2349 0.25 0.75 0.3333333333333333
# 8028 3.700000000000003 0.5 7.400000000000006
# 3455 2.9000000000000057 7.0 0.4142857142857151
# 4162 0.7000000000000028 1.2000000000000028 0.5833333333333344
# 6134 0.8999999999999986 1.8999999999999986 0.4736842105263154
# 8071 0.40000000000000213 1.2999999999999972 0.30769230769231
# [('1560', 121.0), ('2349', 11.75), ('8028', 58.3), ('3455', 88.0), ('4162', 72.6), ('6134', 33.7), ('8071', 16.1)]
#
# Max Ret >= 2% :  3 ['1560', '8028', '3455']
# profit Probability for trade : 42.86 %
# Total PnL without cost: -694.9999999999866
# Total Trade Value: 401450.0
#   Ticker   Entry    Exit           exit_time     PnL    MaxRet    MinRet
# 0   1560  121.00  123.50 2022-01-03 09:00:00  1921.0  0.024793  0.024793
# 1   2349   11.75   11.40 2022-01-03 09:00:46  -408.0  0.000000 -0.029787
# 2   8028   58.30   59.50 2022-01-03 09:00:02   922.0  0.020583  0.020583
# 3   3455   88.00   89.50 2022-01-03 09:00:06  1080.0  0.019318  0.014773
# 4   4162   72.60   70.40 2022-01-03 09:19:53 -2533.0  0.012397 -0.028926
# 5   6134   33.70   32.70 2022-01-03 09:00:18 -1154.0  0.000000 -0.029674
# 6   8071   16.10   15.65 2022-01-03 09:42:37  -523.0  0.003106 -0.027950
#
#
# =======================回測開始=======================
# Backtest 2022-01-04, ticker prepare from 2022-01-03.
#
# 1236 0.0 4.949999999999999 0.0
# 3583 2.0 6.0 0.3333333333333333
# 4994 2.299999999999997 3.0 0.7666666666666657
# 3083 0.29999999999999716 4.0 0.07499999999999929
# 6220 0.6000000000000014 0.7999999999999972 0.7500000000000044
# 6667 1.0 10.200000000000003 0.09803921568627448
# [('1236', 30.3), ('3583', 107.0), ('4994', 65.3), ('3083', 65.7), ('6220', 25.1), ('6667', 88.8)]
#
# Max Ret >= 2% :  3 ['1236', '3583', '6667']
# profit Probability for trade : 50.0 %
# Total PnL without cost: -1445.0000000000018
# Total Trade Value: 382200.0
#   Ticker  Entry    Exit           exit_time     PnL    MaxRet    MinRet
# 0   1236   30.3   31.35 2022-01-04 09:00:35   905.0  0.034653  0.009901
# 1   3583  107.0  109.50 2022-01-04 09:00:02  1987.0  0.023364  0.023364
# 2   4994   65.3   63.30 2022-01-04 09:07:37 -2299.0  0.000000 -0.030628
# 3   3083   65.7   63.70 2022-01-04 09:00:56 -2301.0  0.000000 -0.028919
# 4   6220   25.1   24.60 2022-01-04 13:03:32  -615.0  0.003984 -0.023904
# 5   6667   88.8   90.10 2022-01-04 09:02:33   878.0  0.021396  0.004505
#
#
# =======================回測開始=======================
# Backtest 2022-01-05, ticker prepare from 2022-01-04.
#
# 2323 0.9000000000000004 0.20000000000000107 4.499999999999978
# 2359 0.3999999999999986 1.25 0.31999999999999884
# 2614 0.8500000000000014 0.3999999999999986 2.125000000000011
# 3383 0.0 0.05 0.0
# 3623 0.40000000000000213 1.0 0.40000000000000213
# 6156 0.1999999999999993 1.4499999999999993 0.1379310344827582
# 6532 0.5 2.3999999999999986 0.20833333333333345
# 8038 0.20000000000000284 2.1000000000000014 0.09523809523809652
# [('2323', 12.9), ('2359', 26.75), ('2614', 38.1), ('3383', 10.1), ('3623', 23.9), ('6156', 25.05), ('6532', 58.7), ('8038', 51.0)]
#
# Max Ret >= 2% :  2 ['2359', '3383']
# profit Probability for trade : 25.0 %
# Total PnL without cost: -5893.000000000002
# Total Trade Value: 246500.0
#   Ticker  Entry   Exit           exit_time     PnL    MaxRet    MinRet
# 0   2323  12.90  12.55 2022-01-05 09:02:39  -411.0  0.000000 -0.027132
# 1   2359  26.75  27.20 2022-01-05 12:02:53   324.0  0.018692 -0.028037
# 2   2614  38.10  37.00 2022-01-05 09:51:52 -1274.0  0.000000 -0.028871
# 3   3383  10.10  11.10 2022-01-05 09:00:12   943.0  0.099010  0.099010
# 4   3623  23.90  23.10 2022-01-05 09:00:09  -909.0  0.000000 -0.031381
# 5   6156  25.05  24.30 2022-01-05 09:38:06  -864.0  0.013972 -0.029940
# 6   6532  58.70  57.00 2022-01-05 09:47:15 -1969.0  0.008518 -0.028961
# 7   8038  51.00  49.50 2022-01-05 09:00:09 -1733.0  0.000000 -0.029412
#
#
# =======================回測開始=======================
# Backtest 2022-01-06, ticker prepare from 2022-01-05.
#
# 1732 2.3999999999999986 2.6000000000000014 0.923076923076922
# 3701 0.29999999999999716 4.5 0.06666666666666604
# 4720 0.04999999999999716 0.8500000000000014 0.05882352941176126
# 8104 0.8999999999999915 6.5 0.13846153846153714
# 3628 1.7000000000000028 2.8999999999999986 0.5862068965517254
# 8234 0.9499999999999993 1.1499999999999986 0.8260869565217396
# 8450 1.8999999999999915 0.9000000000000057 2.1111111111110885
# [('1732', 37.6), ('3701', 76.2), ('4720', 19.5), ('8104', 84.2), ('3628', 47.1), ('8234', 26.85), ('8450', 65.4)]
#
# Max Ret >= 2% :  3 ['1732', '4720', '8104']
# profit Probability for trade : 42.86 %
# Total PnL without cost: -3566.0000000000164
# Total Trade Value: 356850.0
#   Ticker  Entry   Exit           exit_time     PnL    MaxRet    MinRet
# 0   1732  37.60  40.40 2022-01-06 09:00:04  2613.0  0.077128  0.077128
# 1   3701  76.20  74.00 2022-01-06 09:02:46 -2550.0  0.000000 -0.028871
# 2   4720  19.50  19.85 2022-01-06 09:00:27   258.0  0.025641  0.010256
# 3   8104  84.20  85.60 2022-01-06 09:09:22  1000.0  0.019002 -0.026128
# 4   3628  47.10  45.70 2022-01-06 10:11:16 -1616.0  0.012739 -0.029724
# 5   8234  26.85  26.20 2022-01-06 13:00:40  -773.0  0.000000 -0.026071
# 6   8450  65.40  63.20 2022-01-06 09:00:08 -2498.0  0.000000 -0.029052
#
#
# =======================回測開始=======================
# Backtest 2022-01-07, ticker prepare from 2022-01-06.
#
# 1533 0.5999999999999943 1.4000000000000057 0.4285714285714228
# 2443 0.0 0.8800000000000008 0.0
# 3043 0.0 0.5700000000000003 0.0
# 3383 0.0 2.209999999999999 0.0
# 8101 0.0 0.3799999999999999 0.0
# 4939 0.09999999999999787 1.4500000000000028 0.0689655172413777
# [('1533', 72.4), ('2443', 4.1), ('3043', 4.8), ('3383', 9.99), ('8101', 3.21), ('4939', 27.1)]
#
# Max Ret >= 2% :  2 ['2443', '4939']
# profit Probability for trade : 33.33 %
# Total PnL without cost: -2328.000000000009
# Total Trade Value: 121600.0
#   Ticker  Entry   Exit           exit_time     PnL    MaxRet    MinRet
# 0   1533  72.40  70.30 2022-01-07 09:16:00 -2432.0  0.000000 -0.029006
# 1   2443   4.10   4.20 2022-01-07 11:30:04    64.0  0.024390 -0.002439
# 2   3043   4.80   4.68 2022-01-07 13:00:01  -158.0  0.037500 -0.022917
# 3   8101   3.21   3.12 2022-01-07 12:00:10  -123.0  0.012461 -0.028037
# 4   4939  27.10  27.55 2022-01-07 09:00:58   321.0  0.018450  0.007380
#
#
# =======================回測開始=======================
# 2022-01-08 is Holiday.
#
#
# =======================回測開始=======================
# 2022-01-09 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2022-01-10, ticker prepare from 2022-01-07.
#
# 2358 0.3000000000000007 2.8999999999999986 0.10344827586206926
# 8071 1.1000000000000014 0.6499999999999986 1.6923076923076983
# 8107 0.6500000000000021 0.6499999999999986 1.0000000000000056
# [('2358', 28.2), ('8071', 20.15), ('8107', 22.95)]
#
# Max Ret >= 2% :  1 ['8071']
# profit Probability for trade : 33.33 %
# Total PnL without cost: -1826.9999999999966
# Total Trade Value: 71300.0
#   Ticker  Entry   Exit           exit_time     PnL    MaxRet    MinRet
# 0   2358  28.20  27.05 2022-01-10 09:00:02 -1278.0  0.000000 -0.040780
# 1   8071  20.15  20.45 2022-01-10 09:03:12   205.0  0.019851 -0.012407
# 2   8107  22.95  22.30 2022-01-10 09:02:56  -754.0  0.000000 -0.028322
#
#
# =======================回測開始=======================
# Backtest 2022-01-11, ticker prepare from 2022-01-10.
#
# 6289 0.0 0.19999999999999973 0.0
# 6598 0.0 3.0 0.0
# 3086 4.0 17.0 0.23529411764705882
# 3687 0.5 29.5 0.01694915254237288
# 4946 0.0 7.099999999999994 0.0
# [('6289', 3.85), ('6598', 53.2), ('3086', 127.0), ('3687', 205.5), ('4946', 87.2)]
#
# Max Ret >= 2% :  2 ['3086', '3687']
# profit Probability for trade : 40.0 %
# Total PnL without cost: -3762.000000000004
# Total Trade Value: 476750.0
#   Ticker   Entry    Exit           exit_time     PnL    MaxRet    MinRet
# 0   6289    3.85    3.64 2022-01-11 10:30:03  -244.0  0.000000 -0.054545
# 1   6598   53.20   51.60 2022-01-11 09:00:16 -1843.0  0.000000 -0.030075
# 2   3086  127.00  129.00 2022-01-11 09:00:46  1395.0  0.023622  0.011811
# 3   3687  205.50  209.00 2022-01-11 09:09:49  2520.0  0.019465 -0.021898
# 4   4946   87.20   82.00 2022-01-11 09:00:11 -5590.0  0.000000 -0.059633
#
#
# =======================回測開始=======================
# Backtest 2022-01-12, ticker prepare from 2022-01-11.
# 1512 0.15000000000000036 0.34999999999999964 0.42857142857143005
# 2614 1.1499999999999986 2.1499999999999986 0.5348837209302323
# 2642 0.09999999999999432 8.299999999999997 0.012048192771083656
# 3043 0.0 0.4500000000000002 0.0
# 3583 4.5 6.5 0.6923076923076923
# 3624 2.299999999999997 2.799999999999997 0.8214285714285713
# 4529 0.9499999999999993 1.5999999999999979 0.5937500000000003
# 6266 1.9500000000000028 4.25 0.45882352941176535
# [('1512', 5.25), ('2614', 39.5), ('2642', 82.9), ('3043', 5.17), ('3583', 103.0), ('3624', 85.4), ('4529', 16.6), ('6266', 34.75)]
#
# Max Ret >= 2% :  5 ['2614', '2642', '3583', '4529', '6266']
# profit Probability for trade : 62.5 %
# Total PnL without cost: 3611.999999999991
# Total Trade Value: 372570.0
#   Ticker   Entry    Exit           exit_time     PnL    MaxRet    MinRet
# 0   1512    5.25    5.00 2022-01-12 09:30:02  -289.0  0.000000 -0.047619
# 1   2614   39.50   40.20 2022-01-12 09:00:00   513.0  0.018987  0.018987
# 2   2642   82.90   86.10 2022-01-12 09:00:07  2799.0  0.043426  0.043426
# 3   3043    5.17    4.98 2022-01-12 10:00:07  -228.0  0.000000 -0.032882
# 4   3583  103.00  106.00 2022-01-12 09:00:01  2504.0  0.033981  0.033981
# 5   3624   85.40   82.90 2022-01-12 09:41:19 -2892.0  0.011710 -0.029274
# 6   4529   16.60   17.05 2022-01-12 09:00:06   371.0  0.030120  0.030120
# 7   6266   34.75   35.75 2022-01-12 09:00:00   834.0  0.028777  0.028777
#
#
# =======================回測開始=======================
# Backtest 2022-01-13, ticker prepare from 2022-01-12.
#
# 6477 0.10000000000000142 1.8999999999999986 0.05263157894736921
# 6231 0.0 9.400000000000006 0.0
# [('6477', 56.9), ('6231', 88.0)]
#
# Max Ret >= 2% :  1 ['6231']
# profit Probability for trade : 50.0 %
# Total PnL without cost: -380.9999999999957
# Total Trade Value: 144900.0
#   Ticker  Entry  Exit           exit_time     PnL    MaxRet    MinRet
# 0   6477   56.9  55.2 2022-01-13 09:02:18 -1960.0  0.000000 -0.029877
# 1   6231   88.0  90.0 2022-01-13 09:09:36  1579.0  0.022727 -0.011364
#
#
# =======================回測開始=======================
# Backtest 2022-01-14, ticker prepare from 2022-01-13.
#
# 3437 0.8999999999999986 0.3000000000000007 2.999999999999988
# 5258 0.6500000000000057 0.09999999999999432 6.500000000000426
# 5344 0.14999999999999858 2.1000000000000014 0.0714285714285707
# [('3437', 29.0), ('5258', 44.8), ('5344', 29.7)]
#
# Max Ret >= 2% :  0 []
# profit Probability for trade : 0.0 %
# Total PnL without cost: -3721.9999999999964
# Total Trade Value: 103500.0
#   Ticker  Entry   Exit           exit_time     PnL  MaxRet    MinRet
# 0   3437   29.0  28.15 2022-01-14 09:01:35  -982.0     0.0 -0.029310
# 1   5258   44.8  43.50 2022-01-14 09:05:09 -1505.0     0.0 -0.029018
# 2   5344   29.7  28.60 2022-01-14 09:00:25 -1235.0     0.0 -0.035354
#
#
# =======================回測開始=======================
# 2022-01-15 is Holiday.
#
#
# =======================回測開始=======================
# 2022-01-16 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2022-01-17, ticker prepare from 2022-01-14.
#
# 2009 0.20000000000000284 0.25 0.8000000000000114
# 2032 0.1999999999999993 0.8000000000000007 0.2499999999999989
# 4171 7.5 2.0 3.75
# [('2009', 44.4), ('2032', 21.8), ('4171', 112.0)]
#
# Max Ret >= 2% :  1 ['4171']
# profit Probability for trade : 33.33 %
# Total PnL without cost: -1283.9999999999995
# Total Trade Value: 178200.0
#   Ticker  Entry    Exit           exit_time     PnL    MaxRet    MinRet
# 0   2009   44.4   43.10 2022-01-17 09:10:59 -1503.0  0.000000 -0.029279
# 1   2032   21.8   21.15 2022-01-17 09:46:17  -749.0  0.000000 -0.029817
# 2   4171  112.0  113.50 2022-01-17 09:00:38   968.0  0.017857  0.000000
#
#
# =======================回測開始=======================
# Backtest 2022-01-18, ticker prepare from 2022-01-17.
#
# No Tickers for 2022-01-18 to Trade.
#
#
#
# =======================回測開始=======================
# Backtest 2022-01-19, ticker prepare from 2022-01-18.
#
# 1316 1.1999999999999993 1.1500000000000021 1.0434782608695627
# 2380 0.6499999999999986 0.15000000000000036 4.3333333333333135
# 4931 0.4499999999999993 1.3500000000000014 0.3333333333333325
# 5245 0.4000000000000057 4.299999999999997 0.09302325581395487
# 6129 1.5499999999999972 0.20000000000000284 7.749999999999876
# 6465 0.0 4.899999999999999 0.0
# 6547 11.0 18.5 0.5945945945945946
# 8155 0.0 5.0 0.0
# 3592 14.0 38.0 0.3684210526315789
# [('1316', 24.85), ('2380', 15.55), ('4931', 25.0), ('5245', 87.6), ('6129', 36.85), ('6465', 30.1), ('6547', 266.0), ('8155', 189.5), ('3592', 666.0)]
#
# Max Ret >= 2% :  2 ['1316', '6129']
# profit Probability for trade : 22.22 %
# Total PnL without cost: -39083.0
# Total Trade Value: 1341450.0
#   Ticker   Entry    Exit           exit_time      PnL    MaxRet    MinRet
# 0   1316   24.85   25.20 2022-01-19 09:07:55    232.0  0.018109 -0.014085
# 1   2380   15.55   15.10 2022-01-19 09:00:21   -521.0  0.000000 -0.028939
# 2   4931   25.00   24.30 2022-01-19 09:43:35   -814.0  0.012000 -0.028000
# 3   5245   87.60   83.60 2022-01-19 09:00:04  -4396.0  0.000000 -0.045662
# 4   6129   36.85   37.35 2022-01-19 13:00:02    326.0  0.016282 -0.023066
# 5   6465   30.10   29.00 2022-01-19 09:01:01  -1236.0  0.000000 -0.033223
# 6   6547  266.00  263.00 2022-01-19 13:00:02  -4240.0  0.016917 -0.018797
# 7   8155  189.50  184.00 2022-01-19 09:00:18  -6371.0  0.000000 -0.029024
# 8   3592  666.00  647.00 2022-01-19 09:00:20 -22063.0  0.000000 -0.028529
#
#
# =======================回測開始=======================
# Backtest 2022-01-20, ticker prepare from 2022-01-19.
#
# 3710 0.0 0.05000000000000071 0.0
# [('3710', 14.0)]
#
# Max Ret >= 2% :  0 []
# profit Probability for trade : 0.0 %
# Total PnL without cost: -813.0
# Total Trade Value: 14000.0
#   Ticker  Entry   Exit           exit_time    PnL  MaxRet  MinRet
# 0   3710   14.0  13.25 2022-01-20 09:00:03 -813.0       0   -0.05
#
#
# =======================回測開始=======================
# Backtest 2022-01-21, ticker prepare from 2022-01-20.
#
# No Tickers for 2022-01-21 to Trade.
#
#
#
# =======================回測開始=======================
# 2022-01-22 is Holiday.
#
#
# =======================回測開始=======================
# 2022-01-23 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2022-01-24, ticker prepare from 2022-01-21.
#
# 2359 1.0999999999999979 1.5 0.733333333333332
# 8440 2.200000000000003 0.34999999999999787 6.285714285714332
# [('2359', 24.1), ('8440', 27.65)]
#
# Max Ret >= 2% :  1 ['8440']
# profit Probability for trade : 50.0 %
# Total PnL without cost: -491.0
# Total Trade Value: 51750.0
#   Ticker  Entry  Exit           exit_time    PnL    MaxRet    MinRet
# 0   2359  24.10  23.4 2022-01-24 09:00:27 -810.0  0.000000 -0.029046
# 1   8440  27.65  28.1 2022-01-24 09:02:45  319.0  0.019892 -0.005425
#
#
# =======================回測開始=======================
# Backtest 2022-01-25, ticker prepare from 2022-01-24.
#
# No Tickers for 2022-01-25 to Trade.
#
#
#
# =======================回測開始=======================
# Backtest 2022-01-26, ticker prepare from 2022-01-25.
#
# 1529 1.75 0.3000000000000007 5.83333333333332
# 6446 9.5 8.0 1.1875
# [('1529', 24.95), ('6446', 285.0)]
#
# Max Ret >= 2% :  2 ['1529', '6446']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 3373.0000000000014
# Total Trade Value: 309950.0
#   Ticker   Entry   Exit           exit_time     PnL    MaxRet    MinRet
# 0   1529   24.95   25.3 2022-01-26 09:05:46   232.0  0.020040 -0.026052
# 1   6446  285.00  289.5 2022-01-26 09:44:54  3141.0  0.019298 -0.014035
#
#
# =======================回測開始=======================
# Backtest 2022-01-27, ticker prepare from 2022-01-26.
#
# No Tickers for 2022-01-27 to Trade.
#
#
#
# =======================回測開始=======================
# Backtest 2022-01-28, ticker prepare from 2022-01-27.
#
# No Tickers for 2022-01-28 to Trade.
#
#
#
# =======================回測開始=======================
# 2022-01-29 is Holiday.
#
#
# =======================回測開始=======================
# 2022-01-30 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2022-01-31, ticker prepare from 2022-01-28.
#
# No Tickers for 2022-01-31 to Trade.
#
#
#
# =======================回測開始=======================
# Backtest 2022-02-01, ticker prepare from 2022-01-31.
#
# No Tickers for 2022-02-01 to Trade.
#
#
#
# =======================回測開始=======================
# Backtest 2022-02-02, ticker prepare from 2022-02-01.
#
# No Tickers for 2022-02-02 to Trade.
#
#
#
# =======================回測開始=======================
# Backtest 2022-02-03, ticker prepare from 2022-02-02.
# No Tickers for 2022-02-03 to Trade.
#
#
#
# =======================回測開始=======================
# Backtest 2022-02-04, ticker prepare from 2022-02-03.
#
# No Tickers for 2022-02-04 to Trade.
#
#
#
# =======================回測開始=======================
# 2022-02-05 is Holiday.
#
#
# =======================回測開始=======================
# 2022-02-06 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2022-02-07, ticker prepare from 2022-02-04.
#
# No Tickers for 2022-02-07 to Trade.
#
#
#
# =======================回測開始=======================
# Backtest 2022-02-08, ticker prepare from 2022-02-07.
#
# No Tickers for 2022-02-08 to Trade.
#
#
#
# =======================回測開始=======================
# Backtest 2022-02-09, ticker prepare from 2022-02-08.
#
# 2497 0.4000000000000057 1.2999999999999972 0.30769230769231276
# 2603 4.5 4.5 1.0
# 2615 6.0 10.0 0.6
# 2618 0.6499999999999986 1.3500000000000014 0.4814814814814799
# 3338 1.2999999999999972 1.0 1.2999999999999972

# %%
start_date = datetime(2022,1,3)
end_date = datetime(2022,1,26)

for date in pd.date_range(start_date, end_date):
    result[date.strftime("%Y-%m-%d")] = MainBacktest(date)
# Out:
# =======================回測開始=======================
# Backtest 2022-01-03, ticker prepare from 2021-12-31.
#
# No Tickers for 2022-01-03 to Trade.
#
#
#
# =======================回測開始=======================
# Backtest 2022-01-04, ticker prepare from 2022-01-03.
#
# [('1236', 30.3)]
#
# Max Ret >= 2% :  1 ['1236']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 905.0000000000007
# Total Trade Value: 30300.0
#   Ticker  Entry   Exit           exit_time    PnL    MaxRet    MinRet
# 0   1236   30.3  31.35 2022-01-04 09:00:35  905.0  0.034653  0.009901
#
#
# =======================回測開始=======================
# Backtest 2022-01-05, ticker prepare from 2022-01-04.
#
# No Tickers for 2022-01-05 to Trade.
#
#
#
# =======================回測開始=======================
# Backtest 2022-01-06, ticker prepare from 2022-01-05.
#
# [('2417', 37.6)]
#
# Max Ret >= 2% :  0 []
# profit Probability for trade : 0.0 %
# Total PnL without cost: -3165.0
# Total Trade Value: 37600.0
#   Ticker  Entry  Exit           exit_time     PnL  MaxRet    MinRet
# 0   2417   37.6  34.6 2022-01-06 09:02:06 -3165.0       0 -0.079787
#
#
# =======================回測開始=======================
# Backtest 2022-01-07, ticker prepare from 2022-01-06.
#
# [('2443', 4.1), ('3043', 4.8), ('3383', 9.99), ('8101', 3.21)]
#
# Max Ret >= 2% :  1 ['2443']
# profit Probability for trade : 25.0 %
# Total PnL without cost: -216.99999999999943
# Total Trade Value: 22100.0
#   Ticker  Entry  Exit           exit_time    PnL    MaxRet    MinRet
# 0   2443   4.10  4.20 2022-01-07 11:30:04   64.0  0.024390 -0.002439
# 1   3043   4.80  4.68 2022-01-07 13:00:01 -158.0  0.037500 -0.022917
# 2   8101   3.21  3.12 2022-01-07 12:00:10 -123.0  0.012461 -0.028037
#
#
# =======================回測開始=======================
# 2022-01-08 is Holiday.
#
#
# =======================回測開始=======================
# 2022-01-09 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2022-01-10, ticker prepare from 2022-01-07.
#
# No Tickers for 2022-01-10 to Trade.
#
#
#
# =======================回測開始=======================
# Backtest 2022-01-11, ticker prepare from 2022-01-10.
#
# [('6289', 3.85), ('6598', 53.2), ('4946', 87.2)]
#
# Max Ret >= 2% :  0 []
# profit Probability for trade : 0.0 %
# Total PnL without cost: -7677.000000000004
# Total Trade Value: 144250.0
#   Ticker  Entry   Exit           exit_time     PnL  MaxRet    MinRet
# 0   6289   3.85   3.64 2022-01-11 10:30:03  -244.0     0.0 -0.054545
# 1   6598  53.20  51.60 2022-01-11 09:00:16 -1843.0     0.0 -0.030075
# 2   4946  87.20  82.00 2022-01-11 09:00:11 -5590.0     0.0 -0.059633
#
#
# =======================回測開始=======================
# Backtest 2022-01-12, ticker prepare from 2022-01-11.
#
# [('1325', 52.3), ('3043', 5.17), ('8440', 29.65)]
#
# Max Ret >= 2% :  1 ['1325']
# profit Probability for trade : 33.33 %
# Total PnL without cost: -810.9999999999952
# Total Trade Value: 87120.0
#   Ticker  Entry   Exit           exit_time     PnL   MaxRet    MinRet
# 0   1325  52.30  53.10 2022-01-12 09:01:06   552.0  0.01912  0.000000
# 1   3043   5.17   4.98 2022-01-12 10:00:07  -228.0  0.00000 -0.032882
# 2   8440  29.65  28.65 2022-01-12 09:20:09 -1135.0  0.00000 -0.033727
#
#
# =======================回測開始=======================
# Backtest 2022-01-13, ticker prepare from 2022-01-12.
#
# [('6231', 88.0)]
#
# Max Ret >= 2% :  1 ['6231']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 1579.0
# Total Trade Value: 88000.0
#   Ticker  Entry  Exit           exit_time     PnL    MaxRet    MinRet
# 0   6231   88.0  90.0 2022-01-13 09:09:36  1579.0  0.022727 -0.011364
#
#
# =======================回測開始=======================
# Backtest 2022-01-14, ticker prepare from 2022-01-13.
#
# No Tickers for 2022-01-14 to Trade.
#
#
#
# =======================回測開始=======================
# 2022-01-15 is Holiday.
#
#
# =======================回測開始=======================
# 2022-01-16 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2022-01-17, ticker prepare from 2022-01-14.
#
# No Tickers for 2022-01-17 to Trade.
#
#
#
# =======================回測開始=======================
# Backtest 2022-01-18, ticker prepare from 2022-01-17.
#
# No Tickers for 2022-01-18 to Trade.
#
#
#
# =======================回測開始=======================
# Backtest 2022-01-19, ticker prepare from 2022-01-18.
#
# [('6465', 30.1), ('8155', 189.5)]
#
# Max Ret >= 2% :  0 []
# profit Probability for trade : 0.0 %
# Total PnL without cost: -7607.000000000002
# Total Trade Value: 219600.0
#   Ticker  Entry   Exit           exit_time     PnL  MaxRet    MinRet
# 0   6465   30.1   29.0 2022-01-19 09:01:01 -1236.0       0 -0.033223
# 1   8155  189.5  184.0 2022-01-19 09:00:18 -6371.0       0 -0.029024
#
#
# =======================回測開始=======================
# Backtest 2022-01-20, ticker prepare from 2022-01-19.
#
# [('3710', 14.0)]
#
# Max Ret >= 2% :  0 []
# profit Probability for trade : 0.0 %
# Total PnL without cost: -813.0
# Total Trade Value: 14000.0
#   Ticker  Entry   Exit           exit_time    PnL  MaxRet  MinRet
# 0   3710   14.0  13.25 2022-01-20 09:00:03 -813.0       0   -0.05
#
#
# =======================回測開始=======================
# Backtest 2022-01-21, ticker prepare from 2022-01-20.
#
# No Tickers for 2022-01-21 to Trade.
#
#
#
# =======================回測開始=======================
# 2022-01-22 is Holiday.
#
#
# =======================回測開始=======================
# 2022-01-23 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2022-01-24, ticker prepare from 2022-01-21.
#
# No Tickers for 2022-01-24 to Trade.
#
#
#
# =======================回測開始=======================
# Backtest 2022-01-25, ticker prepare from 2022-01-24.
#
# No Tickers for 2022-01-25 to Trade.
#
#
#
# =======================回測開始=======================
# Backtest 2022-01-26, ticker prepare from 2022-01-25.
#
# No Tickers for 2022-01-26 to Trade.

# %%
start_date = datetime(2021,12,1)
end_date = datetime(2021,12,30)
# result = {}
for date in pd.date_range(start_date, end_date):
    result[date.strftime("%Y-%m-%d")] = MainBacktest(date)
# Out:
# =======================回測開始=======================
# Backtest 2021-12-01, ticker prepare from 2021-11-30.
#
# ['2331', '2344', '2355', '2375', '3019', '4927', '6182']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2331   -0.004024  0.018109 -0.020121  -100     24850.0
# 2344    0.010920  0.018721 -0.017161   350     32050.0
# 2355    0.045082  0.057377  0.013661   700     36600.0
# 2375    0.000000  0.034188 -0.021368  2000    117000.0
# 3019    0.024218  0.024218 -0.019173  1900     99100.0
# 4927   -0.096491 -0.008772 -0.096491 -5500    114000.0
# 6182    0.059902  0.079462  0.009780  1600     81800.0
# all :  7 ['2331', '2344', '2355', '2375', '3019', '4927', '6182']
# trade :  7 ['2331', '2344', '2355', '2375', '3019', '4927', '6182']
# Max Ret >= 2% :  4 ['2355', '2375', '3019', '6182']
# profit Probability for trade : 57.14 %
# Total PnL without cost: 950
# Total Trade Value: 505400.0
#
#
# =======================回測開始=======================
# Backtest 2021-12-02, ticker prepare from 2021-12-01.
#
# ['2342', '2355', '3483', '3624', '8289']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2342   -0.022222  0.026263 -0.040404   900     49500.0
# 2355   -0.052288  0.003922 -0.053595 -1900     38250.0
# 3483   -0.019417  0.033981 -0.038835  2000    103000.0
# 3624   -0.043893  0.009542 -0.043893 -2300     52400.0
# 8289   -0.048810  0.100000 -0.048810   800     42000.0
# all :  5 ['2342', '2355', '3483', '3624', '8289']
# trade :  5 ['2342', '2355', '3483', '3624', '8289']
# Max Ret >= 2% :  3 ['2342', '3483', '8289']
# profit Probability for trade : 60.0 %
# Total PnL without cost: -500
# Total Trade Value: 285150.0
#
#
# =======================回測開始=======================
# Backtest 2021-12-03, ticker prepare from 2021-12-02.
#
# ['1611', '1721', '2406', '2408', '2603', '2609', '2641', '3006', '6150', '6485']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1611    0.027190  0.045317 -0.015106   300     16550.0
# 1721   -0.017182  0.058419 -0.017182   550     29100.0
# 2406    0.004040  0.058586  0.002020   450     24750.0
# 2408   -0.012531 -0.007519 -0.036341 -1000     79800.0
# 2603    0.003759  0.030075 -0.007519  2500    133000.0
# 2609   -0.008197  0.032787 -0.012295  2000    122000.0
# 2641    0.005415  0.036101 -0.032491   550     27700.0
# 3006    0.023952  0.044910  0.008982  3000    167000.0
# 6150    0.043597  0.059946  0.000000  3500    183500.0
# 6485    0.006098  0.030488 -0.009146  3000    164000.0
# all :  10 ['1611', '1721', '2406', '2408', '2603', '2609', '2641', '3006', '6150', '6485']
# trade :  10 ['1611', '1721', '2406', '2408', '2603', '2609', '3006', '2641', '6150', '6485']
# Max Ret >= 2% :  9 ['1611', '1721', '2406', '2603', '2609', '2641', '3006', '6150', '6485']
# profit Probability for trade : 90.0 %
# Total PnL without cost: 14850
# Total Trade Value: 947400.0
#
#
# =======================回測開始=======================
# 2021-12-04 is Holiday.
#
#
# =======================回測開始=======================
# 2021-12-05 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2021-12-06, ticker prepare from 2021-12-03.
#
# ['2353', '2406', '2607', '6243', '6265']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2353   -0.013267  0.001658 -0.028192  -400     30150.0
# 2406    0.024145  0.034205  0.002012   450     24850.0
# 2607    0.022109  0.040816  0.005102   550     29400.0
# 6243    0.008571  0.095714 -0.034286  1400     70000.0
# 6265    0.018325  0.075916 -0.013089   350     19100.0
# all :  5 ['2353', '2406', '2607', '6243', '6265']
# trade :  5 ['2353', '2406', '2607', '6243', '6265']
# Max Ret >= 2% :  4 ['2406', '2607', '6243', '6265']
# profit Probability for trade : 80.0 %
# Total PnL without cost: 2350
# Total Trade Value: 173500.0
#
#
# =======================回測開始=======================
# Backtest 2021-12-07, ticker prepare from 2021-12-06.
#
# ['2426', '2606', '3508']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2426   -0.097179  0.032915 -0.097179   600     31900.0
# 2606    0.031304  0.034783 -0.005217  1100     57500.0
# 3508    0.098865  0.098865  0.019449  1200     61700.0
# all :  3 ['2426', '2606', '3508']
# trade :  3 ['2426', '2606', '3508']
# Max Ret >= 2% :  3 ['2426', '2606', '3508']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 2900
# Total Trade Value: 151100.0
#
#
# =======================回測開始=======================
# Backtest 2021-12-08, ticker prepare from 2021-12-07.
#
# ['1570', '2014', '2342', '2426', '2615', '3499', '3545', '4961', '8111']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1570    0.025440  0.037182 -0.017613   500     25550.0
# 2014    0.003846  0.051282  0.000000   750     39000.0
# 2342   -0.041441  0.027027 -0.045045  1100     55500.0
# 2426   -0.010417  0.029514 -0.017361   550     28800.0
# 2615    0.031414  0.062827  0.005236  3500    191000.0
# 3499    0.099156  0.099156  0.046414   450     23700.0
# 3545    0.000000  0.028902 -0.002890  3000    173000.0
# 4961    0.005618  0.033708  0.001873  5000    267000.0
# 8111    0.086873  0.098456 -0.032819   500     25900.0
# all :  9 ['1570', '2014', '2342', '2426', '2615', '3499', '3545', '4961', '8111']
# trade :  9 ['2014', '2342', '2426', '2615', '3545', '4961', '1570', '3499', '8111']
# Max Ret >= 2% :  9 ['1570', '2014', '2342', '2426', '2615', '3499', '3545', '4961', '8111']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 15350
# Total Trade Value: 829450.0
#
#
# =======================回測開始=======================
# Backtest 2021-12-09, ticker prepare from 2021-12-08.
#
# ['1611', '2028', '2030', '2485', '2601', '2605', '2606', '2637', '3508', '3515', '3532', '3624', '5608', '6150', '6182', '6191', '8069', '8299']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1611    0.007958  0.034483 -0.010610   350     18850.0
# 2028   -0.008939  0.017877 -0.025698  -400     44750.0
# 2030   -0.015949  0.011164 -0.017544  -500     31350.0
# 2485   -0.010893  0.017429 -0.037037  -250     22950.0
# 2601   -0.007407  0.018519 -0.014815  -100     13500.0
# 2605   -0.003205  0.019231 -0.024038  -100     31200.0
# 2606   -0.003300  0.019802 -0.021452  -200     60600.0
# 2637   -0.013210  0.019815 -0.023778 -1000     75700.0
# 3508    0.063830  0.098784  0.010638  1300     65800.0
# 3515    0.003490  0.006981 -0.036649  1000    286500.0
# 3532   -0.060403  0.031879 -0.062081  5500    298000.0
# 3624    0.039076  0.099467  0.012433  1100     56300.0
# 5608    0.015936  0.057769 -0.017928  1000     50200.0
# 6150    0.026316  0.042105  0.000000  3500    190000.0
# 6182   -0.042986  0.002262 -0.042986 -3800     88400.0
# 6191   -0.046875 -0.010817 -0.052885 -2050     41600.0
# 8069   -0.011278  0.037594 -0.022556  2500    133000.0
# 8299    0.010526  0.037895 -0.018947  9500    475000.0
# all :  18 ['1611', '2028', '2030', '2485', '2601', '2605', '2606', '2637', '3508', '3515', '3532', '3624', '5608', '6150', '6182', '6191', '8069', '8299']
# trade :  18 ['1611', '2028', '2030', '2485', '2601', '2605', '2606', '2637', '3515', '3532', '5608', '6191', '3508', '3624', '6150', '6182', '8069', '8299']
# Max Ret >= 2% :  8 ['1611', '3508', '3532', '3624', '5608', '6150', '8069', '8299']
# profit Probability for trade : 44.44 %
# Total PnL without cost: 17350
# Total Trade Value: 1983700.0
#
#
# =======================回測開始=======================
# Backtest 2021-12-10, ticker prepare from 2021-12-09.
#
# ['2374', '2406', '3701', '4956', '6190', '6251']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2374   -0.028807 -0.002058 -0.032922  -700     24300.0
# 2406    0.099458  0.099458 -0.018083   550     27650.0
# 3701   -0.003322  0.050941 -0.019934  1800     90300.0
# 4956   -0.019643 -0.005357 -0.028571  -550     28000.0
# 6190    0.005128  0.058974  0.000000   750     39000.0
# 6251    0.041575  0.050328 -0.004376   450     22850.0
# all :  6 ['2374', '2406', '3701', '4956', '6190', '6251']
# trade :  6 ['2374', '2406', '3701', '4956', '6251', '6190']
# Max Ret >= 2% :  4 ['2406', '3701', '6190', '6251']
# profit Probability for trade : 66.67 %
# Total PnL without cost: 2300
# Total Trade Value: 232100.0
#
#
# =======================回測開始=======================
# 2021-12-11 is Holiday.
#
#
# =======================回測開始=======================
# 2021-12-12 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2021-12-13, ticker prepare from 2021-12-10.
# ['1708', '2406', '3051', '3059', '6118', '6120', '6226', '6244']
#
#              Ret   HighRet    LowRet  PnL  TradeValue
# Ticker
# 1708   -0.021858  0.031421 -0.021858  700     36600.0
# 2406    0.098684  0.098684 -0.003289  600     30400.0
# 3051    0.097859  0.097859  0.070336  300     16350.0
# 3059    0.038418  0.082486 -0.011299  850     44250.0
# 6118    0.098927  0.098927  0.051251  800     41950.0
# 6120    0.098940  0.098940  0.035336  250     14150.0
# 6226    0.018750  0.040625 -0.006250  300     16000.0
# 6244    0.002660  0.046543 -0.003989  750     37600.0
# all :  8 ['1708', '2406', '3051', '3059', '6118', '6120', '6226', '6244']
# trade :  8 ['1708', '2406', '3051', '3059', '6120', '6226', '6118', '6244']
# Max Ret >= 2% :  8 ['1708', '2406', '3051', '3059', '6118', '6120', '6226', '6244']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 4550
# Total Trade Value: 237300.0
#
#
# =======================回測開始=======================
# Backtest 2021-12-14, ticker prepare from 2021-12-13.
#
# ['1611', '2399', '2406', '2419', '2442', '2457', '3515', '3704', '6129', '8111', '8215']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1611   -0.007299 -0.002433 -0.036496  -150     20550.0
# 2399   -0.064718 -0.010438 -0.079332 -1150     23950.0
# 2406    0.022455  0.041916 -0.031437   650     33400.0
# 2419   -0.049430  0.045627 -0.058935   500     26300.0
# 2442   -0.028777  0.014388 -0.039568  -400     13900.0
# 2457   -0.034320 -0.003550 -0.079290 -2100     42250.0
# 3515   -0.016729  0.040892 -0.016729  5000    269000.0
# 3704   -0.037889 -0.009472 -0.044655 -1400     36950.0
# 6129   -0.076826  0.000000 -0.085642 -1950     39700.0
# 8111    0.022147  0.027257 -0.023850   550     29350.0
# 8215   -0.095402  0.026437 -0.098851   850     43500.0
# all :  11 ['1611', '2399', '2406', '2419', '2442', '2457', '3515', '3704', '6129', '8111', '8215']
# trade :  11 ['1611', '2399', '2406', '2419', '2442', '2457', '3515', '3704', '8215', '6129', '8111']
# Max Ret >= 2% :  5 ['2406', '2419', '3515', '8111', '8215']
# profit Probability for trade : 45.45 %
# Total PnL without cost: 400
# Total Trade Value: 578850.0
#
#
# =======================回測開始=======================
# Backtest 2021-12-15, ticker prepare from 2021-12-14.
#
# ['1560', '2312', '2419', '3051', '3380', '3499', '6118', '6120', '6190', '6226', '6477']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1560   -0.069036 -0.007107 -0.071066 -4900     98500.0
# 2312   -0.050000 -0.012500 -0.053125  -800     16000.0
# 2419    0.004000  0.030000 -0.008000   500     25000.0
# 3051   -0.062176 -0.025907 -0.088083  -950     19300.0
# 3380    0.001466  0.001466 -0.036657    50     34100.0
# 3499    0.025830  0.066421 -0.007380   500     27100.0
# 6118    0.019608  0.045752 -0.021786   900     45900.0
# 6120    0.035461  0.095745  0.003546   250     14100.0
# 6190   -0.018476  0.038106 -0.023095   850     43300.0
# 6226    0.021472  0.042945 -0.006135   300     16300.0
# 6477   -0.001052  0.026288 -0.023134   950     47550.0
# all :  11 ['1560', '2312', '2419', '3051', '3380', '3499', '6118', '6120', '6190', '6226', '6477']
# trade :  11 ['1560', '2312', '2419', '3051', '3380', '6120', '6226', '6477', '3499', '6118', '6190']
# Max Ret >= 2% :  7 ['2419', '3499', '6118', '6120', '6190', '6226', '6477']
# profit Probability for trade : 63.64 %
# Total PnL without cost: -2350
# Total Trade Value: 387150.0
#
#
# =======================回測開始=======================
# Backtest 2021-12-16, ticker prepare from 2021-12-15.
#
# ['1611', '2457', '8111']
#
#              Ret   HighRet    LowRet  PnL  TradeValue
# Ticker
# 1611    0.006865  0.032037 -0.029748  400     21850.0
# 2457    0.055936  0.081050  0.009132  850     43800.0
# 8111   -0.001650  0.029703 -0.023102  600     30300.0
# all :  3 ['1611', '2457', '8111']
# trade :  3 ['1611', '2457', '8111']
# Max Ret >= 2% :  3 ['1611', '2457', '8111']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 1850
# Total Trade Value: 95950.0
#
#
# =======================回測開始=======================
# Backtest 2021-12-17, ticker prepare from 2021-12-16.
#
# ['1440', '2376', '2637', '3034', '3035', '3047', '3049', '3059', '3675', '5475', '5483', '6284', '8069']
#
#              Ret   HighRet    LowRet    PnL  TradeValue
# Ticker
# 1440    0.064516  0.098790  0.018145    450     24800.0
# 2376   -0.022152 -0.009494 -0.031646  -3500    158000.0
# 2637    0.046424  0.080301  0.010038   1500     79700.0
# 3034   -0.005618 -0.001873 -0.020599  -3000    534000.0
# 3035    0.036782  0.055172 -0.006897   4000    217500.0
# 3047   -0.065693  0.000000 -0.080292   -650     13700.0
# 3049    0.022876  0.091503  0.013072    300     15300.0
# 3059   -0.018256  0.028398 -0.030426    900     49300.0
# 3675   -0.100000 -0.012500 -0.100000 -16000    320000.0
# 5475   -0.022409  0.014006 -0.043417   -800     35700.0
# 5483   -0.015317 -0.006565 -0.024070  -3500    228500.0
# 6284    0.009887  0.049435 -0.021186   1400     70800.0
# 8069    0.000000  0.013986 -0.027972      0    143000.0
# all :  13 ['1440', '2376', '2637', '3034', '3035', '3047', '3049', '3059', '3675', '5475', '5483', '6284', '8069']
# trade :  13 ['1440', '2376', '2637', '3034', '3035', '3047', '3049', '3059', '3675', '5475', '5483', '6284', '8069']
# Max Ret >= 2% :  6 ['1440', '2637', '3035', '3049', '3059', '6284']
# profit Probability for trade : 46.15 %
# Total PnL without cost: -18900
# Total Trade Value: 1890300.0
#
#
# =======================回測開始=======================
# 2021-12-18 is Holiday.
#
#
# =======================回測開始=======================
# 2021-12-19 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2021-12-20, ticker prepare from 2021-12-17.
#
# ['1440', '2006', '2014', '2023', '2028', '2103', '2347', '2495', '2606', '3035', '3049', '6284']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1440   -0.005682  0.017045 -0.022727  -150     26400.0
# 2006    0.025373  0.034328  0.000000  1300     67000.0
# 2014    0.056355  0.071942  0.011990   800     41700.0
# 2023    0.024096  0.038153  0.002008   450     24900.0
# 2028    0.015419  0.042952  0.002203   900     45400.0
# 2103    0.100000  0.100000  0.015789   750     38000.0
# 2347   -0.043675  0.006024 -0.057229 -3300     66400.0
# 2495   -0.040000  0.015000 -0.052500 -1000     20000.0
# 2606   -0.006579  0.027961 -0.014803  1200     60800.0
# 3035   -0.037694  0.037694 -0.039911  4500    225500.0
# 3049   -0.025559  0.015974 -0.035144  -400     15650.0
# 6284   -0.018182  0.018182 -0.019580 -1300     71500.0
# all :  12 ['1440', '2006', '2014', '2023', '2028', '2103', '2347', '2495', '2606', '3035', '3049', '6284']
# trade :  12 ['1440', '2006', '2014', '2023', '2028', '2103', '2347', '2495', '2606', '3035', '3049', '6284']
# Max Ret >= 2% :  7 ['2006', '2014', '2023', '2028', '2103', '2606', '3035']
# profit Probability for trade : 58.33 %
# Total PnL without cost: 3750
# Total Trade Value: 703250.0
#
#
# =======================回測開始=======================
# Backtest 2021-12-21, ticker prepare from 2021-12-20.
#
# ['2103', '3033', '6477']
#
#              Ret   HighRet    LowRet  PnL  TradeValue
# Ticker
# 2103    0.027512  0.028708 -0.039474  800     41800.0
# 3033   -0.003170  0.017433 -0.020602 -100     31550.0
# 6477   -0.006211 -0.001035 -0.034161 -300     48300.0
# all :  3 ['2103', '3033', '6477']
# trade :  3 ['2103', '3033', '6477']
# Max Ret >= 2% :  1 ['2103']
# profit Probability for trade : 33.33 %
# Total PnL without cost: 400
# Total Trade Value: 121650.0
#
#
# =======================回測開始=======================
# Backtest 2021-12-22, ticker prepare from 2021-12-21.
#
# ['2103', '2355', '2606', '3041', '3607']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2103   -0.032596 -0.008149 -0.046566 -1400     42950.0
# 2355   -0.008230  0.017833 -0.008230  -300     36450.0
# 2606    0.009419  0.010989 -0.018838   600     63700.0
# 3041    0.001300  0.037711 -0.022107   750     38450.0
# 3607   -0.040816  0.002551 -0.056122  -950     19600.0
# all :  5 ['2103', '2355', '2606', '3041', '3607']
# trade :  5 ['2103', '2355', '2606', '3041', '3607']
# Max Ret >= 2% :  1 ['3041']
# profit Probability for trade : 20.0 %
# Total PnL without cost: -1300
# Total Trade Value: 201150.0
#
#
# =======================回測開始=======================
# Backtest 2021-12-23, ticker prepare from 2021-12-22.
# c:\users\kevin\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:73: RuntimeWarning: divide by zero encountered in longlong_scalars
# ['2374', '2405', '2457', '2476', '3033', '3217', '3322', '6235']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2374    0.099206  0.099206  0.017857   500     25200.0
# 2405    0.005222  0.015666 -0.007833   100     19150.0
# 2457    0.053854  0.098205  0.014784   900     47350.0
# 2476    0.094101  0.095506  0.025281  1400     71200.0
# 3033   -0.010920  0.014041 -0.015601  -350     32050.0
# 3217    0.000000  0.017241 -0.024138     0    145000.0
# 3322    0.099237  0.099237  0.053435   500     26200.0
# 6235   -0.044321  0.044321 -0.044321   700     36100.0
# all :  8 ['2374', '2405', '2457', '2476', '3033', '3217', '3322', '6235']
# trade :  8 ['2374', '2405', '2457', '2476', '3033', '6235', '3217', '3322']
# Max Ret >= 2% :  5 ['2374', '2457', '2476', '3322', '6235']
# profit Probability for trade : 62.5 %
# Total PnL without cost: 3750
# Total Trade Value: 402250.0
#
#
# =======================回測開始=======================
# Backtest 2021-12-24, ticker prepare from 2021-12-23.
#
# ['2312', '2340', '2374', '2399', '2457', '2465', '2476', '3322', '3624', '4915', '6235', '8104']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2312   -0.032836  0.014925 -0.032836  -550     16750.0
# 2340    0.099099  0.099099  0.036036  1300     66600.0
# 2374    0.099278  0.099278  0.010830   550     27700.0
# 2399   -0.016667 -0.001852 -0.029630  -450     27000.0
# 2457   -0.010020  0.026052 -0.011022   900     49900.0
# 2465   -0.059211  0.041667 -0.064693  1800     91200.0
# 2476   -0.002567  0.032092 -0.029525  1500     77900.0
# 3322    0.005208  0.059028 -0.043403   550     28800.0
# 3624    0.075806  0.096774  0.008065  1200     62000.0
# 4915   -0.025685  0.005137 -0.029110 -1500     58400.0
# 6235   -0.043478  0.018841 -0.076812 -1700     34500.0
# 8104    0.017083  0.061761 -0.019711  1500     76100.0
# all :  12 ['2312', '2340', '2374', '2399', '2457', '2465', '2476', '3322', '3624', '4915', '6235', '8104']
# trade :  12 ['2312', '2340', '2374', '2399', '2457', '2465', '2476', '4915', '6235', '8104', '3322', '3624']
# Max Ret >= 2% :  8 ['2340', '2374', '2457', '2465', '2476', '3322', '3624', '8104']
# profit Probability for trade : 66.67 %
# Total PnL without cost: 5100
# Total Trade Value: 616850.0
#
#
# =======================回測開始=======================
# 2021-12-25 is Holiday.
#
#
# =======================回測開始=======================
# 2021-12-26 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2021-12-27, ticker prepare from 2021-12-24.
#
# ['2368', '2374', '3041', '3049', '3322', '3624', '5258', '6282', '8069', '8201']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2368   -0.033962  0.059119 -0.035220  1500     79500.0
# 2374   -0.013136  0.047619 -0.027915   600     30450.0
# 3041    0.099099  0.099099  0.002574   750     38850.0
# 3049    0.098462  0.098462  0.018462   300     16250.0
# 3322    0.015544  0.098446 -0.015544   550     28950.0
# 3624    0.098951  0.098951  0.023988  1300     66700.0
# 5258   -0.021792  0.009685 -0.041162  -900     41300.0
# 6282   -0.058824  0.000000 -0.061327 -1950     39950.0
# 8069   -0.010135  0.020270 -0.020270  2500    148000.0
# 8201   -0.005634  0.022535 -0.014085   350     17750.0
# all :  10 ['2368', '2374', '3041', '3049', '3322', '3624', '5258', '6282', '8069', '8201']
# trade :  10 ['2368', '2374', '3041', '3049', '5258', '6282', '8201', '3322', '3624', '8069']
# Max Ret >= 2% :  8 ['2368', '2374', '3041', '3049', '3322', '3624', '8069', '8201']
# profit Probability for trade : 80.0 %
# Total PnL without cost: 5000
# Total Trade Value: 507700.0
#
#
# =======================回測開始=======================
# Backtest 2021-12-28, ticker prepare from 2021-12-27.
#
# ['2340', '2355', '3033', '3047', '6205', '8110', '8299']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2340   -0.007557  0.007557 -0.030227  -600     79400.0
# 2355   -0.026042  0.010417 -0.027344 -1000     38400.0
# 3033   -0.012308  0.030769 -0.027692   650     32500.0
# 3047    0.010490  0.027972 -0.034965   250     14300.0
# 6205    0.012723  0.024173 -0.016539  1500     78600.0
# 8110   -0.052239  0.007463 -0.052239 -1000     20100.0
# 8299   -0.001001  0.011011 -0.006006  -500    499500.0
# all :  7 ['2340', '2355', '3033', '3047', '6205', '8110', '8299']
# trade :  7 ['2340', '2355', '3033', '3047', '6205', '8110', '8299']
# Max Ret >= 2% :  3 ['3033', '3047', '6205']
# profit Probability for trade : 42.86 %
# Total PnL without cost: -700
# Total Trade Value: 762800.0
#
#
# =======================回測開始=======================
# Backtest 2021-12-29, ticker prepare from 2021-12-28.
#
# ['3033', '3041', '3049', '3094', '3624', '6120', '6138', '6275']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 3033   -0.007788 -0.004673 -0.015576  -250     32100.0
# 3041    0.039506  0.093827 -0.001235   800     40500.0
# 3049   -0.005540  0.083102 -0.013850   350     18050.0
# 3094    0.099045  0.099045  0.014320   800     41900.0
# 3624    0.089261  0.099024  0.008368  1400     71700.0
# 6120   -0.003425  0.030822 -0.010274   250     14600.0
# 6138    0.023339  0.023339 -0.012567  5500    278500.0
# 6275   -0.027842  0.016241 -0.058005 -2150     43100.0
# all :  8 ['3033', '3041', '3049', '3094', '3624', '6120', '6138', '6275']
# trade :  8 ['3033', '3041', '3049', '3094', '6120', '3624', '6138', '6275']
# Max Ret >= 2% :  6 ['3041', '3049', '3094', '3624', '6120', '6138']
# profit Probability for trade : 75.0 %
# Total PnL without cost: 6700
# Total Trade Value: 540450.0
#
#
# =======================回測開始=======================
# Backtest 2021-12-30, ticker prepare from 2021-12-29.
#
# ['1560', '1711', '2405', '2482', '4755', '6196', '6226']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1560    0.029787  0.076596  0.004255  2000    117500.0
# 1711   -0.019784  0.019784 -0.023381  -550     27800.0
# 2405   -0.004902  0.053922 -0.066176   400     20400.0
# 2482   -0.002907  0.017442 -0.008721   -50     17200.0
# 4755   -0.019663  0.053371 -0.022472  3500    178000.0
# 6196    0.025352  0.098592  0.014085  3500    177500.0
# 6226   -0.020772  0.011869 -0.020772  -350     16850.0
# all :  7 ['1560', '1711', '2405', '2482', '4755', '6196', '6226']
# trade :  7 ['1560', '1711', '2405', '2482', '4755', '6196', '6226']
# Max Ret >= 2% :  4 ['1560', '2405', '4755', '6196']
# profit Probability for trade : 57.14 %
# Total PnL without cost: 8450
# Total Trade Value: 555250.0

# %%
start_date = datetime(2021,11,1)
end_date = datetime(2021,11,30)
# result = {}
for date in pd.date_range(start_date, end_date):
    result[date.strftime("%Y-%m-%d")] = MainBacktest(date)
# Out:
# =======================回測開始=======================
# Backtest 2021-11-01, ticker prepare from 2021-10-29.
#
# ['2329', '2351', '2388', '2481', '3305', '3508', '3707', '4128', '4739', '5285', '5425', '6237', '6485', '6509', '8215']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2329    0.016129  0.032258  0.006048   450     24800.0
# 2351    0.099398  0.099398  0.060241  3000    166000.0
# 2388    0.099839  0.099839  0.024155  1200     62100.0
# 2481    0.097778  0.097778  0.031111  2000    112500.0
# 3305    0.060820  0.087694  0.015559  1400     70700.0
# 3508    0.099678  0.099678  0.054662   600     31100.0
# 3707    0.085246  0.098361  0.000000  3000    152500.0
# 4128   -0.028436  0.014218 -0.047393 -1800     63300.0
# 4739   -0.002915  0.029155 -0.020408  3000    171500.0
# 5285    0.098361  0.098361  0.012295  2000    122000.0
# 5425    0.099754  0.099754  0.034483  1600     81200.0
# 6237    0.098039  0.098039  0.039216  2000    102000.0
# 6485    0.011407  0.034221 -0.003802  2500    131500.0
# 6509   -0.001248  0.034956 -0.019975  1600     80100.0
# 8215    0.001271  0.021601 -0.013977   750     39350.0
# all :  15 ['2329', '2351', '2388', '2481', '3305', '3508', '3707', '4128', '4739', '5285', '5425', '6237', '6485', '6509', '8215']
# trade :  15 ['2329', '2351', '2388', '2481', '3305', '4739', '5285', '8215', '3508', '3707', '4128', '5425', '6237', '6485', '6509']
# Max Ret >= 2% :  14 ['2329', '2351', '2388', '2481', '3305', '3508', '3707', '4739', '5285', '5425', '6237', '6485', '6509', '8215']
# profit Probability for trade : 93.33 %
# Total PnL without cost: 23300
# Total Trade Value: 1410650.0
#
#
# =======================回測開始=======================
# Backtest 2021-11-02, ticker prepare from 2021-11-01.
#
# ['2338', '2376', '2388', '2401', '2486', '2610', '2618', '3508', '4721', '6217', '6443', '8069', '8201']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2338    0.055422  0.100000 -0.003614  1600     83000.0
# 2376   -0.008368  0.033473 -0.037657  2000    119500.0
# 2388    0.010249  0.077599 -0.033675  1300     68300.0
# 2401    0.023839  0.099122  0.021330   750     39850.0
# 2486    0.017915  0.099349 -0.011401  1200     61400.0
# 2610    0.046961  0.071823  0.013812   350     18100.0
# 2618    0.043257  0.073791  0.002545   350     19650.0
# 3508    0.023392  0.083333 -0.033626   650     34200.0
# 4721   -0.053521  0.000000 -0.087324 -8500    177500.0
# 6217   -0.061807  0.034865 -0.079239  1200     63100.0
# 6443    0.057143  0.082857  0.008571   700     35000.0
# 8069   -0.026151  0.043933 -0.042887  1900     95600.0
# 8201   -0.043360 -0.002710 -0.059621  -900     18450.0
# all :  13 ['2338', '2376', '2388', '2401', '2486', '2610', '2618', '3508', '4721', '6217', '6443', '8069', '8201']
# trade :  13 ['2338', '2376', '2388', '2401', '2486', '2610', '2618', '6443', '8201', '3508', '4721', '6217', '8069']
# Max Ret >= 2% :  11 ['2338', '2376', '2388', '2401', '2486', '2610', '2618', '3508', '6217', '6443', '8069']
# profit Probability for trade : 84.62 %
# Total PnL without cost: 2600
# Total Trade Value: 833650.0
#
#
# =======================回測開始=======================
# Backtest 2021-11-03, ticker prepare from 2021-11-02.
#
# ['1909', '2328', '2338', '2340', '2351', '2363', '2369', '2401', '2408', '2481', '2486', '2610', '2614', '2618', '3016', '3141', '3704', '5285', '5425', '6237', '8255']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1909   -0.007767  0.013592 -0.017476  -200     25750.0
# 2328   -0.012034  0.006017 -0.016847  -500     41550.0
# 2338    0.027397  0.031963 -0.009132  1700     87600.0
# 2340   -0.042391  0.000000 -0.053261 -2300     46000.0
# 2351   -0.045455  0.039773 -0.065341  3500    176000.0
# 2363    0.010288  0.016461 -0.018519   250     24300.0
# 2369   -0.030075  0.022556 -0.035714   500     26600.0
# 2401   -0.023284  0.019608 -0.053922 -2000     40800.0
# 2408    0.031579  0.037594  0.006015  1300     66500.0
# 2481   -0.031390  0.026906 -0.076233  2000    111500.0
# 2486   -0.068800  0.033600 -0.092800  1200     62500.0
# 2610    0.007916  0.039578 -0.002639   350     18950.0
# 2614    0.098731  0.098731  0.046544   700     35450.0
# 2618    0.009756  0.034146 -0.007317   400     20500.0
# 3016   -0.032710  0.051402 -0.056075  2000    107000.0
# 3141    0.008869  0.055432 -0.048780  4500    225500.0
# 3704    0.047766  0.070878 -0.001541   600     32450.0
# 5285   -0.070248  0.016529 -0.099174 -6000    121000.0
# 5425    0.031653  0.060961 -0.030481  1700     85300.0
# 6237   -0.009302  0.027907 -0.060465  2000    107500.0
# 8255    0.048913  0.048913 -0.019928  5500    276000.0
# all :  21 ['1909', '2328', '2338', '2340', '2351', '2363', '2369', '2401', '2408', '2481', '2486', '2610', '2614', '2618', '3016', '3141', '3704', '5285', '5425', '6237', '8255']
# trade :  21 ['1909', '2328', '2338', '2340', '2351', '2363', '2369', '2401', '2408', '2481', '2486', '2610', '2614', '2618', '3016', '3704', '5285', '3141', '5425', '6237', '8255']
# Max Ret >= 2% :  15 ['2338', '2351', '2369', '2408', '2481', '2486', '2610', '2614', '2618', '3016', '3141', '3704', '5425', '6237', '8255']
# profit Probability for trade : 71.43 %
# Total PnL without cost: 17200
# Total Trade Value: 1738750.0
#
#
# =======================回測開始=======================
# Backtest 2021-11-04, ticker prepare from 2021-11-03.
#
# ['2409', '2614', '6226', '8044']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2409   -0.017544  0.010025 -0.020050  -350     19950.0
# 2614   -0.044929 -0.011553 -0.044929 -1750     38950.0
# 6226    0.099010  0.099010  0.023102   300     15150.0
# 8044   -0.033784  0.047297 -0.033784  2500    148000.0
# all :  4 ['2409', '2614', '6226', '8044']
# trade :  4 ['2409', '2614', '6226', '8044']
# Max Ret >= 2% :  2 ['6226', '8044']
# profit Probability for trade : 50.0 %
# Total PnL without cost: 700
# Total Trade Value: 222050.0
#
#
# =======================回測開始=======================
# Backtest 2021-11-05, ticker prepare from 2021-11-04.
#
# ['2368', '3207', '4927', '5258', '6226', '8261']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2368   -0.009929  0.021277 -0.011348  1400     70500.0
# 3207   -0.007782  0.038911 -0.023346   500     25700.0
# 4927    0.002358  0.017689 -0.047170   200     84800.0
# 5258   -0.024902 -0.003932 -0.040629  -950     38150.0
# 6226   -0.042042  0.099099 -0.045045   300     16650.0
# 8261   -0.039474  0.000000 -0.057018 -5500    114000.0
# all :  6 ['2368', '3207', '4927', '5258', '6226', '8261']
# trade :  6 ['2368', '4927', '5258', '6226', '8261', '3207']
# Max Ret >= 2% :  3 ['2368', '3207', '6226']
# profit Probability for trade : 50.0 %
# Total PnL without cost: -4050
# Total Trade Value: 349800.0
#
#
# =======================回測開始=======================
# 2021-11-06 is Holiday.
#
#
# =======================回測開始=======================
# 2021-11-07 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2021-11-08, ticker prepare from 2021-11-05.
#
# ['2314', '2376', '2409', '3305', '3481', '3701', '5309', '6182', '6226', '8121']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2314   -0.075581 -0.026744 -0.098837 -4300     86000.0
# 2376    0.076613  0.088710 -0.004032  2000    124000.0
# 2409    0.019324  0.033816 -0.019324   400     20700.0
# 3305   -0.025641  0.043590 -0.028205  1500     78000.0
# 3481    0.010959  0.013699 -0.024658   200     18250.0
# 3701   -0.028716  0.043919 -0.069257  1100     59200.0
# 5309   -0.045226  0.011307 -0.045226 -1800     39800.0
# 6182    0.004525  0.043741  0.003017  1300     66300.0
# 6226   -0.065831 -0.012539 -0.075235  -750     15950.0
# 8121   -0.090734  0.044402 -0.092664  1000     51800.0
# all :  10 ['2314', '2376', '2409', '3305', '3481', '3701', '5309', '6182', '6226', '8121']
# trade :  10 ['2314', '2376', '2409', '3305', '3481', '3701', '6226', '5309', '6182', '8121']
# Max Ret >= 2% :  6 ['2376', '2409', '3305', '3701', '6182', '8121']
# profit Probability for trade : 60.0 %
# Total PnL without cost: 650
# Total Trade Value: 560000.0
#
#
# =======================回測開始=======================
# Backtest 2021-11-09, ticker prepare from 2021-11-08.
# ['1316', '1711', '1721', '1727', '1905', '2399', '2498', '2603', '2609', '2610', '2615', '2618', '3207']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1316    0.036415  0.081232 -0.036415   350     17850.0
# 1711    0.100000  0.100000 -0.001818   550     27500.0
# 1721    0.099291  0.099291 -0.030733   400     21150.0
# 1727    0.099284  0.099284 -0.006141   950     48850.0
# 1905   -0.010616  0.004246 -0.023355  -250     23550.0
# 2399    0.069565  0.100000  0.006522   450     23000.0
# 2498    0.058442  0.097403  0.010390  1500     77000.0
# 2603   -0.016129  0.020161 -0.032258  2000    124000.0
# 2609   -0.016949  0.021186 -0.025424  2000    118000.0
# 2610    0.050000  0.052381 -0.011905   400     21000.0
# 2615   -0.034211  0.007895 -0.039474 -6500    190000.0
# 2618    0.061702  0.061702 -0.021277   450     23500.0
# 3207    0.099796  0.099796 -0.002037   450     24550.0
# all :  13 ['1316', '1711', '1721', '1727', '1905', '2399', '2498', '2603', '2609', '2610', '2615', '2618', '3207']
# trade :  13 ['1316', '1711', '1721', '1727', '1905', '2399', '2498', '2603', '2609', '2610', '2615', '2618', '3207']
# Max Ret >= 2% :  11 ['1316', '1711', '1721', '1727', '2399', '2498', '2603', '2609', '2610', '2618', '3207']
# profit Probability for trade : 84.62 %
# Total PnL without cost: 2750
# Total Trade Value: 739950.0
#
#
# =======================回測開始=======================
# Backtest 2021-11-10, ticker prepare from 2021-11-09.
#
# ['1440', '1717', '2363', '2368', '3006', '3033', '3508', '4927', '4961', '6244', '6485', '8215', '8358']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1440    0.031056  0.099379 -0.006211   450     24150.0
# 1717   -0.017812  0.006361 -0.021628  -700     39300.0
# 2363   -0.015842  0.000000 -0.023762  -400     25250.0
# 2368   -0.029412 -0.005602 -0.033613 -2100     71400.0
# 3006    0.020202  0.020202 -0.023569  2500    148500.0
# 3033    0.099825  0.099825  0.015762   550     28550.0
# 3508    0.100000  0.100000  0.027160   800     40500.0
# 4927   -0.013889  0.014957 -0.037393 -1300     93600.0
# 4961   -0.009029  0.006772 -0.027088 -2000    221500.0
# 6244   -0.018841  0.000000 -0.018841  -650     34500.0
# 6485    0.074733  0.099644  0.003559  2500    140500.0
# 8215   -0.030504  0.000000 -0.034483 -1150     37700.0
# 8358   -0.011688  0.003896 -0.020779  -900     77000.0
# all :  13 ['1440', '1717', '2363', '2368', '3006', '3033', '3508', '4927', '4961', '6244', '6485', '8215', '8358']
# trade :  13 ['1440', '1717', '2363', '2368', '3006', '3033', '4927', '4961', '8215', '3508', '6244', '6485', '8358']
# Max Ret >= 2% :  5 ['1440', '3006', '3033', '3508', '6485']
# profit Probability for trade : 38.46 %
# Total PnL without cost: -2400
# Total Trade Value: 982450.0
#
#
# =======================回測開始=======================
# Backtest 2021-11-11, ticker prepare from 2021-11-10.
#
# ['1440', '1711', '1721', '1727', '2377', '2388', '3033', '4927', '5371', '6271', '6282', '6485']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1440    0.008032  0.028112 -0.026104   450     24900.0
# 1711   -0.030612  0.037415 -0.030612   550     29400.0
# 1721    0.033268  0.095890 -0.021526   500     25550.0
# 1727   -0.040140  0.075044 -0.050611  1100     57300.0
# 2377   -0.009009  0.006006 -0.024024 -1500    166500.0
# 2388   -0.027027  0.097297 -0.078919  1800     92500.0
# 3033   -0.012739  0.050955 -0.041401   600     31400.0
# 4927    0.099675  0.099675  0.008667  1800     92300.0
# 5371    0.001332  0.071904 -0.025300  1500     75100.0
# 6271   -0.006944  0.029514 -0.020833  5500    288000.0
# 6282   -0.022911  0.043127 -0.028302   700     37100.0
# 6485    0.043046  0.079470 -0.009934  3000    151000.0
# all :  12 ['1440', '1711', '1721', '1727', '2377', '2388', '3033', '4927', '5371', '6271', '6282', '6485']
# trade :  12 ['1440', '1711', '1721', '1727', '2377', '2388', '3033', '4927', '6271', '6282', '5371', '6485']
# Max Ret >= 2% :  11 ['1440', '1711', '1721', '1727', '2388', '3033', '4927', '5371', '6271', '6282', '6485']
# profit Probability for trade : 91.67 %
# Total PnL without cost: 16000
# Total Trade Value: 1071050.0
#
#
# =======================回測開始=======================
# Backtest 2021-11-12, ticker prepare from 2021-11-11.
#
# ['2023', '2030', '2388', '2498', '2504', '2607', '3006', '3033', '3062', '3141', '3169', '3508', '5371', '6118']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2023   -0.028037  0.018692 -0.035514  -750     26750.0
# 2030    0.003185  0.035032 -0.017516   600     31400.0
# 2388    0.100000  0.100000  0.013333  1800     90000.0
# 2498    0.099154  0.099154  0.003628  1600     82700.0
# 2504    0.037244  0.039106 -0.001862   500     26850.0
# 2607    0.015873  0.021164 -0.008818   550     28350.0
# 3006    0.009677  0.045161 -0.003226  3000    155000.0
# 3033    0.020968  0.025806 -0.014516   600     31000.0
# 3062    0.006838  0.066667  0.001709   550     29250.0
# 3141    0.040936  0.091618  0.013645  5000    256500.0
# 3169    0.098958  0.098958  0.013021  3500    192000.0
# 3508    0.100000  0.100000  0.018367   950     49000.0
# 5371    0.099734  0.099734  0.015957  1500     75200.0
# 6118    0.099788  0.099788  0.044586   450     23550.0
# all :  14 ['2023', '2030', '2388', '2498', '2504', '2607', '3006', '3033', '3062', '3141', '3169', '3508', '5371', '6118']
# trade :  14 ['2023', '2030', '2388', '2498', '2504', '2607', '3006', '3033', '3062', '3141', '3169', '3508', '5371', '6118']
# Max Ret >= 2% :  13 ['2030', '2388', '2498', '2504', '2607', '3006', '3033', '3062', '3141', '3169', '3508', '5371', '6118']
# profit Probability for trade : 92.86 %
# Total PnL without cost: 19850
# Total Trade Value: 1097550.0
#
#
# =======================回測開始=======================
# 2021-11-13 is Holiday.
#
#
# =======================回測開始=======================
# 2021-11-14 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2021-11-15, ticker prepare from 2021-11-12.
# c:\users\kevin\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:73: RuntimeWarning: divide by zero encountered in longlong_scalars
# ['2038', '2368', '2498', '3059', '3588', '6104', '8040']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2038   -0.059445 -0.003963 -0.059445 -1850     37850.0
# 2368    0.057613  0.064472  0.012346  1400     72900.0
# 2498    0.000000  0.070407 -0.041804  1800     90900.0
# 3059   -0.012285  0.023342 -0.015971   800     40700.0
# 3588    0.012422  0.077640 -0.012422  3000    161000.0
# 6104    0.099698  0.099698  0.030211  3000    165500.0
# 8040    0.099310  0.099310  0.020690  1400     72500.0
# all :  7 ['2038', '2368', '2498', '3059', '3588', '6104', '8040']
# trade :  7 ['2038', '2368', '2498', '3059', '3588', '6104', '8040']
# Max Ret >= 2% :  6 ['2368', '2498', '3059', '3588', '6104', '8040']
# profit Probability for trade : 85.71 %
# Total PnL without cost: 9550
# Total Trade Value: 641350.0
#
#
# =======================回測開始=======================
# Backtest 2021-11-16, ticker prepare from 2021-11-15.
#
# ['1785', '2312', '2314', '2338', '2457', '2484', '3019', '3034', '3169', '3207', '3305', '6129', '6282', '8261']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1785   -0.017637  0.015873 -0.021164 -1000     56700.0
# 2312   -0.010563  0.021127 -0.014085   250     14200.0
# 2314    0.071026  0.087937  0.000000  1700     88700.0
# 2338    0.014423  0.052885 -0.019231  2000    104000.0
# 2457   -0.028646  0.026042 -0.029948   750     38400.0
# 2484    0.073548  0.076129 -0.023226   750     38750.0
# 3019   -0.047720  0.029692 -0.065748  1800     94300.0
# 3034    0.000000  0.015957 -0.010638     0    470000.0
# 3169    0.098655  0.098655 -0.015695  4000    223000.0
# 3207   -0.014184  0.007092 -0.033688  -400     28200.0
# 3305    0.036905  0.100000  0.023810  1600     84000.0
# 6129   -0.047076  0.029957 -0.047076   700     35050.0
# 6282    0.000000  0.008054 -0.033557     0     37250.0
# 8261    0.031532  0.036036 -0.018018  2000    111000.0
# all :  14 ['1785', '2312', '2314', '2338', '2457', '2484', '3019', '3034', '3169', '3207', '3305', '6129', '6282', '8261']
# trade :  14 ['2312', '2314', '2338', '2457', '2484', '3019', '3034', '3305', '6282', '8261', '1785', '3169', '3207', '6129']
# Max Ret >= 2% :  10 ['2312', '2314', '2338', '2457', '2484', '3019', '3169', '3305', '6129', '8261']
# profit Probability for trade : 71.43 %
# Total PnL without cost: 14150
# Total Trade Value: 1423550.0
#
#
# =======================回測開始=======================
# Backtest 2021-11-17, ticker prepare from 2021-11-16.
#
# ['2314', '2484', '2607', '2610', '2618', '3016', '3041', '3062', '5309', '5351', '5371', '6118', '6237', '6411', '6485', '8040']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2314   -0.045263 -0.018947 -0.078947 -4700     95000.0
# 2484    0.016827  0.052885 -0.028846   800     41600.0
# 2607   -0.025168  0.000000 -0.033557  -750     29800.0
# 2610    0.070111  0.075646  0.000000   500     27100.0
# 2618    0.044643  0.046429 -0.005357   550     28000.0
# 3016    0.099138  0.099138  0.000000  2000    116000.0
# 3041    0.099415  0.099415  0.008772   650     34200.0
# 3062    0.017241  0.040230 -0.051724   650     34800.0
# 5309    0.034483  0.053508  0.005945   800     42050.0
# 5351    0.001111  0.018889 -0.022222   100     90000.0
# 5371    0.040509  0.076389  0.009259  1700     86400.0
# 6118    0.080675  0.099437  0.009381   500     26650.0
# 6237   -0.012000  0.024000 -0.036000  2500    125000.0
# 6411   -0.003731  0.026119 -0.020522  5000    268000.0
# 6485   -0.023529  0.000000 -0.050000 -8500    170000.0
# 8040   -0.014493  0.031401 -0.039855  1600     82800.0
# all :  16 ['2314', '2484', '2607', '2610', '2618', '3016', '3041', '3062', '5309', '5351', '5371', '6118', '6237', '6411', '6485', '8040']
# trade :  16 ['2314', '2484', '2607', '2610', '2618', '3016', '3041', '3062', '5309', '5351', '5371', '6118', '6237', '6411', '6485', '8040']
# Max Ret >= 2% :  12 ['2484', '2610', '2618', '3016', '3041', '3062', '5309', '5371', '6118', '6237', '6411', '8040']
# profit Probability for trade : 75.0 %
# Total PnL without cost: 3400
# Total Trade Value: 1297400.0
#
#
# =======================回測開始=======================
# Backtest 2021-11-18, ticker prepare from 2021-11-17.
#
# ['1316', '2069', '2363', '2367', '2401', '2426', '2492', '3016', '3034', '3041', '3042', '3221', '3515', '4906', '4961', '5243', '6104', '6138', '6282', '8069', '8261']
#
#              Ret   HighRet    LowRet    PnL  TradeValue
# Ticker
# 1316    0.041237  0.077320 -0.018041    350     19400.0
# 2069    0.006757  0.027027 -0.009459    700     37000.0
# 2363   -0.022556  0.000000 -0.024436   -600     26600.0
# 2367   -0.044944  0.013483 -0.051685  -1100     22250.0
# 2401   -0.022432  0.020071 -0.022432    800     42350.0
# 2426   -0.001815  0.021779 -0.016334    550     27550.0
# 2492    0.023392  0.038012  0.002924   3000    171000.0
# 3016    0.019608  0.050980 -0.027451   2500    127500.0
# 3034    0.006116  0.027523 -0.004077   9500    490500.0
# 3041    0.023936  0.098404 -0.019947    750     37600.0
# 3042   -0.017391 -0.004348 -0.034783  -2000    115000.0
# 3221   -0.038328  0.019744 -0.054588  -2150     43050.0
# 3515   -0.040619  0.007737 -0.067698 -12500    258500.0
# 4906   -0.038333 -0.006667 -0.038333  -1150     30000.0
# 4961    0.037255  0.090196  0.005882   5000    255000.0
# 5243   -0.005413  0.029770 -0.013532   1400     73900.0
# 6104   -0.015544  0.028497 -0.031088   3500    193000.0
# 6138    0.021413  0.066381 -0.023555   4500    233500.0
# 6282   -0.034853 -0.010724 -0.034853  -1300     37300.0
# 8069    0.097938  0.097938  0.046392   1900     97000.0
# 8261   -0.025862  0.021552 -0.025862   2000    116000.0
# all :  21 ['1316', '2069', '2363', '2367', '2401', '2426', '2492', '3016', '3034', '3041', '3042', '3221', '3515', '4906', '4961', '5243', '6104', '6138', '6282', '8069', '8261']
# trade :  21 ['1316', '2069', '2363', '2367', '2401', '2426', '2492', '3016', '3034', '3041', '3042', '3515', '4906', '4961', '5243', '6282', '8261', '3221', '6104', '6138', '8069']
# Max Ret >= 2% :  14 ['1316', '2069', '2401', '2426', '2492', '3016', '3034', '3041', '4961', '5243', '6104', '6138', '8069', '8261']
# profit Probability for trade : 66.67 %
# Total PnL without cost: 15650
# Total Trade Value: 2454000.0
#
#
# =======================回測開始=======================
# Backtest 2021-11-19, ticker prepare from 2021-11-18.
#
# ['2340', '2342', '2368', '2454', '3016', '3049', '3545', '4721', '4739', '5309', '6116', '8215']
#
#              Ret   HighRet    LowRet    PnL  TradeValue
# Ticker
# 2340    0.098232  0.098232  0.003929   1000     50900.0
# 2342   -0.017347  0.018367 -0.028571   -850     49000.0
# 2368   -0.030956  0.020188 -0.044415   1400     74300.0
# 2454    0.004608  0.032258 -0.023041  20000   1085000.0
# 3016    0.100000  0.100000  0.015385   2500    130000.0
# 3049    0.033708  0.041199  0.003745    250     13350.0
# 3545   -0.005764  0.037464 -0.008646   3000    173500.0
# 4721   -0.026316  0.032164 -0.032164   3000    171000.0
# 4739    0.009646  0.041801 -0.009646   3000    155500.0
# 5309   -0.010204  0.018141 -0.038549   -450     44100.0
# 6116    0.018809  0.050157  0.006270    300     15950.0
# 8215    0.013055  0.020888 -0.009138    750     38300.0
# all :  12 ['2340', '2342', '2368', '2454', '3016', '3049', '3545', '4721', '4739', '5309', '6116', '8215']
# trade :  12 ['2340', '2342', '2368', '2454', '3016', '3049', '3545', '4739', '6116', '8215', '4721', '5309']
# Max Ret >= 2% :  10 ['2340', '2368', '2454', '3016', '3049', '3545', '4721', '4739', '6116', '8215']
# profit Probability for trade : 83.33 %
# Total PnL without cost: 33900
# Total Trade Value: 2000900.0
#
#
# =======================回測開始=======================
# 2021-11-20 is Holiday.
#
#
# =======================回測開始=======================
# 2021-11-21 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2021-11-22, ticker prepare from 2021-11-19.
#
# ['2338', '2371', '2374', '2377', '2426', '3062', '3706', '4927', '6265']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2338   -0.040724  0.004525 -0.045249 -4500    110500.0
# 2371   -0.009009  0.016731 -0.024453  -350     38850.0
# 2374   -0.050228  0.015982 -0.059361 -1050     21900.0
# 2377   -0.006024  0.018072 -0.012048 -1000    166000.0
# 2426   -0.027682  0.027682 -0.034602   550     28900.0
# 3062    0.018545  0.029957 -0.019971   700     35050.0
# 3706    0.002907  0.017442 -0.017442   100     34400.0
# 4927   -0.004854  0.077670 -0.014563  2000    103000.0
# 6265    0.098592  0.098592  0.070423   250     14200.0
# all :  9 ['2338', '2371', '2374', '2377', '2426', '3062', '3706', '4927', '6265']
# trade :  9 ['2338', '2371', '2374', '2377', '2426', '3062', '3706', '4927', '6265']
# Max Ret >= 2% :  4 ['2426', '3062', '4927', '6265']
# profit Probability for trade : 44.44 %
# Total PnL without cost: -3300
# Total Trade Value: 552800.0
#
#
# =======================回測開始=======================
# Backtest 2021-11-23, ticker prepare from 2021-11-22.
# ['2340', '2344', '2369', '2408', '3006', '3016', '3019', '3049', '3260', '3704', '4916', '5483', '6104', '6182', '8183']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2340   -0.036545  0.099668 -0.043189  1200     60200.0
# 2344   -0.014173  0.014173 -0.023622  -450     31750.0
# 2369   -0.042125 -0.009158 -0.042125 -1150     27300.0
# 2408    0.003979  0.015915 -0.022546   300     75400.0
# 3006   -0.024242 -0.003030 -0.039394 -4000    165000.0
# 3016   -0.090604 -0.003356 -0.097315 -7000    149000.0
# 3019   -0.049231 -0.005128 -0.054359 -4800     97500.0
# 3049   -0.029703  0.056106 -0.036304   300     15150.0
# 3260   -0.023404  0.021277 -0.036170  1800     94000.0
# 3704   -0.046377 -0.002899 -0.055072 -1700     34500.0
# 4916   -0.099087  0.031291 -0.099087   750     38350.0
# 5483    0.007299  0.029197 -0.009732  4000    205500.0
# 6104   -0.023256  0.031008 -0.062016  3500    193500.0
# 6182   -0.023876  0.001404 -0.030899 -1700     71200.0
# 8183    0.044335  0.077176  0.000000  1200     60900.0
# all :  15 ['2340', '2344', '2369', '2408', '3006', '3016', '3019', '3049', '3260', '3704', '4916', '5483', '6104', '6182', '8183']
# trade :  15 ['2340', '2344', '2369', '2408', '3006', '3016', '3019', '3049', '3704', '4916', '3260', '5483', '6104', '6182', '8183']
# Max Ret >= 2% :  7 ['2340', '3049', '3260', '4916', '5483', '6104', '8183']
# profit Probability for trade : 46.67 %
# Total PnL without cost: -7750
# Total Trade Value: 1319250.0
#
#
# =======================回測開始=======================
# Backtest 2021-11-24, ticker prepare from 2021-11-23.
#
# ['1709', '2340', '2374', '2426', '3317', '6190', '8183']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1709    0.032051  0.044872  0.008547   450     23400.0
# 2340    0.032759  0.058621  0.001724  1100     58000.0
# 2374   -0.043280  0.018223 -0.047836  -950     21950.0
# 2426    0.026596  0.026596 -0.008865   550     28200.0
# 3317   -0.010976  0.010976 -0.036585  -900     82000.0
# 6190    0.001527  0.097710 -0.038168   650     32750.0
# 8183    0.012579  0.042453 -0.025157  1200     63600.0
# all :  7 ['1709', '2340', '2374', '2426', '3317', '6190', '8183']
# trade :  7 ['1709', '2340', '2374', '2426', '3317', '6190', '8183']
# Max Ret >= 2% :  5 ['1709', '2340', '2426', '6190', '8183']
# profit Probability for trade : 71.43 %
# Total PnL without cost: 2100
# Total Trade Value: 309900.0
#
#
# =======================回測開始=======================
# Backtest 2021-11-25, ticker prepare from 2021-11-24.
#
# ['2069', '2393', '2610', '3491', '4128', '5483', '5608', '6182', '6190', '6244', '8069']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2069   -0.001285  0.029563 -0.017995   750     38900.0
# 2393   -0.029630  0.009259 -0.033333 -1600     54000.0
# 2610   -0.013311  0.036606 -0.024958   600     30050.0
# 3491   -0.043716  0.027322 -0.049180  3500    183000.0
# 4128   -0.028050  0.056101 -0.072931  1400     71300.0
# 5483   -0.011628  0.018605 -0.030233 -2500    215000.0
# 5608   -0.017202  0.013761 -0.017202  -750     43600.0
# 6182    0.043194  0.044503 -0.006545  1500     76400.0
# 6190   -0.044207  0.025915 -0.048780   650     32800.0
# 6244   -0.020243  0.024291 -0.040486   700     37050.0
# 8069    0.020576  0.028807 -0.020576  2000    121500.0
# all :  11 ['2069', '2393', '2610', '3491', '4128', '5483', '5608', '6182', '6190', '6244', '8069']
# trade :  11 ['2069', '2393', '2610', '5608', '3491', '4128', '5483', '6182', '6190', '6244', '8069']
# Max Ret >= 2% :  8 ['2069', '2610', '3491', '4128', '6182', '6190', '6244', '8069']
# profit Probability for trade : 72.73 %
# Total PnL without cost: 6250
# Total Trade Value: 903600.0
#
#
# =======================回測開始=======================
# Backtest 2021-11-26, ticker prepare from 2021-11-25.
#
# ['1316', '2374', '2603', '3169', '3701']
#
#              Ret   HighRet    LowRet    PnL  TradeValue
# Ticker
# 1316   -0.020179  0.047085 -0.020179    400     22300.0
# 2374    0.060606  0.090909 -0.021645    450     23100.0
# 2603   -0.048193  0.012048 -0.052209  -6000    124500.0
# 3169   -0.054820  0.015123 -0.062382 -13000    264500.0
# 3701   -0.028264  0.095559 -0.029610   1400     74300.0
# all :  5 ['1316', '2374', '2603', '3169', '3701']
# trade :  5 ['1316', '2374', '2603', '3701', '3169']
# Max Ret >= 2% :  3 ['1316', '2374', '3701']
# profit Probability for trade : 60.0 %
# Total PnL without cost: -16750
# Total Trade Value: 508700.0
#
#
# =======================回測開始=======================
# 2021-11-27 is Holiday.
#
#
# =======================回測開始=======================
# 2021-11-28 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2021-11-29, ticker prepare from 2021-11-26.
#
# ['2374', '2375', '3701', '6138', '6265', '6603', '8183']
#
#              Ret   HighRet    LowRet    PnL  TradeValue
# Ticker
# 2374   -0.040816 -0.004082 -0.059184  -1200     24500.0
# 2375   -0.017316  0.008658 -0.077922  -5500    115500.0
# 3701    0.099723  0.099723  0.004155   1400     72200.0
# 6138   -0.039400 -0.013133 -0.086304 -13000    266500.0
# 6265   -0.074850 -0.011976 -0.095808   -800     16700.0
# 6603   -0.064039 -0.019704 -0.093596  -1000     20300.0
# 8183   -0.054264 -0.010853 -0.089922  -3200     64500.0
# all :  7 ['2374', '2375', '3701', '6138', '6265', '6603', '8183']
# trade :  7 ['2374', '2375', '3701', '6138', '6265', '6603', '8183']
# Max Ret >= 2% :  1 ['3701']
# profit Probability for trade : 14.29 %
# Total PnL without cost: -23300
# Total Trade Value: 580200.0
#
#
# =======================回測開始=======================
# Backtest 2021-11-30, ticker prepare from 2021-11-29.
#
# ['2497', '4919', '6190']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2497    0.099338  0.099338  0.056291  1200     60400.0
# 4919   -0.003205  0.054487 -0.006410  3000    156000.0
# 6190    0.017663  0.078804  0.000000   700     36800.0
# all :  3 ['2497', '4919', '6190']
# trade :  3 ['2497', '4919', '6190']
# Max Ret >= 2% :  3 ['2497', '4919', '6190']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 4900
# Total Trade Value: 253200.0

# %%
start_date = datetime(2021,10,1)
end_date = datetime(2021,10,31)
# result = {}
for date in pd.date_range(start_date, end_date):
    result[date.strftime("%Y-%m-%d")] = MainBacktest(date)
# Out:
# =======================回測開始=======================
# Backtest 2021-10-01, ticker prepare from 2021-09-30.
#
# ['1440', '2436', '2606', '2610', '3062', '6217']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1440   -0.087786  0.009542 -0.095420 -1300     26200.0
# 2436   -0.025611  0.016298 -0.067520 -4200     85900.0
# 2606   -0.083090  0.010204 -0.090379 -3400     68600.0
# 2610   -0.029070  0.017442 -0.037791  -500     17200.0
# 3062   -0.021378  0.026128 -0.040380   400     21050.0
# 6217   -0.095192 -0.003846 -0.100000 -2600     52000.0
# all :  6 ['1440', '2436', '2606', '2610', '3062', '6217']
# trade :  6 ['1440', '2436', '2606', '2610', '3062', '6217']
# Max Ret >= 2% :  1 ['3062']
# profit Probability for trade : 16.67 %
# Total PnL without cost: -11600
# Total Trade Value: 270950.0
#
#
# =======================回測開始=======================
# 2021-10-02 is Holiday.
#
#
# =======================回測開始=======================
# 2021-10-03 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2021-10-04, ticker prepare from 2021-10-01.
# c:\users\kevin\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:73: RuntimeWarning: divide by zero encountered in longlong_scalars
# ['1440']
#
#              Ret   HighRet    LowRet  PnL  TradeValue
# Ticker
# 1440   -0.073222  0.029289 -0.075314  450     23900.0
# all :  1 ['1440']
# trade :  1 ['1440']
# Max Ret >= 2% :  1 ['1440']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 450
# Total Trade Value: 23900.0
#
#
# =======================回測開始=======================
# Backtest 2021-10-05, ticker prepare from 2021-10-04.
# c:\users\kevin\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:73: RuntimeWarning: divide by zero encountered in longlong_scalars
# ['1722', '2618', '5905']
#
#              Ret   HighRet    LowRet  PnL  TradeValue
# Ticker
# 1722    0.007194  0.007194 -0.028777  500     69500.0
# 2618    0.010811  0.016216 -0.024324  200     18500.0
# 5905   -0.008876  0.029586 -0.017751  300     16900.0
# all :  3 ['1722', '2618', '5905']
# trade :  3 ['1722', '2618', '5905']
# Max Ret >= 2% :  1 ['5905']
# profit Probability for trade : 33.33 %
# Total PnL without cost: 1000
# Total Trade Value: 104900.0
#
#
# =======================回測開始=======================
# Backtest 2021-10-06, ticker prepare from 2021-10-05.
#
# No Tickers for 2021-10-06 to Trade.
#
#
#
# =======================回測開始=======================
# Backtest 2021-10-07, ticker prepare from 2021-10-06.
#
# ['1710', '1785', '9958']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1710    0.019272  0.027837 -0.014989   450     23350.0
# 1785    0.009579  0.011494 -0.015326   500     52200.0
# 9958    0.012295  0.016393 -0.040984  1500    122000.0
# all :  3 ['1710', '1785', '9958']
# trade :  3 ['1710', '9958', '1785']
# Max Ret >= 2% :  1 ['1710']
# profit Probability for trade : 33.33 %
# Total PnL without cost: 2450
# Total Trade Value: 197550.0
#
#
# =======================回測開始=======================
# Backtest 2021-10-08, ticker prepare from 2021-10-07.
#
# No Tickers for 2021-10-08 to Trade.
#
#
#
# =======================回測開始=======================
# 2021-10-09 is Holiday.
#
#
# =======================回測開始=======================
# 2021-10-10 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2021-10-11, ticker prepare from 2021-10-08.
#
# ['1710', '2328', '2606', '2612', '5243']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1710    0.037815  0.048319 -0.008403   450     23800.0
# 2328    0.033582  0.057214  0.000000   800     40200.0
# 2606    0.011096  0.044383 -0.015257  1400     72100.0
# 2612   -0.001361  0.028571 -0.025850  1400     73500.0
# 5243    0.061224  0.080063 -0.001570  1200     63700.0
# all :  5 ['1710', '2328', '2606', '2612', '5243']
# trade :  5 ['1710', '2328', '2606', '2612', '5243']
# Max Ret >= 2% :  5 ['1710', '2328', '2606', '2612', '5243']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 5250
# Total Trade Value: 273300.0
#
#
# =======================回測開始=======================
# Backtest 2021-10-12, ticker prepare from 2021-10-11.
#
# ['1710', '2328', '2606', '2612', '5243']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1710   -0.048583  0.006073 -0.076923 -1200     24700.0
# 2328    0.010830  0.031288 -0.007220   800     41550.0
# 2606   -0.098765 -0.017833 -0.098765 -3600     72900.0
# 2612   -0.081744 -0.019074 -0.091281 -3600     73400.0
# 5243   -0.016272  0.026627 -0.029586  1300     67600.0
# all :  5 ['1710', '2328', '2606', '2612', '5243']
# trade :  5 ['1710', '2328', '2606', '2612', '5243']
# Max Ret >= 2% :  2 ['2328', '5243']
# profit Probability for trade : 40.0 %
# Total PnL without cost: -6300
# Total Trade Value: 280150.0
#
#
# =======================回測開始=======================
# Backtest 2021-10-13, ticker prepare from 2021-10-12.
#
# ['3035', '6443']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 3035   -0.011278  0.045113 -0.022556  2500    133000.0
# 6443    0.022876  0.060458  0.003268   600     30600.0
# all :  2 ['3035', '6443']
# trade :  2 ['3035', '6443']
# Max Ret >= 2% :  2 ['3035', '6443']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 3100
# Total Trade Value: 163600.0
#
#
# =======================回測開始=======================
# Backtest 2021-10-14, ticker prepare from 2021-10-13.
#
# ['4503']
#
#              Ret   HighRet    LowRet  PnL  TradeValue
# Ticker
# 4503   -0.064052  0.084967 -0.064052  750     38250.0
# all :  1 ['4503']
# trade :  1 ['4503']
# Max Ret >= 2% :  1 ['4503']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 750
# Total Trade Value: 38250.0
#
#
# =======================回測開始=======================
# Backtest 2021-10-15, ticker prepare from 2021-10-14.
#
# ['1721', '1727', '3701', '6477']
#
#              Ret   HighRet    LowRet  PnL  TradeValue
# Ticker
# 1721    0.071197  0.093851 -0.055016  300     15450.0
# 1727    0.100000  0.100000  0.018056  700     36000.0
# 3701    0.017523  0.099299 -0.036215  850     42800.0
# 6477    0.100000  0.100000  0.033333  750     39000.0
# all :  4 ['1721', '1727', '3701', '6477']
# trade :  4 ['1721', '1727', '3701', '6477']
# Max Ret >= 2% :  4 ['1721', '1727', '3701', '6477']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 2600
# Total Trade Value: 133250.0
#
#
# =======================回測開始=======================
# 2021-10-16 is Holiday.
#
#
# =======================回測開始=======================
# 2021-10-17 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2021-10-18, ticker prepare from 2021-10-15.
#
# ['2328', '3035', '3305', '5243']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2328   -0.063218  0.001149 -0.066667 -2150     43500.0
# 3035   -0.013986  0.017483 -0.038462 -2000    143000.0
# 3305    0.047872  0.060284  0.000000  1100     56400.0
# 5243   -0.071942 -0.005755 -0.071942 -3400     69500.0
# all :  4 ['2328', '3035', '3305', '5243']
# trade :  4 ['2328', '3035', '3305', '5243']
# Max Ret >= 2% :  1 ['3305']
# profit Probability for trade : 25.0 %
# Total PnL without cost: -6450
# Total Trade Value: 312400.0
#
#
# =======================回測開始=======================
# Backtest 2021-10-19, ticker prepare from 2021-10-18.
#
# ['2376']
#
#              Ret  HighRet  LowRet   PnL  TradeValue
# Ticker
# 2376    0.028037  0.03271     0.0  2000    107000.0
# all :  1 ['2376']
# trade :  1 ['2376']
# Max Ret >= 2% :  1 ['2376']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 2000
# Total Trade Value: 107000.0
#
#
# =======================回測開始=======================
# Backtest 2021-10-20, ticker prepare from 2021-10-19.
#
# ['2406', '2481', '3189', '3576', '4721', '4739', '5425', '6244', '6443', '8255']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2406    0.037037  0.041152  0.004115   450     24300.0
# 2481   -0.046305 -0.019704 -0.054187 -5000    101500.0
# 3189    0.044211  0.048421 -0.012632  4500    237500.0
# 3576   -0.020408  0.002041 -0.038776  -500     24500.0
# 4721    0.036000  0.060000  0.008000  2500    125000.0
# 4739    0.016393  0.049180  0.004098  2000    122000.0
# 5425    0.005333  0.032000 -0.018667  1500     75000.0
# 6244   -0.011309  0.011309 -0.019386  -350     30950.0
# 6443    0.004732  0.020505 -0.006309   600     31700.0
# 8255    0.033684  0.050526 -0.004211  4500    237500.0
# all :  10 ['2406', '2481', '3189', '3576', '4721', '4739', '5425', '6244', '6443', '8255']
# trade :  10 ['2406', '2481', '3189', '3576', '4739', '6443', '4721', '5425', '6244', '8255']
# Max Ret >= 2% :  7 ['2406', '3189', '4721', '4739', '5425', '6443', '8255']
# profit Probability for trade : 70.0 %
# Total PnL without cost: 10200
# Total Trade Value: 1009950.0
#
#
# =======================回測開始=======================
# Backtest 2021-10-21, ticker prepare from 2021-10-20.
#
# ['2351', '2457', '3189', '5285', '8255']
#
#              Ret   HighRet    LowRet    PnL  TradeValue
# Ticker
# 2351   -0.012903  0.016129 -0.038710  -2000    155000.0
# 2457    0.000000  0.012748 -0.031161      0     35300.0
# 3189   -0.060484  0.000000 -0.078629 -12000    248000.0
# 5285   -0.029536  0.008439 -0.050633  -5500    118500.0
# 8255    0.002037  0.059063 -0.014257   4500    245500.0
# all :  5 ['2351', '2457', '3189', '5285', '8255']
# trade :  5 ['2351', '2457', '3189', '5285', '8255']
# Max Ret >= 2% :  1 ['8255']
# profit Probability for trade : 20.0 %
# Total PnL without cost: -15000
# Total Trade Value: 802300.0
#
#
# =======================回測開始=======================
# Backtest 2021-10-22, ticker prepare from 2021-10-21.
#
# ['2376', '2406', '2476', '2498', '3016', '3305', '5425']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2376   -0.014085  0.014085 -0.023474 -1500    106500.0
# 2406   -0.038911 -0.011673 -0.044747 -1000     25700.0
# 2476    0.035587  0.040925 -0.005338  1100     56200.0
# 2498    0.088083  0.098446  0.042487   950     48250.0
# 3016    0.035484  0.038710  0.000000  1800     93000.0
# 3305    0.040351  0.045614  0.007018  1100     57000.0
# 5425    0.000000  0.031726 -0.026650  1500     78800.0
# all :  7 ['2376', '2406', '2476', '2498', '3016', '3305', '5425']
# trade :  7 ['2376', '2406', '2476', '2498', '3016', '3305', '5425']
# Max Ret >= 2% :  5 ['2476', '2498', '3016', '3305', '5425']
# profit Probability for trade : 71.43 %
# Total PnL without cost: 3950
# Total Trade Value: 465450.0
#
#
# =======================回測開始=======================
# 2021-10-23 is Holiday.
#
#
# =======================回測開始=======================
# 2021-10-24 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2021-10-25, ticker prepare from 2021-10-22.
# ['2498', '2913', '3504', '4927', '8069']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2498    0.009524  0.038095 -0.026667  1000     52500.0
# 2913    0.000000  0.007042 -0.014085     0     21300.0
# 3504    0.022388  0.063433  0.007463  2500    134000.0
# 4927   -0.040842 -0.001238 -0.043317 -3300     80800.0
# 8069    0.005774  0.010393 -0.018476   500     86600.0
# all :  5 ['2498', '2913', '3504', '4927', '8069']
# trade :  5 ['2498', '2913', '3504', '4927', '8069']
# Max Ret >= 2% :  2 ['2498', '3504']
# profit Probability for trade : 40.0 %
# Total PnL without cost: 700
# Total Trade Value: 375200.0
#
#
# =======================回測開始=======================
# Backtest 2021-10-26, ticker prepare from 2021-10-25.
#
# ['2340', '3305', '4721', '4739', '6217', '6509']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2340    0.057796  0.099462  0.001344   700     37200.0
# 3305   -0.019449  0.009724 -0.024311 -1200     61700.0
# 4721    0.014085  0.091549  0.007042  2500    142000.0
# 4739    0.060498  0.099644  0.032028  2500    140500.0
# 6217   -0.006849  0.049658 -0.011986  1100     58400.0
# 6509    0.002950  0.081121  0.002950  1300     67800.0
# all :  6 ['2340', '3305', '4721', '4739', '6217', '6509']
# trade :  6 ['2340', '3305', '4739', '4721', '6217', '6509']
# Max Ret >= 2% :  5 ['2340', '4721', '4739', '6217', '6509']
# profit Probability for trade : 83.33 %
# Total PnL without cost: 6900
# Total Trade Value: 507600.0
#
#
# =======================回測開始=======================
# Backtest 2021-10-27, ticker prepare from 2021-10-26.
#
# ['2337', '3003', '3707', '4721', '4739', '5309', '5351', '6217', '6271', '6509', '8044', '8069', '8255']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2337   -0.009103  0.007802 -0.020806  -350     38450.0
# 3003   -0.003067  0.027607 -0.006135  1900     97800.0
# 3707    0.010714  0.039286 -0.007143  2500    140000.0
# 4721    0.034722  0.062500  0.010417  2500    144000.0
# 4739    0.030201  0.067114  0.010067  2500    149000.0
# 5309    0.025210  0.030812 -0.025210   700     35700.0
# 5351    0.028143  0.046904  0.005629  1000     53300.0
# 6217    0.024138  0.046552 -0.003448  1100     58000.0
# 6271    0.003861  0.015444 -0.013514  1000    259000.0
# 6509    0.070588  0.095588  0.007353  1300     68000.0
# 8044    0.055970  0.059701 -0.003731  2500    134000.0
# 8069   -0.001133  0.015855 -0.011325  -100     88300.0
# 8255    0.036961  0.039014 -0.014374  4500    243500.0
# all :  13 ['2337', '3003', '3707', '4721', '4739', '5309', '5351', '6217', '6271', '6509', '8044', '8069', '8255']
# trade :  13 ['2337', '3003', '4739', '6271', '3707', '4721', '5309', '5351', '6217', '6509', '8044', '8069', '8255']
# Max Ret >= 2% :  10 ['3003', '3707', '4721', '4739', '5309', '5351', '6217', '6509', '8044', '8255']
# profit Probability for trade : 76.92 %
# Total PnL without cost: 21050
# Total Trade Value: 1509050.0
#
#
# =======================回測開始=======================
# Backtest 2021-10-28, ticker prepare from 2021-10-27.
#
# ['2388', '2476', '3189', '3305', '3508', '3689', '8046']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2388   -0.039116  0.011905 -0.039116 -2300     58800.0
# 2476    0.008039  0.051447 -0.003215  1200     62200.0
# 3189   -0.012024  0.010020 -0.028056 -3000    249500.0
# 3305    0.032103  0.048154 -0.012841  1200     62300.0
# 3508   -0.040678 -0.001695 -0.044068 -1200     29500.0
# 3689   -0.017189  0.039434 -0.018200   950     49450.0
# 8046   -0.010627  0.022317 -0.018066  9000    470500.0
# all :  7 ['2388', '2476', '3189', '3305', '3508', '3689', '8046']
# trade :  7 ['2388', '2476', '3189', '3305', '8046', '3508', '3689']
# Max Ret >= 2% :  4 ['2476', '3305', '3689', '8046']
# profit Probability for trade : 57.14 %
# Total PnL without cost: 5850
# Total Trade Value: 982250.0
#
#
# =======================回測開始=======================
# Backtest 2021-10-29, ticker prepare from 2021-10-28.
#
# ['3006', '3037', '3062', '3545', '4960', '4961', '5285', '6244', '6477', '8069', '8215']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 3006    0.000000  0.028070 -0.014035  2500    142500.0
# 3037    0.064426  0.070028 -0.011204  3500    178500.0
# 3062    0.035225  0.060665  0.001957   500     25550.0
# 3545   -0.024390  0.027439 -0.024390  3000    164000.0
# 4960    0.008475  0.016949 -0.025424   100     11800.0
# 4961   -0.016166  0.025404 -0.020785  4000    216500.0
# 5285    0.038298  0.076596  0.004255  2000    117500.0
# 6244    0.000000  0.018692 -0.028037     0     32100.0
# 6477   -0.066116  0.001033 -0.087810 -2400     48400.0
# 8069    0.011001  0.022002 -0.007701  1800     90900.0
# 8215    0.096100  0.098886  0.000000   700     35900.0
# all :  11 ['3006', '3037', '3062', '3545', '4960', '4961', '5285', '6244', '6477', '8069', '8215']
# trade :  11 ['3006', '3037', '3062', '3545', '4960', '4961', '5285', '6477', '8215', '6244', '8069']
# Max Ret >= 2% :  8 ['3006', '3037', '3062', '3545', '4961', '5285', '8069', '8215']
# profit Probability for trade : 72.73 %
# Total PnL without cost: 15700
# Total Trade Value: 1063650.0
#
#
# =======================回測開始=======================
# 2021-10-30 is Holiday.
#
#
# =======================回測開始=======================
# 2021-10-31 is Holiday.

# %%
start_date = datetime(2021,9,1)
end_date = datetime(2021,9,30)
# result = {}
for date in pd.date_range(start_date, end_date):
    result[date.strftime("%Y-%m-%d")] = MainBacktest(date)
# Out:
# =======================回測開始=======================
# Backtest 2021-09-01, ticker prepare from 2021-08-31.
#
# ['2331', '2641']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2331    0.004032  0.024194 -0.018145   450     24800.0
# 2641   -0.045994 -0.011869 -0.065282 -1650     33700.0
# all :  2 ['2331', '2641']
# trade :  2 ['2331', '2641']
# Max Ret >= 2% :  1 ['2331']
# profit Probability for trade : 50.0 %
# Total PnL without cost: -1200
# Total Trade Value: 58500.0
#
#
# =======================回測開始=======================
# Backtest 2021-09-02, ticker prepare from 2021-09-01.
#
# ['2340', '2371', '2476', '3141', '3504', '3707', '4919', '8064', '8150']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2340    0.000000  0.017118 -0.037090     0     35050.0
# 2371   -0.061514  0.015773 -0.069401 -1550     31700.0
# 2476   -0.003135  0.039185 -0.018809  1200     63800.0
# 3141   -0.032448  0.056047 -0.047198  3000    169500.0
# 3504    0.017544  0.052632 -0.017544  2000    114000.0
# 3707   -0.070175  0.004386 -0.070175 -5500    114000.0
# 4919   -0.047904  0.047904 -0.047904  3000    167000.0
# 8064    0.031983  0.051173 -0.027719   450     23450.0
# 8150   -0.045151  0.006689 -0.045151 -2700     59800.0
# all :  9 ['2340', '2371', '2476', '3141', '3504', '3707', '4919', '8064', '8150']
# trade :  9 ['2340', '2371', '2476', '3504', '4919', '8150', '3141', '3707', '8064']
# Max Ret >= 2% :  5 ['2476', '3141', '3504', '4919', '8064']
# profit Probability for trade : 55.56 %
# Total PnL without cost: -100
# Total Trade Value: 778300.0
#
#
# =======================回測開始=======================
# Backtest 2021-09-03, ticker prepare from 2021-09-02.
#
# ['1727', '2342', '2401', '2436', '3035', '3689', '5483']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1727    0.098086  0.098086 -0.028708   400     20900.0
# 2342    0.017472  0.035971  0.002055   950     48650.0
# 2401    0.027094  0.043103  0.008621   800     40600.0
# 2436    0.066749  0.087763  0.029666  1600     80900.0
# 3035    0.009174  0.045872 -0.004587  2000    109000.0
# 3689    0.002024  0.028340 -0.028340   900     49400.0
# 5483    0.023747  0.029024  0.005277  3500    189500.0
# all :  7 ['1727', '2342', '2401', '2436', '3035', '3689', '5483']
# trade :  7 ['1727', '2342', '2401', '2436', '3035', '3689', '5483']
# Max Ret >= 2% :  7 ['1727', '2342', '2401', '2436', '3035', '3689', '5483']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 10150
# Total Trade Value: 538950.0
#
#
# =======================回測開始=======================
# 2021-09-04 is Holiday.
#
#
# =======================回測開始=======================
# 2021-09-05 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2021-09-06, ticker prepare from 2021-09-03.
#
# ['1727', '2303', '2363', '2436', '3037', '6104']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1727    0.098039  0.098039  0.045752   450     22950.0
# 2303   -0.001429  0.028571 -0.024286  1400     70000.0
# 2363    0.048611  0.062500 -0.010417   550     28800.0
# 2436   -0.011587  0.040556 -0.038239  1700     86300.0
# 3037   -0.003226  0.022581 -0.022581  3000    155000.0
# 6104   -0.056250 -0.015625 -0.065625 -8000    160000.0
# all :  6 ['1727', '2303', '2363', '2436', '3037', '6104']
# trade :  6 ['1727', '2303', '2363', '2436', '3037', '6104']
# Max Ret >= 2% :  5 ['1727', '2303', '2363', '2436', '3037']
# profit Probability for trade : 83.33 %
# Total PnL without cost: -900
# Total Trade Value: 523050.0
#
#
# =======================回測開始=======================
# Backtest 2021-09-07, ticker prepare from 2021-09-06.
#
# ['1785', '2329', '2363', '6251', '6411', '8046', '9945']
#
#              Ret   HighRet    LowRet    PnL  TradeValue
# Ticker
# 1785   -0.007071  0.016162 -0.021212   -350     49500.0
# 2329   -0.041522  0.005190 -0.055363  -1400     28900.0
# 2363   -0.059603 -0.011589 -0.077815  -1500     30200.0
# 6251   -0.037190  0.010331 -0.064050  -1200     24200.0
# 6411   -0.061404  0.023392 -0.087719   3000    171000.0
# 8046   -0.033076 -0.005513 -0.055127 -22500    453500.0
# 9945    0.033967  0.033967 -0.008152   1400     73600.0
# all :  7 ['1785', '2329', '2363', '6251', '6411', '8046', '9945']
# trade :  7 ['2329', '2363', '6251', '8046', '9945', '1785', '6411']
# Max Ret >= 2% :  2 ['6411', '9945']
# profit Probability for trade : 28.57 %
# Total PnL without cost: -22550
# Total Trade Value: 830900.0
#
#
# =======================回測開始=======================
# Backtest 2021-09-08, ticker prepare from 2021-09-07.
#
# ['1727', '2358', '2376', '3017']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1727   -0.062745  0.086275 -0.062745   500     25500.0
# 2358   -0.100000 -0.011765 -0.100000 -1250     25500.0
# 2376   -0.039430 -0.003286 -0.039430 -3600     91300.0
# 3017   -0.040470 -0.006527 -0.045692 -3100     76600.0
# all :  4 ['1727', '2358', '2376', '3017']
# trade :  4 ['1727', '2358', '2376', '3017']
# Max Ret >= 2% :  1 ['1727']
# profit Probability for trade : 25.0 %
# Total PnL without cost: -7450
# Total Trade Value: 218900.0
#
#
# =======================回測開始=======================
# Backtest 2021-09-09, ticker prepare from 2021-09-08.
# c:\users\kevin\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:73: RuntimeWarning: divide by zero encountered in longlong_scalars
# No Tickers for 2021-09-09 to Trade.
#
#
#
# =======================回測開始=======================
# Backtest 2021-09-10, ticker prepare from 2021-09-09.
#
# ['2608', '3689', '4927']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2608   -0.072566  0.017699 -0.079646 -2800     56500.0
# 3689    0.015504  0.052326 -0.035853  1000     51600.0
# 4927    0.022378  0.037762 -0.020979  1400     71500.0
# all :  3 ['2608', '3689', '4927']
# trade :  3 ['2608', '4927', '3689']
# Max Ret >= 2% :  2 ['3689', '4927']
# profit Probability for trade : 66.67 %
# Total PnL without cost: -400
# Total Trade Value: 179600.0
#
#
# =======================回測開始=======================
# 2021-09-11 is Holiday.
#
#
# =======================回測開始=======================
# 2021-09-12 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2021-09-13, ticker prepare from 2021-09-10.
#
# ['1584', '1727', '2002', '2069', '3689', '5347', '8415']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1584    0.086849  0.099256 -0.022333   400     20150.0
# 1727    0.098859  0.098859 -0.017110   500     26300.0
# 2002    0.024297  0.028133  0.001279   750     39100.0
# 2069    0.002439  0.029268 -0.010976   800     41000.0
# 3689   -0.003817  0.041985 -0.022901  1000     52400.0
# 5347   -0.066282  0.020173 -0.072046  3000    173500.0
# 8415    0.017878  0.029797  0.000000   800     41950.0
# all :  7 ['1584', '1727', '2002', '2069', '3689', '5347', '8415']
# trade :  7 ['1727', '2002', '2069', '1584', '3689', '5347', '8415']
# Max Ret >= 2% :  7 ['1584', '1727', '2002', '2069', '3689', '5347', '8415']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 7250
# Total Trade Value: 394400.0
#
#
# =======================回測開始=======================
# Backtest 2021-09-14, ticker prepare from 2021-09-13.
#
# ['1711', '2358', '2641', '2915', '3033', '9945']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1711    0.099558  0.099558  0.000000   450     22600.0
# 2358    0.098266  0.098266  0.021195   500     25950.0
# 2641   -0.022059  0.041176 -0.057353   650     34000.0
# 2915    0.046332  0.046332 -0.003861  2500    129500.0
# 3033    0.036166  0.045208 -0.012658   550     27650.0
# 9945    0.024540  0.024540 -0.009816  1600     81500.0
# all :  6 ['1711', '2358', '2641', '2915', '3033', '9945']
# trade :  6 ['1711', '2358', '2915', '3033', '9945', '2641']
# Max Ret >= 2% :  6 ['1711', '2358', '2641', '2915', '3033', '9945']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 6250
# Total Trade Value: 321200.0
#
#
# =======================回測開始=======================
# Backtest 2021-09-15, ticker prepare from 2021-09-14.
#
# ['1711', '1785', '2358', '9962']
#
#              Ret   HighRet    LowRet  PnL  TradeValue
# Ticker
# 1711    0.098592  0.098592  0.022133  450     24850.0
# 1785   -0.015444  0.001931 -0.032819 -800     51800.0
# 2358   -0.052632  0.047368 -0.059649  550     28500.0
# 9962   -0.018182 -0.004545 -0.029545 -400     22000.0
# all :  4 ['1711', '1785', '2358', '9962']
# trade :  4 ['1711', '2358', '1785', '9962']
# Max Ret >= 2% :  2 ['1711', '2358']
# profit Probability for trade : 50.0 %
# Total PnL without cost: -200
# Total Trade Value: 127150.0
#
#
# =======================回測開始=======================
# Backtest 2021-09-16, ticker prepare from 2021-09-15.
#
# ['1304', '1711', '1727', '2915']
#
#              Ret   HighRet    LowRet  PnL  TradeValue
# Ticker
# 1304    0.092647  0.100000  0.014706  650     34000.0
# 1711   -0.027473  0.056777 -0.040293  500     27300.0
# 1727   -0.012894  0.098854 -0.020057  650     34900.0
# 2915    0.000000  0.010870 -0.021739    0    138000.0
# all :  4 ['1304', '1711', '1727', '2915']
# trade :  4 ['1304', '1711', '1727', '2915']
# Max Ret >= 2% :  3 ['1304', '1711', '1727']
# profit Probability for trade : 75.0 %
# Total PnL without cost: 1800
# Total Trade Value: 234200.0
#
#
# =======================回測開始=======================
# Backtest 2021-09-17, ticker prepare from 2021-09-16.
#
# ['1304', '1609', '1727', '3035']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1304   -0.040377  0.009421 -0.040377 -1500     37150.0
# 1609   -0.037106 -0.001855 -0.037106 -1000     26950.0
# 1727   -0.078374 -0.013062 -0.097242 -1700     34450.0
# 3035    0.013333  0.031111 -0.026667  2000    112500.0
# all :  4 ['1304', '1609', '1727', '3035']
# trade :  4 ['1304', '1609', '1727', '3035']
# Max Ret >= 2% :  1 ['3035']
# profit Probability for trade : 25.0 %
# Total PnL without cost: -2200
# Total Trade Value: 211050.0
#
#
# =======================回測開始=======================
# 2021-09-18 is Holiday.
#
#
# =======================回測開始=======================
# 2021-09-19 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2021-09-20, ticker prepare from 2021-09-17.
#
# ['1308', '1785', '2201', '2331', '2371', '2915', '6217', '9945']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1308    0.026964  0.049238 -0.009379   850     42650.0
# 1785   -0.007707  0.032755 -0.007707  1000     51900.0
# 2201    0.068044  0.089915  0.010936   800     41150.0
# 2331    0.064854  0.098326  0.004184   450     23900.0
# 2371    0.098684  0.098684  0.021382   600     30400.0
# 2915    0.057971  0.068841 -0.007246  2500    138000.0
# 6217    0.099352  0.099352  0.022678   900     46300.0
# 9945    0.013111  0.021454 -0.003576  1600     83900.0
# all :  8 ['1308', '1785', '2201', '2331', '2371', '2915', '6217', '9945']
# trade :  8 ['1308', '2201', '2331', '2371', '2915', '9945', '1785', '6217']
# Max Ret >= 2% :  8 ['1308', '1785', '2201', '2331', '2371', '2915', '6217', '9945']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 8700
# Total Trade Value: 458200.0
#
#
# =======================回測開始=======================
# Backtest 2021-09-21, ticker prepare from 2021-09-20.
#
# ['1308', '1785', '2201', '2331', '2371', '2915', '6217', '9945']
#
# Error :   In (<ipython-input-2-12783c35b416>, Line 110 'df = pd.DataFrame(data).set_index('Date')') : "None of ['Date'] are in the columns"
#
#
# =======================回測開始=======================
# Backtest 2021-09-22, ticker prepare from 2021-09-21.
#
# Error :   In (<ipython-input-2-12783c35b416>, Line 14 'df = pd.DataFrame(data).set_index('Date')') : "None of ['Date'] are in the columns"
# No Tickers for 2021-09-22 to Trade.
#
#
#
# =======================回測開始=======================
# Backtest 2021-09-23, ticker prepare from 2021-09-22.
# c:\users\kevin\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:73: RuntimeWarning: divide by zero encountered in longlong_scalars
# ['2371', '6217']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2371    0.099526  0.099526  0.006319   600     31650.0
# 6217    0.009921  0.067460 -0.010913  1000     50400.0
# all :  2 ['2371', '6217']
# trade :  2 ['2371', '6217']
# Max Ret >= 2% :  2 ['2371', '6217']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 1600
# Total Trade Value: 82050.0
#
#
# =======================回測開始=======================
# Backtest 2021-09-24, ticker prepare from 2021-09-23.
#
# ['1304', '2486', '6213', '6282']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1304    0.027704  0.044855  0.006596   750     37900.0
# 2486    0.040067  0.085142  0.015025  1100     59900.0
# 6213   -0.002994  0.017964 -0.029940  -500    167000.0
# 6282   -0.015332  0.008518 -0.022147  -450     29350.0
# all :  4 ['1304', '2486', '6213', '6282']
# trade :  4 ['1304', '2486', '6213', '6282']
# Max Ret >= 2% :  2 ['1304', '2486']
# profit Probability for trade : 50.0 %
# Total PnL without cost: 900
# Total Trade Value: 294150.0
#
#
# =======================回測開始=======================
# 2021-09-25 is Holiday.
#
#
# =======================回測開始=======================
# 2021-09-26 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2021-09-27, ticker prepare from 2021-09-24.
#
# ['2436', '2486', '3035']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2436    0.008140  0.044186  0.003488  1700     86000.0
# 2486    0.003210  0.032103 -0.004815  1200     62300.0
# 3035   -0.029661  0.029661 -0.033898  2000    118000.0
# all :  3 ['2436', '2486', '3035']
# trade :  3 ['2436', '2486', '3035']
# Max Ret >= 2% :  3 ['2436', '2486', '3035']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 4900
# Total Trade Value: 266300.0
#
#
# =======================回測開始=======================
# Backtest 2021-09-28, ticker prepare from 2021-09-27.
#
# ['1301', '1305', '1718', '2201', '2436', '8358']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1301    0.022422  0.022422 -0.022422  2000    111500.0
# 1305    0.019722  0.020882 -0.015081   850     43100.0
# 1718    0.013889  0.013889 -0.018519   150     10800.0
# 2201   -0.006961  0.000000 -0.029002  -300     43100.0
# 2436    0.035755  0.035755 -0.008074  1700     86700.0
# 8358    0.003755  0.055069  0.003755  1500     79900.0
# all :  6 ['1301', '1305', '1718', '2201', '2436', '8358']
# trade :  6 ['1301', '1305', '1718', '2201', '2436', '8358']
# Max Ret >= 2% :  4 ['1301', '1305', '2436', '8358']
# profit Probability for trade : 66.67 %
# Total PnL without cost: 5900
# Total Trade Value: 375100.0
#
#
# =======================回測開始=======================
# Backtest 2021-09-29, ticker prepare from 2021-09-28.
#
# ['8358']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 8358   -0.078554 -0.006234 -0.078554 -4000     80200.0
# all :  1 ['8358']
# trade :  1 ['8358']
# Max Ret >= 2% :  0 []
# profit Probability for trade : 0.0 %
# Total PnL without cost: -4000
# Total Trade Value: 80200.0
#
#
# =======================回測開始=======================
# Backtest 2021-09-30, ticker prepare from 2021-09-29.
#
# ['1304', '1305', '1308', '1312', '1313', '1718', '1734']
#
#              Ret   HighRet    LowRet  PnL  TradeValue
# Ticker
# 1304   -0.055138  0.025063 -0.055138  750     39900.0
# 1305    0.003250  0.033586 -0.017335  900     46150.0
# 1308   -0.054527  0.026749 -0.060700  950     48600.0
# 1312   -0.028523  0.010067 -0.033557 -850     29800.0
# 1313    0.018000  0.020000 -0.014000  500     25000.0
# 1718    0.023810  0.042857  0.000000  200     10500.0
# 1734   -0.035545  0.029621 -0.050948  800     42200.0
# all :  7 ['1304', '1305', '1308', '1312', '1313', '1718', '1734']
# trade :  7 ['1304', '1305', '1308', '1312', '1313', '1718', '1734']
# Max Ret >= 2% :  6 ['1304', '1305', '1308', '1313', '1718', '1734']
# profit Probability for trade : 85.71 %
# Total PnL without cost: 3250
# Total Trade Value: 242150.0

# %%
start_date = datetime(2021,8,1)
end_date = datetime(2021,8,31)
# result = {}
for date in pd.date_range(start_date, end_date):
    result[date.strftime("%Y-%m-%d")] = MainBacktest(date)
# Out:
# =======================回測開始=======================
# 2021-08-01 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2021-08-02, ticker prepare from 2021-07-30.
#
# ['2007', '2329', '2363', '3031', '3556', '6104', '6226', '6485']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2007    0.099526  0.099526  0.000000   600     31650.0
# 2329    0.018519  0.046296 -0.042593   500     27000.0
# 2363   -0.003906  0.039062 -0.015625   500     25600.0
# 3031   -0.006623  0.026490 -0.064570   600     30200.0
# 3556    0.008811  0.057269 -0.044053  2000    113500.0
# 6104    0.067669  0.082707  0.022556  2500    133000.0
# 6226   -0.018182  0.036364 -0.064935   350     19250.0
# 6485    0.098160  0.098160  0.018405  3000    163000.0
# all :  8 ['2007', '2329', '2363', '3031', '3556', '6104', '6226', '6485']
# trade :  8 ['2007', '2329', '2363', '3031', '6226', '3556', '6104', '6485']
# Max Ret >= 2% :  8 ['2007', '2329', '2363', '3031', '3556', '6104', '6226', '6485']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 10050
# Total Trade Value: 543200.0
#
#
# =======================回測開始=======================
# Backtest 2021-08-03, ticker prepare from 2021-08-02.
#
# ['2329', '3034', '6223']
#
#              Ret   HighRet    LowRet    PnL  TradeValue
# Ticker
# 2329    0.025455  0.030909 -0.010909    550     27500.0
# 3034    0.007394  0.025878  0.000000  10000    541000.0
# 6223   -0.005917  0.023669 -0.035503   3000    169000.0
# all :  3 ['2329', '3034', '6223']
# trade :  3 ['2329', '3034', '6223']
# Max Ret >= 2% :  3 ['2329', '3034', '6223']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 13550
# Total Trade Value: 737500.0
#
#
# =======================回測開始=======================
# Backtest 2021-08-04, ticker prepare from 2021-08-03.
#
# ['1605', '2393', '2498', '3591', '5272', '6164', '8064', '8150']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1605    0.000000  0.005111 -0.022147     0     29350.0
# 2393    0.018182  0.043939 -0.007576  1300     66000.0
# 2498    0.002413  0.015682 -0.013269   100     41450.0
# 3591   -0.041522  0.010381 -0.055363 -1400     28900.0
# 5272   -0.012926  0.022327 -0.059929   850     42550.0
# 6164    0.099698  0.099698  0.018127   300     16550.0
# 8064    0.018519  0.048611 -0.013889   400     21600.0
# 8150    0.010676  0.016014 -0.010676   600     56200.0
# all :  8 ['1605', '2393', '2498', '3591', '5272', '6164', '8064', '8150']
# trade :  8 ['1605', '2393', '2498', '3591', '6164', '8150', '5272', '8064']
# Max Ret >= 2% :  4 ['2393', '5272', '6164', '8064']
# profit Probability for trade : 50.0 %
# Total PnL without cost: 2150
# Total Trade Value: 302600.0
#
#
# =======================回測開始=======================
# Backtest 2021-08-05, ticker prepare from 2021-08-04.
#
# ['2329', '2363', '2406', '3014', '4960', '6164', '6233', '6257', '6278']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2329    0.057003  0.084691 -0.027687   600     30700.0
# 2363    0.056897  0.096552 -0.024138   550     29000.0
# 2406    0.005556  0.033333 -0.018519   500     27000.0
# 3014    0.051661  0.059041 -0.018450  2500    135500.0
# 4960   -0.022059  0.003676 -0.029412  -300     13600.0
# 6164    0.085165  0.098901 -0.043956   350     18200.0
# 6233   -0.023576  0.015717 -0.028487 -1200     50900.0
# 6257    0.042584  0.054332 -0.013216  1300     68100.0
# 6278    0.003984  0.011952 -0.015936   500    125500.0
# all :  9 ['2329', '2363', '2406', '3014', '4960', '6164', '6233', '6257', '6278']
# trade :  9 ['2329', '2363', '2406', '3014', '4960', '6164', '6257', '6278', '6233']
# Max Ret >= 2% :  6 ['2329', '2363', '2406', '3014', '6164', '6257']
# profit Probability for trade : 66.67 %
# Total PnL without cost: 4800
# Total Trade Value: 498500.0
#
#
# =======================回測開始=======================
# Backtest 2021-08-06, ticker prepare from 2021-08-05.
#
# ['2303', '2337', '2369', '8150']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2303   -0.020505  0.006309 -0.028391 -1300     63400.0
# 2337   -0.031903  0.056106 -0.031903   900     45450.0
# 2369   -0.057785  0.036918 -0.069021   600     31150.0
# 8150   -0.050676 -0.011824 -0.052365 -2900     59200.0
# all :  4 ['2303', '2337', '2369', '8150']
# trade :  4 ['2303', '2337', '2369', '8150']
# Max Ret >= 2% :  2 ['2337', '2369']
# profit Probability for trade : 50.0 %
# Total PnL without cost: -2700
# Total Trade Value: 199200.0
#
#
# =======================回測開始=======================
# 2021-08-07 is Holiday.
#
#
# =======================回測開始=======================
# 2021-08-08 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2021-08-09, ticker prepare from 2021-08-06.
#
# ['1605', '1734', '2337', '2369', '3264', '6282']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1605   -0.026224 -0.020979 -0.062937 -1400     28600.0
# 1734   -0.030787  0.037628 -0.037628   850     43850.0
# 2337   -0.020455 -0.002273 -0.023864  -900     44000.0
# 2369    0.017036  0.086882 -0.005111   550     29350.0
# 3264   -0.021070  0.017828 -0.027553 -1300     61700.0
# 6282   -0.022847 -0.003515 -0.022847  -650     28450.0
# all :  6 ['1605', '1734', '2337', '2369', '3264', '6282']
# trade :  6 ['1605', '1734', '2337', '2369', '6282', '3264']
# Max Ret >= 2% :  2 ['1734', '2369']
# profit Probability for trade : 33.33 %
# Total PnL without cost: -2850
# Total Trade Value: 235950.0
#
#
# =======================回測開始=======================
# Backtest 2021-08-10, ticker prepare from 2021-08-09.
#
# No Tickers for 2021-08-10 to Trade.
#
#
#
# =======================回測開始=======================
# Backtest 2021-08-11, ticker prepare from 2021-08-10.
#
# ['5347']
#
#              Ret   HighRet   LowRet   PnL  TradeValue
# Ticker
# 5347   -0.017065  0.020478 -0.03413  2500    146500.0
# all :  1 ['5347']
# trade :  1 ['5347']
# Max Ret >= 2% :  1 ['5347']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 2500
# Total Trade Value: 146500.0
#
#
# =======================回測開始=======================
# Backtest 2021-08-12, ticker prepare from 2021-08-11.
#
# ['6251']
#
#              Ret   HighRet    LowRet  PnL  TradeValue
# Ticker
# 6251   -0.023758  0.023758 -0.028078  450     23150.0
# all :  1 ['6251']
# trade :  1 ['6251']
# Max Ret >= 2% :  1 ['6251']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 450
# Total Trade Value: 23150.0
#
#
# =======================回測開始=======================
# Backtest 2021-08-13, ticker prepare from 2021-08-12.
#
# ['5009']
#
#             Ret   HighRet   LowRet   PnL  TradeValue
# Ticker
# 5009   -0.07395 -0.016807 -0.07395 -1450     29750.0
# all :  1 ['5009']
# trade :  1 ['5009']
# Max Ret >= 2% :  0 []
# profit Probability for trade : 0.0 %
# Total PnL without cost: -1450
# Total Trade Value: 29750.0
#
#
# =======================回測開始=======================
# 2021-08-14 is Holiday.
#
#
# =======================回測開始=======================
# 2021-08-15 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2021-08-16, ticker prepare from 2021-08-13.
#
# ['4721', '4934']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 4721    0.098205  0.098205 -0.006336  1800     94700.0
# 4934   -0.050132 -0.015831 -0.068602 -1850     37900.0
# all :  2 ['4721', '4934']
# trade :  2 ['4934', '4721']
# Max Ret >= 2% :  1 ['4721']
# profit Probability for trade : 50.0 %
# Total PnL without cost: -50
# Total Trade Value: 132600.0
#
#
# =======================回測開始=======================
# Backtest 2021-08-17, ticker prepare from 2021-08-16.
#
# No Tickers for 2021-08-17 to Trade.
#
#
#
# =======================回測開始=======================
# Backtest 2021-08-18, ticker prepare from 2021-08-17.
#
# ['4721']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 4721    0.099526  0.099526 -0.033175  2000    105500.0
# all :  1 ['4721']
# trade :  1 ['4721']
# Max Ret >= 2% :  1 ['4721']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 2000
# Total Trade Value: 105500.0
#
#
# =======================回測開始=======================
# Backtest 2021-08-19, ticker prepare from 2021-08-18.
# ['2612']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2612    0.099112  0.099112  0.060651  1300     67600.0
# all :  1 ['2612']
# trade :  1 ['2612']
# Max Ret >= 2% :  1 ['2612']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 1300
# Total Trade Value: 67600.0
#
#
# =======================回測開始=======================
# Backtest 2021-08-20, ticker prepare from 2021-08-19.
#
# ['2013']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2013    0.022857  0.032381 -0.038095  1000     52500.0
# all :  1 ['2013']
# trade :  1 ['2013']
# Max Ret >= 2% :  1 ['2013']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 1000
# Total Trade Value: 52500.0
#
#
# =======================回測開始=======================
# 2021-08-21 is Holiday.
#
#
# =======================回測開始=======================
# 2021-08-22 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2021-08-23, ticker prepare from 2021-08-20.
#
# ['2612']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2612    0.098916  0.098916  0.036585  1400     73800.0
# all :  1 ['2612']
# trade :  1 ['2612']
# Max Ret >= 2% :  1 ['2612']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 1400
# Total Trade Value: 73800.0
#
#
# =======================回測開始=======================
# Backtest 2021-08-24, ticker prepare from 2021-08-23.
#
# ['6271']
#
#              Ret  HighRet    LowRet   PnL  TradeValue
# Ticker
# 6271   -0.003578   0.0161 -0.033989 -1000    279500.0
# all :  1 ['6271']
# trade :  1 ['6271']
# Max Ret >= 2% :  0 []
# profit Probability for trade : 0.0 %
# Total PnL without cost: -1000
# Total Trade Value: 279500.0
#
#
# =======================回測開始=======================
# Backtest 2021-08-25, ticker prepare from 2021-08-24.
#
# ['2612', '2617', '2637', '3003', '5608']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2612   -0.059417 -0.014574 -0.085202 -4400     89200.0
# 2617    0.009346  0.016822 -0.037383   500     53500.0
# 2637    0.045977  0.050575 -0.002299  1700     87000.0
# 3003    0.014634  0.063415 -0.031220  2000    102500.0
# 5608    0.029781  0.050157 -0.034483  1200     63800.0
# all :  5 ['2612', '2617', '2637', '3003', '5608']
# trade :  5 ['2612', '2617', '2637', '3003', '5608']
# Max Ret >= 2% :  3 ['2637', '3003', '5608']
# profit Probability for trade : 60.0 %
# Total PnL without cost: 1000
# Total Trade Value: 396000.0
#
#
# =======================回測開始=======================
# Backtest 2021-08-26, ticker prepare from 2021-08-25.
#
# ['3588', '4919']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 3588    0.044444  0.059259 -0.007407  2500    135000.0
# 4919   -0.003155  0.037855 -0.018927  3000    158500.0
# all :  2 ['3588', '4919']
# trade :  2 ['3588', '4919']
# Max Ret >= 2% :  2 ['3588', '4919']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 5500
# Total Trade Value: 293500.0
#
#
# =======================回測開始=======================
# Backtest 2021-08-27, ticker prepare from 2021-08-26.
#
# ['1310', '2371', '3504']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1310    0.013699  0.022831 -0.004566   400     21900.0
# 2371    0.038869  0.040636  0.001767   550     28300.0
# 3504    0.021459  0.021459 -0.077253  2000    116500.0
# all :  3 ['1310', '2371', '3504']
# trade :  3 ['1310', '2371', '3504']
# Max Ret >= 2% :  3 ['1310', '2371', '3504']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 2950
# Total Trade Value: 166700.0
#
#
# =======================回測開始=======================
# 2021-08-28 is Holiday.
#
#
# =======================回測開始=======================
# 2021-08-29 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2021-08-30, ticker prepare from 2021-08-27.
#
# ['2013']
#
#              Ret   HighRet    LowRet  PnL  TradeValue
# Ticker
# 2013    0.010899  0.010899 -0.032698  800     73400.0
# all :  1 ['2013']
# trade :  1 ['2013']
# Max Ret >= 2% :  0 []
# profit Probability for trade : 0.0 %
# Total PnL without cost: 800
# Total Trade Value: 73400.0
#
#
# =======================回測開始=======================
# Backtest 2021-08-31, ticker prepare from 2021-08-30.
#
# ['2371', '5608']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2371    0.008251  0.021452 -0.016502   600     30300.0
# 5608    0.010448  0.035821 -0.005970  1300     67000.0
# all :  2 ['2371', '5608']
# trade :  2 ['2371', '5608']
# Max Ret >= 2% :  2 ['2371', '5608']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 1900
# Total Trade Value: 97300.0

# %%
start_date = datetime(2021,7,1)
end_date = datetime(2021,7,31)
# result = {}
for date in pd.date_range(start_date, end_date):
    result[date.strftime("%Y-%m-%d")] = MainBacktest(date)
# Out:
# =======================回測開始=======================
# Backtest 2021-07-01, ticker prepare from 2021-06-30.
#
# ['1308', '1909', '2034', '2069', '2455', '2481', '2486', '4105', '5009', '6443', '8086', '8415']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1308    0.100000  0.100000  0.068571   700     35000.0
# 1909    0.001718  0.051546 -0.010309   550     29100.0
# 2034   -0.039535  0.046512 -0.046512   850     43000.0
# 2069    0.099462  0.099462  0.021505   700     37200.0
# 2455   -0.029851  0.007463 -0.037313 -4000    134000.0
# 2481   -0.075406  0.003480 -0.091647 -4300     86200.0
# 2486   -0.013648  0.099256 -0.018610   800     40300.0
# 4105   -0.027523  0.004587 -0.028670 -2400     87200.0
# 5009   -0.025455  0.072727 -0.036364   550     27500.0
# 6443   -0.031519  0.008596 -0.034384 -1100     34900.0
# 8086   -0.035370  0.012862 -0.041801 -5500    155500.0
# 8415   -0.045122  0.034146 -0.063415   800     41000.0
# all :  12 ['1308', '1909', '2034', '2069', '2455', '2481', '2486', '4105', '5009', '6443', '8086', '8415']
# trade :  12 ['1308', '1909', '2034', '2069', '2455', '2481', '2486', '6443', '4105', '5009', '8086', '8415']
# Max Ret >= 2% :  7 ['1308', '1909', '2034', '2069', '2486', '5009', '8415']
# profit Probability for trade : 58.33 %
# Total PnL without cost: -12350
# Total Trade Value: 750900.0
#
#
# =======================回測開始=======================
# Backtest 2021-07-02, ticker prepare from 2021-07-01.
# c:\users\kevin\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:73: RuntimeWarning: divide by zero encountered in longlong_scalars
# ['1305', '1517', '1809', '2010', '2017', '2030', '2069', '2486', '2606', '2615', '2617', '2636', '2637', '2643', '6191', '6509']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1305   -0.061298  0.097356 -0.069712   800     41600.0
# 1517   -0.010050  0.031826 -0.031826   550     29850.0
# 1809   -0.022581  0.032258 -0.029032   300     15500.0
# 2010   -0.033873  0.045655 -0.042710   650     33950.0
# 2017   -0.037705  0.049180 -0.049180   600     30500.0
# 2030    0.000000  0.016000 -0.050667 -1850     37500.0
# 2069    0.099022  0.099022 -0.033007   800     40900.0
# 2486    0.099371  0.099371 -0.005031   750     39750.0
# 2606   -0.047351  0.029312 -0.066516  1700     88700.0
# 2615   -0.028274  0.035714 -0.075893  6500    336000.0
# 2617    0.026426  0.084840 -0.022253  1400     71900.0
# 2636    0.071553  0.090750 -0.001745  5500    286500.0
# 2637   -0.013514  0.045045 -0.063063  2000    111000.0
# 2643   -0.067194  0.043478 -0.090909  2500    126500.0
# 6191    0.004310  0.031609 -0.007184   650     34800.0
# 6509    0.099526  0.099526  0.042654   800     42200.0
# all :  16 ['1305', '1517', '1809', '2010', '2017', '2030', '2069', '2486', '2606', '2615', '2617', '2636', '2637', '2643', '6191', '6509']
# trade :  16 ['1305', '1517', '1809', '2010', '2017', '2030', '2069', '2486', '2606', '2615', '2617', '2636', '2637', '6191', '2643', '6509']
# Max Ret >= 2% :  15 ['1305', '1517', '1809', '2010', '2017', '2069', '2486', '2606', '2615', '2617', '2636', '2637', '2643', '6191', '6509']
# profit Probability for trade : 93.75 %
# Total PnL without cost: 23650
# Total Trade Value: 1367150.0
#
#
# =======================回測開始=======================
# 2021-07-03 is Holiday.
#
#
# =======================回測開始=======================
# 2021-07-04 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2021-07-05, ticker prepare from 2021-07-02.
#
# ['1305', '1309', '1312', '1714', '2369', '2436', '3317', '6672', '8261']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1305    0.003841  0.029449 -0.001280   750     39050.0
# 1309    0.005459  0.045852 -0.003275   900     45800.0
# 1312    0.023438  0.050000  0.006250   600     32000.0
# 1714    0.024590  0.028689 -0.008197   200     12200.0
# 2369    0.040302  0.065491 -0.005038   350     19850.0
# 2436   -0.006143  0.057740 -0.017199  1600     81400.0
# 3317    0.016949  0.092568 -0.022164  1500     76700.0
# 6672    0.015576  0.052960 -0.037383  3000    160500.0
# 8261    0.086852  0.098914 -0.021713  1600     82900.0
# all :  9 ['1305', '1309', '1312', '1714', '2369', '2436', '3317', '6672', '8261']
# trade :  9 ['1305', '1309', '1312', '1714', '2369', '2436', '6672', '8261', '3317']
# Max Ret >= 2% :  9 ['1305', '1309', '1312', '1714', '2369', '2436', '3317', '6672', '8261']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 10500
# Total Trade Value: 550400.0
#
#
# =======================回測開始=======================
# Backtest 2021-07-06, ticker prepare from 2021-07-05.
#
# ['1710', '2006', '2029', '2031', '2069', '2340', '2342', '2375', '2388', '2484', '2485', '3035', '3189', '3317', '5285', '5351', '6274', '6509', '8021', '8069', '8183', '8261']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1710    0.006036  0.018109 -0.020121   150     24850.0
# 2006   -0.024433  0.041885 -0.036649  1100     57300.0
# 2029   -0.022556  0.062030 -0.026316  1000     53200.0
# 2031    0.023310  0.065268 -0.002331  1700     85800.0
# 2069   -0.044048 -0.004762 -0.083333 -2100     42000.0
# 2340   -0.030405  0.013514 -0.042230  -900     29600.0
# 2342   -0.036488  0.026226 -0.071836   850     43850.0
# 2375    0.029661  0.059322  0.016949  2000    118000.0
# 2388   -0.060897  0.022436 -0.067308  1200     62400.0
# 2484   -0.030956  0.000000 -0.039031 -1150     37150.0
# 2485   -0.046218  0.000000 -0.054622 -1150     23800.0
# 3035   -0.022248  0.016393 -0.050351 -4200     85400.0
# 3189    0.060000  0.080000 -0.033333  3000    150000.0
# 3317   -0.019231  0.032051 -0.021795  1500     78000.0
# 5285   -0.067290 -0.009346 -0.074766 -5000    107000.0
# 5351    0.087774  0.098746 -0.020376   600     31900.0
# 6274   -0.004219  0.004219 -0.016878  -500    118500.0
# 6509    0.011765  0.058824 -0.033333  1000     51000.0
# 8021   -0.011834  0.026036 -0.015385   800     42250.0
# 8069    0.033548  0.090323 -0.011613  1500     77500.0
# 8183   -0.030576  0.000000 -0.050360 -2700     55600.0
# 8261   -0.028857  0.043285 -0.047725  1800     90100.0
# all :  22 ['1710', '2006', '2029', '2031', '2069', '2340', '2342', '2375', '2388', '2484', '2485', '3035', '3189', '3317', '5285', '5351', '6274', '6509', '8021', '8069', '8183', '8261']
# trade :  22 ['1710', '2006', '2029', '2031', '2069', '2340', '2342', '2375', '2388', '2484', '2485', '3035', '3189', '5285', '8021', '8261', '3317', '5351', '6274', '6509', '8069', '8183']
# Max Ret >= 2% :  13 ['2006', '2029', '2031', '2342', '2375', '2388', '3189', '3317', '5351', '6509', '8021', '8069', '8261']
# profit Probability for trade : 59.09 %
# Total PnL without cost: 500
# Total Trade Value: 1465200.0
#
#
# =======================回測開始=======================
# Backtest 2021-07-07, ticker prepare from 2021-07-06.
#
# ['2476', '3016', '3035', '3260', '4739', '4967', '5351', '5425', '6509', '8069', '8110']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2476   -0.008214  0.012320 -0.035934  -400     48700.0
# 3016    0.020592  0.047619 -0.019305  1500     77700.0
# 3035    0.099401  0.099401  0.015569  1600     83500.0
# 3260    0.008032  0.060241 -0.008032  2000    124500.0
# 4739   -0.013158  0.061404 -0.035088  2000    114000.0
# 4967   -0.006711  0.040268 -0.017450  1400     74500.0
# 5351    0.011527  0.037464 -0.048991   650     34700.0
# 5425    0.099607  0.099607 -0.023591  1500     76300.0
# 6509   -0.067829 -0.031008 -0.069767 -2550     51600.0
# 8069    0.018727  0.039950 -0.001248  1600     80100.0
# 8110   -0.020513  0.012821 -0.030769  -400     19500.0
# all :  11 ['2476', '3016', '3035', '3260', '4739', '4967', '5351', '5425', '6509', '8069', '8110']
# trade :  11 ['2476', '3016', '3035', '4739', '4967', '8110', '3260', '5351', '5425', '6509', '8069']
# Max Ret >= 2% :  8 ['3016', '3035', '3260', '4739', '4967', '5351', '5425', '8069']
# profit Probability for trade : 72.73 %
# Total PnL without cost: 8900
# Total Trade Value: 785100.0
#
#
# =======================回測開始=======================
# Backtest 2021-07-08, ticker prepare from 2021-07-07.
#
# ['1517', '1909', '2368', '2455', '2457', '2481', '3552', '3624', '4919', '6127', '6261', '6271', '6283', '8086']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1517   -0.003279  0.029508 -0.013115   600     30500.0
# 1909   -0.054545  0.018182 -0.066667 -1650     33000.0
# 2368    0.089510  0.096503 -0.006993  1400     71500.0
# 2455   -0.016949  0.010169 -0.040678 -2500    147500.0
# 2457    0.039216  0.047794 -0.013480   800     40800.0
# 2481    0.012821  0.060897 -0.008547  1800     93600.0
# 3552   -0.009174  0.038532 -0.020183  5000    272500.0
# 3624    0.004246  0.028662 -0.022293   900     47100.0
# 4919    0.007330  0.029319 -0.038743  1900     95500.0
# 6127   -0.012232  0.033639 -0.025994   650     32700.0
# 6261   -0.010309  0.015464 -0.020619 -1000     97000.0
# 6271    0.017738  0.042129 -0.008869  4500    225500.0
# 6283    0.010017  0.053422 -0.008347  1100     59900.0
# 8086    0.014925  0.044776 -0.011940  3000    167500.0
# all :  14 ['1517', '1909', '2368', '2455', '2457', '2481', '3552', '3624', '4919', '6127', '6261', '6271', '6283', '8086']
# trade :  14 ['1517', '1909', '2368', '2455', '2457', '2481', '4919', '6271', '6283', '3552', '3624', '6127', '6261', '8086']
# Max Ret >= 2% :  11 ['1517', '2368', '2457', '2481', '3552', '3624', '4919', '6127', '6271', '6283', '8086']
# profit Probability for trade : 78.57 %
# Total PnL without cost: 16500
# Total Trade Value: 1414600.0
#
#
# =======================回測開始=======================
# Backtest 2021-07-09, ticker prepare from 2021-07-08.
#
# ['1815', '2030', '2476', '2489', '3035', '3037', '3605', '6237', '8255']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1815    0.019126  0.043716 -0.016393   350     18300.0
# 2030    0.003759  0.003759 -0.047619   150     39900.0
# 2476    0.073812  0.096057 -0.028311   950     49450.0
# 2489   -0.021390 -0.005348 -0.037433  -400     18700.0
# 3035    0.096807  0.096807 -0.014418  1900     97100.0
# 3037    0.010638  0.028369 -0.021277  2500    141000.0
# 3605    0.029514  0.050347 -0.038194  1100     57600.0
# 6237    0.003268  0.009804 -0.039216   500    153000.0
# 8255   -0.004706  0.054118 -0.011765  4000    212500.0
# all :  9 ['1815', '2030', '2476', '2489', '3035', '3037', '3605', '6237', '8255']
# trade :  9 ['2030', '2476', '2489', '3035', '3037', '3605', '1815', '6237', '8255']
# Max Ret >= 2% :  6 ['1815', '2476', '3035', '3037', '3605', '8255']
# profit Probability for trade : 66.67 %
# Total PnL without cost: 11050
# Total Trade Value: 787550.0
#
#
# =======================回測開始=======================
# 2021-07-10 is Holiday.
#
#
# =======================回測開始=======================
# 2021-07-11 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2021-07-12, ticker prepare from 2021-07-09.
# ['1709', '1815', '2369', '2401', '2406', '3305', '3511', '3624', '4714', '5285', '5328', '6168', '8110']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1709   -0.013857  0.006928 -0.016166  -300     21650.0
# 1815    0.061662  0.088472  0.024129   350     18650.0
# 2369    0.100000  0.100000  0.033333   450     24000.0
# 2401    0.098996  0.098996  0.058824   650     34850.0
# 2406    0.010571  0.033827  0.006342   450     23650.0
# 3305    0.041026  0.076923  0.010256  1100     58500.0
# 3511   -0.008961  0.075269 -0.023297  1100     55800.0
# 3624    0.051923  0.094231  0.013462  1000     52000.0
# 4714   -0.016779  0.013423 -0.020134  -250     14900.0
# 5285    0.096916  0.096916  0.048458  2000    113500.0
# 5328   -0.016760  0.033520 -0.022346   350     17900.0
# 6168    0.099624  0.099624  0.077068   500     26600.0
# 8110    0.100000  0.100000  0.046512   400     21500.0
# all :  13 ['1709', '1815', '2369', '2401', '2406', '3305', '3511', '3624', '4714', '5285', '5328', '6168', '8110']
# trade :  13 ['1709', '2369', '2401', '2406', '3305', '5285', '6168', '8110', '1815', '3511', '3624', '4714', '5328']
# Max Ret >= 2% :  11 ['1815', '2369', '2401', '2406', '3305', '3511', '3624', '5285', '5328', '6168', '8110']
# profit Probability for trade : 84.62 %
# Total PnL without cost: 7800
# Total Trade Value: 483500.0
#
#
# =======================回測開始=======================
# Backtest 2021-07-13, ticker prepare from 2021-07-12.
#
# ['1815', '2007', '2017', '2023', '2032', '2069', '2340', '2342', '2415', '2436', '2455', '3003', '3016', '3317', '3372', '4739', '6127', '6175', '6182', '6271', '6283', '8150', '8261']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1815    0.025253  0.055556 -0.010101   350     19800.0
# 2007   -0.097847  0.015656 -0.099804 -1250     25550.0
# 2017   -0.099448  0.016575 -0.099448 -1800     36200.0
# 2023   -0.081818  0.012987 -0.090909 -1900     38500.0
# 2032   -0.099394 -0.013333 -0.099394 -2050     41250.0
# 2069   -0.099881 -0.001189 -0.099881 -2100     42050.0
# 2340   -0.064220  0.006116 -0.081040 -1600     32700.0
# 2342   -0.029297  0.085938 -0.081055  1000     51200.0
# 2415    0.008576  0.099485 -0.046312  1100     58300.0
# 2436   -0.049494  0.057368 -0.083240  1700     88900.0
# 2455   -0.023649  0.030405 -0.047297  2500    148000.0
# 3003   -0.044944  0.062308 -0.092952  1900     97900.0
# 3016   -0.024242  0.059394 -0.032727  1600     82500.0
# 3317   -0.031765  0.081176 -0.043529  1700     85000.0
# 3372   -0.034483  0.041379 -0.089655   550     29000.0
# 4739   -0.044898  0.085714 -0.093878  2000    122500.0
# 6127   -0.034743  0.024169 -0.063444   650     33100.0
# 6175   -0.062382  0.018904 -0.073724 -2600     52900.0
# 6182   -0.008863  0.072378 -0.032496  1300     67700.0
# 6271   -0.022449  0.028571 -0.061224  4500    245000.0
# 6283   -0.077760 -0.009331 -0.088647 -3200     64300.0
# 8150    0.011765  0.074510  0.000000  1000     51000.0
# 8261   -0.017372  0.091205 -0.030402  1800     92100.0
# all :  23 ['1815', '2007', '2017', '2023', '2032', '2069', '2340', '2342', '2415', '2436', '2455', '3003', '3016', '3317', '3372', '4739', '6127', '6175', '6182', '6271', '6283', '8150', '8261']
# trade :  23 ['2007', '2017', '2023', '2032', '2069', '2340', '2342', '2415', '2436', '2455', '3003', '3016', '4739', '6271', '6283', '8150', '8261', '1815', '3317', '3372', '6127', '6175', '6182']
# Max Ret >= 2% :  15 ['1815', '2342', '2415', '2436', '2455', '3003', '3016', '3317', '3372', '4739', '6127', '6182', '6271', '8150', '8261']
# profit Probability for trade : 65.22 %
# Total PnL without cost: 7150
# Total Trade Value: 1605450.0
#
#
# =======================回測開始=======================
# Backtest 2021-07-14, ticker prepare from 2021-07-13.
#
# ['2344', '2369', '2401', '2415', '2484', '2489', '2614', '3003', '3058', '3059', '3149', '3706', '3707', '4721', '4739', '5285', '6129', '6138', '6182', '6191', '6223', '6284', '8021', '8150', '8255', '8261']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2344   -0.077530  0.011827 -0.077530 -1900     38050.0
# 2369   -0.074954  0.031079 -0.085923   500     27350.0
# 2401   -0.026810  0.030831 -0.046917   700     37300.0
# 2415   -0.098639  0.017007 -0.098639 -2900     58800.0
# 2484   -0.032653  0.012245 -0.039456 -1200     36750.0
# 2489   -0.021277  0.018617 -0.039894  -400     18800.0
# 2614   -0.099567 -0.079365 -0.099567 -3400     69300.0
# 3003   -0.056684 -0.002139 -0.071658 -4600     93500.0
# 3058   -0.026455  0.031746 -0.071429   350     18900.0
# 3059    0.009321  0.025300 -0.009321   750     37550.0
# 3149   -0.043011  0.018280 -0.053763 -2300     46500.0
# 3706   -0.010152  0.015228 -0.013536  -300     29550.0
# 3707    0.099338  0.099338  0.012141  1800     90600.0
# 4721   -0.044743  0.041387 -0.049217  1700     89400.0
# 4739   -0.034188  0.025641 -0.051282  2000    117000.0
# 5285   -0.012448  0.099585 -0.037344  2000    120500.0
# 6129   -0.015532  0.060932 -0.025090   800     41850.0
# 6138   -0.030303  0.024793 -0.052342  3500    181500.0
# 6182   -0.008942  0.026826 -0.020864  1300     67100.0
# 6191   -0.096569  0.041931 -0.099111   750     39350.0
# 6223    0.055172  0.055172 -0.031034  2500    145000.0
# 6284    0.007792  0.038961 -0.019481  1500     77000.0
# 8021   -0.051225  0.028953 -0.053452   850     44900.0
# 8150    0.019380  0.032946 -0.031977  1000     51600.0
# 8255   -0.080092  0.045767 -0.093822  4000    218500.0
# 8261    0.016575  0.035359 -0.038674  1800     90500.0
# all :  26 ['2344', '2369', '2401', '2415', '2484', '2489', '2614', '3003', '3058', '3059', '3149', '3706', '3707', '4721', '4739', '5285', '6129', '6138', '6182', '6191', '6223', '6284', '8021', '8150', '8255', '8261']
# trade :  26 ['2344', '2369', '2401', '2415', '2484', '2489', '2614', '3003', '3058', '3059', '3149', '3706', '4739', '5285', '6191', '8021', '8150', '8261', '3707', '4721', '6129', '6138', '6182', '6223', '6284', '8255']
# Max Ret >= 2% :  18 ['2369', '2401', '3058', '3059', '3707', '4721', '4739', '5285', '6129', '6138', '6182', '6191', '6223', '6284', '8021', '8150', '8255', '8261']
# profit Probability for trade : 69.23 %
# Total PnL without cost: 10800
# Total Trade Value: 1887150.0
#
#
# =======================回測開始=======================
# Backtest 2021-07-15, ticker prepare from 2021-07-14.
#
# ['1711', '1785', '1802', '2441', '2476', '3049', '4919', '5443', '8110']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1711    0.004762  0.014286 -0.019048   100     21000.0
# 1785   -0.005758  0.026871 -0.019194  1000     52100.0
# 1802   -0.004608  0.018433 -0.034562  -200     43400.0
# 2441   -0.031505 -0.002334 -0.039673 -2700     85700.0
# 2476   -0.012456  0.023132 -0.037367  1100     56200.0
# 3049   -0.040146 -0.007299 -0.051095  -650     13700.0
# 4919    0.044177  0.044177 -0.032129  2000    124500.0
# 5443   -0.023884  0.015576 -0.043614 -1150     48150.0
# 8110   -0.089744 -0.055556 -0.098291 -1150     23400.0
# all :  9 ['1711', '1785', '1802', '2441', '2476', '3049', '4919', '5443', '8110']
# trade :  9 ['1711', '1802', '2441', '2476', '3049', '4919', '8110', '1785', '5443']
# Max Ret >= 2% :  3 ['1785', '2476', '4919']
# profit Probability for trade : 33.33 %
# Total PnL without cost: -1650
# Total Trade Value: 468150.0
#
#
# =======================回測開始=======================
# Backtest 2021-07-16, ticker prepare from 2021-07-15.
#
# ['2358', '3707', '5351', '8064']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2358    0.045024  0.099526 -0.028436   400     21100.0
# 3707    0.037383  0.065421 -0.051402  2000    107000.0
# 5351    0.002625  0.053806 -0.034121   750     38100.0
# 8064   -0.016432  0.009390 -0.046948  -350     21300.0
# all :  4 ['2358', '3707', '5351', '8064']
# trade :  4 ['2358', '3707', '5351', '8064']
# Max Ret >= 2% :  3 ['2358', '3707', '5351']
# profit Probability for trade : 75.0 %
# Total PnL without cost: 2800
# Total Trade Value: 187500.0
#
#
# =======================回測開始=======================
# 2021-07-17 is Holiday.
#
#
# =======================回測開始=======================
# 2021-07-18 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2021-07-19, ticker prepare from 2021-07-16.
# ['1802', '1815', '2340', '3042', '3122', '6104', '6215', '6244']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1802   -0.004348  0.041304 -0.010870   900     46000.0
# 1815    0.018868  0.075472  0.004717   400     21200.0
# 2340   -0.019403  0.007463 -0.040299  -650     33500.0
# 3042   -0.010830  0.032491 -0.021661  2500    138500.0
# 3122    0.021359  0.083495 -0.019417  1000     51500.0
# 6104    0.098522  0.098522  0.054187  2000    101500.0
# 6215   -0.025886  0.014986 -0.049046  -950     36700.0
# 6244    0.050975  0.085457  0.007496   650     33350.0
# all :  8 ['1802', '1815', '2340', '3042', '3122', '6104', '6215', '6244']
# trade :  8 ['1802', '2340', '3042', '6215', '1815', '3122', '6104', '6244']
# Max Ret >= 2% :  6 ['1802', '1815', '3042', '3122', '6104', '6244']
# profit Probability for trade : 75.0 %
# Total PnL without cost: 5850
# Total Trade Value: 462250.0
#
#
# =======================回測開始=======================
# Backtest 2021-07-20, ticker prepare from 2021-07-19.
#
# ['1605', '1785', '1795', '1815', '2023', '2032', '2383', '2406', '2486', '3016', '4952', '5471', '6173', '6202', '6233', '6244', '6509', '8044', '8069', '8261', '9907', '9945']
#
#              Ret   HighRet    LowRet    PnL  TradeValue
# Ticker
# 1605   -0.046823 -0.015050 -0.050167  -1450     29900.0
# 1785    0.001908  0.017176 -0.015267    100     52400.0
# 1795   -0.047458  0.037288 -0.050847   2500    147500.0
# 1815   -0.062500 -0.018519 -0.074074  -1050     21600.0
# 2023   -0.052826  0.012285 -0.088452  -2000     40700.0
# 2032    0.024213  0.054479 -0.087167    800     41300.0
# 2383   -0.047423  0.010309 -0.053608 -12000    242500.0
# 2406    0.053333  0.062857 -0.038095    500     26250.0
# 2486    0.037162  0.092905  0.000000   1100     59200.0
# 3016    0.005495  0.082418  0.001099   1800     91000.0
# 4952    0.008111  0.086906 -0.057937   1700     86300.0
# 5471   -0.035398 -0.008850 -0.053097  -5500    113000.0
# 6173   -0.035526 -0.003947 -0.039474  -2700     76000.0
# 6202   -0.045775  0.007042 -0.045775  -6500    142000.0
# 6233    0.035824  0.074719 -0.022518    950     48850.0
# 6244   -0.019971 -0.004280 -0.039943   -700     35050.0
# 6509    0.016923  0.030769 -0.032308   1300     65000.0
# 8044    0.020761  0.048443 -0.038062   2500    144500.0
# 8069    0.023438  0.052455 -0.032366   1700     89600.0
# 8261   -0.040796  0.014925 -0.044776  -4100    100500.0
# 9907   -0.030864 -0.006173 -0.033951   -500     16200.0
# 9945   -0.012012  0.000000 -0.019520   -800     66600.0
# all :  22 ['1605', '1785', '1795', '1815', '2023', '2032', '2383', '2406', '2486', '3016', '4952', '5471', '6173', '6202', '6233', '6244', '6509', '8044', '8069', '8261', '9907', '9945']
# trade :  22 ['1605', '1795', '2023', '2032', '2383', '2406', '2486', '3016', '4952', '5471', '6202', '8261', '9907', '9945', '1785', '1815', '6173', '6233', '6244', '6509', '8044', '8069']
# Max Ret >= 2% :  10 ['1795', '2032', '2406', '2486', '3016', '4952', '6233', '6509', '8044', '8069']
# profit Probability for trade : 45.45 %
# Total PnL without cost: -22350
# Total Trade Value: 1735950.0
#
#
# =======================回測開始=======================
# Backtest 2021-07-21, ticker prepare from 2021-07-20.
#
# ['1795', '2007', '2023', '2032', '2034', '2069', '3006', '3016', '3122', '3264', '5475', '5905', '8255']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 1795    0.099644  0.099644 -0.003559  2500    140500.0
# 2007    0.006861  0.099485  0.005146   550     29150.0
# 2023   -0.045396  0.079118 -0.050584   750     38550.0
# 2032   -0.065012  0.099291 -0.078014   800     42300.0
# 2034   -0.043968  0.066516 -0.043968   850     44350.0
# 2069   -0.046563  0.082040 -0.047672   900     45100.0
# 3006    0.034682  0.075145  0.020231  3000    173000.0
# 3016    0.098361  0.098361  0.017486  1800     91500.0
# 3122    0.067474  0.083045  0.010381  1100     57800.0
# 3264    0.003431  0.054889 -0.041166  1100     58300.0
# 5475    0.067227  0.086134  0.010504   950     47600.0
# 5905    0.002778  0.086111 -0.027778   350     18000.0
# 8255    0.077754  0.099352  0.004320  4500    231500.0
# all :  13 ['1795', '2007', '2023', '2032', '2034', '2069', '3006', '3016', '3122', '3264', '5475', '5905', '8255']
# trade :  13 ['1795', '2007', '2023', '2032', '2034', '2069', '3006', '3016', '3122', '3264', '5475', '5905', '8255']
# Max Ret >= 2% :  13 ['1795', '2007', '2023', '2032', '2034', '2069', '3006', '3016', '3122', '3264', '5475', '5905', '8255']
# profit Probability for trade : 100.0 %
# Total PnL without cost: 19150
# Total Trade Value: 1017650.0
#
#
# =======================回測開始=======================
# Backtest 2021-07-22, ticker prepare from 2021-07-21.
#
# ['2338', '2393', '2401', '3122', '3317', '3588', '3605', '3624', '4721', '4739', '5328', '6257', '6509', '8021', '8054']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2338   -0.033333  0.050505 -0.035354  1500     99000.0
# 2393   -0.016556  0.018212 -0.039735 -1000     60400.0
# 2401    0.018223  0.083144 -0.043280   850     43900.0
# 3122   -0.059968  0.024311 -0.066451  1200     61700.0
# 3317    0.019912  0.082965  0.001106  1800     90400.0
# 3588   -0.011111  0.033333 -0.037037  2500    135000.0
# 3605   -0.084877 -0.010802 -0.095679 -3200     64800.0
# 3624   -0.027027  0.052124 -0.028958  1000     51800.0
# 4721   -0.028272  0.031414 -0.040838  1900     95500.0
# 4739   -0.026616  0.022814 -0.045627  2500    131500.0
# 5328    0.002786  0.097493 -0.013928   350     17950.0
# 6257    0.013311  0.023295  0.001664  1200     60100.0
# 6509   -0.057692  0.025148 -0.081361  1300     67600.0
# 8021   -0.004348  0.050000 -0.006522   900     46000.0
# 8054    0.017884  0.055142 -0.022355  1300     67100.0
# all :  15 ['2338', '2393', '2401', '3122', '3317', '3588', '3605', '3624', '4721', '4739', '5328', '6257', '6509', '8021', '8054']
# trade :  15 ['2338', '2393', '2401', '3588', '3605', '4739', '6257', '8021', '3122', '3317', '3624', '4721', '5328', '6509', '8054']
# Max Ret >= 2% :  13 ['2338', '2401', '3122', '3317', '3588', '3624', '4721', '4739', '5328', '6257', '6509', '8021', '8054']
# profit Probability for trade : 86.67 %
# Total PnL without cost: 14100
# Total Trade Value: 1092750.0
#
#
# =======================回測開始=======================
# Backtest 2021-07-23, ticker prepare from 2021-07-22.
# c:\users\kevin\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:73: RuntimeWarning: divide by zero encountered in longlong_scalars
# ['2329', '2369', '2401', '2436', '3035', '3041', '3189', '4919', '4967', '5285', '5351', '6175', '6271', '8016', '8054', '8112', '9962']
#
#              Ret   HighRet    LowRet    PnL  TradeValue
# Ticker
# 2329    0.038710  0.066667  0.002151    450     23250.0
# 2369    0.010791  0.016187 -0.021583    300     27800.0
# 2401    0.004474  0.060403 -0.026846    850     44700.0
# 2436   -0.075824  0.004396 -0.076923  -4500     91000.0
# 3035   -0.050633 -0.012658 -0.080169  -5500    118500.0
# 3041    0.018663  0.018663 -0.027994    600     32150.0
# 3189   -0.047733  0.026253 -0.069212   4000    209500.0
# 4919   -0.078431  0.035948 -0.098039   3000    153000.0
# 4967    0.010825  0.023004 -0.020298   1400     73900.0
# 5285   -0.015209  0.091255 -0.064639   2500    131500.0
# 5351   -0.007634  0.079607 -0.017448    900     45850.0
# 6175   -0.040000  0.016364 -0.045455  -2200     55000.0
# 6271   -0.025974  0.001855 -0.064935 -13000    269500.0
# 8016   -0.004478  0.044776 -0.023881   6500    335000.0
# 8054   -0.017570  0.079063 -0.032211   1300     68300.0
# 8112   -0.003348  0.012277 -0.016741   -150     44800.0
# 9962    0.098712  0.098712  0.030043    450     23300.0
# all :  17 ['2329', '2369', '2401', '2436', '3035', '3041', '3189', '4919', '4967', '5285', '5351', '6175', '6271', '8016', '8054', '8112', '9962']
# trade :  17 ['2329', '2369', '2401', '2436', '3035', '3041', '3189', '4919', '4967', '5285', '6271', '8016', '8112', '5351', '6175', '8054', '9962']
# Max Ret >= 2% :  10 ['2329', '2401', '3189', '4919', '4967', '5285', '5351', '8016', '8054', '9962']
# profit Probability for trade : 58.82 %
# Total PnL without cost: -3100
# Total Trade Value: 1747050.0
#
#
# =======================回測開始=======================
# 2021-07-24 is Holiday.
#
#
# =======================回測開始=======================
# 2021-07-25 is Holiday.
#
#
# =======================回測開始=======================
# Backtest 2021-07-26, ticker prepare from 2021-07-23.
#
# ['2481', '3141', '3221', '3545', '4952', '6168', '6215', '6226', '6548', '8215']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2481    0.050000  0.095455  0.009091  2000    110000.0
# 3141    0.097923  0.097923  0.097923  3000    168500.0
# 3221    0.020115  0.022989 -0.030172   650     34800.0
# 3545    0.020333  0.072089  0.014787  5000    270500.0
# 4952    0.008055  0.034522  0.000000  1700     86900.0
# 6168    0.099844  0.099844  0.024961   600     32050.0
# 6215   -0.054777  0.016561 -0.077707 -1950     39250.0
# 6226    0.000000  0.055718 -0.079179   300     17050.0
# 6548    0.097308  0.097308 -0.003106  1900     96600.0
# 8215    0.098802  0.098802  0.062874   650     33400.0
# all :  10 ['2481', '3141', '3221', '3545', '4952', '6168', '6215', '6226', '6548', '8215']
# trade :  10 ['2481', '3545', '4952', '6168', '6215', '6226', '8215', '3141', '3221', '6548']
# Max Ret >= 2% :  9 ['2481', '3141', '3221', '3545', '4952', '6168', '6226', '6548', '8215']
# profit Probability for trade : 90.0 %
# Total PnL without cost: 13850
# Total Trade Value: 889050.0
#
#
# =======================回測開始=======================
# Backtest 2021-07-27, ticker prepare from 2021-07-26.
#
# ['2426', '3014', '3016', '3372', '4956', '4960', '6127', '6226', '6257', '6261', '6290', '8070']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 2426   -0.087948  0.008143 -0.096091 -1500     30700.0
# 3014    0.007463  0.048507 -0.048507  2500    134000.0
# 3016   -0.060952  0.023810 -0.060952  2000    105000.0
# 3372   -0.059561  0.034483 -0.059561   600     31900.0
# 4956   -0.077170  0.019293 -0.080386 -1550     31100.0
# 4960   -0.040000 -0.008000 -0.048000  -500     12500.0
# 6127   -0.091413  0.000000 -0.095568 -1800     36100.0
# 6226    0.000000  0.043988 -0.041056   300     17050.0
# 6257   -0.014263  0.012678 -0.028526  -900     63100.0
# 6261   -0.092823  0.019139 -0.097608 -5200    104500.0
# 6290   -0.063260  0.029197 -0.085158  1600     82200.0
# 8070   -0.047558  0.000000 -0.048843 -1850     38900.0
# all :  12 ['2426', '3014', '3016', '3372', '4956', '4960', '6127', '6226', '6257', '6261', '6290', '8070']
# trade :  12 ['2426', '3014', '3016', '4956', '4960', '6226', '6257', '8070', '3372', '6127', '6261', '6290']
# Max Ret >= 2% :  5 ['3014', '3016', '3372', '6226', '6290']
# profit Probability for trade : 41.67 %
# Total PnL without cost: -6300
# Total Trade Value: 687050.0
#
#
# =======================回測開始=======================
# Backtest 2021-07-28, ticker prepare from 2021-07-27.
#
# ['2338', '3006', '3014', '3556', '5905', '6138', '6175', '6182', '8016']
#
#              Ret   HighRet    LowRet    PnL  TradeValue
# Ticker
# 2338   -0.063725  0.049020 -0.093137   2000    102000.0
# 3006   -0.097938  0.015464 -0.097938  -9500    194000.0
# 3014   -0.074074 -0.014815 -0.096296  -6500    135000.0
# 3556   -0.050000  0.000000 -0.100000  -5200    104000.0
# 5905   -0.013333  0.013333 -0.066667   -900     18750.0
# 6138   -0.075130  0.069948 -0.098446   3500    193000.0
# 6175   -0.077634  0.007394 -0.099815  -2700     54100.0
# 6182   -0.057183 -0.008368 -0.097629  -3500     71700.0
# 8016   -0.099476 -0.005236 -0.099476 -19000    382000.0
# all :  9 ['2338', '3006', '3014', '3556', '5905', '6138', '6175', '6182', '8016']
# trade :  9 ['2338', '3006', '3014', '8016', '3556', '5905', '6138', '6175', '6182']
# Max Ret >= 2% :  2 ['2338', '6138']
# profit Probability for trade : 22.22 %
# Total PnL without cost: -41800
# Total Trade Value: 1254550.0
#
#
# =======================回測開始=======================
# Backtest 2021-07-29, ticker prepare from 2021-07-28.
#
# No Tickers for 2021-07-29 to Trade.
#
#
#
# =======================回測開始=======================
# Backtest 2021-07-30, ticker prepare from 2021-07-29.
#
# ['3037', '3221', '6257', '8289']
#
#              Ret   HighRet    LowRet   PnL  TradeValue
# Ticker
# 3037   -0.036304  0.009901 -0.046205 -5500    151500.0
# 3221   -0.036096  0.016043 -0.040107 -1350     37400.0
# 6257   -0.003110  0.017107 -0.013997  -200     64300.0
# 8289   -0.001712  0.095890 -0.005137   550     29200.0
# all :  4 ['3037', '3221', '6257', '8289']
# trade :  4 ['3037', '6257', '3221', '8289']
# Max Ret >= 2% :  1 ['8289']
# profit Probability for trade : 25.0 %
# Total PnL without cost: -6500
# Total Trade Value: 282400.0
#
#
# =======================回測開始=======================
# 2021-07-31 is Holiday.

# %%
plot_result = []
for k, v in result.items():
    if v:
        plot_result.append({'Date':k, "PnL":sum([x['PnL'] for x in v])})
    else:
        plot_result.append({'Date':k, "PnL":0})

# %%
plot_df = pd.DataFrame(plot_result).set_index("Date").sort_index()
plot_df['CumPnL'] = plot_df.PnL.cumsum()

# %%
plot_df.CumPnL.plot(figsize=(12,8), title="CumPnL of Backtest.")
# Out:
# <AxesSubplot:title={'center':'CumPnL of Backtest.'}, xlabel='Date'>

# %%
plot_df.CumPnL.plot(figsize=(12,8), title="CumPnL of Backtest.") # old stock picking
# Out:
# c:\users\kevin\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_matplotlib\core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:title={'center':'CumPnL of Backtest.'}, xlabel='Date'>

# %%
plot_df.CumPnL.iloc[-1]
# Out:
# 228130

# %%
import pandas as pd
def create_drawdowns(pnl, **kwargs):
    """
    計算回撤
    Calculate the largest peak-to-trough drawdown of the PnL curve
    as well as the duration of the drawdown. Requires that the
    pnl_returns is a pandas Series.
    :param pnl: A pandas Series representing period percentage returns.
    :return: drawdown, duration - Highest peak-to-trough drawdown and duration
    """
    # Calculate the cumulative returns curve
    # and set up the High Water Mark
    hwm = [0]

    # Create the drawdown and duration series
    idx = pnl.index
    drawdown = pd.Series(index=idx)
    duration = pd.Series(index=idx)
    # Loop over the index range
    for t in range(1, len(idx)):
        try:
            hwm.append(max(hwm[t-1], pnl.iloc[idx[t]]))  # 計算每個時間點的最大的報酬
            drawdown.iloc[idx[t]] = (
                hwm[t]-pnl.iloc[idx[t]]) / hwm[t]  # 計算每個時間點的回撤
            duration.iloc[idx[t]] = (
                0 if drawdown.iloc[idx[t]] == 0 else duration.iloc[idx[t-1]]+1)  # 計算回撤的持續時間
        except:
            hwm.append(max(hwm[t-1], pnl.iloc[t]))  # 計算每個時間點的最大的報酬
            drawdown.iloc[t] = (hwm[t]-pnl.iloc[t]) / hwm[t]  # 計算每個時間點的回撤
            duration.iloc[t] = (0 if drawdown.iloc[t] ==
                                0 else duration.iloc[t-1]+1)  # 計算回撤的持續時間
    return drawdown, drawdown.max(), duration.max()

# %%
dds, maxDD, MaxDuration = create_drawdowns(plot_df.CumPnL)
# Out:
# c:\users\kevin\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:17: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# c:\users\kevin\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:18: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.

# %%
from matplotlib.ticker import FuncFormatter
ax = (-100 * dds).plot(figsize=(12,8), title="Max Drawdown of Backtest.")
def format_perc(x, pos): return '%.0f%%' % x
y_axis_formatter = FuncFormatter(format_perc)
ax.yaxis.set_major_formatter(FuncFormatter(y_axis_formatter))
# Out:
# c:\users\kevin\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_matplotlib\core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

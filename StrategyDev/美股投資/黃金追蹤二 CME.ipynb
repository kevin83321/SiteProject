# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import requests

# %%
# res = requests.get("https://www.cmegroup.com/CmeWS/exp/voiProductsViewExport.ctl?media=xls&tradeDate=20220919&assetClassId=8&reportType=P&excluded=CEE,CEU,KCB")
res = requests.get("https://www.cmegroup.com/CmeWS/exp/voiProductsViewExport.ctl?media=json&tradeDate=20220919&assetClassId=8&reportType=P&excluded=CEE,CEU,KCB")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.pyenv/versions/3.7.8/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-1ce76cecc1ca> in <module>
#       1 # res = requests.get("https://www.cmegroup.com/CmeWS/exp/voiProductsViewExport.ctl?media=xls&tradeDate=20220919&assetClassId=8&reportType=P&excluded=CEE,CEU,KCB")
# ...

# %%
df = pd.read_excel("https://www.cmegroup.com/CmeWS/exp/voiProductsViewExport.ctl?media=xls&tradeDate=20220919&assetClassId=8&reportType=P&excluded=CEE,CEU,KCB")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-2-a4cac390dba2> in <module>
# ----> 1 df = pd.read_excel("https://www.cmegroup.com/CmeWS/exp/voiProductsViewExport.ctl?media=xls&tradeDate=20220919&assetClassId=8&reportType=P&excluded=CEE,CEU,KCB")
#
# ~/.pyenv/versions/3.7.8/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# ...

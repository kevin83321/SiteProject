# %%
__updated__ = '2021-12-28 21:30:56'
import warnings
warnings.filterwarnings("ignore")

from Calculator import Calculator as Calc
# from PlotTools import createPlot
from utils import (
    pd, np, getSchema, getDateBeforeTrade, 
    saveRecommand, timedelta, GetException,
    sendResultTable, VolumeFilter, PriceFilter,
    changedType, datetime
)
import os
parent = os.path.dirname(os.path.abspath("__file__"))
output_path = os.path.join(parent, 'StrongResearch')
if not os.path.isdir(output_path):
    os.makedirs(output_path)
# Out:
# c:\users\kevin\appdata\local\programs\python\python37\lib\site-packages\mpl_finance.py:22: DeprecationWarning:
#
#   =================================================================
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
#   =================================================================
#
#   category=DeprecationWarning)

# %%
def getLimit(price, pct=0.1, trend="U"):
    tmp_price = price
    if trend == "U":
        while 1:
            tick = Calc.get_minimum_tick(tmp_price)
            tmp_price += tick
            if (tmp_price/price) > 1 + pct:
                tmp_price -= tick
                break
    elif trend == "D":
        while 1:
            tick = Calc.get_minimum_tick(tmp_price)
            tmp_price -= tick
            if (tmp_price/price) < 1 - pct:
                tmp_price += tick
                break
            
    return round(tmp_price, 2)

# %%
def BacktestCrossDayTradeV2(td= datetime.today(), tp_ratio=.02, sl_ratio=.05):
    try:
        if td.isocalendar()[-1] > 5:
            tdStr = td.strftime("%Y-%m-%d")
            print(f"It\'s Holiday {tdStr}")
            return
        td, last = getDateBeforeTrade(td.replace(hour=18))
        pre_1y = td + timedelta(-365)
        tdStr = td.strftime("%Y-%m-%d")
        print(f"=============Start Backtest {tdStr}==================")
        # setup data
        schema = getSchema('TWSE')
        table = schema['StockList']
        last_date = sorted(table.distinct("UpdateDate"))[-1]
        info_data = dict((x['Ticker'], x['Industry']+f"({x['Market'][-1]})") for x in table.find({"UpdateDate":{"$eq":last_date}, "Industry" :{"$ne":""}}))

        schema = getSchema('TWSE')
        table = schema['historicalPrice']
        # data = list(table.find({'Date':{'$gte':last.strftime('%Y-%m-%d'), '$lte':last.strftime('%Y-%m-%d')}, "Ticker" :{"$in":list(info_data.keys())}}))
        # sjData = readDataFromSJ(td, list(info_data.keys()))
        # try:
        #     data += sjData
        # except:
        #     pass

        # if datetime.now() >= td.replace(hour=15):
        test_data = list(table.find({'Date':{'$gte':td.strftime('%Y-%m-%d'), '$lte':td.strftime('%Y-%m-%d')}, "Ticker" :{"$eq":"2330"}}))
        if not test_data:
            print(f"It\'s Holiday {tdStr}")
            return
        data = list(table.find({'Date':{'$gte':last.strftime('%Y-%m-%d'), '$lte':td.strftime('%Y-%m-%d')}, "Ticker" :{"$in":list(info_data.keys())}}))
        df = pd.DataFrame(data)
        if len(df.Date.unique()) <= 1:
            data = list(table.find({'Date':{'$gte':(td+timedelta(-30)).strftime('%Y-%m-%d'), '$lte':td.strftime('%Y-%m-%d')}, "Ticker" :{"$in":list(info_data.keys())}}))
            df = pd.DataFrame(data)
            df = df[df.Date.isin(sorted(df.Date.unique())[-2:])]

        StrongTickers = []
        for ticker in list(info_data.keys()):
            try:
                temp_df = df[df.Ticker==ticker]
                uplimit = getLimit(temp_df.Close.iloc[-2], tp_ratio)
                dnlimit = getLimit(temp_df.Close.iloc[-2], sl_ratio, trend="D")
                temp_df['HighRet'] = temp_df.High.iloc[-1] / temp_df.Close.iloc[-2] - 1
                temp_df['LowRet'] = temp_df.Low.iloc[-1] / temp_df.Close.iloc[-2] - 1
            #     temp_df['Ret'] = temp_df.Close.iloc[-1] / temp_df.Close.iloc[-2] - 1
            #     temp_df['OpenRet'] = temp_df.Open.iloc[-1] / temp_df.Close.iloc[-2] - 1
                if temp_df.High.iloc[-1] >= uplimit and temp_df.Volume.iloc[-2] / 1000 >= 1000: #  and temp_df['LowRet'].iloc[-1] > -.05
                    StrongTickers.append(ticker)
            except:
                pass

        with open(os.path.join(output_path, f'{td.strftime("%Y%m%d")}_StrongTicker.csv'), 'w', encoding='utf-8') as f:
            for ticker in StrongTickers:
                f.writelines(ticker + '\n')

        selected = []
        for ticker in list(info_data.keys()):
        #     print(ticker)
            try:
                tmp_data = list(table.find({'Date':{'$gte':pre_1y.strftime('%Y-%m-%d'), '$lte':last.strftime('%Y-%m-%d')}, "Ticker" :{"$eq":ticker}}))

                tmp_df = pd.DataFrame(tmp_data)
                for col in 'Open,High,Low,Close,Volume'.split(','):
                    tmp_df[col] = tmp_df[col].apply(changedType)

                tmp_df = Calc.MA(tmp_df, [5,10,20])
                tmp_df['Adj V'] = tmp_df.Volume.apply(lambda x: int(x/1000))
                if tmp_df['Adj V'].iloc[-1] < 1000:
                    continue
                tmp_df['VMA5'] = tmp_df['Adj V'].rolling(5).mean()
                tmp_df['VMA10'] = tmp_df['Adj V'].rolling(10).mean()
                tmp_df['VMA20'] = tmp_df['Adj V'].rolling(20).mean()

                tmp_df['VSlope5'] = tmp_df['VMA5'].pct_change()
                tmp_df['VSlope10'] = tmp_df['VMA10'].pct_change()
                tmp_df['VSlope20'] = tmp_df['VMA20'].pct_change()

                tmp_df['Slope5'] = tmp_df['MA5'].pct_change()
                tmp_df['Slope10'] = tmp_df['MA10'].pct_change()
                tmp_df['Slope20'] = tmp_df['MA20'].pct_change()
                tmp_df['HC'] = tmp_df['High'] / tmp_df['Close'].shift(1) - 1
                tmp_df['HCMA'] = tmp_df['HC'].rolling(5).mean()# >= .05
                v_slope_condi = tmp_df.VSlope10.iloc[-1] > 0 and tmp_df.VSlope20.iloc[-1] > 0 and tmp_df.VSlope5.iloc[-1] > 0
                p_slope_condi = tmp_df.Slope10.iloc[-1] > 0 and tmp_df.Slope20.iloc[-1] > 0
                tr_condi = tmp_df['HCMA'].iloc[-1] >= .05
                v_condi = min(tmp_df['VMA5'].iloc[-1], tmp_df['VMA20'].iloc[-1]) >= 5000
                p_condi = tmp_df.Close.iloc[-1] < 500
                pct_condi = tmp_df['Close'].pct_change().iloc[-1] >= .06
#                 k_condi_1 = not ((tmp_df['Close'].iloc[-1] < tmp_df['Open'].iloc[-1] or tmp_df['Close'].pct_change().iloc[-1] < 0) and tmp_df['Adj V'].pct_change().iloc[-1] < 0)
#                 k_condi_2 = not (tmp_df['Close'].iloc[-1] < tmp_df['Open'].iloc[-1] and round(tmp_df['Adj V'].pct_change().iloc[-1],2) >= 1)
#                 k_condi = all([k_condi_1, k_condi_2])
                tmp_tick = Calc.get_minimum_tick(tmp_df.Close.iloc[-1])
                limit_condi = True
                if (tmp_df.Close.iloc[-1] + tmp_tick) / tmp_df.Close.iloc[-2] > 1.1:
                    limit_condi = False
                if (tmp_df.Close.iloc[-1] - tmp_tick) / tmp_df.Close.iloc[-2] < 0.9:
                    limit_condi = False
                if v_slope_condi and p_slope_condi and tr_condi and v_condi and p_condi and limit_condi and pct_condi: #  and k_condi
                    selected.append(ticker)
            except:
                pass
        print(selected, len(selected), '\n')
        if selected:
            ShowProfitable(selected, StrongTickers)
            CalculateBacktestResult(td, df, selected, StrongTickers, tp_ratio, sl_ratio)
        else:
            print("沒有符合條件的標的")
    except KeyboardInterrupt:
        raise KeyboardInterrupt
    except Exception as e:
        print(f"It\'s Holiday {tdStr}, {e}")
        pass

# %%
def ShowProfitable(selected, StrongTickers):
    profitable = list(set(selected).intersection(StrongTickers))
    unprofitable = list(set(selected).difference(StrongTickers))
    
    print('profitable',profitable, len(profitable))
    print('unprofitable',unprofitable, len(unprofitable))

def CalculateBacktestResult(td, df, selected, StrongTickers, tp_ratio=.02, sl_ratio=.05):
    with open(os.path.join(output_path, f'{td.strftime("%Y%m%d")}_ProfitLoss.csv'), 'w', encoding='utf-8') as f:
        f.writelines('Ticker,P/L,OpenRet,HighRet,LowRet,CloseRet,pnl\n')#,TakeProfit,StopLoss
        print('Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss\n')
        total_pnl = 0
        num_win = 0
        total_trade_value = 0
        for ticker in selected:
            pnl = 'profit' if ticker in StrongTickers else 'loss'
            temp_df = df[df.Ticker==ticker]
            uplimit = getLimit(temp_df.Close.iloc[-2], tp_ratio)
            upRet = (uplimit / temp_df.Close.iloc[-2] - 1) * 100
            dnlimit = getLimit(temp_df.Close.iloc[-2], sl_ratio, trend="D")
            dnRet = (dnlimit / temp_df.Close.iloc[-2] - 1) * 100
            
            temp_df['HighRet'] = (temp_df.High.iloc[-1] / temp_df.Close.iloc[-2] - 1) * 100
            temp_df['Ret'] = (temp_df.Close.iloc[-1] / temp_df.Close.iloc[-2] - 1) * 100
            temp_df['LowRet'] = (temp_df.Low.iloc[-1] / temp_df.Close.iloc[-2] - 1) * 100
            temp_df['OpenRet'] = (temp_df.Open.iloc[-1] / temp_df.Close.iloc[-2] - 1) * 100
            
            earning = 0
            exit = 0
            if temp_df['Open'].iloc[-1] >= uplimit:
                exit = temp_df['Open'].iloc[-1]
            elif temp_df['Low'].iloc[-1] >= uplimit:
                exit = temp_df['Low'].iloc[-1]
            elif temp_df['High'].iloc[-1] >= uplimit:
                exit = uplimit
            if exit:
                num_win += 1
                
            if not exit:
                if temp_df['Open'].iloc[-1] <= dnlimit:
                    exit = temp_df['Open'].iloc[-1]
                elif temp_df['High'].iloc[-1] <= dnlimit:
                    exit = temp_df['High'].iloc[-1]
                elif temp_df['Low'].iloc[-1] <= dnlimit:
                    exit = dnlimit # temp_df.Close.iloc[-2] * (1 - .05)
                else:
                    exit = temp_df['Close'].iloc[-1]
            print(f"{ticker}, take profit price :{uplimit}, stop loss price:{dnlimit}, entry : {temp_df.Close.iloc[-2]}. exit : {exit}")

            earning = int((exit - temp_df.Close.iloc[-2]) * 1000)
            earning -= round(temp_df.Close.iloc[-2] * 1.425)
            earning -= round(exit * 4.425)
            total_pnl += earning 
            total_trade_value += temp_df.Close.iloc[-2] * 1000
            text = f"{ticker},{pnl},{round(temp_df['OpenRet'].iloc[-1], 2)}%,{round(temp_df['HighRet'].iloc[-1], 2)}%,{round(temp_df['LowRet'].iloc[-1], 2)}%,{round(temp_df['Ret'].iloc[-1], 2)}%,{earning}\n"
#             text = f"{ticker},{pnl},{round(temp_df['Open'].iloc[-1], 2)},{round(temp_df['High'].iloc[-1], 2)},{round(temp_df['Low'].iloc[-1], 2)},{round(temp_df['Close'].iloc[-1], 2)},{earning},{uplimit},{dnlimit}\n"
            f.writelines(text)
            text = f"{ticker},{pnl},{temp_df['Open'].iloc[-1]},{temp_df['High'].iloc[-1]},{temp_df['Close'].iloc[-1]},{temp_df['Low'].iloc[-1]},{earning},{uplimit},{dnlimit}\n"
            print(text)
        total_ret = round((total_pnl / total_trade_value) * 100, 2)
        win_probability = round(num_win / len(selected)*100, 2)
        f.writelines(f"total,{win_probability}%,,,,{total_ret}%,{total_pnl},{total_trade_value}\n")
        print(f"total,{win_probability}%,,,{total_ret}%,,{total_pnl},{total_trade_value}\n")

# %%
# for date in pd.date_range(datetime(2021, 7, 1), datetime.today()):
for date in pd.date_range(datetime(2018, 1, 1), datetime(2019,12,31)):# datetime(2020,12,31)
    try:
        BacktestCrossDayTradeV2(date, .02, .025)
    except KeyboardInterrupt:
        break
# Out:
# 2018-01-01 18:00:00
# =============Start Backtest 2018-01-01==================
# It's Holiday 2018-01-01
# 2018-01-02 18:00:00
# =============Start Backtest 2018-01-02==================
# [] 0
#
# 沒有符合條件的標的
# 2018-01-03 18:00:00
# =============Start Backtest 2018-01-03==================
# ['2481', '1785'] 2
#
# profitable ['2481', '1785'] 2
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2481,profit,32.8,34.4,33.55,32.7,408,33.0,31.6
#
# 1785,profit,24.0,24.45,24.0,23.4,711,23.6,22.6
#
# total,100.0%,,,2.01%,,1119,55550.0
#
# 2018-01-04 18:00:00
# =============Start Backtest 2018-01-04==================
# [] 0
#
# 沒有符合條件的標的
# 2018-01-05 18:00:00
# =============Start Backtest 2018-01-05==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-01-06
# It's Holiday 2018-01-07
# 2018-01-08 18:00:00
# =============Start Backtest 2018-01-08==================
# ['4906'] 1
#
# profitable ['4906'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 4906,profit,31.6,32.5,30.6,30.5,415,31.8,30.45
#
# total,100.0%,,,1.33%,,415,31200.0
#
# 2018-01-09 18:00:00
# =============Start Backtest 2018-01-09==================
# [] 0
#
# 沒有符合條件的標的
# 2018-01-10 18:00:00
# =============Start Backtest 2018-01-10==================
# [] 0
#
# 沒有符合條件的標的
# 2018-01-11 18:00:00
# =============Start Backtest 2018-01-11==================
# ['2371'] 1
#
# profitable ['2371'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2371,profit,23.75,24.1,23.55,23.3,309,24.05,23.05
#
# total,100.0%,,,1.31%,,309,23600.0
#
# 2018-01-12 18:00:00
# =============Start Backtest 2018-01-12==================
# ['3026'] 1
#
# profitable [] 0
# unprofitable ['3026'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3026,loss,130.0,131.0,124.0,123.0,-3747,132.5,127.0
#
# total,0.0%,,,-2.88%,,-3747,130000.0
#
# It's Holiday 2018-01-13
# It's Holiday 2018-01-14
# 2018-01-15 18:00:00
# =============Start Backtest 2018-01-15==================
# [] 0
#
# 沒有符合條件的標的
# 2018-01-16 18:00:00
# =============Start Backtest 2018-01-16==================
# [] 0
#
# 沒有符合條件的標的
# 2018-01-17 18:00:00
# =============Start Backtest 2018-01-17==================
# ['2371', '3645'] 2
#
# profitable ['3645', '2371'] 2
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2371,profit,27.25,28.25,27.35,26.8,338,27.9,26.75
#
# 3645,profit,96.1,100.0,97.6,95.7,1331,97.7,93.5
#
# total,100.0%,,,1.35%,,1669,123200.0
#
# 2018-01-18 18:00:00
# =============Start Backtest 2018-01-18==================
# [] 0
#
# 沒有符合條件的標的
# 2018-01-19 18:00:00
# =============Start Backtest 2018-01-19==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-01-20
# It's Holiday 2018-01-21
# 2018-01-22 18:00:00
# =============Start Backtest 2018-01-22==================
# [] 0
#
# 沒有符合條件的標的
# 2018-01-23 18:00:00
# =============Start Backtest 2018-01-23==================
# [] 0
#
# 沒有符合條件的標的
# 2018-01-24 18:00:00
# =============Start Backtest 2018-01-24==================
# [] 0
#
# 沒有符合條件的標的
# 2018-01-25 18:00:00
# =============Start Backtest 2018-01-25==================
# [] 0
#
# 沒有符合條件的標的
# 2018-01-26 18:00:00
# =============Start Backtest 2018-01-26==================
# ['6215'] 1
#
# profitable ['6215'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 6215,profit,28.0,29.8,28.8,27.3,384,28.55,27.35
#
# total,100.0%,,,1.37%,,384,28000.0
#
# It's Holiday 2018-01-27
# It's Holiday 2018-01-28
# 2018-01-29 18:00:00
# =============Start Backtest 2018-01-29==================
# [] 0
#
# 沒有符合條件的標的
# 2018-01-30 18:00:00
# =============Start Backtest 2018-01-30==================
# ['2376', '3019', '3035', '3661'] 4
#
# profitable [] 0
# unprofitable ['3661', '3035', '2376', '3019'] 4
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2376,loss,74.3,74.3,74.2,72.5,-2230,76.5,73.2
#
# 3019,loss,124.0,125.0,123.0,120.5,-3712,126.0,121.0
#
# 3035,loss,81.9,82.5,79.8,79.4,-2476,84.4,80.8
#
# 3661,loss,128.0,131.0,122.5,121.0,-3742,131.5,126.0
#
# total,0.0%,,,-2.96%,,-12160,410800.0
#
# 2018-01-31 18:00:00
# =============Start Backtest 2018-01-31==================
# [] 0
#
# 沒有符合條件的標的
# 2018-02-01 18:00:00
# =============Start Backtest 2018-02-01==================
# ['3037'] 1
#
# profitable ['3037'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3037,profit,21.4,21.65,21.1,20.85,274,21.6,20.7
#
# total,100.0%,,,1.29%,,274,21200.0
#
# 2018-02-02 18:00:00
# =============Start Backtest 2018-02-02==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-02-03
# It's Holiday 2018-02-04
# 2018-02-05 18:00:00
# =============Start Backtest 2018-02-05==================
# [] 0
#
# 沒有符合條件的標的
# 2018-02-06 18:00:00
# =============Start Backtest 2018-02-06==================
# [] 0
#
# 沒有符合條件的標的
# 2018-02-07 18:00:00
# =============Start Backtest 2018-02-07==================
# [] 0
#
# 沒有符合條件的標的
# 2018-02-08 18:00:00
# =============Start Backtest 2018-02-08==================
# [] 0
#
# 沒有符合條件的標的
# 2018-02-09 18:00:00
# =============Start Backtest 2018-02-09==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-02-10
# It's Holiday 2018-02-11
# 2018-02-12 18:00:00
# =============Start Backtest 2018-02-12==================
# [] 0
#
# 沒有符合條件的標的
# 2018-02-13 18:00:00
# =============Start Backtest 2018-02-13==================
# It's Holiday 2018-02-13
# 2018-02-14 18:00:00
# =============Start Backtest 2018-02-14==================
# It's Holiday 2018-02-14
# 2018-02-15 18:00:00
# =============Start Backtest 2018-02-15==================
# It's Holiday 2018-02-15
# 2018-02-16 18:00:00
# =============Start Backtest 2018-02-16==================
# It's Holiday 2018-02-16
# It's Holiday 2018-02-17
# It's Holiday 2018-02-18
# 2018-02-19 18:00:00
# =============Start Backtest 2018-02-19==================
# It's Holiday 2018-02-19
# 2018-02-20 18:00:00
# =============Start Backtest 2018-02-20==================
# It's Holiday 2018-02-20
# 2018-02-21 18:00:00
# =============Start Backtest 2018-02-21==================
# [] 0
#
# 沒有符合條件的標的
# 2018-02-22 18:00:00
# =============Start Backtest 2018-02-22==================
# ['3532'] 1
#
# profitable [] 0
# unprofitable ['3532'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3532,loss,135.0,137.5,134.0,133.5,-2286,138.0,132.5
#
# total,0.0%,,,-1.69%,,-2286,135500.0
#
# 2018-02-23 18:00:00
# =============Start Backtest 2018-02-23==================
# ['2388', '4739'] 2
#
# profitable ['4739', '2388'] 2
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2388,profit,20.5,21.3,18.65,18.6,277,21.0,20.1
#
# 4739,profit,138.5,144.5,134.5,134.5,4197,136.0,130.5
#
# total,100.0%,,,2.9%,,4474,154100.0
#
# It's Holiday 2018-02-24
# It's Holiday 2018-02-25
# 2018-02-26 18:00:00
# =============Start Backtest 2018-02-26==================
# [] 0
#
# 沒有符合條件的標的
# 2018-02-27 18:00:00
# =============Start Backtest 2018-02-27==================
# [] 0
#
# 沒有符合條件的標的
# 2018-02-28 18:00:00
# =============Start Backtest 2018-02-28==================
# It's Holiday 2018-02-28
# 2018-03-01 18:00:00
# =============Start Backtest 2018-03-01==================
# [] 0
#
# 沒有符合條件的標的
# 2018-03-02 18:00:00
# =============Start Backtest 2018-03-02==================
# ['4739'] 1
#
# profitable [] 0
# unprofitable ['4739'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 4739,loss,136.5,140.0,139.0,135.0,-5305,143.5,137.5
#
# total,0.0%,,,-3.76%,,-5305,141000.0
#
# It's Holiday 2018-03-03
# It's Holiday 2018-03-04
# 2018-03-05 18:00:00
# =============Start Backtest 2018-03-05==================
# [] 0
#
# 沒有符合條件的標的
# 2018-03-06 18:00:00
# =============Start Backtest 2018-03-06==================
# [] 0
#
# 沒有符合條件的標的
# 2018-03-07 18:00:00
# =============Start Backtest 2018-03-07==================
# ['1785'] 1
#
# profitable ['1785'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 1785,profit,25.15,26.15,24.1,24.05,300,25.45,24.4
#
# total,100.0%,,,1.2%,,300,25000.0
#
# 2018-03-08 18:00:00
# =============Start Backtest 2018-03-08==================
# [] 0
#
# 沒有符合條件的標的
# 2018-03-09 18:00:00
# =============Start Backtest 2018-03-09==================
# ['1785'] 1
#
# profitable [] 0
# unprofitable ['1785'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 1785,loss,25.6,25.9,25.25,24.8,-746,26.05,24.95
#
# total,0.0%,,,-2.92%,,-746,25550.0
#
# It's Holiday 2018-03-10
# It's Holiday 2018-03-11
# 2018-03-12 18:00:00
# =============Start Backtest 2018-03-12==================
# [] 0
#
# 沒有符合條件的標的
# 2018-03-13 18:00:00
# =============Start Backtest 2018-03-13==================
# [] 0
#
# 沒有符合條件的標的
# 2018-03-14 18:00:00
# =============Start Backtest 2018-03-14==================
# [] 0
#
# 沒有符合條件的標的
# 2018-03-15 18:00:00
# =============Start Backtest 2018-03-15==================
# [] 0
#
# 沒有符合條件的標的
# 2018-03-16 18:00:00
# =============Start Backtest 2018-03-16==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-03-17
# It's Holiday 2018-03-18
# 2018-03-19 18:00:00
# =============Start Backtest 2018-03-19==================
# [] 0
#
# 沒有符合條件的標的
# 2018-03-20 18:00:00
# =============Start Backtest 2018-03-20==================
# [] 0
#
# 沒有符合條件的標的
# 2018-03-21 18:00:00
# =============Start Backtest 2018-03-21==================
# [] 0
#
# 沒有符合條件的標的
# 2018-03-22 18:00:00
# =============Start Backtest 2018-03-22==================
# [] 0
#
# 沒有符合條件的標的
# 2018-03-23 18:00:00
# =============Start Backtest 2018-03-23==================
# ['2492'] 1
#
# profitable [] 0
# unprofitable ['2492'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2492,loss,115.0,119.5,112.5,112.0,-5179,121.5,117.0
#
# total,0.0%,,,-4.33%,,-5179,119500.0
#
# It's Holiday 2018-03-24
# It's Holiday 2018-03-25
# 2018-03-26 18:00:00
# =============Start Backtest 2018-03-26==================
# [] 0
#
# 沒有符合條件的標的
# 2018-03-27 18:00:00
# =============Start Backtest 2018-03-27==================
# [] 0
#
# 沒有符合條件的標的
# 2018-03-28 18:00:00
# =============Start Backtest 2018-03-28==================
# [] 0
#
# 沒有符合條件的標的
# 2018-03-29 18:00:00
# =============Start Backtest 2018-03-29==================
# [] 0
#
# 沒有符合條件的標的
# 2018-03-30 18:00:00
# =============Start Backtest 2018-03-30==================
# ['1609'] 1
#
# profitable ['1609'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 1609,profit,15.8,16.15,15.25,15.0,709,15.25,14.65
#
# total,100.0%,,,4.73%,,709,15000.0
#
# It's Holiday 2018-03-31
# It's Holiday 2018-04-01
# 2018-04-02 18:00:00
# =============Start Backtest 2018-04-02==================
# ['6161'] 1
#
# profitable [] 0
# unprofitable ['6161'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 6161,loss,21.4,21.75,21.05,21.05,-624,21.95,21.05
#
# total,0.0%,,,-2.9%,,-624,21550.0
#
# 2018-04-03 18:00:00
# =============Start Backtest 2018-04-03==================
# [] 0
#
# 沒有符合條件的標的
# 2018-04-04 18:00:00
# =============Start Backtest 2018-04-04==================
# It's Holiday 2018-04-04
# 2018-04-05 18:00:00
# =============Start Backtest 2018-04-05==================
# It's Holiday 2018-04-05
# 2018-04-06 18:00:00
# =============Start Backtest 2018-04-06==================
# It's Holiday 2018-04-06
# It's Holiday 2018-04-07
# It's Holiday 2018-04-08
# 2018-04-09 18:00:00
# =============Start Backtest 2018-04-09==================
# ['1609'] 1
#
# profitable ['1609'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 1609,profit,17.75,18.25,17.9,16.8,947,17.0,16.3
#
# total,100.0%,,,5.67%,,947,16700.0
#
# 2018-04-10 18:00:00
# =============Start Backtest 2018-04-10==================
# ['1609', '2027'] 2
#
# profitable ['2027'] 1
# unprofitable ['1609'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 1609,loss,17.9,17.9,16.15,16.15,-502,18.25,17.5
#
# 2027,profit,32.6,33.5,31.6,31.2,456,33.15,31.7
#
# total,50.0%,,,-0.09%,,-46,50400.0
#
# 2018-04-11 18:00:00
# =============Start Backtest 2018-04-11==================
# [] 0
#
# 沒有符合條件的標的
# 2018-04-12 18:00:00
# =============Start Backtest 2018-04-12==================
# ['2376', '2481'] 2
#
# profitable [] 0
# unprofitable ['2481', '2376'] 2
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2376,loss,73.2,74.0,71.2,70.0,-2219,74.6,71.4
#
# 2481,loss,57.0,57.0,55.9,55.0,-1728,58.4,55.9
#
# total,0.0%,,,-3.02%,,-3947,130500.0
#
# 2018-04-13 18:00:00
# =============Start Backtest 2018-04-13==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-04-14
# It's Holiday 2018-04-15
# 2018-04-16 18:00:00
# =============Start Backtest 2018-04-16==================
# ['2323', '2478', '5483'] 3
#
# profitable ['2478', '2323', '5483'] 3
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2323,profit,6.4,6.87,6.87,6.31,113,6.37,6.1
#
# 2478,profit,50.9,54.8,54.7,49.3,603,50.9,48.75
#
# 5483,profit,130.0,140.5,139.0,128.0,1729,132.5,127.0
#
# total,100.0%,,,1.31%,,2445,186250.0
#
# 2018-04-17 18:00:00
# =============Start Backtest 2018-04-17==================
# ['2478', '3026', '5483'] 3
#
# profitable [] 0
# unprofitable ['2478', '5483', '3026'] 3
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2478,loss,49.85,52.1,49.25,49.25,-5149,55.7,53.4
#
# 3026,loss,151.5,153.0,141.5,141.5,-4364,153.5,147.0
#
# 5483,loss,138.0,139.0,127.5,127.0,-3800,141.5,136.0
#
# total,0.0%,,,-3.87%,,-13313,344200.0
#
# 2018-04-18 18:00:00
# =============Start Backtest 2018-04-18==================
# ['2492'] 1
#
# profitable ['2492'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2492,profit,156.0,169.0,169.0,154.5,2066,160.5,154.0
#
# total,100.0%,,,1.31%,,2066,157500.0
#
# 2018-04-19 18:00:00
# =============Start Backtest 2018-04-19==================
# ['2367', '2492'] 2
#
# profitable ['2492', '2367'] 2
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2367,profit,24.2,24.4,23.45,23.4,359,24.15,23.15
#
# 2492,profit,167.0,185.5,181.0,165.5,1998,172.0,165.0
#
# total,100.0%,,,1.22%,,2357,192700.0
#
# 2018-04-20 18:00:00
# =============Start Backtest 2018-04-20==================
# ['1786', '2492', '3016'] 3
#
# profitable ['1786'] 1
# unprofitable ['2492', '3016'] 2
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 1786,profit,90.0,91.5,84.2,84.2,1168,91.4,87.5
#
# 2492,loss,178.0,184.0,164.0,163.5,-5539,184.5,176.5
#
# 3016,loss,38.35,38.95,37.95,37.5,-1174,39.9,38.2
#
# total,33.33%,,,-1.79%,,-5545,309850.0
#
# It's Holiday 2018-04-21
# It's Holiday 2018-04-22
# 2018-04-23 18:00:00
# =============Start Backtest 2018-04-23==================
# [] 0
#
# 沒有符合條件的標的
# 2018-04-24 18:00:00
# =============Start Backtest 2018-04-24==================
# [] 0
#
# 沒有符合條件的標的
# 2018-04-25 18:00:00
# =============Start Backtest 2018-04-25==================
# [] 0
#
# 沒有符合條件的標的
# 2018-04-26 18:00:00
# =============Start Backtest 2018-04-26==================
# ['2038', '2601', '4306'] 3
#
# profitable ['2601', '2038'] 2
# unprofitable ['4306'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2038,profit,14.4,14.55,13.65,13.3,166,14.55,13.95
#
# 2601,profit,11.3,12.0,11.2,11.0,134,11.3,10.85
#
# 4306,loss,18.4,18.4,16.9,16.75,-555,18.85,18.05
#
# total,66.67%,,,-0.58%,,-255,43900.0
#
# 2018-04-27 18:00:00
# =============Start Backtest 2018-04-27==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-04-28
# It's Holiday 2018-04-29
# 2018-04-30 18:00:00
# =============Start Backtest 2018-04-30==================
# ['2601'] 1
#
# profitable ['2601'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2601,profit,12.4,12.8,12.35,12.0,127,12.45,11.95
#
# total,100.0%,,,1.04%,,127,12250.0
#
# 2018-05-01 18:00:00
# =============Start Backtest 2018-05-01==================
# It's Holiday 2018-05-01
# 2018-05-02 18:00:00
# =============Start Backtest 2018-05-02==================
# [] 0
#
# 沒有符合條件的標的
# 2018-05-03 18:00:00
# =============Start Backtest 2018-05-03==================
# [] 0
#
# 沒有符合條件的標的
# 2018-05-04 18:00:00
# =============Start Backtest 2018-05-04==================
# ['2492'] 1
#
# profitable ['2492'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2492,profit,228.5,236.0,227.0,225.0,3163,229.5,219.5
#
# total,100.0%,,,1.41%,,3163,225000.0
#
# It's Holiday 2018-05-05
# It's Holiday 2018-05-06
# 2018-05-07 18:00:00
# =============Start Backtest 2018-05-07==================
# [] 0
#
# 沒有符合條件的標的
# 2018-05-08 18:00:00
# =============Start Backtest 2018-05-08==================
# ['6153'] 1
#
# profitable ['6153'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 6153,profit,55.0,56.4,53.6,53.6,674,56.0,53.7
#
# total,100.0%,,,1.23%,,674,55000.0
#
# 2018-05-09 18:00:00
# =============Start Backtest 2018-05-09==================
# ['6182'] 1
#
# profitable [] 0
# unprofitable ['6182'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 6182,loss,54.2,54.6,52.5,52.1,-1608,54.8,52.5
#
# total,0.0%,,,-2.99%,,-1608,53800.0
#
# 2018-05-10 18:00:00
# =============Start Backtest 2018-05-10==================
# ['3016'] 1
#
# profitable ['3016'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3016,profit,45.0,46.35,46.2,43.75,1089,44.5,42.6
#
# total,100.0%,,,2.49%,,1089,43650.0
#
# 2018-05-11 18:00:00
# =============Start Backtest 2018-05-11==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-05-12
# It's Holiday 2018-05-13
# 2018-05-14 18:00:00
# =============Start Backtest 2018-05-14==================
# ['2601'] 1
#
# profitable [] 0
# unprofitable ['2601'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2601,loss,13.85,13.95,13.45,13.25,-431,14.3,13.7
#
# total,0.0%,,,-3.07%,,-431,14050.0
#
# 2018-05-15 18:00:00
# =============Start Backtest 2018-05-15==================
# ['3090', '3624'] 2
#
# profitable ['3624', '3090'] 2
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3090,profit,84.1,88.7,85.1,83.0,1810,83.4,79.8
#
# 3624,profit,41.6,42.0,39.1,38.65,1209,40.95,39.15
#
# total,100.0%,,,2.48%,,3019,121950.0
#
# 2018-05-16 18:00:00
# =============Start Backtest 2018-05-16==================
# ['3016', '4306', '6153', '8163'] 4
#
# profitable ['3016', '4306'] 2
# unprofitable ['6153', '8163'] 2
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3016,profit,52.9,59.0,55.6,52.8,681,54.8,52.5
#
# 4306,profit,19.3,19.7,19.55,19.0,237,19.5,18.7
#
# 6153,loss,62.2,62.9,60.4,60.2,-1855,63.0,60.3
#
# 8163,loss,46.8,48.5,47.0,46.15,-1876,49.35,47.2
#
# total,50.0%,,,-1.54%,,-2813,183150.0
#
# 2018-05-17 18:00:00
# =============Start Backtest 2018-05-17==================
# ['6182'] 1
#
# profitable ['6182'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 6182,profit,63.5,65.6,61.2,60.9,1131,63.2,60.5
#
# total,100.0%,,,1.82%,,1131,62000.0
#
# 2018-05-18 18:00:00
# =============Start Backtest 2018-05-18==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-05-19
# It's Holiday 2018-05-20
# 2018-05-21 18:00:00
# =============Start Backtest 2018-05-21==================
# [] 0
#
# 沒有符合條件的標的
# 2018-05-22 18:00:00
# =============Start Backtest 2018-05-22==================
# ['6153'] 1
#
# profitable ['6153'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 6153,profit,66.4,67.3,64.3,64.0,913,66.4,63.5
#
# total,100.0%,,,1.4%,,913,65099.99999999999
#
# 2018-05-23 18:00:00
# =============Start Backtest 2018-05-23==================
# [] 0
#
# 沒有符合條件的標的
# 2018-05-24 18:00:00
# =============Start Backtest 2018-05-24==================
# ['2345', '8163'] 2
#
# profitable ['2345', '8163'] 2
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2345,profit,87.1,87.5,84.8,83.8,1191,87.4,83.6
#
# 8163,profit,54.8,56.0,54.7,53.2,881,54.6,52.3
#
# total,100.0%,,,1.49%,,2072,139300.0
#
# 2018-05-25 18:00:00
# =============Start Backtest 2018-05-25==================
# ['3406', '3624'] 2
#
# profitable ['3624'] 1
# unprofitable ['3406'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3406,loss,462.0,469.5,455.0,452.5,-9671,471.0,450.5
#
# 3624,profit,48.0,50.7,50.7,47.0,1621,47.0,44.95
#
# total,50.0%,,,-1.58%,,-8050,508100.0
#
# It's Holiday 2018-05-26
# It's Holiday 2018-05-27
# 2018-05-28 18:00:00
# =============Start Backtest 2018-05-28==================
# ['2492'] 1
#
# profitable ['2492'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2492,profit,355.0,374.0,373.5,348.0,12945,346.5,331.5
#
# total,100.0%,,,3.81%,,12945,340000.0
#
# 2018-05-29 18:00:00
# =============Start Backtest 2018-05-29==================
# ['2492', '5469', '6173'] 3
#
# profitable ['6173'] 1
# unprofitable ['2492', '5469'] 2
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2492,loss,368.0,375.5,366.5,358.0,-11145,380.5,364.5
#
# 5469,loss,31.6,31.6,30.05,29.75,-932,32.2,30.85
#
# 6173,profit,88.3,91.9,87.5,86.4,1176,90.0,86.1
#
# total,33.33%,,,-2.21%,,-10901,493400.0
#
# 2018-05-30 18:00:00
# =============Start Backtest 2018-05-30==================
# ['3707'] 1
#
# profitable ['3707'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3707,profit,33.9,37.6,37.6,33.9,446,34.85,33.35
#
# total,100.0%,,,1.3%,,446,34200.0
#
# 2018-05-31 18:00:00
# =============Start Backtest 2018-05-31==================
# [] 0
#
# 沒有符合條件的標的
# 2018-06-01 18:00:00
# =============Start Backtest 2018-06-01==================
# ['2323'] 1
#
# profitable ['2323'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2323,profit,10.1,10.35,9.85,9.76,91,10.15,9.75
#
# total,100.0%,,,0.91%,,91,10000.0
#
# It's Holiday 2018-06-02
# It's Holiday 2018-06-03
# 2018-06-04 18:00:00
# =============Start Backtest 2018-06-04==================
# [] 0
#
# 沒有符合條件的標的
# 2018-06-05 18:00:00
# =============Start Backtest 2018-06-05==================
# ['2329', '3050'] 2
#
# profitable ['3050'] 1
# unprofitable ['2329'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2329,loss,11.1,11.1,10.7,10.6,-314,11.35,10.9
#
# 3050,profit,15.8,16.05,14.65,14.6,508,15.5,14.85
#
# total,50.0%,,,0.74%,,194,26350.0
#
# 2018-06-06 18:00:00
# =============Start Backtest 2018-06-06==================
# ['2349', '6127'] 2
#
# profitable ['6127'] 1
# unprofitable ['2349'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2349,loss,18.2,19.4,18.25,18.2,-1359,19.8,19.0
#
# 6127,profit,39.75,41.9,40.0,39.75,518,39.75,38.05
#
# total,50.0%,,,-1.44%,,-841,58450.0
#
# 2018-06-07 18:00:00
# =============Start Backtest 2018-06-07==================
# ['2375'] 1
#
# profitable ['2375'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2375,profit,55.0,56.5,54.0,53.4,676,55.5,53.2
#
# total,100.0%,,,1.24%,,676,54500.0
#
# 2018-06-08 18:00:00
# =============Start Backtest 2018-06-08==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-06-09
# It's Holiday 2018-06-10
# 2018-06-11 18:00:00
# =============Start Backtest 2018-06-11==================
# [] 0
#
# 沒有符合條件的標的
# 2018-06-12 18:00:00
# =============Start Backtest 2018-06-12==================
# ['8076'] 1
#
# profitable ['8076'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 8076,profit,60.0,62.0,58.8,58.4,747,60.6,58.1
#
# total,100.0%,,,1.26%,,747,59500.0
#
# 2018-06-13 18:00:00
# =============Start Backtest 2018-06-13==================
# ['3317'] 1
#
# profitable ['3317'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3317,profit,57.8,59.8,53.2,53.2,962,57.6,55.1
#
# total,100.0%,,,1.7%,,962,56500.0
#
# 2018-06-14 18:00:00
# =============Start Backtest 2018-06-14==================
# ['3406'] 1
#
# profitable [] 0
# unprofitable ['3406'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3406,loss,549.0,552.0,530.0,521.0,-16183,565.0,541.0
#
# total,0.0%,,,-2.92%,,-16183,554000.0
#
# 2018-06-15 18:00:00
# =============Start Backtest 2018-06-15==================
# ['3059', '8261'] 2
#
# profitable ['3059'] 1
# unprofitable ['8261'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3059,profit,44.4,44.6,43.1,42.3,591,44.45,42.55
#
# 8261,loss,58.8,58.8,57.5,56.0,-1846,61.4,58.7
#
# total,50.0%,,,-1.21%,,-1255,103800.0
#
# It's Holiday 2018-06-16
# It's Holiday 2018-06-17
# 2018-06-18 18:00:00
# =============Start Backtest 2018-06-18==================
# It's Holiday 2018-06-18
# 2018-06-19 18:00:00
# =============Start Backtest 2018-06-19==================
# ['2388'] 1
#
# profitable ['2388'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2388,profit,44.0,47.15,47.15,43.45,844,43.75,41.85
#
# total,100.0%,,,1.97%,,844,42900.0
#
# 2018-06-20 18:00:00
# =============Start Backtest 2018-06-20==================
# ['2340', '8163'] 2
#
# profitable ['2340', '8163'] 2
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2340,profit,32.25,33.4,30.4,29.45,408,32.95,31.55
#
# 8163,profit,95.0,95.8,83.9,83.3,1948,94.3,90.2
#
# total,100.0%,,,1.89%,,2356,124850.0
#
# 2018-06-21 18:00:00
# =============Start Backtest 2018-06-21==================
# ['6120'] 1
#
# profitable ['6120'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 6120,profit,29.0,31.75,31.15,28.7,379,29.45,28.2
#
# total,100.0%,,,1.31%,,379,28900.0
#
# 2018-06-22 18:00:00
# =============Start Backtest 2018-06-22==================
# ['2426', '6120'] 2
#
# profitable ['6120', '2426'] 2
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2426,profit,22.7,23.7,23.7,22.0,1018,21.95,21.05
#
# 6120,profit,31.8,33.05,30.0,29.75,465,31.75,30.4
#
# total,100.0%,,,2.81%,,1483,52700.0
#
# It's Holiday 2018-06-23
# It's Holiday 2018-06-24
# 2018-06-25 18:00:00
# =============Start Backtest 2018-06-25==================
# ['6168', '6127'] 2
#
# profitable ['6127', '6168'] 2
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 6168,profit,23.2,24.0,21.5,21.5,464,23.05,22.05
#
# 6127,profit,43.4,45.95,45.95,42.0,1348,42.6,40.8
#
# total,100.0%,,,2.81%,,1812,64400.0
#
# 2018-06-26 18:00:00
# =============Start Backtest 2018-06-26==================
# ['6155'] 1
#
# profitable ['6155'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 6155,profit,44.0,47.4,45.4,43.6,631,46.0,44.0
#
# total,100.0%,,,1.4%,,631,45100.0
#
# 2018-06-27 18:00:00
# =============Start Backtest 2018-06-27==================
# ['2486'] 1
#
# profitable ['2486'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2486,profit,14.95,15.15,14.9,14.15,163,14.95,14.35
#
# total,100.0%,,,1.11%,,163,14700.0
#
# 2018-06-28 18:00:00
# =============Start Backtest 2018-06-28==================
# ['3026', '4944'] 2
#
# profitable ['3026'] 1
# unprofitable ['4944'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3026,profit,247.0,248.5,242.5,237.0,3059,247.5,237.0
#
# 4944,loss,24.4,25.4,23.75,23.75,-1244,26.0,24.9
#
# total,50.0%,,,0.68%,,1815,268500.0
#
# 2018-06-29 18:00:00
# =============Start Backtest 2018-06-29==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-06-30
# It's Holiday 2018-07-01
# 2018-07-02 18:00:00
# =============Start Backtest 2018-07-02==================
# ['3221', '3360'] 2
#
# profitable ['3221'] 1
# unprofitable ['3360'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3221,profit,32.0,33.05,31.15,30.6,413,32.2,30.85
#
# 3360,loss,22.1,22.1,21.2,20.9,-677,22.55,21.6
#
# total,50.0%,,,-0.49%,,-264,53750.0
#
# 2018-07-03 18:00:00
# =============Start Backtest 2018-07-03==================
# ['2375'] 1
#
# profitable ['2375'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2375,profit,92.5,95.5,86.0,85.8,1662,92.1,88.1
#
# total,100.0%,,,1.84%,,1662,90300.0
#
# 2018-07-04 18:00:00
# =============Start Backtest 2018-07-04==================
# ['5328', '5425'] 2
#
# profitable ['5328'] 1
# unprofitable ['5425'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 5328,profit,25.6,26.5,24.8,24.0,350,25.7,24.6
#
# 5425,loss,96.6,97.9,93.3,91.9,-2958,99.1,94.8
#
# total,50.0%,,,-2.13%,,-2608,122400.0
#
# 2018-07-05 18:00:00
# =============Start Backtest 2018-07-05==================
# [] 0
#
# 沒有符合條件的標的
# 2018-07-06 18:00:00
# =============Start Backtest 2018-07-06==================
# ['8043'] 1
#
# profitable [] 0
# unprofitable ['8043'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 8043,loss,95.0,96.0,86.8,86.8,-2953,98.3,94.0
#
# total,0.0%,,,-3.06%,,-2953,96400.0
#
# It's Holiday 2018-07-07
# It's Holiday 2018-07-08
# 2018-07-09 18:00:00
# =============Start Backtest 2018-07-09==================
# [] 0
#
# 沒有符合條件的標的
# 2018-07-10 18:00:00
# =============Start Backtest 2018-07-10==================
# ['3011', '3360'] 2
#
# profitable ['3011'] 1
# unprofitable ['3360'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3011,profit,11.6,12.15,11.85,11.2,128,12.1,11.65
#
# 3360,loss,23.3,23.3,22.0,21.5,-684,23.75,22.75
#
# total,50.0%,,,-1.58%,,-556,35200.0
#
# 2018-07-11 18:00:00
# =============Start Backtest 2018-07-11==================
# [] 0
#
# 沒有符合條件的標的
# 2018-07-12 18:00:00
# =============Start Backtest 2018-07-12==================
# [] 0
#
# 沒有符合條件的標的
# 2018-07-13 18:00:00
# =============Start Backtest 2018-07-13==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-07-14
# It's Holiday 2018-07-15
# 2018-07-16 18:00:00
# =============Start Backtest 2018-07-16==================
# ['2349', '2371'] 2
#
# profitable ['2349', '2371'] 2
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2349,profit,16.65,17.2,16.15,16.1,201,17.05,16.35
#
# 2371,profit,36.05,37.35,36.9,35.3,540,36.0,34.45
#
# total,100.0%,,,1.42%,,741,52050.0
#
# 2018-07-17 18:00:00
# =============Start Backtest 2018-07-17==================
# [] 0
#
# 沒有符合條件的標的
# 2018-07-18 18:00:00
# =============Start Backtest 2018-07-18==================
# [] 0
#
# 沒有符合條件的標的
# 2018-07-19 18:00:00
# =============Start Backtest 2018-07-19==================
# [] 0
#
# 沒有符合條件的標的
# 2018-07-20 18:00:00
# =============Start Backtest 2018-07-20==================
# ['2371'] 1
#
# profitable [] 0
# unprofitable ['2371'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2371,loss,39.25,39.35,37.85,36.65,-1175,39.85,38.15
#
# total,0.0%,,,-3.01%,,-1175,39100.0
#
# It's Holiday 2018-07-21
# It's Holiday 2018-07-22
# 2018-07-23 18:00:00
# =============Start Backtest 2018-07-23==================
# [] 0
#
# 沒有符合條件的標的
# 2018-07-24 18:00:00
# =============Start Backtest 2018-07-24==================
# [] 0
#
# 沒有符合條件的標的
# 2018-07-25 18:00:00
# =============Start Backtest 2018-07-25==================
# [] 0
#
# 沒有符合條件的標的
# 2018-07-26 18:00:00
# =============Start Backtest 2018-07-26==================
# [] 0
#
# 沒有符合條件的標的
# 2018-07-27 18:00:00
# =============Start Backtest 2018-07-27==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-07-28
# It's Holiday 2018-07-29
# 2018-07-30 18:00:00
# =============Start Backtest 2018-07-30==================
# [] 0
#
# 沒有符合條件的標的
# 2018-07-31 18:00:00
# =============Start Backtest 2018-07-31==================
# [] 0
#
# 沒有符合條件的標的
# 2018-08-01 18:00:00
# =============Start Backtest 2018-08-01==================
# [] 0
#
# 沒有符合條件的標的
# 2018-08-02 18:00:00
# =============Start Backtest 2018-08-02==================
# [] 0
#
# 沒有符合條件的標的
# 2018-08-03 18:00:00
# =============Start Backtest 2018-08-03==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-08-04
# It's Holiday 2018-08-05
# 2018-08-06 18:00:00
# =============Start Backtest 2018-08-06==================
# [] 0
#
# 沒有符合條件的標的
# 2018-08-07 18:00:00
# =============Start Backtest 2018-08-07==================
# [] 0
#
# 沒有符合條件的標的
# 2018-08-08 18:00:00
# =============Start Backtest 2018-08-08==================
# [] 0
#
# 沒有符合條件的標的
# 2018-08-09 18:00:00
# =============Start Backtest 2018-08-09==================
# [] 0
#
# 沒有符合條件的標的
# 2018-08-10 18:00:00
# =============Start Backtest 2018-08-10==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-08-11
# It's Holiday 2018-08-12
# 2018-08-13 18:00:00
# =============Start Backtest 2018-08-13==================
# [] 0
#
# 沒有符合條件的標的
# 2018-08-14 18:00:00
# =============Start Backtest 2018-08-14==================
# [] 0
#
# 沒有符合條件的標的
# 2018-08-15 18:00:00
# =============Start Backtest 2018-08-15==================
# [] 0
#
# 沒有符合條件的標的
# 2018-08-16 18:00:00
# =============Start Backtest 2018-08-16==================
# ['2368'] 1
#
# profitable ['2368'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2368,profit,12.2,13.05,13.0,12.0,128,12.4,11.9
#
# total,100.0%,,,1.05%,,128,12200.0
#
# 2018-08-17 18:00:00
# =============Start Backtest 2018-08-17==================
# ['2368'] 1
#
# profitable ['2368'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2368,profit,13.4,14.3,14.3,13.4,322,13.25,12.7
#
# total,100.0%,,,2.48%,,322,13000.0
#
# It's Holiday 2018-08-18
# It's Holiday 2018-08-19
# 2018-08-20 18:00:00
# =============Start Backtest 2018-08-20==================
# [] 0
#
# 沒有符合條件的標的
# 2018-08-21 18:00:00
# =============Start Backtest 2018-08-21==================
# [] 0
#
# 沒有符合條件的標的
# 2018-08-22 18:00:00
# =============Start Backtest 2018-08-22==================
# ['2368'] 1
#
# profitable [] 0
# unprofitable ['2368'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2368,loss,15.0,15.55,15.05,14.7,-438,15.6,14.95
#
# total,0.0%,,,-2.86%,,-438,15300.0
#
# 2018-08-23 18:00:00
# =============Start Backtest 2018-08-23==================
# [] 0
#
# 沒有符合條件的標的
# 2018-08-24 18:00:00
# =============Start Backtest 2018-08-24==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-08-25
# It's Holiday 2018-08-26
# 2018-08-27 18:00:00
# =============Start Backtest 2018-08-27==================
# [] 0
#
# 沒有符合條件的標的
# 2018-08-28 18:00:00
# =============Start Backtest 2018-08-28==================
# [] 0
#
# 沒有符合條件的標的
# 2018-08-29 18:00:00
# =============Start Backtest 2018-08-29==================
# [] 0
#
# 沒有符合條件的標的
# 2018-08-30 18:00:00
# =============Start Backtest 2018-08-30==================
# [] 0
#
# 沒有符合條件的標的
# 2018-08-31 18:00:00
# =============Start Backtest 2018-08-31==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-09-01
# It's Holiday 2018-09-02
# 2018-09-03 18:00:00
# =============Start Backtest 2018-09-03==================
# [] 0
#
# 沒有符合條件的標的
# 2018-09-04 18:00:00
# =============Start Backtest 2018-09-04==================
# [] 0
#
# 沒有符合條件的標的
# 2018-09-05 18:00:00
# =============Start Backtest 2018-09-05==================
# [] 0
#
# 沒有符合條件的標的
# 2018-09-06 18:00:00
# =============Start Backtest 2018-09-06==================
# [] 0
#
# 沒有符合條件的標的
# 2018-09-07 18:00:00
# =============Start Backtest 2018-09-07==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-09-08
# It's Holiday 2018-09-09
# 2018-09-10 18:00:00
# =============Start Backtest 2018-09-10==================
# [] 0
#
# 沒有符合條件的標的
# 2018-09-11 18:00:00
# =============Start Backtest 2018-09-11==================
# [] 0
#
# 沒有符合條件的標的
# 2018-09-12 18:00:00
# =============Start Backtest 2018-09-12==================
# [] 0
#
# 沒有符合條件的標的
# 2018-09-13 18:00:00
# =============Start Backtest 2018-09-13==================
# ['9958'] 1
#
# profitable ['9958'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 9958,profit,86.3,86.7,83.1,83.1,1195,86.7,82.9
#
# total,100.0%,,,1.41%,,1195,85000.0
#
# 2018-09-14 18:00:00
# =============Start Backtest 2018-09-14==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-09-15
# It's Holiday 2018-09-16
# 2018-09-17 18:00:00
# =============Start Backtest 2018-09-17==================
# [] 0
#
# 沒有符合條件的標的
# 2018-09-18 18:00:00
# =============Start Backtest 2018-09-18==================
# ['4426'] 1
#
# profitable ['4426'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 4426,profit,53.0,54.7,51.9,51.7,685,54.0,51.7
#
# total,100.0%,,,1.29%,,685,53000.0
#
# 2018-09-19 18:00:00
# =============Start Backtest 2018-09-19==================
# [] 0
#
# 沒有符合條件的標的
# 2018-09-20 18:00:00
# =============Start Backtest 2018-09-20==================
# ['2406'] 1
#
# profitable [] 0
# unprofitable ['2406'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2406,loss,10.7,10.9,10.35,10.3,-313,11.1,10.65
#
# total,0.0%,,,-2.87%,,-313,10900.0
#
# 2018-09-21 18:00:00
# =============Start Backtest 2018-09-21==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-09-22
# It's Holiday 2018-09-23
# 2018-09-24 18:00:00
# =============Start Backtest 2018-09-24==================
# It's Holiday 2018-09-24
# 2018-09-25 18:00:00
# =============Start Backtest 2018-09-25==================
# ['2349'] 1
#
# profitable ['2349'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2349,profit,14.5,15.15,14.5,14.35,162,15.15,14.55
#
# total,100.0%,,,1.09%,,162,14900.0
#
# 2018-09-26 18:00:00
# =============Start Backtest 2018-09-26==================
# ['2031'] 1
#
# profitable [] 0
# unprofitable ['2031'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2031,loss,46.4,47.25,46.9,45.35,226,47.3,45.25
#
# total,0.0%,,,0.49%,,226,46400.0
#
# 2018-09-27 18:00:00
# =============Start Backtest 2018-09-27==================
# ['9958'] 1
#
# profitable [] 0
# unprofitable ['9958'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 9958,loss,97.2,99.9,99.0,96.1,-3371,102.0,97.5
#
# total,0.0%,,,-3.37%,,-3371,100000.0
#
# 2018-09-28 18:00:00
# =============Start Backtest 2018-09-28==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-09-29
# It's Holiday 2018-09-30
# 2018-10-01 18:00:00
# =============Start Backtest 2018-10-01==================
# ['2442'] 1
#
# profitable ['2442'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2442,profit,15.4,16.0,16.0,15.1,208,15.8,15.15
#
# total,100.0%,,,1.34%,,208,15500.0
#
# 2018-10-02 18:00:00
# =============Start Backtest 2018-10-02==================
# [] 0
#
# 沒有符合條件的標的
# 2018-10-03 18:00:00
# =============Start Backtest 2018-10-03==================
# ['2329'] 1
#
# profitable [] 0
# unprofitable ['2329'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2329,loss,12.6,12.6,12.0,11.8,-372,12.7,12.2
#
# total,0.0%,,,-2.98%,,-372,12500.0
#
# 2018-10-04 18:00:00
# =============Start Backtest 2018-10-04==================
# [] 0
#
# 沒有符合條件的標的
# 2018-10-05 18:00:00
# =============Start Backtest 2018-10-05==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-10-06
# It's Holiday 2018-10-07
# 2018-10-08 18:00:00
# =============Start Backtest 2018-10-08==================
# [] 0
#
# 沒有符合條件的標的
# 2018-10-09 18:00:00
# =============Start Backtest 2018-10-09==================
# [] 0
#
# 沒有符合條件的標的
# 2018-10-10 18:00:00
# =============Start Backtest 2018-10-10==================
# It's Holiday 2018-10-10
# 2018-10-11 18:00:00
# =============Start Backtest 2018-10-11==================
# [] 0
#
# 沒有符合條件的標的
# 2018-10-12 18:00:00
# =============Start Backtest 2018-10-12==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-10-13
# It's Holiday 2018-10-14
# 2018-10-15 18:00:00
# =============Start Backtest 2018-10-15==================
# [] 0
#
# 沒有符合條件的標的
# 2018-10-16 18:00:00
# =============Start Backtest 2018-10-16==================
# [] 0
#
# 沒有符合條件的標的
# 2018-10-17 18:00:00
# =============Start Backtest 2018-10-17==================
# [] 0
#
# 沒有符合條件的標的
# 2018-10-18 18:00:00
# =============Start Backtest 2018-10-18==================
# [] 0
#
# 沒有符合條件的標的
# 2018-10-19 18:00:00
# =============Start Backtest 2018-10-19==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-10-20
# It's Holiday 2018-10-21
# 2018-10-22 18:00:00
# =============Start Backtest 2018-10-22==================
# [] 0
#
# 沒有符合條件的標的
# 2018-10-23 18:00:00
# =============Start Backtest 2018-10-23==================
# [] 0
#
# 沒有符合條件的標的
# 2018-10-24 18:00:00
# =============Start Backtest 2018-10-24==================
# [] 0
#
# 沒有符合條件的標的
# 2018-10-25 18:00:00
# =============Start Backtest 2018-10-25==================
# [] 0
#
# 沒有符合條件的標的
# 2018-10-26 18:00:00
# =============Start Backtest 2018-10-26==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-10-27
# It's Holiday 2018-10-28
# 2018-10-29 18:00:00
# =============Start Backtest 2018-10-29==================
# [] 0
#
# 沒有符合條件的標的
# 2018-10-30 18:00:00
# =============Start Backtest 2018-10-30==================
# [] 0
#
# 沒有符合條件的標的
# 2018-10-31 18:00:00
# =============Start Backtest 2018-10-31==================
# [] 0
#
# 沒有符合條件的標的
# 2018-11-01 18:00:00
# =============Start Backtest 2018-11-01==================
# [] 0
#
# 沒有符合條件的標的
# 2018-11-02 18:00:00
# =============Start Backtest 2018-11-02==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-11-03
# It's Holiday 2018-11-04
# 2018-11-05 18:00:00
# =============Start Backtest 2018-11-05==================
# [] 0
#
# 沒有符合條件的標的
# 2018-11-06 18:00:00
# =============Start Backtest 2018-11-06==================
# [] 0
#
# 沒有符合條件的標的
# 2018-11-07 18:00:00
# =============Start Backtest 2018-11-07==================
# [] 0
#
# 沒有符合條件的標的
# 2018-11-08 18:00:00
# =============Start Backtest 2018-11-08==================
# ['2481'] 1
#
# profitable ['2481'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2481,profit,26.5,26.55,24.65,24.6,545,26.3,25.2
#
# total,100.0%,,,2.11%,,545,25800.0
#
# 2018-11-09 18:00:00
# =============Start Backtest 2018-11-09==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-11-10
# It's Holiday 2018-11-11
# 2018-11-12 18:00:00
# =============Start Backtest 2018-11-12==================
# [] 0
#
# 沒有符合條件的標的
# 2018-11-13 18:00:00
# =============Start Backtest 2018-11-13==================
# [] 0
#
# 沒有符合條件的標的
# 2018-11-14 18:00:00
# =============Start Backtest 2018-11-14==================
# [] 0
#
# 沒有符合條件的標的
# 2018-11-15 18:00:00
# =============Start Backtest 2018-11-15==================
# [] 0
#
# 沒有符合條件的標的
# 2018-11-16 18:00:00
# =============Start Backtest 2018-11-16==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-11-17
# It's Holiday 2018-11-18
# 2018-11-19 18:00:00
# =============Start Backtest 2018-11-19==================
# [] 0
#
# 沒有符合條件的標的
# 2018-11-20 18:00:00
# =============Start Backtest 2018-11-20==================
# [] 0
#
# 沒有符合條件的標的
# 2018-11-21 18:00:00
# =============Start Backtest 2018-11-21==================
# [] 0
#
# 沒有符合條件的標的
# 2018-11-22 18:00:00
# =============Start Backtest 2018-11-22==================
# [] 0
#
# 沒有符合條件的標的
# 2018-11-23 18:00:00
# =============Start Backtest 2018-11-23==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-11-24
# It's Holiday 2018-11-25
# 2018-11-26 18:00:00
# =============Start Backtest 2018-11-26==================
# ['3016'] 1
#
# profitable ['3016'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3016,profit,43.75,45.15,44.0,43.2,591,44.6,42.7
#
# total,100.0%,,,1.35%,,591,43750.0
#
# 2018-11-27 18:00:00
# =============Start Backtest 2018-11-27==================
# [] 0
#
# 沒有符合條件的標的
# 2018-11-28 18:00:00
# =============Start Backtest 2018-11-28==================
# ['2455', '3105'] 2
#
# profitable ['2455', '3105'] 2
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2455,profit,60.0,62.2,60.9,60.0,744,61.1,58.6
#
# 3105,profit,119.5,121.5,120.5,118.0,1295,121.0,116.5
#
# total,100.0%,,,1.14%,,2039,179000.0
#
# 2018-11-29 18:00:00
# =============Start Backtest 2018-11-29==================
# ['6244'] 1
#
# profitable [] 0
# unprofitable ['6244'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 6244,loss,9.19,9.36,9.18,9.08,-63,9.37,8.97
#
# total,0.0%,,,-0.69%,,-63,9190.0
#
# 2018-11-30 18:00:00
# =============Start Backtest 2018-11-30==================
# ['5483'] 1
#
# profitable [] 0
# unprofitable ['5483'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 5483,loss,85.8,85.8,84.5,83.6,-2591,87.5,83.7
#
# total,0.0%,,,-3.02%,,-2591,85800.0
#
# It's Holiday 2018-12-01
# It's Holiday 2018-12-02
# 2018-12-03 18:00:00
# =============Start Backtest 2018-12-03==================
# [] 0
#
# 沒有符合條件的標的
# 2018-12-04 18:00:00
# =============Start Backtest 2018-12-04==================
# ['3037', '3406', '3105', '5425', '6462'] 5
#
# profitable ['6462'] 1
# unprofitable ['3037', '5425', '3105', '3406'] 4
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3037,loss,22.5,23.1,22.55,21.95,-680,23.2,22.2
#
# 3406,loss,239.5,239.5,225.0,224.0,-6876,244.0,234.0
#
# 3105,loss,139.0,139.0,131.0,131.0,-3788,139.5,134.0
#
# 5425,loss,61.3,61.3,58.9,58.5,-1849,62.0,59.3
#
# 6462,profit,176.5,187.5,186.5,174.5,2452,180.0,172.5
#
# total,20.0%,,,-1.69%,,-10741,636550.0
#
# 2018-12-05 18:00:00
# =============Start Backtest 2018-12-05==================
# [] 0
#
# 沒有符合條件的標的
# 2018-12-06 18:00:00
# =============Start Backtest 2018-12-06==================
# ['2375'] 1
#
# profitable [] 0
# unprofitable ['2375'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2375,loss,37.75,37.9,34.5,34.05,-1116,38.55,36.9
#
# total,0.0%,,,-2.95%,,-1116,37800.0
#
# 2018-12-07 18:00:00
# =============Start Backtest 2018-12-07==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-12-08
# It's Holiday 2018-12-09
# 2018-12-10 18:00:00
# =============Start Backtest 2018-12-10==================
# ['1515', '6462'] 2
#
# profitable ['6462'] 1
# unprofitable ['1515'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 1515,loss,67.9,70.1,69.7,67.0,-2096,70.3,67.3
#
# 6462,profit,177.0,192.5,179.0,166.5,2426,184.5,176.5
#
# total,50.0%,,,0.13%,,330,250000.0
#
# 2018-12-11 18:00:00
# =============Start Backtest 2018-12-11==================
# [] 0
#
# 沒有符合條件的標的
# 2018-12-12 18:00:00
# =============Start Backtest 2018-12-12==================
# [] 0
#
# 沒有符合條件的標的
# 2018-12-13 18:00:00
# =============Start Backtest 2018-12-13==================
# [] 0
#
# 沒有符合條件的標的
# 2018-12-14 18:00:00
# =============Start Backtest 2018-12-14==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-12-15
# It's Holiday 2018-12-16
# 2018-12-17 18:00:00
# =============Start Backtest 2018-12-17==================
# ['6462'] 1
#
# profitable [] 0
# unprofitable ['6462'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 6462,loss,205.5,205.5,205.5,205.5,-23734,232.5,222.5
#
# total,0.0%,,,-10.41%,,-23734,228000.0
#
# 2018-12-18 18:00:00
# =============Start Backtest 2018-12-18==================
# [] 0
#
# 沒有符合條件的標的
# 2018-12-19 18:00:00
# =============Start Backtest 2018-12-19==================
# [] 0
#
# 沒有符合條件的標的
# 2018-12-20 18:00:00
# =============Start Backtest 2018-12-20==================
# [] 0
#
# 沒有符合條件的標的
# 2018-12-21 18:00:00
# =============Start Backtest 2018-12-21==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-12-22
# It's Holiday 2018-12-23
# 2018-12-24 18:00:00
# =============Start Backtest 2018-12-24==================
# [] 0
#
# 沒有符合條件的標的
# 2018-12-25 18:00:00
# =============Start Backtest 2018-12-25==================
# [] 0
#
# 沒有符合條件的標的
# 2018-12-26 18:00:00
# =============Start Backtest 2018-12-26==================
# [] 0
#
# 沒有符合條件的標的
# 2018-12-27 18:00:00
# =============Start Backtest 2018-12-27==================
# [] 0
#
# 沒有符合條件的標的
# 2018-12-28 18:00:00
# =============Start Backtest 2018-12-28==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2018-12-29
# It's Holiday 2018-12-30
# 2018-12-31 18:00:00
# =============Start Backtest 2018-12-31==================
# It's Holiday 2018-12-31
# 2019-01-01 18:00:00
# =============Start Backtest 2019-01-01==================
# It's Holiday 2019-01-01
# 2019-01-02 18:00:00
# =============Start Backtest 2019-01-02==================
# ['8086'] 1
#
# profitable ['8086'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 8086,profit,48.2,49.2,48.5,46.85,666,48.85,46.75
#
# total,100.0%,,,1.39%,,666,47900.0
#
# 2019-01-03 18:00:00
# =============Start Backtest 2019-01-03==================
# [] 0
#
# 沒有符合條件的標的
# 2019-01-04 18:00:00
# =============Start Backtest 2019-01-04==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2019-01-05
# It's Holiday 2019-01-06
# 2019-01-07 18:00:00
# =============Start Backtest 2019-01-07==================
# [] 0
#
# 沒有符合條件的標的
# 2019-01-08 18:00:00
# =============Start Backtest 2019-01-08==================
# ['3234'] 1
#
# profitable [] 0
# unprofitable ['3234'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3234,loss,36.5,37.3,37.3,36.0,-1114,38.1,36.5
#
# total,0.0%,,,-2.98%,,-1114,37400.0
#
# 2019-01-09 18:00:00
# =============Start Backtest 2019-01-09==================
# [] 0
#
# 沒有符合條件的標的
# 2019-01-10 18:00:00
# =============Start Backtest 2019-01-10==================
# [] 0
#
# 沒有符合條件的標的
# 2019-01-11 18:00:00
# =============Start Backtest 2019-01-11==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2019-01-12
# It's Holiday 2019-01-13
# 2019-01-14 18:00:00
# =============Start Backtest 2019-01-14==================
# [] 0
#
# 沒有符合條件的標的
# 2019-01-15 18:00:00
# =============Start Backtest 2019-01-15==================
# [] 0
#
# 沒有符合條件的標的
# 2019-01-16 18:00:00
# =============Start Backtest 2019-01-16==================
# [] 0
#
# 沒有符合條件的標的
# 2019-01-17 18:00:00
# =============Start Backtest 2019-01-17==================
# [] 0
#
# 沒有符合條件的標的
# 2019-01-18 18:00:00
# =============Start Backtest 2019-01-18==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2019-01-19
# It's Holiday 2019-01-20
# 2019-01-21 18:00:00
# =============Start Backtest 2019-01-21==================
# [] 0
#
# 沒有符合條件的標的
# 2019-01-22 18:00:00
# =============Start Backtest 2019-01-22==================
# [] 0
#
# 沒有符合條件的標的
# 2019-01-23 18:00:00
# =============Start Backtest 2019-01-23==================
# [] 0
#
# 沒有符合條件的標的
# 2019-01-24 18:00:00
# =============Start Backtest 2019-01-24==================
# [] 0
#
# 沒有符合條件的標的
# 2019-01-25 18:00:00
# =============Start Backtest 2019-01-25==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2019-01-26
# It's Holiday 2019-01-27
# 2019-01-28 18:00:00
# =============Start Backtest 2019-01-28==================
# ['3105'] 1
#
# profitable [] 0
# unprofitable ['3105'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3105,loss,154.0,154.5,150.0,150.0,-2881,155.0,148.5
#
# total,0.0%,,,-1.9%,,-2881,152000.0
#
# 2019-01-29 18:00:00
# =============Start Backtest 2019-01-29==================
# [] 0
#
# 沒有符合條件的標的
# 2019-01-30 18:00:00
# =============Start Backtest 2019-01-30==================
# [] 0
#
# 沒有符合條件的標的
# 2019-01-31 18:00:00
# =============Start Backtest 2019-01-31==================
# It's Holiday 2019-01-31
# 2019-02-01 18:00:00
# =============Start Backtest 2019-02-01==================
# It's Holiday 2019-02-01
# It's Holiday 2019-02-02
# It's Holiday 2019-02-03
# 2019-02-04 18:00:00
# =============Start Backtest 2019-02-04==================
# It's Holiday 2019-02-04
# 2019-02-05 18:00:00
# =============Start Backtest 2019-02-05==================
# It's Holiday 2019-02-05
# 2019-02-06 18:00:00
# =============Start Backtest 2019-02-06==================
# It's Holiday 2019-02-06
# 2019-02-07 18:00:00
# ...
#
# 沒有符合條件的標的
# 2019-07-18 18:00:00
# =============Start Backtest 2019-07-18==================
# ['4968'] 1
#
# profitable ['4968'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 4968,profit,108.0,117.5,117.5,108.0,1366,109.0,104.5
#
# total,100.0%,,,1.28%,,1366,107000.0
#
# 2019-07-19 18:00:00
# =============Start Backtest 2019-07-19==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2019-07-20
# It's Holiday 2019-07-21
# 2019-07-22 18:00:00
# =============Start Backtest 2019-07-22==================
# ['2387'] 1
#
# profitable ['2387'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2387,profit,33.0,34.25,33.55,32.2,455,33.45,32.0
#
# total,100.0%,,,1.39%,,455,32800.0
#
# 2019-07-23 18:00:00
# =============Start Backtest 2019-07-23==================
# [] 0
#
# 沒有符合條件的標的
# 2019-07-24 18:00:00
# =============Start Backtest 2019-07-24==================
# [] 0
#
# 沒有符合條件的標的
# 2019-07-25 18:00:00
# =============Start Backtest 2019-07-25==================
# ['3374'] 1
#
# profitable [] 0
# unprofitable ['3374'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3374,loss,51.3,51.6,51.5,50.1,-1496,52.5,50.3
#
# total,0.0%,,,-2.9%,,-1496,51500.0
#
# 2019-07-26 18:00:00
# =============Start Backtest 2019-07-26==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2019-07-27
# It's Holiday 2019-07-28
# 2019-07-29 18:00:00
# =============Start Backtest 2019-07-29==================
# [] 0
#
# 沒有符合條件的標的
# 2019-07-30 18:00:00
# =============Start Backtest 2019-07-30==================
# [] 0
#
# 沒有符合條件的標的
# 2019-07-31 18:00:00
# =============Start Backtest 2019-07-31==================
# [] 0
#
# 沒有符合條件的標的
# 2019-08-01 18:00:00
# =============Start Backtest 2019-08-01==================
# ['2387'] 1
#
# profitable ['2387'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2387,profit,39.35,43.55,42.9,39.35,513,40.65,38.95
#
# total,100.0%,,,1.29%,,513,39900.0
#
# 2019-08-02 18:00:00
# =============Start Backtest 2019-08-02==================
# ['2387'] 1
#
# profitable [] 0
# unprofitable ['2387'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2387,loss,42.4,42.9,39.55,39.55,-1295,43.75,41.85
#
# total,0.0%,,,-3.02%,,-1295,42900.0
#
# It's Holiday 2019-08-03
# It's Holiday 2019-08-04
# 2019-08-05 18:00:00
# =============Start Backtest 2019-08-05==================
# [] 0
#
# 沒有符合條件的標的
# 2019-08-06 18:00:00
# =============Start Backtest 2019-08-06==================
# [] 0
#
# 沒有符合條件的標的
# 2019-08-07 18:00:00
# =============Start Backtest 2019-08-07==================
# [] 0
#
# 沒有符合條件的標的
# 2019-08-08 18:00:00
# =============Start Backtest 2019-08-08==================
# [] 0
#
# 沒有符合條件的標的
# 2019-08-09 18:00:00
# =============Start Backtest 2019-08-09==================
# It's Holiday 2019-08-09
# It's Holiday 2019-08-10
# It's Holiday 2019-08-11
# 2019-08-12 18:00:00
# =============Start Backtest 2019-08-12==================
# [] 0
#
# 沒有符合條件的標的
# 2019-08-13 18:00:00
# =============Start Backtest 2019-08-13==================
# ['2421'] 1
#
# profitable [] 0
# unprofitable ['2421'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2421,loss,41.85,43.2,41.75,41.0,-1295,43.55,41.65
#
# total,0.0%,,,-3.03%,,-1295,42700.0
#
# 2019-08-14 18:00:00
# =============Start Backtest 2019-08-14==================
# ['3338', '4968'] 2
#
# profitable ['3338', '4968'] 2
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3338,profit,83.1,83.3,83.0,80.1,3819,80.3,76.9
#
# 4968,profit,145.0,152.0,143.0,139.5,1652,145.5,139.5
#
# total,100.0%,,,2.47%,,5471,221800.0
#
# 2019-08-15 18:00:00
# =============Start Backtest 2019-08-15==================
# ['8358'] 1
#
# profitable ['8358'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 8358,profit,40.5,42.3,41.8,40.0,553,42.3,40.5
#
# total,100.0%,,,1.33%,,553,41500.0
#
# 2019-08-16 18:00:00
# =============Start Backtest 2019-08-16==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2019-08-17
# It's Holiday 2019-08-18
# 2019-08-19 18:00:00
# =============Start Backtest 2019-08-19==================
# [] 0
#
# 沒有符合條件的標的
# 2019-08-20 18:00:00
# =============Start Backtest 2019-08-20==================
# ['6290'] 1
#
# profitable ['6290'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 6290,profit,66.8,68.8,67.3,65.9,904,67.8,64.9
#
# total,100.0%,,,1.36%,,904,66500.0
#
# 2019-08-21 18:00:00
# =============Start Backtest 2019-08-21==================
# [] 0
#
# 沒有符合條件的標的
# 2019-08-22 18:00:00
# =============Start Backtest 2019-08-22==================
# [] 0
#
# 沒有符合條件的標的
# 2019-08-23 18:00:00
# =============Start Backtest 2019-08-23==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2019-08-24
# It's Holiday 2019-08-25
# 2019-08-26 18:00:00
# =============Start Backtest 2019-08-26==================
# ['3338'] 1
#
# profitable [] 0
# unprofitable ['3338'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3338,loss,100.5,102.5,96.5,96.5,-3088,104.5,100.0
#
# total,0.0%,,,-3.01%,,-3088,102500.0
#
# 2019-08-27 18:00:00
# =============Start Backtest 2019-08-27==================
# [] 0
#
# 沒有符合條件的標的
# 2019-08-28 18:00:00
# =============Start Backtest 2019-08-28==================
# [] 0
#
# 沒有符合條件的標的
# 2019-08-29 18:00:00
# =============Start Backtest 2019-08-29==================
# [] 0
#
# 沒有符合條件的標的
# 2019-08-30 18:00:00
# =============Start Backtest 2019-08-30==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2019-08-31
# It's Holiday 2019-09-01
# 2019-09-02 18:00:00
# =============Start Backtest 2019-09-02==================
# ['2367'] 1
#
# profitable ['2367'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2367,profit,30.6,31.1,31.1,29.65,522,30.45,29.2
#
# total,100.0%,,,1.75%,,522,29900.0
#
# 2019-09-03 18:00:00
# =============Start Backtest 2019-09-03==================
# [] 0
#
# 沒有符合條件的標的
# 2019-09-04 18:00:00
# =============Start Backtest 2019-09-04==================
# [] 0
#
# 沒有符合條件的標的
# 2019-09-05 18:00:00
# =============Start Backtest 2019-09-05==================
# [] 0
#
# 沒有符合條件的標的
# 2019-09-06 18:00:00
# =============Start Backtest 2019-09-06==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2019-09-07
# It's Holiday 2019-09-08
# 2019-09-09 18:00:00
# =============Start Backtest 2019-09-09==================
# [] 0
#
# 沒有符合條件的標的
# 2019-09-10 18:00:00
# =============Start Backtest 2019-09-10==================
# ['8086'] 1
#
# profitable [] 0
# unprofitable ['8086'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 8086,loss,82.8,83.5,81.2,79.5,-2476,84.6,81.0
#
# total,0.0%,,,-2.98%,,-2476,83000.0
#
# 2019-09-11 18:00:00
# =============Start Backtest 2019-09-11==================
# [] 0
#
# 沒有符合條件的標的
# 2019-09-12 18:00:00
# =============Start Backtest 2019-09-12==================
# [] 0
#
# 沒有符合條件的標的
# 2019-09-13 18:00:00
# =============Start Backtest 2019-09-13==================
# It's Holiday 2019-09-13
# It's Holiday 2019-09-14
# It's Holiday 2019-09-15
# 2019-09-16 18:00:00
# =============Start Backtest 2019-09-16==================
# [] 0
#
# 沒有符合條件的標的
# 2019-09-17 18:00:00
# =============Start Backtest 2019-09-17==================
# [] 0
#
# 沒有符合條件的標的
# 2019-09-18 18:00:00
# =============Start Backtest 2019-09-18==================
# [] 0
#
# 沒有符合條件的標的
# 2019-09-19 18:00:00
# =============Start Backtest 2019-09-19==================
# [] 0
#
# 沒有符合條件的標的
# 2019-09-20 18:00:00
# =============Start Backtest 2019-09-20==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2019-09-21
# It's Holiday 2019-09-22
# 2019-09-23 18:00:00
# =============Start Backtest 2019-09-23==================
# ['3661'] 1
#
# profitable [] 0
# unprofitable ['3661'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3661,loss,161.5,166.0,164.0,160.0,-4942,167.0,160.0
#
# total,0.0%,,,-3.01%,,-4942,164000.0
#
# 2019-09-24 18:00:00
# =============Start Backtest 2019-09-24==================
# ['3041'] 1
#
# profitable ['3041'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3041,profit,14.0,15.3,14.3,13.65,167,14.25,13.7
#
# total,100.0%,,,1.19%,,167,14000.0
#
# 2019-09-25 18:00:00
# =============Start Backtest 2019-09-25==================
# [] 0
#
# 沒有符合條件的標的
# 2019-09-26 18:00:00
# =============Start Backtest 2019-09-26==================
# ['6233'] 1
#
# profitable ['6233'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 6233,profit,15.4,16.7,16.35,15.4,207,16.05,15.4
#
# total,100.0%,,,1.31%,,207,15750.0
#
# 2019-09-27 18:00:00
# =============Start Backtest 2019-09-27==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2019-09-28
# It's Holiday 2019-09-29
# 2019-09-30 18:00:00
# =============Start Backtest 2019-09-30==================
# It's Holiday 2019-09-30
# 2019-10-01 18:00:00
# =============Start Backtest 2019-10-01==================
# [] 0
#
# 沒有符合條件的標的
# 2019-10-02 18:00:00
# =============Start Backtest 2019-10-02==================
# [] 0
#
# 沒有符合條件的標的
# 2019-10-03 18:00:00
# =============Start Backtest 2019-10-03==================
# [] 0
#
# 沒有符合條件的標的
# 2019-10-04 18:00:00
# =============Start Backtest 2019-10-04==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2019-10-05
# It's Holiday 2019-10-06
# 2019-10-07 18:00:00
# =============Start Backtest 2019-10-07==================
# [] 0
#
# 沒有符合條件的標的
# 2019-10-08 18:00:00
# =============Start Backtest 2019-10-08==================
# [] 0
#
# 沒有符合條件的標的
# 2019-10-09 18:00:00
# =============Start Backtest 2019-10-09==================
# [] 0
#
# 沒有符合條件的標的
# 2019-10-10 18:00:00
# =============Start Backtest 2019-10-10==================
# It's Holiday 2019-10-10
# 2019-10-11 18:00:00
# =============Start Backtest 2019-10-11==================
# It's Holiday 2019-10-11
# It's Holiday 2019-10-12
# It's Holiday 2019-10-13
# 2019-10-14 18:00:00
# =============Start Backtest 2019-10-14==================
# [] 0
#
# 沒有符合條件的標的
# 2019-10-15 18:00:00
# =============Start Backtest 2019-10-15==================
# [] 0
#
# 沒有符合條件的標的
# 2019-10-16 18:00:00
# =============Start Backtest 2019-10-16==================
# [] 0
#
# 沒有符合條件的標的
# 2019-10-17 18:00:00
# =============Start Backtest 2019-10-17==================
# ['2504'] 1
#
# profitable ['2504'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 2504,profit,13.0,13.85,13.1,12.65,172,13.25,12.7
#
# total,100.0%,,,1.32%,,172,13000.0
#
# 2019-10-18 18:00:00
# =============Start Backtest 2019-10-18==================
# ['8086'] 1
#
# profitable [] 0
# unprofitable ['8086'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 8086,loss,110.0,111.5,108.0,107.5,-3133,112.0,107.5
#
# total,0.0%,,,-2.85%,,-3133,110000.0
#
# It's Holiday 2019-10-19
# It's Holiday 2019-10-20
# 2019-10-21 18:00:00
# =============Start Backtest 2019-10-21==================
# [] 0
#
# 沒有符合條件的標的
# 2019-10-22 18:00:00
# =============Start Backtest 2019-10-22==================
# [] 0
#
# 沒有符合條件的標的
# 2019-10-23 18:00:00
# =============Start Backtest 2019-10-23==================
# [] 0
#
# 沒有符合條件的標的
# 2019-10-24 18:00:00
# =============Start Backtest 2019-10-24==================
# [] 0
#
# 沒有符合條件的標的
# 2019-10-25 18:00:00
# =============Start Backtest 2019-10-25==================
# ['3374'] 1
#
# profitable ['3374'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3374,profit,57.3,59.4,58.4,57.2,761,58.2,55.7
#
# total,100.0%,,,1.33%,,761,57100.0
#
# It's Holiday 2019-10-26
# It's Holiday 2019-10-27
# 2019-10-28 18:00:00
# =============Start Backtest 2019-10-28==================
# ['6278'] 1
#
# profitable ['6278'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 6278,profit,97.2,98.7,96.1,93.5,1325,98.7,94.4
#
# total,100.0%,,,1.37%,,1325,96800.0
#
# 2019-10-29 18:00:00
# =============Start Backtest 2019-10-29==================
# ['3374'] 1
#
# profitable [] 0
# unprofitable ['3374'] 1
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3374,loss,63.0,63.3,62.5,59.6,-1859,63.7,61.0
#
# total,0.0%,,,-2.97%,,-1859,62500.0
#
# 2019-10-30 18:00:00
# =============Start Backtest 2019-10-30==================
# [] 0
#
# 沒有符合條件的標的
# 2019-10-31 18:00:00
# =============Start Backtest 2019-10-31==================
# [] 0
#
# 沒有符合條件的標的
# 2019-11-01 18:00:00
# =============Start Backtest 2019-11-01==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2019-11-02
# It's Holiday 2019-11-03
# 2019-11-04 18:00:00
# =============Start Backtest 2019-11-04==================
# [] 0
#
# 沒有符合條件的標的
# 2019-11-05 18:00:00
# =============Start Backtest 2019-11-05==================
# [] 0
#
# 沒有符合條件的標的
# 2019-11-06 18:00:00
# =============Start Backtest 2019-11-06==================
# [] 0
#
# 沒有符合條件的標的
# 2019-11-07 18:00:00
# =============Start Backtest 2019-11-07==================
# [] 0
#
# 沒有符合條件的標的
# 2019-11-08 18:00:00
# =============Start Backtest 2019-11-08==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2019-11-09
# It's Holiday 2019-11-10
# 2019-11-11 18:00:00
# =============Start Backtest 2019-11-11==================
# [] 0
#
# 沒有符合條件的標的
# 2019-11-12 18:00:00
# =============Start Backtest 2019-11-12==================
# [] 0
#
# 沒有符合條件的標的
# 2019-11-13 18:00:00
# =============Start Backtest 2019-11-13==================
# [] 0
#
# 沒有符合條件的標的
# 2019-11-14 18:00:00
# =============Start Backtest 2019-11-14==================
# [] 0
#
# 沒有符合條件的標的
# 2019-11-15 18:00:00
# =============Start Backtest 2019-11-15==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2019-11-16
# It's Holiday 2019-11-17
# 2019-11-18 18:00:00
# =============Start Backtest 2019-11-18==================
# [] 0
#
# 沒有符合條件的標的
# 2019-11-19 18:00:00
# =============Start Backtest 2019-11-19==================
# [] 0
#
# 沒有符合條件的標的
# 2019-11-20 18:00:00
# =============Start Backtest 2019-11-20==================
# [] 0
#
# 沒有符合條件的標的
# 2019-11-21 18:00:00
# =============Start Backtest 2019-11-21==================
# [] 0
#
# 沒有符合條件的標的
# 2019-11-22 18:00:00
# =============Start Backtest 2019-11-22==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2019-11-23
# It's Holiday 2019-11-24
# 2019-11-25 18:00:00
# =============Start Backtest 2019-11-25==================
# [] 0
#
# 沒有符合條件的標的
# 2019-11-26 18:00:00
# =============Start Backtest 2019-11-26==================
# [] 0
#
# 沒有符合條件的標的
# 2019-11-27 18:00:00
# =============Start Backtest 2019-11-27==================
# [] 0
#
# 沒有符合條件的標的
# 2019-11-28 18:00:00
# =============Start Backtest 2019-11-28==================
# [] 0
#
# 沒有符合條件的標的
# 2019-11-29 18:00:00
# =============Start Backtest 2019-11-29==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2019-11-30
# It's Holiday 2019-12-01
# 2019-12-02 18:00:00
# =============Start Backtest 2019-12-02==================
# [] 0
#
# 沒有符合條件的標的
# 2019-12-03 18:00:00
# =============Start Backtest 2019-12-03==================
# [] 0
#
# 沒有符合條件的標的
# 2019-12-04 18:00:00
# =============Start Backtest 2019-12-04==================
# [] 0
#
# 沒有符合條件的標的
# 2019-12-05 18:00:00
# =============Start Backtest 2019-12-05==================
# [] 0
#
# 沒有符合條件的標的
# 2019-12-06 18:00:00
# =============Start Backtest 2019-12-06==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2019-12-07
# It's Holiday 2019-12-08
# 2019-12-09 18:00:00
# =============Start Backtest 2019-12-09==================
# [] 0
#
# 沒有符合條件的標的
# 2019-12-10 18:00:00
# =============Start Backtest 2019-12-10==================
# [] 0
#
# 沒有符合條件的標的
# 2019-12-11 18:00:00
# =============Start Backtest 2019-12-11==================
# [] 0
#
# 沒有符合條件的標的
# 2019-12-12 18:00:00
# =============Start Backtest 2019-12-12==================
# [] 0
#
# 沒有符合條件的標的
# 2019-12-13 18:00:00
# =============Start Backtest 2019-12-13==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2019-12-14
# It's Holiday 2019-12-15
# 2019-12-16 18:00:00
# =============Start Backtest 2019-12-16==================
# [] 0
#
# 沒有符合條件的標的
# 2019-12-17 18:00:00
# =============Start Backtest 2019-12-17==================
# [] 0
#
# 沒有符合條件的標的
# 2019-12-18 18:00:00
# =============Start Backtest 2019-12-18==================
# [] 0
#
# 沒有符合條件的標的
# 2019-12-19 18:00:00
# =============Start Backtest 2019-12-19==================
# [] 0
#
# 沒有符合條件的標的
# 2019-12-20 18:00:00
# =============Start Backtest 2019-12-20==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2019-12-21
# It's Holiday 2019-12-22
# 2019-12-23 18:00:00
# =============Start Backtest 2019-12-23==================
# [] 0
#
# 沒有符合條件的標的
# 2019-12-24 18:00:00
# =============Start Backtest 2019-12-24==================
# [] 0
#
# 沒有符合條件的標的
# 2019-12-25 18:00:00
# =============Start Backtest 2019-12-25==================
# [] 0
#
# 沒有符合條件的標的
# 2019-12-26 18:00:00
# =============Start Backtest 2019-12-26==================
# [] 0
#
# 沒有符合條件的標的
# 2019-12-27 18:00:00
# =============Start Backtest 2019-12-27==================
# [] 0
#
# 沒有符合條件的標的
# It's Holiday 2019-12-28
# It's Holiday 2019-12-29
# 2019-12-30 18:00:00
# =============Start Backtest 2019-12-30==================
# [] 0
#
# 沒有符合條件的標的
# 2019-12-31 18:00:00
# =============Start Backtest 2019-12-31==================
# [] 0
#
# 沒有符合條件的標的

# %%
# for date in pd.date_range(datetime(2021, 7, 1), datetime.today()):
#     try:
date = datetime(2022,3,18)
BacktestCrossDayTradeV2(date, .02, .025)
#     except KeyboardInterrupt:
#         break
# Out:
# 2022-03-18 18:00:00
# =============Start Backtest 2022-03-18==================
# ['3016'] 1
#
# profitable ['3016'] 1
# unprofitable [] 0
# Ticker,P/L,Open,High,Low,Close,pnl,TakeProfit,StopLoss
#
# 3016,profit,123.0,125.0,125.0,119.5,1272,125.0,120.0
#
# total,100.0%,,,1.03%,,1272,123000.0

# %%
pnl_cum = []
for back_date in pd.date_range(datetime(2018,1,1), datetime.today()):#
# for back_date in pd.date_range(datetime(2021,8,1), datetime(2022,8,31)):#.today()
    dtStr = back_date.strftime("%Y%m%d")
    f_path = os.path.join(output_path, f"{dtStr}_ProfitLoss.csv")
    if os.path.isfile(f_path):
        try:
            with open(f_path, 'r') as f:
                lines = f.readlines()
#                 print(dtStr, lines[-1])
                pnl_cum.append({
                    "Date":back_date.strftime("%Y-%m-%d"),
                    "PnL":int(lines[-1].split(',')[-2]),
                    "TradeValue":int(float(lines[-1].split(',')[-1]))
                })
        except:
            print(lines[-1])
# Out:
# Ticker,P/L,OpenRet,HighRet,LowRet,CloseRet,pnl
#
# Ticker,P/L,OpenRet,HighRet,LowRet,CloseRet,pnl

# %%
pd.DataFrame(pnl_cum).set_index('Date').PnL.cumsum().plot(figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
pd.DataFrame(pnl_cum).set_index('Date').TradeValue.plot(figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# import pandas as pd
# import quandl as qdl
from pandas_datareader import data as web
from scipy.stats import linregress

# get AAPL 10 years data

# data = qdl.get("WIKI/AAPL", start_date="2007-01-01", end_date="2017-05-01")
data = web.DataReader("AAPL",'yahoo',"2007-01-01", "2017-05-01")
# print(data)
data0 = data.copy()

data0['date_id'] = ((data0.index.date - data0.index.date.min())).astype('timedelta64[D]')
data0['date_id'] = data0['date_id'].dt.days + 1

# high trend line
print(data0['date_id'])
data1 = data0.copy()

while len(data1)>3:

    reg = linregress(
                    x=data1['date_id'],
                    y=data1['High'],
                    )
    data1 = data1.loc[data1['High'] > reg[0] * data1['date_id'] + reg[1]]

reg = linregress(
                    x=data1['date_id'],
                    y=data1['High'],
                    )

data0['high_trend'] = reg[0] * data0['date_id'] + reg[1]

# low trend line

data1 = data0.copy()

while len(data1)>3:

    reg = linregress(
                    x=data1['date_id'],
                    y=data1['Low'],
                    )
    data1 = data1.loc[data1['Low'] < reg[0] * data1['date_id'] + reg[1]]

reg = linregress(
                    x=data1['date_id'],
                    y=data1['Low'],
                    )

data0['low_trend'] = reg[0] * data0['date_id'] + reg[1]

# plot

data0['Adj Close'].plot()
data0['high_trend'].plot()
data0['low_trend'].plot()
# Out:
# Date
# 2007-01-03       1
# 2007-01-04       2
# 2007-01-05       3
# 2007-01-08       6
# 2007-01-09       7
#               ...
# 2017-04-25    3766
# 2017-04-26    3767
# 2017-04-27    3768
# 2017-04-28    3769
# 2017-05-01    3772
# Name: date_id, Length: 2600, dtype: int64
# <AxesSubplot:xlabel='Date'>
